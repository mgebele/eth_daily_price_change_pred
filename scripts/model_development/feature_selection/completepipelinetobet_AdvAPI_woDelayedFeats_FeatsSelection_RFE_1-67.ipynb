# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Data-Import-via-Application-Programming-Interfaces" data-toc-modified-id="Data-Import-via-Application-Programming-Interfaces-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data Import via Application Programming Interfaces</a></span><ul class="toc-item"><li><span><a href="#Blockchain-Data-from-Glassnode" data-toc-modified-id="Blockchain-Data-from-Glassnode-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Blockchain Data from Glassnode</a></span><ul class="toc-item"><li><span><a href="#Market-Metrics-from-Glassnode" data-toc-modified-id="Market-Metrics-from-Glassnode-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Market Metrics from Glassnode</a></span></li><li><span><a href="#Mining-Metrics-from-Glassnode" data-toc-modified-id="Mining-Metrics-from-Glassnode-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Mining Metrics from Glassnode</a></span></li><li><span><a href="#Blocks-Metrics-from-Glassnode" data-toc-modified-id="Blocks-Metrics-from-Glassnode-1.1.1.3"><span class="toc-item-num">1.1.1.3&nbsp;&nbsp;</span>Blocks Metrics from Glassnode</a></span></li><li><span><a href="#Distribution-Metrics-from-Glassnode" data-toc-modified-id="Distribution-Metrics-from-Glassnode-1.1.1.4"><span class="toc-item-num">1.1.1.4&nbsp;&nbsp;</span>Distribution Metrics from Glassnode</a></span></li><li><span><a href="#Fee-Metrics-from-Glassnode" data-toc-modified-id="Fee-Metrics-from-Glassnode-1.1.1.5"><span class="toc-item-num">1.1.1.5&nbsp;&nbsp;</span>Fee Metrics from Glassnode</a></span></li><li><span><a href="#UTXO-Metrics-from-Glassnode" data-toc-modified-id="UTXO-Metrics-from-Glassnode-1.1.1.6"><span class="toc-item-num">1.1.1.6&nbsp;&nbsp;</span>UTXO Metrics from Glassnode</a></span></li><li><span><a href="#Supply-Metrics-from-Glassnode" data-toc-modified-id="Supply-Metrics-from-Glassnode-1.1.1.7"><span class="toc-item-num">1.1.1.7&nbsp;&nbsp;</span>Supply Metrics from Glassnode</a></span></li><li><span><a href="#Transaction-Metrics-from-Glassnode" data-toc-modified-id="Transaction-Metrics-from-Glassnode-1.1.1.8"><span class="toc-item-num">1.1.1.8&nbsp;&nbsp;</span>Transaction Metrics from Glassnode</a></span></li><li><span><a href="#Exchange-Metrics-from-Glassnode---1-Month-Lag" data-toc-modified-id="Exchange-Metrics-from-Glassnode---1-Month-Lag-1.1.1.9"><span class="toc-item-num">1.1.1.9&nbsp;&nbsp;</span>Exchange Metrics from Glassnode - 1 Month Lag</a></span></li><li><span><a href="#Indicator-I-Metrics-from-Glassnode" data-toc-modified-id="Indicator-I-Metrics-from-Glassnode-1.1.1.10"><span class="toc-item-num">1.1.1.10&nbsp;&nbsp;</span>Indicator-I Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-2-Metrics-from-Glassnode" data-toc-modified-id="Indicator-2-Metrics-from-Glassnode-1.1.1.11"><span class="toc-item-num">1.1.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-3-Metrics-from-Glassnode" data-toc-modified-id="Indicator-3-Metrics-from-Glassnode-1.1.1.12"><span class="toc-item-num">1.1.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics from Glassnode</a></span></li><li><span><a href="#Addresses-Metrics-from-Glassnode" data-toc-modified-id="Addresses-Metrics-from-Glassnode-1.1.1.13"><span class="toc-item-num">1.1.1.13&nbsp;&nbsp;</span>Addresses Metrics from Glassnode</a></span></li><li><span><a href="#Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020-1.1.1.14"><span class="toc-item-num">1.1.1.14&nbsp;&nbsp;</span>Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Futures-Features" data-toc-modified-id="List-of-Futures-Features-1.1.1.14.1"><span class="toc-item-num">1.1.1.14.1&nbsp;&nbsp;</span>List of Futures Features</a></span></li><li><span><a href="#Data-Frame-of-Future-features" data-toc-modified-id="Data-Frame-of-Future-features-1.1.1.14.2"><span class="toc-item-num">1.1.1.14.2&nbsp;&nbsp;</span>Data Frame of Future features</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#File-Import-and-Data-Tidying" data-toc-modified-id="File-Import-and-Data-Tidying-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>File Import and Data Tidying</a></span><ul class="toc-item"><li><span><a href="#Import-Blockchain-CSV-Files" data-toc-modified-id="Import-Blockchain-CSV-Files-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Import Blockchain CSV-Files</a></span><ul class="toc-item"><li><span><a href="#Market-Metric-CSV-Files" data-toc-modified-id="Market-Metric-CSV-Files-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>Market Metric CSV-Files</a></span></li><li><span><a href="#Mining-Metric-CSV-Files" data-toc-modified-id="Mining-Metric-CSV-Files-1.2.1.2"><span class="toc-item-num">1.2.1.2&nbsp;&nbsp;</span>Mining Metric CSV-Files</a></span></li><li><span><a href="#Blocks-Metric-CSV-Files" data-toc-modified-id="Blocks-Metric-CSV-Files-1.2.1.3"><span class="toc-item-num">1.2.1.3&nbsp;&nbsp;</span>Blocks Metric CSV-Files</a></span></li><li><span><a href="#Distribution-Metric-CSV-Files" data-toc-modified-id="Distribution-Metric-CSV-Files-1.2.1.4"><span class="toc-item-num">1.2.1.4&nbsp;&nbsp;</span>Distribution Metric CSV-Files</a></span></li><li><span><a href="#Fee-Metric-CSV-Files" data-toc-modified-id="Fee-Metric-CSV-Files-1.2.1.5"><span class="toc-item-num">1.2.1.5&nbsp;&nbsp;</span>Fee Metric CSV-Files</a></span></li><li><span><a href="#UTXO-Metric-CSV-Files" data-toc-modified-id="UTXO-Metric-CSV-Files-1.2.1.6"><span class="toc-item-num">1.2.1.6&nbsp;&nbsp;</span>UTXO Metric CSV-Files</a></span></li><li><span><a href="#Supply-Metric-CSV-Files" data-toc-modified-id="Supply-Metric-CSV-Files-1.2.1.7"><span class="toc-item-num">1.2.1.7&nbsp;&nbsp;</span>Supply Metric CSV-Files</a></span></li><li><span><a href="#Transaction-Metric-CSV-Files" data-toc-modified-id="Transaction-Metric-CSV-Files-1.2.1.8"><span class="toc-item-num">1.2.1.8&nbsp;&nbsp;</span>Transaction Metric CSV-Files</a></span></li><li><span><a href="#Exchange-Metrics-CSV-Files" data-toc-modified-id="Exchange-Metrics-CSV-Files-1.2.1.9"><span class="toc-item-num">1.2.1.9&nbsp;&nbsp;</span>Exchange Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-1-Metric-CSV-Files" data-toc-modified-id="Indicator-1-Metric-CSV-Files-1.2.1.10"><span class="toc-item-num">1.2.1.10&nbsp;&nbsp;</span>Indicator-1 Metric CSV-Files</a></span></li><li><span><a href="#Indicator-2-Metrics-CSV-Files" data-toc-modified-id="Indicator-2-Metrics-CSV-Files-1.2.1.11"><span class="toc-item-num">1.2.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-3-Metrics-CSV-Files" data-toc-modified-id="Indicator-3-Metrics-CSV-Files-1.2.1.12"><span class="toc-item-num">1.2.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics CSV-Files</a></span></li><li><span><a href="#Addresses-Metric-CSV-Files" data-toc-modified-id="Addresses-Metric-CSV-Files-1.2.1.13"><span class="toc-item-num">1.2.1.13&nbsp;&nbsp;</span>Addresses Metric CSV-Files</a></span></li><li><span><a href="#Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020-1.2.1.14"><span class="toc-item-num">1.2.1.14&nbsp;&nbsp;</span>Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Future-Features" data-toc-modified-id="List-of-Future-Features-1.2.1.14.1"><span class="toc-item-num">1.2.1.14.1&nbsp;&nbsp;</span>List of Future Features</a></span></li><li><span><a href="#Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension" data-toc-modified-id="Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension-1.2.1.14.2"><span class="toc-item-num">1.2.1.14.2&nbsp;&nbsp;</span>Counter to Differentiate between Data Frame Setup and Data Frame Extension</a></span></li><li><span><a href="#For-Loop-through-all-Features-in-the-List" data-toc-modified-id="For-Loop-through-all-Features-in-the-List-1.2.1.14.3"><span class="toc-item-num">1.2.1.14.3&nbsp;&nbsp;</span>For Loop through all Features in the List</a></span></li><li><span><a href="#Store-Data-Frame-Copy-in-Market-Data-Frame" data-toc-modified-id="Store-Data-Frame-Copy-in-Market-Data-Frame-1.2.1.14.4"><span class="toc-item-num">1.2.1.14.4&nbsp;&nbsp;</span>Store Data Frame Copy in Market Data Frame</a></span></li><li><span><a href="#Delete-Original-Data-Frame" data-toc-modified-id="Delete-Original-Data-Frame-1.2.1.14.5"><span class="toc-item-num">1.2.1.14.5&nbsp;&nbsp;</span>Delete Original Data Frame</a></span></li><li><span><a href="#Change-Data-Type-of-Columns-to-Float" data-toc-modified-id="Change-Data-Type-of-Columns-to-Float-1.2.1.14.6"><span class="toc-item-num">1.2.1.14.6&nbsp;&nbsp;</span>Change Data Type of Columns to Float</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Target-Variables" data-toc-modified-id="Target-Variables-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Target Variables</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Volatility" data-toc-modified-id="Volatility-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Volatility</a></span></li><li><span><a href="#Log-Price" data-toc-modified-id="Log-Price-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Log Price</a></span></li></ul></li></ul></li><li><span><a href="#Data-Sets" data-toc-modified-id="Data-Sets-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I.---Blockchain-Metrics-Only" data-toc-modified-id="Data-Set-I.---Blockchain-Metrics-Only-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data Set I. - Blockchain Metrics Only</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-Variations" data-toc-modified-id="Classification-Models---Data-Set-Variations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Classification Models - Data Set Variations</a></span></li><li><span><a href="#Import-Data-Sets" data-toc-modified-id="Import-Data-Sets-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Data Set I.</a></span></li><li><span><a href="#Prediction-Shift" data-toc-modified-id="Prediction-Shift-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Prediction Shift</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Data Set I.</a></span></li></ul></li></ul></li><li><span><a href="#Classification-Setup" data-toc-modified-id="Classification-Setup-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Classification Setup</a></span><ul class="toc-item"><li><span><a href="#Create-Data-Set-Copies-for-Trading-Strategy" data-toc-modified-id="Create-Data-Set-Copies-for-Trading-Strategy-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Create Data Set Copies for Trading Strategy</a></span></li><li><span><a href="#Categorization---Data-Set-I." data-toc-modified-id="Categorization---Data-Set-I.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Categorization - Data Set I.</a></span></li></ul></li><li><span><a href="#Model-Preparation---Data-Set-I." data-toc-modified-id="Model-Preparation---Data-Set-I.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model Preparation - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split---Data-Set-I." data-toc-modified-id="Train-Test-Split---Data-Set-I.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Train Test Split - Data Set I.</a></span></li></ul></li><li><span><a href="#Explore-Number-of-Features" data-toc-modified-id="Explore-Number-of-Features-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Explore Number of Features</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Check-of-Class-Balance" data-toc-modified-id="Check-of-Class-Balance-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Check of Class Balance</a></span></li></ul></li><li><span><a href="#Feature-Scaling---Data-Set-I." data-toc-modified-id="Feature-Scaling---Data-Set-I.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Feature Scaling - Data Set I.</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-I." data-toc-modified-id="Classification-Models---Data-Set-I.-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Classification Models - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression---Data-Set-I." data-toc-modified-id="Logistic-Regression---Data-Set-I.-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Logistic Regression - Data Set I.</a></span></li><li><span><a href="#Random-Forest-Classifier---Data-Set-I." data-toc-modified-id="Random-Forest-Classifier---Data-Set-I.-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Random Forest Classifier - Data Set I.</a></span></li></ul></li><li><span><a href="#Trading-Strategy---Data-Set-I" data-toc-modified-id="Trading-Strategy---Data-Set-I-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Trading Strategy - Data Set I</a></span><ul class="toc-item"><li><span><a href="#Trading-Strategy-in-Combination-with-Logistic-Regression" data-toc-modified-id="Trading-Strategy-in-Combination-with-Logistic-Regression-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Trading Strategy in Combination with Logistic Regression</a></span></li></ul></li><li><span><a href="#Bet-on-tomorrow" data-toc-modified-id="Bet-on-tomorrow-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Bet on tomorrow</a></span></li><li><span><a href="#get-x-train-data-of-today-to-predict-tomorrow-y" data-toc-modified-id="get-x-train-data-of-today-to-predict-tomorrow-y-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>get x train data of today to predict tomorrow y</a></span></li></ul></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Import via Application Programming Interfaces

# %%
# Import of Modules and Packages
import os
import requests
import json
import datetime
import yfinance as yf
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pytrends.request import TrendReq
from pytrends import dailydata

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %%
# Glassnode API Key
API_Key =''

# %%
os.getcwd()
# Out:
# 'C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010\\model development\\Feature Selection'

# %%
os.chdir('C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010\\Glassnode')

# %% [markdown]
# ### Blockchain Data from Glassnode

# %%
# Import Function for a Single Feature Variable from Glassnode
def import_glassnode (url, feature_name):
    data = requests.get(url).json()
    df = pd.json_normalize(data)
    
    # Rename columns
    df.columns = ['Date', feature_name]
   
    # Convert Object to Datetime Object
    df.Date = pd.to_datetime(df.Date, unit='s')
    df.Date = df.Date.map(lambda x: x.strftime('%Y-%m-%d'))
    
    # Set Date Column as Index
    df.set_index('Date', inplace=True)
    
    # Drop Missing Values
    df = df.dropna()
    
    # Change Data Type to Float
    df = df.astype(float)
    
    # Creation of CSV-File, Part of Feature Name as CSV File Name 
    df.to_csv("{}.csv".format(feature_name.rsplit('/')[-1]), decimal=',')
    
    # Plot of DataFrame
    #df.plot(figsize=(4.5, 1.75))
    #plt.xticks(rotation=45)
    return df

# %%
# Import Function for Several Feature Variables from Glassnode
def import_glassnode_many(feature_list):
    # Counter to Differentiate between Data Frame Setup and Data Frame Join
    counter=0
    
    # For Loop through all Features in the List
    for feature in feature_list:
        
        # URL
        url = 'https://api.glassnode.com/v1/metrics/{}?a=btc&f=json&api_key={}'.format(feature, API_Key)
        
        # Execute Import Function for a Single Feature Variable
        df=import_glassnode(url, feature)
        
        # Display Data Frame Tail
        print(df.tail())
        
        # Condition - Data Frame Set up or Data Frame Join
        if counter > 0:
            
            # Data Frame Join
            df_new = df_new.join(df, how='inner')   
        
        else:
            
            # Data Frame Setup
            df_new = df
        
        # Increase Counter
        counter +=1
    
    return df_new

# %% [markdown]
# #### Market Metrics from Glassnode

# %%
# List of Market Features
market_feature_list = ['market/price_usd_close', 'market/price_drawdown_relative', 'market/price_realized_usd', 'market/mvrv']

# %%
try: 
    # Data Frame of Market Features
    df_market = import_glassnode_many(market_feature_list)
except:
    time.sleep(60)
    df_market = import_glassnode_many(market_feature_list)
# Out:
#             market/price_usd_close
# Date
# 2020-11-28                17714.06
# 2020-11-29                18147.64
# 2020-11-30                19689.81
# 2020-12-01                18863.78
# 2020-12-02                18846.02
#             market/price_drawdown_relative
# Date
# 2020-11-27                           -0.14
# 2020-11-28                           -0.11
# 2020-11-29                           -0.08
# 2020-11-30                           -0.01
# 2020-12-01                           -0.05
#             market/price_realized_usd
# Date
# 2020-11-27                    7324.71
# 2020-11-28                    7331.63
# 2020-11-29                    7344.01
# 2020-11-30                    7383.43
# 2020-12-01                    7433.57
#             market/mvrv
# Date
# 2020-11-27         2.32
# 2020-11-28         2.36
# 2020-11-29         2.45
# 2020-11-30         2.56
# 2020-12-01         2.59

# %% [markdown]
# #### Mining Metrics from Glassnode

# %%
# List of Mining Features    #'mining/revenue_sum',
mining_feature_list = ['mining/difficulty_latest', 'mining/hash_rate_mean', 'mining/marketcap_thermocap_ratio']

# %%
# Data Frame of Mining Features
df_mining = import_glassnode_many(mining_feature_list)
# Out:
#              mining/difficulty_latest
# Date
# 2020-11-27 75577685065077505392640.00
# 2020-11-28 75577685065077505392640.00
# 2020-11-29 82279353027041903509504.00
# 2020-11-30 82279353027041903509504.00
# 2020-12-01 82279353027041903509504.00
#               mining/hash_rate_mean
# Date
# 2020-11-27 134789789111882006528.00
# 2020-11-28 133670565738951000064.00
# 2020-11-29 135712889718699999232.00
# 2020-11-30 107377083337826992128.00
# 2020-12-01 146392546734912995328.00
#             mining/marketcap_thermocap_ratio
# Date
# 2020-11-27                              0.00
# 2020-11-28                              0.00
# 2020-11-29                              0.00
# 2020-11-30                              0.00
# 2020-12-01                              0.00

# %% [markdown]
# #### Blocks Metrics from Glassnode

# %%
# List of Blockchain Features
blockchain_feature_list = ['blockchain/block_count', 'blockchain/block_interval_mean', 'blockchain/block_size_sum']

# %%
# Data Frame of Blockchain Features
df_blockchainfeatures = import_glassnode_many(blockchain_feature_list)
# Out:
#             blockchain/block_count
# Date
# 2020-11-27                  154.00
# 2020-11-28                  154.00
# 2020-11-29                  150.00
# 2020-11-30                  113.00
# 2020-12-01                  152.00
#             blockchain/block_interval_mean
# Date
# 2020-11-27                          560.71
# 2020-11-28                          565.40
# 2020-11-29                          576.96
# 2020-11-30                          766.27
# 2020-12-01                          562.05
#             blockchain/block_size_sum
# Date
# 2020-11-27               197914555.00
# 2020-11-28               203325984.00
# 2020-11-29               165724061.00
# 2020-11-30               148990700.00
# 2020-12-01               194130643.00

# %% [markdown]
# #### Distribution Metrics from Glassnode

# %%
# List of Distribution Features
#distribution_feature_list = ['distribution/balance_1pct_holders', 'distribution/gini', 'distribution/herfindahl'] #

# %%
# Data Frame of Distribution Features
#df_distribution = import_glassnode_many(distribution_feature_list)

# %% [markdown]
# #### Fee Metrics from Glassnode

# %%
# List of Fee Features
fees_feature_list = ['fees/volume_sum', 'fees/volume_mean', 'fees/fee_ratio_multiple']

# %%
# Data Frame of Fee Features
df_fees = import_glassnode_many(fees_feature_list)
# Out:
#             fees/volume_sum
# Date
# 2020-11-27            84.21
# 2020-11-28            56.82
# 2020-11-29            39.87
# 2020-11-30            72.32
# 2020-12-01           145.31
#             fees/volume_mean
# Date
# 2020-11-27              0.00
# 2020-11-28              0.00
# 2020-11-29              0.00
# 2020-11-30              0.00
# 2020-12-01              0.00
#             fees/fee_ratio_multiple
# Date
# 2020-11-27                    12.43
# 2020-11-28                    17.94
# 2020-11-29                    24.52
# 2020-11-30                    10.77
# 2020-12-01                     7.54

# %% [markdown]
# #### UTXO Metrics from Glassnode

# %%
# List of UTXO Features
utxo_feature_list = ['blockchain/utxo_created_count', 'blockchain/utxo_spent_count', 'blockchain/utxo_created_value_sum', 'blockchain/utxo_spent_value_sum', 'blockchain/utxo_profit_relative', 'blockchain/utxo_profit_count', 'blockchain/utxo_loss_count']

# %%
# Data Frame of UTXO Features
df_utxo = import_glassnode_many(utxo_feature_list)
# Out:
#             blockchain/utxo_created_count
# Date
# 2020-11-27                      919277.00
# 2020-11-28                      823749.00
# 2020-11-29                      747296.00
# 2020-11-30                      772603.00
# 2020-12-01                     1056559.00
#             blockchain/utxo_spent_count
# Date
# 2020-11-27                    956335.00
# 2020-11-28                    955855.00
# 2020-11-29                    769819.00
# 2020-11-30                    696986.00
# 2020-12-01                    905405.00
#             blockchain/utxo_created_value_sum
# Date
# 2020-11-27                         1857757.44
# 2020-11-28                         1297738.60
# 2020-11-29                         1275997.46
# 2020-11-30                         2254249.72
# 2020-12-01                         2099814.43
#             blockchain/utxo_spent_value_sum
# Date
# 2020-11-27                       1856794.94
# 2020-11-28                       1296776.10
# 2020-11-29                       1275059.96
# 2020-11-30                       2253543.47
# 2020-12-01                       2098864.43
#             blockchain/utxo_profit_relative
# Date
# 2020-11-27                             0.98
# 2020-11-28                             0.98
# 2020-11-29                             0.99
# 2020-11-30                             1.00
# 2020-12-01                             0.99
#             blockchain/utxo_profit_count
# Date
# 2020-11-27                  112351600.00
# 2020-11-28                  112838038.00
# 2020-11-29                  113368033.00
# 2020-11-30                  114997966.00
# 2020-12-01                  114051582.00
#             blockchain/utxo_loss_count
# Date
# 2020-11-27                  2758813.00
# 2020-11-28                  2140269.00
# 2020-11-29                  1585703.00
# 2020-11-30                    10627.00
# 2020-12-01                  1130973.00

# %% [markdown]
# #### Supply Metrics from Glassnode

# %%
# List of Supply Features
supply_feature_list = ['supply/current','supply/profit_relative', 'supply/profit_sum', 'supply/loss_sum', 'supply/active_more_1y_percent', 'supply/active_more_2y_percent', 'supply/active_more_3y_percent', 'supply/active_more_5y_percent', 'supply/active_24h', 'supply/active_1d_1w', 'supply/active_1w_1m', 'supply/active_1m_3m', 'supply/active_3m_6m', 'supply/active_6m_12m', 'supply/active_1y_2y', 'supply/active_2y_3y', 'supply/active_3y_5y', 'supply/active_5y_7y', 'supply/active_7y_10y', 'supply/active_more_10y', 'supply/issued', 'supply/inflation_rate']

# %%
# Data Frame of Supply Features
df_supply = import_glassnode_many(supply_feature_list)
# Out:
#             supply/current
# Date
# 2020-11-27     18556137.50
# 2020-11-28     18557100.00
# 2020-11-29     18558037.50
# 2020-11-30     18558743.75
# 2020-12-01     18559693.75
#             supply/profit_relative
# Date
# 2020-11-27                    0.94
# 2020-11-28                    0.95
# 2020-11-29                    0.96
# 2020-11-30                    1.00
# 2020-12-01                    0.97
#             supply/profit_sum
# Date
# 2020-11-27        17381451.07
# 2020-11-28        17622583.20
# 2020-11-29        17882503.89
# 2020-11-30        18508745.21
# 2020-12-01        17976928.39
#             supply/loss_sum
# Date
# 2020-11-27       1161716.03
# 2020-11-28        921546.39
# 2020-11-29        660647.67
# 2020-11-30          5332.87
# 2020-12-01        569794.96
#             supply/active_more_1y_percent
# Date
# 2020-11-27                           0.61
# 2020-11-28                           0.61
# 2020-11-29                           0.61
# 2020-11-30                           0.61
# 2020-12-01                           0.61
#             supply/active_more_2y_percent
# Date
# 2020-11-27                           0.44
# 2020-11-28                           0.44
# 2020-11-29                           0.44
# 2020-11-30                           0.44
# 2020-12-01                           0.44
#             supply/active_more_3y_percent
# Date
# 2020-11-27                           0.33
# 2020-11-28                           0.33
# 2020-11-29                           0.33
# 2020-11-30                           0.33
# 2020-12-01                           0.33
#             supply/active_more_5y_percent
# Date
# 2020-11-27                           0.22
# 2020-11-28                           0.22
# 2020-11-29                           0.22
# 2020-11-30                           0.22
# 2020-12-01                           0.22
#             supply/active_24h
# Date
# 2020-11-27          288809.43
# 2020-11-28          145627.22
# 2020-11-29          148654.67
# 2020-11-30          344613.63
# 2020-12-01          316734.60
#             supply/active_1d_1w
# Date
# 2020-11-27            588750.79
# 2020-11-28            689281.38
# 2020-11-29            690785.10
# 2020-11-30            544835.84
# 2020-12-01            574383.08
#             supply/active_1w_1m
# Date
# 2020-11-27           1559456.81
# 2020-11-28           1573298.24
# 2020-11-29           1557439.77
# 2020-11-30           1522574.47
# 2020-12-01           1550547.64
#             supply/active_1m_3m
# Date
# 2020-11-27           1538563.77
# 2020-11-28           1564231.41
# 2020-11-29           1557129.40
# 2020-11-30           1552900.73
# 2020-12-01           1536320.17
#             supply/active_3m_6m
# Date
# 2020-11-27           1382362.87
# 2020-11-28           1349269.20
# 2020-11-29           1356692.15
# 2020-11-30           1363027.17
# 2020-12-01           1363545.05
#             supply/active_6m_12m
# Date
# 2020-11-27            1790632.86
# 2020-11-28            1822854.18
# 2020-11-29            1834935.00
# 2020-11-30            1830493.66
# 2020-12-01            1827059.56
#             supply/active_1y_2y
# Date
# 2020-11-27           3289432.16
# 2020-11-28           3294375.58
# 2020-11-29           3236015.19
# 2020-11-30           3178409.69
# 2020-12-01           3177203.22
#             supply/active_2y_3y
# Date
# 2020-11-27           2063541.16
# 2020-11-28           2049727.01
# 2020-11-29           2101911.81
# 2020-11-30           2148894.49
# 2020-12-01           2132277.92
#             supply/active_3y_5y
# Date
# 2020-11-27           1995883.53
# 2020-11-28           2009493.24
# 2020-11-29           2014579.02
# 2020-11-30           2012952.46
# 2020-12-01           2023160.92
#             supply/active_5y_7y
# Date
# 2020-11-27            871086.00
# 2020-11-28            869446.52
# 2020-11-29            868768.77
# 2020-11-30            866940.79
# 2020-12-01            862263.39
#             supply/active_7y_10y
# Date
# 2020-11-27            1348826.21
# 2020-11-28            1350121.77
# 2020-11-29            1350999.20
# 2020-11-30            1351921.45
# 2020-12-01            1354008.93
#             supply/active_more_10y
# Date
# 2020-11-27              1838762.96
# 2020-11-28              1839345.31
# 2020-11-29              1840098.48
# 2020-11-30              1841150.43
# 2020-12-01              1842160.32
#             supply/issued
# Date
# 2020-11-27         962.50
# 2020-11-28         962.50
# 2020-11-29         937.50
# 2020-11-30         706.25
# 2020-12-01         950.00
#             supply/inflation_rate
# Date
# 2020-11-27                   0.02
# 2020-11-28                   0.02
# 2020-11-29                   0.02
# 2020-11-30                   0.01
# 2020-12-01                   0.02

# %% [markdown]
# #### Transaction Metrics from Glassnode

# %%
# List of Transaction Features
transaction_feature_list = ['transactions/count', 'transactions/size_sum','transactions/transfers_volume_sum', 'transactions/transfers_volume_adjusted_sum']

# %%
# Data Frame of Transaction Features
df_transaction = import_glassnode_many(transaction_feature_list)
# Out:
#             transactions/count
# Date
# 2020-11-27           322291.00
# 2020-11-28           293795.00
# 2020-11-29           263423.00
# 2020-11-30           256438.00
# 2020-12-01           377916.00
#             transactions/size_sum
# Date
# 2020-11-27           197852505.00
# 2020-11-28           203263899.00
# 2020-11-29           165665191.00
# 2020-11-30           148946689.00
# 2020-12-01           194069127.00
#             transactions/transfers_volume_sum
# Date
# 2020-11-27                         1856710.72
# 2020-11-28                         1296719.28
# 2020-11-29                         1275020.09
# 2020-11-30                         2253471.16
# 2020-12-01                         2098719.12
#             transactions/transfers_volume_adjusted_sum
# Date
# 2020-11-27                                   660956.82
# 2020-11-28                                   342520.51
# 2020-11-29                                   413188.45
# 2020-11-30                                   641130.20
# 2020-12-01                                   777037.47

# %% [markdown]
# #### Exchange Metrics from Glassnode - 1 Month Lag

# %%
# List of Exchange Features
#exchange_feature_list = ['transactions/transfers_volume_to_exchanges_sum', 'transactions/transfers_volume_from_exchanges_sum', 'transactions/transfers_to_exchanges_count', 'transactions/transfers_from_exchanges_count', 'distribution/balance_exchanges', 'transactions/transfers_volume_exchanges_net']

# %%
# Data Frame of Exchange Features
#df_exchange = import_glassnode_many(exchange_feature_list)

# %% [markdown]
# #### Indicator-I Metrics from Glassnode

# %%
# List of Indicator-1 Features
indicator1_feature_list = ['indicators/sopr_adjusted', 'indicators/nvt', 'indicators/velocity', 'indicators/cdd', 'indicators/reserve_risk', 'indicators/average_dormancy', 'indicators/liveliness']

# %%
# Data Frame of Indicator-1 Features
df_indicator1 = import_glassnode_many(indicator1_feature_list)
# Out:
#             indicators/sopr_adjusted
# Date
# 2020-11-27                      1.03
# 2020-11-28                      1.03
# 2020-11-29                      1.04
# 2020-11-30                      1.09
# 2020-12-01                      1.07
#             indicators/nvt
# Date
# 2020-11-27           28.07
# 2020-11-28           54.18
# 2020-11-29           44.91
# 2020-11-30           28.95
# 2020-12-01           23.89
#             indicators/velocity
# Date
# 2020-11-27                 0.04
# 2020-11-28                 0.02
# 2020-11-29                 0.02
# 2020-11-30                 0.03
# 2020-12-01                 0.04
#             indicators/cdd
# Date
# 2020-11-27     22067884.44
# 2020-11-28      5768075.20
# 2020-11-29      9024622.08
# 2020-11-30     23587199.18
# 2020-12-01     23639692.65
#             indicators/reserve_risk
# Date
# 2020-11-27                     0.00
# 2020-11-28                     0.00
# 2020-11-29                     0.00
# 2020-11-30                     0.00
# 2020-12-01                     0.00
#             indicators/average_dormancy
# Date
# 2020-11-27                        33.39
# 2020-11-28                        16.84
# 2020-11-29                        21.84
# 2020-11-30                        36.79
# 2020-12-01                        30.42
#             indicators/liveliness
# Date
# 2020-11-27                   0.60
# 2020-11-28                   0.60
# 2020-11-29                   0.60
# 2020-11-30                   0.60
# 2020-12-01                   0.60

# %% [markdown]
# #### Indicator-2 Metrics from Glassnode

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['indicators/asol', 'indicators/sol_1h', 'indicators/sol_1h_24h', 'indicators/sol_1d_1w', 'indicators/sol_1w_1m', 'indicators/sol_1m_3m', 'indicators/sol_3m_6m', 'indicators/sol_6m_12m', 'indicators/sol_1y_2y', 'indicators/sol_2y_3y', 'indicators/sol_3y_5y', 'indicators/sol_5y_7y', 'indicators/sol_7y_10y']

# %%
# Data Frame of Indicator-2 Features
df_indicator2 = import_glassnode_many(indicator2_feature_list)
# Out:
#             indicators/asol
# Date
# 2020-11-27            39.81
# 2020-11-28            47.32
# 2020-11-29            58.66
# 2020-11-30            38.42
# 2020-12-01            52.93
#             indicators/sol_1h
# Date
# 2020-11-27          199527.00
# 2020-11-28          189661.00
# 2020-11-29          170417.00
# 2020-11-30          156129.00
# 2020-12-01          221420.00
#             indicators/sol_1h_24h
# Date
# 2020-11-27              345546.00
# 2020-11-28              299206.00
# 2020-11-29              240405.00
# 2020-11-30              224157.00
# 2020-12-01              335946.00
#             indicators/sol_1d_1w
# Date
# 2020-11-27             232134.00
# 2020-11-28             251704.00
# 2020-11-29             193345.00
# 2020-11-30             177745.00
# 2020-12-01             154791.00
#             indicators/sol_1w_1m
# Date
# 2020-11-27              86893.00
# 2020-11-28             100026.00
# 2020-11-29              82080.00
# 2020-11-30              75099.00
# 2020-12-01              85878.00
#             indicators/sol_1m_3m
# Date
# 2020-11-27              41758.00
# 2020-11-28              48330.00
# 2020-11-29              31311.00
# 2020-11-30              29392.00
# 2020-12-01              46000.00
#             indicators/sol_3m_6m
# Date
# 2020-11-27              13164.00
# 2020-11-28              19487.00
# 2020-11-29              13161.00
# 2020-11-30              10059.00
# 2020-12-01              15220.00
#             indicators/sol_6m_12m
# Date
# 2020-11-27               11330.00
# 2020-11-28               15585.00
# 2020-11-29               14472.00
# 2020-11-30                7873.00
# 2020-12-01               14365.00
#             indicators/sol_1y_2y
# Date
# 2020-11-27              14587.00
# 2020-11-28              17730.00
# 2020-11-29              10358.00
# 2020-11-30               6792.00
# 2020-12-01              13278.00
#             indicators/sol_2y_3y
# Date
# 2020-11-27               7182.00
# 2020-11-28               9643.00
# 2020-11-29               5800.00
# 2020-11-30               6748.00
# 2020-12-01              13945.00
#             indicators/sol_3y_5y
# Date
# 2020-11-27               2950.00
# 2020-11-28               3359.00
# 2020-11-29               2789.00
# 2020-11-30               2422.00
# 2020-12-01               4017.00
#             indicators/sol_5y_7y
# Date
# 2020-11-27               1049.00
# 2020-11-28                969.00
# 2020-11-29               4885.00
# 2020-11-30                391.00
# 2020-12-01                416.00
#             indicators/sol_7y_10y
# Date
# 2020-11-27                 215.00
# 2020-11-28                 155.00
# 2020-11-29                 796.00
# 2020-11-30                 179.00
# 2020-12-01                 129.00

# %% [markdown]
# #### Indicator-3 Metrics from Glassnode

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['indicators/net_unrealized_profit_loss', 'indicators/unrealized_profit', 'indicators/unrealized_loss', 'indicators/net_realized_profit_loss', 'indicators/realized_profit', 'indicators/realized_loss', 'indicators/nupl_more_155', 'indicators/nupl_less_155', 'indicators/puell_multiple', 'indicators/stock_to_flow_deflection', 'indicators/difficulty_ribbon_compression']

# %%
# Data Frame of Indicator-3 Features
df_indicator3 = import_glassnode_many(indicator3_feature_list)
# Out:
#             indicators/net_unrealized_profit_loss
# Date
# 2020-11-27                                   0.57
# 2020-11-28                                   0.58
# 2020-11-29                                   0.59
# 2020-11-30                                   0.62
# 2020-12-01                                   0.60
#             indicators/unrealized_profit
# Date
# 2020-11-27                          0.57
# 2020-11-28                          0.59
# 2020-11-29                          0.59
# 2020-11-30                          0.62
# 2020-12-01                          0.60
#             indicators/unrealized_loss
# Date
# 2020-11-27                        0.00
# 2020-11-28                        0.00
# 2020-11-29                        0.00
# 2020-11-30                        0.00
# 2020-12-01                        0.00
#             indicators/net_realized_profit_loss
# Date
# 2020-11-27                         287463917.99
# 2020-11-28                         174442581.58
# 2020-11-29                         243291799.68
# 2020-11-30                         930610432.56
# 2020-12-01                         773064011.72
#             indicators/realized_profit
# Date
# 2020-11-27                499823727.98
# 2020-11-28                218246122.17
# 2020-11-29                281095917.02
# 2020-11-30                961528905.35
# 2020-12-01                907547252.96
#             indicators/realized_loss
# Date
# 2020-11-27              212359809.98
# 2020-11-28               43803540.59
# 2020-11-29               37804117.34
# 2020-11-30               30918472.79
# 2020-12-01              134483241.24
#             indicators/nupl_more_155
# Date
# 2020-11-27                      0.67
# 2020-11-28                      0.68
# 2020-11-29                      0.69
# 2020-11-30                      0.72
# 2020-12-01                      0.70
#             indicators/nupl_less_155
# Date
# 2020-11-27                      0.19
# 2020-11-28                      0.21
# 2020-11-29                      0.23
# 2020-11-30                      0.28
# 2020-12-01                      0.24
#             indicators/puell_multiple
# Date
# 2020-11-27                       1.34
# 2020-11-28                       1.36
# 2020-11-29                       1.38
# 2020-11-30                       1.09
# 2020-12-01                       1.50
#             indicators/stock_to_flow_deflection
# Date
# 2020-11-27                                 0.62
# 2020-11-28                                 0.63
# 2020-11-29                                 0.65
# 2020-11-30                                 0.70
# 2020-12-01                                 0.66
#             indicators/difficulty_ribbon_compression
# Date
# 2020-11-27                                      0.03
# 2020-11-28                                      0.03
# 2020-11-29                                      0.03
# 2020-11-30                                      0.03
# 2020-12-01                                      0.02

# %% [markdown]
# #### Addresses Metrics from Glassnode

# %%
# List of Addresses Features
addresses_feature_list = ['addresses/active_count', 'addresses/sending_count', 'addresses/receiving_count', 'addresses/new_non_zero_count', 'addresses/non_zero_count', 'addresses/min_point_zero_1_count','addresses/min_point_1_count', 'addresses/min_1_count', 'addresses/min_10_count', 'addresses/min_100_count', 'addresses/min_1k_count', 'addresses/min_10k_count']

# %%
# Data Frame of Addresses Features
df_addresses = import_glassnode_many(addresses_feature_list)
# Out:
#             addresses/active_count
# Date
# 2020-11-27              1098290.00
# 2020-11-28              1043272.00
# 2020-11-29               884127.00
# 2020-11-30               889631.00
# 2020-12-01              1170489.00
#             addresses/sending_count
# Date
# 2020-11-27                718366.00
# 2020-11-28                703716.00
# 2020-11-29                563015.00
# 2020-11-30                519025.00
# 2020-12-01                687581.00
#             addresses/receiving_count
# Date
# 2020-11-27                  719222.00
# 2020-11-28                  644191.00
# 2020-11-29                  588994.00
# 2020-11-30                  623543.00
# 2020-12-01                  841565.00
#             addresses/new_non_zero_count
# Date
# 2020-11-27                     513799.00
# 2020-11-28                     472882.00
# 2020-11-29                     434832.00
# 2020-11-30                     441143.00
# 2020-12-01                     614449.00
#             addresses/non_zero_count
# Date
# 2020-11-27               32675862.00
# 2020-11-28               32586624.00
# 2020-11-29               32586946.00
# 2020-11-30               32659333.00
# 2020-12-01               32764603.00
#             addresses/min_point_zero_1_count
# Date
# 2020-11-27                        8515464.00
# 2020-11-28                        8481925.00
# 2020-11-29                        8468254.00
# 2020-11-30                        8499912.00
# 2020-12-01                        8525194.00
#             addresses/min_point_1_count
# Date
# 2020-11-27                   3121227.00
# 2020-11-28                   3118114.00
# 2020-11-29                   3111465.00
# 2020-11-30                   3117495.00
# 2020-12-01                   3115114.00
#             addresses/min_1_count
# Date
# 2020-11-27              820011.00
# 2020-11-28              820175.00
# 2020-11-29              819629.00
# 2020-11-30              821144.00
# 2020-12-01              820762.00
#             addresses/min_10_count
# Date
# 2020-11-27               154563.00
# 2020-11-28               154599.00
# 2020-11-29               154481.00
# 2020-11-30               154578.00
# 2020-12-01               154377.00
#             addresses/min_100_count
# Date
# 2020-11-27                 16089.00
# 2020-11-28                 16082.00
# 2020-11-29                 16105.00
# 2020-11-30                 16150.00
# 2020-12-01                 16130.00
#             addresses/min_1k_count
# Date
# 2020-11-27                 2263.00
# 2020-11-28                 2262.00
# 2020-11-29                 2262.00
# 2020-11-30                 2261.00
# 2020-12-01                 2259.00
#             addresses/min_10k_count
# Date
# 2020-11-27                   109.00
# 2020-11-28                   109.00
# 2020-11-29                   109.00
# 2020-11-30                   109.00
# 2020-12-01                   108.00

# %% [markdown]
# #### Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Futures Features
# futures_feature_list = ['derivatives/futures_volume_daily_all_sum', 'derivatives/futures_volume_daily_perpetual_sum', 'derivatives/futures_open_interest_all_sum', 'derivatives/futures_open_interest_perpetual_sum', 'derivatives/futures_funding_rate_perpetual']

# %% [markdown]
# ##### Data Frame of Future features
# df_futures = import_glassnode_many(futures_feature_list)

# %% [markdown]
# ## File Import and Data Tidying

# %%
# Import of Modules and Packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.6f}'.format

# %%
os.chdir('C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010')

# %% [markdown]
# ### Import Blockchain CSV-Files

# %% [markdown]
# #### Market Metric CSV-Files

# %%
# List of Market Features
market_feature_list = ['price_usd_close', 'price_drawdown_relative', 'price_realized_usd', 'mvrv']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in market_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_market = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_market.columns:
    try:
        df_market["{}".format(y)] = df_market["{}".format(y)].str.replace(',','.')
        df_market["{}".format(y)] = df_market["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Market Metric Values
df_market.tail()
# Out:
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2020-11-27            17096.724533                       -0.137049
# 2020-11-28            17714.060586                       -0.105889
# 2020-11-29            18147.636460                       -0.084005
# 2020-11-30            19689.810545                       -0.006164
# 2020-12-01            18863.780861                       -0.049165
#
#             market/price_realized_usd  market/mvrv
# Date
# 2020-11-27                7324.711202     2.321520
# 2020-11-28                7331.626545     2.360943
# 2020-11-29                7344.014152     2.449016
# 2020-11-30                7383.431438     2.555244
# 2020-12-01                7433.569725     2.590058

# %% [markdown]
# #### Mining Metric CSV-Files

# %%
# # List of Mining Features
# mining_feature_list = ['difficulty_latest'] #, 'hash_rate_mean', 'revenue_sum','marketcap_thermocap_ratio'

# # For Loop through all Features in the List
# for x in mining_feature_list:
    
#     # Import Feature CSV-Files
#     df_mining_difficulty_latest = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
# # Change Data Type of Columns to Float
# for y in df_mining_difficulty_latest.columns:
#     try:
#         df_mining_difficulty_latest["{}".format(y)] = df_mining_difficulty_latest["{}".format(y)].str.replace(',','.')
#         df_mining_difficulty_latest["{}".format(y)] = df_mining_difficulty_latest["{}".format(y)].astype(float)
#     except:
#         pass
    
# df_mining_difficulty_latest

# %%
# # List of Mining Features
# mining_feature_list = ['hash_rate_mean'] # 'revenue_sum','marketcap_thermocap_ratio'

# # For Loop through all Features in the List
# for x in mining_feature_list:
    
#     # Import Feature CSV-Files
#     df_mining_hash_rate_mean = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
# # Change Data Type of Columns to Float
# for y in df_mining_hash_rate_mean.columns:
#     try:
#         df_mining_hash_rate_mean["{}".format(y)] = df_mining_hash_rate_mean["{}".format(y)].str.replace(',','.')
#         df_mining_hash_rate_mean["{}".format(y)] = df_mining_hash_rate_mean["{}".format(y)].astype(float)
#     except:
#         pass
    
# df_mining_hash_rate_mean

# %%
# # List of Mining Features
# mining_feature_list = ['marketcap_thermocap_ratio'] # 'revenue_sum','marketcap_thermocap_ratio'

# # For Loop through all Features in the List
# for x in mining_feature_list:
    
#     # Import Feature CSV-Files
#     df_mining_marketcap_thermocap_ratio = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
# # Change Data Type of Columns to Float
# for y in df_mining_marketcap_thermocap_ratio.columns:
#     try:
#         df_mining_marketcap_thermocap_ratio["{}".format(y)] = df_mining_marketcap_thermocap_ratio["{}".format(y)].str.replace(',','.')
#         df_mining_marketcap_thermocap_ratio["{}".format(y)] = df_mining_marketcap_thermocap_ratio["{}".format(y)].astype(float)
#     except:
#         pass
    
# df_mining_revenue_sum

# %%
# List of Mining Features
mining_feature_list = ['difficulty_latest', 'hash_rate_mean'] #, 'revenue_sum','marketcap_thermocap_ratio'

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in mining_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame    
df_mining = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_mining.columns:
    try:
        df_mining["{}".format(y)] = df_mining["{}".format(y)].str.replace(',','.')
        df_mining["{}".format(y)] = df_mining["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Mining Metric Values
df_mining.tail()
# Out:
#                  mining/difficulty_latest        mining/hash_rate_mean
# Date
# 2020-11-27 75577685065077505392640.000000 134789789111882006528.000000
# 2020-11-28 75577685065077505392640.000000 133670565738951000064.000000
# 2020-11-29 82279353027041903509504.000000 135712889718699999232.000000
# 2020-11-30 82279353027041903509504.000000 107377083337826992128.000000
# 2020-12-01 82279353027041903509504.000000 146392546734912995328.000000

# %% [markdown]
# #### Blocks Metric CSV-Files

# %%
# List of Blockchain Features
block_feature_list = ['block_count', 'block_interval_mean', 'block_size_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in block_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_blockfeatures = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_blockfeatures.columns:
    try:
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].str.replace(',','.')
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].astype(float)
    except:
        pass

# %%
# Show Latest Feature Values
df_blockfeatures.tail()
# Out:
#             blockchain/block_count  blockchain/block_interval_mean  \
# Date
# 2020-11-27              154.000000                      560.707792
# 2020-11-28              154.000000                      565.402597
# 2020-11-29              150.000000                      576.960000
# 2020-11-30              113.000000                      766.265487
# 2020-12-01              152.000000                      562.046053
#
#             blockchain/block_size_sum
# Date
# 2020-11-27           197914555.000000
# 2020-11-28           203325984.000000
# 2020-11-29           165724061.000000
# 2020-11-30           148990700.000000
# 2020-12-01           194130643.000000

# %% [markdown]
# #### Distribution Metric CSV-Files

# %%
# # List of Distribution Features
# distribution_feature_list = ['balance_1pct_holders', 'gini', 'herfindahl']

# # Counter to Differentiate between Data Frame Setup and Data Frame Extension
# counter=0

# # For Loop through all Features in the List
# for x in distribution_feature_list:
    
#     # Import Feature CSV-Files
#     df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
#     # Condition - Data Frame Set up or Data Frame Extension
#     if counter > 0:
        
#         # Data Frame Extension - Inner Join
#         df_new = df_new.join(df, how='inner')
    
#     else:
#         # Data Frame Setup
#         df_new = df
    
#     # Increase Counter    
#     counter +=1

# # Store Data Frame Copy in Distribution Data Frame    
# df_distribution = df_new.copy()

# # Delete Original Data Frame
# del df_new

# # Change Data Type of Columns to Float
# for y in df_distribution.columns:
#     try:
#         df_distribution["{}".format(y)] = df_distribution["{}".format(y)].str.replace(',','.')
#         df_distribution["{}".format(y)] = df_distribution["{}".format(y)].astype(float)
#     except:
#         pass

# %%
# # Latest Distribution Metric Values
# df_distribution.tail()

# %% [markdown]
# #### Fee Metric CSV-Files

# %%
# List of Fee Features
fees_feature_list = ['volume_sum', 'volume_mean', 'fee_ratio_multiple']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in fees_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date') #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
        
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Fees Data Frame    
df_fees = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_fees.columns:
    try:
        df_fees["{}".format(y)] = df_fees["{}".format(y)].str.replace(',','.')
        df_fees["{}".format(y)] = df_fees["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Fee Metric Values
df_fees.tail()
# Out:
#             fees/volume_sum  fees/volume_mean  fees/fee_ratio_multiple
# Date
# 2020-11-27        84.214949          0.000261                12.429087
# 2020-11-28        56.820280          0.000193                17.939374
# 2020-11-29        39.865948          0.000151                24.516310
# 2020-11-30        72.317829          0.000282                10.765918
# 2020-12-01       145.308383          0.000384                 7.537820

# %% [markdown]
# #### UTXO Metric CSV-Files

# %%
# List of UTXO Features
utxo_feature_list = ['utxo_created_count', 'utxo_spent_count','utxo_created_value_sum', 'utxo_spent_value_sum', 'utxo_profit_relative', 'utxo_profit_count', 'utxo_loss_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in utxo_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df

    # Increase Counter
    counter +=1

# Store Data Frame Copy in UTXO Data Frame
df_utxo = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_utxo.columns:
    try:
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].str.replace(',','.')
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest UTXO Metric Values
df_utxo.tail()
# Out:
#             blockchain/utxo_created_count  blockchain/utxo_spent_count  \
# Date
# 2020-11-27                  919277.000000                956335.000000
# 2020-11-28                  823749.000000                955855.000000
# 2020-11-29                  747296.000000                769819.000000
# 2020-11-30                  772603.000000                696986.000000
# 2020-12-01                 1056559.000000                905405.000000
#
#             blockchain/utxo_created_value_sum  \
# Date
# 2020-11-27                     1857757.436596
# 2020-11-28                     1297738.598791
# 2020-11-29                     1275997.458033
# 2020-11-30                     2254249.723763
# 2020-12-01                     2099814.428736
#
#             blockchain/utxo_spent_value_sum  blockchain/utxo_profit_relative  \
# Date
# 2020-11-27                   1856794.936596                         0.976033
# 2020-11-28                   1296776.098791                         0.981385
# 2020-11-29                   1275059.958033                         0.986188
# 2020-11-30                   2253543.473763                         0.999709
# 2020-12-01                   2098864.428736                         0.990181
#
#             blockchain/utxo_profit_count  blockchain/utxo_loss_count
# Date
# 2020-11-27              112351600.000000              2758813.000000
# 2020-11-28              112838038.000000              2140269.000000
# 2020-11-29              113368033.000000              1585703.000000
# 2020-11-30              114997966.000000                10627.000000
# 2020-12-01              114051582.000000              1130973.000000

# %% [markdown]
# #### Supply Metric CSV-Files

# %%
# List of Supply Features
supply_feature_list = ['current','profit_relative', 'profit_sum', 'loss_sum', 'active_more_1y_percent', 'active_more_2y_percent', 'active_more_3y_percent', 'active_more_5y_percent', 'active_24h', 'active_1d_1w', 'active_1w_1m', 'active_1m_3m', 'active_3m_6m', 'active_6m_12m', 'active_1y_2y', 'active_2y_3y', 'active_3y_5y', 'active_5y_7y', 'active_7y_10y', 'active_more_10y', 'issued', 'inflation_rate']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in supply_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Supply Data Frame    
df_supply = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_supply.columns:
    try:
        df_supply["{}".format(y)] = df_supply["{}".format(y)].str.replace(',','.')
        df_supply["{}".format(y)] = df_supply["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Supply Metric Values
df_supply.tail()
# Out:
#             supply/current  supply/profit_relative  supply/profit_sum  \
# Date
# 2020-11-27 18556137.500000                0.937351    17381451.070415
# 2020-11-28 18557100.000000                0.950305    17622583.204449
# 2020-11-29 18558037.500000                0.964273    17882503.887525
# 2020-11-30 18558743.750000                0.998003    18508745.208329
# 2020-12-01 18559693.750000                0.969278    17976928.385263
#
#             supply/loss_sum  supply/active_more_1y_percent  \
# Date
# 2020-11-27   1161716.025083                       0.614758
# 2020-11-28    921546.391049                       0.614994
# 2020-11-29    660647.673520                       0.614956
# 2020-11-30      5332.865657                       0.614280
# 2020-12-01    569794.960235                       0.613753
#
#             supply/active_more_2y_percent  supply/active_more_3y_percent  \
# Date
# 2020-11-27                       0.437489                       0.326283
# 2020-11-28                       0.437468                       0.327013
# 2020-11-29                       0.440583                       0.327322
# 2020-11-30                       0.443018                       0.327229
# 2020-12-01                       0.442565                       0.327677
#
#             supply/active_more_5y_percent  supply/active_24h  \
# Date
# 2020-11-27                       0.218724      288809.431831
# 2020-11-28                       0.218726      145627.222835
# 2020-11-29                       0.218766      148654.673336
# 2020-11-30                       0.218765      344613.631284
# 2020-12-01                       0.218669      316734.595710
#
#             supply/active_1d_1w  ...  supply/active_3m_6m  \
# Date                             ...
# 2020-11-27        588750.788106  ...       1382362.869021
# 2020-11-28        689281.380092  ...       1349269.198003
# 2020-11-29        690785.098405  ...       1356692.145072
# 2020-11-30        544835.838108  ...       1363027.165516
# 2020-12-01        574383.081195  ...       1363545.050144
#
#             supply/active_6m_12m  supply/active_1y_2y  supply/active_2y_3y  \
# Date
# 2020-11-27        1790632.855051       3289432.163467       2063541.161777
# 2020-11-28        1822854.180325       3294375.581548       2049727.006793
# 2020-11-29        1834935.002837       3236015.187847       2101911.805385
# 2020-11-30        1830493.660165       3178409.687079       2148894.487112
# 2020-12-01        1827059.564973       3177203.219007       2132277.920779
#
#             supply/active_3y_5y  supply/active_5y_7y  supply/active_7y_10y  \
# Date
# 2020-11-27       1995883.526556        871085.999917        1348826.206163
# 2020-11-28       2009493.240743        869446.515325        1350121.766577
# 2020-11-29       2014579.020223        868768.766887        1350999.196783
# 2020-11-30       2012952.458750        866940.785670        1351921.446147
# 2020-12-01       2023160.923652        862263.392576        1354008.926480
#
#             supply/active_more_10y  supply/issued  supply/inflation_rate
# Date
# 2020-11-27          1838762.958235     962.500000               0.019112
# 2020-11-28          1839345.308235     962.500000               0.019111
# 2020-11-29          1840098.478235     937.500000               0.018609
# 2020-11-30          1841150.428235     706.250000               0.013987
# 2020-12-01          1842160.318235     950.000000               0.018858
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Transaction Metric CSV-Files

# %%
# List of Transaction features
transaction_feature_list = ['count', 'size_sum','transfers_volume_sum', 'transfers_volume_adjusted_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in transaction_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Transaction Data Frame
df_transaction = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_transaction.columns:
    try:
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].str.replace(',','.')
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Transaction Metric Values
df_transaction.tail()
# Out:
#             transactions/count  transactions/size_sum  \
# Date
# 2020-11-27       322291.000000       197852505.000000
# 2020-11-28       293795.000000       203263899.000000
# 2020-11-29       263423.000000       165665191.000000
# 2020-11-30       256438.000000       148946689.000000
# 2020-12-01       377916.000000       194069127.000000
#
#             transactions/transfers_volume_sum  \
# Date
# 2020-11-27                     1856710.721646
# 2020-11-28                     1296719.278511
# 2020-11-29                     1275020.092085
# 2020-11-30                     2253471.155935
# 2020-12-01                     2098719.120353
#
#             transactions/transfers_volume_adjusted_sum
# Date
# 2020-11-27                               660956.816131
# 2020-11-28                               342520.511352
# 2020-11-29                               413188.447311
# 2020-11-30                               641130.200126
# 2020-12-01                               777037.467005

# %% [markdown]
# #### Exchange Metrics CSV-Files

# %%
# # List of Exchange Features
# exchange_feature_list = ['transfers_volume_to_exchanges_sum', 'transfers_volume_from_exchanges_sum', 'transfers_to_exchanges_count', 
#                          'transfers_from_exchanges_count', 'balance_exchanges', 'transfers_volume_exchanges_net']

# # Counter to Differentiate between Data Frame Setup and Data Frame Extension
# counter=0

# # For Loop through all Features in the List
# for x in exchange_feature_list:
    
#     # Import Feature CSV-Files
#     df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
#     # Condition - Data Frame Set up or Data Frame Extension
#     if counter > 0:
        
#         # Data Frame Extension - Inner Join
#         df_new = df_new.join(df, how='inner')
    
#     else:
        
#         # Data Frame Setup
#         df_new = df
    
#     # Increase Counter
#     counter +=1

# # Store Data Frame Copy in Exchange Data Frame    
# df_exchange = df_new.copy()

# # Delete Original Data Frame
# del df_new

# # Change Data Type of Columns to Float
# for y in df_exchange.columns:
#     try:
#         df_exchange["{}".format(y)] = df_exchange["{}".format(y)].str.replace(',','.')
#         df_exchange["{}".format(y)] = df_exchange["{}".format(y)].astype(float)
#     except:
#         pass

# %%
# # Latest Exchange Metric Values
# df_exchange.tail()

# %% [markdown]
# #### Indicator-1 Metric CSV-Files

# %%
# List of Indicator-1 features
indicator1_feature_list = ['sopr_adjusted', 'nvt', 'velocity', 'cdd','reserve_risk', 'average_dormancy', 'liveliness'] 

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator1_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-1 Data Frame    
df_indicator1 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator1.columns:
    try:
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].str.replace(',','.')
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-1 Metric Values
df_indicator1.tail()
# Out:
#             indicators/sopr_adjusted  indicators/nvt  indicators/velocity  \
# Date
# 2020-11-27                  1.029315       28.074659             0.035619
# 2020-11-28                  1.026012       54.178069             0.018458
# 2020-11-29                  1.037644       44.914222             0.022265
# 2020-11-30                  1.086601       28.946919             0.034546
# 2020-12-01                  1.066294       23.885198             0.041867
#
#             indicators/cdd  indicators/reserve_risk  \
# Date
# 2020-11-27 22067884.439785                 0.002742
# 2020-11-28  5768075.198675                 0.002789
# 2020-11-29  9024622.077505                 0.002895
# 2020-11-30 23587199.175718                 0.003033
# 2020-12-01 23639692.647496                 0.003093
#
#             indicators/average_dormancy  indicators/liveliness
# Date
# 2020-11-27                    33.387786               0.603623
# 2020-11-28                    16.840087               0.603646
# 2020-11-29                    21.841419               0.603591
# 2020-11-30                    36.790030               0.603680
# 2020-12-01                    30.422848               0.604011

# %% [markdown]
# #### Indicator-2 Metrics CSV-Files

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['asol', 'sol_1h', 'sol_1h_24h', 'sol_1d_1w','sol_1w_1m', 'sol_1m_3m', 'sol_3m_6m', 'sol_6m_12m','sol_1y_2y', 'sol_2y_3y', 'sol_3y_5y', 'sol_5y_7y', 'sol_7y_10y']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator2_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-2 Data Frame
df_indicator2 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator2.columns:
    try:
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].str.replace(',','.')
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-2 Metric Values
df_indicator2.tail()
# Out:
#             indicators/asol  indicators/sol_1h  indicators/sol_1h_24h  \
# Date
# 2020-11-27        39.811225      199527.000000          345546.000000
# 2020-11-28        47.320904      189661.000000          299206.000000
# 2020-11-29        58.657665      170417.000000          240405.000000
# 2020-11-30        38.417301      156129.000000          224157.000000
# 2020-12-01        52.932243      221420.000000          335946.000000
#
#             indicators/sol_1d_1w  indicators/sol_1w_1m  indicators/sol_1m_3m  \
# Date
# 2020-11-27         232134.000000          86893.000000          41758.000000
# 2020-11-28         251704.000000         100026.000000          48330.000000
# 2020-11-29         193345.000000          82080.000000          31311.000000
# 2020-11-30         177745.000000          75099.000000          29392.000000
# 2020-12-01         154791.000000          85878.000000          46000.000000
#
#             indicators/sol_3m_6m  indicators/sol_6m_12m  indicators/sol_1y_2y  \
# Date
# 2020-11-27          13164.000000           11330.000000          14587.000000
# 2020-11-28          19487.000000           15585.000000          17730.000000
# 2020-11-29          13161.000000           14472.000000          10358.000000
# 2020-11-30          10059.000000            7873.000000           6792.000000
# 2020-12-01          15220.000000           14365.000000          13278.000000
#
#             indicators/sol_2y_3y  indicators/sol_3y_5y  indicators/sol_5y_7y  \
# Date
# 2020-11-27           7182.000000           2950.000000           1049.000000
# 2020-11-28           9643.000000           3359.000000            969.000000
# 2020-11-29           5800.000000           2789.000000           4885.000000
# 2020-11-30           6748.000000           2422.000000            391.000000
# 2020-12-01          13945.000000           4017.000000            416.000000
#
#             indicators/sol_7y_10y
# Date
# 2020-11-27             215.000000
# 2020-11-28             155.000000
# 2020-11-29             796.000000
# 2020-11-30             179.000000
# 2020-12-01             129.000000

# %% [markdown]
# #### Indicator-3 Metrics CSV-Files

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['net_unrealized_profit_loss', 'unrealized_profit', 'unrealized_loss', 'net_realized_profit_loss', 'realized_profit', 'realized_loss', 'nupl_more_155', 'nupl_less_155', 'puell_multiple', 'stock_to_flow_deflection', 'difficulty_ribbon_compression']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator3_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-3 Data Frame
df_indicator3 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator3.columns:
    try:
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].str.replace(',','.')
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-3 Metric Values
df_indicator3.tail()
# Out:
#             indicators/net_unrealized_profit_loss  \
# Date
# 2020-11-27                               0.569638
# 2020-11-28                               0.584076
# 2020-11-29                               0.593261
# 2020-11-30                               0.622548
# 2020-12-01                               0.603777
#
#             indicators/unrealized_profit  indicators/unrealized_loss  \
# Date
# 2020-11-27                      0.573845                    0.004206
# 2020-11-28                      0.586118                    0.002042
# 2020-11-29                      0.594296                    0.001034
# 2020-11-30                      0.622548                    0.000001
# 2020-12-01                      0.604387                    0.000610
#
#             indicators/net_realized_profit_loss  indicators/realized_profit  \
# Date
# 2020-11-27                     287463917.994573            499823727.975242
# 2020-11-28                     174442581.582252            218246122.168506
# 2020-11-29                     243291799.680883            281095917.024708
# 2020-11-30                     930610432.561855            961528905.350072
# 2020-12-01                     773064011.715369            907547252.958713
#
#             indicators/realized_loss  indicators/nupl_more_155  \
# Date
# 2020-11-27          212359809.980669                  0.673585
# 2020-11-28           43803540.586254                  0.684383
# 2020-11-29           37804117.343825                  0.692025
# 2020-11-30           30918472.788217                  0.716211
# 2020-12-01          134483241.243344                  0.703497
#
#             indicators/nupl_less_155  indicators/puell_multiple  \
# Date
# 2020-11-27                  0.185563                   1.342383
# 2020-11-28                  0.210765                   1.363777
# 2020-11-29                  0.227499                   1.379278
# 2020-11-30                  0.280243                   1.087892
# 2020-12-01                  0.240982                   1.496095
#
#             indicators/stock_to_flow_deflection  \
# Date
# 2020-11-27                             0.616738
# 2020-11-28                             0.634911
# 2020-11-29                             0.647637
# 2020-11-30                             0.697539
# 2020-12-01                             0.663430
#
#             indicators/difficulty_ribbon_compression
# Date
# 2020-11-27                                  0.029690
# 2020-11-28                                  0.028495
# 2020-11-29                                  0.026482
# 2020-11-30                                  0.025092
# 2020-12-01                                  0.024159

# %% [markdown]
# #### Addresses Metric CSV-Files

# %%
# List of Addresses Features
addresses_feature_list = ['active_count', 'sending_count', 'receiving_count', 'new_non_zero_count', 'non_zero_count', 'min_point_zero_1_count', 'min_point_1_count', 'min_1_count', 'min_10_count', 'min_100_count', 'min_1k_count', 'min_10k_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in addresses_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Addresses Data Frame
df_addresses = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_addresses.columns:
    try:
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].str.replace(',','.')
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Addresses Metric Values
df_addresses.tail()
# Out:
#             addresses/active_count  addresses/sending_count  \
# Date
# 2020-11-27          1098290.000000            718366.000000
# 2020-11-28          1043272.000000            703716.000000
# 2020-11-29           884127.000000            563015.000000
# 2020-11-30           889631.000000            519025.000000
# 2020-12-01          1170489.000000            687581.000000
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-11-27              719222.000000                 513799.000000
# 2020-11-28              644191.000000                 472882.000000
# 2020-11-29              588994.000000                 434832.000000
# 2020-11-30              623543.000000                 441143.000000
# 2020-12-01              841565.000000                 614449.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-11-27           32675862.000000                    8515464.000000
# 2020-11-28           32586624.000000                    8481925.000000
# 2020-11-29           32586946.000000                    8468254.000000
# 2020-11-30           32659333.000000                    8499912.000000
# 2020-12-01           32764603.000000                    8525194.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-11-27               3121227.000000          820011.000000
# 2020-11-28               3118114.000000          820175.000000
# 2020-11-29               3111465.000000          819629.000000
# 2020-11-30               3117495.000000          821144.000000
# 2020-12-01               3115114.000000          820762.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-11-27           154563.000000             16089.000000
# 2020-11-28           154599.000000             16082.000000
# 2020-11-29           154481.000000             16105.000000
# 2020-11-30           154578.000000             16150.000000
# 2020-12-01           154377.000000             16130.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-11-27             2263.000000               109.000000
# 2020-11-28             2262.000000               109.000000
# 2020-11-29             2262.000000               109.000000
# 2020-11-30             2261.000000               109.000000
# 2020-12-01             2259.000000               108.000000

# %% [markdown]
# #### Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Future Features
# futures_feature_list = ['futures_volume_daily_all_sum', 'futures_volume_daily_perpetual_sum', 'futures_open_interest_all_sum', 'futures_open_interest_perpetual_sum', 'futures_funding_rate_perpetual']
#
# ##### Counter to Differentiate between Data Frame Setup and Data Frame Extension
# counter=0
#
# ##### For Loop through all Features in the List
# for x in futures_feature_list:
#
#     ##### Import Feature CSV-Files
#     df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
#
#     ##### Condition - Data Frame Set up or Data Frame Extension
#     if counter > 0:
#
#         ##### Data Frame Extension - Inner Join
#         df_new = df_new.join(df, how='inner')
#
#     else:
#
#         ##### Data Frame Setup
#         df_new = df
#
#     ##### Increase Counter
#     counter +=1
#
# ##### Store Data Frame Copy in Market Data Frame
# df_futures = df_new.copy()
#
# ##### Delete Original Data Frame
# del df_new
#
# ##### Change Data Type of Columns to Float
# for y in df_futures.columns:
#     try:
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].str.replace(',','.')
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].astype(float)
#     except:
#         pass

# %% [markdown]
# ## Target Variables

# %%
df_return = pd.DataFrame(df_market['market/price_usd_close'])

# %%
df_return.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_return['Daily Return in USD'] = df_return['Closed Price USD'].diff()

# %% [raw]
# # Add Column with BTC Daily Returns in Percent
# df_return['Daily Returns in Percent'] = (df_return['Daily Returns USD']) / (df_return['Closed Price USD'].shift(1))*100

# %% [raw]
# # Add Column with BTC Daily Log Returns in Percent
# df_return['Daily Log Returns in Percent'] = pd.DataFrame(np.log(df_return['Closed Price USD']/df_return['Closed Price USD'].shift(1))*100)

# %%
df_return.tail()
# Out:
#             Closed Price USD  Daily Return in USD
# Date
# 2020-11-27      17096.724533            -9.566168
# 2020-11-28      17714.060586           617.336053
# 2020-11-29      18147.636460           433.575874
# 2020-11-30      19689.810545          1542.174085
# 2020-12-01      18863.780861          -826.029684

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Volatility

# %%
# Selecting BTC Close Price in USD
df_volatility = pd.DataFrame(df_market['market/price_usd_close'])

# %%
# Rename Price Column
df_volatility.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_volatility['Daily Return in USD'] = df_volatility['Closed Price USD'].diff()

# %%
# Add Column with BTC Daily Returns in Percent
df_volatility['Daily Return in Percent'] = (df_volatility['Daily Return in USD']) / (df_volatility['Closed Price USD'].shift(1))*100

# %%
# Add Column with BTC Daily Log Returns in Percent
df_volatility['Daily Log Return in Percent'] = pd.DataFrame(np.log(df_volatility['Closed Price USD']/df_volatility['Closed Price USD'].shift(1))*100)

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-11-27      17096.724533            -9.566168                -0.055922
# 2020-11-28      17714.060586           617.336053                 3.610844
# 2020-11-29      18147.636460           433.575874                 2.447637
# 2020-11-30      19689.810545          1542.174085                 8.497934
# 2020-12-01      18863.780861          -826.029684                -4.195214
#
#             Daily Log Return in Percent
# Date
# 2020-11-27                    -0.055938
# 2020-11-28                     3.547181
# 2020-11-29                     2.418162
# 2020-11-30                     8.156094
# 2020-12-01                    -4.285754

# %%
# Calculation of Rolling Volatility of BTC Daily Log Returns for 10, 20 and 30 days period
df_volatility['Volatility Daily Log Return in Percent 3D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=3, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 5D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=5, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 10D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=10, min_periods=1).std())

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-11-27      17096.724533            -9.566168                -0.055922
# 2020-11-28      17714.060586           617.336053                 3.610844
# 2020-11-29      18147.636460           433.575874                 2.447637
# 2020-11-30      19689.810545          1542.174085                 8.497934
# 2020-12-01      18863.780861          -826.029684                -4.195214
#
#             Daily Log Return in Percent  \
# Date
# 2020-11-27                    -0.055938
# 2020-11-28                     3.547181
# 2020-11-29                     2.418162
# 2020-11-30                     8.156094
# 2020-12-01                    -4.285754
#
#             Volatility Daily Log Return in Percent 3D  \
# Date
# 2020-11-27                                   4.909464
# 2020-11-28                                   6.600074
# 2020-11-29                                   1.842929
# 2020-11-30                                   3.039754
# 2020-12-01                                   6.227171
#
#             Volatility Daily Log Return in Percent 5D  \
# Date
# 2020-11-27                                   4.829046
# 2020-11-28                                   5.343618
# 2020-11-29                                   5.044789
# 2020-11-30                                   6.440478
# 2020-12-01                                   4.587865
#
#             Volatility Daily Log Return in Percent 10D
# Date
# 2020-11-27                                    3.752302
# 2020-11-28                                    3.939559
# 2020-11-29                                    4.016258
# 2020-11-30                                    4.574515
# 2020-12-01                                    4.825944

# %%
df_volatility_reduced = df_volatility['Volatility Daily Log Return in Percent 5D']

# %% [markdown]
# ### Log Price

# %%
# Selecting BTC Close Price in USD
df_logprice = pd.DataFrame(np.log(df_market['market/price_usd_close']))

# %%
df_logprice.columns = ['Log Price in USD']

# %%
df_logprice.tail()
# Out:
#             Log Price in USD
# Date
# 2020-11-27          9.746642
# 2020-11-28          9.782114
# 2020-11-29          9.806296
# 2020-11-30          9.887857
# 2020-12-01          9.844999

# %% [markdown]
# # Data Sets

# %% [markdown]
# ## Data Set I. - Blockchain Metrics Only

# %%
# Merging all Blockchain DataFrame Metrics
df_blockchain = pd.concat([df_return, df_logprice, df_volatility_reduced, df_market, df_mining, df_blockfeatures, df_fees, df_utxo, df_supply, 
                           df_transaction, df_indicator1, df_indicator2, df_indicator3, df_addresses], axis=1, join='inner')

# %%
df_blockchain = df_blockchain.dropna()

# %%
df_blockchain = df_blockchain.drop(['Closed Price USD'], axis=1)

# %%
df_blockchain.index = df_blockchain.index.astype('datetime64[ns]')

# %%
df_blockchain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3427 entries, 2011-07-16 to 2020-12-01
# Data columns (total 91 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Daily Return in USD                         3427 non-null   float64
#  1   Log Price in USD                            3427 non-null   float64
#  2   Volatility Daily Log Return in Percent 5D   3427 non-null   float64
#  3   market/price_usd_close                      3427 non-null   float64
#  4   market/price_drawdown_relative              3427 non-null   float64
#  5   market/price_realized_usd                   3427 non-null   float64
#  6   market/mvrv                                 3427 non-null   float64
#  7   mining/difficulty_latest                    3427 non-null   float64
#  8   mining/hash_rate_mean                       3427 non-null   float64
#  9   blockchain/block_count                      3427 non-null   float64
#  10  blockchain/block_interval_mean              3427 non-null   float64
#  11  blockchain/block_size_sum                   3427 non-null   float64
#  12  fees/volume_sum                             3427 non-null   float64
#  13  fees/volume_mean                            3427 non-null   float64
#  14  fees/fee_ratio_multiple                     3427 non-null   float64
#  15  blockchain/utxo_created_count               3427 non-null   float64
#  16  blockchain/utxo_spent_count                 3427 non-null   float64
#  17  blockchain/utxo_created_value_sum           3427 non-null   float64
#  18  blockchain/utxo_spent_value_sum             3427 non-null   float64
#  19  blockchain/utxo_profit_relative             3427 non-null   float64
#  20  blockchain/utxo_profit_count                3427 non-null   float64
#  21  blockchain/utxo_loss_count                  3427 non-null   float64
#  22  supply/current                              3427 non-null   float64
#  23  supply/profit_relative                      3427 non-null   float64
#  24  supply/profit_sum                           3427 non-null   float64
#  25  supply/loss_sum                             3427 non-null   float64
#  26  supply/active_more_1y_percent               3427 non-null   float64
#  27  supply/active_more_2y_percent               3427 non-null   float64
#  28  supply/active_more_3y_percent               3427 non-null   float64
#  29  supply/active_more_5y_percent               3427 non-null   float64
#  30  supply/active_24h                           3427 non-null   float64
#  31  supply/active_1d_1w                         3427 non-null   float64
#  32  supply/active_1w_1m                         3427 non-null   float64
#  33  supply/active_1m_3m                         3427 non-null   float64
#  34  supply/active_3m_6m                         3427 non-null   float64
#  35  supply/active_6m_12m                        3427 non-null   float64
#  36  supply/active_1y_2y                         3427 non-null   float64
#  37  supply/active_2y_3y                         3427 non-null   float64
#  38  supply/active_3y_5y                         3427 non-null   float64
#  39  supply/active_5y_7y                         3427 non-null   float64
#  40  supply/active_7y_10y                        3427 non-null   float64
#  41  supply/active_more_10y                      3427 non-null   float64
#  42  supply/issued                               3427 non-null   float64
#  43  supply/inflation_rate                       3427 non-null   float64
#  44  transactions/count                          3427 non-null   float64
#  45  transactions/size_sum                       3427 non-null   float64
#  46  transactions/transfers_volume_sum           3427 non-null   float64
#  47  transactions/transfers_volume_adjusted_sum  3427 non-null   float64
#  48  indicators/sopr_adjusted                    3427 non-null   float64
#  49  indicators/nvt                              3427 non-null   float64
#  50  indicators/velocity                         3427 non-null   float64
#  51  indicators/cdd                              3427 non-null   float64
#  52  indicators/reserve_risk                     3427 non-null   float64
#  53  indicators/average_dormancy                 3427 non-null   float64
#  54  indicators/liveliness                       3427 non-null   float64
#  55  indicators/asol                             3427 non-null   float64
#  56  indicators/sol_1h                           3427 non-null   float64
#  57  indicators/sol_1h_24h                       3427 non-null   float64
#  58  indicators/sol_1d_1w                        3427 non-null   float64
#  59  indicators/sol_1w_1m                        3427 non-null   float64
#  60  indicators/sol_1m_3m                        3427 non-null   float64
#  61  indicators/sol_3m_6m                        3427 non-null   float64
#  62  indicators/sol_6m_12m                       3427 non-null   float64
#  63  indicators/sol_1y_2y                        3427 non-null   float64
#  64  indicators/sol_2y_3y                        3427 non-null   float64
#  65  indicators/sol_3y_5y                        3427 non-null   float64
#  66  indicators/sol_5y_7y                        3427 non-null   float64
#  67  indicators/sol_7y_10y                       3427 non-null   float64
#  68  indicators/net_unrealized_profit_loss       3427 non-null   float64
#  69  indicators/unrealized_profit                3427 non-null   float64
#  70  indicators/unrealized_loss                  3427 non-null   float64
#  71  indicators/net_realized_profit_loss         3427 non-null   float64
#  72  indicators/realized_profit                  3427 non-null   float64
#  73  indicators/realized_loss                    3427 non-null   float64
#  74  indicators/nupl_more_155                    3427 non-null   float64
#  75  indicators/nupl_less_155                    3427 non-null   float64
#  76  indicators/puell_multiple                   3427 non-null   float64
#  77  indicators/stock_to_flow_deflection         3427 non-null   float64
#  78  indicators/difficulty_ribbon_compression    3427 non-null   float64
#  79  addresses/active_count                      3427 non-null   float64
#  80  addresses/sending_count                     3427 non-null   float64
#  81  addresses/receiving_count                   3427 non-null   float64
#  82  addresses/new_non_zero_count                3427 non-null   float64
#  83  addresses/non_zero_count                    3427 non-null   float64
#  84  addresses/min_point_zero_1_count            3427 non-null   float64
#  85  addresses/min_point_1_count                 3427 non-null   float64
#  86  addresses/min_1_count                       3427 non-null   float64
#  87  addresses/min_10_count                      3427 non-null   float64
#  88  addresses/min_100_count                     3427 non-null   float64
#  89  addresses/min_1k_count                      3427 non-null   float64
#  90  addresses/min_10k_count                     3427 non-null   float64
# dtypes: float64(91)
# memory usage: 2.4 MB

# %%
df_blockchain.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-27            -9.566168          9.746642
# 2020-11-28           617.336053          9.782114
# 2020-11-29           433.575874          9.806296
# 2020-11-30          1542.174085          9.887857
# 2020-12-01          -826.029684          9.844999
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-27                                   4.829046            17096.724533
# 2020-11-28                                   5.343618            17714.060586
# 2020-11-29                                   5.044789            18147.636460
# 2020-11-30                                   6.440478            19689.810545
# 2020-12-01                                   4.587865            18863.780861
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-27                       -0.137049                7324.711202
# 2020-11-28                       -0.105889                7331.626545
# 2020-11-29                       -0.084005                7344.014152
# 2020-11-30                       -0.006164                7383.431438
# 2020-12-01                       -0.049165                7433.569725
#
#             market/mvrv       mining/difficulty_latest  \
# Date
# 2020-11-27     2.321520 75577685065077505392640.000000
# 2020-11-28     2.360943 75577685065077505392640.000000
# 2020-11-29     2.449016 82279353027041903509504.000000
# 2020-11-30     2.555244 82279353027041903509504.000000
# 2020-12-01     2.590058 82279353027041903509504.000000
#
#                   mining/hash_rate_mean  blockchain/block_count  ...  \
# Date                                                             ...
# 2020-11-27 134789789111882006528.000000              154.000000  ...
# 2020-11-28 133670565738951000064.000000              154.000000  ...
# 2020-11-29 135712889718699999232.000000              150.000000  ...
# 2020-11-30 107377083337826992128.000000              113.000000  ...
# 2020-12-01 146392546734912995328.000000              152.000000  ...
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-11-27              719222.000000                 513799.000000
# 2020-11-28              644191.000000                 472882.000000
# 2020-11-29              588994.000000                 434832.000000
# 2020-11-30              623543.000000                 441143.000000
# 2020-12-01              841565.000000                 614449.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-11-27           32675862.000000                    8515464.000000
# 2020-11-28           32586624.000000                    8481925.000000
# 2020-11-29           32586946.000000                    8468254.000000
# 2020-11-30           32659333.000000                    8499912.000000
# 2020-12-01           32764603.000000                    8525194.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-11-27               3121227.000000          820011.000000
# 2020-11-28               3118114.000000          820175.000000
# 2020-11-29               3111465.000000          819629.000000
# 2020-11-30               3117495.000000          821144.000000
# 2020-12-01               3115114.000000          820762.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-11-27           154563.000000             16089.000000
# 2020-11-28           154599.000000             16082.000000
# 2020-11-29           154481.000000             16105.000000
# 2020-11-30           154578.000000             16150.000000
# 2020-12-01           154377.000000             16130.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-11-27             2263.000000               109.000000
# 2020-11-28             2262.000000               109.000000
# 2020-11-29             2262.000000               109.000000
# 2020-11-30             2261.000000               109.000000
# 2020-12-01             2259.000000               108.000000
#
# [5 rows x 91 columns]

# %%
# Summary of each variable
df_blockchain.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count          3427.000000       3427.000000
# mean              5.500429          6.357303
# std             232.809183          2.475641
# min           -3052.461475          0.718341
# 25%              -6.980254          5.405136
# 50%               0.102697          6.416282
# 75%              12.756603          8.780327
# max            3224.132131          9.887857
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                3427.000000             3427.000000
# mean                                    3.536239             3178.286011
# std                                     3.362698             4179.356515
# min                                     0.157723                2.051027
# 25%                                     1.517253              222.546633
# 50%                                     2.653754              611.724312
# 75%                                     4.417728             6505.004406
# max                                    41.749946            19689.810545
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                     3427.000000                3427.000000  3427.000000
# mean                        -0.549479                1921.066095     1.687814
# std                          0.230680                2390.891152     0.743507
# min                         -0.935694                   4.780226     0.402165
# 25%                         -0.715045                 110.887151     1.184703
# 50%                         -0.596692                 349.907576     1.598906
# 75%                         -0.450774                4860.182349     1.977049
# max                          0.000000                7433.569725     5.733982
#
#             mining/difficulty_latest        mining/hash_rate_mean  \
# count                    3427.000000                  3427.000000
# mean  13809291318056737308672.000000  23400277815955836928.000000
# std   23076639658811274035200.000000  39002884300803047424.000000
# min          4684588175054590.000000         6399665203131.940430
# 25%       2617708177598920192.000000      4798276647006305.000000
# 50%     710803494424285937664.000000   1207072827652849920.000000
# 75%   23036823578322000674816.000000  38314210336822706176.000000
# max   85887904103269694177280.000000 160765244797356015616.000000
#
#        blockchain/block_count  ...  addresses/receiving_count  \
# count             3427.000000  ...                3427.000000
# mean               152.634666  ...              323952.439743
# std                 18.998607  ...              227728.669831
# min                 80.000000  ...                7539.000000
# 25%                140.000000  ...               98356.000000
# 50%                152.000000  ...              366101.000000
# 75%                164.000000  ...              509692.000000
# max                260.000000  ...             1072829.000000
#
#        addresses/new_non_zero_count  addresses/non_zero_count  \
# count                   3427.000000               3427.000000
# mean                  216789.266414           12162132.882696
# std                   159518.332733           10795038.352755
# min                     4241.000000             296738.000000
# 25%                    60727.500000            2080736.500000
# 50%                   223657.000000            7436662.000000
# 75%                   348885.500000           22404783.000000
# max                   800180.000000           32849437.000000
#
#        addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# count                       3427.000000                  3427.000000
# mean                     3463763.951853               1390346.730960
# std                      2906740.704137               1026190.126568
# min                       195085.000000                125059.000000
# 25%                       684792.500000                399635.000000
# 50%                      2567356.000000               1186798.000000
# 75%                      6385967.500000               2461892.500000
# max                      8753449.000000               3186455.000000
#
#        addresses/min_1_count  addresses/min_10_count  addresses/min_100_count  \
# count            3427.000000             3427.000000              3427.000000
# mean           469910.070907           125418.739714             14676.156697
# std            239925.805157            28899.790678              3631.075202
# min             98120.000000            64333.000000              3746.000000
# 25%            232553.500000            98981.500000             12878.500000
# 50%            476115.000000           138103.000000             16185.000000
# 75%            710453.500000           149749.000000             17153.000000
# max            825254.000000           157275.000000             18543.000000
#
#        addresses/min_1k_count  addresses/min_10k_count
# count             3427.000000              3427.000000
# mean              1618.897286               102.220601
# std                386.396933                14.753444
# min                597.000000                62.000000
# 25%               1458.000000                96.000000
# 50%               1683.000000               105.000000
# 75%               1843.000000               113.000000
# max               2274.000000               126.000000
#
# [8 rows x 91 columns]

# %%
# Creating CSV-File of Blockchain Data
df_blockchain.to_csv("df_dataset1.csv")

# %% [markdown]
# # Classification Models - Data Set Variations

# %%
# Import of Modules and Packages
import os
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix, classification_report

# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from pycaret.classification import *

# Deep Neural Networks
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from keras.optimizers import Adam

# PyCaret
import pycaret

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Import Data Sets

# %% [markdown]
# ## Data Set I.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010'

# %%
# CSV Import of Data Set I. - Blockchain Data
df_dataset1 = pd.read_csv('df_dataset1.csv', parse_dates = True, index_col='Date')

# %%
df_dataset1
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-07-16                -0.09              2.62
# 2011-07-17                -0.55              2.58
# 2011-07-18                 0.26              2.60
# 2011-07-19                 0.42              2.63
# 2011-07-20                -0.15              2.62
# ...                         ...               ...
# 2020-11-27                -9.57              9.75
# 2020-11-28               617.34              9.78
# 2020-11-29               433.58              9.81
# 2020-11-30              1542.17              9.89
# 2020-12-01              -826.03              9.84
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-07-16                                       0.70                   13.72
# 2011-07-17                                       1.70                   13.17
# 2011-07-18                                       2.23                   13.42
# 2011-07-19                                       2.83                   13.84
# 2011-07-20                                       2.80                   13.69
# ...                                               ...                     ...
# 2020-11-27                                       4.83                17096.72
# 2020-11-28                                       5.34                17714.06
# 2020-11-29                                       5.04                18147.64
# 2020-11-30                                       6.44                19689.81
# 2020-12-01                                       4.59                18863.78
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-07-16                           -0.57                       7.31
# 2011-07-17                           -0.59                       7.32
# 2011-07-18                           -0.58                       7.01
# 2011-07-19                           -0.57                       7.03
# 2011-07-20                           -0.57                       6.97
# ...                                    ...                        ...
# 2020-11-27                           -0.14                    7324.71
# 2020-11-28                           -0.11                    7331.63
# 2020-11-29                           -0.08                    7344.01
# 2020-11-30                           -0.01                    7383.43
# 2020-12-01                           -0.05                    7433.57
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2011-07-16         1.87        6713154126051590.00        11654137109701.80
# 2011-07-17         1.82        6713154126051590.00        13208752331351.50
# 2011-07-18         1.86        6713154126051590.00        13355914725081.60
# 2011-07-19         1.96        7262342175053680.00        11065053631354.40
# 2011-07-20         1.98        7262342175053680.00        12525772772957.20
# ...                 ...                        ...                      ...
# 2020-11-27         2.32 75577685065077505392640.00 134789789111882006528.00
# 2020-11-28         2.36 75577685065077505392640.00 133670565738951000064.00
# 2020-11-29         2.45 82279353027041903509504.00 135712889718699999232.00
# 2020-11-30         2.56 82279353027041903509504.00 107377083337826992128.00
# 2020-12-01         2.59 82279353027041903509504.00 146392546734912995328.00
#
#             blockchain/block_count  ...  addresses/receiving_count  \
# Date                                ...
# 2011-07-16                  157.00  ...                   20543.00
# 2011-07-17                  170.00  ...                   21180.00
# 2011-07-18                  170.00  ...                   21198.00
# 2011-07-19                  142.00  ...                   21433.00
# 2011-07-20                  149.00  ...                   21633.00
# ...                            ...  ...                        ...
# 2020-11-27                  154.00  ...                  719222.00
# 2020-11-28                  154.00  ...                  644191.00
# 2020-11-29                  150.00  ...                  588994.00
# 2020-11-30                  113.00  ...                  623543.00
# 2020-12-01                  152.00  ...                  841565.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-07-16                      14625.00                 296738.00
# 2011-07-17                      15530.00                 303267.00
# 2011-07-18                      15356.00                 305043.00
# 2011-07-19                      15873.00                 310575.00
# 2011-07-20                      15840.00                 315842.00
# ...                                  ...                       ...
# 2020-11-27                     513799.00               32675862.00
# 2020-11-28                     472882.00               32586624.00
# 2020-11-29                     434832.00               32586946.00
# 2020-11-30                     441143.00               32659333.00
# 2020-12-01                     614449.00               32764603.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-07-16                         196860.00                    126035.00
# 2011-07-17                         197576.00                    126461.00
# 2011-07-18                         195085.00                    125059.00
# 2011-07-19                         196075.00                    125791.00
# 2011-07-20                         196368.00                    126121.00
# ...                                      ...                          ...
# 2020-11-27                        8515464.00                   3121227.00
# 2020-11-28                        8481925.00                   3118114.00
# 2020-11-29                        8468254.00                   3111465.00
# 2020-11-30                        8499912.00                   3117495.00
# 2020-12-01                        8525194.00                   3115114.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-07-16               99005.00                64333.00
# 2011-07-17               99364.00                64511.00
# 2011-07-18               98120.00                64454.00
# 2011-07-19               98755.00                64598.00
# 2011-07-20               99090.00                64643.00
# ...                           ...                     ...
# 2020-11-27              820011.00               154563.00
# 2020-11-28              820175.00               154599.00
# 2020-11-29              819629.00               154481.00
# 2020-11-30              821144.00               154578.00
# 2020-12-01              820762.00               154377.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-07-16                  3805.00                  598.00
# 2011-07-17                  3824.00                  599.00
# 2011-07-18                  3746.00                  600.00
# 2011-07-19                  3761.00                  597.00
# 2011-07-20                  3799.00                  598.00
# ...                             ...                     ...
# 2020-11-27                 16089.00                 2263.00
# 2020-11-28                 16082.00                 2262.00
# 2020-11-29                 16105.00                 2262.00
# 2020-11-30                 16150.00                 2261.00
# 2020-12-01                 16130.00                 2259.00
#
#             addresses/min_10k_count
# Date
# 2011-07-16                    62.00
# 2011-07-17                    62.00
# 2011-07-18                    63.00
# 2011-07-19                    63.00
# 2011-07-20                    63.00
# ...                             ...
# 2020-11-27                   109.00
# 2020-11-28                   109.00
# 2020-11-29                   109.00
# 2020-11-30                   109.00
# 2020-12-01                   108.00
#
# [3427 rows x 91 columns]

# %%
# Data Set Info
df_dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3427 entries, 2011-07-16 to 2020-12-01
# Data columns (total 91 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Daily Return in USD                         3427 non-null   float64
#  1   Log Price in USD                            3427 non-null   float64
#  2   Volatility Daily Log Return in Percent 5D   3427 non-null   float64
#  3   market/price_usd_close                      3427 non-null   float64
#  4   market/price_drawdown_relative              3427 non-null   float64
#  5   market/price_realized_usd                   3427 non-null   float64
#  6   market/mvrv                                 3427 non-null   float64
#  7   mining/difficulty_latest                    3427 non-null   float64
#  8   mining/hash_rate_mean                       3427 non-null   float64
#  9   blockchain/block_count                      3427 non-null   float64
#  10  blockchain/block_interval_mean              3427 non-null   float64
#  11  blockchain/block_size_sum                   3427 non-null   float64
#  12  fees/volume_sum                             3427 non-null   float64
#  13  fees/volume_mean                            3427 non-null   float64
#  14  fees/fee_ratio_multiple                     3427 non-null   float64
#  15  blockchain/utxo_created_count               3427 non-null   float64
#  16  blockchain/utxo_spent_count                 3427 non-null   float64
#  17  blockchain/utxo_created_value_sum           3427 non-null   float64
#  18  blockchain/utxo_spent_value_sum             3427 non-null   float64
#  19  blockchain/utxo_profit_relative             3427 non-null   float64
#  20  blockchain/utxo_profit_count                3427 non-null   float64
#  21  blockchain/utxo_loss_count                  3427 non-null   float64
#  22  supply/current                              3427 non-null   float64
#  23  supply/profit_relative                      3427 non-null   float64
#  24  supply/profit_sum                           3427 non-null   float64
#  25  supply/loss_sum                             3427 non-null   float64
#  26  supply/active_more_1y_percent               3427 non-null   float64
#  27  supply/active_more_2y_percent               3427 non-null   float64
#  28  supply/active_more_3y_percent               3427 non-null   float64
#  29  supply/active_more_5y_percent               3427 non-null   float64
#  30  supply/active_24h                           3427 non-null   float64
#  31  supply/active_1d_1w                         3427 non-null   float64
#  32  supply/active_1w_1m                         3427 non-null   float64
#  33  supply/active_1m_3m                         3427 non-null   float64
#  34  supply/active_3m_6m                         3427 non-null   float64
#  35  supply/active_6m_12m                        3427 non-null   float64
#  36  supply/active_1y_2y                         3427 non-null   float64
#  37  supply/active_2y_3y                         3427 non-null   float64
#  38  supply/active_3y_5y                         3427 non-null   float64
#  39  supply/active_5y_7y                         3427 non-null   float64
#  40  supply/active_7y_10y                        3427 non-null   float64
#  41  supply/active_more_10y                      3427 non-null   float64
#  42  supply/issued                               3427 non-null   float64
#  43  supply/inflation_rate                       3427 non-null   float64
#  44  transactions/count                          3427 non-null   float64
#  45  transactions/size_sum                       3427 non-null   float64
#  46  transactions/transfers_volume_sum           3427 non-null   float64
#  47  transactions/transfers_volume_adjusted_sum  3427 non-null   float64
#  48  indicators/sopr_adjusted                    3427 non-null   float64
#  49  indicators/nvt                              3427 non-null   float64
#  50  indicators/velocity                         3427 non-null   float64
#  51  indicators/cdd                              3427 non-null   float64
#  52  indicators/reserve_risk                     3427 non-null   float64
#  53  indicators/average_dormancy                 3427 non-null   float64
#  54  indicators/liveliness                       3427 non-null   float64
#  55  indicators/asol                             3427 non-null   float64
#  56  indicators/sol_1h                           3427 non-null   float64
#  57  indicators/sol_1h_24h                       3427 non-null   float64
#  58  indicators/sol_1d_1w                        3427 non-null   float64
#  59  indicators/sol_1w_1m                        3427 non-null   float64
#  60  indicators/sol_1m_3m                        3427 non-null   float64
#  61  indicators/sol_3m_6m                        3427 non-null   float64
#  62  indicators/sol_6m_12m                       3427 non-null   float64
#  63  indicators/sol_1y_2y                        3427 non-null   float64
#  64  indicators/sol_2y_3y                        3427 non-null   float64
#  65  indicators/sol_3y_5y                        3427 non-null   float64
#  66  indicators/sol_5y_7y                        3427 non-null   float64
#  67  indicators/sol_7y_10y                       3427 non-null   float64
#  68  indicators/net_unrealized_profit_loss       3427 non-null   float64
#  69  indicators/unrealized_profit                3427 non-null   float64
#  70  indicators/unrealized_loss                  3427 non-null   float64
#  71  indicators/net_realized_profit_loss         3427 non-null   float64
#  72  indicators/realized_profit                  3427 non-null   float64
#  73  indicators/realized_loss                    3427 non-null   float64
#  74  indicators/nupl_more_155                    3427 non-null   float64
#  75  indicators/nupl_less_155                    3427 non-null   float64
#  76  indicators/puell_multiple                   3427 non-null   float64
#  77  indicators/stock_to_flow_deflection         3427 non-null   float64
#  78  indicators/difficulty_ribbon_compression    3427 non-null   float64
#  79  addresses/active_count                      3427 non-null   float64
#  80  addresses/sending_count                     3427 non-null   float64
#  81  addresses/receiving_count                   3427 non-null   float64
#  82  addresses/new_non_zero_count                3427 non-null   float64
#  83  addresses/non_zero_count                    3427 non-null   float64
#  84  addresses/min_point_zero_1_count            3427 non-null   float64
#  85  addresses/min_point_1_count                 3427 non-null   float64
#  86  addresses/min_1_count                       3427 non-null   float64
#  87  addresses/min_10_count                      3427 non-null   float64
#  88  addresses/min_100_count                     3427 non-null   float64
#  89  addresses/min_1k_count                      3427 non-null   float64
#  90  addresses/min_10k_count                     3427 non-null   float64
# dtypes: float64(91)
# memory usage: 2.4 MB

# %%
# List of Data Types
l_dtypes = df_dataset1.dtypes

# %%
# Counter
counter = 0

# Cross-Check of Data Types
for i in l_dtypes:
    if (i == float):
        counter = counter+1
    else:
        counter = counter

# Number of Float Data Types
print(counter)
# Out:
# 91

# %%
# Data Types
df_dataset1.dtypes
# Out:
# Daily Return in USD                          float64
# Log Price in USD                             float64
# Volatility Daily Log Return in Percent 5D    float64
# market/price_usd_close                       float64
# market/price_drawdown_relative               float64
#                                               ...
# addresses/min_1_count                        float64
# addresses/min_10_count                       float64
# addresses/min_100_count                      float64
# addresses/min_1k_count                       float64
# addresses/min_10k_count                      float64
# Length: 91, dtype: object

# %%
# Summary Statistics
df_dataset1.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count              3427.00           3427.00
# mean                  5.50              6.36
# std                 232.81              2.48
# min               -3052.46              0.72
# 25%                  -6.98              5.41
# 50%                   0.10              6.42
# 75%                  12.76              8.78
# max                3224.13              9.89
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                    3427.00                 3427.00
# mean                                        3.54                 3178.29
# std                                         3.36                 4179.36
# min                                         0.16                    2.05
# 25%                                         1.52                  222.55
# 50%                                         2.65                  611.72
# 75%                                         4.42                 6505.00
# max                                        41.75                19689.81
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                         3427.00                    3427.00      3427.00
# mean                            -0.55                    1921.07         1.69
# std                              0.23                    2390.89         0.74
# min                             -0.94                       4.78         0.40
# 25%                             -0.72                     110.89         1.18
# 50%                             -0.60                     349.91         1.60
# 75%                             -0.45                    4860.18         1.98
# max                              0.00                    7433.57         5.73
#
#         mining/difficulty_latest    mining/hash_rate_mean  \
# count                    3427.00                  3427.00
# mean  13809291318056737308672.00  23400277815955836928.00
# std   23076639658811274035200.00  39002884300803047424.00
# min          4684588175054590.00         6399665203131.94
# 25%       2617708177598920192.00      4798276647006305.00
# 50%     710803494424285937664.00   1207072827652849920.00
# 75%   23036823578322000674816.00  38314210336822706176.00
# max   85887904103269694177280.00 160765244797356015616.00
#
#        blockchain/block_count  ...  addresses/receiving_count  \
# count                 3427.00  ...                    3427.00
# mean                   152.63  ...                  323952.44
# std                     19.00  ...                  227728.67
# min                     80.00  ...                    7539.00
# 25%                    140.00  ...                   98356.00
# 50%                    152.00  ...                  366101.00
# 75%                    164.00  ...                  509692.00
# max                    260.00  ...                 1072829.00
#
#        addresses/new_non_zero_count  addresses/non_zero_count  \
# count                       3427.00                   3427.00
# mean                      216789.27               12162132.88
# std                       159518.33               10795038.35
# min                         4241.00                 296738.00
# 25%                        60727.50                2080736.50
# 50%                       223657.00                7436662.00
# 75%                       348885.50               22404783.00
# max                       800180.00               32849437.00
#
#        addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# count                           3427.00                      3427.00
# mean                         3463763.95                   1390346.73
# std                          2906740.70                   1026190.13
# min                           195085.00                    125059.00
# 25%                           684792.50                    399635.00
# 50%                          2567356.00                   1186798.00
# 75%                          6385967.50                   2461892.50
# max                          8753449.00                   3186455.00
#
#        addresses/min_1_count  addresses/min_10_count  addresses/min_100_count  \
# count                3427.00                 3427.00                  3427.00
# mean               469910.07               125418.74                 14676.16
# std                239925.81                28899.79                  3631.08
# min                 98120.00                64333.00                  3746.00
# 25%                232553.50                98981.50                 12878.50
# 50%                476115.00               138103.00                 16185.00
# 75%                710453.50               149749.00                 17153.00
# max                825254.00               157275.00                 18543.00
#
#        addresses/min_1k_count  addresses/min_10k_count
# count                 3427.00                  3427.00
# mean                  1618.90                   102.22
# std                    386.40                    14.75
# min                    597.00                    62.00
# 25%                   1458.00                    96.00
# 50%                   1683.00                   105.00
# 75%                   1843.00                   113.00
# max                   2274.00                   126.00
#
# [8 rows x 91 columns]

# %%
# Dataset Tail
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-27                -9.57              9.75
# 2020-11-28               617.34              9.78
# 2020-11-29               433.58              9.81
# 2020-11-30              1542.17              9.89
# 2020-12-01              -826.03              9.84
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-27                                       4.83                17096.72
# 2020-11-28                                       5.34                17714.06
# 2020-11-29                                       5.04                18147.64
# 2020-11-30                                       6.44                19689.81
# 2020-12-01                                       4.59                18863.78
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-27                           -0.14                    7324.71
# 2020-11-28                           -0.11                    7331.63
# 2020-11-29                           -0.08                    7344.01
# 2020-11-30                           -0.01                    7383.43
# 2020-12-01                           -0.05                    7433.57
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-11-27         2.32 75577685065077505392640.00 134789789111882006528.00
# 2020-11-28         2.36 75577685065077505392640.00 133670565738951000064.00
# 2020-11-29         2.45 82279353027041903509504.00 135712889718699999232.00
# 2020-11-30         2.56 82279353027041903509504.00 107377083337826992128.00
# 2020-12-01         2.59 82279353027041903509504.00 146392546734912995328.00
#
#             blockchain/block_count  ...  addresses/receiving_count  \
# Date                                ...
# 2020-11-27                  154.00  ...                  719222.00
# 2020-11-28                  154.00  ...                  644191.00
# 2020-11-29                  150.00  ...                  588994.00
# 2020-11-30                  113.00  ...                  623543.00
# 2020-12-01                  152.00  ...                  841565.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-27                     513799.00               32675862.00
# 2020-11-28                     472882.00               32586624.00
# 2020-11-29                     434832.00               32586946.00
# 2020-11-30                     441143.00               32659333.00
# 2020-12-01                     614449.00               32764603.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-27                        8515464.00                   3121227.00
# 2020-11-28                        8481925.00                   3118114.00
# 2020-11-29                        8468254.00                   3111465.00
# 2020-11-30                        8499912.00                   3117495.00
# 2020-12-01                        8525194.00                   3115114.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-27              820011.00               154563.00
# 2020-11-28              820175.00               154599.00
# 2020-11-29              819629.00               154481.00
# 2020-11-30              821144.00               154578.00
# 2020-12-01              820762.00               154377.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-27                 16089.00                 2263.00
# 2020-11-28                 16082.00                 2262.00
# 2020-11-29                 16105.00                 2262.00
# 2020-11-30                 16150.00                 2261.00
# 2020-12-01                 16130.00                 2259.00
#
#             addresses/min_10k_count
# Date
# 2020-11-27                   109.00
# 2020-11-28                   109.00
# 2020-11-29                   109.00
# 2020-11-30                   109.00
# 2020-12-01                   108.00
#
# [5 rows x 91 columns]

# %% [markdown]
# ## Prediction Shift

# %% [markdown]
# ### Data Set I.

# %%
# Shift of Target Column by 1 Day
df_dataset1['Daily Return in USD'] = df_dataset1['Daily Return in USD'].shift(1)

# %%
# Check Shift
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-27             -1658.19              9.75
# 2020-11-28                -9.57              9.78
# 2020-11-29               617.34              9.81
# 2020-11-30               433.58              9.89
# 2020-12-01              1542.17              9.84
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-27                                       4.83                17096.72
# 2020-11-28                                       5.34                17714.06
# 2020-11-29                                       5.04                18147.64
# 2020-11-30                                       6.44                19689.81
# 2020-12-01                                       4.59                18863.78
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-27                           -0.14                    7324.71
# 2020-11-28                           -0.11                    7331.63
# 2020-11-29                           -0.08                    7344.01
# 2020-11-30                           -0.01                    7383.43
# 2020-12-01                           -0.05                    7433.57
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-11-27         2.32 75577685065077505392640.00 134789789111882006528.00
# 2020-11-28         2.36 75577685065077505392640.00 133670565738951000064.00
# 2020-11-29         2.45 82279353027041903509504.00 135712889718699999232.00
# 2020-11-30         2.56 82279353027041903509504.00 107377083337826992128.00
# 2020-12-01         2.59 82279353027041903509504.00 146392546734912995328.00
#
#             blockchain/block_count  ...  addresses/receiving_count  \
# Date                                ...
# 2020-11-27                  154.00  ...                  719222.00
# 2020-11-28                  154.00  ...                  644191.00
# 2020-11-29                  150.00  ...                  588994.00
# 2020-11-30                  113.00  ...                  623543.00
# 2020-12-01                  152.00  ...                  841565.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-27                     513799.00               32675862.00
# 2020-11-28                     472882.00               32586624.00
# 2020-11-29                     434832.00               32586946.00
# 2020-11-30                     441143.00               32659333.00
# 2020-12-01                     614449.00               32764603.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-27                        8515464.00                   3121227.00
# 2020-11-28                        8481925.00                   3118114.00
# 2020-11-29                        8468254.00                   3111465.00
# 2020-11-30                        8499912.00                   3117495.00
# 2020-12-01                        8525194.00                   3115114.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-27              820011.00               154563.00
# 2020-11-28              820175.00               154599.00
# 2020-11-29              819629.00               154481.00
# 2020-11-30              821144.00               154578.00
# 2020-12-01              820762.00               154377.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-27                 16089.00                 2263.00
# 2020-11-28                 16082.00                 2262.00
# 2020-11-29                 16105.00                 2262.00
# 2020-11-30                 16150.00                 2261.00
# 2020-12-01                 16130.00                 2259.00
#
#             addresses/min_10k_count
# Date
# 2020-11-27                   109.00
# 2020-11-28                   109.00
# 2020-11-29                   109.00
# 2020-11-30                   109.00
# 2020-12-01                   108.00
#
# [5 rows x 91 columns]

# %%
# Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          1
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 91, dtype: int64

# %%
# daily return: von gestern auf heute die preisveränderung deswegen shift später
df_dataset1.isnull()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-07-16                 True             False
# 2011-07-17                False             False
# 2011-07-18                False             False
# 2011-07-19                False             False
# 2011-07-20                False             False
# ...                         ...               ...
# 2020-11-27                False             False
# 2020-11-28                False             False
# 2020-11-29                False             False
# 2020-11-30                False             False
# 2020-12-01                False             False
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-07-16                                      False                   False
# 2011-07-17                                      False                   False
# 2011-07-18                                      False                   False
# 2011-07-19                                      False                   False
# 2011-07-20                                      False                   False
# ...                                               ...                     ...
# 2020-11-27                                      False                   False
# 2020-11-28                                      False                   False
# 2020-11-29                                      False                   False
# 2020-11-30                                      False                   False
# 2020-12-01                                      False                   False
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-07-16                           False                      False
# 2011-07-17                           False                      False
# 2011-07-18                           False                      False
# 2011-07-19                           False                      False
# 2011-07-20                           False                      False
# ...                                    ...                        ...
# 2020-11-27                           False                      False
# 2020-11-28                           False                      False
# 2020-11-29                           False                      False
# 2020-11-30                           False                      False
# 2020-12-01                           False                      False
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-07-16        False                     False                  False
# 2011-07-17        False                     False                  False
# 2011-07-18        False                     False                  False
# 2011-07-19        False                     False                  False
# 2011-07-20        False                     False                  False
# ...                 ...                       ...                    ...
# 2020-11-27        False                     False                  False
# 2020-11-28        False                     False                  False
# 2020-11-29        False                     False                  False
# 2020-11-30        False                     False                  False
# 2020-12-01        False                     False                  False
#
#             blockchain/block_count  ...  addresses/receiving_count  \
# Date                                ...
# 2011-07-16                   False  ...                      False
# 2011-07-17                   False  ...                      False
# 2011-07-18                   False  ...                      False
# 2011-07-19                   False  ...                      False
# 2011-07-20                   False  ...                      False
# ...                            ...  ...                        ...
# 2020-11-27                   False  ...                      False
# 2020-11-28                   False  ...                      False
# 2020-11-29                   False  ...                      False
# 2020-11-30                   False  ...                      False
# 2020-12-01                   False  ...                      False
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-07-16                         False                     False
# 2011-07-17                         False                     False
# 2011-07-18                         False                     False
# 2011-07-19                         False                     False
# 2011-07-20                         False                     False
# ...                                  ...                       ...
# 2020-11-27                         False                     False
# 2020-11-28                         False                     False
# 2020-11-29                         False                     False
# 2020-11-30                         False                     False
# 2020-12-01                         False                     False
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-07-16                             False                        False
# 2011-07-17                             False                        False
# 2011-07-18                             False                        False
# 2011-07-19                             False                        False
# 2011-07-20                             False                        False
# ...                                      ...                          ...
# 2020-11-27                             False                        False
# 2020-11-28                             False                        False
# 2020-11-29                             False                        False
# 2020-11-30                             False                        False
# 2020-12-01                             False                        False
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-07-16                  False                   False
# 2011-07-17                  False                   False
# 2011-07-18                  False                   False
# 2011-07-19                  False                   False
# 2011-07-20                  False                   False
# ...                           ...                     ...
# 2020-11-27                  False                   False
# 2020-11-28                  False                   False
# 2020-11-29                  False                   False
# 2020-11-30                  False                   False
# 2020-12-01                  False                   False
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-07-16                    False                   False
# 2011-07-17                    False                   False
# 2011-07-18                    False                   False
# 2011-07-19                    False                   False
# 2011-07-20                    False                   False
# ...                             ...                     ...
# 2020-11-27                    False                   False
# 2020-11-28                    False                   False
# 2020-11-29                    False                   False
# 2020-11-30                    False                   False
# 2020-12-01                    False                   False
#
#             addresses/min_10k_count
# Date
# 2011-07-16                    False
# 2011-07-17                    False
# 2011-07-18                    False
# 2011-07-19                    False
# 2011-07-20                    False
# ...                             ...
# 2020-11-27                    False
# 2020-11-28                    False
# 2020-11-29                    False
# 2020-11-30                    False
# 2020-12-01                    False
#
# [3427 rows x 91 columns]

# %%
# Delete Empty Row
df_dataset1 = df_dataset1.dropna()

# %%
# Re-Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          0
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 91, dtype: int64

# %% [markdown]
# # Classification Setup

# %% [markdown]
# ## Create Data Set Copies for Trading Strategy

# %%
# Data Set Copy for Trading Extension
df_dataset1_copy = df_dataset1.copy()

# %% [markdown]
# ## Categorization - Data Set I.

# %%
# Categorization
# Class 1 for all Returns >= 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] >= 0, 'Class'] = 1
# Class 0 for all Returns < 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0
# Out:
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(new_indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-298-55abdf32f90e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-07-17                -0.09              2.58
# 2011-07-18                -0.55              2.60
# 2011-07-19                 0.26              2.63
# 2011-07-20                 0.42              2.62
# 2011-07-21                -0.15              2.61
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-07-17                                       1.70                   13.17
# 2011-07-18                                       2.23                   13.42
# 2011-07-19                                       2.83                   13.84
# 2011-07-20                                       2.80                   13.69
# 2011-07-21                                       2.80                   13.61
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-07-17                           -0.59                       7.32
# 2011-07-18                           -0.58                       7.01
# 2011-07-19                           -0.57                       7.03
# 2011-07-20                           -0.57                       6.97
# 2011-07-21                           -0.57                       6.97
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-07-17         1.82       6713154126051590.00      13208752331351.50
# 2011-07-18         1.86       6713154126051590.00      13355914725081.60
# 2011-07-19         1.96       7262342175053680.00      11065053631354.40
# 2011-07-20         1.98       7262342175053680.00      12525772772957.20
# 2011-07-21         1.96       7262342175053680.00      12836364605425.40
#
#             blockchain/block_count  ...  addresses/new_non_zero_count  \
# Date                                ...
# 2011-07-17                  170.00  ...                      15530.00
# 2011-07-18                  170.00  ...                      15356.00
# 2011-07-19                  142.00  ...                      15873.00
# 2011-07-20                  149.00  ...                      15840.00
# 2011-07-21                  152.00  ...                      16486.00
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2011-07-17                 303267.00                         197576.00
# 2011-07-18                 305043.00                         195085.00
# 2011-07-19                 310575.00                         196075.00
# 2011-07-20                 315842.00                         196368.00
# 2011-07-21                 322618.00                         196641.00
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2011-07-17                    126461.00               99364.00
# 2011-07-18                    125059.00               98120.00
# 2011-07-19                    125791.00               98755.00
# 2011-07-20                    126121.00               99090.00
# 2011-07-21                    126152.00               99055.00
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2011-07-17                64511.00                  3824.00
# 2011-07-18                64454.00                  3746.00
# 2011-07-19                64598.00                  3761.00
# 2011-07-20                64643.00                  3799.00
# 2011-07-21                64747.00                  3816.00
#
#             addresses/min_1k_count  addresses/min_10k_count  Class
# Date
# 2011-07-17                  599.00                    62.00   0.00
# 2011-07-18                  600.00                    63.00   0.00
# 2011-07-19                  597.00                    63.00   1.00
# 2011-07-20                  598.00                    63.00   1.00
# 2011-07-21                  599.00                    63.00   0.00
#
# [5 rows x 92 columns]

# %%
# Delete Original Target Column
df_dataset1 = df_dataset1.drop(['Daily Return in USD'], axis=1)

# %%
# Check Class Balance
df_dataset1['Class'].value_counts()
# Out:
# 1.00    1858
# 0.00    1568
# Name: Class, dtype: int64

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Log Price in USD  Volatility Daily Log Return in Percent 5D  \
# Date
# 2011-07-17              2.58                                       1.70
# 2011-07-18              2.60                                       2.23
# 2011-07-19              2.63                                       2.83
# 2011-07-20              2.62                                       2.80
# 2011-07-21              2.61                                       2.80
#
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2011-07-17                   13.17                           -0.59
# 2011-07-18                   13.42                           -0.58
# 2011-07-19                   13.84                           -0.57
# 2011-07-20                   13.69                           -0.57
# 2011-07-21                   13.61                           -0.57
#
#             market/price_realized_usd  market/mvrv  mining/difficulty_latest  \
# Date
# 2011-07-17                       7.32         1.82       6713154126051590.00
# 2011-07-18                       7.01         1.86       6713154126051590.00
# 2011-07-19                       7.03         1.96       7262342175053680.00
# 2011-07-20                       6.97         1.98       7262342175053680.00
# 2011-07-21                       6.97         1.96       7262342175053680.00
#
#             mining/hash_rate_mean  blockchain/block_count  \
# Date
# 2011-07-17      13208752331351.50                  170.00
# 2011-07-18      13355914725081.60                  170.00
# 2011-07-19      11065053631354.40                  142.00
# 2011-07-20      12525772772957.20                  149.00
# 2011-07-21      12836364605425.40                  152.00
#
#             blockchain/block_interval_mean  ...  addresses/new_non_zero_count  \
# Date                                        ...
# 2011-07-17                          508.24  ...                      15530.00
# 2011-07-18                          502.64  ...                      15356.00
# 2011-07-19                          615.92  ...                      15873.00
# 2011-07-20                          579.79  ...                      15840.00
# 2011-07-21                          565.76  ...                      16486.00
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2011-07-17                 303267.00                         197576.00
# 2011-07-18                 305043.00                         195085.00
# 2011-07-19                 310575.00                         196075.00
# 2011-07-20                 315842.00                         196368.00
# 2011-07-21                 322618.00                         196641.00
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2011-07-17                    126461.00               99364.00
# 2011-07-18                    125059.00               98120.00
# 2011-07-19                    125791.00               98755.00
# 2011-07-20                    126121.00               99090.00
# 2011-07-21                    126152.00               99055.00
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2011-07-17                64511.00                  3824.00
# 2011-07-18                64454.00                  3746.00
# 2011-07-19                64598.00                  3761.00
# 2011-07-20                64643.00                  3799.00
# 2011-07-21                64747.00                  3816.00
#
#             addresses/min_1k_count  addresses/min_10k_count  Class
# Date
# 2011-07-17                  599.00                    62.00   0.00
# 2011-07-18                  600.00                    63.00   0.00
# 2011-07-19                  597.00                    63.00   1.00
# 2011-07-20                  598.00                    63.00   1.00
# 2011-07-21                  599.00                    63.00   0.00
#
# [5 rows x 91 columns]

# %% [markdown]
# # Model Preparation - Data Set I.

# %% [markdown]
# ## Train Test Split - Data Set I.

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
predictors = df_dataset1.drop(['Class'], axis=1).values.astype(np.float32)

# %%
len(predictors[1])
# Out:
# 90

# %%
# Setup of Categorized Target Variable
target = df_dataset1['Class'].astype(np.float32)

# %%
# Predictor Dimensions
predictors.shape
# Out:
# (3426, 90)

# %%
# Target Dimensions
target.shape
# Out:
# (3426,)

# %% [markdown]
# # Explore Number of Features

# %%
# report which features were selected by RFE
from sklearn.datasets import make_classification
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier

rank_delete_list = []

# define dataset
#X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# define RFE
rfe = RFE(estimator=LogisticRegression(max_iter=1200), n_features_to_select=88)
# fit RFE
rfe.fit(predictors, target)
# summarize all features
for i in range(predictors.shape[1]):
    print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
    if rfe.support_[i] == False:
        rank_delete_list.append(i)
# Out:
# Column: 0, Selected True, Rank: 1.000
# Column: 1, Selected True, Rank: 1.000
# Column: 2, Selected True, Rank: 1.000
# Column: 3, Selected True, Rank: 1.000
# Column: 4, Selected True, Rank: 1.000
# Column: 5, Selected True, Rank: 1.000
# Column: 6, Selected True, Rank: 1.000
# Column: 7, Selected True, Rank: 1.000
# Column: 8, Selected True, Rank: 1.000
# Column: 9, Selected True, Rank: 1.000
# Column: 10, Selected True, Rank: 1.000
# Column: 11, Selected True, Rank: 1.000
# Column: 12, Selected False, Rank: 3.000
# Column: 13, Selected True, Rank: 1.000
# Column: 14, Selected True, Rank: 1.000
# Column: 15, Selected True, Rank: 1.000
# Column: 16, Selected True, Rank: 1.000
# Column: 17, Selected True, Rank: 1.000
# Column: 18, Selected True, Rank: 1.000
# Column: 19, Selected True, Rank: 1.000
# Column: 20, Selected True, Rank: 1.000
# Column: 21, Selected True, Rank: 1.000
# Column: 22, Selected True, Rank: 1.000
# Column: 23, Selected True, Rank: 1.000
# Column: 24, Selected True, Rank: 1.000
# Column: 25, Selected True, Rank: 1.000
# Column: 26, Selected True, Rank: 1.000
# Column: 27, Selected True, Rank: 1.000
# Column: 28, Selected True, Rank: 1.000
# Column: 29, Selected True, Rank: 1.000
# Column: 30, Selected True, Rank: 1.000
# Column: 31, Selected True, Rank: 1.000
# Column: 32, Selected True, Rank: 1.000
# Column: 33, Selected True, Rank: 1.000
# Column: 34, Selected True, Rank: 1.000
# Column: 35, Selected True, Rank: 1.000
# Column: 36, Selected True, Rank: 1.000
# Column: 37, Selected True, Rank: 1.000
# Column: 38, Selected True, Rank: 1.000
# Column: 39, Selected True, Rank: 1.000
# Column: 40, Selected True, Rank: 1.000
# Column: 41, Selected True, Rank: 1.000
# Column: 42, Selected True, Rank: 1.000
# Column: 43, Selected True, Rank: 1.000
# Column: 44, Selected True, Rank: 1.000
# Column: 45, Selected True, Rank: 1.000
# Column: 46, Selected True, Rank: 1.000
# Column: 47, Selected True, Rank: 1.000
# Column: 48, Selected True, Rank: 1.000
# Column: 49, Selected True, Rank: 1.000
# Column: 50, Selected True, Rank: 1.000
# Column: 51, Selected False, Rank: 2.000
# Column: 52, Selected True, Rank: 1.000
# Column: 53, Selected True, Rank: 1.000
# Column: 54, Selected True, Rank: 1.000
# Column: 55, Selected True, Rank: 1.000
# Column: 56, Selected True, Rank: 1.000
# Column: 57, Selected True, Rank: 1.000
# Column: 58, Selected True, Rank: 1.000
# Column: 59, Selected True, Rank: 1.000
# Column: 60, Selected True, Rank: 1.000
# Column: 61, Selected True, Rank: 1.000
# Column: 62, Selected True, Rank: 1.000
# Column: 63, Selected True, Rank: 1.000
# Column: 64, Selected True, Rank: 1.000
# Column: 65, Selected True, Rank: 1.000
# Column: 66, Selected True, Rank: 1.000
# Column: 67, Selected True, Rank: 1.000
# Column: 68, Selected True, Rank: 1.000
# Column: 69, Selected True, Rank: 1.000
# Column: 70, Selected True, Rank: 1.000
# Column: 71, Selected True, Rank: 1.000
# Column: 72, Selected True, Rank: 1.000
# Column: 73, Selected True, Rank: 1.000
# Column: 74, Selected True, Rank: 1.000
# Column: 75, Selected True, Rank: 1.000
# Column: 76, Selected True, Rank: 1.000
# Column: 77, Selected True, Rank: 1.000
# Column: 78, Selected True, Rank: 1.000
# Column: 79, Selected True, Rank: 1.000
# Column: 80, Selected True, Rank: 1.000
# Column: 81, Selected True, Rank: 1.000
# Column: 82, Selected True, Rank: 1.000
# Column: 83, Selected True, Rank: 1.000
# Column: 84, Selected True, Rank: 1.000
# Column: 85, Selected True, Rank: 1.000
# Column: 86, Selected True, Rank: 1.000
# Column: 87, Selected True, Rank: 1.000
# Column: 88, Selected True, Rank: 1.000
# Column: 89, Selected True, Rank: 1.000

# %%
rank_delete_list
# Out:
# [12, 51]

# %%
predictors.shape
# Out:
# (3426, 90)

# %%
len(rank_delete_list)
# Out:
# 2

# %%
predictors = np.delete(predictors, rank_delete_list, 1)

# %%
predictors.shape
# Out:
# (3426, 88)

# %%
# Train-Test-Split Function to Create Training and Test Data Set
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state = 41, stratify=target)

# %%
# Dimensions of Predictors for Training
X_train.shape
# Out:
# (2398, 88)

# %%
# Dimensions of Target for Training
y_train.shape
# Out:
# (2398,)

# %%
# Number of Predictors
n_nodes = predictors.shape[1]
n_nodes
# Out:
# 88

# %% [markdown]
# ### Check of Class Balance

# %%
# Check Training Target of Class 0
y_train[y_train==0].count()
# Out:
# 1098

# %%
# Check Training Target of Class 1
y_train[y_train==1].count()
# Out:
# 1300

# %%
# Check Test Target of Class 0
y_test[y_test==0].count()
# Out:
# 470

# %%
# Check Test Target of Class 1
y_test[y_test==1].count()
# Out:
# 558

# %% [markdown]
# ## Feature Scaling - Data Set I.

# %%
# Instantiation of MinMaxScaler and StandardSacler
norm_scaler = MinMaxScaler()
#std_scaler = StandardScaler()

# %%
# Scaler Training and Transformation of Training Set
X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))

# %%
# Scaler Transformation of Test Set
X_test_scaled = norm_scaler.transform(X_test)

# %%
# Scaled Test Features
X_test_scaled
# Out:
# array([[0.9229681 , 0.06751736, 0.49339128, ..., 0.9228325 , 0.6306683 ,
#         0.78125   ],
#        [0.95443875, 0.05941685, 0.65847445, ..., 0.83545256, 0.9552507 ,
#         0.671875  ],
#        [0.5528749 , 0.03652924, 0.01647154, ..., 0.8804275 , 0.70763725,
#         0.6875    ],
#        ...,
#        [0.6874135 , 0.07722074, 0.05681274, ..., 0.98133373, 0.6778043 ,
#         0.828125  ],
#        [0.5925591 , 0.01096711, 0.02374676, ..., 0.78655493, 0.55966586,
#         0.578125  ],
#        [0.6325788 , 0.07026467, 0.03432088, ..., 0.911538  , 0.770883  ,
#         0.96875   ]], dtype=float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
predictors_scaled = norm_scaler.transform(predictors)

# %% [markdown]
# # Classification Models - Data Set I.

# %%
# Function To Show Accuracy Mean and Accuracy Standard Deviation
def show_scores(scores):
    # Scores Series
    print('Scores:', scores)
    # Score Mean
    print('Mean:', np.mean(scores))
    # Score Standard Deviation
    print('Standard Deviation:', np.std(scores))

# %% [markdown]
# ## Logistic Regression - Data Set I.

# %%
# Instantiate Classifier - LogisticRegression
lreg = LogisticRegression(max_iter=1200)

# %%
# Train Classifier
lreg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1200)

# %%
# Prediction of Classes
y_pred = lreg.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = lreg.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.73148627, 0.41394015, 0.77579731, 0.49353235, 0.62986547,
#        0.38129862, 0.6754231 , 0.6035323 , 0.66272658, 0.55734311])

# %%
# Select Actual Classes
np.array(y_test[1:11])
# Out:
# array([1., 0., 1., 0., 0., 0., 1., 0., 1., 0.], dtype=float32)

# %%
# Train Accuracy
lreg.score(X_train_scaled, y_train)
# Out:
# 0.6321934945788157

# %%
# Test Accuracy
lreg.score(X_test_scaled, y_test)
# Out:
# 0.603112840466926

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[227 243]
#  [165 393]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.48      0.53       470
#          1.0       0.62      0.70      0.66       558
#
#     accuracy                           0.60      1028
#    macro avg       0.60      0.59      0.59      1028
# weighted avg       0.60      0.60      0.60      1028

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC Score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6400366048959049

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.65348264 0.64995548 0.71981371 0.65111979 0.67512499 0.66248887
#  0.59731451 0.64217593 0.61466088 0.70181969]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.58309038 0.63556851 0.58892128 0.64139942 0.60641399 0.60349854
#  0.64327485 0.64619883 0.61403509 0.55555556]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.58309038 0.63556851 0.58892128 0.64139942 0.60641399 0.60349854
#  0.64327485 0.64619883 0.61403509 0.55555556]
# Mean: 0.6117956455765263
# Standard Deviation: 0.028686317136267923

# %% [markdown]
# ## Random Forest Classifier - Data Set I.

# %%
# Instantiate Classifier - Random Forest
rfc = RandomForestClassifier(n_estimators=100, max_leaf_nodes=None, criterion='gini', max_depth=3, random_state=41)

# %%
# Train Classifier
rfc.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=3, random_state=41)

# %%
# Prediction of Classes
y_pred = rfc.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = rfc.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.65467594, 0.55074714, 0.67987966, 0.47139791, 0.6468946 ,
#        0.43724131, 0.58644383, 0.58017046, 0.74666716, 0.57389413])

# %%
# Train Accuracy
rfc.score(X_train_scaled, y_train)
# Out:
# 0.6330275229357798

# %%
# Test Accuracy
rfc.score(X_test_scaled, y_test)
# Out:
# 0.6284046692607004

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[245 225]
#  [157 401]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.52      0.56       470
#          1.0       0.64      0.72      0.68       558
#
#     accuracy                           0.63      1028
#    macro avg       0.63      0.62      0.62      1028
# weighted avg       0.63      0.63      0.62      1028

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6601006634637382

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.6786179  0.65050339 0.70156154 0.67899459 0.64475036 0.59855489
#  0.62991909 0.6889654  0.60321891 0.65732699]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.64431487 0.6180758  0.60641399 0.6122449  0.60932945 0.60058309
#  0.64327485 0.61403509 0.6374269  0.5994152 ]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.64431487 0.6180758  0.60641399 0.6122449  0.60932945 0.60058309
#  0.64327485 0.61403509 0.6374269  0.5994152 ]
# Mean: 0.6185114145908991
# Standard Deviation: 0.01616503771022906

# %% [markdown]
# # Trading Strategy - Data Set I

# %% [markdown]
# ## Trading Strategy in Combination with Logistic Regression

# %%
# Create Lists To Store All Calculated Values For Every Variable of Every Run
# Specified Period
# Threshold 0.5
spec_list_05_total = []
spec_list_05_profit = []
spec_list_05_loss = []
spec_list_05_trans = []
spec_list_05_acc = []
spec_list_05_preds_corr = []
spec_list_05_preds = []
# Threshold 0.6
spec_list_06_total = []
spec_list_06_profit = []
spec_list_06_loss = []
spec_list_06_trans = []
spec_list_06_acc = []
spec_list_06_preds_corr = []
spec_list_06_preds = []
# Threshold 0.7
spec_list_07_total = []
spec_list_07_profit = []
spec_list_07_loss = []
spec_list_07_trans = []
spec_list_07_acc = []
spec_list_07_preds_corr = []
spec_list_07_preds = []
# Threshold 0.8
spec_list_08_total = []
spec_list_08_profit = []
spec_list_08_loss = []
spec_list_08_trans = []
spec_list_08_acc = []
spec_list_08_preds_corr = []
spec_list_08_preds = []

# Entire Period
# Threshold 0.5
list_05_total = []
list_05_profit = []
list_05_loss = []
list_05_trans = []
list_05_acc = []
list_05_preds_corr = []
list_05_preds = []
# Threshold 0.6
list_06_total = []
list_06_profit = []
list_06_loss = []
list_06_trans = []
list_06_acc = []
list_06_preds_corr = []
list_06_preds = []
# Threshold 0.7
list_07_total = []
list_07_profit = []
list_07_loss = []
list_07_trans = []
list_07_acc = []
list_07_preds_corr = []
list_07_preds = []
# Threshold 0.8
list_08_total = []
list_08_profit = []
list_08_loss = []
list_08_trans = []
list_08_acc = []
list_08_preds_corr = []
list_08_preds = []

# %%
target
# Out:
# Date
# 2011-07-17   0.00
# 2011-07-18   0.00
# 2011-07-19   1.00
# 2011-07-20   1.00
# 2011-07-21   0.00
#              ...
# 2020-11-27   0.00
# 2020-11-28   0.00
# 2020-11-29   1.00
# 2020-11-30   1.00
# 2020-12-01   1.00
# Name: Class, Length: 3426, dtype: float32

# %%
predictors
# Out:
# array([[2.5777836e+00, 1.7005341e+00, 1.3167919e+01, ..., 3.8240000e+03,
#         5.9900000e+02, 6.2000000e+01],
#        [2.5969751e+00, 2.2271056e+00, 1.3423072e+01, ..., 3.7460000e+03,
#         6.0000000e+02, 6.3000000e+01],
#        [2.6277070e+00, 2.8262084e+00, 1.3841993e+01, ..., 3.7610000e+03,
#         5.9700000e+02, 6.3000000e+01],
#        ...,
#        [9.8062954e+00, 5.0447888e+00, 1.8147637e+04, ..., 1.6105000e+04,
#         2.2620000e+03, 1.0900000e+02],
#        [9.8878565e+00, 6.4404783e+00, 1.9689811e+04, ..., 1.6150000e+04,
#         2.2610000e+03, 1.0900000e+02],
#        [9.8449993e+00, 4.5878649e+00, 1.8863781e+04, ..., 1.6130000e+04,
#         2.2590000e+03, 1.0800000e+02]], dtype=float32)

# %%
for x in df_dataset1.columns:
    print(x)
# Out:
# Log Price in USD
# Volatility Daily Log Return in Percent 5D
# market/price_usd_close
# market/price_drawdown_relative
# market/price_realized_usd
# market/mvrv
# mining/difficulty_latest
# mining/hash_rate_mean
# blockchain/block_count
# blockchain/block_interval_mean
# blockchain/block_size_sum
# fees/volume_sum
# fees/volume_mean
# fees/fee_ratio_multiple
# blockchain/utxo_created_count
# blockchain/utxo_spent_count
# blockchain/utxo_created_value_sum
# blockchain/utxo_spent_value_sum
# blockchain/utxo_profit_relative
# blockchain/utxo_profit_count
# blockchain/utxo_loss_count
# supply/current
# supply/profit_relative
# supply/profit_sum
# supply/loss_sum
# supply/active_more_1y_percent
# supply/active_more_2y_percent
# supply/active_more_3y_percent
# supply/active_more_5y_percent
# supply/active_24h
# supply/active_1d_1w
# supply/active_1w_1m
# supply/active_1m_3m
# supply/active_3m_6m
# supply/active_6m_12m
# supply/active_1y_2y
# supply/active_2y_3y
# supply/active_3y_5y
# supply/active_5y_7y
# supply/active_7y_10y
# supply/active_more_10y
# supply/issued
# supply/inflation_rate
# transactions/count
# transactions/size_sum
# transactions/transfers_volume_sum
# transactions/transfers_volume_adjusted_sum
# indicators/sopr_adjusted
# indicators/nvt
# indicators/velocity
# indicators/cdd
# indicators/reserve_risk
# indicators/average_dormancy
# indicators/liveliness
# indicators/asol
# indicators/sol_1h
# indicators/sol_1h_24h
# indicators/sol_1d_1w
# indicators/sol_1w_1m
# indicators/sol_1m_3m
# indicators/sol_3m_6m
# indicators/sol_6m_12m
# indicators/sol_1y_2y
# indicators/sol_2y_3y
# indicators/sol_3y_5y
# indicators/sol_5y_7y
# indicators/sol_7y_10y
# indicators/net_unrealized_profit_loss
# indicators/unrealized_profit
# indicators/unrealized_loss
# indicators/net_realized_profit_loss
# indicators/realized_profit
# indicators/realized_loss
# indicators/nupl_more_155
# indicators/nupl_less_155
# indicators/puell_multiple
# indicators/stock_to_flow_deflection
# indicators/difficulty_ribbon_compression
# addresses/active_count
# addresses/sending_count
# addresses/receiving_count
# addresses/new_non_zero_count
# addresses/non_zero_count
# addresses/min_point_zero_1_count
# addresses/min_point_1_count
# addresses/min_1_count
# addresses/min_10_count
# addresses/min_100_count
# addresses/min_1k_count
# addresses/min_10k_count
# Class

# %%
df_dataset1_copy[['Daily Return in USD']]
# Out:
#             Daily Return in USD
# Date
# 2011-07-17                -0.09
# 2011-07-18                -0.55
# 2011-07-19                 0.26
# 2011-07-20                 0.42
# 2011-07-21                -0.15
# ...                         ...
# 2020-11-27             -1658.19
# 2020-11-28                -9.57
# 2020-11-29               617.34
# 2020-11-30               433.58
# 2020-12-01              1542.17
#
# [3426 rows x 1 columns]

# %%
df_dataset1_copy["percentage_daily_return"] = df_dataset1_copy["Daily Return in USD"]/df_dataset1_copy["market/price_usd_close"]
df_dataset1_copy["percentage_daily_return"]
# Out:
# Date
# 2011-07-17   -0.01
# 2011-07-18   -0.04
# 2011-07-19    0.02
# 2011-07-20    0.03
# 2011-07-21   -0.01
#               ...
# 2020-11-27   -0.10
# 2020-11-28   -0.00
# 2020-11-29    0.03
# 2020-11-30    0.02
# 2020-12-01    0.08
# Name: percentage_daily_return, Length: 3426, dtype: float64

# %%
predictors
# Out:
# array([[2.5777836e+00, 1.7005341e+00, 1.3167919e+01, ..., 3.8240000e+03,
#         5.9900000e+02, 6.2000000e+01],
#        [2.5969751e+00, 2.2271056e+00, 1.3423072e+01, ..., 3.7460000e+03,
#         6.0000000e+02, 6.3000000e+01],
#        [2.6277070e+00, 2.8262084e+00, 1.3841993e+01, ..., 3.7610000e+03,
#         5.9700000e+02, 6.3000000e+01],
#        ...,
#        [9.8062954e+00, 5.0447888e+00, 1.8147637e+04, ..., 1.6105000e+04,
#         2.2620000e+03, 1.0900000e+02],
#        [9.8878565e+00, 6.4404783e+00, 1.9689811e+04, ..., 1.6150000e+04,
#         2.2610000e+03, 1.0900000e+02],
#        [9.8449993e+00, 4.5878649e+00, 1.8863781e+04, ..., 1.6130000e+04,
#         2.2590000e+03, 1.0800000e+02]], dtype=float32)

# %%
einsatz = 1000
prestakepercentlist = []
zinseszins = []
profitpercent = []
current_profitpercent = []
spec_start_date = '2019-09-09'

prestakepercentlist51 = []
prestakepercentlist52 = []
prestakepercentlist53 = []

profitpercent51 = []
profitpercent52 = []
profitpercent53 = []

current_profitpercent51 = []
current_profitpercent52 = []
current_profitpercent53 = []

zinseszins51 = []
zinseszins52 = []
zinseszins53 = []

current_zinseszins = []
current_zinseszins51 = []
current_zinseszins52 = []
current_zinseszins53 = []


# For Loop to Simulate K-fold Cross Validation
for x in range(1, 100):

    # Display Number of Runs
    print("Run:", x)

    # Split Data into Training and Testing
    X_train, X_test, y_train, y_test = train_test_split(
        predictors, target, test_size=0.3, stratify=target)

    # Amount of Columns
    n_nodes = predictors.shape[1]

    # Instantiation of MinMaxScaler
    norm_scaler = MinMaxScaler()

    # Training and Application of Feature Scaler on Training Data of Predictors
    X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))

    # Application of Feature Scaler on Test Data of Predictors
    X_test_scaled = norm_scaler.transform(X_test)

    # Instantiate Classifier Logistic Regression
    lreg = LogisticRegression(max_iter=12000)

    # Train Classifier
    lreg.fit(X_train_scaled, y_train)

    # Prediction of Classes
    y_pred = lreg.predict(X_test_scaled)

    # Display Confusion Matrix and Classification Report
    print(confusion_matrix(y_test, y_pred))
#     print(classification_report(y_test, y_pred))

    # Prediction of Probabilities
    y_pred_prob = lreg.predict_proba(X_test_scaled)[:, 1]

    # Create Data Frame of Actual Values - y_test
    df_y_test = pd.DataFrame(y_test)

    # Add Predicted Probabilities to Data Frame
    df_y_test["y_pred_prob"] = y_pred_prob

    # Add Predicted Classes (0 or 1) to Data Frame to Cross-Check Predicted Probabilities
    df_y_test["y_pred"] = y_pred

    # Select Actual Daily Returns in USD from the Data Set Copy
    df_dataset1_copy_dailyreturns = df_dataset1_copy[['Daily Return in USD']]

    # Merge Predictions and Daily Returns Data Frame on the Column "Date"
    df_y_test_withdailyreturns = pd.merge(
        df_y_test, df_dataset1_copy_dailyreturns, on='Date')

    df_dataset1_copy_percentage = df_dataset1_copy[['percentage_daily_return']]
    df_y_test_withdailyreturns = pd.merge(
        df_y_test_withdailyreturns, df_dataset1_copy_percentage, on='Date')

    # Add Bitcoin Price in USD
    df_y_test_withdailyreturns = pd.merge(
        df_y_test_withdailyreturns, df_dataset1['market/price_usd_close'], on='Date')

    df_y_test_withdailyreturns['y_pred_prob_bereinigt'] = np.where(
        df_y_test_withdailyreturns['y_pred_prob'] < 0.5, 1-df_y_test_withdailyreturns['y_pred_prob'], df_y_test_withdailyreturns['y_pred_prob'])

    df_y_test_withdailyreturns["Einsatz"] = einsatz * \
        df_y_test_withdailyreturns["y_pred_prob_bereinigt"]  # **2

    # Add and Calculate Transaction Costs based on the Bitcoin Price in USD
    df_y_test_withdailyreturns['Transaction Costs in USD'] = df_y_test_withdailyreturns['Einsatz']*0.0003*2

    # Create List of Multiple Thresholds
    # A Threshold of 0.7 means that only predicted probabilites with more than 0.7 or less than 0.3 are considered further
    list_thresholdcalc = [0.5, 0.51, 0.52, 0.53]

    # Try and Except Block to Address Cases in Which a Data Frame does NOT Contain Any Values Because No predicted Probability Meets the Threshold Requirements
    try:

        # For Loop Over List
        for thresholdcalc in list_thresholdcalc:

            # Creation of a Data Frame Containing Only Probability Predictions Which Meet the Threshold Requirements
            df_y_test_probaall = df_y_test.loc[(df_y_test['y_pred_prob'] > thresholdcalc) | (
                df_y_test['y_pred_prob'] < 1-thresholdcalc)]

            # Calculation Of Accuracy Only for the Data Subset Meeting Threshold Requirements
            acc_calc = len(df_y_test_probaall[df_y_test_probaall['Class']
                                              == df_y_test_probaall['y_pred']]) / len(df_y_test_probaall)

            print("Threshold of:", thresholdcalc)
            print(classification_report(
                df_y_test_probaall["Class"], df_y_test_probaall["y_pred"]))

            # Creation of Another Data Frame including Returns and Transaction Costs
            # Only For Probability Predicitons that Meet the Threshold Requirements
            df_y_test_probaall_withdailyreturns = df_y_test_withdailyreturns.loc[(
                df_y_test_withdailyreturns['y_pred_prob'] > thresholdcalc) | (df_y_test_withdailyreturns['y_pred_prob'] < 1-thresholdcalc)]

            # Trading Assumption: Bet Amount = 1 Bitcoin for Each Prediction
            # Select Daily Returns Only From True Predictions Where Predicted Class equals Actual Class.
            # It does not matter whether Daily Returns are Positive or Negative as Short-Selling Option Allows To Profit From Falling Prices
            profit = df_y_test_probaall_withdailyreturns["percentage_daily_return"][
                df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()

            # Select  Daily Returns Only From False Predictions Where Predicted Class equals Actual Class
            loss = df_y_test_probaall_withdailyreturns["percentage_daily_return"][df_y_test_probaall_withdailyreturns['Class']
                                                                                  != df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()

            print("prestake profit-loss {:.2f} x".format(profit-loss))

            if thresholdcalc == 0.5:
                prestakepercentlist.append(int((profit-loss)*100))
            if thresholdcalc == 0.51:
                prestakepercentlist51.append(int((profit-loss)*100))
            if thresholdcalc == 0.52:
                prestakepercentlist52.append(int((profit-loss)*100))
            if thresholdcalc == 0.53:
                prestakepercentlist53.append(int((profit-loss)*100))

            loss = loss * einsatz
            profit = profit * einsatz

            # Calculation of Transaction Costs based On BTC Value in USD. Each Future Trade considers Transaction Costs twice, becauase of Buying and Selling the Future
            transaction_costs = df_y_test_probaall_withdailyreturns['Transaction Costs in USD'].sum(
            )

            # Calculation of Total Profit Considering Profit, Loss and Transaction Costs
            total = profit-loss-transaction_costs

            # In addition, the same setting with different time horizon
            currentpreds_all = df_y_test_probaall_withdailyreturns[
                df_y_test_probaall_withdailyreturns.index >= spec_start_date]

            # the len
            currentpreds_all_count = len(currentpreds_all)

            # Analog to Profit Calculation Above
            currentpreds_winning_total = currentpreds_all["percentage_daily_return"][(
                currentpreds_all['Class'] == currentpreds_all['y_pred'])].abs().sum()
            # Analog to Loss Calculation Above
            currentpreds_loosing_total = currentpreds_all["percentage_daily_return"][(
                currentpreds_all['Class'] != currentpreds_all['y_pred'])].abs().sum()
            # Analog to Calculation of Transaction Costs Above
            currentpreds_transaction_costs = currentpreds_all['Transaction Costs in USD'][(
                currentpreds_all['Class'] != currentpreds_all['y_pred'])].abs().sum()

            currentpreds_loosing_total = currentpreds_loosing_total * einsatz
            currentpreds_winning_total = currentpreds_winning_total * einsatz

            # Analog to Calculation of Total Profit
            currentpreds_total = currentpreds_winning_total - \
                currentpreds_loosing_total-currentpreds_transaction_costs

            # Condition
            # In Case the Shorter Time Horizon Does Not Include any Sample -> Empyt Output
            if currentpreds_all_count == 0:
                currentpreds_all_count = '-'
                current_acc_calc = '-'

            # Otherwise Calculation of Accuracy analog to theeins Accuracy Calculation for the Entire Period
            else:
                current_acc_calc = (len(currentpreds_all["Daily Return in USD"][(
                    currentpreds_all['Class'] == currentpreds_all['y_pred'])]))/currentpreds_all_count

            # Display of Threshold, Total Profit, Profit, Loss, Transaction Costs, Accuracy and Correct Number of Predictions Both for the Specified Time Horizon and the Entire Time
            print("SpecPeriod:")
            print("einsatz", int(currentpreds_all["Einsatz"].sum()), "Total Return in SpecPeriod:", int(currentpreds_total), "/ Profit: ", int(currentpreds_winning_total), "/ Loss: ", int(currentpreds_loosing_total), "/ TransCosts: ", int(currentpreds_transaction_costs),
                  "/ #CorrectPreds:", (len(currentpreds_all["Daily Return in USD"][(currentpreds_all['Class'] == currentpreds_all['y_pred'])])), "of", len(currentpreds_all))

            print("CalcAccuracy {:.2f} -- profit in %/bet: {:.2f}".format(current_acc_calc, 100*(int(
                currentpreds_total) / len(currentpreds_all)) / (currentpreds_all["Einsatz"].sum() / len(currentpreds_all))))
            print("einsatz * 1+profit% ^ # wetten {:.2f}".format(einsatz*(1+(int(currentpreds_total) / len(currentpreds_all)) / (
                currentpreds_all["Einsatz"].sum() / len(currentpreds_all))) ** len(currentpreds_all)))

            if thresholdcalc == 0.5:
                current_profitpercent.append(100*(int(currentpreds_total) / len(
                    currentpreds_all)) / (currentpreds_all["Einsatz"].sum() / len(currentpreds_all)))
            if thresholdcalc == 0.51:
                current_profitpercent51.append(100*(int(currentpreds_total) / len(
                    currentpreds_all)) / (currentpreds_all["Einsatz"].sum() / len(currentpreds_all)))
            if thresholdcalc == 0.52:
                current_profitpercent52.append(100*(int(currentpreds_total) / len(
                    currentpreds_all)) / (currentpreds_all["Einsatz"].sum() / len(currentpreds_all)))
            if thresholdcalc == 0.53:
                current_profitpercent53.append(100*(int(currentpreds_total) / len(
                    currentpreds_all)) / (currentpreds_all["Einsatz"].sum() / len(currentpreds_all)))

            print()
            print("Entire Period:")
            print("einsatz", int(df_y_test_probaall_withdailyreturns["Einsatz"].sum()), "TotReturn:", int(total), "/ Profit: ", int(profit), "/ Loss: ", int(loss), "/ TransCosts: ", int(
                transaction_costs), "/ CalcAccuracy", round(acc_calc, 2), "/ #CorrectPreds:", len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]),  "Of", len(df_y_test_probaall))
            print("einsatz/bet", df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall), "TotReturn / bet", int(total) / len(
                df_y_test_probaall), "/ TranCosts / bet ", int(transaction_costs) / len(df_y_test_probaall), "/ CalcuAcc", round(acc_calc, 2))
            print("profit in %/bet: {:.2f}".format(100*(int(total) / len(df_y_test_probaall)) / (
                df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall))))

            if thresholdcalc == 0.5:
                profitpercent.append(100*(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall)))
            if thresholdcalc == 0.51:
                profitpercent51.append(100*(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall)))
            if thresholdcalc == 0.52:
                profitpercent52.append(100*(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall)))
            if thresholdcalc == 0.53:
                profitpercent53.append(100*(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall)))

            print("einsatz * 1+profit% ^ # wetten {:.2f}".format(einsatz*(1+(int(total) / len(df_y_test_probaall)) / (
                df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall))) ** len(df_y_test_probaall)))
            if thresholdcalc == 0.5:
                zinseszins.append(einsatz*(1+(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall))) ** len(df_y_test_probaall))

                current_zinseszins.append(einsatz*(1+(int(currentpreds_total) / len(currentpreds_all)) / (
                    currentpreds_all["Einsatz"].sum() / len(currentpreds_all))) ** len(currentpreds_all))

            print()
            print()

            # Store All Calculated Values For Every Variable of Every Run
            # Specified Period
            # Threshold = 0.5
            if thresholdcalc == 0.5:
                spec_list_05_total.append(currentpreds_total)
                spec_list_05_profit.append(currentpreds_winning_total)
                spec_list_05_loss.append(currentpreds_loosing_total)
                spec_list_05_trans.append(currentpreds_transaction_costs)
                spec_list_05_acc.append(current_acc_calc)
                spec_list_05_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(
                    df_y_test_probaall_withdailyreturns.index >= spec_start_date) & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_05_preds.append(currentpreds_all_count)
                # Entire Period:
                list_05_total.append(total)
                list_05_profit.append(profit)
                list_05_loss.append(loss)
                list_05_trans.append(transaction_costs)
                list_05_acc.append(acc_calc)
                list_05_preds_corr.append(len(
                    df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_05_preds.append(len(df_y_test_probaall))

            # Threshold = 0.6
            if thresholdcalc == 0.51:
                spec_list_06_total.append(currentpreds_total)
                spec_list_06_profit.append(currentpreds_winning_total)
                spec_list_06_loss.append(currentpreds_loosing_total)
                spec_list_06_trans.append(currentpreds_transaction_costs)
                spec_list_06_acc.append(current_acc_calc)
                spec_list_06_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(
                    df_y_test_probaall_withdailyreturns.index >= spec_start_date) & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_06_preds.append(currentpreds_all_count)
                # Entire Period:
                list_06_total.append(total)
                list_06_profit.append(profit)
                list_06_loss.append(loss)
                list_06_trans.append(transaction_costs)
                list_06_acc.append(acc_calc)
                list_06_preds_corr.append(len(
                    df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_06_preds.append(len(df_y_test_probaall))

                zinseszins51.append(einsatz*(1+(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall))) ** len(df_y_test_probaall))

                current_zinseszins51.append(einsatz*(1+(int(currentpreds_total) / len(currentpreds_all)) / (
                    currentpreds_all["Einsatz"].sum() / len(currentpreds_all))) ** len(currentpreds_all))

            # Threshold = 0.7
            if thresholdcalc == 0.52:
                spec_list_07_total.append(currentpreds_total)
                spec_list_07_profit.append(currentpreds_winning_total)
                spec_list_07_loss.append(currentpreds_loosing_total)
                spec_list_07_trans.append(currentpreds_transaction_costs)
                spec_list_07_acc.append(current_acc_calc)
                spec_list_07_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(
                    df_y_test_probaall_withdailyreturns.index >= spec_start_date) & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_07_preds.append(currentpreds_all_count)
                # Entire Period:
                list_07_total.append(total)
                list_07_profit.append(profit)
                list_07_loss.append(loss)
                list_07_trans.append(transaction_costs)
                list_07_acc.append(acc_calc)
                list_07_preds_corr.append(len(
                    df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_07_preds.append(len(df_y_test_probaall))
                zinseszins52.append(einsatz*(1+(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall))) ** len(df_y_test_probaall))

                current_zinseszins52.append(einsatz*(1+(int(currentpreds_total) / len(currentpreds_all)) / (
                    currentpreds_all["Einsatz"].sum() / len(currentpreds_all))) ** len(currentpreds_all))

            # Threshold = 0.8
            if thresholdcalc == 0.53:
                spec_list_08_total.append(currentpreds_total)
                spec_list_08_profit.append(currentpreds_winning_total)
                spec_list_08_loss.append(currentpreds_loosing_total)
                spec_list_08_trans.append(currentpreds_transaction_costs)
                spec_list_08_acc.append(current_acc_calc)
                spec_list_08_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(
                    df_y_test_probaall_withdailyreturns.index >= spec_start_date) & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_08_preds.append(currentpreds_all_count)
                # Entire Period:
                list_08_total.append(total)
                list_08_profit.append(profit)
                list_08_loss.append(loss)
                list_08_trans.append(transaction_costs)
                list_08_acc.append(acc_calc)
                list_08_preds_corr.append(len(
                    df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_08_preds.append(len(df_y_test_probaall))
                zinseszins53.append(einsatz*(1+(int(total) / len(df_y_test_probaall)) / (
                    df_y_test_probaall_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall))) ** len(df_y_test_probaall))

                current_zinseszins53.append(einsatz*(1+(int(currentpreds_total) / len(currentpreds_all)) / (
                    currentpreds_all["Einsatz"].sum() / len(currentpreds_all))) ** len(currentpreds_all))

    except:
        print("error")
    print()
    print()
# Out:
# Run: 1
# [[218 252]
#  [154 404]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.46      0.52       470
#          1.0       0.62      0.72      0.67       558
#
#     accuracy                           0.61      1028
#    macro avg       0.60      0.59      0.59      1028
# weighted avg       0.60      0.61      0.60      1028
#
# prestake profit-loss 8.63 x
# SpecPeriod:
# einsatz 72750 Total Return in SpecPeriod: 805 / Profit:  1543 / Loss:  719 / TransCosts:  17 / #CorrectPreds: 75 of 129
# CalcAccuracy 0.58 -- profit in %/bet: 1.11
# einsatz * 1+profit% ^ # wetten 4135.32
#
# Entire Period:
# einsatz 624944 TotReturn: 8258 / Profit:  19048 / Loss:  10414 / TransCosts:  374 / CalcAccuracy 0.61 / #CorrectPreds: 622 Of 1028
# einsatz/bet 607.9224217323977 TotReturn / bet 8.03307392996109 / TranCosts / bet  0.3638132295719844 / CalcuAcc 0.61
# profit in %/bet: 1.32
# einsatz * 1+profit% ^ # wetten 725781170.00
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.46      0.52       442
#          1.0       0.63      0.74      0.68       540
#
#     accuracy                           0.61       982
#    macro avg       0.61      0.60      0.60       982
# weighted avg       0.61      0.61      0.61       982
#
# prestake profit-loss 8.98 x
# SpecPeriod:
# einsatz 68716 Total Return in SpecPeriod: 784 / Profit:  1505 / Loss:  704 / TransCosts:  16 / #CorrectPreds: 70 of 121
# CalcAccuracy 0.58 -- profit in %/bet: 1.14
# einsatz * 1+profit% ^ # wetten 3945.95
#
# Entire Period:
# einsatz 601702 TotReturn: 8623 / Profit:  18583 / Loss:  9598 / TransCosts:  361 / CalcAccuracy 0.61 / #CorrectPreds: 602 Of 982
# einsatz/bet 612.7313096777422 TotReturn / bet 8.781059063136457 / TranCosts / bet  0.36761710794297353 / CalcuAcc 0.61
# profit in %/bet: 1.43
# einsatz * 1+profit% ^ # wetten 1170761954.73
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.47      0.53       421
#          1.0       0.63      0.76      0.69       508
#
#     accuracy                           0.63       929
#    macro avg       0.62      0.61      0.61       929
# weighted avg       0.62      0.63      0.62       929
#
# prestake profit-loss 9.01 x
# SpecPeriod:
# einsatz 60988 Total Return in SpecPeriod: 820 / Profit:  1446 / Loss:  612 / TransCosts:  14 / #CorrectPreds: 64 of 106
# CalcAccuracy 0.60 -- profit in %/bet: 1.34
# einsatz * 1+profit% ^ # wetten 4119.37
#
# Entire Period:
# einsatz 574417 TotReturn: 8668 / Profit:  18116 / Loss:  9102 / TransCosts:  344 / CalcAccuracy 0.63 / #CorrectPreds: 581 Of 929
# einsatz/bet 618.3175459633346 TotReturn / bet 9.330462863293864 / TranCosts / bet  0.37029063509149623 / CalcuAcc 0.63
# profit in %/bet: 1.51
# einsatz * 1+profit% ^ # wetten 1103466742.29
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.45      0.52       384
#          1.0       0.63      0.76      0.69       481
#
#     accuracy                           0.62       865
#    macro avg       0.62      0.61      0.60       865
# weighted avg       0.62      0.62      0.61       865
#
# prestake profit-loss 9.03 x
# SpecPeriod:
# einsatz 54187 Total Return in SpecPeriod: 768 / Profit:  1299 / Loss:  518 / TransCosts:  12 / #CorrectPreds: 57 of 93
# CalcAccuracy 0.61 -- profit in %/bet: 1.42
# einsatz * 1+profit% ^ # wetten 3701.86
#
# Entire Period:
# einsatz 540858 TotReturn: 8707 / Profit:  17319 / Loss:  8287 / TransCosts:  324 / CalcAccuracy 0.62 / #CorrectPreds: 540 Of 865
# einsatz/bet 625.2702224983053 TotReturn / bet 10.065895953757225 / TranCosts / bet  0.3745664739884393 / CalcuAcc 0.62
# profit in %/bet: 1.61
# einsatz * 1+profit% ^ # wetten 998771113.16
#
#
#
#
# Run: 2
# [[206 264]
#  [171 387]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.44      0.49       470
#          1.0       0.59      0.69      0.64       558
#
#     accuracy                           0.58      1028
#    macro avg       0.57      0.57      0.56      1028
# weighted avg       0.57      0.58      0.57      1028
#
# prestake profit-loss 9.23 x
# SpecPeriod:
# einsatz 84023 Total Return in SpecPeriod: 788 / Profit:  1909 / Loss:  1101 / TransCosts:  19 / #CorrectPreds: 86 of 142
# CalcAccuracy 0.61 -- profit in %/bet: 0.94
# einsatz * 1+profit% ^ # wetten 3764.13
#
# Entire Period:
# einsatz 633224 TotReturn: 8854 / Profit:  18932 / Loss:  9697 / TransCosts:  379 / CalcAccuracy 0.58 / #CorrectPreds: 593 Of 1028
# einsatz/bet 615.9767005292541 TotReturn / bet 8.61284046692607 / TranCosts / bet  0.36867704280155644 / CalcuAcc 0.58
# profit in %/bet: 1.40
# einsatz * 1+profit% ^ # wetten 1582246578.32
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.44      0.49       453
#          1.0       0.60      0.70      0.64       544
#
#     accuracy                           0.58       997
#    macro avg       0.57      0.57      0.56       997
# weighted avg       0.57      0.58      0.57       997
#
# prestake profit-loss 9.32 x
# SpecPeriod:
# einsatz 82498 Total Return in SpecPeriod: 815 / Profit:  1908 / Loss:  1074 / TransCosts:  18 / #CorrectPreds: 85 of 139
# CalcAccuracy 0.61 -- profit in %/bet: 0.99
# einsatz * 1+profit% ^ # wetten 3921.33
#
# Entire Period:
# einsatz 617546 TotReturn: 8952 / Profit:  18590 / Loss:  9267 / TransCosts:  370 / CalcAccuracy 0.58 / #CorrectPreds: 577 Of 997
# einsatz/bet 619.4045161435237 TotReturn / bet 8.978936810431295 / TranCosts / bet  0.3711133400200602 / CalcuAcc 0.58
# profit in %/bet: 1.45
# einsatz * 1+profit% ^ # wetten 1704597022.60
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.44      0.49       422
#          1.0       0.61      0.71      0.66       518
#
#     accuracy                           0.59       940
#    macro avg       0.58      0.57      0.57       940
# weighted avg       0.58      0.59      0.58       940
#
# prestake profit-loss 9.45 x
# SpecPeriod:
# einsatz 73748 Total Return in SpecPeriod: 911 / Profit:  1816 / Loss:  888 / TransCosts:  15 / #CorrectPreds: 77 of 122
# CalcAccuracy 0.63 -- profit in %/bet: 1.24
# einsatz * 1+profit% ^ # wetten 4471.91
#
# Entire Period:
# einsatz 588185 TotReturn: 9094 / Profit:  18211 / Loss:  8763 / TransCosts:  352 / CalcAccuracy 0.59 / #CorrectPreds: 553 Of 940
# einsatz/bet 625.7291544925698 TotReturn / bet 9.674468085106383 / TranCosts / bet  0.37446808510638296 / CalcuAcc 0.59
# profit in %/bet: 1.55
# einsatz * 1+profit% ^ # wetten 1834417930.01
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.44      0.49       386
#          1.0       0.62      0.73      0.67       492
#
#     accuracy                           0.60       878
#    macro avg       0.59      0.58      0.58       878
# weighted avg       0.60      0.60      0.59       878
#
# prestake profit-loss 9.20 x
# SpecPeriod:
# einsatz 69544 Total Return in SpecPeriod: 916 / Profit:  1753 / Loss:  822 / TransCosts:  14 / #CorrectPreds: 73 of 114
# CalcAccuracy 0.64 -- profit in %/bet: 1.32
# einsatz * 1+profit% ^ # wetten 4444.82
#
# Entire Period:
# einsatz 555653 TotReturn: 8869 / Profit:  17317 / Loss:  8114 / TransCosts:  333 / CalcAccuracy 0.6 / #CorrectPreds: 528 Of 878
# einsatz/bet 632.863093798867 TotReturn / bet 10.101366742596811 / TranCosts / bet  0.3792710706150342 / CalcuAcc 0.6
# profit in %/bet: 1.60
# einsatz * 1+profit% ^ # wetten 1091892939.51
#
#
#
#
# Run: 3
# [[226 244]
#  [156 402]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.48      0.53       470
#          1.0       0.62      0.72      0.67       558
#
#     accuracy                           0.61      1028
#    macro avg       0.61      0.60      0.60      1028
# weighted avg       0.61      0.61      0.61      1028
#
# prestake profit-loss 12.58 x
# SpecPeriod:
# einsatz 84425 Total Return in SpecPeriod: 1043 / Profit:  2188 / Loss:  1121 / TransCosts:  22 / #CorrectPreds: 78 of 143
# CalcAccuracy 0.55 -- profit in %/bet: 1.24
# einsatz * 1+profit% ^ # wetten 5788.10
#
# Entire Period:
# einsatz 625090 TotReturn: 12206 / Profit:  21456 / Loss:  8874 / TransCosts:  375 / CalcAccuracy 0.61 / #CorrectPreds: 628 Of 1028
# einsatz/bet 608.0650465499 TotReturn / bet 11.873540856031129 / TranCosts / bet  0.3647859922178988 / CalcuAcc 0.61
# profit in %/bet: 1.95
# einsatz * 1+profit% ^ # wetten 430319940358.85
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.46      0.52       442
#          1.0       0.62      0.73      0.67       541
#
#     accuracy                           0.61       983
#    macro avg       0.60      0.60      0.59       983
# weighted avg       0.61      0.61      0.60       983
#
# prestake profit-loss 12.27 x
# SpecPeriod:
# einsatz 79356 Total Return in SpecPeriod: 1037 / Profit:  2098 / Loss:  1040 / TransCosts:  21 / #CorrectPreds: 73 of 133
# CalcAccuracy 0.55 -- profit in %/bet: 1.31
# einsatz * 1+profit% ^ # wetten 5622.31
#
# Entire Period:
# einsatz 602351 TotReturn: 11912 / Profit:  20688 / Loss:  8414 / TransCosts:  361 / CalcAccuracy 0.61 / #CorrectPreds: 599 Of 983
# einsatz/bet 612.7681047945939 TotReturn / bet 12.118006103763987 / TranCosts / bet  0.3672431332655137 / CalcuAcc 0.61
# profit in %/bet: 1.98
# einsatz * 1+profit% ^ # wetten 229160570801.43
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.47      0.52       414
#          1.0       0.63      0.73      0.68       514
#
#     accuracy                           0.62       928
#    macro avg       0.61      0.60      0.60       928
# weighted avg       0.61      0.62      0.61       928
#
# prestake profit-loss 11.78 x
# SpecPeriod:
# einsatz 74224 Total Return in SpecPeriod: 1028 / Profit:  1986 / Loss:  938 / TransCosts:  19 / #CorrectPreds: 69 of 123
# CalcAccuracy 0.56 -- profit in %/bet: 1.38
# einsatz * 1+profit% ^ # wetten 5429.45
#
# Entire Period:
# einsatz 574040 TotReturn: 11436 / Profit:  19757 / Loss:  7976 / TransCosts:  344 / CalcAccuracy 0.62 / #CorrectPreds: 571 Of 928
# einsatz/bet 618.5778302788693 TotReturn / bet 12.323275862068966 / TranCosts / bet  0.3706896551724138 / CalcuAcc 0.62
# profit in %/bet: 1.99
# einsatz * 1+profit% ^ # wetten 89149395688.32
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.46      0.52       385
#          1.0       0.63      0.74      0.68       484
#
#     accuracy                           0.62       869
#    macro avg       0.61      0.60      0.60       869
# weighted avg       0.61      0.62      0.61       869
#
# prestake profit-loss 11.08 x
# SpecPeriod:
# einsatz 68429 Total Return in SpecPeriod: 1027 / Profit:  1919 / Loss:  874 / TransCosts:  17 / #CorrectPreds: 64 of 112
# CalcAccuracy 0.57 -- profit in %/bet: 1.50
# einsatz * 1+profit% ^ # wetten 5303.78
#
# Entire Period:
# einsatz 543042 TotReturn: 10753 / Profit:  18675 / Loss:  7596 / TransCosts:  325 / CalcAccuracy 0.62 / #CorrectPreds: 536 Of 869
# einsatz/bet 624.9055489893108 TotReturn / bet 12.373993095512082 / TranCosts / bet  0.3739930955120829 / CalcuAcc 0.62
# profit in %/bet: 1.98
# einsatz * 1+profit% ^ # wetten 25121920733.17
#
#
#
#
# Run: 4
# [[227 243]
#  [151 407]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.54       470
#          1.0       0.63      0.73      0.67       558
#
#     accuracy                           0.62      1028
#    macro avg       0.61      0.61      0.60      1028
# weighted avg       0.61      0.62      0.61      1028
#
# prestake profit-loss 10.04 x
# SpecPeriod:
# einsatz 73391 Total Return in SpecPeriod: 947 / Profit:  1806 / Loss:  842 / TransCosts:  16 / #CorrectPreds: 80 of 129
# CalcAccuracy 0.62 -- profit in %/bet: 1.29
# einsatz * 1+profit% ^ # wetten 5227.24
#
# Entire Period:
# einsatz 622390 TotReturn: 9668 / Profit:  20055 / Loss:  10013 / TransCosts:  373 / CalcAccuracy 0.62 / #CorrectPreds: 634 Of 1028
# einsatz/bet 605.4377837684613 TotReturn / bet 9.40466926070039 / TranCosts / bet  0.36284046692607 / CalcuAcc 0.62
# profit in %/bet: 1.55
# einsatz * 1+profit% ^ # wetten 7616704169.05
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.48      0.54       447
#          1.0       0.63      0.74      0.68       528
#
#     accuracy                           0.62       975
#    macro avg       0.62      0.61      0.61       975
# weighted avg       0.62      0.62      0.61       975
#
# prestake profit-loss 9.93 x
# SpecPeriod:
# einsatz 66816 Total Return in SpecPeriod: 957 / Profit:  1696 / Loss:  724 / TransCosts:  14 / #CorrectPreds: 74 of 116
# CalcAccuracy 0.64 -- profit in %/bet: 1.43
# einsatz * 1+profit% ^ # wetten 5205.22
#
# Entire Period:
# einsatz 595633 TotReturn: 9570 / Profit:  19423 / Loss:  9495 / TransCosts:  357 / CalcAccuracy 0.62 / #CorrectPreds: 605 Of 975
# einsatz/bet 610.9059640987058 TotReturn / bet 9.815384615384616 / TranCosts / bet  0.36615384615384616 / CalcuAcc 0.62
# profit in %/bet: 1.61
# einsatz * 1+profit% ^ # wetten 5613833433.86
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.48      0.54       417
#          1.0       0.63      0.75      0.69       497
#
#     accuracy                           0.63       914
#    macro avg       0.63      0.62      0.61       914
# weighted avg       0.63      0.63      0.62       914
#
# prestake profit-loss 10.30 x
# SpecPeriod:
# einsatz 61142 Total Return in SpecPeriod: 1019 / Profit:  1624 / Loss:  591 / TransCosts:  13 / #CorrectPreds: 67 of 105
# CalcAccuracy 0.64 -- profit in %/bet: 1.67
# einsatz * 1+profit% ^ # wetten 5671.72
#
# Entire Period:
# einsatz 564209 TotReturn: 9960 / Profit:  18625 / Loss:  8326 / TransCosts:  338 / CalcAccuracy 0.63 / #CorrectPreds: 575 Of 914
# einsatz/bet 617.2975268730386 TotReturn / bet 10.897155361050329 / TranCosts / bet  0.36980306345733044 / CalcuAcc 0.63
# profit in %/bet: 1.77
# einsatz * 1+profit% ^ # wetten 8833704710.64
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.49      0.55       385
#          1.0       0.65      0.77      0.70       470
#
#     accuracy                           0.64       855
#    macro avg       0.64      0.63      0.63       855
# weighted avg       0.64      0.64      0.64       855
#
# prestake profit-loss 10.37 x
# SpecPeriod:
# einsatz 56959 Total Return in SpecPeriod: 1034 / Profit:  1592 / Loss:  546 / TransCosts:  11 / #CorrectPreds: 64 of 97
# CalcAccuracy 0.66 -- profit in %/bet: 1.82
# einsatz * 1+profit% ^ # wetten 5726.38
#
# Entire Period:
# einsatz 533266 TotReturn: 10046 / Profit:  18013 / Loss:  7646 / TransCosts:  319 / CalcAccuracy 0.64 / #CorrectPreds: 551 Of 855
# einsatz/bet 623.7038146789303 TotReturn / bet 11.749707602339182 / TranCosts / bet  0.3730994152046784 / CalcuAcc 0.64
# profit in %/bet: 1.88
# einsatz * 1+profit% ^ # wetten 8513523364.72
#
#
#
#
# Run: 5
# [[212 258]
#  [162 396]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.45      0.50       470
#          1.0       0.61      0.71      0.65       558
#
#     accuracy                           0.59      1028
#    macro avg       0.59      0.58      0.58      1028
# weighted avg       0.59      0.59      0.58      1028
#
# prestake profit-loss 10.46 x
# SpecPeriod:
# einsatz 68175 Total Return in SpecPeriod: 720 / Profit:  1560 / Loss:  823 / TransCosts:  16 / #CorrectPreds: 69 of 117
# CalcAccuracy 0.59 -- profit in %/bet: 1.06
# einsatz * 1+profit% ^ # wetten 3418.37
#
# Entire Period:
# einsatz 631768 TotReturn: 10076 / Profit:  20229 / Loss:  9774 / TransCosts:  379 / CalcAccuracy 0.59 / #CorrectPreds: 608 Of 1028
# einsatz/bet 614.5609980844326 TotReturn / bet 9.801556420233464 / TranCosts / bet  0.36867704280155644 / CalcuAcc 0.59
# profit in %/bet: 1.59
# einsatz * 1+profit% ^ # wetten 11594861665.99
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.45      0.51       439
#          1.0       0.61      0.73      0.67       527
#
#     accuracy                           0.60       966
#    macro avg       0.60      0.59      0.59       966
# weighted avg       0.60      0.60      0.60       966
#
# prestake profit-loss 10.89 x
# SpecPeriod:
# einsatz 62103 Total Return in SpecPeriod: 724 / Profit:  1453 / Loss:  715 / TransCosts:  14 / #CorrectPreds: 64 of 105
# CalcAccuracy 0.61 -- profit in %/bet: 1.17
# einsatz * 1+profit% ^ # wetten 3377.04
#
# Entire Period:
# einsatz 600435 TotReturn: 10525 / Profit:  19719 / Loss:  8833 / TransCosts:  360 / CalcAccuracy 0.6 / #CorrectPreds: 583 Of 966
# einsatz/bet 621.5690525825703 TotReturn / bet 10.895445134575569 / TranCosts / bet  0.37267080745341613 / CalcuAcc 0.6
# profit in %/bet: 1.75
# einsatz * 1+profit% ^ # wetten 19506478170.34
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.45      0.51       410
#          1.0       0.63      0.75      0.68       504
#
#     accuracy                           0.61       914
#    macro avg       0.61      0.60      0.60       914
# weighted avg       0.61      0.61      0.61       914
#
# prestake profit-loss 10.89 x
# SpecPeriod:
# einsatz 54905 Total Return in SpecPeriod: 856 / Profit:  1433 / Loss:  566 / TransCosts:  10 / #CorrectPreds: 61 of 91
# CalcAccuracy 0.67 -- profit in %/bet: 1.56
# einsatz * 1+profit% ^ # wetten 4086.86
#
# Entire Period:
# einsatz 573667 TotReturn: 10549 / Profit:  19253 / Loss:  8359 / TransCosts:  344 / CalcAccuracy 0.61 / #CorrectPreds: 562 Of 914
# einsatz/bet 627.645206051837 TotReturn / bet 11.541575492341357 / TranCosts / bet  0.37636761487964987 / CalcuAcc 0.61
# profit in %/bet: 1.84
# einsatz * 1+profit% ^ # wetten 17100238200.14
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.45      0.51       386
#          1.0       0.63      0.75      0.69       484
#
#     accuracy                           0.62       870
#    macro avg       0.61      0.60      0.60       870
# weighted avg       0.62      0.62      0.61       870
#
# prestake profit-loss 10.58 x
# SpecPeriod:
# einsatz 53339 Total Return in SpecPeriod: 845 / Profit:  1397 / Loss:  542 / TransCosts:  10 / #CorrectPreds: 59 of 88
# CalcAccuracy 0.67 -- profit in %/bet: 1.58
# einsatz * 1+profit% ^ # wetten 3987.49
#
# Entire Period:
# einsatz 550547 TotReturn: 10247 / Profit:  18460 / Loss:  7882 / TransCosts:  330 / CalcAccuracy 0.62 / #CorrectPreds: 540 Of 870
# einsatz/bet 632.8130130573181 TotReturn / bet 11.77816091954023 / TranCosts / bet  0.3793103448275862 / CalcuAcc 0.62
# profit in %/bet: 1.86
# einsatz * 1+profit% ^ # wetten 9285160108.60
# Run: 6
# [[204 266]
#  [185 373]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.43      0.47       470
#          1.0       0.58      0.67      0.62       558
#
#     accuracy                           0.56      1028
#    macro avg       0.55      0.55      0.55      1028
# weighted avg       0.56      0.56      0.56      1028
#
# prestake profit-loss 9.83 x
# SpecPeriod:
# einsatz 85640 Total Return in SpecPeriod: 699 / Profit:  1871 / Loss:  1147 / TransCosts:  24 / #CorrectPreds: 73 of 146
# CalcAccuracy 0.50 -- profit in %/bet: 0.82
# einsatz * 1+profit% ^ # wetten 3276.65
#
# Entire Period:
# einsatz 632706 TotReturn: 9452 / Profit:  19788 / Loss:  9956 / TransCosts:  379 / CalcAccuracy 0.56 / #CorrectPreds: 577 Of 1028
# einsatz/bet 615.4727838985636 TotReturn / bet 9.194552529182879 / TranCosts / bet  0.36867704280155644 / CalcuAcc 0.56
# profit in %/bet: 1.49
# einsatz * 1+profit% ^ # wetten 4171215731.69
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.44      0.48       446
#          1.0       0.59      0.68      0.63       532
#
#     accuracy                           0.57       978
#    macro avg       0.56      0.56      0.56       978
# weighted avg       0.57      0.57      0.56       978
#
# prestake profit-loss 9.64 x
# SpecPeriod:
# einsatz 82110 Total Return in SpecPeriod: 776 / Profit:  1856 / Loss:  1057 / TransCosts:  23 / #CorrectPreds: 71 of 139
# CalcAccuracy 0.51 -- profit in %/bet: 0.95
# einsatz * 1+profit% ^ # wetten 3696.81
#
# Entire Period:
# einsatz 607460 TotReturn: 9279 / Profit:  18908 / Loss:  9264 / TransCosts:  364 / CalcAccuracy 0.57 / #CorrectPreds: 558 Of 978
# einsatz/bet 621.1257005876106 TotReturn / bet 9.487730061349692 / TranCosts / bet  0.3721881390593047 / CalcuAcc 0.57
# profit in %/bet: 1.53
# einsatz * 1+profit% ^ # wetten 2747101067.00
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.44      0.48       416
#          1.0       0.60      0.70      0.64       504
#
#     accuracy                           0.58       920
#    macro avg       0.57      0.57      0.56       920
# weighted avg       0.57      0.58      0.57       920
#
# prestake profit-loss 9.67 x
# SpecPeriod:
# einsatz 75419 Total Return in SpecPeriod: 803 / Profit:  1793 / Loss:  969 / TransCosts:  20 / #CorrectPreds: 67 of 126
# CalcAccuracy 0.53 -- profit in %/bet: 1.06
# einsatz * 1+profit% ^ # wetten 3797.91
#
# Entire Period:
# einsatz 577618 TotReturn: 9327 / Profit:  18351 / Loss:  8677 / TransCosts:  346 / CalcAccuracy 0.58 / #CorrectPreds: 533 Of 920
# einsatz/bet 627.84635689068 TotReturn / bet 10.138043478260869 / TranCosts / bet  0.3760869565217391 / CalcuAcc 0.58
# profit in %/bet: 1.61
# einsatz * 1+profit% ^ # wetten 2512734815.59
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.42      0.47       384
#          1.0       0.60      0.70      0.65       484
#
#     accuracy                           0.58       868
#    macro avg       0.56      0.56      0.56       868
# weighted avg       0.57      0.58      0.57       868
#
# prestake profit-loss 8.88 x
# SpecPeriod:
# einsatz 69633 Total Return in SpecPeriod: 871 / Profit:  1756 / Loss:  867 / TransCosts:  18 / #CorrectPreds: 63 of 115
# CalcAccuracy 0.55 -- profit in %/bet: 1.25
# einsatz * 1+profit% ^ # wetten 4176.75
#
# Entire Period:
# einsatz 550301 TotReturn: 8551 / Profit:  17191 / Loss:  8309 / TransCosts:  330 / CalcAccuracy 0.58 / #CorrectPreds: 500 Of 868
# einsatz/bet 633.9876846037066 TotReturn / bet 9.851382488479263 / TranCosts / bet  0.38018433179723504 / CalcuAcc 0.58
# profit in %/bet: 1.55
# einsatz * 1+profit% ^ # wetten 649479218.86
#
#
#
#
# Run: 7
# [[221 249]
#  [163 395]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.47      0.52       470
#          1.0       0.61      0.71      0.66       558
#
#     accuracy                           0.60      1028
#    macro avg       0.59      0.59      0.59      1028
# weighted avg       0.60      0.60      0.59      1028
#
# prestake profit-loss 9.93 x
# SpecPeriod:
# einsatz 88128 Total Return in SpecPeriod: 1126 / Profit:  2415 / Loss:  1263 / TransCosts:  25 / #CorrectPreds: 77 of 150
# CalcAccuracy 0.51 -- profit in %/bet: 1.28
# einsatz * 1+profit% ^ # wetten 6715.20
#
# Entire Period:
# einsatz 628716 TotReturn: 9550 / Profit:  19783 / Loss:  9855 / TransCosts:  377 / CalcAccuracy 0.6 / #CorrectPreds: 616 Of 1028
# einsatz/bet 611.5921468515652 TotReturn / bet 9.289883268482491 / TranCosts / bet  0.3667315175097276 / CalcuAcc 0.6
# profit in %/bet: 1.52
# einsatz * 1+profit% ^ # wetten 5376647532.76
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.47      0.52       447
#          1.0       0.62      0.73      0.67       530
#
#     accuracy                           0.61       977
#    macro avg       0.61      0.60      0.60       977
# weighted avg       0.61      0.61      0.60       977
#
# prestake profit-loss 10.48 x
# SpecPeriod:
# einsatz 83086 Total Return in SpecPeriod: 1225 / Profit:  2395 / Loss:  1146 / TransCosts:  22 / #CorrectPreds: 74 of 140
# CalcAccuracy 0.53 -- profit in %/bet: 1.47
# einsatz * 1+profit% ^ # wetten 7760.48
#
# Entire Period:
# einsatz 602964 TotReturn: 10117 / Profit:  19474 / Loss:  8995 / TransCosts:  361 / CalcAccuracy 0.61 / #CorrectPreds: 597 Of 977
# einsatz/bet 617.1590910531373 TotReturn / bet 10.355168884339816 / TranCosts / bet  0.3694984646878199 / CalcuAcc 0.61
# profit in %/bet: 1.68
# einsatz * 1+profit% ^ # wetten 11488408258.30
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.47      0.53       418
#          1.0       0.63      0.74      0.68       510
#
#     accuracy                           0.62       928
#    macro avg       0.62      0.61      0.60       928
# weighted avg       0.62      0.62      0.61       928
#
# prestake profit-loss 10.67 x
# SpecPeriod:
# einsatz 79495 Total Return in SpecPeriod: 1290 / Profit:  2373 / Loss:  1062 / TransCosts:  21 / #CorrectPreds: 73 of 133
# CalcAccuracy 0.55 -- profit in %/bet: 1.62
# einsatz * 1+profit% ^ # wetten 8507.22
#
# Entire Period:
# einsatz 577755 TotReturn: 10325 / Profit:  19095 / Loss:  8422 / TransCosts:  346 / CalcAccuracy 0.62 / #CorrectPreds: 575 Of 928
# einsatz/bet 622.5811905128191 TotReturn / bet 11.126077586206897 / TranCosts / bet  0.3728448275862069 / CalcuAcc 0.62
# profit in %/bet: 1.79
# einsatz * 1+profit% ^ # wetten 13766346408.64
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.47      0.53       391
#          1.0       0.64      0.76      0.69       484
#
#     accuracy                           0.63       875
#    macro avg       0.63      0.62      0.61       875
# weighted avg       0.63      0.63      0.62       875
#
# prestake profit-loss 10.94 x
# SpecPeriod:
# einsatz 72674 Total Return in SpecPeriod: 1428 / Profit:  2314 / Loss:  867 / TransCosts:  18 / #CorrectPreds: 68 of 120
# CalcAccuracy 0.57 -- profit in %/bet: 1.96
# einsatz * 1+profit% ^ # wetten 10329.78
#
# Entire Period:
# einsatz 549932 TotReturn: 10610 / Profit:  18643 / Loss:  7702 / TransCosts:  329 / CalcAccuracy 0.63 / #CorrectPreds: 552 Of 875
# einsatz/bet 628.4941232776778 TotReturn / bet 12.125714285714286 / TranCosts / bet  0.376 / CalcuAcc 0.63
# profit in %/bet: 1.93
# einsatz * 1+profit% ^ # wetten 18271179408.46
#
#
#
#
# Run: 8
# [[215 255]
#  [125 433]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.46      0.53       470
#          1.0       0.63      0.78      0.70       558
#
#     accuracy                           0.63      1028
#    macro avg       0.63      0.62      0.61      1028
# weighted avg       0.63      0.63      0.62      1028
#
# prestake profit-loss 13.22 x
# SpecPeriod:
# einsatz 86988 Total Return in SpecPeriod: 827 / Profit:  1926 / Loss:  1075 / TransCosts:  23 / #CorrectPreds: 80 of 146
# CalcAccuracy 0.55 -- profit in %/bet: 0.95
# einsatz * 1+profit% ^ # wetten 3980.72
#
# Entire Period:
# einsatz 629152 TotReturn: 12839 / Profit:  21473 / Loss:  8256 / TransCosts:  377 / CalcAccuracy 0.63 / #CorrectPreds: 648 Of 1028
# einsatz/bet 612.0157889529152 TotReturn / bet 12.48929961089494 / TranCosts / bet  0.3667315175097276 / CalcuAcc 0.63
# profit in %/bet: 2.04
# einsatz * 1+profit% ^ # wetten 1044741931709.32
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.45      0.53       451
#          1.0       0.63      0.80      0.70       528
#
#     accuracy                           0.64       979
#    macro avg       0.64      0.62      0.62       979
# weighted avg       0.64      0.64      0.62       979
#
# prestake profit-loss 13.60 x
# SpecPeriod:
# einsatz 82946 Total Return in SpecPeriod: 828 / Profit:  1858 / Loss:  1007 / TransCosts:  21 / #CorrectPreds: 76 of 138
# CalcAccuracy 0.55 -- profit in %/bet: 1.00
# einsatz * 1+profit% ^ # wetten 3938.24
#
# Entire Period:
# einsatz 604407 TotReturn: 13232 / Profit:  21101 / Loss:  7505 / TransCosts:  362 / CalcAccuracy 0.64 / #CorrectPreds: 623 Of 979
# einsatz/bet 617.3722397512233 TotReturn / bet 13.515832482124617 / TranCosts / bet  0.36976506639427986 / CalcuAcc 0.64
# profit in %/bet: 2.19
# einsatz * 1+profit% ^ # wetten 1613279131567.52
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.45      0.53       429
#          1.0       0.63      0.81      0.71       511
#
#     accuracy                           0.64       940
#    macro avg       0.65      0.63      0.62       940
# weighted avg       0.65      0.64      0.63       940
#
# prestake profit-loss 13.64 x
# SpecPeriod:
# einsatz 80884 Total Return in SpecPeriod: 779 / Profit:  1798 / Loss:  997 / TransCosts:  21 / #CorrectPreds: 73 of 134
# CalcAccuracy 0.54 -- profit in %/bet: 0.96
# einsatz * 1+profit% ^ # wetten 3612.41
#
# Entire Period:
# einsatz 584316 TotReturn: 13289 / Profit:  20473 / Loss:  6833 / TransCosts:  350 / CalcAccuracy 0.64 / #CorrectPreds: 604 Of 940
# einsatz/bet 621.6131996380084 TotReturn / bet 14.13723404255319 / TranCosts / bet  0.3723404255319149 / CalcuAcc 0.64
# profit in %/bet: 2.27
# einsatz * 1+profit% ^ # wetten 1515133710087.88
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.45      0.54       404
#          1.0       0.64      0.82      0.72       483
#
#     accuracy                           0.65       887
#    macro avg       0.66      0.63      0.63       887
# weighted avg       0.65      0.65      0.64       887
#
# prestake profit-loss 13.45 x
# SpecPeriod:
# einsatz 76151 Total Return in SpecPeriod: 701 / Profit:  1685 / Loss:  963 / TransCosts:  20 / #CorrectPreds: 68 of 125
# CalcAccuracy 0.54 -- profit in %/bet: 0.92
# einsatz * 1+profit% ^ # wetten 3143.70
#
# Entire Period:
# einsatz 556459 TotReturn: 13115 / Profit:  19776 / Loss:  6327 / TransCosts:  333 / CalcAccuracy 0.65 / #CorrectPreds: 576 Of 887
# einsatz/bet 627.3500345782555 TotReturn / bet 14.785794813979708 / TranCosts / bet  0.3754227733934611 / CalcuAcc 0.65
# profit in %/bet: 2.36
# einsatz * 1+profit% ^ # wetten 941365714922.92
#
#
#
#
# Run: 9
# [[210 260]
#  [164 394]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.45      0.50       470
#          1.0       0.60      0.71      0.65       558
#
#     accuracy                           0.59      1028
#    macro avg       0.58      0.58      0.57      1028
# weighted avg       0.58      0.59      0.58      1028
#
# prestake profit-loss 9.76 x
# SpecPeriod:
# einsatz 87370 Total Return in SpecPeriod: 1123 / Profit:  2379 / Loss:  1230 / TransCosts:  24 / #CorrectPreds: 76 of 147
# CalcAccuracy 0.52 -- profit in %/bet: 1.29
# einsatz * 1+profit% ^ # wetten 6536.42
#
# Entire Period:
# einsatz 631105 TotReturn: 9383 / Profit:  19693 / Loss:  9930 / TransCosts:  378 / CalcAccuracy 0.59 / #CorrectPreds: 604 Of 1028
# einsatz/bet 613.9156696724665 TotReturn / bet 9.127431906614786 / TranCosts / bet  0.36770428015564205 / CalcuAcc 0.59
# profit in %/bet: 1.49
# einsatz * 1+profit% ^ # wetten 3880035933.38
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.44      0.49       451
#          1.0       0.60      0.71      0.65       529
#
#     accuracy                           0.58       980
#    macro avg       0.58      0.57      0.57       980
# weighted avg       0.58      0.58      0.58       980
#
# prestake profit-loss 9.23 x
# SpecPeriod:
# einsatz 83319 Total Return in SpecPeriod: 1082 / Profit:  2304 / Loss:  1197 / TransCosts:  24 / #CorrectPreds: 69 of 139
# CalcAccuracy 0.50 -- profit in %/bet: 1.30
# einsatz * 1+profit% ^ # wetten 6010.17
#
# Entire Period:
# einsatz 606841 TotReturn: 8867 / Profit:  18901 / Loss:  9669 / TransCosts:  364 / CalcAccuracy 0.58 / #CorrectPreds: 573 Of 980
# einsatz/bet 619.2263425406544 TotReturn / bet 9.04795918367347 / TranCosts / bet  0.37142857142857144 / CalcuAcc 0.58
# profit in %/bet: 1.46
# einsatz * 1+profit% ^ # wetten 1492365787.49
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.44      0.50       433
#          1.0       0.60      0.72      0.65       497
#
#     accuracy                           0.59       930
#    macro avg       0.59      0.58      0.58       930
# weighted avg       0.59      0.59      0.58       930
#
# prestake profit-loss 9.19 x
# SpecPeriod:
# einsatz 78159 Total Return in SpecPeriod: 1246 / Profit:  2296 / Loss:  1027 / TransCosts:  22 / #CorrectPreds: 67 of 129
# CalcAccuracy 0.52 -- profit in %/bet: 1.59
# einsatz * 1+profit% ^ # wetten 7692.70
#
# Entire Period:
# einsatz 581062 TotReturn: 8837 / Profit:  18338 / Loss:  9152 / TransCosts:  348 / CalcAccuracy 0.59 / #CorrectPreds: 548 Of 930
# einsatz/bet 624.7983583454759 TotReturn / bet 9.502150537634408 / TranCosts / bet  0.3741935483870968 / CalcuAcc 0.59
# profit in %/bet: 1.52
# einsatz * 1+profit% ^ # wetten 1248295637.67
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.43      0.50       412
#          1.0       0.60      0.73      0.66       475
#
#     accuracy                           0.59       887
#    macro avg       0.59      0.58      0.58       887
# weighted avg       0.59      0.59      0.58       887
#
# prestake profit-loss 9.10 x
# SpecPeriod:
# einsatz 73418 Total Return in SpecPeriod: 1241 / Profit:  2209 / Loss:  947 / TransCosts:  20 / #CorrectPreds: 63 of 120
# CalcAccuracy 0.53 -- profit in %/bet: 1.69
# einsatz * 1+profit% ^ # wetten 7473.87
#
# Entire Period:
# einsatz 558468 TotReturn: 8760 / Profit:  17789 / Loss:  8693 / TransCosts:  335 / CalcAccuracy 0.59 / #CorrectPreds: 526 Of 887
# einsatz/bet 629.615555033274 TotReturn / bet 9.875986471251409 / TranCosts / bet  0.37767756482525366 / CalcuAcc 0.59
# profit in %/bet: 1.57
# einsatz * 1+profit% ^ # wetten 989801979.52
#
#
#
#
# Run: 10
# [[236 234]
#  [148 410]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.50      0.55       470
#          1.0       0.64      0.73      0.68       558
#
#     accuracy                           0.63      1028
#    macro avg       0.63      0.62      0.62      1028
# weighted avg       0.63      0.63      0.62      1028
#
# prestake profit-loss 11.55 x
# SpecPeriod:
# einsatz 70437 Total Return in SpecPeriod: 764 / Profit:  1730 / Loss:  949 / TransCosts:  17 / #CorrectPreds: 73 of 123
# CalcAccuracy 0.59 -- profit in %/bet: 1.08
# einsatz * 1+profit% ^ # wetten 3769.48
#
# Entire Period:
# einsatz 621811 TotReturn: 11179 / Profit:  19998 / Loss:  8445 / TransCosts:  373 / CalcAccuracy 0.63 / #CorrectPreds: 646 Of 1028
# einsatz/bet 604.8746077468569 TotReturn / bet 10.874513618677042 / TranCosts / bet  0.36284046692607 / CalcuAcc 0.63
# profit in %/bet: 1.80
# einsatz * 1+profit% ^ # wetten 90182826665.18
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.56       435
#          1.0       0.65      0.75      0.69       532
#
#     accuracy                           0.64       967
#    macro avg       0.63      0.63      0.63       967
# weighted avg       0.64      0.64      0.63       967
#
# prestake profit-loss 11.52 x
# SpecPeriod:
# einsatz 63876 Total Return in SpecPeriod: 624 / Profit:  1552 / Loss:  913 / TransCosts:  15 / #CorrectPreds: 65 of 110
# CalcAccuracy 0.59 -- profit in %/bet: 0.98
# einsatz * 1+profit% ^ # wetten 2913.52
#
# Entire Period:
# einsatz 591023 TotReturn: 11168 / Profit:  19404 / Loss:  7881 / TransCosts:  354 / CalcAccuracy 0.64 / #CorrectPreds: 617 Of 967
# einsatz/bet 611.1928445966421 TotReturn / bet 11.549120992761116 / TranCosts / bet  0.36608066184074456 / CalcuAcc 0.64
# profit in %/bet: 1.89
# einsatz * 1+profit% ^ # wetten 72708662453.81
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.56       402
#          1.0       0.66      0.76      0.70       503
#
#     accuracy                           0.64       905
#    macro avg       0.64      0.63      0.63       905
# weighted avg       0.64      0.64      0.64       905
#
# prestake profit-loss 11.50 x
# SpecPeriod:
# einsatz 57695 Total Return in SpecPeriod: 664 / Profit:  1474 / Loss:  796 / TransCosts:  13 / #CorrectPreds: 59 of 98
# CalcAccuracy 0.60 -- profit in %/bet: 1.15
# einsatz * 1+profit% ^ # wetten 3069.19
#
# Entire Period:
# einsatz 559107 TotReturn: 11160 / Profit:  18756 / Loss:  7260 / TransCosts:  335 / CalcAccuracy 0.64 / #CorrectPreds: 582 Of 905
# einsatz/bet 617.7987464247266 TotReturn / bet 12.331491712707182 / TranCosts / bet  0.3701657458563536 / CalcuAcc 0.64
# profit in %/bet: 2.00
# einsatz * 1+profit% ^ # wetten 58598245950.49
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.51      0.56       374
#          1.0       0.66      0.76      0.71       472
#
#     accuracy                           0.65       846
#    macro avg       0.65      0.64      0.64       846
# weighted avg       0.65      0.65      0.65       846
#
# prestake profit-loss 11.36 x
# SpecPeriod:
# einsatz 54017 Total Return in SpecPeriod: 681 / Profit:  1449 / Loss:  755 / TransCosts:  13 / #CorrectPreds: 54 of 91
# CalcAccuracy 0.59 -- profit in %/bet: 1.26
# einsatz * 1+profit% ^ # wetten 3126.96
#
# Entire Period:
# einsatz 528137 TotReturn: 11046 / Profit:  18013 / Loss:  6650 / TransCosts:  316 / CalcAccuracy 0.65 / #CorrectPreds: 551 Of 846
# einsatz/bet 624.2763523009071 TotReturn / bet 13.056737588652481 / TranCosts / bet  0.3735224586288416 / CalcuAcc 0.65
# profit in %/bet: 2.09
# einsatz * 1+profit% ^ # wetten 40289086639.23
#
#
#
#
# Run: 11
# [[230 240]
#  [156 402]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.49      0.54       470
#          1.0       0.63      0.72      0.67       558
#
#     accuracy                           0.61      1028
#    macro avg       0.61      0.60      0.60      1028
# weighted avg       0.61      0.61      0.61      1028
#
# prestake profit-loss 10.79 x
# SpecPeriod:
# einsatz 84855 Total Return in SpecPeriod: 646 / Profit:  1948 / Loss:  1281 / TransCosts:  21 / #CorrectPreds: 83 of 145
# CalcAccuracy 0.57 -- profit in %/bet: 0.76
# einsatz * 1+profit% ^ # wetten 3003.25
#
# Entire Period:
# einsatz 626288 TotReturn: 10414 / Profit:  20543 / Loss:  9752 / TransCosts:  375 / CalcAccuracy 0.61 / #CorrectPreds: 632 Of 1028
# einsatz/bet 609.2301224124066 TotReturn / bet 10.130350194552529 / TranCosts / bet  0.3647859922178988 / CalcuAcc 0.61
# profit in %/bet: 1.66
# einsatz * 1+profit% ^ # wetten 23049231702.30
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.49      0.54       441
#          1.0       0.64      0.73      0.68       537
#
#     accuracy                           0.62       978
#    macro avg       0.62      0.61      0.61       978
# weighted avg       0.62      0.62      0.62       978
#
# prestake profit-loss 10.80 x
# SpecPeriod:
# einsatz 79789 Total Return in SpecPeriod: 651 / Profit:  1868 / Loss:  1198 / TransCosts:  18 / #CorrectPreds: 80 of 135
# CalcAccuracy 0.59 -- profit in %/bet: 0.82
# einsatz * 1+profit% ^ # wetten 2995.12
#
# Entire Period:
# einsatz 601002 TotReturn: 10440 / Profit:  20110 / Loss:  9309 / TransCosts:  360 / CalcAccuracy 0.62 / #CorrectPreds: 610 Of 978
# einsatz/bet 614.5215621575387 TotReturn / bet 10.674846625766872 / TranCosts / bet  0.36809815950920244 / CalcuAcc 0.62
# profit in %/bet: 1.74
# einsatz * 1+profit% ^ # wetten 20644441605.71
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.49      0.54       415
#          1.0       0.64      0.74      0.69       514
#
#     accuracy                           0.63       929
#    macro avg       0.62      0.61      0.61       929
# weighted avg       0.62      0.63      0.62       929
#
# prestake profit-loss 10.91 x
# SpecPeriod:
# einsatz 75154 Total Return in SpecPeriod: 589 / Profit:  1744 / Loss:  1137 / TransCosts:  17 / #CorrectPreds: 75 of 126
# CalcAccuracy 0.60 -- profit in %/bet: 0.78
# einsatz * 1+profit% ^ # wetten 2674.18
#
# Entire Period:
# einsatz 575795 TotReturn: 10569 / Profit:  19676 / Loss:  8761 / TransCosts:  345 / CalcAccuracy 0.63 / #CorrectPreds: 583 Of 929
# einsatz/bet 619.8014007855685 TotReturn / bet 11.376749192680302 / TranCosts / bet  0.3713670613562971 / CalcuAcc 0.63
# profit in %/bet: 1.84
# einsatz * 1+profit% ^ # wetten 21804448233.15
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.50      0.56       391
#          1.0       0.65      0.76      0.70       485
#
#     accuracy                           0.64       876
#    macro avg       0.64      0.63      0.63       876
# weighted avg       0.64      0.64      0.64       876
#
# prestake profit-loss 10.63 x
# SpecPeriod:
# einsatz 69905 Total Return in SpecPeriod: 592 / Profit:  1663 / Loss:  1056 / TransCosts:  15 / #CorrectPreds: 73 of 116
# CalcAccuracy 0.63 -- profit in %/bet: 0.85
# einsatz * 1+profit% ^ # wetten 2659.72
#
# Entire Period:
# einsatz 547978 TotReturn: 10303 / Profit:  18891 / Loss:  8259 / TransCosts:  328 / CalcAccuracy 0.64 / #CorrectPreds: 564 Of 876
# einsatz/bet 625.5462166179202 TotReturn / bet 11.761415525114156 / TranCosts / bet  0.3744292237442922 / CalcuAcc 0.64
# profit in %/bet: 1.88
# einsatz * 1+profit% ^ # wetten 12206543087.87
#
#
#
#
# Run: 12
# [[229 241]
#  [148 410]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.49      0.54       470
#          1.0       0.63      0.73      0.68       558
#
#     accuracy                           0.62      1028
#    macro avg       0.62      0.61      0.61      1028
# weighted avg       0.62      0.62      0.62      1028
#
# prestake profit-loss 13.88 x
# SpecPeriod:
# einsatz 79130 Total Return in SpecPeriod: 1215 / Profit:  1936 / Loss:  705 / TransCosts:  15 / #CorrectPreds: 90 of 137
# CalcAccuracy 0.66 -- profit in %/bet: 1.54
# einsatz * 1+profit% ^ # wetten 8065.15
#
# Entire Period:
# einsatz 619985 TotReturn: 13509 / Profit:  23301 / Loss:  9419 / TransCosts:  371 / CalcAccuracy 0.62 / #CorrectPreds: 639 Of 1028
# einsatz/bet 603.0990996550853 TotReturn / bet 13.141050583657588 / TranCosts / bet  0.36089494163424124 / CalcuAcc 0.62
# profit in %/bet: 2.18
# einsatz * 1+profit% ^ # wetten 4201721875844.62
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.54       434
#          1.0       0.64      0.74      0.69       535
#
#     accuracy                           0.63       969
#    macro avg       0.62      0.61      0.61       969
# weighted avg       0.62      0.63      0.62       969
#
# prestake profit-loss 13.53 x
# SpecPeriod:
# einsatz 75074 Total Return in SpecPeriod: 1190 / Profit:  1895 / Loss:  690 / TransCosts:  14 / #CorrectPreds: 86 of 129
# CalcAccuracy 0.67 -- profit in %/bet: 1.59
# einsatz * 1+profit% ^ # wetten 7604.35
#
# Entire Period:
# einsatz 590197 TotReturn: 13179 / Profit:  22348 / Loss:  8814 / TransCosts:  354 / CalcAccuracy 0.63 / #CorrectPreds: 607 Of 969
# einsatz/bet 609.0789050198208 TotReturn / bet 13.60061919504644 / TranCosts / bet  0.3653250773993808 / CalcuAcc 0.63
# profit in %/bet: 2.23
# einsatz * 1+profit% ^ # wetten 1966548994235.77
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.49      0.55       411
#          1.0       0.64      0.76      0.70       501
#
#     accuracy                           0.64       912
#    macro avg       0.63      0.62      0.62       912
# weighted avg       0.64      0.64      0.63       912
#
# prestake profit-loss 13.46 x
# SpecPeriod:
# einsatz 67344 Total Return in SpecPeriod: 1114 / Profit:  1711 / Loss:  585 / TransCosts:  11 / #CorrectPreds: 80 of 114
# CalcAccuracy 0.70 -- profit in %/bet: 1.65
# einsatz * 1+profit% ^ # wetten 6490.56
#
# Entire Period:
# einsatz 560839 TotReturn: 13119 / Profit:  21486 / Loss:  8029 / TransCosts:  336 / CalcAccuracy 0.64 / #CorrectPreds: 581 Of 912
# einsatz/bet 614.9551239885875 TotReturn / bet 14.384868421052632 / TranCosts / bet  0.3684210526315789 / CalcuAcc 0.64
# profit in %/bet: 2.34
# einsatz * 1+profit% ^ # wetten 1439521964342.26
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.49      0.55       379
#          1.0       0.66      0.77      0.71       479
#
#     accuracy                           0.65       858
#    macro avg       0.64      0.63      0.63       858
# weighted avg       0.64      0.65      0.64       858
#
# prestake profit-loss 13.28 x
# SpecPeriod:
# einsatz 63672 Total Return in SpecPeriod: 1162 / Profit:  1701 / Loss:  529 / TransCosts:  10 / #CorrectPreds: 78 of 107
# CalcAccuracy 0.73 -- profit in %/bet: 1.82
# einsatz * 1+profit% ^ # wetten 6924.88
#
# Entire Period:
# einsatz 532502 TotReturn: 12963 / Profit:  20942 / Loss:  7659 / TransCosts:  319 / CalcAccuracy 0.65 / #CorrectPreds: 554 Of 858
# einsatz/bet 620.6325243093551 TotReturn / bet 15.108391608391608 / TranCosts / bet  0.3717948717948718 / CalcuAcc 0.65
# profit in %/bet: 2.43
# einsatz * 1+profit% ^ # wetten 916964266313.58
#
#
#
#
# Run: 13
# [[226 244]
#  [151 407]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.53       470
#          1.0       0.63      0.73      0.67       558
#
#     accuracy                           0.62      1028
#    macro avg       0.61      0.61      0.60      1028
# weighted avg       0.61      0.62      0.61      1028
#
# prestake profit-loss 10.71 x
# SpecPeriod:
# einsatz 92979 Total Return in SpecPeriod: 183 / Profit:  1921 / Loss:  1711 / TransCosts:  25 / #CorrectPreds: 84 of 159
# CalcAccuracy 0.53 -- profit in %/bet: 0.20
# einsatz * 1+profit% ^ # wetten 1367.02
#
# Entire Period:
# einsatz 619700 TotReturn: 10335 / Profit:  20381 / Loss:  9674 / TransCosts:  371 / CalcAccuracy 0.62 / #CorrectPreds: 633 Of 1028
# einsatz/bet 602.8214974868118 TotReturn / bet 10.053501945525293 / TranCosts / bet  0.36089494163424124 / CalcuAcc 0.62
# profit in %/bet: 1.67
# einsatz * 1+profit% ^ # wetten 24227201188.39
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.49      0.54       441
#          1.0       0.64      0.74      0.68       537
#
#     accuracy                           0.63       978
#    macro avg       0.62      0.61      0.61       978
# weighted avg       0.62      0.63      0.62       978
#
# prestake profit-loss 11.14 x
# SpecPeriod:
# einsatz 89941 Total Return in SpecPeriod: 211 / Profit:  1893 / Loss:  1657 / TransCosts:  25 / #CorrectPreds: 80 of 153
# CalcAccuracy 0.52 -- profit in %/bet: 0.23
# einsatz * 1+profit% ^ # wetten 1431.20
#
# Entire Period:
# einsatz 594457 TotReturn: 10784 / Profit:  20071 / Loss:  8929 / TransCosts:  356 / CalcAccuracy 0.63 / #CorrectPreds: 612 Of 978
# einsatz/bet 607.8294468530349 TotReturn / bet 11.026584867075664 / TranCosts / bet  0.36400817995910023 / CalcuAcc 0.63
# profit in %/bet: 1.81
# einsatz * 1+profit% ^ # wetten 43263186503.00
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.48      0.54       414
#          1.0       0.64      0.75      0.69       504
#
#     accuracy                           0.63       918
#    macro avg       0.63      0.62      0.61       918
# weighted avg       0.63      0.63      0.62       918
#
# prestake profit-loss 11.33 x
# SpecPeriod:
# einsatz 84787 Total Return in SpecPeriod: 272 / Profit:  1821 / Loss:  1524 / TransCosts:  23 / #CorrectPreds: 75 of 143
# CalcAccuracy 0.52 -- profit in %/bet: 0.32
# einsatz * 1+profit% ^ # wetten 1580.93
#
# Entire Period:
# einsatz 563536 TotReturn: 10991 / Profit:  19330 / Loss:  8000 / TransCosts:  338 / CalcAccuracy 0.63 / #CorrectPreds: 578 Of 918
# einsatz/bet 613.8744694017065 TotReturn / bet 11.972766884531591 / TranCosts / bet  0.3681917211328976 / CalcuAcc 0.63
# profit in %/bet: 1.95
# einsatz * 1+profit% ^ # wetten 50221316546.34
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.48      0.55       388
#          1.0       0.65      0.77      0.70       476
#
#     accuracy                           0.64       864
#    macro avg       0.64      0.63      0.63       864
# weighted avg       0.64      0.64      0.63       864
#
# prestake profit-loss 11.37 x
# SpecPeriod:
# einsatz 78502 Total Return in SpecPeriod: 385 / Profit:  1781 / Loss:  1374 / TransCosts:  20 / #CorrectPreds: 72 of 131
# ...
# profit in %/bet: 2.06
# einsatz * 1+profit% ^ # wetten 162979803616.24
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.54       397
#          1.0       0.63      0.74      0.68       478
#
#     accuracy                           0.62       875
#    macro avg       0.62      0.61      0.61       875
# weighted avg       0.62      0.62      0.61       875
#
# prestake profit-loss 11.75 x
# SpecPeriod:
# einsatz 62164 Total Return in SpecPeriod: 1030 / Profit:  1705 / Loss:  660 / TransCosts:  14 / #CorrectPreds: 63 of 103
# CalcAccuracy 0.61 -- profit in %/bet: 1.66
# einsatz * 1+profit% ^ # wetten 5433.69
#
# Entire Period:
# einsatz 549200 TotReturn: 11415 / Profit:  19295 / Loss:  7550 / TransCosts:  329 / CalcAccuracy 0.62 / #CorrectPreds: 543 Of 875
# einsatz/bet 627.6573505525573 TotReturn / bet 13.045714285714286 / TranCosts / bet  0.376 / CalcuAcc 0.62
# profit in %/bet: 2.08
# einsatz * 1+profit% ^ # wetten 65676414998.82
#
#
#
#
# Run: 96
# [[207 263]
#  [147 411]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.44      0.50       470
#          1.0       0.61      0.74      0.67       558
#
#     accuracy                           0.60      1028
#    macro avg       0.60      0.59      0.58      1028
# weighted avg       0.60      0.60      0.59      1028
#
# prestake profit-loss 10.71 x
# SpecPeriod:
# einsatz 70202 Total Return in SpecPeriod: 1631 / Profit:  2543 / Loss:  895 / TransCosts:  16 / #CorrectPreds: 72 of 122
# CalcAccuracy 0.59 -- profit in %/bet: 2.32
# einsatz * 1+profit% ^ # wetten 16477.20
#
# Entire Period:
# einsatz 625507 TotReturn: 10338 / Profit:  19976 / Loss:  9262 / TransCosts:  375 / CalcAccuracy 0.6 / #CorrectPreds: 618 Of 1028
# einsatz/bet 608.4704450015823 TotReturn / bet 10.056420233463035 / TranCosts / bet  0.3647859922178988 / CalcuAcc 0.6
# profit in %/bet: 1.65
# einsatz * 1+profit% ^ # wetten 20816781309.41
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.43      0.51       449
#          1.0       0.61      0.76      0.68       520
#
#     accuracy                           0.61       969
#    macro avg       0.61      0.60      0.59       969
# weighted avg       0.61      0.61      0.60       969
#
# prestake profit-loss 10.54 x
# SpecPeriod:
# einsatz 65645 Total Return in SpecPeriod: 1643 / Profit:  2420 / Loss:  761 / TransCosts:  15 / #CorrectPreds: 67 of 113
# CalcAccuracy 0.59 -- profit in %/bet: 2.50
# einsatz * 1+profit% ^ # wetten 16336.32
#
# Entire Period:
# einsatz 595698 TotReturn: 10182 / Profit:  19078 / Loss:  8539 / TransCosts:  357 / CalcAccuracy 0.61 / #CorrectPreds: 590 Of 969
# einsatz/bet 614.7554645222382 TotReturn / bet 10.507739938080496 / TranCosts / bet  0.3684210526315789 / CalcuAcc 0.61
# profit in %/bet: 1.71
# einsatz * 1+profit% ^ # wetten 13561242808.75
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.43      0.51       420
#          1.0       0.62      0.78      0.69       496
#
#     accuracy                           0.62       916
#    macro avg       0.62      0.60      0.60       916
# weighted avg       0.62      0.62      0.61       916
#
# prestake profit-loss 10.83 x
# SpecPeriod:
# einsatz 59465 Total Return in SpecPeriod: 1712 / Profit:  2317 / Loss:  591 / TransCosts:  13 / #CorrectPreds: 63 of 101
# CalcAccuracy 0.62 -- profit in %/bet: 2.88
# einsatz * 1+profit% ^ # wetten 17579.03
#
# Entire Period:
# einsatz 568388 TotReturn: 10487 / Profit:  18681 / Loss:  7852 / TransCosts:  341 / CalcAccuracy 0.62 / #CorrectPreds: 566 Of 916
# einsatz/bet 620.5109650004887 TotReturn / bet 11.448689956331878 / TranCosts / bet  0.3722707423580786 / CalcuAcc 0.62
# profit in %/bet: 1.85
# einsatz * 1+profit% ^ # wetten 18747441218.32
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.43      0.50       393
#          1.0       0.62      0.78      0.69       473
#
#     accuracy                           0.62       866
#    macro avg       0.62      0.60      0.60       866
# weighted avg       0.62      0.62      0.61       866
#
# prestake profit-loss 10.68 x
# SpecPeriod:
# einsatz 56844 Total Return in SpecPeriod: 1702 / Profit:  2290 / Loss:  575 / TransCosts:  12 / #CorrectPreds: 61 of 96
# CalcAccuracy 0.64 -- profit in %/bet: 2.99
# einsatz * 1+profit% ^ # wetten 16981.99
#
# Entire Period:
# einsatz 542135 TotReturn: 10356 / Profit:  18246 / Loss:  7565 / TransCosts:  325 / CalcAccuracy 0.62 / #CorrectPreds: 536 Of 866
# einsatz/bet 626.0220687268427 TotReturn / bet 11.958429561200925 / TranCosts / bet  0.37528868360277134 / CalcuAcc 0.62
# profit in %/bet: 1.91
# einsatz * 1+profit% ^ # wetten 13079171762.48
#
#
#
#
# Run: 97
# [[224 246]
#  [146 412]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.48      0.53       470
#          1.0       0.63      0.74      0.68       558
#
#     accuracy                           0.62      1028
#    macro avg       0.62      0.61      0.61      1028
# weighted avg       0.62      0.62      0.61      1028
#
# prestake profit-loss 11.00 x
# SpecPeriod:
# einsatz 85136 Total Return in SpecPeriod: 1534 / Profit:  2474 / Loss:  917 / TransCosts:  21 / #CorrectPreds: 81 of 143
# CalcAccuracy 0.57 -- profit in %/bet: 1.80
# einsatz * 1+profit% ^ # wetten 12854.01
#
# Entire Period:
# einsatz 626138 TotReturn: 10624 / Profit:  20801 / Loss:  9801 / TransCosts:  375 / CalcAccuracy 0.62 / #CorrectPreds: 636 Of 1028
# einsatz/bet 609.0841101168966 TotReturn / bet 10.334630350194553 / TranCosts / bet  0.3647859922178988 / CalcuAcc 0.62
# profit in %/bet: 1.70
# einsatz * 1+profit% ^ # wetten 32483966219.11
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.47      0.53       445
#          1.0       0.63      0.74      0.68       532
#
#     accuracy                           0.62       977
#    macro avg       0.62      0.61      0.61       977
# weighted avg       0.62      0.62      0.61       977
#
# prestake profit-loss 10.66 x
# SpecPeriod:
# einsatz 82100 Total Return in SpecPeriod: 1478 / Profit:  2368 / Loss:  868 / TransCosts:  20 / #CorrectPreds: 78 of 137
# CalcAccuracy 0.57 -- profit in %/bet: 1.80
# einsatz * 1+profit% ^ # wetten 11523.44
#
# Entire Period:
# einsatz 600398 TotReturn: 10294 / Profit:  19868 / Loss:  9213 / TransCosts:  360 / CalcAccuracy 0.62 / #CorrectPreds: 605 Of 977
# einsatz/bet 614.532519217974 TotReturn / bet 10.536335721596725 / TranCosts / bet  0.368474923234391 / CalcuAcc 0.62
# profit in %/bet: 1.71
# einsatz * 1+profit% ^ # wetten 16337358708.57
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.46      0.53       418
#          1.0       0.63      0.75      0.68       501
#
#     accuracy                           0.62       919
#    macro avg       0.62      0.61      0.60       919
# weighted avg       0.62      0.62      0.61       919
#
# prestake profit-loss 10.43 x
# SpecPeriod:
# einsatz 75406 Total Return in SpecPeriod: 1475 / Profit:  2247 / Loss:  752 / TransCosts:  18 / #CorrectPreds: 71 of 124
# CalcAccuracy 0.57 -- profit in %/bet: 1.96
# einsatz * 1+profit% ^ # wetten 11046.39
#
# Entire Period:
# einsatz 570572 TotReturn: 10086 / Profit:  19224 / Loss:  8795 / TransCosts:  342 / CalcAccuracy 0.62 / #CorrectPreds: 569 Of 919
# einsatz/bet 620.8624969339241 TotReturn / bet 10.974972796517955 / TranCosts / bet  0.3721436343852013 / CalcuAcc 0.62
# profit in %/bet: 1.77
# einsatz * 1+profit% ^ # wetten 9852446492.55
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.46      0.53       390
#          1.0       0.64      0.77      0.70       477
#
#     accuracy                           0.63       867
#    macro avg       0.63      0.62      0.62       867
# weighted avg       0.63      0.63      0.62       867
#
# prestake profit-loss 10.71 x
# SpecPeriod:
# einsatz 68577 Total Return in SpecPeriod: 1494 / Profit:  2189 / Loss:  678 / TransCosts:  16 / #CorrectPreds: 65 of 111
# CalcAccuracy 0.59 -- profit in %/bet: 2.18
# einsatz * 1+profit% ^ # wetten 10937.98
#
# Entire Period:
# einsatz 543248 TotReturn: 10381 / Profit:  18886 / Loss:  8178 / TransCosts:  325 / CalcAccuracy 0.63 / #CorrectPreds: 549 Of 867
# einsatz/bet 626.583634333385 TotReturn / bet 11.973471741637832 / TranCosts / bet  0.3748558246828143 / CalcuAcc 0.63
# profit in %/bet: 1.91
# einsatz * 1+profit% ^ # wetten 13407333579.24
#
#
#
#
# Run: 98
# [[246 224]
#  [161 397]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.52      0.56       470
#          1.0       0.64      0.71      0.67       558
#
#     accuracy                           0.63      1028
#    macro avg       0.62      0.62      0.62      1028
# weighted avg       0.62      0.63      0.62      1028
#
# prestake profit-loss 11.91 x
# SpecPeriod:
# einsatz 74937 Total Return in SpecPeriod: 761 / Profit:  1450 / Loss:  670 / TransCosts:  18 / #CorrectPreds: 75 of 128
# CalcAccuracy 0.59 -- profit in %/bet: 1.02
# einsatz * 1+profit% ^ # wetten 3644.79
#
# Entire Period:
# einsatz 621580 TotReturn: 11538 / Profit:  19561 / Loss:  7650 / TransCosts:  372 / CalcAccuracy 0.63 / #CorrectPreds: 643 Of 1028
# einsatz/bet 604.6500234795822 TotReturn / bet 11.22373540856031 / TranCosts / bet  0.36186770428015563 / CalcuAcc 0.63
# profit in %/bet: 1.86
# einsatz * 1+profit% ^ # wetten 162659542643.59
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.52      0.56       447
#          1.0       0.64      0.73      0.68       529
#
#     accuracy                           0.63       976
#    macro avg       0.63      0.62      0.62       976
# weighted avg       0.63      0.63      0.63       976
#
# prestake profit-loss 11.78 x
# SpecPeriod:
# einsatz 71899 Total Return in SpecPeriod: 716 / Profit:  1404 / Loss:  670 / TransCosts:  18 / #CorrectPreds: 69 of 122
# CalcAccuracy 0.57 -- profit in %/bet: 1.00
# einsatz * 1+profit% ^ # wetten 3349.84
#
# Entire Period:
# einsatz 595289 TotReturn: 11424 / Profit:  19000 / Loss:  7218 / TransCosts:  357 / CalcAccuracy 0.63 / #CorrectPreds: 616 Of 976
# einsatz/bet 609.9276938132272 TotReturn / bet 11.704918032786885 / TranCosts / bet  0.36577868852459017 / CalcuAcc 0.63
# profit in %/bet: 1.92
# einsatz * 1+profit% ^ # wetten 114105533290.98
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.52      0.56       413
#          1.0       0.65      0.73      0.69       496
#
#     accuracy                           0.63       909
#    macro avg       0.63      0.63      0.62       909
# weighted avg       0.63      0.63      0.63       909
#
# prestake profit-loss 11.36 x
# SpecPeriod:
# einsatz 64712 Total Return in SpecPeriod: 692 / Profit:  1305 / Loss:  596 / TransCosts:  16 / #CorrectPreds: 62 of 108
# CalcAccuracy 0.57 -- profit in %/bet: 1.07
# einsatz * 1+profit% ^ # wetten 3154.27
#
# Entire Period:
# einsatz 560822 TotReturn: 11019 / Profit:  18152 / Loss:  6796 / TransCosts:  336 / CalcAccuracy 0.63 / #CorrectPreds: 577 Of 909
# einsatz/bet 616.9663243543481 TotReturn / bet 12.122112211221122 / TranCosts / bet  0.3696369636963696 / CalcuAcc 0.63
# profit in %/bet: 1.96
# einsatz * 1+profit% ^ # wetten 48003240610.07
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.52      0.57       393
#          1.0       0.65      0.74      0.69       473
#
#     accuracy                           0.64       866
#    macro avg       0.64      0.63      0.63       866
# weighted avg       0.64      0.64      0.63       866
#
# prestake profit-loss 11.12 x
# SpecPeriod:
# einsatz 59987 Total Return in SpecPeriod: 568 / Profit:  1163 / Loss:  579 / TransCosts:  15 / #CorrectPreds: 56 of 99
# CalcAccuracy 0.57 -- profit in %/bet: 0.95
# einsatz * 1+profit% ^ # wetten 2542.07
#
# Entire Period:
# einsatz 538251 TotReturn: 10800 / Profit:  17661 / Loss:  6537 / TransCosts:  322 / CalcAccuracy 0.64 / #CorrectPreds: 554 Of 866
# einsatz/bet 621.5375614972039 TotReturn / bet 12.471131639722863 / TranCosts / bet  0.371824480369515 / CalcuAcc 0.64
# profit in %/bet: 2.01
# einsatz * 1+profit% ^ # wetten 29628078750.40
#
#
#
#
# Run: 99
# [[237 233]
#  [162 396]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.50      0.55       470
#          1.0       0.63      0.71      0.67       558
#
#     accuracy                           0.62      1028
#    macro avg       0.61      0.61      0.61      1028
# weighted avg       0.61      0.62      0.61      1028
#
# prestake profit-loss 11.15 x
# SpecPeriod:
# einsatz 63902 Total Return in SpecPeriod: 822 / Profit:  1628 / Loss:  789 / TransCosts:  16 / #CorrectPreds: 62 of 112
# CalcAccuracy 0.55 -- profit in %/bet: 1.29
# einsatz * 1+profit% ^ # wetten 4184.97
#
# Entire Period:
# einsatz 622861 TotReturn: 10781 / Profit:  19953 / Loss:  8798 / TransCosts:  373 / CalcAccuracy 0.62 / #CorrectPreds: 633 Of 1028
# einsatz/bet 605.8966472675195 TotReturn / bet 10.487354085603112 / TranCosts / bet  0.36284046692607 / CalcuAcc 0.62
# profit in %/bet: 1.73
# einsatz * 1+profit% ^ # wetten 45865602436.43
#
#
# Threshold of: 0.51
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.51      0.55       449
#          1.0       0.64      0.72      0.67       531
#
#     accuracy                           0.62       980
#    macro avg       0.62      0.61      0.61       980
# weighted avg       0.62      0.62      0.62       980
#
# prestake profit-loss 11.29 x
# SpecPeriod:
# einsatz 58858 Total Return in SpecPeriod: 840 / Profit:  1590 / Loss:  734 / TransCosts:  15 / #CorrectPreds: 57 of 102
# CalcAccuracy 0.56 -- profit in %/bet: 1.43
# einsatz * 1+profit% ^ # wetten 4243.57
#
# Entire Period:
# einsatz 598618 TotReturn: 10929 / Profit:  19581 / Loss:  8292 / TransCosts:  359 / CalcAccuracy 0.62 / #CorrectPreds: 611 Of 980
# einsatz/bet 610.8351682341487 TotReturn / bet 11.152040816326531 / TranCosts / bet  0.3663265306122449 / CalcuAcc 0.62
# profit in %/bet: 1.83
# einsatz * 1+profit% ^ # wetten 50150131574.61
#
#
# Threshold of: 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.52      0.57       415
#          1.0       0.64      0.74      0.69       490
#
#     accuracy                           0.64       905
#    macro avg       0.63      0.63      0.63       905
# weighted avg       0.64      0.64      0.63       905
#
# prestake profit-loss 11.72 x
# SpecPeriod:
# einsatz 52146 Total Return in SpecPeriod: 885 / Profit:  1525 / Loss:  627 / TransCosts:  12 / #CorrectPreds: 52 of 89
# CalcAccuracy 0.58 -- profit in %/bet: 1.70
# einsatz * 1+profit% ^ # wetten 4471.78
#
# Entire Period:
# einsatz 559998 TotReturn: 11381 / Profit:  19074 / Loss:  7357 / TransCosts:  335 / CalcAccuracy 0.64 / #CorrectPreds: 576 Of 905
# einsatz/bet 618.7823211609269 TotReturn / bet 12.575690607734806 / TranCosts / bet  0.3701657458563536 / CalcuAcc 0.64
# profit in %/bet: 2.03
# einsatz * 1+profit% ^ # wetten 80855170566.38
#
#
# Threshold of: 0.53
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.51      0.56       374
#          1.0       0.65      0.75      0.70       454
#
#     accuracy                           0.64       828
#    macro avg       0.64      0.63      0.63       828
# weighted avg       0.64      0.64      0.64       828
#
# prestake profit-loss 11.20 x
# SpecPeriod:
# einsatz 46363 Total Return in SpecPeriod: 796 / Profit:  1409 / Loss:  601 / TransCosts:  11 / #CorrectPreds: 45 of 78
# CalcAccuracy 0.58 -- profit in %/bet: 1.72
# einsatz * 1+profit% ^ # wetten 3772.72
#
# Entire Period:
# einsatz 519533 TotReturn: 10886 / Profit:  17900 / Loss:  6702 / TransCosts:  311 / CalcAccuracy 0.64 / #CorrectPreds: 532 Of 828
# einsatz/bet 627.4559665444094 TotReturn / bet 13.147342995169081 / TranCosts / bet  0.3756038647342995 / CalcuAcc 0.64
# profit in %/bet: 2.10
# einsatz * 1+profit% ^ # wetten 28635553459.88

# %%
import statistics

# %%
print( statistics.median(prestakepercentlist) )
print( statistics.median(profitpercent) )
print( statistics.median(zinseszins) )
print( statistics.median(current_profitpercent) )
print( statistics.median(current_zinseszins) )
# Out:
# 1087
# 1.6677411119939758
# 24227201188.38521
# 1.2218203609069151
# 5215.350425908278

# %%
print( statistics.median(prestakepercentlist51) )
print( statistics.median(profitpercent51) )
print( statistics.median(zinseszins51) )
print( statistics.median(current_profitpercent51) )
print( statistics.median(current_zinseszins51) )
# Out:
# 1073
# 1.7370987908525608
# 19506478170.340885
# 1.3015727332392233
# 5008.368214940873

# %%
print( statistics.median(prestakepercentlist52) )
print( statistics.median(profitpercent52) )
print( statistics.median(zinseszins52) )
print( statistics.median(current_profitpercent52) )
print( statistics.median(current_zinseszins52) )
# Out:
# 1082
# 1.8388693773259128
# 17808384325.1278
# 1.384981669359122
# 5204.5784072667

# %%
print( statistics.median(prestakepercentlist53) )
print( statistics.median(profitpercent53) )
print( statistics.median(zinseszins53) )
print( statistics.median(current_profitpercent53) )
print( statistics.median(current_zinseszins53) )
# Out:
# 1070
# 1.9159011863623496
# 13079171762.476011
# 1.5199061109202368
# 4980.330432605413

# %%
24227201188.38521
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-376-92d0ab52ec08> in <module>
# ----> 1 asas
#
# NameError: name 'asas' is not defined

# %%
currentpreds_all["Daily Return in USD"][(
    currentpreds_all['Class'] == currentpreds_all['y_pred'])].sort_values()

# %%
currentpreds_all["Daily Return in USD"][(
    currentpreds_all['Class'] != currentpreds_all['y_pred'])].sort_values()

# %%
current_profitpercent

# %%
profitpercent

# %%
df_y_test_withdailyreturns.sort_values("Daily Return in USD")

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]].abs().sum()

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]].abs().sum()

# %%
dfrights = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]]
dfwrongs = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]]

# %%
dfwrongs.abs().sort_values("percentage_daily_return")

# %%
dfrights.sort_values("percentage_daily_return")

# %%
dfwrongs["year"] = dfwrongs.index.year
dfwrongs.abs().groupby(['year']).agg(['sum', 'count'])

# %%
# HERE DIFF LOOK AT percentage_daily_return

dfrights["year"] = dfrights.index.year
dfrights.abs().groupby(['year']).agg(['sum', 'count']) - dfwrongs.abs().groupby(['year']).agg(['sum', 'count'])

# %%
predictors

# %% [markdown]
# # Bet on tomorrow

# %%
# Split Data into Training and Testing
#X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, stratify=target)

# Amount of Columns
n_nodes = predictors.shape[1]
print("Amount of Columns", n_nodes)

# Instantiation of MinMaxScaler
norm_scaler = MinMaxScaler()

# Training and Application of Feature Scaler on Training Data of Predictors
predictors_scaled = pd.DataFrame(norm_scaler.fit_transform(predictors))

# Instantiate Classifier Logistic Regression
lreg = LogisticRegression(max_iter=12000) 

# Train Classifier
lreg.fit(predictors_scaled, target)

# %% [markdown]
# # get x train data of today to predict tomorrow y

# %%
most_current_day = df_dataset1.tail(1)
dateofprediction = most_current_day.index
most_current_day

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
most_current_day_predictors = most_current_day.drop(['Class'], axis=1).values.astype(np.float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
most_current_day_predictors_scaled = norm_scaler.transform(most_current_day_predictors)
most_current_day_predictors_scaled

# %%
# Prediction of Probabilities
most_current_day_pred_prob = lreg.predict_proba(most_current_day_predictors_scaled)[:,1]
most_current_day_pred_prob[0]

# %%
# Prediction of Classes
most_current_day_pred = lreg.predict(most_current_day_predictors_scaled)
algoprediction = int( most_current_day_pred[0] )
algoprediction

# %%
dateofprediction[0]
