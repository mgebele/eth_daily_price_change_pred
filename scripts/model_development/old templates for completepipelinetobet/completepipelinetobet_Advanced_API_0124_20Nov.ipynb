# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Data-Import-via-Application-Programming-Interfaces" data-toc-modified-id="Data-Import-via-Application-Programming-Interfaces-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data Import via Application Programming Interfaces</a></span><ul class="toc-item"><li><span><a href="#Blockchain-Data-from-Glassnode" data-toc-modified-id="Blockchain-Data-from-Glassnode-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Blockchain Data from Glassnode</a></span><ul class="toc-item"><li><span><a href="#Market-Metrics-from-Glassnode" data-toc-modified-id="Market-Metrics-from-Glassnode-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Market Metrics from Glassnode</a></span></li><li><span><a href="#Mining-Metrics-from-Glassnode" data-toc-modified-id="Mining-Metrics-from-Glassnode-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Mining Metrics from Glassnode</a></span></li><li><span><a href="#Blocks-Metrics-from-Glassnode" data-toc-modified-id="Blocks-Metrics-from-Glassnode-1.1.1.3"><span class="toc-item-num">1.1.1.3&nbsp;&nbsp;</span>Blocks Metrics from Glassnode</a></span></li><li><span><a href="#Distribution-Metrics-from-Glassnode" data-toc-modified-id="Distribution-Metrics-from-Glassnode-1.1.1.4"><span class="toc-item-num">1.1.1.4&nbsp;&nbsp;</span>Distribution Metrics from Glassnode</a></span></li><li><span><a href="#Fee-Metrics-from-Glassnode" data-toc-modified-id="Fee-Metrics-from-Glassnode-1.1.1.5"><span class="toc-item-num">1.1.1.5&nbsp;&nbsp;</span>Fee Metrics from Glassnode</a></span></li><li><span><a href="#UTXO-Metrics-from-Glassnode" data-toc-modified-id="UTXO-Metrics-from-Glassnode-1.1.1.6"><span class="toc-item-num">1.1.1.6&nbsp;&nbsp;</span>UTXO Metrics from Glassnode</a></span></li><li><span><a href="#Supply-Metrics-from-Glassnode" data-toc-modified-id="Supply-Metrics-from-Glassnode-1.1.1.7"><span class="toc-item-num">1.1.1.7&nbsp;&nbsp;</span>Supply Metrics from Glassnode</a></span></li><li><span><a href="#Transaction-Metrics-from-Glassnode" data-toc-modified-id="Transaction-Metrics-from-Glassnode-1.1.1.8"><span class="toc-item-num">1.1.1.8&nbsp;&nbsp;</span>Transaction Metrics from Glassnode</a></span></li><li><span><a href="#Exchange-Metrics-from-Glassnode---1-Month-Lag" data-toc-modified-id="Exchange-Metrics-from-Glassnode---1-Month-Lag-1.1.1.9"><span class="toc-item-num">1.1.1.9&nbsp;&nbsp;</span>Exchange Metrics from Glassnode - 1 Month Lag</a></span></li><li><span><a href="#Indicator-I-Metrics-from-Glassnode" data-toc-modified-id="Indicator-I-Metrics-from-Glassnode-1.1.1.10"><span class="toc-item-num">1.1.1.10&nbsp;&nbsp;</span>Indicator-I Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-2-Metrics-from-Glassnode" data-toc-modified-id="Indicator-2-Metrics-from-Glassnode-1.1.1.11"><span class="toc-item-num">1.1.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-3-Metrics-from-Glassnode" data-toc-modified-id="Indicator-3-Metrics-from-Glassnode-1.1.1.12"><span class="toc-item-num">1.1.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics from Glassnode</a></span></li><li><span><a href="#Addresses-Metrics-from-Glassnode" data-toc-modified-id="Addresses-Metrics-from-Glassnode-1.1.1.13"><span class="toc-item-num">1.1.1.13&nbsp;&nbsp;</span>Addresses Metrics from Glassnode</a></span></li><li><span><a href="#Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020-1.1.1.14"><span class="toc-item-num">1.1.1.14&nbsp;&nbsp;</span>Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Futures-Features" data-toc-modified-id="List-of-Futures-Features-1.1.1.14.1"><span class="toc-item-num">1.1.1.14.1&nbsp;&nbsp;</span>List of Futures Features</a></span></li><li><span><a href="#Data-Frame-of-Future-features" data-toc-modified-id="Data-Frame-of-Future-features-1.1.1.14.2"><span class="toc-item-num">1.1.1.14.2&nbsp;&nbsp;</span>Data Frame of Future features</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#File-Import-and-Data-Tidying" data-toc-modified-id="File-Import-and-Data-Tidying-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>File Import and Data Tidying</a></span><ul class="toc-item"><li><span><a href="#Import-Blockchain-CSV-Files" data-toc-modified-id="Import-Blockchain-CSV-Files-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Import Blockchain CSV-Files</a></span><ul class="toc-item"><li><span><a href="#Market-Metric-CSV-Files" data-toc-modified-id="Market-Metric-CSV-Files-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>Market Metric CSV-Files</a></span></li><li><span><a href="#Mining-Metric-CSV-Files" data-toc-modified-id="Mining-Metric-CSV-Files-1.2.1.2"><span class="toc-item-num">1.2.1.2&nbsp;&nbsp;</span>Mining Metric CSV-Files</a></span></li><li><span><a href="#Blocks-Metric-CSV-Files" data-toc-modified-id="Blocks-Metric-CSV-Files-1.2.1.3"><span class="toc-item-num">1.2.1.3&nbsp;&nbsp;</span>Blocks Metric CSV-Files</a></span></li><li><span><a href="#Distribution-Metric-CSV-Files" data-toc-modified-id="Distribution-Metric-CSV-Files-1.2.1.4"><span class="toc-item-num">1.2.1.4&nbsp;&nbsp;</span>Distribution Metric CSV-Files</a></span></li><li><span><a href="#Fee-Metric-CSV-Files" data-toc-modified-id="Fee-Metric-CSV-Files-1.2.1.5"><span class="toc-item-num">1.2.1.5&nbsp;&nbsp;</span>Fee Metric CSV-Files</a></span></li><li><span><a href="#UTXO-Metric-CSV-Files" data-toc-modified-id="UTXO-Metric-CSV-Files-1.2.1.6"><span class="toc-item-num">1.2.1.6&nbsp;&nbsp;</span>UTXO Metric CSV-Files</a></span></li><li><span><a href="#Supply-Metric-CSV-Files" data-toc-modified-id="Supply-Metric-CSV-Files-1.2.1.7"><span class="toc-item-num">1.2.1.7&nbsp;&nbsp;</span>Supply Metric CSV-Files</a></span></li><li><span><a href="#Transaction-Metric-CSV-Files" data-toc-modified-id="Transaction-Metric-CSV-Files-1.2.1.8"><span class="toc-item-num">1.2.1.8&nbsp;&nbsp;</span>Transaction Metric CSV-Files</a></span></li><li><span><a href="#Exchange-Metrics-CSV-Files" data-toc-modified-id="Exchange-Metrics-CSV-Files-1.2.1.9"><span class="toc-item-num">1.2.1.9&nbsp;&nbsp;</span>Exchange Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-1-Metric-CSV-Files" data-toc-modified-id="Indicator-1-Metric-CSV-Files-1.2.1.10"><span class="toc-item-num">1.2.1.10&nbsp;&nbsp;</span>Indicator-1 Metric CSV-Files</a></span></li><li><span><a href="#Indicator-2-Metrics-CSV-Files" data-toc-modified-id="Indicator-2-Metrics-CSV-Files-1.2.1.11"><span class="toc-item-num">1.2.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-3-Metrics-CSV-Files" data-toc-modified-id="Indicator-3-Metrics-CSV-Files-1.2.1.12"><span class="toc-item-num">1.2.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics CSV-Files</a></span></li><li><span><a href="#Addresses-Metric-CSV-Files" data-toc-modified-id="Addresses-Metric-CSV-Files-1.2.1.13"><span class="toc-item-num">1.2.1.13&nbsp;&nbsp;</span>Addresses Metric CSV-Files</a></span></li><li><span><a href="#Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020-1.2.1.14"><span class="toc-item-num">1.2.1.14&nbsp;&nbsp;</span>Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Future-Features" data-toc-modified-id="List-of-Future-Features-1.2.1.14.1"><span class="toc-item-num">1.2.1.14.1&nbsp;&nbsp;</span>List of Future Features</a></span></li><li><span><a href="#Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension" data-toc-modified-id="Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension-1.2.1.14.2"><span class="toc-item-num">1.2.1.14.2&nbsp;&nbsp;</span>Counter to Differentiate between Data Frame Setup and Data Frame Extension</a></span></li><li><span><a href="#For-Loop-through-all-Features-in-the-List" data-toc-modified-id="For-Loop-through-all-Features-in-the-List-1.2.1.14.3"><span class="toc-item-num">1.2.1.14.3&nbsp;&nbsp;</span>For Loop through all Features in the List</a></span></li><li><span><a href="#Store-Data-Frame-Copy-in-Market-Data-Frame" data-toc-modified-id="Store-Data-Frame-Copy-in-Market-Data-Frame-1.2.1.14.4"><span class="toc-item-num">1.2.1.14.4&nbsp;&nbsp;</span>Store Data Frame Copy in Market Data Frame</a></span></li><li><span><a href="#Delete-Original-Data-Frame" data-toc-modified-id="Delete-Original-Data-Frame-1.2.1.14.5"><span class="toc-item-num">1.2.1.14.5&nbsp;&nbsp;</span>Delete Original Data Frame</a></span></li><li><span><a href="#Change-Data-Type-of-Columns-to-Float" data-toc-modified-id="Change-Data-Type-of-Columns-to-Float-1.2.1.14.6"><span class="toc-item-num">1.2.1.14.6&nbsp;&nbsp;</span>Change Data Type of Columns to Float</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Target-Variables" data-toc-modified-id="Target-Variables-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Target Variables</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Volatility" data-toc-modified-id="Volatility-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Volatility</a></span></li><li><span><a href="#Log-Price" data-toc-modified-id="Log-Price-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Log Price</a></span></li></ul></li></ul></li><li><span><a href="#Data-Sets" data-toc-modified-id="Data-Sets-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I.---Blockchain-Metrics-Only" data-toc-modified-id="Data-Set-I.---Blockchain-Metrics-Only-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data Set I. - Blockchain Metrics Only</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-Variations" data-toc-modified-id="Classification-Models---Data-Set-Variations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Classification Models - Data Set Variations</a></span></li><li><span><a href="#Import-Data-Sets" data-toc-modified-id="Import-Data-Sets-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Data Set I.</a></span></li><li><span><a href="#Prediction-Shift" data-toc-modified-id="Prediction-Shift-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Prediction Shift</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Data Set I.</a></span></li></ul></li></ul></li><li><span><a href="#Classification-Setup" data-toc-modified-id="Classification-Setup-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Classification Setup</a></span><ul class="toc-item"><li><span><a href="#Create-Data-Set-Copies-for-Trading-Strategy" data-toc-modified-id="Create-Data-Set-Copies-for-Trading-Strategy-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Create Data Set Copies for Trading Strategy</a></span></li><li><span><a href="#Categorization---Data-Set-I." data-toc-modified-id="Categorization---Data-Set-I.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Categorization - Data Set I.</a></span></li></ul></li><li><span><a href="#Model-Preparation---Data-Set-I." data-toc-modified-id="Model-Preparation---Data-Set-I.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model Preparation - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split---Data-Set-I." data-toc-modified-id="Train-Test-Split---Data-Set-I.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Train Test Split - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Check-of-Class-Balance" data-toc-modified-id="Check-of-Class-Balance-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Check of Class Balance</a></span></li></ul></li><li><span><a href="#Feature-Scaling---Data-Set-I." data-toc-modified-id="Feature-Scaling---Data-Set-I.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Feature Scaling - Data Set I.</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-I." data-toc-modified-id="Classification-Models---Data-Set-I.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Classification Models - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression---Data-Set-I." data-toc-modified-id="Logistic-Regression---Data-Set-I.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Logistic Regression - Data Set I.</a></span></li><li><span><a href="#Random-Forest-Classifier---Data-Set-I." data-toc-modified-id="Random-Forest-Classifier---Data-Set-I.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Random Forest Classifier - Data Set I.</a></span></li></ul></li><li><span><a href="#Trading-Strategy---Data-Set-I" data-toc-modified-id="Trading-Strategy---Data-Set-I-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Trading Strategy - Data Set I</a></span><ul class="toc-item"><li><span><a href="#Trading-Strategy-in-Combination-with-Logistic-Regression" data-toc-modified-id="Trading-Strategy-in-Combination-with-Logistic-Regression-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Trading Strategy in Combination with Logistic Regression</a></span></li></ul></li><li><span><a href="#Bet-on-tomorrow" data-toc-modified-id="Bet-on-tomorrow-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Bet on tomorrow</a></span></li><li><span><a href="#get-x-train-data-of-today-to-predict-tomorrow-y" data-toc-modified-id="get-x-train-data-of-today-to-predict-tomorrow-y-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>get x train data of today to predict tomorrow y</a></span></li><li><span><a href="#Store-DF-of-the-one-prediction-in-database" data-toc-modified-id="Store-DF-of-the-one-prediction-in-database-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Store DF of the one prediction in database</a></span></li></ul></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Import via Application Programming Interfaces

# %%
# Import of Modules and Packages
import os
import requests
import json
import datetime
import yfinance as yf
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pytrends.request import TrendReq
from pytrends import dailydata

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %%
# Glassnode API Key
API_Key =''

# %%
os.getcwd()
# Out:
# 'C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010'

# %%
os.chdir('C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010\\Glassnode')

# %% [markdown]
# ### Blockchain Data from Glassnode

# %%
# Import Function for a Single Feature Variable from Glassnode
def import_glassnode (url, feature_name):
    data = requests.get(url).json()
    df = pd.json_normalize(data)
    
    # Rename columns
    df.columns = ['Date', feature_name]
   
    # Convert Object to Datetime Object
    df.Date = pd.to_datetime(df.Date, unit='s')
    df.Date = df.Date.map(lambda x: x.strftime('%Y-%m-%d'))
    
    # Set Date Column as Index
    df.set_index('Date', inplace=True)
    
    # Drop Missing Values
    df = df.dropna()
    
    # Change Data Type to Float
    df = df.astype(float)
    
    # Creation of CSV-File, Part of Feature Name as CSV File Name 
    df.to_csv("{}.csv".format(feature_name.rsplit('/')[-1]), decimal=',')
    
    # Plot of DataFrame
    #df.plot(figsize=(4.5, 1.75))
    #plt.xticks(rotation=45)
    return df

# %%
# Import Function for Several Feature Variables from Glassnode
def import_glassnode_many(feature_list):
    # Counter to Differentiate between Data Frame Setup and Data Frame Join
    counter=0
    
    # For Loop through all Features in the List
    for feature in feature_list:
        
        # URL
        url = 'https://api.glassnode.com/v1/metrics/{}?a=btc&f=json&api_key={}'.format(feature, API_Key)
        
        # Execute Import Function for a Single Feature Variable
        df=import_glassnode(url, feature)
        
        # Display Data Frame Tail
        print(df.tail())
        
        # Condition - Data Frame Set up or Data Frame Join
        if counter > 0:
            
            # Data Frame Join
            df_new = df_new.join(df, how='inner')   
        
        else:
            
            # Data Frame Setup
            df_new = df
        
        # Increase Counter
        counter +=1
    
    return df_new

# %% [markdown]
# #### Market Metrics from Glassnode

# %%
# List of Market Features
market_feature_list = ['market/price_usd_close', 'market/price_drawdown_relative', 'market/price_realized_usd', 'market/mvrv']

# %%
# Data Frame of Market Features
df_market = import_glassnode_many(market_feature_list)
# Out:
#             market/price_usd_close
# Date
# 2020-11-16                16709.61
# 2020-11-17                17667.38
# 2020-11-18                17812.23
# 2020-11-19                17797.55
# 2020-11-20                17887.50
#             market/price_drawdown_relative
# Date
# 2020-11-15                           -0.19
# 2020-11-16                           -0.16
# 2020-11-17                           -0.11
# 2020-11-18                           -0.10
# 2020-11-19                           -0.10
#             market/price_realized_usd
# Date
# 2020-11-15                    6910.67
# 2020-11-16                    6926.41
# 2020-11-17                    6962.39
# 2020-11-18                    7037.45
# 2020-11-19                    7058.99
#             market/mvrv
# Date
# 2020-11-15         2.31
# 2020-11-16         2.36
# 2020-11-17         2.45
# 2020-11-18         2.54
# 2020-11-19         2.52

# %% [markdown]
# #### Mining Metrics from Glassnode

# %%
# List of Mining Features
mining_feature_list = ['mining/difficulty_latest', 'mining/hash_rate_mean', 'mining/revenue_sum', 'mining/marketcap_thermocap_ratio']

# %%
# Data Frame of Mining Features
df_mining = import_glassnode_many(mining_feature_list)
# Out:
#              mining/difficulty_latest
# Date
# 2020-11-15 72102964397116403744768.00
# 2020-11-16 75577685065077505392640.00
# 2020-11-17 75577685065077505392640.00
# 2020-11-18 75577685065077505392640.00
# 2020-11-19 75577685065077505392640.00
#               mining/hash_rate_mean
# Date
# 2020-11-15 124875241422092992512.00
# 2020-11-16 136158304329831006208.00
# 2020-11-17 136840305323567005696.00
# 2020-11-18 146411297553796005888.00
# 2020-11-19 119466801130333995008.00
#             mining/revenue_sum
# Date
# 2020-11-14              946.66
# 2020-11-15              979.93
# 2020-11-16             1083.46
# 2020-11-17             1071.79
# 2020-11-18             1147.11
#             mining/marketcap_thermocap_ratio
# Date
# 2020-11-15                              0.00
# 2020-11-16                              0.00
# 2020-11-17                              0.00
# 2020-11-18                              0.00
# 2020-11-19                              0.00

# %% [markdown]
# #### Blocks Metrics from Glassnode

# %%
# List of Blockchain Features
blockchain_feature_list = ['blockchain/block_count', 'blockchain/block_interval_mean', 'blockchain/block_size_sum']

# %%
# Data Frame of Blockchain Features
df_blockchainfeatures = import_glassnode_many(blockchain_feature_list)
# Out:
#             blockchain/block_count
# Date
# 2020-11-15                  150.00
# 2020-11-16                  160.00
# 2020-11-17                  157.00
# 2020-11-18                  169.00
# 2020-11-19                  136.00
#             blockchain/block_interval_mean
# Date
# 2020-11-15                          577.40
# 2020-11-16                          536.43
# 2020-11-17                          552.31
# 2020-11-18                          516.20
# 2020-11-19                          632.62
#             blockchain/block_size_sum
# Date
# 2020-11-15               180783978.00
# 2020-11-16               193429011.00
# 2020-11-17               201346288.00
# 2020-11-18               213284264.00
# 2020-11-19               180810954.00

# %% [markdown]
# #### Distribution Metrics from Glassnode

# %%
# List of Distribution Features
distribution_feature_list = ['distribution/balance_1pct_holders', 'distribution/gini', 'distribution/herfindahl']

# %%
# Data Frame of Distribution Features
df_distribution = import_glassnode_many(distribution_feature_list)
# Out:
#             distribution/balance_1pct_holders
# Date
# 2020-11-14                               0.89
# 2020-11-15                               0.89
# 2020-11-16                               0.89
# 2020-11-17                               0.89
# 2020-11-18                               0.89
#             distribution/gini
# Date
# 2020-11-14               0.99
# 2020-11-15               0.99
# 2020-11-16               0.99
# 2020-11-17               0.99
# 2020-11-18               0.99
#             distribution/herfindahl
# Date
# 2020-11-14                     0.00
# 2020-11-15                     0.00
# 2020-11-16                     0.00
# 2020-11-17                     0.00
# 2020-11-18                     0.00

# %% [markdown]
# #### Fee Metrics from Glassnode

# %%
# List of Fee Features
fees_feature_list = ['fees/volume_sum', 'fees/volume_mean', 'fees/fee_ratio_multiple']

# %%
# Data Frame of Fee Features
df_fees = import_glassnode_many(fees_feature_list)
# Out:
#             fees/volume_sum
# Date
# 2020-11-15            42.43
# 2020-11-16            83.46
# 2020-11-17            90.54
# 2020-11-18            97.64
# 2020-11-19            94.13
#             fees/volume_mean
# Date
# 2020-11-15              0.00
# 2020-11-16              0.00
# 2020-11-17              0.00
# 2020-11-18              0.00
# 2020-11-19              0.00
#             fees/fee_ratio_multiple
# Date
# 2020-11-15                    23.09
# 2020-11-16                    12.98
# 2020-11-17                    11.84
# 2020-11-18                    11.82
# 2020-11-19                    10.03

# %% [markdown]
# #### UTXO Metrics from Glassnode

# %%
# List of UTXO Features
utxo_feature_list = ['blockchain/utxo_created_count', 'blockchain/utxo_spent_count', 'blockchain/utxo_created_value_sum', 'blockchain/utxo_spent_value_sum', 'blockchain/utxo_profit_relative', 'blockchain/utxo_profit_count', 'blockchain/utxo_loss_count']

# %%
# Data Frame of UTXO Features
df_utxo = import_glassnode_many(utxo_feature_list)
# Out:
#             blockchain/utxo_created_count
# Date
# 2020-11-15                      720717.00
# 2020-11-16                      869288.00
# 2020-11-17                      974192.00
# 2020-11-18                     1017548.00
# 2020-11-19                      895148.00
#             blockchain/utxo_spent_count
# Date
# 2020-11-15                    856807.00
# 2020-11-16                    919942.00
# 2020-11-17                    952316.00
# 2020-11-18                   1015256.00
# 2020-11-19                    847262.00
#             blockchain/utxo_created_value_sum
# Date
# 2020-11-15                         1598945.68
# 2020-11-16                         3618303.62
# 2020-11-17                         3030811.52
# 2020-11-18                         2930159.47
# 2020-11-19                         2358224.03
#             blockchain/utxo_spent_value_sum
# Date
# 2020-11-15                       1598008.18
# 2020-11-16                       3617303.62
# 2020-11-17                       3029830.27
# 2020-11-18                       2929103.22
# 2020-11-19                       2357374.03
#             blockchain/utxo_profit_relative
# Date
# 2020-11-15                             0.99
# 2020-11-16                             0.99
# 2020-11-17                             1.00
# 2020-11-18                             1.00
# 2020-11-19                             0.99
#             blockchain/utxo_profit_count
# Date
# 2020-11-15                  113245855.00
# 2020-11-16                  114208074.00
# 2020-11-17                  114563460.00
# 2020-11-18                  114328125.00
# 2020-11-19                  114261729.00
#             blockchain/utxo_loss_count
# Date
# 2020-11-15                  1631223.00
# 2020-11-16                   618350.00
# 2020-11-17                   284840.00
# 2020-11-18                   511448.00
# 2020-11-19                   640779.00

# %% [markdown]
# #### Supply Metrics from Glassnode

# %%
# List of Supply Features
supply_feature_list = ['supply/current','supply/profit_relative', 'supply/profit_sum', 'supply/loss_sum', 'supply/active_more_1y_percent', 'supply/active_more_2y_percent', 'supply/active_more_3y_percent', 'supply/active_more_5y_percent', 'supply/active_24h', 'supply/active_1d_1w', 'supply/active_1w_1m', 'supply/active_1m_3m', 'supply/active_3m_6m', 'supply/active_6m_12m', 'supply/active_1y_2y', 'supply/active_2y_3y', 'supply/active_3y_5y', 'supply/active_5y_7y', 'supply/active_7y_10y', 'supply/active_more_10y', 'supply/issued', 'supply/inflation_rate']

# %%
# Data Frame of Supply Features
df_supply = import_glassnode_many(supply_feature_list)
# Out:
#             supply/current
# Date
# 2020-11-15     18544412.50
# 2020-11-16     18545412.50
# 2020-11-17     18546393.75
# 2020-11-18     18547450.00
# 2020-11-19     18548300.00
#             supply/profit_relative
# Date
# 2020-11-15                    0.97
# 2020-11-16                    0.99
# 2020-11-17                    0.99
# 2020-11-18                    0.99
# 2020-11-19                    0.99
#             supply/profit_sum
# Date
# 2020-11-15        17945673.96
# 2020-11-16        18346861.57
# 2020-11-17        18411620.91
# 2020-11-18        18316325.54
# 2020-11-19        18279213.14
#             supply/loss_sum
# Date
# 2020-11-15        585768.13
# 2020-11-16        185580.53
# 2020-11-17        121802.43
# 2020-11-18        197306.40
# 2020-11-19        232499.62
#             supply/active_more_1y_percent
# Date
# 2020-11-15                           0.62
# 2020-11-16                           0.62
# 2020-11-17                           0.62
# 2020-11-18                           0.61
# 2020-11-19                           0.61
#             supply/active_more_2y_percent
# Date
# 2020-11-15                           0.44
# 2020-11-16                           0.44
# 2020-11-17                           0.44
# 2020-11-18                           0.44
# 2020-11-19                           0.44
#             supply/active_more_3y_percent
# Date
# 2020-11-15                           0.32
# 2020-11-16                           0.32
# 2020-11-17                           0.32
# 2020-11-18                           0.32
# 2020-11-19                           0.32
#             supply/active_more_5y_percent
# Date
# 2020-11-15                           0.22
# 2020-11-16                           0.22
# 2020-11-17                           0.22
# 2020-11-18                           0.22
# 2020-11-19                           0.22
#             supply/active_24h
# Date
# 2020-11-15          139075.56
# 2020-11-16          227828.59
# 2020-11-17          313405.86
# 2020-11-18          394194.82
# 2020-11-19          225887.25
#             supply/active_1d_1w
# Date
# 2020-11-15            593580.45
# 2020-11-16            492479.14
# 2020-11-17            492280.72
# 2020-11-18            549168.94
# 2020-11-19            692548.70
#             supply/active_1w_1m
# Date
# 2020-11-15           1725468.65
# 2020-11-16           1755278.02
# 2020-11-17           1709309.33
# 2020-11-18           1619539.85
# 2020-11-19           1649372.28
#             supply/active_1m_3m
# Date
# 2020-11-15           1273759.50
# 2020-11-16           1249076.01
# 2020-11-17           1227603.01
# 2020-11-18           1212140.82
# 2020-11-19           1211778.55
#             supply/active_3m_6m
# Date
# 2020-11-15           1366710.58
# 2020-11-16           1380162.58
# 2020-11-17           1382657.88
# 2020-11-18           1377854.54
# 2020-11-19           1386125.92
#             supply/active_6m_12m
# Date
# 2020-11-15            2013697.32
# 2020-11-16            2014860.74
# 2020-11-17            2003131.79
# 2020-11-18            1990316.15
# 2020-11-19            1984460.75
#             supply/active_1y_2y
# Date
# 2020-11-15           3265603.11
# 2020-11-16           3263008.47
# 2020-11-17           3266448.44
# 2020-11-18           3262643.36
# 2020-11-19           3258472.71
#             supply/active_2y_3y
# Date
# 2020-11-15           2172900.50
# 2020-11-16           2163209.23
# 2020-11-17           2147485.02
# 2020-11-18           2137064.62
# 2020-11-19           2129573.98
#             supply/active_3y_5y
# Date
# 2020-11-15           1928168.41
# 2020-11-16           1934808.60
# 2020-11-17           1938911.19
# 2020-11-18           1940395.31
# 2020-11-19           1948164.66
#             supply/active_5y_7y
# Date
# 2020-11-15            911328.97
# 2020-11-16            909509.51
# 2020-11-17            905284.01
# 2020-11-18            899361.19
# 2020-11-19            894064.25
#             supply/active_7y_10y
# Date
# 2020-11-15            1325715.61
# 2020-11-16            1326036.83
# 2020-11-17            1330216.46
# 2020-11-18            1334656.14
# 2020-11-19            1337175.84
#             supply/active_more_10y
# Date
# 2020-11-15              1828374.88
# 2020-11-16              1829125.84
# 2020-11-17              1829631.10
# 2020-11-18              1830085.31
# 2020-11-19              1830639.90
#             supply/issued
# Date
# 2020-11-15         937.50
# 2020-11-16        1000.00
# 2020-11-17         981.25
# 2020-11-18        1056.25
# 2020-11-19         850.00
#             supply/inflation_rate
# Date
# 2020-11-15                   0.02
# 2020-11-16                   0.02
# 2020-11-17                   0.02
# 2020-11-18                   0.02
# 2020-11-19                   0.02

# %% [markdown]
# #### Transaction Metrics from Glassnode

# %%
# List of Transaction Features
transaction_feature_list = ['transactions/count', 'transactions/size_sum','transactions/transfers_volume_sum', 'transactions/transfers_volume_adjusted_sum']

# %%
# Data Frame of Transaction Features
df_transaction = import_glassnode_many(transaction_feature_list)
# Out:
#             transactions/count
# Date
# 2020-11-15           252565.00
# 2020-11-16           311317.00
# 2020-11-17           347615.00
# 2020-11-18           361838.00
# 2020-11-19           309004.00
#             transactions/size_sum
# Date
# 2020-11-15           180725345.00
# 2020-11-16           193367265.00
# 2020-11-17           201284684.00
# 2020-11-18           213218316.00
# 2020-11-19           180757487.00
#             transactions/transfers_volume_sum
# Date
# 2020-11-15                         1597965.75
# 2020-11-16                         3617220.16
# 2020-11-17                         3029739.73
# 2020-11-18                         2929005.58
# 2020-11-19                         2357279.91
#             transactions/transfers_volume_adjusted_sum
# Date
# 2020-11-15                                   339972.31
# 2020-11-16                                   500350.56
# 2020-11-17                                   606039.94
# 2020-11-18                                   720480.43
# 2020-11-19                                   509022.91

# %% [markdown]
# #### Exchange Metrics from Glassnode - 1 Month Lag

# %%
# List of Exchange Features
exchange_feature_list = ['transactions/transfers_volume_to_exchanges_sum', 'transactions/transfers_volume_from_exchanges_sum', 'transactions/transfers_to_exchanges_count', 'transactions/transfers_from_exchanges_count', 'distribution/balance_exchanges', 'transactions/transfers_volume_exchanges_net']

# %%
# Data Frame of Exchange Features
df_exchange = import_glassnode_many(exchange_feature_list)
# Out:
#             transactions/transfers_volume_to_exchanges_sum
# Date
# 2020-11-14                                        29394.77
# 2020-11-15                                        14774.68
# 2020-11-16                                        44275.52
# 2020-11-17                                        62730.40
# 2020-11-18                                        62371.00
#             transactions/transfers_volume_from_exchanges_sum
# Date
# 2020-11-14                                          20632.98
# 2020-11-15                                          26919.63
# 2020-11-16                                          57897.53
# 2020-11-17                                          58178.14
# 2020-11-18                                          63319.65
#             transactions/transfers_to_exchanges_count
# Date
# 2020-11-14                                   36952.00
# 2020-11-15                                   33827.00
# 2020-11-16                                   46149.00
# 2020-11-17                                   54804.00
# 2020-11-18                                   52840.00
#             transactions/transfers_from_exchanges_count
# Date
# 2020-11-14                                     32178.00
# 2020-11-15                                     27693.00
# 2020-11-16                                     38790.00
# 2020-11-17                                     45565.00
# 2020-11-18                                     51707.00
#             distribution/balance_exchanges
# Date
# 2020-11-14                      2400576.36
# 2020-11-15                      2388426.03
# 2020-11-16                      2374796.99
# 2020-11-17                      2379341.21
# 2020-11-18                      2378383.01
#             transactions/transfers_volume_exchanges_net
# Date
# 2020-11-14                                      8761.80
# 2020-11-15                                    -12144.95
# 2020-11-16                                    -13622.01
# 2020-11-17                                      4552.26
# 2020-11-18                                      -948.65

# %% [markdown]
# #### Indicator-I Metrics from Glassnode

# %%
# List of Indicator-1 Features
indicator1_feature_list = ['indicators/sopr_adjusted', 'indicators/nvt', 'indicators/velocity', 'indicators/cdd', 'indicators/reserve_risk', 'indicators/average_dormancy', 'indicators/liveliness']

# %%
# Data Frame of Indicator-1 Features
df_indicator1 = import_glassnode_many(indicator1_feature_list)
# Out:
#             indicators/sopr_adjusted
# Date
# 2020-11-15                      1.03
# 2020-11-16                      1.06
# 2020-11-17                      1.09
# 2020-11-18                      1.14
# 2020-11-19                      1.06
#             indicators/nvt
# Date
# 2020-11-15           54.55
# 2020-11-16           37.06
# 2020-11-17           30.60
# 2020-11-18           25.74
# 2020-11-19           36.44
#             indicators/velocity
# Date
# 2020-11-15                 0.02
# 2020-11-16                 0.03
# 2020-11-17                 0.03
# 2020-11-18                 0.04
# 2020-11-19                 0.03
#             indicators/cdd
# Date
# 2020-11-15      6737980.38
# 2020-11-16     11738676.20
# 2020-11-17     19199910.20
# 2020-11-18     26137906.24
# 2020-11-19     13365616.18
#             indicators/reserve_risk
# Date
# 2020-11-15                     0.00
# 2020-11-16                     0.00
# 2020-11-17                     0.00
# 2020-11-18                     0.00
# 2020-11-19                     0.00
#             indicators/average_dormancy
# Date
# 2020-11-15                        19.82
# 2020-11-16                        23.46
# 2020-11-17                        31.68
# 2020-11-18                        36.28
# 2020-11-19                        26.26
#             indicators/liveliness
# Date
# 2020-11-15                   0.60
# 2020-11-16                   0.60
# 2020-11-17                   0.60
# 2020-11-18                   0.60
# 2020-11-19                   0.60

# %% [markdown]
# #### Indicator-2 Metrics from Glassnode

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['indicators/asol', 'indicators/sol_1h', 'indicators/sol_1h_24h', 'indicators/sol_1d_1w', 'indicators/sol_1w_1m', 'indicators/sol_1m_3m', 'indicators/sol_3m_6m', 'indicators/sol_6m_12m', 'indicators/sol_1y_2y', 'indicators/sol_2y_3y', 'indicators/sol_3y_5y', 'indicators/sol_5y_7y', 'indicators/sol_7y_10y']

# %%
# Data Frame of Indicator-2 Features
df_indicator2 = import_glassnode_many(indicator2_feature_list)
# Out:
#             indicators/asol
# Date
# 2020-11-15            63.95
# 2020-11-16            40.54
# 2020-11-17            50.81
# 2020-11-18            65.74
# 2020-11-19            44.25
#             indicators/sol_1h
# Date
# 2020-11-15          163126.00
# 2020-11-16          192036.00
# 2020-11-17          201319.00
# 2020-11-18          213162.00
# 2020-11-19          181096.00
#             indicators/sol_1h_24h
# Date
# 2020-11-15              241036.00
# 2020-11-16              267226.00
# 2020-11-17              352909.00
# 2020-11-18              381374.00
# 2020-11-19              309894.00
#             indicators/sol_1d_1w
# Date
# 2020-11-15             178305.00
# 2020-11-16             214443.00
# 2020-11-17             173725.00
# 2020-11-18             170940.00
# 2020-11-19             175049.00
#             indicators/sol_1w_1m
# Date
# 2020-11-15              72499.00
# 2020-11-16             113569.00
# 2020-11-17             102277.00
# 2020-11-18             108110.00
# 2020-11-19              90893.00
#             indicators/sol_1m_3m
# Date
# 2020-11-15              67035.00
# 2020-11-16              71610.00
# 2020-11-17              52328.00
# 2020-11-18              46348.00
# 2020-11-19              39309.00
#             indicators/sol_3m_6m
# Date
# 2020-11-15              39096.00
# 2020-11-16              28353.00
# 2020-11-17              21482.00
# 2020-11-18              24868.00
# 2020-11-19              13997.00
#             indicators/sol_6m_12m
# Date
# 2020-11-15               74430.00
# 2020-11-16               12903.00
# 2020-11-17               17076.00
# 2020-11-18               22454.00
# 2020-11-19               12585.00
#             indicators/sol_1y_2y
# Date
# 2020-11-15              13304.00
# 2020-11-16              10135.00
# 2020-11-17              14237.00
# 2020-11-18              23293.00
# 2020-11-19              10935.00
#             indicators/sol_2y_3y
# Date
# 2020-11-15               5138.00
# 2020-11-16               6554.00
# 2020-11-17              12030.00
# 2020-11-18              18314.00
# 2020-11-19               9726.00
#             indicators/sol_3y_5y
# Date
# 2020-11-15               2037.00
# 2020-11-16               2391.00
# 2020-11-17               3818.00
# 2020-11-18               5096.00
# 2020-11-19               2979.00
#             indicators/sol_5y_7y
# Date
# 2020-11-15                766.00
# 2020-11-16                600.00
# 2020-11-17               1034.00
# 2020-11-18               1009.00
# 2020-11-19                701.00
#             indicators/sol_7y_10y
# Date
# 2020-11-15                  35.00
# 2020-11-16                 122.00
# 2020-11-17                  81.00
# 2020-11-18                 288.00
# 2020-11-19                  97.00

# %% [markdown]
# #### Indicator-3 Metrics from Glassnode

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['indicators/net_unrealized_profit_loss', 'indicators/unrealized_profit', 'indicators/unrealized_loss', 'indicators/net_realized_profit_loss', 'indicators/realized_profit', 'indicators/realized_loss', 'indicators/nupl_more_155', 'indicators/nupl_less_155', 'indicators/puell_multiple', 'indicators/stock_to_flow_deflection', 'indicators/difficulty_ribbon_compression']

# %%
# Data Frame of Indicator-3 Features
df_indicator3 = import_glassnode_many(indicator3_feature_list)
# Out:
#             indicators/net_unrealized_profit_loss
# Date
# 2020-11-15                                   0.57
# 2020-11-16                                   0.58
# 2020-11-17                                   0.60
# 2020-11-18                                   0.60
# 2020-11-19                                   0.60
#             indicators/unrealized_profit
# Date
# 2020-11-15                          0.57
# 2020-11-16                          0.58
# 2020-11-17                          0.60
# 2020-11-18                          0.60
# 2020-11-19                          0.60
#             indicators/unrealized_loss
# Date
# 2020-11-15                        0.00
# 2020-11-16                        0.00
# 2020-11-17                        0.00
# 2020-11-18                        0.00
# 2020-11-19                        0.00
#             indicators/net_realized_profit_loss
# Date
# 2020-11-15                         137336945.28
# 2020-11-16                         372514844.96
# 2020-11-17                         807779063.20
# 2020-11-18                        1334539073.51
# 2020-11-19                         401301333.11
#             indicators/realized_profit
# Date
# 2020-11-15                168119815.55
# 2020-11-16                390235235.90
# 2020-11-17                838096570.16
# 2020-11-18               1421394923.04
# 2020-11-19                455307158.88
#             indicators/realized_loss
# Date
# 2020-11-15               30782870.28
# 2020-11-16               17720390.93
# 2020-11-17               30317506.96
# 2020-11-18               86855849.53
# 2020-11-19               54005825.77
#             indicators/nupl_more_155
# Date
# 2020-11-15                      0.65
# 2020-11-16                      0.66
# 2020-11-17                      0.68
# 2020-11-18                      0.69
# 2020-11-19                      0.69
#             indicators/nupl_less_155
# Date
# 2020-11-15                      0.22
# 2020-11-16                      0.25
# 2020-11-17                      0.28
# 2020-11-18                      0.27
# 2020-11-19                      0.26
#             indicators/puell_multiple
# Date
# 2020-11-15                       1.24
# 2020-11-16                       1.35
# 2020-11-17                       1.39
# 2020-11-18                       1.56
# 2020-11-19                       1.25
#             indicators/stock_to_flow_deflection
# Date
# 2020-11-15                                 0.62
# 2020-11-16                                 0.64
# 2020-11-17                                 0.67
# 2020-11-18                                 0.68
# 2020-11-19                                 0.67
#             indicators/difficulty_ribbon_compression
# Date
# 2020-11-15                                      0.04
# 2020-11-16                                      0.04
# 2020-11-17                                      0.04
# 2020-11-18                                      0.04
# 2020-11-19                                      0.04

# %% [markdown]
# #### Addresses Metrics from Glassnode

# %%
# List of Addresses Features
addresses_feature_list = ['addresses/active_count', 'addresses/sending_count', 'addresses/receiving_count', 'addresses/new_non_zero_count', 'addresses/non_zero_count', 'addresses/min_point_zero_1_count','addresses/min_point_1_count', 'addresses/min_1_count', 'addresses/min_10_count', 'addresses/min_100_count', 'addresses/min_1k_count', 'addresses/min_10k_count']

# %%
# Data Frame of Addresses Features
df_addresses = import_glassnode_many(addresses_feature_list)
# Out:
#             addresses/active_count
# Date
# 2020-11-15               859865.00
# 2020-11-16              1036960.00
# 2020-11-17              1134731.00
# 2020-11-18              1187942.00
# 2020-11-19              1052797.00
#             addresses/sending_count
# Date
# 2020-11-15                559028.00
# 2020-11-16                663147.00
# 2020-11-17                706546.00
# 2020-11-18                750796.00
# 2020-11-19                655520.00
#             addresses/receiving_count
# Date
# 2020-11-15                  555358.00
# 2020-11-16                  681255.00
# 2020-11-17                  770674.00
# 2020-11-18                  807692.00
# 2020-11-19                  713380.00
#             addresses/new_non_zero_count
# Date
# 2020-11-15                     407914.00
# 2020-11-16                     493329.00
# 2020-11-17                     558880.00
# 2020-11-18                     581082.00
# 2020-11-19                     514027.00
#             addresses/non_zero_count
# Date
# 2020-11-15               32479715.00
# 2020-11-16               32473955.00
# 2020-11-17               32506599.00
# 2020-11-18               32525162.00
# 2020-11-19               32545753.00
#             addresses/min_point_zero_1_count
# Date
# 2020-11-15                        8571801.00
# 2020-11-16                        8564964.00
# 2020-11-17                        8553575.00
# 2020-11-18                        8532965.00
# 2020-11-19                        8543831.00
#             addresses/min_point_1_count
# Date
# 2020-11-15                   3126946.00
# 2020-11-16                   3124999.00
# 2020-11-17                   3127510.00
# 2020-11-18                   3123601.00
# 2020-11-19                   3125740.00
#             addresses/min_1_count
# Date
# 2020-11-15              818993.00
# 2020-11-16              818622.00
# 2020-11-17              819167.00
# 2020-11-18              818953.00
# 2020-11-19              819282.00
#             addresses/min_10_count
# Date
# 2020-11-15               154497.00
# 2020-11-16               154343.00
# 2020-11-17               154240.00
# 2020-11-18               154259.00
# 2020-11-19               154436.00
#             addresses/min_100_count
# Date
# 2020-11-15                 16241.00
# 2020-11-16                 16276.00
# 2020-11-17                 16238.00
# 2020-11-18                 16242.00
# 2020-11-19                 16200.00
#             addresses/min_1k_count
# Date
# 2020-11-15                 2237.00
# 2020-11-16                 2237.00
# 2020-11-17                 2232.00
# 2020-11-18                 2228.00
# 2020-11-19                 2228.00
#             addresses/min_10k_count
# Date
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
# 2020-11-19                   112.00

# %% [markdown]
# #### Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Futures Features
# futures_feature_list = ['derivatives/futures_volume_daily_all_sum', 'derivatives/futures_volume_daily_perpetual_sum', 'derivatives/futures_open_interest_all_sum', 'derivatives/futures_open_interest_perpetual_sum', 'derivatives/futures_funding_rate_perpetual']

# %% [markdown]
# ##### Data Frame of Future features
# df_futures = import_glassnode_many(futures_feature_list)

# %% [markdown]
# ## File Import and Data Tidying

# %%
# Import of Modules and Packages
import os
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.6f}'.format

# %%
os.chdir('C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010')

# %% [markdown]
# ### Import Blockchain CSV-Files

# %% [markdown]
# #### Market Metric CSV-Files

# %%
# List of Market Features
market_feature_list = ['price_usd_close', 'price_drawdown_relative', 'price_realized_usd', 'mvrv']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in market_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_market = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_market.columns:
    try:
        df_market["{}".format(y)] = df_market["{}".format(y)].str.replace(',','.')
        df_market["{}".format(y)] = df_market["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Market Metric Values
df_market.tail()
# Out:
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2020-11-15            15962.098952                       -0.194319
# 2020-11-16            16709.612284                       -0.156588
# 2020-11-17            17667.381593                       -0.108245
# 2020-11-18            17812.233237                       -0.100934
# 2020-11-19            17797.552692                       -0.101675
#
#             market/price_realized_usd  market/mvrv
# Date
# 2020-11-15                6910.668850     2.311843
# 2020-11-16                6926.408944     2.359903
# 2020-11-17                6962.388651     2.448941
# 2020-11-18                7037.449307     2.537373
# 2020-11-19                7058.986270     2.524014

# %% [markdown]
# #### Mining Metric CSV-Files

# %%
# List of Mining Features
mining_feature_list = ['difficulty_latest', 'hash_rate_mean', 'revenue_sum','marketcap_thermocap_ratio']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in mining_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame    
df_mining = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_mining.columns:
    try:
        df_mining["{}".format(y)] = df_mining["{}".format(y)].str.replace(',','.')
        df_mining["{}".format(y)] = df_mining["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Mining Metric Values
df_mining.tail()
# Out:
#                  mining/difficulty_latest        mining/hash_rate_mean  \
# Date
# 2020-11-14 72102964397116403744768.000000 118951378399870992384.000000
# 2020-11-15 72102964397116403744768.000000 124875241422092992512.000000
# 2020-11-16 75577685065077505392640.000000 136158304329831006208.000000
# 2020-11-17 75577685065077505392640.000000 136840305323567005696.000000
# 2020-11-18 75577685065077505392640.000000 146411297553796005888.000000
#
#             mining/revenue_sum  mining/marketcap_thermocap_ratio
# Date
# 2020-11-14          946.655581                          0.000001
# 2020-11-15          979.933355                          0.000001
# 2020-11-16         1083.457706                          0.000001
# 2020-11-17         1071.791296                          0.000001
# 2020-11-18         1147.107592                          0.000001

# %% [markdown]
# #### Blocks Metric CSV-Files

# %%
# List of Blockchain Features
block_feature_list = ['block_count', 'block_interval_mean', 'block_size_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in block_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_blockfeatures = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_blockfeatures.columns:
    try:
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].str.replace(',','.')
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].astype(float)
    except:
        pass

# %%
# Show Latest Feature Values
df_blockfeatures.tail()
# Out:
#             blockchain/block_count  blockchain/block_interval_mean  \
# Date
# 2020-11-15              150.000000                      577.400000
# 2020-11-16              160.000000                      536.431250
# 2020-11-17              157.000000                      552.305732
# 2020-11-18              169.000000                      516.201183
# 2020-11-19              136.000000                      632.625000
#
#             blockchain/block_size_sum
# Date
# 2020-11-15           180783978.000000
# 2020-11-16           193429011.000000
# 2020-11-17           201346288.000000
# 2020-11-18           213284264.000000
# 2020-11-19           180810954.000000

# %% [markdown]
# #### Distribution Metric CSV-Files

# %%
# List of Distribution Features
distribution_feature_list = ['balance_1pct_holders', 'gini', 'herfindahl']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in distribution_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        # Data Frame Setup
        df_new = df
    
    # Increase Counter    
    counter +=1

# Store Data Frame Copy in Distribution Data Frame    
df_distribution = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_distribution.columns:
    try:
        df_distribution["{}".format(y)] = df_distribution["{}".format(y)].str.replace(',','.')
        df_distribution["{}".format(y)] = df_distribution["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Distribution Metric Values
df_distribution.tail()
# Out:
#             distribution/balance_1pct_holders  distribution/gini  \
# Date
# 2020-11-14                           0.893213           0.987450
# 2020-11-15                           0.893373           0.987462
# 2020-11-16                           0.893520           0.987468
# 2020-11-17                           0.893628           0.987461
# 2020-11-18                           0.893914           0.987459
#
#             distribution/herfindahl
# Date
# 2020-11-14                 0.000257
# 2020-11-15                 0.000257
# 2020-11-16                 0.000257
# 2020-11-17                 0.000257
# 2020-11-18                 0.000259

# %% [markdown]
# #### Fee Metric CSV-Files

# %%
# List of Fee Features
fees_feature_list = ['volume_sum', 'volume_mean', 'fee_ratio_multiple']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in fees_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date') #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
        
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Fees Data Frame    
df_fees = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_fees.columns:
    try:
        df_fees["{}".format(y)] = df_fees["{}".format(y)].str.replace(',','.')
        df_fees["{}".format(y)] = df_fees["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Fee Metric Values
df_fees.tail()
# Out:
#             fees/volume_sum  fees/volume_mean  fees/fee_ratio_multiple
# Date
# 2020-11-15        42.433355          0.000168                23.093469
# 2020-11-16        83.457706          0.000268                12.982117
# 2020-11-17        90.541296          0.000260                11.837596
# 2020-11-18        97.638686          0.000270                11.817946
# 2020-11-19        94.126362          0.000305                10.030414

# %% [markdown]
# #### UTXO Metric CSV-Files

# %%
# List of UTXO Features
utxo_feature_list = ['utxo_created_count', 'utxo_spent_count','utxo_created_value_sum', 'utxo_spent_value_sum', 'utxo_profit_relative', 'utxo_profit_count', 'utxo_loss_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in utxo_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df

    # Increase Counter
    counter +=1

# Store Data Frame Copy in UTXO Data Frame
df_utxo = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_utxo.columns:
    try:
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].str.replace(',','.')
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest UTXO Metric Values
df_utxo.tail()
# Out:
#             blockchain/utxo_created_count  blockchain/utxo_spent_count  \
# Date
# 2020-11-15                  720717.000000                856807.000000
# 2020-11-16                  869288.000000                919942.000000
# 2020-11-17                  974192.000000                952316.000000
# 2020-11-18                 1017548.000000               1015256.000000
# 2020-11-19                  895148.000000                847262.000000
#
#             blockchain/utxo_created_value_sum  \
# Date
# 2020-11-15                     1598945.684913
# 2020-11-16                     3618303.617861
# 2020-11-17                     3030811.519460
# 2020-11-18                     2930159.471229
# 2020-11-19                     2358224.033346
#
#             blockchain/utxo_spent_value_sum  blockchain/utxo_profit_relative  \
# Date
# 2020-11-15                   1598008.184913                         0.985800
# 2020-11-16                   3617303.617861                         0.994615
# 2020-11-17                   3029830.269460                         0.997520
# 2020-11-18                   2929103.221229                         0.995451
# 2020-11-19                   2357374.033346                         0.994345
#
#             blockchain/utxo_profit_count  blockchain/utxo_loss_count
# Date
# 2020-11-15              113245855.000000              1631223.000000
# 2020-11-16              114208074.000000               618350.000000
# 2020-11-17              114563460.000000               284840.000000
# 2020-11-18              114328125.000000               511448.000000
# 2020-11-19              114261729.000000               640779.000000

# %% [markdown]
# #### Supply Metric CSV-Files

# %%
# List of Supply Features
supply_feature_list = ['current','profit_relative', 'profit_sum', 'loss_sum', 'active_more_1y_percent', 'active_more_2y_percent', 'active_more_3y_percent', 'active_more_5y_percent', 'active_24h', 'active_1d_1w', 'active_1w_1m', 'active_1m_3m', 'active_3m_6m', 'active_6m_12m', 'active_1y_2y', 'active_2y_3y', 'active_3y_5y', 'active_5y_7y', 'active_7y_10y', 'active_more_10y', 'issued', 'inflation_rate']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in supply_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Supply Data Frame    
df_supply = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_supply.columns:
    try:
        df_supply["{}".format(y)] = df_supply["{}".format(y)].str.replace(',','.')
        df_supply["{}".format(y)] = df_supply["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Supply Metric Values
df_supply.tail()
# Out:
#             supply/current  supply/profit_relative  supply/profit_sum  \
# Date
# 2020-11-15 18544412.500000                0.968391    17945673.963364
# 2020-11-16 18545412.500000                0.989986    18346861.568218
# 2020-11-17 18546393.750000                0.993428    18411620.914683
# 2020-11-18 18547450.000000                0.988230    18316325.540314
# 2020-11-19 18548300.000000                0.986185    18279213.136520
#
#             supply/loss_sum  supply/active_more_1y_percent  \
# Date
# 2020-11-15    585768.132134                       0.616471
# 2020-11-16    185580.527281                       0.616093
# 2020-11-17    121802.430816                       0.615644
# 2020-11-18    197306.397519                       0.614867
# 2020-11-19    232499.616751                       0.614509
#
#             supply/active_more_2y_percent  supply/active_more_3y_percent  \
# Date
# 2020-11-15                       0.440375                       0.323202
# 2020-11-16                       0.440146                       0.323502
# 2020-11-17                       0.439521                       0.323731
# 2020-11-18                       0.438959                       0.323737
# 2020-11-19                       0.438834                       0.324021
#
#             supply/active_more_5y_percent  supply/active_24h  \
# Date
# 2020-11-15                       0.219226      139075.561298
# 2020-11-16                       0.219174      227828.587066
# 2020-11-17                       0.219187      313405.857466
# 2020-11-18                       0.219119      394194.817699
# 2020-11-19                       0.218989      225887.252895
#
#             supply/active_1d_1w  ...  supply/active_3m_6m  \
# Date                             ...
# 2020-11-15        593580.449497  ...       1366710.575710
# 2020-11-16        492479.137858  ...       1380162.578385
# 2020-11-17        492280.719246  ...       1382657.878780
# 2020-11-18        549168.936573  ...       1377854.544249
# 2020-11-19        692548.702289  ...       1386125.917397
#
#             supply/active_6m_12m  supply/active_1y_2y  supply/active_2y_3y  \
# Date
# 2020-11-15        2013697.316634       3265603.113156       2172900.504835
# 2020-11-16        2014860.736466       3263008.474305       2163209.234417
# 2020-11-17        2003131.791775       3266448.437168       2147485.015524
# 2020-11-18        1990316.146085       3262643.362735       2137064.624152
# 2020-11-19        1984460.754823       3258472.711879       2129573.979192
#
#             supply/active_3y_5y  supply/active_5y_7y  supply/active_7y_10y  \
# Date
# 2020-11-15       1928168.414221        911328.968932        1325715.614833
# 2020-11-16       1934808.597038        909509.505109        1326036.831733
# 2020-11-17       1938911.185932        905284.005404        1330216.463808
# 2020-11-18       1940395.309883        899361.187043        1334656.136976
# 2020-11-19       1948164.656401        894064.250619        1337175.843458
#
#             supply/active_more_10y  supply/issued  supply/inflation_rate
# Date
# 2020-11-15          1828374.878235     937.500000               0.018623
# 2020-11-16          1829125.838235    1000.000000               0.019876
# 2020-11-17          1829631.098235     981.250000               0.019499
# 2020-11-18          1830085.308235    1056.250000               0.021003
# 2020-11-19          1830639.898235     850.000000               0.016867
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Transaction Metric CSV-Files

# %%
# List of Transaction features
transaction_feature_list = ['count', 'size_sum','transfers_volume_sum', 'transfers_volume_adjusted_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in transaction_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Transaction Data Frame
df_transaction = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_transaction.columns:
    try:
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].str.replace(',','.')
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Transaction Metric Values
df_transaction.tail()
# Out:
#             transactions/count  transactions/size_sum  \
# Date
# 2020-11-15       252565.000000       180725345.000000
# 2020-11-16       311317.000000       193367265.000000
# 2020-11-17       347615.000000       201284684.000000
# 2020-11-18       361838.000000       213218316.000000
# 2020-11-19       309004.000000       180757487.000000
#
#             transactions/transfers_volume_sum  \
# Date
# 2020-11-15                     1597965.751559
# 2020-11-16                     3617220.160155
# 2020-11-17                     3029739.728163
# 2020-11-18                     2929005.582543
# 2020-11-19                     2357279.906984
#
#             transactions/transfers_volume_adjusted_sum
# Date
# 2020-11-15                               339972.305718
# 2020-11-16                               500350.562608
# 2020-11-17                               606039.940181
# 2020-11-18                               720480.434819
# 2020-11-19                               509022.914127

# %% [markdown]
# #### Exchange Metrics CSV-Files

# %%
# List of Exchange Features
exchange_feature_list = ['transfers_volume_to_exchanges_sum', 'transfers_volume_from_exchanges_sum', 'transfers_to_exchanges_count', 
                         'transfers_from_exchanges_count', 'balance_exchanges', 'transfers_volume_exchanges_net']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in exchange_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Exchange Data Frame    
df_exchange = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_exchange.columns:
    try:
        df_exchange["{}".format(y)] = df_exchange["{}".format(y)].str.replace(',','.')
        df_exchange["{}".format(y)] = df_exchange["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Exchange Metric Values
df_exchange.tail()
# Out:
#             transactions/transfers_volume_to_exchanges_sum  \
# Date
# 2020-11-14                                    29394.773578
# 2020-11-15                                    14774.675611
# 2020-11-16                                    44275.522876
# 2020-11-17                                    62730.396791
# 2020-11-18                                    62371.002047
#
#             transactions/transfers_volume_from_exchanges_sum  \
# Date
# 2020-11-14                                      20632.976680
# 2020-11-15                                      26919.625111
# 2020-11-16                                      57897.530500
# 2020-11-17                                      58178.135283
# 2020-11-18                                      63319.649125
#
#             transactions/transfers_to_exchanges_count  \
# Date
# 2020-11-14                               36952.000000
# 2020-11-15                               33827.000000
# 2020-11-16                               46149.000000
# 2020-11-17                               54804.000000
# 2020-11-18                               52840.000000
#
#             transactions/transfers_from_exchanges_count  \
# Date
# 2020-11-14                                 32178.000000
# 2020-11-15                                 27693.000000
# 2020-11-16                                 38790.000000
# 2020-11-17                                 45565.000000
# 2020-11-18                                 51707.000000
#
#             distribution/balance_exchanges  \
# Date
# 2020-11-14                  2400576.357583
# 2020-11-15                  2388426.026312
# 2020-11-16                  2374796.992253
# 2020-11-17                  2379341.205018
# 2020-11-18                  2378383.011846
#
#             transactions/transfers_volume_exchanges_net
# Date
# 2020-11-14                                  8761.796898
# 2020-11-15                                -12144.949499
# 2020-11-16                                -13622.007624
# 2020-11-17                                  4552.261508
# 2020-11-18                                  -948.647077

# %% [markdown]
# #### Indicator-1 Metric CSV-Files

# %%
# List of Indicator-1 features
indicator1_feature_list = ['sopr_adjusted', 'nvt', 'velocity', 'cdd','reserve_risk', 'average_dormancy', 'liveliness'] 

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator1_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-1 Data Frame    
df_indicator1 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator1.columns:
    try:
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].str.replace(',','.')
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-1 Metric Values
df_indicator1.tail()
# Out:
#             indicators/sopr_adjusted  indicators/nvt  indicators/velocity  \
# Date
# 2020-11-15                  1.030034       54.546833             0.018333
# 2020-11-16                  1.058912       37.064838             0.026980
# 2020-11-17                  1.091134       30.602593             0.032677
# 2020-11-18                  1.135606       25.743170             0.038845
# 2020-11-19                  1.061903       36.439028             0.027443
#
#             indicators/cdd  indicators/reserve_risk  \
# Date
# 2020-11-15  6737980.384089                 0.002615
# 2020-11-16 11738676.198240                 0.002673
# 2020-11-17 19199910.199331                 0.002785
# 2020-11-18 26137906.239649                 0.002913
# 2020-11-19 13365616.182113                 0.002902
#
#             indicators/average_dormancy  indicators/liveliness
# Date
# 2020-11-15                    19.819204               0.601624
# 2020-11-16                    23.460903               0.601580
# 2020-11-17                    31.680932               0.601637
# 2020-11-18                    36.278440               0.601956
# 2020-11-19                    26.257396               0.602099

# %% [markdown]
# #### Indicator-2 Metrics CSV-Files

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['asol', 'sol_1h', 'sol_1h_24h', 'sol_1d_1w','sol_1w_1m', 'sol_1m_3m', 'sol_3m_6m', 'sol_6m_12m','sol_1y_2y', 'sol_2y_3y', 'sol_3y_5y', 'sol_5y_7y', 'sol_7y_10y']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator2_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-2 Data Frame
df_indicator2 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator2.columns:
    try:
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].str.replace(',','.')
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-2 Metric Values
df_indicator2.tail()
# Out:
#             indicators/asol  indicators/sol_1h  indicators/sol_1h_24h  \
# Date
# 2020-11-15        63.952704      163126.000000          241036.000000
# 2020-11-16        40.539993      192036.000000          267226.000000
# 2020-11-17        50.813525      201319.000000          352909.000000
# 2020-11-18        65.742210      213162.000000          381374.000000
# 2020-11-19        44.245656      181096.000000          309894.000000
#
#             indicators/sol_1d_1w  indicators/sol_1w_1m  indicators/sol_1m_3m  \
# Date
# 2020-11-15         178305.000000          72499.000000          67035.000000
# 2020-11-16         214443.000000         113569.000000          71610.000000
# 2020-11-17         173725.000000         102277.000000          52328.000000
# 2020-11-18         170940.000000         108110.000000          46348.000000
# 2020-11-19         175049.000000          90893.000000          39309.000000
#
#             indicators/sol_3m_6m  indicators/sol_6m_12m  indicators/sol_1y_2y  \
# Date
# 2020-11-15          39096.000000           74430.000000          13304.000000
# 2020-11-16          28353.000000           12903.000000          10135.000000
# 2020-11-17          21482.000000           17076.000000          14237.000000
# 2020-11-18          24868.000000           22454.000000          23293.000000
# 2020-11-19          13997.000000           12585.000000          10935.000000
#
#             indicators/sol_2y_3y  indicators/sol_3y_5y  indicators/sol_5y_7y  \
# Date
# 2020-11-15           5138.000000           2037.000000            766.000000
# 2020-11-16           6554.000000           2391.000000            600.000000
# 2020-11-17          12030.000000           3818.000000           1034.000000
# 2020-11-18          18314.000000           5096.000000           1009.000000
# 2020-11-19           9726.000000           2979.000000            701.000000
#
#             indicators/sol_7y_10y
# Date
# 2020-11-15              35.000000
# 2020-11-16             122.000000
# 2020-11-17              81.000000
# 2020-11-18             288.000000
# 2020-11-19              97.000000

# %% [markdown]
# #### Indicator-3 Metrics CSV-Files

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['net_unrealized_profit_loss', 'unrealized_profit', 'unrealized_loss', 'net_realized_profit_loss', 'realized_profit', 'realized_loss', 'nupl_more_155', 'nupl_less_155', 'puell_multiple', 'stock_to_flow_deflection', 'difficulty_ribbon_compression']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator3_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-3 Data Frame
df_indicator3 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator3.columns:
    try:
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].str.replace(',','.')
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-3 Metric Values
df_indicator3.tail()
# Out:
#             indicators/net_unrealized_profit_loss  \
# Date
# 2020-11-15                               0.565391
# 2020-11-16                               0.583600
# 2020-11-17                               0.603680
# 2020-11-18                               0.602824
# 2020-11-19                               0.603339
#
#             indicators/unrealized_profit  indicators/unrealized_loss  \
# Date
# 2020-11-15                      0.566447                    0.001056
# 2020-11-16                      0.583943                    0.000343
# 2020-11-17                      0.603805                    0.000124
# 2020-11-18                      0.603017                    0.000193
# 2020-11-19                      0.603501                    0.000162
#
#             indicators/net_realized_profit_loss  indicators/realized_profit  \
# Date
# 2020-11-15                     137336945.277239            168119815.554779
# 2020-11-16                     372514844.963326            390235235.895932
# 2020-11-17                     807779063.197345            838096570.157533
# 2020-11-18                    1334539073.514310           1421394923.043790
# 2020-11-19                     401301333.108778            455307158.880232
#
#             indicators/realized_loss  indicators/nupl_more_155  \
# Date
# 2020-11-15           30782870.277541                  0.649257
# 2020-11-16           17720390.932606                  0.664884
# 2020-11-17           30317506.960188                  0.682597
# 2020-11-18           86855849.529486                  0.685710
# 2020-11-19           54005825.771454                  0.685397
#
#             indicators/nupl_less_155  indicators/puell_multiple  \
# Date
# 2020-11-15                  0.215121                   1.240418
# 2020-11-16                  0.246091                   1.353830
# 2020-11-17                  0.277236                   1.386802
# 2020-11-18                  0.269365                   1.563237
# 2020-11-19                  0.264972                   1.253221
#
#             indicators/stock_to_flow_deflection  \
# Date
# 2020-11-15                             0.617117
# 2020-11-16                             0.641549
# 2020-11-17                             0.673337
# 2020-11-18                             0.675437
# 2020-11-19                             0.670462
#
#             indicators/difficulty_ribbon_compression
# Date
# 2020-11-15                                  0.043579
# 2020-11-16                                  0.043584
# 2020-11-17                                  0.041677
# 2020-11-18                                  0.039892
# 2020-11-19                                  0.037933

# %% [markdown]
# #### Addresses Metric CSV-Files

# %%
# List of Addresses Features
addresses_feature_list = ['active_count', 'sending_count', 'receiving_count', 'new_non_zero_count', 'non_zero_count', 'min_point_zero_1_count', 'min_point_1_count', 'min_1_count', 'min_10_count', 'min_100_count', 'min_1k_count', 'min_10k_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in addresses_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Addresses Data Frame
df_addresses = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_addresses.columns:
    try:
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].str.replace(',','.')
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Addresses Metric Values
df_addresses.tail()
# Out:
#             addresses/active_count  addresses/sending_count  \
# Date
# 2020-11-15           859865.000000            559028.000000
# 2020-11-16          1036960.000000            663147.000000
# 2020-11-17          1134731.000000            706546.000000
# 2020-11-18          1187942.000000            750796.000000
# 2020-11-19          1052797.000000            655520.000000
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-11-15              555358.000000                 407914.000000
# 2020-11-16              681255.000000                 493329.000000
# 2020-11-17              770674.000000                 558880.000000
# 2020-11-18              807692.000000                 581082.000000
# 2020-11-19              713380.000000                 514027.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-11-15           32479715.000000                    8571801.000000
# 2020-11-16           32473955.000000                    8564964.000000
# 2020-11-17           32506599.000000                    8553575.000000
# 2020-11-18           32525162.000000                    8532965.000000
# 2020-11-19           32545753.000000                    8543831.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-11-15               3126946.000000          818993.000000
# 2020-11-16               3124999.000000          818622.000000
# 2020-11-17               3127510.000000          819167.000000
# 2020-11-18               3123601.000000          818953.000000
# 2020-11-19               3125740.000000          819282.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-11-15           154497.000000             16241.000000
# 2020-11-16           154343.000000             16276.000000
# 2020-11-17           154240.000000             16238.000000
# 2020-11-18           154259.000000             16242.000000
# 2020-11-19           154436.000000             16200.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-11-15             2237.000000               110.000000
# 2020-11-16             2237.000000               111.000000
# 2020-11-17             2232.000000               111.000000
# 2020-11-18             2228.000000               113.000000
# 2020-11-19             2228.000000               112.000000

# %% [markdown]
# #### Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Future Features
# futures_feature_list = ['futures_volume_daily_all_sum', 'futures_volume_daily_perpetual_sum', 'futures_open_interest_all_sum', 'futures_open_interest_perpetual_sum', 'futures_funding_rate_perpetual']
#
# ##### Counter to Differentiate between Data Frame Setup and Data Frame Extension
# counter=0
#
# ##### For Loop through all Features in the List
# for x in futures_feature_list:
#
#     ##### Import Feature CSV-Files
#     df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
#
#     ##### Condition - Data Frame Set up or Data Frame Extension
#     if counter > 0:
#
#         ##### Data Frame Extension - Inner Join
#         df_new = df_new.join(df, how='inner')
#
#     else:
#
#         ##### Data Frame Setup
#         df_new = df
#
#     ##### Increase Counter
#     counter +=1
#
# ##### Store Data Frame Copy in Market Data Frame
# df_futures = df_new.copy()
#
# ##### Delete Original Data Frame
# del df_new
#
# ##### Change Data Type of Columns to Float
# for y in df_futures.columns:
#     try:
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].str.replace(',','.')
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].astype(float)
#     except:
#         pass

# %% [markdown]
# ## Target Variables

# %%
df_return = pd.DataFrame(df_market['market/price_usd_close'])

# %%
df_return.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_return['Daily Return in USD'] = df_return['Closed Price USD'].diff()

# %% [raw]
# # Add Column with BTC Daily Returns in Percent
# df_return['Daily Returns in Percent'] = (df_return['Daily Returns USD']) / (df_return['Closed Price USD'].shift(1))*100

# %% [raw]
# # Add Column with BTC Daily Log Returns in Percent
# df_return['Daily Log Returns in Percent'] = pd.DataFrame(np.log(df_return['Closed Price USD']/df_return['Closed Price USD'].shift(1))*100)

# %%
df_return.tail()
# Out:
#             Closed Price USD  Daily Return in USD
# Date
# 2020-11-15      15962.098952          -113.353782
# 2020-11-16      16709.612284           747.513332
# 2020-11-17      17667.381593           957.769310
# 2020-11-18      17812.233237           144.851643
# 2020-11-19      17797.552692           -14.680545

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Volatility

# %%
# Selecting BTC Close Price in USD
df_volatility = pd.DataFrame(df_market['market/price_usd_close'])

# %%
# Rename Price Column
df_volatility.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_volatility['Daily Return in USD'] = df_volatility['Closed Price USD'].diff()

# %%
# Add Column with BTC Daily Returns in Percent
df_volatility['Daily Return in Percent'] = (df_volatility['Daily Return in USD']) / (df_volatility['Closed Price USD'].shift(1))*100

# %%
# Add Column with BTC Daily Log Returns in Percent
df_volatility['Daily Log Return in Percent'] = pd.DataFrame(np.log(df_volatility['Closed Price USD']/df_volatility['Closed Price USD'].shift(1))*100)

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-11-15      15962.098952          -113.353782                -0.705136
# 2020-11-16      16709.612284           747.513332                 4.683052
# 2020-11-17      17667.381593           957.769310                 5.731846
# 2020-11-18      17812.233237           144.851643                 0.819882
# 2020-11-19      17797.552692           -14.680545                -0.082418
#
#             Daily Log Return in Percent
# Date
# 2020-11-15                    -0.707634
# 2020-11-16                     4.576704
# 2020-11-17                     5.573595
# 2020-11-18                     0.816539
# 2020-11-19                    -0.082452

# %%
# Calculation of Rolling Volatility of BTC Daily Log Returns for 10, 20 and 30 days period
df_volatility['Volatility Daily Log Return in Percent 3D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=3, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 5D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=5, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 10D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=10, min_periods=1).std())

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-11-15      15962.098952          -113.353782                -0.705136
# 2020-11-16      16709.612284           747.513332                 4.683052
# 2020-11-17      17667.381593           957.769310                 5.731846
# 2020-11-18      17812.233237           144.851643                 0.819882
# 2020-11-19      17797.552692           -14.680545                -0.082418
#
#             Daily Log Return in Percent  \
# Date
# 2020-11-15                    -0.707634
# 2020-11-16                     4.576704
# 2020-11-17                     5.573595
# 2020-11-18                     0.816539
# 2020-11-19                    -0.082452
#
#             Volatility Daily Log Return in Percent 3D  \
# Date
# 2020-11-15                                   0.822261
# 2020-11-16                                   3.288918
# 2020-11-17                                   3.375694
# 2020-11-18                                   2.508725
# 2020-11-19                                   3.039425
#
#             Volatility Daily Log Return in Percent 5D  \
# Date
# 2020-11-15                                   2.194807
# 2020-11-16                                   2.704052
# 2020-11-17                                   3.214138
# 2020-11-18                                   3.154788
# 2020-11-19                                   2.849220
#
#             Volatility Daily Log Return in Percent 10D
# Date
# 2020-11-15                                    2.633703
# 2020-11-16                                    2.960628
# 2020-11-17                                    2.655435
# 2020-11-18                                    2.518824
# 2020-11-19                                    2.440548

# %%
df_volatility_reduced = df_volatility['Volatility Daily Log Return in Percent 5D']

# %% [markdown]
# ### Log Price

# %%
# Selecting BTC Close Price in USD
df_logprice = pd.DataFrame(np.log(df_market['market/price_usd_close']))

# %%
df_logprice.columns = ['Log Price in USD']

# %%
df_logprice.tail()
# Out:
#             Log Price in USD
# Date
# 2020-11-15          9.677972
# 2020-11-16          9.723739
# 2020-11-17          9.779475
# 2020-11-18          9.787641
# 2020-11-19          9.786816

# %% [markdown]
# # Data Sets

# %% [markdown]
# ## Data Set I. - Blockchain Metrics Only

# %%
# Merging all Blockchain DataFrame Metrics
df_blockchain = pd.concat([df_return, df_logprice, df_volatility_reduced, df_market, df_mining, df_blockfeatures, df_distribution, df_fees, df_utxo, df_supply, 
                           df_transaction, df_exchange, df_indicator1, df_indicator2, df_indicator3, df_addresses], axis=1, join='inner')

# %%
df_blockchain = df_blockchain.dropna()

# %%
df_blockchain = df_blockchain.drop(['Closed Price USD'], axis=1)

# %%
df_blockchain.index = df_blockchain.index.astype('datetime64[ns]')

# %%
df_blockchain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3382 entries, 2011-08-17 to 2020-11-18
# Columns: 102 entries, Daily Return in USD to addresses/min_10k_count
# dtypes: float64(102)
# memory usage: 2.7 MB

# %%
df_blockchain.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-14          -236.060589          9.685049
# 2020-11-15          -113.353782          9.677972
# 2020-11-16           747.513332          9.723739
# 2020-11-17           957.769310          9.779475
# 2020-11-18           144.851643          9.787641
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-14                                   2.129520            16075.452734
# 2020-11-15                                   2.194807            15962.098952
# 2020-11-16                                   2.704052            16709.612284
# 2020-11-17                                   3.214138            17667.381593
# 2020-11-18                                   3.154788            17812.233237
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-14                       -0.188597                6902.437824
# 2020-11-15                       -0.194319                6910.668850
# 2020-11-16                       -0.156588                6926.408944
# 2020-11-17                       -0.108245                6962.388651
# 2020-11-18                       -0.100934                7037.449307
#
#             market/mvrv       mining/difficulty_latest  \
# Date
# 2020-11-14     2.319186 72102964397116403744768.000000
# 2020-11-15     2.311843 72102964397116403744768.000000
# 2020-11-16     2.359903 75577685065077505392640.000000
# 2020-11-17     2.448941 75577685065077505392640.000000
# 2020-11-18     2.537373 75577685065077505392640.000000
#
#                   mining/hash_rate_mean  mining/revenue_sum  ...  \
# Date                                                         ...
# 2020-11-14 118951378399870992384.000000          946.655581  ...
# 2020-11-15 124875241422092992512.000000          979.933355  ...
# 2020-11-16 136158304329831006208.000000         1083.457706  ...
# 2020-11-17 136840305323567005696.000000         1071.791296  ...
# 2020-11-18 146411297553796005888.000000         1147.107592  ...
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-11-14              613361.000000                 449703.000000
# 2020-11-15              555358.000000                 407914.000000
# 2020-11-16              681255.000000                 493329.000000
# 2020-11-17              770674.000000                 558880.000000
# 2020-11-18              807692.000000                 581082.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-11-14           32497576.000000                    8576405.000000
# 2020-11-15           32479715.000000                    8571801.000000
# 2020-11-16           32473955.000000                    8564964.000000
# 2020-11-17           32506599.000000                    8553575.000000
# 2020-11-18           32525162.000000                    8532965.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-11-14               3136060.000000          819561.000000
# 2020-11-15               3126946.000000          818993.000000
# 2020-11-16               3124999.000000          818622.000000
# 2020-11-17               3127510.000000          819167.000000
# 2020-11-18               3123601.000000          818953.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-11-14           154540.000000             16211.000000
# 2020-11-15           154497.000000             16241.000000
# 2020-11-16           154343.000000             16276.000000
# 2020-11-17           154240.000000             16238.000000
# 2020-11-18           154259.000000             16242.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-11-14             2236.000000               110.000000
# 2020-11-15             2237.000000               110.000000
# 2020-11-16             2237.000000               111.000000
# 2020-11-17             2232.000000               111.000000
# 2020-11-18             2228.000000               113.000000
#
# [5 rows x 102 columns]

# %%
# Summary of each variable
df_blockchain.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count          3382.000000       3382.000000
# mean              5.263535          6.380989
# std             229.387829          2.453336
# min           -3052.461475          0.718341
# 25%              -7.013234          5.421148
# 50%               0.109251          6.426153
# 75%              12.980680          8.779792
# max            3224.132131          9.882653
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                3382.000000             3382.000000
# mean                                    3.496043             3149.997792
# std                                     3.254872             4088.867156
# min                                     0.157723                2.051027
# 25%                                     1.515305              226.138513
# 50%                                     2.647045              617.793002
# 75%                                     4.397043             6501.524342
# max                                    41.749946            19587.613733
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                     3382.000000                3382.000000  3382.000000
# mean                        -0.550542                1918.658530     1.684408
# std                          0.230096                2376.585378     0.746196
# min                         -0.935694                   4.780226     0.402165
# 25%                         -0.717085                 244.943484     1.174069
# 50%                         -0.597396                 350.933659     1.592643
# 75%                         -0.451087                4840.104582     1.964991
# max                          0.000000                7037.449307     5.733982
#
#             mining/difficulty_latest        mining/hash_rate_mean  \
# count                    3382.000000                  3382.000000
# mean  13696577821885241229312.000000  23196952414309183488.000000
# std   22855131807634616745984.000000  38583510990718803968.000000
# min          4684588175054590.000000         6399665203131.940430
# 25%       3254055892334367744.000000      7213804770386562.000000
# 50%     716621792837638029312.000000   1238202949978849792.000000
# 75%   22838173403343176597504.000000  38066776596314546176.000000
# max   85887904103269694177280.000000 160765244797356015616.000000
#
#        mining/revenue_sum  ...  addresses/receiving_count  \
# count         3382.000000  ...                3382.000000
# mean          3462.648725  ...              325382.902425
# std           1915.534344  ...              226036.355561
# min            738.150148  ...                7539.000000
# 25%           1942.949764  ...              108200.250000
# 50%           3336.834281  ...              368205.000000
# 75%           4256.101014  ...              509189.000000
# max           9214.887810  ...             1072829.000000
#
#        addresses/new_non_zero_count  addresses/non_zero_count  \
# count                   3382.000000               3382.000000
# mean                  217592.179775           12195101.329391
# std                   158290.057465           10731237.067113
# min                     4241.000000             425513.000000
# 25%                    66880.500000            2281327.000000
# 50%                   225114.500000            7546893.500000
# 75%                   348561.250000           22402760.000000
# max                   800180.000000           32849437.000000
#
#        addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# count                       3382.000000                  3382.000000
# mean                     3475166.798936               1395614.630988
# std                      2891756.387999               1020039.246773
# min                       208208.000000                133210.000000
# 25%                       803127.000000                446635.250000
# 50%                      2587116.000000               1194128.500000
# 75%                      6384974.000000               2461441.250000
# max                      8753449.000000               3186455.000000
#
#        addresses/min_1_count  addresses/min_10_count  addresses/min_100_count  \
# count            3382.000000             3382.000000              3382.000000
# mean           472048.575991           125877.858664             14771.995565
# std            237845.902472            28431.693817              3500.544945
# min            103869.000000            65620.000000              4147.000000
# 25%            246536.250000           100356.500000             12971.250000
# 50%            481508.000000           138440.500000             16192.000000
# 75%            710291.500000           149744.250000             17163.500000
# max            825254.000000           157275.000000             18543.000000
#
#        addresses/min_1k_count  addresses/min_10k_count
# count             3382.000000              3382.000000
# mean              1625.904494               102.522176
# std                374.410097                14.437351
# min                622.000000                63.000000
# 25%               1478.500000                97.000000
# 50%               1686.500000               105.000000
# 75%               1843.000000               113.000000
# max               2237.000000               126.000000
#
# [8 rows x 102 columns]

# %%
# Creating CSV-File of Blockchain Data
df_blockchain.to_csv("df_dataset1.csv")

# %% [markdown]
# # Classification Models - Data Set Variations

# %%
# Import of Modules and Packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix, classification_report

# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from pycaret.classification import *

# Deep Neural Networks
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from keras.optimizers import Adam

# PyCaret
import pycaret

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Import Data Sets

# %% [markdown]
# ## Data Set I.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010'

# %%
# CSV Import of Data Set I. - Blockchain Data
df_dataset1 = pd.read_csv('df_dataset1.csv', parse_dates = True, index_col='Date')

# %%
df_dataset1
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-08-17                 0.03              2.40
# 2011-08-18                -0.15              2.38
# 2011-08-19                 0.80              2.46
# 2011-08-20                -0.20              2.44
# 2011-08-21                -0.13              2.43
# ...                         ...               ...
# 2020-11-14              -236.06              9.69
# 2020-11-15              -113.35              9.68
# 2020-11-16               747.51              9.72
# 2020-11-17               957.77              9.78
# 2020-11-18               144.85              9.79
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-08-17                                       3.60                   10.99
# 2011-08-18                                       3.29                   10.85
# 2011-08-19                                       3.72                   11.65
# 2011-08-20                                       3.77                   11.45
# 2011-08-21                                       3.71                   11.32
# ...                                               ...                     ...
# 2020-11-14                                       2.13                16075.45
# 2020-11-15                                       2.19                15962.10
# 2020-11-16                                       2.70                16709.61
# 2020-11-17                                       3.21                17667.38
# 2020-11-18                                       3.15                17812.23
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-08-17                           -0.66                       6.81
# 2011-08-18                           -0.66                       6.81
# 2011-08-19                           -0.63                       6.82
# 2011-08-20                           -0.64                       6.83
# 2011-08-21                           -0.64                       6.83
# ...                                    ...                        ...
# 2020-11-14                           -0.19                    6902.44
# 2020-11-15                           -0.19                    6910.67
# 2020-11-16                           -0.16                    6926.41
# 2020-11-17                           -0.11                    6962.39
# 2020-11-18                           -0.10                    7037.45
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2011-08-17         1.60        7755426037811680.00        12230547335773.00
# 2011-08-18         1.60        7755426037811680.00        12915246321786.50
# 2011-08-19         1.65        7755426037811680.00        11678381642086.70
# 2011-08-20         1.68        7755426037811680.00        13035626696015.50
# 2011-08-21         1.67        7755426037811680.00        14115210625069.60
# ...                 ...                        ...                      ...
# 2020-11-14         2.32 72102964397116403744768.00 118951378399870992384.00
# 2020-11-15         2.31 72102964397116403744768.00 124875241422092992512.00
# 2020-11-16         2.36 75577685065077505392640.00 136158304329831006208.00
# 2020-11-17         2.45 75577685065077505392640.00 136840305323567005696.00
# 2020-11-18         2.54 75577685065077505392640.00 146411297553796005888.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2011-08-17             6806.74  ...                   16662.00
# 2011-08-18             7205.92  ...                   17676.00
# 2011-08-19             6557.77  ...                   18932.00
# 2011-08-20             7605.42  ...                   18345.00
# 2011-08-21             8005.69  ...                   19626.00
# ...                        ...  ...                        ...
# 2020-11-14              946.66  ...                  613361.00
# 2020-11-15              979.93  ...                  555358.00
# 2020-11-16             1083.46  ...                  681255.00
# 2020-11-17             1071.79  ...                  770674.00
# 2020-11-18             1147.11  ...                  807692.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-08-17                      11974.00                 425513.00
# 2011-08-18                      11917.00                 429263.00
# 2011-08-19                      14238.00                 434988.00
# 2011-08-20                      12994.00                 440560.00
# 2011-08-21                      14851.00                 446963.00
# ...                                  ...                       ...
# 2020-11-14                     449703.00               32497576.00
# 2020-11-15                     407914.00               32479715.00
# 2020-11-16                     493329.00               32473955.00
# 2020-11-17                     558880.00               32506599.00
# 2020-11-18                     581082.00               32525162.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-08-17                         208208.00                    133210.00
# 2011-08-18                         208892.00                    133657.00
# 2011-08-19                         209553.00                    133993.00
# 2011-08-20                         210510.00                    134628.00
# 2011-08-21                         211300.00                    135057.00
# ...                                      ...                          ...
# 2020-11-14                        8576405.00                   3136060.00
# 2020-11-15                        8571801.00                   3126946.00
# 2020-11-16                        8564964.00                   3124999.00
# 2020-11-17                        8553575.00                   3127510.00
# 2020-11-18                        8532965.00                   3123601.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-08-17              103869.00                65620.00
# 2011-08-18              104143.00                65707.00
# 2011-08-19              104342.00                65756.00
# 2011-08-20              104796.00                65874.00
# 2011-08-21              105154.00                66045.00
# ...                           ...                     ...
# 2020-11-14              819561.00               154540.00
# 2020-11-15              818993.00               154497.00
# 2020-11-16              818622.00               154343.00
# 2020-11-17              819167.00               154240.00
# 2020-11-18              818953.00               154259.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-08-17                  4147.00                  622.00
# 2011-08-18                  4174.00                  624.00
# 2011-08-19                  4171.00                  627.00
# 2011-08-20                  4187.00                  625.00
# 2011-08-21                  4203.00                  625.00
# ...                             ...                     ...
# 2020-11-14                 16211.00                 2236.00
# 2020-11-15                 16241.00                 2237.00
# 2020-11-16                 16276.00                 2237.00
# 2020-11-17                 16238.00                 2232.00
# 2020-11-18                 16242.00                 2228.00
#
#             addresses/min_10k_count
# Date
# 2011-08-17                    75.00
# 2011-08-18                    75.00
# 2011-08-19                    75.00
# 2011-08-20                    75.00
# 2011-08-21                    75.00
# ...                             ...
# 2020-11-14                   110.00
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
#
# [3382 rows x 102 columns]

# %%
# Data Set Info
df_dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3382 entries, 2011-08-17 to 2020-11-18
# Columns: 102 entries, Daily Return in USD to addresses/min_10k_count
# dtypes: float64(102)
# memory usage: 2.7 MB

# %%
# List of Data Types
l_dtypes = df_dataset1.dtypes

# %%
# Counter
counter = 0

# Cross-Check of Data Types
for i in l_dtypes:
    if (i == float):
        counter = counter+1
    else:
        counter = counter

# Number of Float Data Types
print(counter)
# Out:
# 102

# %%
# Data Types
df_dataset1.dtypes
# Out:
# Daily Return in USD                          float64
# Log Price in USD                             float64
# Volatility Daily Log Return in Percent 5D    float64
# market/price_usd_close                       float64
# market/price_drawdown_relative               float64
#                                               ...
# addresses/min_1_count                        float64
# addresses/min_10_count                       float64
# addresses/min_100_count                      float64
# addresses/min_1k_count                       float64
# addresses/min_10k_count                      float64
# Length: 102, dtype: object

# %%
# Summary Statistics
df_dataset1.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count              3382.00           3382.00
# mean                  5.26              6.38
# std                 229.39              2.45
# min               -3052.46              0.72
# 25%                  -7.01              5.42
# 50%                   0.11              6.43
# 75%                  12.98              8.78
# max                3224.13              9.88
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                    3382.00                 3382.00
# mean                                        3.50                 3150.00
# std                                         3.25                 4088.87
# min                                         0.16                    2.05
# 25%                                         1.52                  226.14
# 50%                                         2.65                  617.79
# 75%                                         4.40                 6501.52
# max                                        41.75                19587.61
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                         3382.00                    3382.00      3382.00
# mean                            -0.55                    1918.66         1.68
# std                              0.23                    2376.59         0.75
# min                             -0.94                       4.78         0.40
# 25%                             -0.72                     244.94         1.17
# 50%                             -0.60                     350.93         1.59
# 75%                             -0.45                    4840.10         1.96
# max                              0.00                    7037.45         5.73
#
#         mining/difficulty_latest    mining/hash_rate_mean  mining/revenue_sum  \
# count                    3382.00                  3382.00             3382.00
# mean  13696577821885241229312.00  23196952414309183488.00             3462.65
# std   22855131807634616745984.00  38583510990718803968.00             1915.53
# min          4684588175054590.00         6399665203131.94              738.15
# 25%       3254055892334367744.00      7213804770386562.00             1942.95
# 50%     716621792837638029312.00   1238202949978849792.00             3336.83
# 75%   22838173403343176597504.00  38066776596314546176.00             4256.10
# max   85887904103269694177280.00 160765244797356015616.00             9214.89
#
#        ...  addresses/receiving_count  addresses/new_non_zero_count  \
# count  ...                    3382.00                       3382.00
# mean   ...                  325382.90                     217592.18
# std    ...                  226036.36                     158290.06
# min    ...                    7539.00                       4241.00
# 25%    ...                  108200.25                      66880.50
# 50%    ...                  368205.00                     225114.50
# 75%    ...                  509189.00                     348561.25
# max    ...                 1072829.00                     800180.00
#
#        addresses/non_zero_count  addresses/min_point_zero_1_count  \
# count                   3382.00                           3382.00
# mean                12195101.33                        3475166.80
# std                 10731237.07                        2891756.39
# min                   425513.00                         208208.00
# 25%                  2281327.00                         803127.00
# 50%                  7546893.50                        2587116.00
# 75%                 22402760.00                        6384974.00
# max                 32849437.00                        8753449.00
#
#        addresses/min_point_1_count  addresses/min_1_count  \
# count                      3382.00                3382.00
# mean                    1395614.63              472048.58
# std                     1020039.25              237845.90
# min                      133210.00              103869.00
# 25%                      446635.25              246536.25
# 50%                     1194128.50              481508.00
# 75%                     2461441.25              710291.50
# max                     3186455.00              825254.00
#
#        addresses/min_10_count  addresses/min_100_count  \
# count                 3382.00                  3382.00
# mean                125877.86                 14772.00
# std                  28431.69                  3500.54
# min                  65620.00                  4147.00
# 25%                 100356.50                 12971.25
# 50%                 138440.50                 16192.00
# 75%                 149744.25                 17163.50
# max                 157275.00                 18543.00
#
#        addresses/min_1k_count  addresses/min_10k_count
# count                 3382.00                  3382.00
# mean                  1625.90                   102.52
# std                    374.41                    14.44
# min                    622.00                    63.00
# 25%                   1478.50                    97.00
# 50%                   1686.50                   105.00
# 75%                   1843.00                   113.00
# max                   2237.00                   126.00
#
# [8 rows x 102 columns]

# %%
# Dataset Tail
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-14              -236.06              9.69
# 2020-11-15              -113.35              9.68
# 2020-11-16               747.51              9.72
# 2020-11-17               957.77              9.78
# 2020-11-18               144.85              9.79
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-14                                       2.13                16075.45
# 2020-11-15                                       2.19                15962.10
# 2020-11-16                                       2.70                16709.61
# 2020-11-17                                       3.21                17667.38
# 2020-11-18                                       3.15                17812.23
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-14                           -0.19                    6902.44
# 2020-11-15                           -0.19                    6910.67
# 2020-11-16                           -0.16                    6926.41
# 2020-11-17                           -0.11                    6962.39
# 2020-11-18                           -0.10                    7037.45
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-11-14         2.32 72102964397116403744768.00 118951378399870992384.00
# 2020-11-15         2.31 72102964397116403744768.00 124875241422092992512.00
# 2020-11-16         2.36 75577685065077505392640.00 136158304329831006208.00
# 2020-11-17         2.45 75577685065077505392640.00 136840305323567005696.00
# 2020-11-18         2.54 75577685065077505392640.00 146411297553796005888.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2020-11-14              946.66  ...                  613361.00
# 2020-11-15              979.93  ...                  555358.00
# 2020-11-16             1083.46  ...                  681255.00
# 2020-11-17             1071.79  ...                  770674.00
# 2020-11-18             1147.11  ...                  807692.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-14                     449703.00               32497576.00
# 2020-11-15                     407914.00               32479715.00
# 2020-11-16                     493329.00               32473955.00
# 2020-11-17                     558880.00               32506599.00
# 2020-11-18                     581082.00               32525162.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-14                        8576405.00                   3136060.00
# 2020-11-15                        8571801.00                   3126946.00
# 2020-11-16                        8564964.00                   3124999.00
# 2020-11-17                        8553575.00                   3127510.00
# 2020-11-18                        8532965.00                   3123601.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-14              819561.00               154540.00
# 2020-11-15              818993.00               154497.00
# 2020-11-16              818622.00               154343.00
# 2020-11-17              819167.00               154240.00
# 2020-11-18              818953.00               154259.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-14                 16211.00                 2236.00
# 2020-11-15                 16241.00                 2237.00
# 2020-11-16                 16276.00                 2237.00
# 2020-11-17                 16238.00                 2232.00
# 2020-11-18                 16242.00                 2228.00
#
#             addresses/min_10k_count
# Date
# 2020-11-14                   110.00
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
#
# [5 rows x 102 columns]

# %% [markdown]
# ## Prediction Shift

# %% [markdown]
# ### Data Set I.

# %%
# Shift of Target Column by 1 Day
df_dataset1['Daily Return in USD'] = df_dataset1['Daily Return in USD'].shift(1)

# %%
# Check Shift
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-14                30.10              9.69
# 2020-11-15              -236.06              9.68
# 2020-11-16              -113.35              9.72
# 2020-11-17               747.51              9.78
# 2020-11-18               957.77              9.79
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-14                                       2.13                16075.45
# 2020-11-15                                       2.19                15962.10
# 2020-11-16                                       2.70                16709.61
# 2020-11-17                                       3.21                17667.38
# 2020-11-18                                       3.15                17812.23
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-14                           -0.19                    6902.44
# 2020-11-15                           -0.19                    6910.67
# 2020-11-16                           -0.16                    6926.41
# 2020-11-17                           -0.11                    6962.39
# 2020-11-18                           -0.10                    7037.45
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-11-14         2.32 72102964397116403744768.00 118951378399870992384.00
# 2020-11-15         2.31 72102964397116403744768.00 124875241422092992512.00
# 2020-11-16         2.36 75577685065077505392640.00 136158304329831006208.00
# 2020-11-17         2.45 75577685065077505392640.00 136840305323567005696.00
# 2020-11-18         2.54 75577685065077505392640.00 146411297553796005888.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2020-11-14              946.66  ...                  613361.00
# 2020-11-15              979.93  ...                  555358.00
# 2020-11-16             1083.46  ...                  681255.00
# 2020-11-17             1071.79  ...                  770674.00
# 2020-11-18             1147.11  ...                  807692.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-14                     449703.00               32497576.00
# 2020-11-15                     407914.00               32479715.00
# 2020-11-16                     493329.00               32473955.00
# 2020-11-17                     558880.00               32506599.00
# 2020-11-18                     581082.00               32525162.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-14                        8576405.00                   3136060.00
# 2020-11-15                        8571801.00                   3126946.00
# 2020-11-16                        8564964.00                   3124999.00
# 2020-11-17                        8553575.00                   3127510.00
# 2020-11-18                        8532965.00                   3123601.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-14              819561.00               154540.00
# 2020-11-15              818993.00               154497.00
# 2020-11-16              818622.00               154343.00
# 2020-11-17              819167.00               154240.00
# 2020-11-18              818953.00               154259.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-14                 16211.00                 2236.00
# 2020-11-15                 16241.00                 2237.00
# 2020-11-16                 16276.00                 2237.00
# 2020-11-17                 16238.00                 2232.00
# 2020-11-18                 16242.00                 2228.00
#
#             addresses/min_10k_count
# Date
# 2020-11-14                   110.00
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
#
# [5 rows x 102 columns]

# %%
# Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          1
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 102, dtype: int64

# %%
# daily return: von gestern auf heute die preisveränderung deswegen shift später
df_dataset1.isnull()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-08-17                 True             False
# 2011-08-18                False             False
# 2011-08-19                False             False
# 2011-08-20                False             False
# 2011-08-21                False             False
# ...                         ...               ...
# 2020-11-14                False             False
# 2020-11-15                False             False
# 2020-11-16                False             False
# 2020-11-17                False             False
# 2020-11-18                False             False
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-08-17                                      False                   False
# 2011-08-18                                      False                   False
# 2011-08-19                                      False                   False
# 2011-08-20                                      False                   False
# 2011-08-21                                      False                   False
# ...                                               ...                     ...
# 2020-11-14                                      False                   False
# 2020-11-15                                      False                   False
# 2020-11-16                                      False                   False
# 2020-11-17                                      False                   False
# 2020-11-18                                      False                   False
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-08-17                           False                      False
# 2011-08-18                           False                      False
# 2011-08-19                           False                      False
# 2011-08-20                           False                      False
# 2011-08-21                           False                      False
# ...                                    ...                        ...
# 2020-11-14                           False                      False
# 2020-11-15                           False                      False
# 2020-11-16                           False                      False
# 2020-11-17                           False                      False
# 2020-11-18                           False                      False
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-08-17        False                     False                  False
# 2011-08-18        False                     False                  False
# 2011-08-19        False                     False                  False
# 2011-08-20        False                     False                  False
# 2011-08-21        False                     False                  False
# ...                 ...                       ...                    ...
# 2020-11-14        False                     False                  False
# 2020-11-15        False                     False                  False
# 2020-11-16        False                     False                  False
# 2020-11-17        False                     False                  False
# 2020-11-18        False                     False                  False
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2011-08-17               False  ...                      False
# 2011-08-18               False  ...                      False
# 2011-08-19               False  ...                      False
# 2011-08-20               False  ...                      False
# 2011-08-21               False  ...                      False
# ...                        ...  ...                        ...
# 2020-11-14               False  ...                      False
# 2020-11-15               False  ...                      False
# 2020-11-16               False  ...                      False
# 2020-11-17               False  ...                      False
# 2020-11-18               False  ...                      False
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-08-17                         False                     False
# 2011-08-18                         False                     False
# 2011-08-19                         False                     False
# 2011-08-20                         False                     False
# 2011-08-21                         False                     False
# ...                                  ...                       ...
# 2020-11-14                         False                     False
# 2020-11-15                         False                     False
# 2020-11-16                         False                     False
# 2020-11-17                         False                     False
# 2020-11-18                         False                     False
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-08-17                             False                        False
# 2011-08-18                             False                        False
# 2011-08-19                             False                        False
# 2011-08-20                             False                        False
# 2011-08-21                             False                        False
# ...                                      ...                          ...
# 2020-11-14                             False                        False
# 2020-11-15                             False                        False
# 2020-11-16                             False                        False
# 2020-11-17                             False                        False
# 2020-11-18                             False                        False
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-08-17                  False                   False
# 2011-08-18                  False                   False
# 2011-08-19                  False                   False
# 2011-08-20                  False                   False
# 2011-08-21                  False                   False
# ...                           ...                     ...
# 2020-11-14                  False                   False
# 2020-11-15                  False                   False
# 2020-11-16                  False                   False
# 2020-11-17                  False                   False
# 2020-11-18                  False                   False
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-08-17                    False                   False
# 2011-08-18                    False                   False
# 2011-08-19                    False                   False
# 2011-08-20                    False                   False
# 2011-08-21                    False                   False
# ...                             ...                     ...
# 2020-11-14                    False                   False
# 2020-11-15                    False                   False
# 2020-11-16                    False                   False
# 2020-11-17                    False                   False
# 2020-11-18                    False                   False
#
#             addresses/min_10k_count
# Date
# 2011-08-17                    False
# 2011-08-18                    False
# 2011-08-19                    False
# 2011-08-20                    False
# 2011-08-21                    False
# ...                             ...
# 2020-11-14                    False
# 2020-11-15                    False
# 2020-11-16                    False
# 2020-11-17                    False
# 2020-11-18                    False
#
# [3382 rows x 102 columns]

# %%
# Delete Empty Row
df_dataset1 = df_dataset1.dropna()

# %%
# Re-Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          0
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 102, dtype: int64

# %% [markdown]
# # Classification Setup

# %% [markdown]
# ## Create Data Set Copies for Trading Strategy

# %%
# Data Set Copy for Trading Extension
df_dataset1_copy = df_dataset1.copy()

# %% [markdown]
# ## Categorization - Data Set I.

# %%
# Categorization
# Class 1 for all Returns >= 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] >= 0, 'Class'] = 1
# Class 0 for all Returns < 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0
# Out:
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(new_indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-105-55abdf32f90e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-08-18                 0.03              2.38
# 2011-08-19                -0.15              2.46
# 2011-08-20                 0.80              2.44
# 2011-08-21                -0.20              2.43
# 2011-08-22                -0.13              2.39
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-08-18                                       3.29                   10.85
# 2011-08-19                                       3.72                   11.65
# 2011-08-20                                       3.77                   11.45
# 2011-08-21                                       3.71                   11.32
# 2011-08-22                                       4.15                   10.94
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-08-18                           -0.66                       6.81
# 2011-08-19                           -0.63                       6.82
# 2011-08-20                           -0.64                       6.83
# 2011-08-21                           -0.64                       6.83
# 2011-08-22                           -0.66                       6.84
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-08-18         1.60       7755426037811680.00      12915246321786.50
# 2011-08-19         1.65       7755426037811680.00      11678381642086.70
# 2011-08-20         1.68       7755426037811680.00      13035626696015.50
# 2011-08-21         1.67       7755426037811680.00      14115210625069.60
# 2011-08-22         1.63       7755426037811680.00      15232874647151.10
#
#             mining/revenue_sum  ...  addresses/new_non_zero_count  \
# Date                            ...
# 2011-08-18             7205.92  ...                      11917.00
# 2011-08-19             6557.77  ...                      14238.00
# 2011-08-20             7605.42  ...                      12994.00
# 2011-08-21             8005.69  ...                      14851.00
# 2011-08-22             8457.55  ...                      16250.00
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2011-08-18                 429263.00                         208892.00
# 2011-08-19                 434988.00                         209553.00
# 2011-08-20                 440560.00                         210510.00
# 2011-08-21                 446963.00                         211300.00
# 2011-08-22                 454630.00                         212086.00
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2011-08-18                    133657.00              104143.00
# 2011-08-19                    133993.00              104342.00
# 2011-08-20                    134628.00              104796.00
# 2011-08-21                    135057.00              105154.00
# 2011-08-22                    135509.00              105520.00
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2011-08-18                65707.00                  4174.00
# 2011-08-19                65756.00                  4171.00
# 2011-08-20                65874.00                  4187.00
# 2011-08-21                66045.00                  4203.00
# 2011-08-22                66149.00                  4218.00
#
#             addresses/min_1k_count  addresses/min_10k_count  Class
# Date
# 2011-08-18                  624.00                    75.00   1.00
# 2011-08-19                  627.00                    75.00   0.00
# 2011-08-20                  625.00                    75.00   1.00
# 2011-08-21                  625.00                    75.00   0.00
# 2011-08-22                  627.00                    76.00   0.00
#
# [5 rows x 103 columns]

# %%
# Delete Original Target Column
df_dataset1 = df_dataset1.drop(['Daily Return in USD'], axis=1)

# %%
# Check Class Balance
df_dataset1['Class'].value_counts()
# Out:
# 1.00    1835
# 0.00    1546
# Name: Class, dtype: int64

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Log Price in USD  Volatility Daily Log Return in Percent 5D  \
# Date
# 2011-08-18              2.38                                       3.29
# 2011-08-19              2.46                                       3.72
# 2011-08-20              2.44                                       3.77
# 2011-08-21              2.43                                       3.71
# 2011-08-22              2.39                                       4.15
#
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2011-08-18                   10.85                           -0.66
# 2011-08-19                   11.65                           -0.63
# 2011-08-20                   11.45                           -0.64
# 2011-08-21                   11.32                           -0.64
# 2011-08-22                   10.94                           -0.66
#
#             market/price_realized_usd  market/mvrv  mining/difficulty_latest  \
# Date
# 2011-08-18                       6.81         1.60       7755426037811680.00
# 2011-08-19                       6.82         1.65       7755426037811680.00
# 2011-08-20                       6.83         1.68       7755426037811680.00
# 2011-08-21                       6.83         1.67       7755426037811680.00
# 2011-08-22                       6.84         1.63       7755426037811680.00
#
#             mining/hash_rate_mean  mining/revenue_sum  \
# Date
# 2011-08-18      12915246321786.50             7205.92
# 2011-08-19      11678381642086.70             6557.77
# 2011-08-20      13035626696015.50             7605.42
# 2011-08-21      14115210625069.60             8005.69
# 2011-08-22      15232874647151.10             8457.55
#
#             mining/marketcap_thermocap_ratio  ...  \
# Date                                          ...
# 2011-08-18                              0.00  ...
# 2011-08-19                              0.00  ...
# 2011-08-20                              0.00  ...
# 2011-08-21                              0.00  ...
# 2011-08-22                              0.00  ...
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-08-18                      11917.00                 429263.00
# 2011-08-19                      14238.00                 434988.00
# 2011-08-20                      12994.00                 440560.00
# 2011-08-21                      14851.00                 446963.00
# 2011-08-22                      16250.00                 454630.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-08-18                         208892.00                    133657.00
# 2011-08-19                         209553.00                    133993.00
# 2011-08-20                         210510.00                    134628.00
# 2011-08-21                         211300.00                    135057.00
# 2011-08-22                         212086.00                    135509.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-08-18              104143.00                65707.00
# 2011-08-19              104342.00                65756.00
# 2011-08-20              104796.00                65874.00
# 2011-08-21              105154.00                66045.00
# 2011-08-22              105520.00                66149.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-08-18                  4174.00                  624.00
# 2011-08-19                  4171.00                  627.00
# 2011-08-20                  4187.00                  625.00
# 2011-08-21                  4203.00                  625.00
# 2011-08-22                  4218.00                  627.00
#
#             addresses/min_10k_count  Class
# Date
# 2011-08-18                    75.00   1.00
# 2011-08-19                    75.00   0.00
# 2011-08-20                    75.00   1.00
# 2011-08-21                    75.00   0.00
# 2011-08-22                    76.00   0.00
#
# [5 rows x 102 columns]

# %% [markdown]
# # Model Preparation - Data Set I.

# %% [markdown]
# ## Train Test Split - Data Set I.

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
predictors = df_dataset1.drop(['Class'], axis=1).values.astype(np.float32)

# %%
# Setup of Categorized Target Variable
target = df_dataset1['Class'].astype(np.float32)

# %%
# Predictor Dimensions
predictors.shape
# Out:
# (3381, 101)

# %%
# Target Dimensions
target.shape
# Out:
# (3381,)

# %%
# Train-Test-Split Function to Create Training and Test Data Set
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state = 41, stratify=target)

# %%
# Dimensions of Predictors for Training
X_train.shape
# Out:
# (2366, 101)

# %%
# Dimensions of Target for Training
y_train.shape
# Out:
# (2366,)

# %%
# Number of Predictors
n_nodes = predictors.shape[1]
n_nodes
# Out:
# 101

# %% [markdown]
# ### Check of Class Balance

# %%
# Check Training Target of Class 0
y_train[y_train==0].count()
# Out:
# 1082

# %%
# Check Training Target of Class 1
y_train[y_train==1].count()
# Out:
# 1284

# %%
# Check Test Target of Class 0
y_test[y_test==0].count()
# Out:
# 464

# %%
# Check Test Target of Class 1
y_test[y_test==1].count()
# Out:
# 551

# %% [markdown]
# ## Feature Scaling - Data Set I.

# %%
# Instantiation of MinMaxScaler and StandardSacler
norm_scaler = MinMaxScaler()
#std_scaler = StandardScaler()

# %%
# Scaler Training and Transformation of Training Set
X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))

# %%
# Scaler Transformation of Test Set
X_test_scaled = norm_scaler.transform(X_test)

# %%
# Scaled Test Features
X_test_scaled
# Out:
# array([[0.85705435, 0.06179439, 0.269744  , ..., 0.84574175, 0.8498759 ,
#         0.6349207 ],
#        [0.44207895, 0.09661104, 0.00591413, ..., 0.49965206, 0.46836227,
#         0.5079366 ],
#        [0.87727714, 0.01034379, 0.3246885 , ..., 0.86536324, 0.7040943 ,
#         0.952381  ],
#        ...,
#        [0.5557819 , 0.07443654, 0.01695817, ..., 0.6049262 , 0.514268  ,
#         0.5079366 ],
#        [0.6395094 , 0.55119306, 0.03664796, ..., 0.61042297, 0.5105459 ,
#         0.49206352],
#        [0.5146563 , 0.02781713, 0.01160031, ..., 0.8731562 , 0.6954094 ,
#         0.71428585]], dtype=float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
predictors_scaled = norm_scaler.transform(predictors)

# %% [markdown]
# # Classification Models - Data Set I.

# %%
# Function To Show Accuracy Mean and Accuracy Standard Deviation
def show_scores(scores):
    # Scores Series
    print('Scores:', scores)
    # Score Mean
    print('Mean:', np.mean(scores))
    # Score Standard Deviation
    print('Standard Deviation:', np.std(scores))

# %% [markdown]
# ## Logistic Regression - Data Set I.

# %%
# Instantiate Classifier - LogisticRegression
lreg = LogisticRegression(max_iter=1200)

# %%
# Train Classifier
lreg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1200)

# %%
# Prediction of Classes
y_pred = lreg.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = lreg.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.49522431, 0.58745096, 0.53098138, 0.46279719, 0.47940312,
#        0.4037284 , 0.43919761, 0.72523679, 0.52740003, 0.27183101])

# %%
# Select Actual Classes
np.array(y_test[1:11])
# Out:
# array([0., 1., 1., 1., 0., 1., 1., 1., 0., 0.], dtype=float32)

# %%
# Train Accuracy
lreg.score(X_train_scaled, y_train)
# Out:
# 0.6259509721048182

# %%
# Test Accuracy
lreg.score(X_test_scaled, y_test)
# Out:
# 0.6305418719211823

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[232 232]
#  [143 408]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.55       464
#          1.0       0.64      0.74      0.69       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.62      0.62      1015
# weighted avg       0.63      0.63      0.62      1015

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# Plot of ROC curve
_ = plt.plot([0, 1], [0, 1])
_ = plt.plot(fpr, tpr)
_ = plt.xlabel('False Positive Rate')
_ = plt.ylabel('True Positive Rate')
_ = plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC Score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6817620001251643

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.62948808 0.66053783 0.64836251 0.69187606 0.68665302 0.64981491
#  0.6885951  0.64558435 0.64702979 0.65594923]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.58702065 0.61538462 0.6035503  0.59763314 0.61242604 0.64497041
#  0.6035503  0.67159763 0.60650888 0.57988166]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.58702065 0.61538462 0.6035503  0.59763314 0.61242604 0.64497041
#  0.6035503  0.67159763 0.60650888 0.57988166]
# Mean: 0.6122523607547433
# Standard Deviation: 0.025855050817918328

# %% [markdown]
# ## Random Forest Classifier - Data Set I.

# %%
# Instantiate Classifier - Random Forest
rfc = RandomForestClassifier(n_estimators=100, max_leaf_nodes=None, criterion='gini', max_depth=3, random_state=41)

# %%
# Train Classifier
rfc.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=3, random_state=41)

# %%
# Prediction of Classes
y_pred = rfc.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = rfc.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.41461928, 0.48897441, 0.4573253 , 0.46372862, 0.46785895,
#        0.43611775, 0.51454482, 0.78211177, 0.46631749, 0.45469903])

# %%
# Train Accuracy
rfc.score(X_train_scaled, y_train)
# Out:
# 0.6306001690617076

# %%
# Test Accuracy
rfc.score(X_test_scaled, y_test)
# Out:
# 0.6305418719211823

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[241 223]
#  [152 399]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.52      0.56       464
#          1.0       0.64      0.72      0.68       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.62      0.62      1015
# weighted avg       0.63      0.63      0.63      1015

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6743303711120847

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.66847826 0.63945158 0.70493365 0.6545384  0.62125918 0.68894765
#  0.63398555 0.6568306  0.6594747  0.65422175]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.60766962 0.60946746 0.62426036 0.6183432  0.62721893 0.64201183
#  0.61538462 0.64201183 0.61538462 0.60946746]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.60766962 0.60946746 0.62426036 0.6183432  0.62721893 0.64201183
#  0.61538462 0.64201183 0.61538462 0.60946746]
# Mean: 0.6211219912377163
# Standard Deviation: 0.012024860058481388

# %% [markdown]
# # Trading Strategy - Data Set I

# %% [markdown]
# ## Trading Strategy in Combination with Logistic Regression

# %%
# Create Lists To Store All Calculated Values For Every Variable of Every Run
# Specified Period
# Threshold 0.5
spec_list_05_total = []
spec_list_05_profit = []
spec_list_05_loss = []
spec_list_05_trans = []
spec_list_05_acc = []
spec_list_05_preds_corr = []
spec_list_05_preds = []
# Threshold 0.6
spec_list_06_total = []
spec_list_06_profit = []
spec_list_06_loss = []
spec_list_06_trans = []
spec_list_06_acc = []
spec_list_06_preds_corr = []
spec_list_06_preds = []
# Threshold 0.7
spec_list_07_total = []
spec_list_07_profit = []
spec_list_07_loss = []
spec_list_07_trans = []
spec_list_07_acc = []
spec_list_07_preds_corr = []
spec_list_07_preds = []
# Threshold 0.8
spec_list_08_total = []
spec_list_08_profit = []
spec_list_08_loss = []
spec_list_08_trans = []
spec_list_08_acc = []
spec_list_08_preds_corr = []
spec_list_08_preds = []

# Entire Period
# Threshold 0.5
list_05_total = []
list_05_profit = []
list_05_loss = []
list_05_trans = []
list_05_acc = []
list_05_preds_corr = []
list_05_preds = []
# Threshold 0.6
list_06_total = []
list_06_profit = []
list_06_loss = []
list_06_trans = []
list_06_acc = []
list_06_preds_corr = []
list_06_preds = []
# Threshold 0.7
list_07_total = []
list_07_profit = []
list_07_loss = []
list_07_trans = []
list_07_acc = []
list_07_preds_corr = []
list_07_preds = []
# Threshold 0.8
list_08_total = []
list_08_profit = []
list_08_loss = []
list_08_trans = []
list_08_acc = []
list_08_preds_corr = []
list_08_preds = []

# %%
target
# Out:
# Date
# 2011-08-18   1.00
# 2011-08-19   0.00
# 2011-08-20   1.00
# 2011-08-21   0.00
# 2011-08-22   0.00
#              ...
# 2020-11-14   1.00
# 2020-11-15   0.00
# 2020-11-16   0.00
# 2020-11-17   1.00
# 2020-11-18   1.00
# Name: Class, Length: 3381, dtype: float32

# %%
predictors
# Out:
# array([[2.3838902e+00, 3.2931430e+00, 1.0847017e+01, ..., 4.1740000e+03,
#         6.2400000e+02, 7.5000000e+01],
#        [2.4553063e+00, 3.7208679e+00, 1.1650000e+01, ..., 4.1710000e+03,
#         6.2700000e+02, 7.5000000e+01],
#        [2.4380770e+00, 3.7733192e+00, 1.1450998e+01, ..., 4.1870000e+03,
#         6.2500000e+02, 7.5000000e+01],
#        ...,
#        [9.7237396e+00, 2.7040515e+00, 1.6709611e+04, ..., 1.6276000e+04,
#         2.2370000e+03, 1.1100000e+02],
#        [9.7794752e+00, 3.2141380e+00, 1.7667381e+04, ..., 1.6238000e+04,
#         2.2320000e+03, 1.1100000e+02],
#        [9.7876406e+00, 3.1547880e+00, 1.7812232e+04, ..., 1.6242000e+04,
#         2.2280000e+03, 1.1300000e+02]], dtype=float32)

# %%
for x in df_dataset1.columns:
    print(x)
# Out:
# Log Price in USD
# Volatility Daily Log Return in Percent 5D
# market/price_usd_close
# market/price_drawdown_relative
# market/price_realized_usd
# market/mvrv
# mining/difficulty_latest
# mining/hash_rate_mean
# mining/revenue_sum
# mining/marketcap_thermocap_ratio
# blockchain/block_count
# blockchain/block_interval_mean
# blockchain/block_size_sum
# distribution/balance_1pct_holders
# distribution/gini
# distribution/herfindahl
# fees/volume_sum
# fees/volume_mean
# fees/fee_ratio_multiple
# blockchain/utxo_created_count
# blockchain/utxo_spent_count
# blockchain/utxo_created_value_sum
# blockchain/utxo_spent_value_sum
# blockchain/utxo_profit_relative
# blockchain/utxo_profit_count
# blockchain/utxo_loss_count
# supply/current
# supply/profit_relative
# supply/profit_sum
# supply/loss_sum
# supply/active_more_1y_percent
# supply/active_more_2y_percent
# supply/active_more_3y_percent
# supply/active_more_5y_percent
# supply/active_24h
# supply/active_1d_1w
# supply/active_1w_1m
# supply/active_1m_3m
# supply/active_3m_6m
# supply/active_6m_12m
# supply/active_1y_2y
# supply/active_2y_3y
# supply/active_3y_5y
# supply/active_5y_7y
# supply/active_7y_10y
# supply/active_more_10y
# supply/issued
# supply/inflation_rate
# transactions/count
# transactions/size_sum
# transactions/transfers_volume_sum
# transactions/transfers_volume_adjusted_sum
# transactions/transfers_volume_to_exchanges_sum
# transactions/transfers_volume_from_exchanges_sum
# transactions/transfers_to_exchanges_count
# transactions/transfers_from_exchanges_count
# distribution/balance_exchanges
# transactions/transfers_volume_exchanges_net
# indicators/sopr_adjusted
# indicators/nvt
# indicators/velocity
# indicators/cdd
# indicators/reserve_risk
# indicators/average_dormancy
# indicators/liveliness
# indicators/asol
# indicators/sol_1h
# indicators/sol_1h_24h
# indicators/sol_1d_1w
# indicators/sol_1w_1m
# indicators/sol_1m_3m
# indicators/sol_3m_6m
# indicators/sol_6m_12m
# indicators/sol_1y_2y
# indicators/sol_2y_3y
# indicators/sol_3y_5y
# indicators/sol_5y_7y
# indicators/sol_7y_10y
# indicators/net_unrealized_profit_loss
# indicators/unrealized_profit
# indicators/unrealized_loss
# indicators/net_realized_profit_loss
# indicators/realized_profit
# indicators/realized_loss
# indicators/nupl_more_155
# indicators/nupl_less_155
# indicators/puell_multiple
# indicators/stock_to_flow_deflection
# indicators/difficulty_ribbon_compression
# addresses/active_count
# addresses/sending_count
# addresses/receiving_count
# addresses/new_non_zero_count
# addresses/non_zero_count
# addresses/min_point_zero_1_count
# addresses/min_point_1_count
# addresses/min_1_count
# addresses/min_10_count
# addresses/min_100_count
# addresses/min_1k_count
# addresses/min_10k_count
# Class

# %%
df_dataset1_copy[['Daily Return in USD']]
# Out:
#             Daily Return in USD
# Date
# 2011-08-18                 0.03
# 2011-08-19                -0.15
# 2011-08-20                 0.80
# 2011-08-21                -0.20
# 2011-08-22                -0.13
# ...                         ...
# 2020-11-14                30.10
# 2020-11-15              -236.06
# 2020-11-16              -113.35
# 2020-11-17               747.51
# 2020-11-18               957.77
#
# [3381 rows x 1 columns]

# %%
df_dataset1_copy["percentage_daily_return"] = df_dataset1_copy["Daily Return in USD"]/df_dataset1_copy["market/price_usd_close"]
df_dataset1_copy["percentage_daily_return"]
# Out:
# Date
# 2011-08-18    0.00
# 2011-08-19   -0.01
# 2011-08-20    0.07
# 2011-08-21   -0.02
# 2011-08-22   -0.01
#               ...
# 2020-11-14    0.00
# 2020-11-15   -0.01
# 2020-11-16   -0.01
# 2020-11-17    0.04
# 2020-11-18    0.05
# Name: percentage_daily_return, Length: 3381, dtype: float64

# %%
predictors
# Out:
# array([[2.3838902e+00, 3.2931430e+00, 1.0847017e+01, ..., 4.1740000e+03,
#         6.2400000e+02, 7.5000000e+01],
#        [2.4553063e+00, 3.7208679e+00, 1.1650000e+01, ..., 4.1710000e+03,
#         6.2700000e+02, 7.5000000e+01],
#        [2.4380770e+00, 3.7733192e+00, 1.1450998e+01, ..., 4.1870000e+03,
#         6.2500000e+02, 7.5000000e+01],
#        ...,
#        [9.7237396e+00, 2.7040515e+00, 1.6709611e+04, ..., 1.6276000e+04,
#         2.2370000e+03, 1.1100000e+02],
#        [9.7794752e+00, 3.2141380e+00, 1.7667381e+04, ..., 1.6238000e+04,
#         2.2320000e+03, 1.1100000e+02],
#        [9.7876406e+00, 3.1547880e+00, 1.7812232e+04, ..., 1.6242000e+04,
#         2.2280000e+03, 1.1300000e+02]], dtype=float32)

# %%
einsatz = 1000
percentlist=[]
zinseszins=[]
profitpercent=[]


# For Loop to Simulate K-fold Cross Validation
for x in range(1, 20):
    
    # Display Number of Runs
    print("Run:", x)
    
    # Split Data into Training and Testing
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, stratify=target)
    
    # Amount of Columns
    n_nodes = predictors.shape[1]

    # Instantiation of MinMaxScaler
    norm_scaler = MinMaxScaler()
    
    # Training and Application of Feature Scaler on Training Data of Predictors
    X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))
    
    # Application of Feature Scaler on Test Data of Predictors
    X_test_scaled = norm_scaler.transform(X_test)
    
    # Instantiate Classifier Logistic Regression
    lreg = LogisticRegression(max_iter=12000) 
    
    # Train Classifier
    lreg.fit(X_train_scaled, y_train)
    
    # Prediction of Classes
    y_pred = lreg.predict(X_test_scaled)
    
    # Display Confusion Matrix and Classification Report
    print(confusion_matrix(y_test, y_pred))
#     print(classification_report(y_test, y_pred))

    # Prediction of Probabilities
    y_pred_prob = lreg.predict_proba(X_test_scaled)[:,1]

    # Create Data Frame of Actual Values - y_test
    df_y_test = pd.DataFrame(y_test)
    
    # Add Predicted Probabilities to Data Frame
    df_y_test["y_pred_prob"] = y_pred_prob
    
    # Add Predicted Classes (0 or 1) to Data Frame to Cross-Check Predicted Probabilities 
    df_y_test["y_pred"] =  y_pred
    
    # Select Actual Daily Returns in USD from the Data Set Copy
    df_dataset1_copy_dailyreturns=df_dataset1_copy[['Daily Return in USD']]
    
    # Merge Predictions and Daily Returns Data Frame on the Column "Date"
    df_y_test_withdailyreturns = pd.merge(df_y_test, df_dataset1_copy_dailyreturns, on='Date')
    
    df_dataset1_copy_percentage=df_dataset1_copy[['percentage_daily_return']]
    df_y_test_withdailyreturns = pd.merge(df_y_test_withdailyreturns, df_dataset1_copy_percentage, on='Date')
    
    # Add Bitcoin Price in USD
    df_y_test_withdailyreturns = pd.merge(df_y_test_withdailyreturns, df_dataset1['market/price_usd_close'] , on='Date')
    
    df_y_test_withdailyreturns['y_pred_prob_bereinigt'] = np.where(df_y_test_withdailyreturns['y_pred_prob']<0.5, 1-df_y_test_withdailyreturns['y_pred_prob'],df_y_test_withdailyreturns['y_pred_prob'])

    df_y_test_withdailyreturns["Einsatz"]=einsatz*df_y_test_withdailyreturns["y_pred_prob_bereinigt"]#**2
    
    # Add and Calculate Transaction Costs based on the Bitcoin Price in USD
    df_y_test_withdailyreturns['Transaction Costs in USD'] = df_y_test_withdailyreturns['Einsatz']*0.0003*2
    
    # Create List of Multiple Thresholds 
    # A Threshold of 0.7 means that only predicted probabilites with more than 0.7 or less than 0.3 are considered further
    list_thresholdcalc = [0.5, 0.6, 0.7, 0.8]
    
    # Try and Except Block to Address Cases in Which a Data Frame does NOT Contain Any Values Because No predicted Probability Meets the Threshold Requirements
    try:
        
        # For Loop Over List
        for thresholdcalc in list_thresholdcalc:
            
            # Creation of a Data Frame Containing Only Probability Predictions Which Meet the Threshold Requirements 
            df_y_test_probaall = df_y_test.loc[(df_y_test['y_pred_prob'] > thresholdcalc) | (df_y_test['y_pred_prob'] < 1-thresholdcalc)]
            
            # Calculation Of Accuracy Only for the Data Subset Meeting Threshold Requirements
            acc_calc = len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]) / len(df_y_test_probaall)
 
            print("Threshold of:", thresholdcalc)
            print(classification_report(df_y_test_probaall["Class"], df_y_test_probaall["y_pred"]))

            # Creation of Another Data Frame including Returns and Transaction Costs Only For Probability Predicitons that Meet the Threshold Requirements
            df_y_test_probaall_withdailyreturns = df_y_test_withdailyreturns.loc[(df_y_test_withdailyreturns['y_pred_prob'] > thresholdcalc) | (df_y_test_withdailyreturns['y_pred_prob'] < 1-thresholdcalc)]
            
            # Trading Assumption: Bet Amount = 1 Bitcoin for Each Prediction
            # Select Daily Returns Only From True Predictions Where Predicted Class equals Actual Class. It does not matter whether Daily Returns are Positive or Negative as Short-Selling Option Allows To Profit From Falling Prices
            profit = df_y_test_probaall_withdailyreturns["percentage_daily_return"][df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()
            
            # Select  Daily Returns Only From False Predictions Where Predicted Class equals Actual Class
            loss = df_y_test_probaall_withdailyreturns["percentage_daily_return"][df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()
            
            print( "{:.2f}%".format((profit-loss)*100) )
            
            if thresholdcalc == 0.5:
                percentlist.append( int((profit-loss)*100) )
            
            
            loss = loss * einsatz
            profit = profit * einsatz
            
            # Calculation of Transaction Costs based On BTC Value in USD. Each Future Trade considers Transaction Costs twice, becauase of Buying and Selling the Future
            transaction_costs = df_y_test_probaall_withdailyreturns['Transaction Costs in USD'].sum()
            
            # Calculation of Total Profit Considering Profit, Loss and Transaction Costs
            total=profit-loss-transaction_costs
            
            # In addition, the same setting with different time horizon
            currentpreds_all = len(df_y_test_probaall_withdailyreturns[df_y_test_probaall_withdailyreturns.index >= '2019-09-09' ])
            
            # Analog to Profit Calculation Above
            currentpreds_winning_total = df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])].abs().sum()
            # Analog to Loss Calculation Above 
            currentpreds_loosing_total = df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred'])].abs().sum()
            # Analog to Calculation of Transaction Costs Above
            currentpreds_transaction_costs = df_y_test_probaall_withdailyreturns['Transaction Costs in USD'][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred'])].sum()
            
            # Analog to Calculation of Total Profit
            currentpreds_total=currentpreds_winning_total-currentpreds_loosing_total-currentpreds_transaction_costs
            
            # Condition
            # In Case the Shorter Time Horizon Does Not Include any Sample -> Empyt Output
            if currentpreds_all == 0:
                currentpreds_all = '-'
                current_acc_calc = '-'
            
            # Otherwise Calculation of Accuracy analog to theeins Accuracy Calculation for the Entire Period
            else:
                current_acc_calc = (len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])]))/currentpreds_all
            
            #Display of Threshold, Total Profit, Profit, Loss, Transaction Costs, Accuracy and Correct Number of Predictions Both for the Specified Time Horizon and the Entire Time
            print("Specified Period:")
            print("Total Return in Specified Period:", int(currentpreds_total), "/ Profit: ", int(currentpreds_winning_total), "/ Loss: ", int(currentpreds_loosing_total), "/ Transaction Costs: ", int(currentpreds_transaction_costs),"/ Calculated Accuracy", current_acc_calc, "/ #Correct Predictions:", (len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])), "of", currentpreds_all)
            print()
            print("Entire Period:")
            print("einsatz", int(df_y_test_withdailyreturns["Einsatz"].sum()),"Total Return:", int(total), "/ Profit: ", int(profit), "/ Loss: ", int(loss), "/ Transaction Costs: ", int(transaction_costs), "/ Calculated Accuracy", round(acc_calc, 2), "/ #Correct Predictions:", len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]),  "Of", len(df_y_test_probaall))
            print("einsatz/bet", df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall), "Total Return / bet", int(total) / len(df_y_test_probaall),"/ Transaction Costs / bet ", int(transaction_costs) / len(df_y_test_probaall), "/ Calculated Accuracy", round(acc_calc, 2))
            print("profit in % per bet: {:.2f}".format( 100*(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ))
            if thresholdcalc == 0.5:
                profitpercent.append( 100*(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) )
            
            print("einsatz * 1+profit% ^ # wetten {:.2f}".format( einsatz*(1+(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ) ** len(df_y_test_probaall) ) )
            if thresholdcalc == 0.5:
                zinseszins.append( einsatz*(1+(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ) ** len(df_y_test_probaall) )
            print()
            print()
            
            # Store All Calculated Values For Every Variable of Every Run
            # Specified Period
            # Threshold = 0.5
            if thresholdcalc == 0.5:
                spec_list_05_total.append(currentpreds_total) 
                spec_list_05_profit.append(currentpreds_winning_total) 
                spec_list_05_loss.append(currentpreds_loosing_total)
                spec_list_05_trans.append(currentpreds_transaction_costs)
                spec_list_05_acc.append(current_acc_calc)
                spec_list_05_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_05_preds.append(currentpreds_all)
            # Threshold = 0.6
            if thresholdcalc == 0.6:
                spec_list_06_total.append(currentpreds_total) 
                spec_list_06_profit.append(currentpreds_winning_total) 
                spec_list_06_loss.append(currentpreds_loosing_total)
                spec_list_06_trans.append(currentpreds_transaction_costs)
                spec_list_06_acc.append(current_acc_calc)
                spec_list_06_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_06_preds.append(currentpreds_all)
            # Threshold = 0.7
            if thresholdcalc == 0.7:
                spec_list_07_total.append(currentpreds_total) 
                spec_list_07_profit.append(currentpreds_winning_total) 
                spec_list_07_loss.append(currentpreds_loosing_total)
                spec_list_07_trans.append(currentpreds_transaction_costs)
                spec_list_07_acc.append(current_acc_calc)
                spec_list_07_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_07_preds.append(currentpreds_all)
            # Threshold = 0.8
            if thresholdcalc == 0.8:
                spec_list_08_total.append(currentpreds_total) 
                spec_list_08_profit.append(currentpreds_winning_total) 
                spec_list_08_loss.append(currentpreds_loosing_total)
                spec_list_08_trans.append(currentpreds_transaction_costs)
                spec_list_08_acc.append(current_acc_calc)
                spec_list_08_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_08_preds.append(currentpreds_all)  
          
            # Entire Period
            # Threshold = 0.5
            if thresholdcalc == 0.5:
                list_05_total.append(total) 
                list_05_profit.append(profit) 
                list_05_loss.append(loss)
                list_05_trans.append(transaction_costs)
                list_05_acc.append(acc_calc)
                list_05_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_05_preds.append(len(df_y_test_probaall))    
            # Threshold = 0.6
            if thresholdcalc == 0.6:
                list_06_total.append(total) 
                list_06_profit.append(profit) 
                list_06_loss.append(loss)
                list_06_trans.append(transaction_costs)
                list_06_acc.append(acc_calc)
                list_06_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_06_preds.append(len(df_y_test_probaall))        
            # Threshold = 0.7
            if thresholdcalc == 0.7:
                list_07_total.append(total) 
                list_07_profit.append(profit) 
                list_07_loss.append(loss)
                list_07_trans.append(transaction_costs)
                list_07_acc.append(acc_calc)
                list_07_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_07_preds.append(len(df_y_test_probaall))
            # Threshold = 0.8
            if thresholdcalc == 0.8:
                list_08_total.append(total) 
                list_08_profit.append(profit) 
                list_08_loss.append(loss)
                list_08_trans.append(transaction_costs)
                list_08_acc.append(acc_calc)
                list_08_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_08_preds.append(len(df_y_test_probaall)) 
            
    except:
        print("error")
    # Display Empty Rows Between Each Run
    print()
    print()
# Out:
# Run: 1
# [[220 244]
#  [136 415]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.47      0.54       464
#          1.0       0.63      0.75      0.69       551
#
#     accuracy                           0.63      1015
#    macro avg       0.62      0.61      0.61      1015
# weighted avg       0.62      0.63      0.62      1015
#
# 1052.45%
# Specified Period:
# Total Return in Specified Period: 15221 / Profit:  21644 / Loss:  6407 / Transaction Costs:  15 / Calculated Accuracy 0.6356589147286822 / #Correct Predictions: 82 of 129
#
# Entire Period:
# einsatz 620808 Total Return: 10151 / Profit:  19204 / Loss:  8680 / Transaction Costs:  372 / Calculated Accuracy 0.63 / #Correct Predictions: 635 Of 1015
# einsatz/bet 611.6344001928749 Total Return / bet 10.000985221674878 / Transaction Costs / bet  0.3665024630541872 / Calculated Accuracy 0.63
# profit in % per bet: 1.64
# einsatz * 1+profit% ^ # wetten 14108530198.40
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.44      0.53       190
#          1.0       0.71      0.86      0.78       301
#
#     accuracy                           0.70       491
#    macro avg       0.69      0.65      0.65       491
# weighted avg       0.69      0.70      0.68       491
#
# 860.06%
# Specified Period:
# Total Return in Specified Period: 6479 / Profit:  7602 / Loss:  1121 / Transaction Costs:  1 / Calculated Accuracy 0.84375 / #Correct Predictions: 27 of 32
#
# Entire Period:
# einsatz 620808 Total Return: 8400 / Profit:  11972 / Loss:  3372 / Transaction Costs:  200 / Calculated Accuracy 0.7 / #Correct Predictions: 343 Of 491
# einsatz/bet 1264.376611396676 Total Return / bet 17.10794297352342 / Transaction Costs / bet  0.4073319755600815 / Calculated Accuracy 0.7
# profit in % per bet: 1.35
# einsatz * 1+profit% ^ # wetten 734393.65
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.40      0.51        48
#          1.0       0.77      0.92      0.84       103
#
#     accuracy                           0.75       151
#    macro avg       0.73      0.66      0.67       151
# weighted avg       0.75      0.75      0.73       151
#
# 375.37%
# Specified Period:
# Total Return in Specified Period: -521 / Profit:  116 / Loss:  637 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 620808 Total Return: 3686 / Profit:  4502 / Loss:  748 / Transaction Costs:  67 / Calculated Accuracy 0.75 / #Correct Predictions: 114 Of 151
# einsatz/bet 4111.317325799788 Total Return / bet 24.410596026490065 / Transaction Costs / bet  0.44370860927152317 / Calculated Accuracy 0.75
# profit in % per bet: 0.59
# einsatz * 1+profit% ^ # wetten 2444.64
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.83      0.77         6
#          1.0       0.93      0.88      0.90        16
#
#     accuracy                           0.86        22
#    macro avg       0.82      0.85      0.84        22
# weighted avg       0.87      0.86      0.87        22
#
# 130.74%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 620808 Total Return: 1296 / Profit:  1388 / Loss:  80 / Transaction Costs:  11 / Calculated Accuracy 0.86 / #Correct Predictions: 19 Of 22
# einsatz/bet 28218.58709980763 Total Return / bet 58.90909090909091 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.86
# profit in % per bet: 0.21
# einsatz * 1+profit% ^ # wetten 1046.95
#
#
#
#
# Run: 2
# [[222 242]
#  [135 416]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.48      0.54       464
#          1.0       0.63      0.75      0.69       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.62      0.61      1015
# weighted avg       0.63      0.63      0.62      1015
#
# 1129.49%
# Specified Period:
# Total Return in Specified Period: 8642 / Profit:  18385 / Loss:  9722 / Transaction Costs:  20 / Calculated Accuracy 0.5869565217391305 / #Correct Predictions: 81 of 138
#
# Entire Period:
# einsatz 613752 Total Return: 10926 / Profit:  20592 / Loss:  9298 / Transaction Costs:  368 / Calculated Accuracy 0.63 / #Correct Predictions: 638 Of 1015
# einsatz/bet 604.6817778748243 Total Return / bet 10.764532019704433 / Transaction Costs / bet  0.3625615763546798 / Calculated Accuracy 0.63
# profit in % per bet: 1.78
# einsatz * 1+profit% ^ # wetten 60012280418.77
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.45      0.54       199
#          1.0       0.68      0.85      0.76       275
#
#     accuracy                           0.68       474
#    macro avg       0.69      0.65      0.65       474
# weighted avg       0.68      0.68      0.67       474
#
# 872.39%
# Specified Period:
# Total Return in Specified Period: 5397 / Profit:  9056 / Loss:  3650 / Transaction Costs:  7 / Calculated Accuracy 0.6078431372549019 / #Correct Predictions: 31 of 51
#
# Entire Period:
# einsatz 613752 Total Return: 8533 / Profit:  12825 / Loss:  4101 / Transaction Costs:  190 / Calculated Accuracy 0.68 / #Correct Predictions: 324 Of 474
# einsatz/bet 1294.8354526222504 Total Return / bet 18.00210970464135 / Transaction Costs / bet  0.4008438818565401 / Calculated Accuracy 0.68
# profit in % per bet: 1.39
# einsatz * 1+profit% ^ # wetten 695503.58
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.56      0.66        34
#          1.0       0.83      0.94      0.88        77
#
#     accuracy                           0.82       111
#    macro avg       0.81      0.75      0.77       111
# weighted avg       0.82      0.82      0.81       111
#
# 366.90%
# Specified Period:
# Total Return in Specified Period: 2653 / Profit:  3494 / Loss:  840 / Transaction Costs:  0 / Calculated Accuracy 0.8 / #Correct Predictions: 8 of 10
#
# Entire Period:
# einsatz 613752 Total Return: 3618 / Profit:  4353 / Loss:  684 / Transaction Costs:  50 / Calculated Accuracy 0.82 / #Correct Predictions: 91 Of 111
# einsatz/bet 5529.297338224745 Total Return / bet 32.5945945945946 / Transaction Costs / bet  0.45045045045045046 / Calculated Accuracy 0.82
# profit in % per bet: 0.59
# einsatz * 1+profit% ^ # wetten 1920.17
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         8
#          1.0       0.69      1.00      0.82         9
#
#     accuracy                           0.76        17
#    macro avg       0.85      0.75      0.74        17
# weighted avg       0.84      0.76      0.75        17
#
# 79.20%
# Specified Period:
# Total Return in Specified Period: -153 / Profit:  0 / Loss:  153 / Transaction Costs:  0 / Calculated Accuracy 0.0 / #Correct Predictions: 0 of 1
#
# Entire Period:
# einsatz 613752 Total Return: 783 / Profit:  906 / Loss:  114 / Transaction Costs:  8 / Calculated Accuracy 0.76 / #Correct Predictions: 13 Of 17
# einsatz/bet 36103.05909076157 Total Return / bet 46.05882352941177 / Transaction Costs / bet  0.47058823529411764 / Calculated Accuracy 0.76
# profit in % per bet: 0.13
# einsatz * 1+profit% ^ # wetten 1021.91
#
#
#
#
# Run: 3
# [[205 259]
#  [141 410]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.44      0.51       464
#          1.0       0.61      0.74      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.60      0.59      0.59      1015
# weighted avg       0.60      0.61      0.60      1015
#
# 1069.87%
# Specified Period:
# Total Return in Specified Period: 4591 / Profit:  13733 / Loss:  9120 / Transaction Costs:  21 / Calculated Accuracy 0.5153846153846153 / #Correct Predictions: 67 of 130
#
# Entire Period:
# einsatz 616685 Total Return: 10328 / Profit:  19069 / Loss:  8371 / Transaction Costs:  370 / Calculated Accuracy 0.61 / #Correct Predictions: 615 Of 1015
# einsatz/bet 607.5722347418041 Total Return / bet 10.17536945812808 / Transaction Costs / bet  0.3645320197044335 / Calculated Accuracy 0.61
# profit in % per bet: 1.67
# einsatz * 1+profit% ^ # wetten 20957914746.08
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.41      0.51       199
#          1.0       0.69      0.87      0.77       295
#
#     accuracy                           0.68       494
#    macro avg       0.68      0.64      0.64       494
# weighted avg       0.68      0.68      0.66       494
#
# 748.12%
# Specified Period:
# Total Return in Specified Period: 5127 / Profit:  6384 / Loss:  1253 / Transaction Costs:  3 / Calculated Accuracy 0.7692307692307693 / #Correct Predictions: 30 of 39
#
# Entire Period:
# einsatz 616685 Total Return: 7282 / Profit:  11170 / Loss:  3689 / Transaction Costs:  198 / Calculated Accuracy 0.68 / #Correct Predictions: 338 Of 494
# einsatz/bet 1248.3518588318445 Total Return / bet 14.740890688259109 / Transaction Costs / bet  0.4008097165991903 / Calculated Accuracy 0.68
# profit in % per bet: 1.18
# einsatz * 1+profit% ^ # wetten 330008.84
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.56      0.67        41
#          1.0       0.84      0.95      0.89        97
#
#     accuracy                           0.83       138
#    macro avg       0.83      0.75      0.78       138
# weighted avg       0.83      0.83      0.82       138
#
# 464.07%
# Specified Period:
# Total Return in Specified Period: 1279 / Profit:  1279 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 5 of 5
#
# Entire Period:
# einsatz 616685 Total Return: 4579 / Profit:  5010 / Loss:  370 / Transaction Costs:  61 / Calculated Accuracy 0.83 / #Correct Predictions: 115 Of 138
# einsatz/bet 4468.7378134995015 Total Return / bet 33.18115942028985 / Transaction Costs / bet  0.4420289855072464 / Calculated Accuracy 0.83
# profit in % per bet: 0.74
# einsatz * 1+profit% ^ # wetten 2775.66
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.86      0.86         7
#          1.0       0.67      0.67      0.67         3
#
#     accuracy                           0.80        10
#    macro avg       0.76      0.76      0.76        10
# weighted avg       0.80      0.80      0.80        10
#
# 73.31%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 616685 Total Return: 727 / Profit:  770 / Loss:  37 / Transaction Costs:  5 / Calculated Accuracy 0.8 / #Correct Predictions: 8 Of 10
# einsatz/bet 61668.58182629312 Total Return / bet 72.7 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.8
# profit in % per bet: 0.12
# einsatz * 1+profit% ^ # wetten 1011.85
#
#
#
#
# Run: 4
# [[221 243]
#  [149 402]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.53       464
#          1.0       0.62      0.73      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.61      1015
#
# 1058.67%
# Specified Period:
# Total Return in Specified Period: 12994 / Profit:  19313 / Loss:  6302 / Transaction Costs:  16 / Calculated Accuracy 0.6444444444444445 / #Correct Predictions: 87 of 135
#
# Entire Period:
# einsatz 613268 Total Return: 10218 / Profit:  18513 / Loss:  7927 / Transaction Costs:  367 / Calculated Accuracy 0.61 / #Correct Predictions: 623 Of 1015
# einsatz/bet 604.2050653096189 Total Return / bet 10.066995073891626 / Transaction Costs / bet  0.361576354679803 / Calculated Accuracy 0.61
# profit in % per bet: 1.67
# einsatz * 1+profit% ^ # wetten 19232974219.92
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.49      0.58       176
#          1.0       0.73      0.87      0.80       282
#
#     accuracy                           0.72       458
#    macro avg       0.72      0.68      0.69       458
# weighted avg       0.72      0.72      0.71       458
#
# 922.09%
# Specified Period:
# Total Return in Specified Period: 7714 / Profit:  8564 / Loss:  846 / Transaction Costs:  2 / Calculated Accuracy 0.7142857142857143 / #Correct Predictions: 20 of 28
#
# Entire Period:
# einsatz 613268 Total Return: 9036 / Profit:  11636 / Loss:  2415 / Transaction Costs:  184 / Calculated Accuracy 0.72 / #Correct Predictions: 332 Of 458
# einsatz/bet 1339.0134089285225 Total Return / bet 19.729257641921397 / Transaction Costs / bet  0.4017467248908297 / Calculated Accuracy 0.72
# profit in % per bet: 1.47
# einsatz * 1+profit% ^ # wetten 811610.14
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.62      0.71        26
#          1.0       0.89      0.97      0.93        86
#
#     accuracy                           0.88       112
#    macro avg       0.87      0.79      0.82       112
# weighted avg       0.88      0.88      0.88       112
#
# 436.77%
# Specified Period:
# Total Return in Specified Period: 492 / Profit:  492 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 2 of 2
#
# Entire Period:
# einsatz 613268 Total Return: 4317 / Profit:  4615 / Loss:  247 / Transaction Costs:  50 / Calculated Accuracy 0.88 / #Correct Predictions: 99 Of 112
# einsatz/bet 5475.608404368422 Total Return / bet 38.544642857142854 / Transaction Costs / bet  0.44642857142857145 / Calculated Accuracy 0.88
# profit in % per bet: 0.70
# einsatz * 1+profit% ^ # wetten 2193.82
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.67      0.73         6
#          1.0       0.86      0.92      0.89        13
#
#     accuracy                           0.84        19
#    macro avg       0.83      0.79      0.81        19
# weighted avg       0.84      0.84      0.84        19
#
# 99.25%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 613268 Total Return: 982 / Profit:  1060 / Loss:  67 / Transaction Costs:  9 / Calculated Accuracy 0.84 / #Correct Predictions: 16 Of 19
# einsatz/bet 32277.27059417175 Total Return / bet 51.68421052631579 / Transaction Costs / bet  0.47368421052631576 / Calculated Accuracy 0.84
# profit in % per bet: 0.16
# einsatz * 1+profit% ^ # wetten 1030.87
#
#
#
#
# Run: 5
# [[229 235]
#  [167 384]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.49      0.53       464
#          1.0       0.62      0.70      0.66       551
#
#     accuracy                           0.60      1015
#    macro avg       0.60      0.60      0.59      1015
# weighted avg       0.60      0.60      0.60      1015
#
# 901.71%
# Specified Period:
# Total Return in Specified Period: 4984 / Profit:  13411 / Loss:  8409 / Transaction Costs:  17 / Calculated Accuracy 0.6015625 / #Correct Predictions: 77 of 128
#
# Entire Period:
# einsatz 619285 Total Return: 8645 / Profit:  18306 / Loss:  9289 / Transaction Costs:  371 / Calculated Accuracy 0.6 / #Correct Predictions: 613 Of 1015
# einsatz/bet 610.1339814156852 Total Return / bet 8.517241379310345 / Transaction Costs / bet  0.36551724137931035 / Calculated Accuracy 0.6
# profit in % per bet: 1.40
# einsatz * 1+profit% ^ # wetten 1291135723.15
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.47      0.54       210
#          1.0       0.67      0.80      0.73       279
#
#     accuracy                           0.66       489
#    macro avg       0.65      0.63      0.63       489
# weighted avg       0.66      0.66      0.65       489
#
# 713.09%
# Specified Period:
# Total Return in Specified Period: 2388 / Profit:  6210 / Loss:  3814 / Transaction Costs:  6 / Calculated Accuracy 0.6170212765957447 / #Correct Predictions: 29 of 47
#
# Entire Period:
# einsatz 619285 Total Return: 6932 / Profit:  11618 / Loss:  4487 / Transaction Costs:  198 / Calculated Accuracy 0.66 / #Correct Predictions: 322 Of 489
# einsatz/bet 1266.4335197074038 Total Return / bet 14.175869120654397 / Transaction Costs / bet  0.4049079754601227 / Calculated Accuracy 0.66
# profit in % per bet: 1.12
# einsatz * 1+profit% ^ # wetten 231187.97
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.44      0.55        57
#          1.0       0.74      0.91      0.82       102
#
#     accuracy                           0.74       159
#    macro avg       0.74      0.68      0.68       159
# weighted avg       0.74      0.74      0.72       159
#
# 340.32%
# Specified Period:
# Total Return in Specified Period: 1068 / Profit:  2219 / Loss:  1150 / Transaction Costs:  0 / Calculated Accuracy 0.8181818181818182 / #Correct Predictions: 9 of 11
#
# Entire Period:
# einsatz 619285 Total Return: 3331 / Profit:  4607 / Loss:  1204 / Transaction Costs:  71 / Calculated Accuracy 0.74 / #Correct Predictions: 118 Of 159
# einsatz/bet 3894.8804474020153 Total Return / bet 20.949685534591193 / Transaction Costs / bet  0.44654088050314467 / Calculated Accuracy 0.74
# profit in % per bet: 0.54
# einsatz * 1+profit% ^ # wetten 2346.52
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.83      0.71         6
#          1.0       0.89      0.73      0.80        11
#
#     accuracy                           0.76        17
#    macro avg       0.76      0.78      0.76        17
# weighted avg       0.80      0.76      0.77        17
#
# 73.96%
# Specified Period:
# Total Return in Specified Period: -192 / Profit:  2 / Loss:  195 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 619285 Total Return: 731 / Profit:  822 / Loss:  83 / Transaction Costs:  8 / Calculated Accuracy 0.76 / #Correct Predictions: 13 Of 17
# einsatz/bet 36428.5877139365 Total Return / bet 43.0 / Transaction Costs / bet  0.47058823529411764 / Calculated Accuracy 0.76
# profit in % per bet: 0.12
# einsatz * 1+profit% ^ # wetten 1020.26
#
#
#
#
# Run: 6
# [[201 263]
#  [157 394]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.43      0.49       464
#          1.0       0.60      0.72      0.65       551
#
#     accuracy                           0.59      1015
#    macro avg       0.58      0.57      0.57      1015
# weighted avg       0.58      0.59      0.58      1015
#
# 914.29%
# Specified Period:
# Total Return in Specified Period: 2745 / Profit:  12997 / Loss:  10229 / Transaction Costs:  21 / Calculated Accuracy 0.5367647058823529 / #Correct Predictions: 73 of 136
#
# Entire Period:
# einsatz 620589 Total Return: 8770 / Profit:  19295 / Loss:  10152 / Transaction Costs:  372 / Calculated Accuracy 0.59 / #Correct Predictions: 595 Of 1015
# einsatz/bet 611.4183464616788 Total Return / bet 8.64039408866995 / Transaction Costs / bet  0.3665024630541872 / Calculated Accuracy 0.59
# profit in % per bet: 1.41
# einsatz * 1+profit% ^ # wetten 1533850918.72
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.42      0.49       201
#          1.0       0.68      0.81      0.74       313
#
#     accuracy                           0.66       514
#    macro avg       0.63      0.61      0.62       514
# weighted avg       0.64      0.66      0.64       514
#
# 808.67%
# Specified Period:
# Total Return in Specified Period: 3542 / Profit:  7301 / Loss:  3750 / Transaction Costs:  8 / Calculated Accuracy 0.5416666666666666 / #Correct Predictions: 26 of 48
#
# Entire Period:
# einsatz 620589 Total Return: 7879 / Profit:  12651 / Loss:  4564 / Transaction Costs:  206 / Calculated Accuracy 0.66 / #Correct Predictions: 337 Of 514
# einsatz/bet 1207.372804783276 Total Return / bet 15.328793774319067 / Transaction Costs / bet  0.40077821011673154 / Calculated Accuracy 0.66
# profit in % per bet: 1.27
# einsatz * 1+profit% ^ # wetten 655016.96
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.59      0.65        46
#          1.0       0.80      0.88      0.84        84
#
#     accuracy                           0.78       130
#    macro avg       0.76      0.73      0.74       130
# weighted avg       0.77      0.78      0.77       130
#
# 385.52%
# Specified Period:
# Total Return in Specified Period: 1518 / Profit:  1556 / Loss:  37 / Transaction Costs:  0 / Calculated Accuracy 0.875 / #Correct Predictions: 7 of 8
#
# Entire Period:
# einsatz 620589 Total Return: 3796 / Profit:  5055 / Loss:  1199 / Transaction Costs:  59 / Calculated Accuracy 0.78 / #Correct Predictions: 101 Of 130
# einsatz/bet 4773.766320450799 Total Return / bet 29.2 / Transaction Costs / bet  0.45384615384615384 / Calculated Accuracy 0.78
# profit in % per bet: 0.61
# einsatz * 1+profit% ^ # wetten 2209.48
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.78      0.74         9
#          1.0       0.86      0.80      0.83        15
#
#     accuracy                           0.79        24
#    macro avg       0.78      0.79      0.78        24
# weighted avg       0.80      0.79      0.79        24
#
# 99.67%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 620589 Total Return: 984 / Profit:  1318 / Loss:  322 / Transaction Costs:  12 / Calculated Accuracy 0.79 / #Correct Predictions: 19 Of 24
# einsatz/bet 25857.90090244183 Total Return / bet 41.0 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.79
# profit in % per bet: 0.16
# einsatz * 1+profit% ^ # wetten 1038.76
#
#
#
#
# Run: 7
# [[232 232]
#  [148 403]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.50      0.55       464
#          1.0       0.63      0.73      0.68       551
#
#     accuracy                           0.63      1015
#    macro avg       0.62      0.62      0.61      1015
# weighted avg       0.62      0.63      0.62      1015
#
# 1365.44%
# Specified Period:
# Total Return in Specified Period: 10233 / Profit:  17986 / Loss:  7732 / Transaction Costs:  19 / Calculated Accuracy 0.6 / #Correct Predictions: 87 of 145
#
# Entire Period:
# einsatz 612693 Total Return: 13286 / Profit:  21248 / Loss:  7594 / Transaction Costs:  367 / Calculated Accuracy 0.63 / #Correct Predictions: 635 Of 1015
# einsatz/bet 603.6384374113372 Total Return / bet 13.089655172413794 / Transaction Costs / bet  0.361576354679803 / Calculated Accuracy 0.63
# profit in % per bet: 2.17
# einsatz * 1+profit% ^ # wetten 2861527286669.71
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.47      0.56       198
#          1.0       0.70      0.86      0.77       287
#
#     accuracy                           0.70       485
#    macro avg       0.70      0.66      0.67       485
# weighted avg       0.70      0.70      0.69       485
#
# 1044.67%
# Specified Period:
# Total Return in Specified Period: 9356 / Profit:  11259 / Loss:  1895 / Transaction Costs:  7 / Calculated Accuracy 0.6666666666666666 / #Correct Predictions: 38 of 57
#
# Entire Period:
# einsatz 612693 Total Return: 10253 / Profit:  13116 / Loss:  2670 / Transaction Costs:  193 / Calculated Accuracy 0.7 / #Correct Predictions: 339 Of 485
# einsatz/bet 1263.2845648917678 Total Return / bet 21.14020618556701 / Transaction Costs / bet  0.3979381443298969 / Calculated Accuracy 0.7
# profit in % per bet: 1.67
# einsatz * 1+profit% ^ # wetten 3130611.38
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.56      0.67        32
#          1.0       0.84      0.95      0.89        77
#
#     accuracy                           0.83       109
#    macro avg       0.83      0.76      0.78       109
# weighted avg       0.83      0.83      0.82       109
#
# 443.85%
# Specified Period:
# Total Return in Specified Period: 1821 / Profit:  1941 / Loss:  118 / Transaction Costs:  0 / Calculated Accuracy 0.75 / #Correct Predictions: 6 of 8
#
# Entire Period:
# einsatz 612693 Total Return: 4390 / Profit:  4725 / Loss:  286 / Transaction Costs:  48 / Calculated Accuracy 0.83 / #Correct Predictions: 91 Of 109
# einsatz/bet 5621.036825435847 Total Return / bet 40.27522935779817 / Transaction Costs / bet  0.44036697247706424 / Calculated Accuracy 0.83
# profit in % per bet: 0.72
# einsatz * 1+profit% ^ # wetten 2177.57
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.80      0.73         5
#          1.0       0.67      0.50      0.57         4
#
#     accuracy                           0.67         9
#    macro avg       0.67      0.65      0.65         9
# weighted avg       0.67      0.67      0.66         9
#
# 32.41%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 612693 Total Return: 319 / Profit:  467 / Loss:  143 / Transaction Costs:  4 / Calculated Accuracy 0.67 / #Correct Predictions: 6 Of 9
# einsatz/bet 68077.00155250082 Total Return / bet 35.44444444444444 / Transaction Costs / bet  0.4444444444444444 / Calculated Accuracy 0.67
# profit in % per bet: 0.05
# einsatz * 1+profit% ^ # wetten 1004.70
#
#
#
#
# Run: 8
# [[226 238]
#  [156 395]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.49      0.53       464
#          1.0       0.62      0.72      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.61      1015
#
# 1126.50%
# Specified Period:
# Total Return in Specified Period: 8052 / Profit:  17312 / Loss:  9240 / Transaction Costs:  19 / Calculated Accuracy 0.5746268656716418 / #Correct Predictions: 77 of 134
#
# Entire Period:
# einsatz 624725 Total Return: 10890 / Profit:  19974 / Loss:  8709 / Transaction Costs:  374 / Calculated Accuracy 0.61 / #Correct Predictions: 621 Of 1015
# einsatz/bet 615.4931776901385 Total Return / bet 10.729064039408867 / Transaction Costs / bet  0.36847290640394087 / Calculated Accuracy 0.61
# profit in % per bet: 1.74
# einsatz * 1+profit% ^ # wetten 41478568370.39
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.45      0.53       231
#          1.0       0.67      0.80      0.73       315
#
#     accuracy                           0.66       546
#    macro avg       0.65      0.63      0.63       546
# weighted avg       0.65      0.66      0.64       546
#
# 896.06%
# Specified Period:
# Total Return in Specified Period: 7949 / Profit:  11273 / Loss:  3316 / Transaction Costs:  7 / Calculated Accuracy 0.6610169491525424 / #Correct Predictions: 39 of 59
#
# Entire Period:
# einsatz 624725 Total Return: 8739 / Profit:  13238 / Loss:  4277 / Transaction Costs:  220 / Calculated Accuracy 0.66 / #Correct Predictions: 358 Of 546
# einsatz/bet 1144.1860354496164 Total Return / bet 16.005494505494507 / Transaction Costs / bet  0.40293040293040294 / Calculated Accuracy 0.66
# profit in % per bet: 1.40
# einsatz * 1+profit% ^ # wetten 1968085.53
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.49      0.59        45
#          1.0       0.81      0.92      0.86       103
#
#     accuracy                           0.79       148
#    macro avg       0.77      0.71      0.72       148
# weighted avg       0.78      0.79      0.78       148
#
# 524.76%
# Specified Period:
# Total Return in Specified Period: 4311 / Profit:  4506 / Loss:  195 / Transaction Costs:  0 / Calculated Accuracy 0.9090909090909091 / #Correct Predictions: 10 of 11
#
# Entire Period:
# einsatz 624725 Total Return: 5181 / Profit:  6127 / Loss:  880 / Transaction Costs:  66 / Calculated Accuracy 0.79 / #Correct Predictions: 117 Of 148
# einsatz/bet 4221.118752401963 Total Return / bet 35.00675675675676 / Transaction Costs / bet  0.44594594594594594 / Calculated Accuracy 0.79
# profit in % per bet: 0.83
# einsatz * 1+profit% ^ # wetten 3395.12
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.75      1.00      0.86         3
#          1.0       1.00      0.90      0.95        10
#
#     accuracy                           0.92        13
#    macro avg       0.88      0.95      0.90        13
# weighted avg       0.94      0.92      0.93        13
#
# 78.76%
# Specified Period:
# Total Return in Specified Period: -192 / Profit:  2 / Loss:  195 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 624725 Total Return: 780 / Profit:  826 / Loss:  38 / Transaction Costs:  6 / Calculated Accuracy 0.92 / #Correct Predictions: 12 Of 13
# einsatz/bet 48055.81348888389 Total Return / bet 60.0 / Transaction Costs / bet  0.46153846153846156 / Calculated Accuracy 0.92
# profit in % per bet: 0.12
# einsatz * 1+profit% ^ # wetten 1016.35
#
#
#
#
# Run: 9
# [[203 261]
#  [121 430]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.44      0.52       464
#          1.0       0.62      0.78      0.69       551
#
#     accuracy                           0.62      1015
#    macro avg       0.62      0.61      0.60      1015
# weighted avg       0.62      0.62      0.61      1015
#
# 1137.19%
# Specified Period:
# Total Return in Specified Period: 8938 / Profit:  15749 / Loss:  6794 / Transaction Costs:  17 / Calculated Accuracy 0.5726495726495726 / #Correct Predictions: 67 of 117
#
# Entire Period:
# einsatz 617908 Total Return: 11001 / Profit:  20202 / Loss:  8831 / Transaction Costs:  370 / Calculated Accuracy 0.62 / #Correct Predictions: 633 Of 1015
# einsatz/bet 608.7769152411519 Total Return / bet 10.838423645320198 / Transaction Costs / bet  0.3645320197044335 / Calculated Accuracy 0.62
# profit in % per bet: 1.78
# einsatz * 1+profit% ^ # wetten 60109690988.74
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.40      0.48       175
#          1.0       0.71      0.85      0.78       308
#
#     accuracy                           0.69       483
#    macro avg       0.66      0.63      0.63       483
# weighted avg       0.68      0.69      0.67       483
#
# 877.18%
# Specified Period:
# Total Return in Specified Period: 5802 / Profit:  8728 / Loss:  2919 / Transaction Costs:  6 / Calculated Accuracy 0.6097560975609756 / #Correct Predictions: 25 of 41
#
# Entire Period:
# einsatz 617908 Total Return: 8576 / Profit:  12430 / Loss:  3658 / Transaction Costs:  195 / Calculated Accuracy 0.69 / #Correct Predictions: 333 Of 483
# einsatz/bet 1279.3138073908265 Total Return / bet 17.755693581780537 / Transaction Costs / bet  0.40372670807453415 / Calculated Accuracy 0.69
# profit in % per bet: 1.39
# einsatz * 1+profit% ^ # wetten 778601.90
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.56      0.61        41
#          1.0       0.82      0.88      0.85        94
#
#     accuracy                           0.79       135
#    macro avg       0.75      0.72      0.73       135
# weighted avg       0.78      0.79      0.78       135
#
# 445.50%
# Specified Period:
# Total Return in Specified Period: 4622 / Profit:  4802 / Loss:  179 / Transaction Costs:  0 / Calculated Accuracy 0.8571428571428571 / #Correct Predictions: 6 of 7
#
# Entire Period:
# einsatz 617908 Total Return: 4394 / Profit:  5294 / Loss:  839 / Transaction Costs:  60 / Calculated Accuracy 0.79 / #Correct Predictions: 106 Of 135
# einsatz/bet 4577.100510887179 Total Return / bet 32.54814814814815 / Transaction Costs / bet  0.4444444444444444 / Calculated Accuracy 0.79
# profit in % per bet: 0.71
# einsatz * 1+profit% ^ # wetten 2602.83
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80         5
#          1.0       0.86      0.86      0.86         7
#
#     accuracy                           0.83        12
#    macro avg       0.83      0.83      0.83        12
# weighted avg       0.83      0.83      0.83        12
#
# 106.29%
# Specified Period:
# Total Return in Specified Period: 3055 / Profit:  3055 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 2 of 2
#
# Entire Period:
# einsatz 617908 Total Return: 1056 / Profit:  1085 / Loss:  22 / Transaction Costs:  6 / Calculated Accuracy 0.83 / #Correct Predictions: 10 Of 12
# einsatz/bet 51492.38074748076 Total Return / bet 88.0 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.83
# profit in % per bet: 0.17
# einsatz * 1+profit% ^ # wetten 1020.70
#
#
#
#
# Run: 10
# [[223 241]
#  [167 384]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.48      0.52       464
#          1.0       0.61      0.70      0.65       551
#
#     accuracy                           0.60      1015
#    macro avg       0.59      0.59      0.59      1015
# weighted avg       0.59      0.60      0.59      1015
#
# 1075.26%
# Specified Period:
# Total Return in Specified Period: 13744 / Profit:  22461 / Loss:  8694 / Transaction Costs:  21 / Calculated Accuracy 0.5547445255474452 / #Correct Predictions: 76 of 137
#
# Entire Period:
# einsatz 626299 Total Return: 10376 / Profit:  19539 / Loss:  8786 / Transaction Costs:  375 / Calculated Accuracy 0.6 / #Correct Predictions: 607 Of 1015
# einsatz/bet 617.0433544940156 Total Return / bet 10.222660098522168 / Transaction Costs / bet  0.3694581280788177 / Calculated Accuracy 0.6
# profit in % per bet: 1.66
# einsatz * 1+profit% ^ # wetten 17503295588.26
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.44      0.52       229
#          1.0       0.66      0.83      0.74       307
#
#     accuracy                           0.66       536
#    macro avg       0.66      0.63      0.63       536
# weighted avg       0.66      0.66      0.65       536
#
# 910.27%
# Specified Period:
# Total Return in Specified Period: 11417 / Profit:  16107 / Loss:  4678 / Transaction Costs:  11 / Calculated Accuracy 0.5915492957746479 / #Correct Predictions: 42 of 71
#
# Entire Period:
# einsatz 626299 Total Return: 8884 / Profit:  13064 / Loss:  3961 / Transaction Costs:  218 / Calculated Accuracy 0.66 / #Correct Predictions: 355 Of 536
# einsatz/bet 1168.4682925586303 Total Return / bet 16.574626865671643 / Transaction Costs / bet  0.40671641791044777 / Calculated Accuracy 0.66
# profit in % per bet: 1.42
# einsatz * 1+profit% ^ # wetten 1900164.65
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.51      0.58        51
#          1.0       0.80      0.90      0.85       115
#
#     accuracy                           0.78       166
#    macro avg       0.74      0.70      0.72       166
# weighted avg       0.77      0.78      0.77       166
#
# 551.88%
# Specified Period:
# Total Return in Specified Period: 7428 / Profit:  8250 / Loss:  821 / Transaction Costs:  0 / Calculated Accuracy 0.875 / #Correct Predictions: 14 of 16
#
# Entire Period:
# einsatz 626299 Total Return: 5444 / Profit:  6443 / Loss:  924 / Transaction Costs:  74 / Calculated Accuracy 0.78 / #Correct Predictions: 129 Of 166
# einsatz/bet 3772.8855711531673 Total Return / bet 32.795180722891565 / Transaction Costs / bet  0.4457831325301205 / Calculated Accuracy 0.78
# profit in % per bet: 0.87
# einsatz * 1+profit% ^ # wetten 4206.76
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89         8
#          1.0       1.00      0.75      0.86         8
#
#     accuracy                           0.88        16
#    macro avg       0.90      0.88      0.87        16
# weighted avg       0.90      0.88      0.87        16
#
# 132.17%
# Specified Period:
# Total Return in Specified Period: 3431 / Profit:  3431 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 3 of 3
#
# Entire Period:
# einsatz 626299 Total Return: 1313 / Profit:  1351 / Loss:  30 / Transaction Costs:  8 / Calculated Accuracy 0.88 / #Correct Predictions: 14 Of 16
# einsatz/bet 39143.68780071411 Total Return / bet 82.0625 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.88
# profit in % per bet: 0.21
# einsatz * 1+profit% ^ # wetten 1034.08
#
#
#
#
# Run: 11
# [[205 259]
#  [149 402]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.44      0.50       464
#          1.0       0.61      0.73      0.66       551
#
#     accuracy                           0.60      1015
#    macro avg       0.59      0.59      0.58      1015
# weighted avg       0.59      0.60      0.59      1015
#
# 883.14%
# Specified Period:
# Total Return in Specified Period: 9277 / Profit:  17435 / Loss:  8138 / Transaction Costs:  19 / Calculated Accuracy 0.5447154471544715 / #Correct Predictions: 67 of 123
#
# Entire Period:
# einsatz 625069 Total Return: 8456 / Profit:  18770 / Loss:  9938 / Transaction Costs:  375 / Calculated Accuracy 0.6 / #Correct Predictions: 607 Of 1015
# einsatz/bet 615.8320347826643 Total Return / bet 8.331034482758621 / Transaction Costs / bet  0.3694581280788177 / Calculated Accuracy 0.6
# profit in % per bet: 1.35
# einsatz * 1+profit% ^ # wetten 838163736.32
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.44      0.54       232
#          1.0       0.65      0.85      0.74       290
#
#     accuracy                           0.66       522
#    macro avg       0.67      0.64      0.64       522
# weighted avg       0.67      0.66      0.65       522
#
# 789.06%
# Specified Period:
# Total Return in Specified Period: 6416 / Profit:  9370 / Loss:  2945 / Transaction Costs:  7 / Calculated Accuracy 0.5918367346938775 / #Correct Predictions: 29 of 49
#
# Entire Period:
# einsatz 625069 Total Return: 7677 / Profit:  12489 / Loss:  4598 / Transaction Costs:  213 / Calculated Accuracy 0.66 / #Correct Predictions: 347 Of 522
# einsatz/bet 1197.4511787440695 Total Return / bet 14.706896551724139 / Transaction Costs / bet  0.40804597701149425 / Calculated Accuracy 0.66
# profit in % per bet: 1.23
# einsatz * 1+profit% ^ # wetten 585266.09
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.42      0.53        62
#          1.0       0.73      0.90      0.81       110
#
#     accuracy                           0.73       172
#    macro avg       0.72      0.66      0.67       172
# weighted avg       0.72      0.73      0.71       172
#
# 478.34%
# Specified Period:
# Total Return in Specified Period: -89 / Profit:  966 / Loss:  1054 / Transaction Costs:  1 / Calculated Accuracy 0.5555555555555556 / #Correct Predictions: 5 of 9
#
# Entire Period:
# einsatz 625069 Total Return: 4706 / Profit:  6062 / Loss:  1279 / Transaction Costs:  77 / Calculated Accuracy 0.73 / #Correct Predictions: 125 Of 172
# einsatz/bet 3634.125088979095 Total Return / bet 27.36046511627907 / Transaction Costs / bet  0.4476744186046512 / Calculated Accuracy 0.73
# profit in % per bet: 0.75
# einsatz * 1+profit% ^ # wetten 3633.14
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.73      0.73        11
#          1.0       0.75      0.75      0.75        12
#
#     accuracy                           0.74        23
#    macro avg       0.74      0.74      0.74        23
# weighted avg       0.74      0.74      0.74        23
#
# 165.32%
# Specified Period:
# Total Return in Specified Period: -195 / Profit:  0 / Loss:  195 / Transaction Costs:  0 / Calculated Accuracy 0.0 / #Correct Predictions: 0 of 1
#
# Entire Period:
# einsatz 625069 Total Return: 1641 / Profit:  1797 / Loss:  143 / Transaction Costs:  11 / Calculated Accuracy 0.74 / #Correct Predictions: 17 Of 23
# einsatz/bet 27176.93544801758 Total Return / bet 71.34782608695652 / Transaction Costs / bet  0.4782608695652174 / Calculated Accuracy 0.74
# profit in % per bet: 0.26
# einsatz * 1+profit% ^ # wetten 1062.16
#
#
#
#
# Run: 12
# [[225 239]
#  [170 381]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.48      0.52       464
#          1.0       0.61      0.69      0.65       551
#
#     accuracy                           0.60      1015
#    macro avg       0.59      0.59      0.59      1015
# weighted avg       0.59      0.60      0.59      1015
#
# 1030.99%
# Specified Period:
# Total Return in Specified Period: 9108 / Profit:  14489 / Loss:  5367 / Transaction Costs:  14 / Calculated Accuracy 0.6226415094339622 / #Correct Predictions: 66 of 106
#
# Entire Period:
# einsatz 618524 Total Return: 9938 / Profit:  19473 / Loss:  9163 / Transaction Costs:  371 / Calculated Accuracy 0.6 / #Correct Predictions: 606 Of 1015
# einsatz/bet 609.3837355598934 Total Return / bet 9.791133004926108 / Transaction Costs / bet  0.36551724137931035 / Calculated Accuracy 0.6
# profit in % per bet: 1.61
# einsatz * 1+profit% ^ # wetten 10624263421.24
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.53      0.59       208
#          1.0       0.71      0.81      0.76       298
#
#     accuracy                           0.70       506
#    macro avg       0.69      0.67      0.68       506
# weighted avg       0.69      0.70      0.69       506
#
# 897.30%
# Specified Period:
# Total Return in Specified Period: 5647 / Profit:  6745 / Loss:  1093 / Transaction Costs:  4 / Calculated Accuracy 0.6842105263157895 / #Correct Predictions: 26 of 38
#
# Entire Period:
# einsatz 618524 Total Return: 8768 / Profit:  12427 / Loss:  3454 / Transaction Costs:  204 / Calculated Accuracy 0.7 / #Correct Predictions: 353 Of 506
# einsatz/bet 1222.3804181685607 Total Return / bet 17.32806324110672 / Transaction Costs / bet  0.4031620553359684 / Calculated Accuracy 0.7
# profit in % per bet: 1.42
# einsatz * 1+profit% ^ # wetten 1239576.32
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.65      0.71        52
#          1.0       0.82      0.89      0.86        93
#
#     accuracy                           0.81       145
#    macro avg       0.80      0.77      0.78       145
# weighted avg       0.80      0.81      0.80       145
#
# 466.17%
# Specified Period:
# Total Return in Specified Period: 1114 / Profit:  1375 / Loss:  259 / Transaction Costs:  0 / Calculated Accuracy 0.75 / #Correct Predictions: 6 of 8
#
# Entire Period:
# einsatz 618524 Total Return: 4596 / Profit:  5202 / Loss:  540 / Transaction Costs:  64 / Calculated Accuracy 0.81 / #Correct Predictions: 117 Of 145
# einsatz/bet 4265.686148919253 Total Return / bet 31.69655172413793 / Transaction Costs / bet  0.4413793103448276 / Calculated Accuracy 0.81
# profit in % per bet: 0.74
# einsatz * 1+profit% ^ # wetten 2925.46
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.78      0.74         9
#          1.0       0.67      0.57      0.62         7
#
#     accuracy                           0.69        16
#    macro avg       0.68      0.67      0.68        16
# weighted avg       0.69      0.69      0.68        16
#
# 107.98%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 618524 Total Return: 1071 / Profit:  1214 / Loss:  134 / Transaction Costs:  8 / Calculated Accuracy 0.69 / #Correct Predictions: 11 Of 16
# einsatz/bet 38657.780724580734 Total Return / bet 66.9375 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.69
# profit in % per bet: 0.17
# einsatz * 1+profit% ^ # wetten 1028.07
#
#
#
#
# Run: 13
# [[234 230]
#  [156 395]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.50      0.55       464
#          1.0       0.63      0.72      0.67       551
#
#     accuracy                           0.62      1015
#    macro avg       0.62      0.61      0.61      1015
# weighted avg       0.62      0.62      0.62      1015
#
# 1119.42%
# Specified Period:
# Total Return in Specified Period: 10136 / Profit:  17965 / Loss:  7809 / Transaction Costs:  19 / Calculated Accuracy 0.5944055944055944 / #Correct Predictions: 85 of 143
#
# Entire Period:
# einsatz 611255 Total Return: 10827 / Profit:  20635 / Loss:  9440 / Transaction Costs:  366 / Calculated Accuracy 0.62 / #Correct Predictions: 629 Of 1015
# einsatz/bet 602.2226259515193 Total Return / bet 10.666995073891625 / Transaction Costs / bet  0.3605911330049261 / Calculated Accuracy 0.62
# profit in % per bet: 1.77
# einsatz * 1+profit% ^ # wetten 54900536348.37
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.48      0.59       177
#          1.0       0.73      0.90      0.81       276
#
#     accuracy                           0.74       453
#    macro avg       0.74      0.69      0.70       453
# weighted avg       0.74      0.74      0.72       453
#
# 948.37%
# Specified Period:
# Total Return in Specified Period: 8219 / Profit:  9744 / Loss:  1519 / Transaction Costs:  5 / Calculated Accuracy 0.7592592592592593 / #Correct Predictions: 41 of 54
#
# Entire Period:
# einsatz 611255 Total Return: 9302 / Profit:  12245 / Loss:  2761 / Transaction Costs:  181 / Calculated Accuracy 0.74 / #Correct Predictions: 333 Of 453
# einsatz/bet 1349.3509168670907 Total Return / bet 20.53421633554084 / Transaction Costs / bet  0.3995584988962472 / Calculated Accuracy 0.74
# profit in % per bet: 1.52
# einsatz * 1+profit% ^ # wetten 936132.94
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.79      0.80        33
#          1.0       0.91      0.92      0.91        75
#
#     accuracy                           0.88       108
#    macro avg       0.86      0.85      0.86       108
# weighted avg       0.88      0.88      0.88       108
#
# 467.35%
# Specified Period:
# Total Return in Specified Period: 856 / Profit:  856 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 4 of 4
#
# Entire Period:
# einsatz 611255 Total Return: 4625 / Profit:  4963 / Loss:  289 / Transaction Costs:  48 / Calculated Accuracy 0.88 / #Correct Predictions: 95 Of 108
# einsatz/bet 5659.777456859186 Total Return / bet 42.824074074074076 / Transaction Costs / bet  0.4444444444444444 / Calculated Accuracy 0.88
# profit in % per bet: 0.76
# einsatz * 1+profit% ^ # wetten 2257.13
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.86      0.86         7
#          1.0       0.89      0.89      0.89         9
#
#     accuracy                           0.88        16
#    macro avg       0.87      0.87      0.87        16
# weighted avg       0.88      0.88      0.88        16
#
# 88.74%
# Specified Period:
# Total Return in Specified Period: 2 / Profit:  2 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 1 of 1
#
# Entire Period:
# einsatz 611255 Total Return: 879 / Profit:  909 / Loss:  22 / Transaction Costs:  8 / Calculated Accuracy 0.88 / #Correct Predictions: 14 Of 16
# einsatz/bet 38203.497833799505 Total Return / bet 54.9375 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.88
# profit in % per bet: 0.14
# einsatz * 1+profit% ^ # wetten 1023.26
#
#
#
#
# Run: 14
# [[233 231]
#  [158 393]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.50      0.55       464
#          1.0       0.63      0.71      0.67       551
#
#     accuracy                           0.62      1015
#    macro avg       0.61      0.61      0.61      1015
# weighted avg       0.61      0.62      0.61      1015
#
# 1117.53%
# Specified Period:
# Total Return in Specified Period: 11174 / Profit:  19274 / Loss:  8080 / Transaction Costs:  19 / Calculated Accuracy 0.5703125 / #Correct Predictions: 73 of 128
#
# Entire Period:
# ...
#
# 430.47%
# Specified Period:
# Total Return in Specified Period: 1795 / Profit:  2483 / Loss:  686 / Transaction Costs:  0 / Calculated Accuracy 0.8888888888888888 / #Correct Predictions: 8 of 9
#
# Entire Period:
# einsatz 616874 Total Return: 4248 / Profit:  4858 / Loss:  553 / Transaction Costs:  56 / Calculated Accuracy 0.84 / #Correct Predictions: 105 Of 125
# einsatz/bet 4934.993596165561 Total Return / bet 33.984 / Transaction Costs / bet  0.448 / Calculated Accuracy 0.84
# profit in % per bet: 0.69
# einsatz * 1+profit% ^ # wetten 2358.06
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.71      0.77         7
#          1.0       0.87      0.93      0.90        14
#
#     accuracy                           0.86        21
#    macro avg       0.85      0.82      0.83        21
# weighted avg       0.86      0.86      0.85        21
#
# 136.74%
# Specified Period:
# Total Return in Specified Period: 2 / Profit:  2 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 1 of 1
#
# Entire Period:
# einsatz 616874 Total Return: 1356 / Profit:  1435 / Loss:  67 / Transaction Costs:  10 / Calculated Accuracy 0.86 / #Correct Predictions: 18 Of 21
# einsatz/bet 29374.961881937863 Total Return / bet 64.57142857142857 / Transaction Costs / bet  0.47619047619047616 / Calculated Accuracy 0.86
# profit in % per bet: 0.22
# einsatz * 1+profit% ^ # wetten 1047.19
#
#
#
#
# Run: 16
# [[231 233]
#  [139 412]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.55       464
#          1.0       0.64      0.75      0.69       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.62      0.62      1015
# weighted avg       0.63      0.63      0.63      1015
#
# 1169.40%
# Specified Period:
# Total Return in Specified Period: 11030 / Profit:  19153 / Loss:  8105 / Transaction Costs:  17 / Calculated Accuracy 0.6124031007751938 / #Correct Predictions: 79 of 129
#
# Entire Period:
# einsatz 616920 Total Return: 11323 / Profit:  20341 / Loss:  8647 / Transaction Costs:  370 / Calculated Accuracy 0.63 / #Correct Predictions: 643 Of 1015
# einsatz/bet 607.803297929501 Total Return / bet 11.155665024630542 / Transaction Costs / bet  0.3645320197044335 / Calculated Accuracy 0.63
# profit in % per bet: 1.84
# einsatz * 1+profit% ^ # wetten 104060531365.40
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.45      0.54       203
#          1.0       0.69      0.86      0.76       285
#
#     accuracy                           0.69       488
#    macro avg       0.69      0.65      0.65       488
# weighted avg       0.69      0.69      0.67       488
#
# 896.19%
# Specified Period:
# Total Return in Specified Period: 4668 / Profit:  6963 / Loss:  2289 / Transaction Costs:  5 / Calculated Accuracy 0.6744186046511628 / #Correct Predictions: 29 of 43
#
# Entire Period:
# einsatz 616920 Total Return: 8764 / Profit:  12745 / Loss:  3783 / Transaction Costs:  197 / Calculated Accuracy 0.69 / #Correct Predictions: 335 Of 488
# einsatz/bet 1264.181039750909 Total Return / bet 17.959016393442624 / Transaction Costs / bet  0.4036885245901639 / Calculated Accuracy 0.69
# profit in % per bet: 1.42
# einsatz * 1+profit% ^ # wetten 976300.80
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.56      0.65        41
#          1.0       0.83      0.92      0.87        93
#
#     accuracy                           0.81       134
#    macro avg       0.80      0.74      0.76       134
# weighted avg       0.81      0.81      0.80       134
#
# 463.77%
# Specified Period:
# Total Return in Specified Period: 1818 / Profit:  1818 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 6 of 6
#
# Entire Period:
# einsatz 616920 Total Return: 4577 / Profit:  5415 / Loss:  778 / Transaction Costs:  60 / Calculated Accuracy 0.81 / #Correct Predictions: 109 Of 134
# einsatz/bet 4603.883189540623 Total Return / bet 34.156716417910445 / Transaction Costs / bet  0.44776119402985076 / Calculated Accuracy 0.81
# profit in % per bet: 0.74
# einsatz * 1+profit% ^ # wetten 2692.56
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.67      0.73         6
#          1.0       0.87      0.93      0.90        14
#
#     accuracy                           0.85        20
#    macro avg       0.83      0.80      0.81        20
# weighted avg       0.85      0.85      0.85        20
#
# 105.61%
# Specified Period:
# Total Return in Specified Period: 2 / Profit:  2 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 1 of 1
#
# Entire Period:
# einsatz 616920 Total Return: 1046 / Profit:  1165 / Loss:  109 / Transaction Costs:  10 / Calculated Accuracy 0.85 / #Correct Predictions: 17 Of 20
# einsatz/bet 30846.017369922174 Total Return / bet 52.3 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.85
# profit in % per bet: 0.17
# einsatz * 1+profit% ^ # wetten 1034.46
#
#
#
#
# Run: 17
# [[216 248]
#  [135 416]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.47      0.53       464
#          1.0       0.63      0.75      0.68       551
#
#     accuracy                           0.62      1015
#    macro avg       0.62      0.61      0.61      1015
# weighted avg       0.62      0.62      0.61      1015
#
# 1007.66%
# Specified Period:
# Total Return in Specified Period: 12181 / Profit:  17877 / Loss:  5677 / Transaction Costs:  17 / Calculated Accuracy 0.6 / #Correct Predictions: 75 of 125
#
# Entire Period:
# einsatz 620633 Total Return: 9704 / Profit:  18879 / Loss:  8802 / Transaction Costs:  372 / Calculated Accuracy 0.62 / #Correct Predictions: 632 Of 1015
# einsatz/bet 611.4616179714039 Total Return / bet 9.560591133004927 / Transaction Costs / bet  0.3665024630541872 / Calculated Accuracy 0.62
# profit in % per bet: 1.56
# einsatz * 1+profit% ^ # wetten 6902391350.95
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.41      0.52       213
#          1.0       0.67      0.88      0.76       288
#
#     accuracy                           0.68       501
#    macro avg       0.69      0.64      0.64       501
# weighted avg       0.69      0.68      0.66       501
#
# 803.54%
# Specified Period:
# Total Return in Specified Period: 8356 / Profit:  9923 / Loss:  1560 / Transaction Costs:  7 / Calculated Accuracy 0.62 / #Correct Predictions: 31 of 50
#
# Entire Period:
# einsatz 620633 Total Return: 7832 / Profit:  11899 / Loss:  3863 / Transaction Costs:  203 / Calculated Accuracy 0.68 / #Correct Predictions: 340 Of 501
# einsatz/bet 1238.789505471008 Total Return / bet 15.632734530938123 / Transaction Costs / bet  0.405189620758483 / Calculated Accuracy 0.68
# profit in % per bet: 1.26
# einsatz * 1+profit% ^ # wetten 535254.13
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.43      0.55        47
#          1.0       0.77      0.94      0.85        96
#
#     accuracy                           0.77       143
#    macro avg       0.77      0.68      0.70       143
# weighted avg       0.77      0.77      0.75       143
#
# 344.50%
# Specified Period:
# Total Return in Specified Period: 2374 / Profit:  2528 / Loss:  153 / Transaction Costs:  0 / Calculated Accuracy 0.8571428571428571 / #Correct Predictions: 6 of 7
#
# Entire Period:
# einsatz 620633 Total Return: 3380 / Profit:  4570 / Loss:  1125 / Transaction Costs:  64 / Calculated Accuracy 0.77 / #Correct Predictions: 110 Of 143
# einsatz/bet 4340.094700985839 Total Return / bet 23.636363636363637 / Transaction Costs / bet  0.44755244755244755 / Calculated Accuracy 0.77
# profit in % per bet: 0.54
# einsatz * 1+profit% ^ # wetten 2174.22
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         6
#          1.0       0.84      1.00      0.91        16
#
#     accuracy                           0.86        22
#    macro avg       0.92      0.75      0.79        22
# weighted avg       0.89      0.86      0.85        22
#
# 90.68%
# Specified Period:
# Total Return in Specified Period: -151 / Profit:  2 / Loss:  153 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 620633 Total Return: 895 / Profit:  977 / Loss:  70 / Transaction Costs:  11 / Calculated Accuracy 0.86 / #Correct Predictions: 19 Of 22
# einsatz/bet 28210.615556407953 Total Return / bet 40.68181818181818 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.86
# profit in % per bet: 0.14
# einsatz * 1+profit% ^ # wetten 1032.21
#
#
#
#
# Run: 18
# [[233 231]
#  [138 413]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.50      0.56       464
#          1.0       0.64      0.75      0.69       551
#
#     accuracy                           0.64      1015
#    macro avg       0.63      0.63      0.62      1015
# weighted avg       0.64      0.64      0.63      1015
#
# 974.52%
# Specified Period:
# Total Return in Specified Period: 10290 / Profit:  19511 / Loss:  9201 / Transaction Costs:  19 / Calculated Accuracy 0.583941605839416 / #Correct Predictions: 80 of 137
#
# Entire Period:
# einsatz 618894 Total Return: 9373 / Profit:  19220 / Loss:  9475 / Transaction Costs:  371 / Calculated Accuracy 0.64 / #Correct Predictions: 646 Of 1015
# einsatz/bet 609.7480366392504 Total Return / bet 9.23448275862069 / Transaction Costs / bet  0.36551724137931035 / Calculated Accuracy 0.64
# profit in % per bet: 1.51
# einsatz * 1+profit% ^ # wetten 4225648494.52
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.43      0.54       206
#          1.0       0.68      0.89      0.77       284
#
#     accuracy                           0.70       490
#    macro avg       0.71      0.66      0.66       490
# weighted avg       0.71      0.70      0.68       490
#
# 841.87%
# Specified Period:
# Total Return in Specified Period: 8137 / Profit:  10801 / Loss:  2657 / Transaction Costs:  6 / Calculated Accuracy 0.66 / #Correct Predictions: 33 of 50
#
# Entire Period:
# einsatz 618894 Total Return: 8220 / Profit:  12497 / Loss:  4079 / Transaction Costs:  198 / Calculated Accuracy 0.7 / #Correct Predictions: 341 Of 490
# einsatz/bet 1263.0495044670186 Total Return / bet 16.775510204081634 / Transaction Costs / bet  0.40408163265306124 / Calculated Accuracy 0.7
# profit in % per bet: 1.33
# einsatz * 1+profit% ^ # wetten 642404.49
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.47      0.59        53
#          1.0       0.75      0.92      0.83        91
#
#     accuracy                           0.76       144
#    macro avg       0.77      0.70      0.71       144
# weighted avg       0.76      0.76      0.74       144
#
# 407.74%
# Specified Period:
# Total Return in Specified Period: 3843 / Profit:  4799 / Loss:  955 / Transaction Costs:  0 / Calculated Accuracy 0.8888888888888888 / #Correct Predictions: 8 of 9
#
# Entire Period:
# einsatz 618894 Total Return: 4012 / Profit:  5499 / Loss:  1421 / Transaction Costs:  64 / Calculated Accuracy 0.76 / #Correct Predictions: 109 Of 144
# einsatz/bet 4297.876786033605 Total Return / bet 27.86111111111111 / Transaction Costs / bet  0.4444444444444444 / Calculated Accuracy 0.76
# profit in % per bet: 0.65
# einsatz * 1+profit% ^ # wetten 2535.70
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.86      0.86         7
#          1.0       0.91      0.91      0.91        11
#
#     accuracy                           0.89        18
#    macro avg       0.88      0.88      0.88        18
# weighted avg       0.89      0.89      0.89        18
#
# 109.13%
# Specified Period:
# Total Return in Specified Period: 3055 / Profit:  3055 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 2 of 2
#
# Entire Period:
# einsatz 618894 Total Return: 1082 / Profit:  1230 / Loss:  139 / Transaction Costs:  9 / Calculated Accuracy 0.89 / #Correct Predictions: 16 Of 18
# einsatz/bet 34383.01428826884 Total Return / bet 60.111111111111114 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.89
# profit in % per bet: 0.17
# einsatz * 1+profit% ^ # wetten 1031.94
#
#
#
#
# Run: 19
# [[217 247]
#  [149 402]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.47      0.52       464
#          1.0       0.62      0.73      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.60      1015
#
# 1259.85%
# Specified Period:
# Total Return in Specified Period: 2545 / Profit:  12072 / Loss:  9506 / Transaction Costs:  20 / Calculated Accuracy 0.5083333333333333 / #Correct Predictions: 61 of 120
#
# Entire Period:
# einsatz 623760 Total Return: 12224 / Profit:  21301 / Loss:  8703 / Transaction Costs:  374 / Calculated Accuracy 0.61 / #Correct Predictions: 619 Of 1015
# einsatz/bet 614.5423118934035 Total Return / bet 12.043349753694581 / Transaction Costs / bet  0.36847290640394087 / Calculated Accuracy 0.61
# profit in % per bet: 1.96
# einsatz * 1+profit% ^ # wetten 358998484270.37
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.48      0.55       197
#          1.0       0.72      0.83      0.77       307
#
#     accuracy                           0.70       504
#    macro avg       0.68      0.66      0.66       504
# weighted avg       0.69      0.70      0.69       504
#
# 1142.21%
# Specified Period:
# Total Return in Specified Period: 2999 / Profit:  6978 / Loss:  3971 / Transaction Costs:  7 / Calculated Accuracy 0.6170212765957447 / #Correct Predictions: 29 of 47
#
# Entire Period:
# einsatz 623760 Total Return: 11216 / Profit:  14866 / Loss:  3443 / Transaction Costs:  205 / Calculated Accuracy 0.7 / #Correct Predictions: 351 Of 504
# einsatz/bet 1237.6199336742154 Total Return / bet 22.253968253968253 / Transaction Costs / bet  0.40674603174603174 / Calculated Accuracy 0.7
# profit in % per bet: 1.80
# einsatz * 1+profit% ^ # wetten 7958864.94
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.63      0.64        43
#          1.0       0.86      0.87      0.86       113
#
#     accuracy                           0.80       156
#    macro avg       0.75      0.75      0.75       156
# weighted avg       0.80      0.80      0.80       156
#
# 576.52%
# Specified Period:
# Total Return in Specified Period: 511 / Profit:  1394 / Loss:  881 / Transaction Costs:  1 / Calculated Accuracy 0.8 / #Correct Predictions: 8 of 10
#
# Entire Period:
# einsatz 623760 Total Return: 5694 / Profit:  6596 / Loss:  830 / Transaction Costs:  70 / Calculated Accuracy 0.8 / #Correct Predictions: 125 Of 156
# einsatz/bet 3998.4644011013115 Total Return / bet 36.5 / Transaction Costs / bet  0.44871794871794873 / Calculated Accuracy 0.8
# profit in % per bet: 0.91
# einsatz * 1+profit% ^ # wetten 4127.15
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.89      0.70         9
#          1.0       0.88      0.54      0.67        13
#
#     accuracy                           0.68        22
#    macro avg       0.72      0.71      0.68        22
# weighted avg       0.75      0.68      0.68        22
#
# 69.56%
# Specified Period:
# Total Return in Specified Period: -880 / Profit:  2 / Loss:  881 / Transaction Costs:  1 / Calculated Accuracy 0.3333333333333333 / #Correct Predictions: 1 of 3
#
# Entire Period:
# einsatz 623760 Total Return: 684 / Profit:  991 / Loss:  295 / Transaction Costs:  11 / Calculated Accuracy 0.68 / #Correct Predictions: 15 Of 22
# einsatz/bet 28352.747571445663 Total Return / bet 31.09090909090909 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.68
# profit in % per bet: 0.11
# einsatz * 1+profit% ^ # wetten 1024.40

# %%
import statistics
print("einsatz", einsatz)
print( statistics.median(zinseszins) )
print( statistics.median(profitpercent) )
print( statistics.median(percentlist) )
# Out:
# einsatz 1000
# 19232974219.9166
# 1.6661553588156188
# 1069

# %%
zinseszins
# Out:
# [14108530198.395134,
#  60012280418.77033,
#  20957914746.081253,
#  19232974219.9166,
#  1291135723.1508584,
#  1533850918.715354,
#  2861527286669.713,
#  41478568370.385506,
#  60109690988.7392,
#  17503295588.259342,
#  838163736.3179125,
#  10624263421.238392,
#  54900536348.36814,
#  36999042795.3116,
#  139825961.53609884,
#  104060531365.40141,
#  6902391350.948183,
#  4225648494.5227427,
#  358998484270.37006]

# %%
df_y_test_withdailyreturns.sort_values("Daily Return in USD")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2018-01-17   0.00         0.15    0.00             -2107.42
# 2018-01-12   0.00         0.39    0.00             -1539.51
# 2018-01-31   0.00         0.26    0.00             -1211.70
# 2018-01-09   0.00         0.42    0.00             -1164.56
# 2019-09-25   0.00         0.31    0.00             -1108.76
# ...           ...          ...     ...                  ...
# 2018-04-13   1.00         0.51    1.00               987.42
# 2017-12-16   1.00         0.63    1.00              1036.31
# 2019-07-04   1.00         0.63    1.00              1142.89
# 2018-01-01   1.00         0.31    0.00              1152.82
# 2019-06-29   1.00         0.64    1.00              1240.96
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2018-01-17                    -0.19                11136.81
# 2018-01-12                    -0.11                13797.82
# 2018-01-31                    -0.12                10087.72
# 2018-01-09                    -0.08                14415.47
# 2019-09-25                    -0.13                 8486.99
# ...                             ...                     ...
# 2018-04-13                     0.13                 7858.32
# 2017-12-16                     0.05                19587.61
# 2019-07-04                     0.10                11212.61
# 2018-01-01                     0.09                13436.40
# 2019-06-29                     0.10                11958.97
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2018-01-17                   0.85   850.54                      0.51
# 2018-01-12                   0.61   611.65                      0.37
# 2018-01-31                   0.74   736.76                      0.44
# 2018-01-09                   0.58   583.75                      0.35
# 2019-09-25                   0.69   694.53                      0.42
# ...                           ...      ...                       ...
# 2018-04-13                   0.51   507.72                      0.30
# 2017-12-16                   0.63   627.70                      0.38
# 2019-07-04                   0.63   632.36                      0.38
# 2018-01-01                   0.69   687.41                      0.41
# 2019-06-29                   0.64   635.93                      0.38
#
# [1015 rows x 9 columns]

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]].abs().sum()
# Out:
# Class                          149.00
# y_pred_prob                    207.49
# y_pred                         247.00
# Daily Return in USD          28369.17
# percentage_daily_return          8.70
# market/price_usd_close     1289341.18
# y_pred_prob_bereinigt          236.00
# Einsatz                     236001.17
# Transaction Costs in USD       141.60
# dtype: float64

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]].abs().sum()
# Out:
# Class                          402.00
# y_pred_prob                    341.98
# y_pred                         402.00
# Daily Return in USD          61411.60
# percentage_daily_return         21.30
# market/price_usd_close     1831617.81
# y_pred_prob_bereinigt          387.76
# Einsatz                     387759.27
# Transaction Costs in USD       232.66
# dtype: float64

# %%
dfrights = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]]
dfwrongs = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]]

# %%
dfwrongs.abs().sort_values("percentage_daily_return")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2013-01-12   0.00         0.70    1.00                 0.00
# 2020-03-19   1.00         0.34    0.00                 0.15
# 2018-07-23   0.00         0.68    1.00                 0.22
# 2020-07-15   0.00         0.52    1.00                 0.40
# 2017-02-09   0.00         0.67    1.00                 0.15
# ...           ...          ...     ...                  ...
# 2013-07-11   1.00         0.49    0.00                11.03
# 2020-03-14   1.00         0.16    0.00               686.71
# 2012-08-18   0.00         0.59    1.00                 1.80
# 2015-01-16   1.00         0.41    0.00                38.01
# 2012-08-20   0.00         0.65    1.00                 3.48
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2013-01-12                     0.00                   13.89
# 2020-03-19                     0.00                 6193.30
# 2018-07-23                     0.00                 7713.31
# 2020-07-15                     0.00                 9192.84
# 2017-02-09                     0.00                  988.41
# ...                             ...                     ...
# 2013-07-11                     0.13                   87.63
# 2020-03-14                     0.13                 5195.86
# 2012-08-18                     0.16                   11.40
# 2015-01-16                     0.18                  207.40
# 2012-08-20                     0.35                   10.07
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2013-01-12                   0.70   701.10                      0.42
# 2020-03-19                   0.66   655.71                      0.39
# 2018-07-23                   0.68   680.71                      0.41
# 2020-07-15                   0.52   517.15                      0.31
# 2017-02-09                   0.67   668.97                      0.40
# ...                           ...      ...                       ...
# 2013-07-11                   0.51   510.66                      0.31
# 2020-03-14                   0.84   844.50                      0.51
# 2012-08-18                   0.59   588.60                      0.35
# 2015-01-16                   0.59   593.92                      0.36
# 2012-08-20                   0.65   649.17                      0.39
#
# [396 rows x 9 columns]

# %%
dfrights.sort_values("percentage_daily_return")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2013-04-11   0.00         0.26    0.00               -69.39
# 2013-04-12   0.00         0.21    0.00               -78.88
# 2013-12-07   0.00         0.44    0.00              -214.66
# 2013-12-17   0.00         0.38    0.00              -171.19
# 2015-01-14   0.00         0.35    0.00               -40.78
# ...           ...          ...     ...                  ...
# 2013-11-09   1.00         0.75    1.00                43.35
# 2013-03-20   1.00         0.75    1.00                 8.98
# 2012-01-06   1.00         0.67    1.00                 1.40
# 2017-07-21   1.00         0.62    1.00               574.01
# 2013-11-19   1.00         0.76    1.00               192.19
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2013-04-11                    -0.85                   81.20
# 2013-04-12                    -0.73                  108.31
# 2013-12-07                    -0.31                  693.82
# 2013-12-17                    -0.25                  675.86
# 2015-01-14                    -0.24                  172.21
# ...                             ...                     ...
# 2013-11-09                     0.13                  334.88
# 2013-03-20                     0.14                   64.46
# 2012-01-06                     0.21                    6.70
# 2017-07-21                     0.22                 2667.80
# 2013-11-19                     0.36                  540.54
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2013-04-11                   0.74   741.64                      0.44
# 2013-04-12                   0.79   787.04                      0.47
# 2013-12-07                   0.56   560.16                      0.34
# 2013-12-17                   0.62   622.44                      0.37
# 2015-01-14                   0.65   654.23                      0.39
# ...                           ...      ...                       ...
# 2013-11-09                   0.75   753.98                      0.45
# 2013-03-20                   0.75   753.11                      0.45
# 2012-01-06                   0.67   665.82                      0.40
# 2017-07-21                   0.62   622.45                      0.37
# 2013-11-19                   0.76   756.27                      0.45
#
# [619 rows x 9 columns]

# %%
dfwrongs["year"] = dfwrongs.index.year
dfwrongs.abs().groupby(['year']).agg(['sum', 'count'])
# Out:
# <ipython-input-180-dc1a0dd5c2f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfwrongs["year"] = dfwrongs.index.year
#         Class       y_pred_prob       y_pred       Daily Return in USD        \
#           sum count         sum count    sum count                 sum count
# year
# 2011.00 11.00    17        6.77    17   6.00    17                3.06    17
# 2012.00 19.00    46       24.86    46  27.00    46               10.11    46
# 2013.00  8.00    35       20.46    35  27.00    35              117.35    35
# 2014.00 19.00    39       20.36    39  20.00    39              379.72    39
# 2015.00 16.00    54       29.46    54  38.00    54              269.95    54
# 2016.00  3.00    36       21.39    36  33.00    36              274.40    36
# 2017.00  3.00    32       18.36    32  29.00    32             3795.61    32
# 2018.00 28.00    44       19.99    44  16.00    44             9492.26    44
# 2019.00 27.00    55       26.93    55  28.00    55             6553.47    55
# 2020.00 15.00    38       18.90    38  23.00    38             7473.23    38
#
#         percentage_daily_return       market/price_usd_close        \
#                             sum count                    sum count
# year
# 2011.00                    0.67    17                  86.64    17
# 2012.00                    1.18    46                 345.20    46
# 2013.00                    0.72    35                5371.97    35
# 2014.00                    0.71    39               21504.99    39
# 2015.00                    1.02    54               14613.01    54
# 2016.00                    0.44    36               21344.14    36
# 2017.00                    1.06    32              114161.72    32
# 2018.00                    1.21    44              322365.78    44
# 2019.00                    0.84    55              408176.70    55
# 2020.00                    0.84    38              381371.04    38
#
#         y_pred_prob_bereinigt        Einsatz       Transaction Costs in USD  \
#                           sum count      sum count                      sum
# year
# 2011.00                 11.91    17 11914.55    17                     7.15
# 2012.00                 26.78    46 26777.27    46                    16.07
# 2013.00                 21.38    35 21377.97    35                    12.83
# 2014.00                 23.53    39 23528.14    39                    14.12
# 2015.00                 30.62    54 30617.94    54                    18.37
# 2016.00                 21.87    36 21869.63    36                    13.12
# 2017.00                 18.85    32 18854.28    32                    11.31
# 2018.00                 26.31    44 26312.17    44                    15.79
# 2019.00                 32.25    55 32249.99    55                    19.35
# 2020.00                 22.50    38 22499.23    38                    13.50
#
#
#         count
# year
# 2011.00    17
# 2012.00    46
# 2013.00    35
# 2014.00    39
# 2015.00    54
# 2016.00    36
# 2017.00    32
# 2018.00    44
# 2019.00    55
# 2020.00    38

# %%
dfrights["year"] = dfrights.index.year
dfrights.abs().groupby(['year']).agg(['sum', 'count'])
# Out:
# <ipython-input-181-90c79a75818e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfrights["year"] = dfrights.index.year
#         Class       y_pred_prob       y_pred       Daily Return in USD        \
#           sum count         sum count    sum count                 sum count
# year
# 2011.00 13.00    29       13.53    29  13.00    29                4.42    29
# 2012.00 42.00    65       35.98    65  42.00    65               10.05    65
# 2013.00 62.00    76       49.10    76  62.00    76             1595.25    76
# 2014.00 23.00    71       33.75    71  23.00    71              913.22    71
# 2015.00 41.00    64       35.59    64  41.00    64              549.37    64
# 2016.00 50.00    58       33.96    58  50.00    58              523.46    58
# 2017.00 76.00    86       53.27    86  76.00    86            11195.62    86
# 2018.00 33.00    66       31.17    66  33.00    66            23605.91    66
# 2019.00 35.00    63       33.39    63  35.00    63            15115.84    63
# 2020.00 27.00    41       22.23    41  27.00    41             7898.46    41
#
#         percentage_daily_return       market/price_usd_close        \
#                             sum count                    sum count
# year
# 2011.00                    1.08    29                 117.97    29
# 2012.00                    1.38    65                 528.15    65
# 2013.00                    5.92    76               15929.14    76
# 2014.00                    1.81    71               36275.62    71
# 2015.00                    2.01    64               17448.68    64
# 2016.00                    1.01    58               31588.13    58
# 2017.00                    2.77    86              335035.35    86
# 2018.00                    2.72    66              532473.52    66
# 2019.00                    1.77    63              469899.11    63
# 2020.00                    0.84    41              392322.14    41
#
#         y_pred_prob_bereinigt        Einsatz       Transaction Costs in USD  \
#                           sum count      sum count                      sum
# year
# 2011.00                 20.36    29 20362.99    29                    12.22
# 2012.00                 40.14    65 40135.49    65                    24.08
# 2013.00                 52.28    76 52284.14    76                    31.37
# 2014.00                 41.66    71 41656.01    71                    24.99
# 2015.00                 37.86    64 37855.21    64                    22.71
# 2016.00                 35.20    58 35203.14    58                    21.12
# 2017.00                 55.06    86 55059.50    86                    33.04
# 2018.00                 40.65    66 40651.60    66                    24.39
# 2019.00                 39.35    63 39349.13    63                    23.61
# 2020.00                 25.20    41 25202.05    41                    15.12
#
#
#         count
# year
# 2011.00    29
# 2012.00    65
# 2013.00    76
# 2014.00    71
# 2015.00    64
# 2016.00    58
# 2017.00    86
# 2018.00    66
# 2019.00    63
# 2020.00    41

# %%
predictors
# Out:
# array([[2.3838902e+00, 3.2931430e+00, 1.0847017e+01, ..., 4.1740000e+03,
#         6.2400000e+02, 7.5000000e+01],
#        [2.4553063e+00, 3.7208679e+00, 1.1650000e+01, ..., 4.1710000e+03,
#         6.2700000e+02, 7.5000000e+01],
#        [2.4380770e+00, 3.7733192e+00, 1.1450998e+01, ..., 4.1870000e+03,
#         6.2500000e+02, 7.5000000e+01],
#        ...,
#        [9.7237396e+00, 2.7040515e+00, 1.6709611e+04, ..., 1.6276000e+04,
#         2.2370000e+03, 1.1100000e+02],
#        [9.7794752e+00, 3.2141380e+00, 1.7667381e+04, ..., 1.6238000e+04,
#         2.2320000e+03, 1.1100000e+02],
#        [9.7876406e+00, 3.1547880e+00, 1.7812232e+04, ..., 1.6242000e+04,
#         2.2280000e+03, 1.1300000e+02]], dtype=float32)

# %% [markdown]
# # Bet on tomorrow

# %%
# Split Data into Training and Testing
#X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, stratify=target)

# Amount of Columns
n_nodes = predictors.shape[1]
print("Amount of Columns", n_nodes)

# Instantiation of MinMaxScaler
norm_scaler = MinMaxScaler()

# Training and Application of Feature Scaler on Training Data of Predictors
predictors_scaled = pd.DataFrame(norm_scaler.fit_transform(predictors))

# Instantiate Classifier Logistic Regression
lreg = LogisticRegression(max_iter=12000) 

# Train Classifier
lreg.fit(predictors_scaled, target)
# Out:
# Amount of Columns 101
# LogisticRegression(max_iter=12000)

# %% [markdown]
# # get x train data of today to predict tomorrow y

# %%
most_current_day = df_dataset1.tail(1)
dateofprediction = most_current_day.index
most_current_day
# Out:
#             Log Price in USD  Volatility Daily Log Return in Percent 5D  \
# Date
# 2020-11-18              9.79                                       3.15
#
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2020-11-18                17812.23                           -0.10
#
#             market/price_realized_usd  market/mvrv   mining/difficulty_latest  \
# Date
# 2020-11-18                    7037.45         2.54 75577685065077505392640.00
#
#               mining/hash_rate_mean  mining/revenue_sum  \
# Date
# 2020-11-18 146411297553796005888.00             1147.11
#
#             mining/marketcap_thermocap_ratio  ...  \
# Date                                          ...
# 2020-11-18                              0.00  ...
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-18                     581082.00               32525162.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-18                        8532965.00                   3123601.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-18              818953.00               154259.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-18                 16242.00                 2228.00
#
#             addresses/min_10k_count  Class
# Date
# 2020-11-18                   113.00   1.00
#
# [1 rows x 102 columns]

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
most_current_day_predictors = most_current_day.drop(['Class'], axis=1).values.astype(np.float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
most_current_day_predictors_scaled = norm_scaler.transform(most_current_day_predictors)
most_current_day_predictors_scaled
# Out:
# array([[9.8963243e-01, 7.2058305e-02, 9.0935254e-01, 8.9212912e-01,
#         1.0000000e+00, 4.0046543e-01, 8.7995738e-01, 9.1071481e-01,
#         4.8244670e-02, 1.6999203e-01, 4.9444446e-01, 2.3015958e-01,
#         8.3270723e-01, 9.9014521e-01, 9.2981148e-01, 2.3990683e-04,
#         6.3960530e-02, 5.3459508e-03, 2.9510441e-03, 4.9740076e-01,
#         8.2160640e-01, 4.0808782e-02, 4.0878478e-02, 9.9504560e-01,
#         9.9648660e-01, 7.7577513e-03, 9.9999994e-01, 9.8156559e-01,
#         9.9367297e-01, 1.8454958e-02, 9.4240314e-01, 9.0008974e-01,
#         8.7449759e-01, 9.8251826e-01, 4.2911547e-01, 2.5130326e-01,
#         5.0707567e-01, 1.8960525e-01, 2.5201330e-01, 3.2913893e-01,
#         6.4922321e-01, 6.3385385e-01, 6.0383844e-01, 4.4684741e-01,
#         5.5077082e-01, 1.0000000e+00, 5.3740017e-02, 1.7398221e-02,
#         7.3533189e-01, 8.3270270e-01, 4.0877115e-02, 8.0514122e-03,
#         2.2115390e-01, 2.2752807e-01, 1.9626488e-01, 4.9231637e-01,
#         8.0000257e-01, 4.1330209e-01, 5.3700626e-01, 3.5444415e-01,
#         5.6393212e-03, 6.5299496e-02, 5.4142043e-02, 1.6525517e-01,
#         9.4915187e-01, 1.8401293e-01, 5.0844806e-01, 9.5909357e-01,
#         4.5104811e-01, 3.3870995e-01, 1.6566767e-01, 1.8324962e-01,
#         6.8536095e-02, 8.9761078e-02, 1.8367448e-01, 7.6880142e-02,
#         1.3795461e-01, 1.6237244e-02, 9.0142703e-01, 5.6359589e-01,
#         9.8617682e-05, 4.9603796e-01, 3.3530962e-01, 6.0358711e-02,
#         8.9995992e-01, 9.1487187e-01, 1.2947452e-01, 3.4807343e-02,
#         5.1342398e-02, 9.2468071e-01, 8.8954359e-01, 7.5111288e-01,
#         7.2473013e-01, 9.8999780e-01, 9.7419602e-01, 9.7941107e-01,
#         9.9126214e-01, 9.6706271e-01, 8.3989704e-01, 9.9442387e-01,
#         7.9365087e-01]], dtype=float32)

# %%
# Prediction of Classes
most_current_day_pred = lreg.predict(most_current_day_predictors_scaled)
most_current_day_pred
# Out:
# array([1.], dtype=float32)

# %%
# Prediction of Probabilities
most_current_day_pred_prob = lreg.predict_proba(most_current_day_predictors_scaled)[:,1]
most_current_day_pred_prob[0]
# Out:
# 0.699654531309074

# %%
dateofprediction[0]
# Out:
# Timestamp('2020-11-18 00:00:00')

# %%
predicted_df = pd.DataFrame([[dateofprediction[0],most_current_day_pred_prob[0],most_current_day_pred[0]]], index=dateofprediction, columns=["dateofprediction","most_current_day_pred_prob","most_current_day_pred"])
predicted_df
# Out:
#            dateofprediction  most_current_day_pred_prob  most_current_day_pred
# Date
# 2020-11-18       2020-11-18                        0.70                   1.00

# %% [markdown]
# # Store DF of the one prediction in database

# %%
from datetime import datetime
from sqlalchemy import create_engine

engine = create_engine("mysql://root:root@127.0.0.1/btc_predictions")

predicted_df.to_sql(name="btc_preds", 
                con=engine, index=False,
                if_exists='append', 
                )
