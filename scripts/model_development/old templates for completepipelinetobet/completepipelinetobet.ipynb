# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Data-Import-via-Application-Programming-Interfaces" data-toc-modified-id="Data-Import-via-Application-Programming-Interfaces-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data Import via Application Programming Interfaces</a></span><ul class="toc-item"><li><span><a href="#Blockchain-Data-from-Glassnode" data-toc-modified-id="Blockchain-Data-from-Glassnode-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Blockchain Data from Glassnode</a></span><ul class="toc-item"><li><span><a href="#Market-Metrics-from-Glassnode" data-toc-modified-id="Market-Metrics-from-Glassnode-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Market Metrics from Glassnode</a></span></li><li><span><a href="#Mining-Metrics-from-Glassnode" data-toc-modified-id="Mining-Metrics-from-Glassnode-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Mining Metrics from Glassnode</a></span></li><li><span><a href="#Blocks-Metrics-from-Glassnode" data-toc-modified-id="Blocks-Metrics-from-Glassnode-1.1.1.3"><span class="toc-item-num">1.1.1.3&nbsp;&nbsp;</span>Blocks Metrics from Glassnode</a></span></li><li><span><a href="#Distribution-Metrics-from-Glassnode" data-toc-modified-id="Distribution-Metrics-from-Glassnode-1.1.1.4"><span class="toc-item-num">1.1.1.4&nbsp;&nbsp;</span>Distribution Metrics from Glassnode</a></span></li><li><span><a href="#Fee-Metrics-from-Glassnode" data-toc-modified-id="Fee-Metrics-from-Glassnode-1.1.1.5"><span class="toc-item-num">1.1.1.5&nbsp;&nbsp;</span>Fee Metrics from Glassnode</a></span></li><li><span><a href="#UTXO-Metrics-from-Glassnode" data-toc-modified-id="UTXO-Metrics-from-Glassnode-1.1.1.6"><span class="toc-item-num">1.1.1.6&nbsp;&nbsp;</span>UTXO Metrics from Glassnode</a></span></li><li><span><a href="#Supply-Metrics-from-Glassnode" data-toc-modified-id="Supply-Metrics-from-Glassnode-1.1.1.7"><span class="toc-item-num">1.1.1.7&nbsp;&nbsp;</span>Supply Metrics from Glassnode</a></span></li><li><span><a href="#Transaction-Metrics-from-Glassnode" data-toc-modified-id="Transaction-Metrics-from-Glassnode-1.1.1.8"><span class="toc-item-num">1.1.1.8&nbsp;&nbsp;</span>Transaction Metrics from Glassnode</a></span></li><li><span><a href="#Exchange-Metrics-from-Glassnode---1-Month-Lag" data-toc-modified-id="Exchange-Metrics-from-Glassnode---1-Month-Lag-1.1.1.9"><span class="toc-item-num">1.1.1.9&nbsp;&nbsp;</span>Exchange Metrics from Glassnode - 1 Month Lag</a></span></li><li><span><a href="#Indicator-I-Metrics-from-Glassnode" data-toc-modified-id="Indicator-I-Metrics-from-Glassnode-1.1.1.10"><span class="toc-item-num">1.1.1.10&nbsp;&nbsp;</span>Indicator-I Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-2-Metrics-from-Glassnode" data-toc-modified-id="Indicator-2-Metrics-from-Glassnode-1.1.1.11"><span class="toc-item-num">1.1.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-3-Metrics-from-Glassnode" data-toc-modified-id="Indicator-3-Metrics-from-Glassnode-1.1.1.12"><span class="toc-item-num">1.1.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics from Glassnode</a></span></li><li><span><a href="#Addresses-Metrics-from-Glassnode" data-toc-modified-id="Addresses-Metrics-from-Glassnode-1.1.1.13"><span class="toc-item-num">1.1.1.13&nbsp;&nbsp;</span>Addresses Metrics from Glassnode</a></span></li><li><span><a href="#Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020-1.1.1.14"><span class="toc-item-num">1.1.1.14&nbsp;&nbsp;</span>Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Futures-Features" data-toc-modified-id="List-of-Futures-Features-1.1.1.14.1"><span class="toc-item-num">1.1.1.14.1&nbsp;&nbsp;</span>List of Futures Features</a></span></li><li><span><a href="#Data-Frame-of-Future-features" data-toc-modified-id="Data-Frame-of-Future-features-1.1.1.14.2"><span class="toc-item-num">1.1.1.14.2&nbsp;&nbsp;</span>Data Frame of Future features</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#File-Import-and-Data-Tidying" data-toc-modified-id="File-Import-and-Data-Tidying-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>File Import and Data Tidying</a></span><ul class="toc-item"><li><span><a href="#Import-Blockchain-CSV-Files" data-toc-modified-id="Import-Blockchain-CSV-Files-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Import Blockchain CSV-Files</a></span><ul class="toc-item"><li><span><a href="#Market-Metric-CSV-Files" data-toc-modified-id="Market-Metric-CSV-Files-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>Market Metric CSV-Files</a></span></li><li><span><a href="#Mining-Metric-CSV-Files" data-toc-modified-id="Mining-Metric-CSV-Files-1.2.1.2"><span class="toc-item-num">1.2.1.2&nbsp;&nbsp;</span>Mining Metric CSV-Files</a></span></li><li><span><a href="#Blocks-Metric-CSV-Files" data-toc-modified-id="Blocks-Metric-CSV-Files-1.2.1.3"><span class="toc-item-num">1.2.1.3&nbsp;&nbsp;</span>Blocks Metric CSV-Files</a></span></li><li><span><a href="#Distribution-Metric-CSV-Files" data-toc-modified-id="Distribution-Metric-CSV-Files-1.2.1.4"><span class="toc-item-num">1.2.1.4&nbsp;&nbsp;</span>Distribution Metric CSV-Files</a></span></li><li><span><a href="#Fee-Metric-CSV-Files" data-toc-modified-id="Fee-Metric-CSV-Files-1.2.1.5"><span class="toc-item-num">1.2.1.5&nbsp;&nbsp;</span>Fee Metric CSV-Files</a></span></li><li><span><a href="#UTXO-Metric-CSV-Files" data-toc-modified-id="UTXO-Metric-CSV-Files-1.2.1.6"><span class="toc-item-num">1.2.1.6&nbsp;&nbsp;</span>UTXO Metric CSV-Files</a></span></li><li><span><a href="#Supply-Metric-CSV-Files" data-toc-modified-id="Supply-Metric-CSV-Files-1.2.1.7"><span class="toc-item-num">1.2.1.7&nbsp;&nbsp;</span>Supply Metric CSV-Files</a></span></li><li><span><a href="#Transaction-Metric-CSV-Files" data-toc-modified-id="Transaction-Metric-CSV-Files-1.2.1.8"><span class="toc-item-num">1.2.1.8&nbsp;&nbsp;</span>Transaction Metric CSV-Files</a></span></li><li><span><a href="#Exchange-Metrics-CSV-Files" data-toc-modified-id="Exchange-Metrics-CSV-Files-1.2.1.9"><span class="toc-item-num">1.2.1.9&nbsp;&nbsp;</span>Exchange Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-1-Metric-CSV-Files" data-toc-modified-id="Indicator-1-Metric-CSV-Files-1.2.1.10"><span class="toc-item-num">1.2.1.10&nbsp;&nbsp;</span>Indicator-1 Metric CSV-Files</a></span></li><li><span><a href="#Indicator-2-Metrics-CSV-Files" data-toc-modified-id="Indicator-2-Metrics-CSV-Files-1.2.1.11"><span class="toc-item-num">1.2.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-3-Metrics-CSV-Files" data-toc-modified-id="Indicator-3-Metrics-CSV-Files-1.2.1.12"><span class="toc-item-num">1.2.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics CSV-Files</a></span></li><li><span><a href="#Addresses-Metric-CSV-Files" data-toc-modified-id="Addresses-Metric-CSV-Files-1.2.1.13"><span class="toc-item-num">1.2.1.13&nbsp;&nbsp;</span>Addresses Metric CSV-Files</a></span></li><li><span><a href="#Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020-1.2.1.14"><span class="toc-item-num">1.2.1.14&nbsp;&nbsp;</span>Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Future-Features" data-toc-modified-id="List-of-Future-Features-1.2.1.14.1"><span class="toc-item-num">1.2.1.14.1&nbsp;&nbsp;</span>List of Future Features</a></span></li><li><span><a href="#Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension" data-toc-modified-id="Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension-1.2.1.14.2"><span class="toc-item-num">1.2.1.14.2&nbsp;&nbsp;</span>Counter to Differentiate between Data Frame Setup and Data Frame Extension</a></span></li><li><span><a href="#For-Loop-through-all-Features-in-the-List" data-toc-modified-id="For-Loop-through-all-Features-in-the-List-1.2.1.14.3"><span class="toc-item-num">1.2.1.14.3&nbsp;&nbsp;</span>For Loop through all Features in the List</a></span></li><li><span><a href="#Store-Data-Frame-Copy-in-Market-Data-Frame" data-toc-modified-id="Store-Data-Frame-Copy-in-Market-Data-Frame-1.2.1.14.4"><span class="toc-item-num">1.2.1.14.4&nbsp;&nbsp;</span>Store Data Frame Copy in Market Data Frame</a></span></li><li><span><a href="#Delete-Original-Data-Frame" data-toc-modified-id="Delete-Original-Data-Frame-1.2.1.14.5"><span class="toc-item-num">1.2.1.14.5&nbsp;&nbsp;</span>Delete Original Data Frame</a></span></li><li><span><a href="#Change-Data-Type-of-Columns-to-Float" data-toc-modified-id="Change-Data-Type-of-Columns-to-Float-1.2.1.14.6"><span class="toc-item-num">1.2.1.14.6&nbsp;&nbsp;</span>Change Data Type of Columns to Float</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Target-Variables" data-toc-modified-id="Target-Variables-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Target Variables</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Volatility" data-toc-modified-id="Volatility-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Volatility</a></span></li><li><span><a href="#Log-Price" data-toc-modified-id="Log-Price-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Log Price</a></span></li></ul></li></ul></li><li><span><a href="#Data-Sets" data-toc-modified-id="Data-Sets-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I.---Blockchain-Metrics-Only" data-toc-modified-id="Data-Set-I.---Blockchain-Metrics-Only-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data Set I. - Blockchain Metrics Only</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-Variations" data-toc-modified-id="Classification-Models---Data-Set-Variations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Classification Models - Data Set Variations</a></span></li><li><span><a href="#Import-Data-Sets" data-toc-modified-id="Import-Data-Sets-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Data Set I.</a></span></li><li><span><a href="#Prediction-Shift" data-toc-modified-id="Prediction-Shift-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Prediction Shift</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Data Set I.</a></span></li></ul></li></ul></li><li><span><a href="#Classification-Setup" data-toc-modified-id="Classification-Setup-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Classification Setup</a></span><ul class="toc-item"><li><span><a href="#Create-Data-Set-Copies-for-Trading-Strategy" data-toc-modified-id="Create-Data-Set-Copies-for-Trading-Strategy-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Create Data Set Copies for Trading Strategy</a></span></li><li><span><a href="#Categorization---Data-Set-I." data-toc-modified-id="Categorization---Data-Set-I.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Categorization - Data Set I.</a></span></li></ul></li><li><span><a href="#Model-Preparation---Data-Set-I." data-toc-modified-id="Model-Preparation---Data-Set-I.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model Preparation - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split---Data-Set-I." data-toc-modified-id="Train-Test-Split---Data-Set-I.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Train Test Split - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Check-of-Class-Balance" data-toc-modified-id="Check-of-Class-Balance-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Check of Class Balance</a></span></li></ul></li><li><span><a href="#Feature-Scaling---Data-Set-I." data-toc-modified-id="Feature-Scaling---Data-Set-I.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Feature Scaling - Data Set I.</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-I." data-toc-modified-id="Classification-Models---Data-Set-I.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Classification Models - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression---Data-Set-I." data-toc-modified-id="Logistic-Regression---Data-Set-I.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Logistic Regression - Data Set I.</a></span></li><li><span><a href="#Random-Forest-Classifier---Data-Set-I." data-toc-modified-id="Random-Forest-Classifier---Data-Set-I.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Random Forest Classifier - Data Set I.</a></span></li></ul></li><li><span><a href="#Trading-Strategy---Data-Set-I" data-toc-modified-id="Trading-Strategy---Data-Set-I-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Trading Strategy - Data Set I</a></span><ul class="toc-item"><li><span><a href="#Trading-Strategy-in-Combination-with-Logistic-Regression" data-toc-modified-id="Trading-Strategy-in-Combination-with-Logistic-Regression-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Trading Strategy in Combination with Logistic Regression</a></span></li></ul></li><li><span><a href="#Bet-on-tomorrow" data-toc-modified-id="Bet-on-tomorrow-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Bet on tomorrow</a></span></li><li><span><a href="#get-x-train-data-of-today-to-predict-tomorrow-y" data-toc-modified-id="get-x-train-data-of-today-to-predict-tomorrow-y-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>get x train data of today to predict tomorrow y</a></span></li><li><span><a href="#Store-DF-of-the-one-prediction-in-database" data-toc-modified-id="Store-DF-of-the-one-prediction-in-database-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Store DF of the one prediction in database</a></span></li></ul></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Import via Application Programming Interfaces

# %%
# Import of Modules and Packages
import os
import requests
import json
import datetime
import yfinance as yf
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pytrends.request import TrendReq
from pytrends import dailydata

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %%
# Glassnode API Key
API_Key =''

# %% [markdown]
# ### Blockchain Data from Glassnode

# %%
# Import Function for a Single Feature Variable from Glassnode
def import_glassnode (url, feature_name):
    data = requests.get(url).json()
    df = pd.json_normalize(data)
    
    # Rename columns
    df.columns = ['Date', feature_name]
   
    # Convert Object to Datetime Object
    df.Date = pd.to_datetime(df.Date, unit='s')
    df.Date = df.Date.map(lambda x: x.strftime('%Y-%m-%d'))
    
    # Set Date Column as Index
    df.set_index('Date', inplace=True)
    
    # Drop Missing Values
    df = df.dropna()
    
    # Change Data Type to Float
    df = df.astype(float)
    
    # Creation of CSV-File, Part of Feature Name as CSV File Name 
    df.to_csv("{}.csv".format(feature_name.rsplit('/')[-1]), decimal=',')
    
    # Plot of DataFrame
    #df.plot(figsize=(4.5, 1.75))
    #plt.xticks(rotation=45)
    return df

# %%
# Import Function for Several Feature Variables from Glassnode
def import_glassnode_many(feature_list):
    # Counter to Differentiate between Data Frame Setup and Data Frame Join
    counter=0
    
    # For Loop through all Features in the List
    for feature in feature_list:
        
        # URL
        url = 'https://api.glassnode.com/v1/metrics/{}?a=btc&f=json&api_key='.format(feature)
        
        # Execute Import Function for a Single Feature Variable
        df=import_glassnode(url, feature)
        
        # Display Data Frame Tail
        print(df.tail())
        
        # Condition - Data Frame Set up or Data Frame Join
        if counter > 0:
            
            # Data Frame Join
            df_new = df_new.join(df, how='inner')   
        
        else:
            
            # Data Frame Setup
            df_new = df
        
        # Increase Counter
        counter +=1
    
    return df_new

# %% [markdown]
# #### Market Metrics from Glassnode

# %%
# List of Market Features
market_feature_list = ['market/price_usd_close', 'market/price_drawdown_relative', 'market/price_realized_usd', 'market/mvrv']

# %%
# Data Frame of Market Features
df_market = import_glassnode_many(market_feature_list)
# Out:
#             market/price_usd_close
# Date
# 2020-11-15                15962.10
# 2020-11-16                16709.61
# 2020-11-17                17667.38
# 2020-11-18                17812.23
# 2020-11-19                17893.43
#             market/price_drawdown_relative
# Date
# 2020-11-14                           -0.19
# 2020-11-15                           -0.19
# 2020-11-16                           -0.16
# 2020-11-17                           -0.11
# 2020-11-18                           -0.10
#             market/price_realized_usd
# Date
# 2019-11-14                    5720.47
# 2019-11-15                    5719.82
# 2019-11-16                    5718.93
# 2019-11-17                    5719.16
# 2019-11-18                    5717.47
#             market/mvrv
# Date
# 2019-11-14         1.53
# 2019-11-15         1.50
# 2019-11-16         1.49
# 2019-11-17         1.50
# 2019-11-18         1.48

# %% [markdown]
# #### Mining Metrics from Glassnode

# %%
# List of Mining Features
mining_feature_list = ['mining/difficulty_latest', 'mining/hash_rate_mean', 'mining/revenue_sum', 'mining/marketcap_thermocap_ratio']

# %%
# Data Frame of Mining Features
df_mining = import_glassnode_many(mining_feature_list)
# Out:
#              mining/difficulty_latest
# Date
# 2020-11-14 72102964397116403744768.00
# 2020-11-15 72102964397116403744768.00
# 2020-11-16 75577685065077505392640.00
# 2020-11-17 75577685065077505392640.00
# 2020-11-18 75577685065077505392640.00
#               mining/hash_rate_mean
# Date
# 2020-11-14 118951378399870992384.00
# 2020-11-15 124875241422092992512.00
# 2020-11-16 136158304329831006208.00
# 2020-11-17 136840305323567005696.00
# 2020-11-18 146411297553796005888.00
#             mining/revenue_sum
# Date
# 2019-11-14             2142.14
# 2019-11-15             2004.65
# 2019-11-16             1872.93
# 2019-11-17             1946.08
# 2019-11-18             1777.83
#             mining/marketcap_thermocap_ratio
# Date
# 2019-11-14                              0.00
# 2019-11-15                              0.00
# 2019-11-16                              0.00
# 2019-11-17                              0.00
# 2019-11-18                              0.00

# %% [markdown]
# #### Blocks Metrics from Glassnode

# %%
# List of Blockchain Features
blockchain_feature_list = ['blockchain/block_count', 'blockchain/block_interval_mean', 'blockchain/block_size_sum']

# %%
# Data Frame of Blockchain Features
df_blockchainfeatures = import_glassnode_many(blockchain_feature_list)
# Out:
#             blockchain/block_count
# Date
# 2020-11-14                  142.00
# 2020-11-15                  150.00
# 2020-11-16                  160.00
# 2020-11-17                  157.00
# 2020-11-18                  169.00
#             blockchain/block_interval_mean
# Date
# 2020-11-14                          606.15
# 2020-11-15                          577.40
# 2020-11-16                          536.43
# 2020-11-17                          552.31
# 2020-11-18                          516.20
#             blockchain/block_size_sum
# Date
# 2020-11-14               183207923.00
# 2020-11-15               180783978.00
# 2020-11-16               193429011.00
# 2020-11-17               201346288.00
# 2020-11-18               213284264.00

# %% [markdown]
# #### Distribution Metrics from Glassnode

# %%
# List of Distribution Features
distribution_feature_list = ['distribution/balance_1pct_holders', 'distribution/gini', 'distribution/herfindahl']

# %%
# Data Frame of Distribution Features
df_distribution = import_glassnode_many(distribution_feature_list)
# Out:
#             distribution/balance_1pct_holders
# Date
# 2019-11-14                               0.89
# 2019-11-15                               0.89
# 2019-11-16                               0.89
# 2019-11-17                               0.89
# 2019-11-18                               0.89
#             distribution/gini
# Date
# 2019-11-14               0.99
# 2019-11-15               0.99
# 2019-11-16               0.99
# 2019-11-17               0.99
# 2019-11-18               0.99
#             distribution/herfindahl
# Date
# 2019-11-14                     0.00
# 2019-11-15                     0.00
# 2019-11-16                     0.00
# 2019-11-17                     0.00
# 2019-11-18                     0.00

# %% [markdown]
# #### Fee Metrics from Glassnode

# %%
# List of Fee Features
fees_feature_list = ['fees/volume_sum', 'fees/volume_mean', 'fees/fee_ratio_multiple']

# %%
# Data Frame of Fee Features
df_fees = import_glassnode_many(fees_feature_list)
# Out:
#             fees/volume_sum
# Date
# 2020-11-14            59.16
# 2020-11-15            42.43
# 2020-11-16            83.46
# 2020-11-17            90.54
# 2020-11-18            97.64
#             fees/volume_mean
# Date
# 2020-11-14              0.00
# 2020-11-15              0.00
# 2020-11-16              0.00
# 2020-11-17              0.00
# 2020-11-18              0.00
#             fees/fee_ratio_multiple
# Date
# 2019-11-14                    72.27
# 2019-11-15                    67.61
# 2019-11-16                    81.67
# 2019-11-17                    92.31
# 2019-11-18                    63.89

# %% [markdown]
# #### UTXO Metrics from Glassnode

# %%
# List of UTXO Features
utxo_feature_list = ['blockchain/utxo_created_count', 'blockchain/utxo_spent_count', 'blockchain/utxo_created_value_sum', 'blockchain/utxo_spent_value_sum', 'blockchain/utxo_profit_relative', 'blockchain/utxo_profit_count', 'blockchain/utxo_loss_count']

# %%
# Data Frame of UTXO Features
df_utxo = import_glassnode_many(utxo_feature_list)
# Out:
#             blockchain/utxo_created_count
# Date
# 2020-11-14                      790805.00
# 2020-11-15                      720717.00
# 2020-11-16                      869288.00
# 2020-11-17                      974192.00
# 2020-11-18                     1017548.00
#             blockchain/utxo_spent_count
# Date
# 2020-11-14                    833376.00
# 2020-11-15                    856807.00
# 2020-11-16                    919942.00
# 2020-11-17                    952316.00
# 2020-11-18                   1015256.00
#             blockchain/utxo_created_value_sum
# Date
# 2020-11-14                         1902618.94
# 2020-11-15                         1598945.68
# 2020-11-16                         3618303.62
# 2020-11-17                         3030811.52
# 2020-11-18                         2930159.47
#             blockchain/utxo_spent_value_sum
# Date
# 2020-11-14                       1901731.44
# 2020-11-15                       1598008.18
# 2020-11-16                       3617303.62
# 2020-11-17                       3029830.27
# 2020-11-18                       2929103.22
#             blockchain/utxo_profit_relative
# Date
# 2019-11-14                             0.72
# 2019-11-15                             0.71
# 2019-11-16                             0.71
# 2019-11-17                             0.72
# 2019-11-18                             0.69
#             blockchain/utxo_profit_count
# Date
# 2019-11-14                   72662011.00
# 2019-11-15                   70998766.00
# 2019-11-16                   71549016.00
# 2019-11-17                   71598844.00
# 2019-11-18                   68832409.00
#             blockchain/utxo_loss_count
# Date
# 2019-11-14                 27842570.00
# 2019-11-15                 29499152.00
# 2019-11-16                 28781816.00
# 2019-11-17                 28505126.00
# 2019-11-18                 31356148.00

# %%
# 1 Minute Break for API Request - Only 30 Requests per Minute Possible
time.sleep(60)

# %% [markdown]
# #### Supply Metrics from Glassnode

# %%
# List of Supply Features
supply_feature_list = ['supply/current','supply/profit_relative', 'supply/profit_sum', 'supply/loss_sum', 'supply/active_more_1y_percent', 'supply/active_more_2y_percent', 'supply/active_more_3y_percent', 'supply/active_more_5y_percent', 'supply/active_24h', 'supply/active_1d_1w', 'supply/active_1w_1m', 'supply/active_1m_3m', 'supply/active_3m_6m', 'supply/active_6m_12m', 'supply/active_1y_2y', 'supply/active_2y_3y', 'supply/active_3y_5y', 'supply/active_5y_7y', 'supply/active_7y_10y', 'supply/active_more_10y', 'supply/issued', 'supply/inflation_rate']

# %%
# Data Frame of Supply Features
df_supply = import_glassnode_many(supply_feature_list)
# Out:
#             supply/current
# Date
# 2020-11-14     18543475.00
# 2020-11-15     18544412.50
# 2020-11-16     18545412.50
# 2020-11-17     18546393.75
# 2020-11-18     18547450.00
#             supply/profit_relative
# Date
# 2019-11-14                    0.69
# 2019-11-15                    0.67
# 2019-11-16                    0.69
# 2019-11-17                    0.69
# 2019-11-18                    0.65
#             supply/profit_sum
# Date
# 2019-11-14        12439822.77
# 2019-11-15        12180796.86
# 2019-11-16        12399498.89
# 2019-11-17        12415563.48
# 2019-11-18        11672206.32
#             supply/loss_sum
# Date
# 2019-11-14       5607835.77
# 2019-11-15       5868836.69
# 2019-11-16       5651984.66
# 2019-11-17       5637845.06
# 2019-11-18       6382952.23
#             supply/active_more_1y_percent
# Date
# 2020-11-14                           0.62
# 2020-11-15                           0.62
# 2020-11-16                           0.62
# 2020-11-17                           0.62
# 2020-11-18                           0.61
#             supply/active_more_2y_percent
# Date
# 2019-11-14                           0.36
# 2019-11-15                           0.36
# 2019-11-16                           0.36
# 2019-11-17                           0.36
# 2019-11-18                           0.36
#             supply/active_more_3y_percent
# Date
# 2019-11-14                           0.27
# 2019-11-15                           0.27
# 2019-11-16                           0.27
# 2019-11-17                           0.27
# 2019-11-18                           0.27
#             supply/active_more_5y_percent
# Date
# 2019-11-14                           0.22
# 2019-11-15                           0.22
# 2019-11-16                           0.22
# 2019-11-17                           0.22
# 2019-11-18                           0.22
#             supply/active_24h
# Date
# 2019-11-14          193458.43
# 2019-11-15          204923.23
# 2019-11-16          117248.00
# 2019-11-17           94633.46
# 2019-11-18          202688.57
#             supply/active_1d_1w
# Date
# 2019-11-14            394744.25
# 2019-11-15            360865.45
# 2019-11-16            440633.28
# 2019-11-17            457620.15
# 2019-11-18            386333.61
#             supply/active_1w_1m
# Date
# 2019-11-14           1221017.29
# 2019-11-15           1242705.14
# 2019-11-16           1228882.31
# 2019-11-17           1218053.68
# 2019-11-18           1203328.92
#             supply/active_1m_3m
# Date
# 2019-11-14           1524188.60
# 2019-11-15           1530002.60
# 2019-11-16           1549410.25
# 2019-11-17           1557963.80
# 2019-11-18           1539742.66
#             supply/active_3m_6m
# Date
# 2019-11-14           2226267.20
# 2019-11-15           2214980.45
# 2019-11-16           2200004.91
# 2019-11-17           2195855.85
# 2019-11-18           2199598.07
#             supply/active_6m_12m
# Date
# 2019-11-14            2701901.94
# 2019-11-15            2707169.75
# 2019-11-16            2720145.65
# 2019-11-17            2732763.09
# 2019-11-18            2741380.45
#             supply/active_1y_2y
# Date
# 2019-11-14           3262545.97
# 2019-11-15           3254645.88
# 2019-11-16           3251917.23
# 2019-11-17           3242748.08
# 2019-11-18           3223104.89
#             supply/active_2y_3y
# Date
# 2019-11-14           1672360.16
# 2019-11-15           1680316.42
# 2019-11-16           1687335.45
# 2019-11-17           1697160.16
# 2019-11-18           1702276.49
#             supply/active_3y_5y
# Date
# 2019-11-14            952851.27
# 2019-11-15            955629.14
# 2019-11-16            956583.59
# 2019-11-17            956795.47
# 2019-11-18            956198.25
#             supply/active_5y_7y
# Date
# 2019-11-14           1266307.98
# 2019-11-15           1265484.74
# 2019-11-16           1265684.66
# 2019-11-17           1265368.48
# 2019-11-18           1265455.29
#             supply/active_7y_10y
# Date
# 2019-11-14            1638743.15
# 2019-11-15            1637788.44
# 2019-11-16            1636765.90
# 2019-11-17            1636074.00
# 2019-11-18            1634879.02
#             supply/active_more_10y
# Date
# 2019-11-14               993272.32
# 2019-11-15               995122.32
# 2019-11-16               996872.32
# 2019-11-17               998372.32
# 2019-11-18              1000172.32
#             supply/issued
# Date
# 2019-11-14        2112.50
# 2019-11-15        1975.00
# 2019-11-16        1850.00
# 2019-11-17        1925.00
# 2019-11-18        1750.00
#             supply/inflation_rate
# Date
# 2019-11-14                   0.04
# 2019-11-15                   0.04
# 2019-11-16                   0.04
# 2019-11-17                   0.04
# 2019-11-18                   0.04

# %% [markdown]
# #### Transaction Metrics from Glassnode

# %%
# List of Transaction Features
transaction_feature_list = ['transactions/count', 'transactions/size_sum','transactions/transfers_volume_sum', 'transactions/transfers_volume_adjusted_sum']

# %%
# Data Frame of Transaction Features
df_transaction = import_glassnode_many(transaction_feature_list)
# Out:
#             transactions/count
# Date
# 2020-11-14           273369.00
# 2020-11-15           252565.00
# 2020-11-16           311317.00
# 2020-11-17           347615.00
# 2020-11-18           361838.00
#             transactions/size_sum
# Date
# 2020-11-14           183152220.00
# 2020-11-15           180725345.00
# 2020-11-16           193367265.00
# 2020-11-17           201284684.00
# 2020-11-18           213218316.00
#             transactions/transfers_volume_sum
# Date
# 2020-11-14                         1901672.29
# 2020-11-15                         1597965.75
# 2020-11-16                         3617220.16
# 2020-11-17                         3029739.73
# 2020-11-18                         2929005.58
#             transactions/transfers_volume_adjusted_sum
# Date
# 2019-11-14                                   543473.22
# 2019-11-15                                   667857.35
# 2019-11-16                                   368486.15
# 2019-11-17                                   307901.12
# 2019-11-18                                   551766.90

# %%
# 1 Minute Break for API Request - Only 30 Requests per Minute Possible
time.sleep(60)

# %% [markdown]
# #### Exchange Metrics from Glassnode - 1 Month Lag

# %%
# List of Exchange Features
exchange_feature_list = ['transactions/transfers_volume_to_exchanges_sum', 'transactions/transfers_volume_from_exchanges_sum', 'transactions/transfers_to_exchanges_count', 'transactions/transfers_from_exchanges_count', 'distribution/balance_exchanges', 'transactions/transfers_volume_exchanges_net']

# %%
# Data Frame of Exchange Features
df_exchange = import_glassnode_many(exchange_feature_list)
# Out:
#             transactions/transfers_volume_to_exchanges_sum
# Date
# 2019-11-14                                        28405.85
# 2019-11-15                                        41231.14
# 2019-11-16                                        14253.71
# 2019-11-17                                        13094.65
# 2019-11-18                                        48367.09
#             transactions/transfers_volume_from_exchanges_sum
# Date
# 2019-11-14                                          48108.53
# 2019-11-15                                          42353.78
# 2019-11-16                                          13742.74
# 2019-11-17                                          11975.30
# 2019-11-18                                          37648.47
#             transactions/transfers_to_exchanges_count
# Date
# 2019-11-14                                   33999.00
# 2019-11-15                                   35873.00
# 2019-11-16                                   28593.00
# 2019-11-17                                   25904.00
# 2019-11-18                                   34675.00
#             transactions/transfers_from_exchanges_count
# Date
# 2019-11-14                                     27016.00
# 2019-11-15                                     28885.00
# 2019-11-16                                     21921.00
# 2019-11-17                                     19959.00
# 2019-11-18                                     27234.00
#             distribution/balance_exchanges
# Date
# 2019-11-14                      2855400.88
# 2019-11-15                      2854270.61
# 2019-11-16                      2854775.26
# 2019-11-17                      2855888.70
# 2019-11-18                      2866600.12
#             transactions/transfers_volume_exchanges_net
# Date
# 2019-11-14                                    -19702.68
# 2019-11-15                                     -1122.64
# 2019-11-16                                       510.97
# 2019-11-17                                      1119.35
# 2019-11-18                                     10718.62

# %% [markdown]
# #### Indicator-I Metrics from Glassnode

# %%
# List of Indicator-1 Features
indicator1_feature_list = ['indicators/sopr_adjusted', 'indicators/nvt', 'indicators/velocity', 'indicators/cdd', 'indicators/reserve_risk', 'indicators/average_dormancy', 'indicators/liveliness']

# %%
# Data Frame of Indicator-1 Features
df_indicator1 = import_glassnode_many(indicator1_feature_list)
# Out:
#             indicators/sopr_adjusted
# Date
# 2019-11-14                      0.99
# 2019-11-15                      1.00
# 2019-11-16                      0.99
# 2019-11-17                      1.00
# 2019-11-18                      0.99
#             indicators/nvt
# Date
# 2019-11-14           33.21
# 2019-11-15           27.03
# 2019-11-16           48.99
# 2019-11-17           58.63
# 2019-11-18           32.72
#             indicators/velocity
# Date
# 2019-11-14                 0.03
# 2019-11-15                 0.04
# 2019-11-16                 0.02
# 2019-11-17                 0.02
# 2019-11-18                 0.03
#             indicators/cdd
# Date
# 2019-11-14      3694850.50
# 2019-11-15      7267692.47
# 2019-11-16      1405992.23
# 2019-11-17      1728080.37
# 2019-11-18     13992589.04
#             indicators/reserve_risk
# Date
# 2019-11-14                     0.00
# 2019-11-15                     0.00
# 2019-11-16                     0.00
# 2019-11-17                     0.00
# 2019-11-18                     0.00
#             indicators/average_dormancy
# Date
# 2019-11-14                         6.80
# 2019-11-15                        10.88
# 2019-11-16                         3.82
# 2019-11-17                         5.61
# 2019-11-18                        25.36
#             indicators/liveliness
# Date
# 2019-11-14                   0.61
# 2019-11-15                   0.61
# 2019-11-16                   0.61
# 2019-11-17                   0.61
# 2019-11-18                   0.61

# %% [markdown]
# #### Indicator-2 Metrics from Glassnode

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['indicators/asol', 'indicators/sol_1h', 'indicators/sol_1h_24h', 'indicators/sol_1d_1w', 'indicators/sol_1w_1m', 'indicators/sol_1m_3m', 'indicators/sol_3m_6m', 'indicators/sol_6m_12m', 'indicators/sol_1y_2y', 'indicators/sol_2y_3y', 'indicators/sol_3y_5y', 'indicators/sol_5y_7y', 'indicators/sol_7y_10y']

# %%
# Data Frame of Indicator-2 Features
df_indicator2 = import_glassnode_many(indicator2_feature_list)
# Out:
#             indicators/asol
# Date
# 2019-11-14            35.50
# 2019-11-15            97.66
# 2019-11-16           162.89
# 2019-11-17           177.80
# 2019-11-18            34.34
#             indicators/sol_1h
# Date
# 2019-11-14          275522.00
# 2019-11-15          249930.00
# 2019-11-16          217239.00
# 2019-11-17          207986.00
# 2019-11-18          230794.00
#             indicators/sol_1h_24h
# Date
# 2019-11-14              214998.00
# 2019-11-15              219319.00
# 2019-11-16              185684.00
# 2019-11-17              151618.00
# 2019-11-18              183717.00
#             indicators/sol_1d_1w
# Date
# 2019-11-14              96722.00
# 2019-11-15             104549.00
# 2019-11-16              87468.00
# 2019-11-17             112941.00
# 2019-11-18             121115.00
#             indicators/sol_1w_1m
# Date
# 2019-11-14              65361.00
# 2019-11-15              57803.00
# 2019-11-16              59366.00
# 2019-11-17              43709.00
# 2019-11-18              48820.00
#             indicators/sol_1m_3m
# Date
# 2019-11-14              55975.00
# 2019-11-15              42933.00
# 2019-11-16              41111.00
# 2019-11-17              44040.00
# 2019-11-18              35178.00
#             indicators/sol_3m_6m
# Date
# 2019-11-14              26318.00
# 2019-11-15              40283.00
# 2019-11-16              58241.00
# 2019-11-17              59580.00
# 2019-11-18              20172.00
#             indicators/sol_6m_12m
# Date
# 2019-11-14                6010.00
# 2019-11-15               49731.00
# 2019-11-16               95531.00
# 2019-11-17              105607.00
# 2019-11-18                8010.00
#             indicators/sol_1y_2y
# Date
# 2019-11-14               9664.00
# 2019-11-15              62429.00
# 2019-11-16             130800.00
# 2019-11-17             147349.00
# 2019-11-18               6262.00
#             indicators/sol_2y_3y
# Date
# 2019-11-14               1069.00
# 2019-11-15               1123.00
# 2019-11-16               1022.00
# 2019-11-17               1174.00
# 2019-11-18               1407.00
#             indicators/sol_3y_5y
# Date
# 2019-11-14                652.00
# 2019-11-15                495.00
# 2019-11-16                961.00
# 2019-11-17                666.00
# 2019-11-18               1223.00
#             indicators/sol_5y_7y
# Date
# 2019-11-14                244.00
# 2019-11-15                151.00
# 2019-11-16                182.00
# 2019-11-17                199.00
# 2019-11-18                359.00
#             indicators/sol_7y_10y
# Date
# 2019-11-14                   1.00
# 2019-11-15                   0.00
# 2019-11-16                   4.00
# 2019-11-17                  19.00
# 2019-11-18                   1.00

# %%
# 1 Minute Break for API Request - Only 30 Requests per Minute Possible
time.sleep(60)

# %% [markdown]
# #### Indicator-3 Metrics from Glassnode

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['indicators/net_unrealized_profit_loss', 'indicators/unrealized_profit', 'indicators/unrealized_loss', 'indicators/net_realized_profit_loss', 'indicators/realized_profit', 'indicators/realized_loss', 'indicators/nupl_more_155', 'indicators/nupl_less_155', 'indicators/puell_multiple', 'indicators/stock_to_flow_deflection', 'indicators/difficulty_ribbon_compression']

# %%
# Data Frame of Indicator-3 Features
df_indicator3 = import_glassnode_many(indicator3_feature_list)
# Out:
#             indicators/net_unrealized_profit_loss
# Date
# 2019-11-14                                   0.34
# 2019-11-15                                   0.33
# 2019-11-16                                   0.33
# 2019-11-17                                   0.33
# 2019-11-18                                   0.31
#             indicators/unrealized_profit
# Date
# 2019-11-14                          0.42
# 2019-11-15                          0.41
# 2019-11-16                          0.41
# 2019-11-17                          0.41
# 2019-11-18                          0.40
#             indicators/unrealized_loss
# Date
# 2019-11-14                        0.07
# 2019-11-15                        0.08
# 2019-11-16                        0.08
# 2019-11-17                        0.08
# 2019-11-18                        0.09
#             indicators/net_realized_profit_loss
# Date
# 2019-11-14                         -22865595.85
# 2019-11-15                         -20717261.56
# 2019-11-16                         -17889883.92
# 2019-11-17                            -69892.23
# 2019-11-18                         -46597810.37
#             indicators/realized_profit
# Date
# 2019-11-14                 25837270.59
# 2019-11-15                 42449727.36
# 2019-11-16                 10148071.23
# 2019-11-17                 16481605.66
# 2019-11-18                 41882858.70
#             indicators/realized_loss
# Date
# 2019-11-14               48702866.44
# 2019-11-15               63166988.92
# 2019-11-16               28037955.14
# 2019-11-17               16551497.89
# 2019-11-18               88480669.07
#             indicators/nupl_more_155
# Date
# 2019-11-14                      0.46
# 2019-11-15                      0.44
# 2019-11-16                      0.44
# 2019-11-17                      0.44
# 2019-11-18                      0.43
#             indicators/nupl_less_155
# Date
# 2019-11-14                     -0.11
# 2019-11-15                     -0.14
# 2019-11-16                     -0.13
# 2019-11-17                     -0.13
# 2019-11-18                     -0.16
#             indicators/puell_multiple
# Date
# 2019-11-14                       1.43
# 2019-11-15                       1.31
# 2019-11-16                       1.22
# 2019-11-17                       1.28
# 2019-11-18                       1.15
#             indicators/stock_to_flow_deflection
# Date
# 2019-11-14                                 1.05
# 2019-11-15                                 1.02
# 2019-11-16                                 1.03
# 2019-11-17                                 1.03
# 2019-11-18                                 1.00
#             indicators/difficulty_ribbon_compression
# Date
# 2019-11-14                                      0.09
# 2019-11-15                                      0.09
# 2019-11-16                                      0.09
# 2019-11-17                                      0.09
# 2019-11-18                                      0.09

# %% [markdown]
# #### Addresses Metrics from Glassnode

# %%
# List of Addresses Features
addresses_feature_list = ['addresses/active_count', 'addresses/sending_count', 'addresses/receiving_count', 'addresses/new_non_zero_count', 'addresses/non_zero_count', 'addresses/min_point_zero_1_count','addresses/min_point_1_count', 'addresses/min_1_count', 'addresses/min_10_count', 'addresses/min_100_count', 'addresses/min_1k_count', 'addresses/min_10k_count']

# %%
# Data Frame of Addresses Features
df_addresses = import_glassnode_many(addresses_feature_list)
# Out:
#             addresses/active_count
# Date
# 2020-11-14               916241.00
# 2020-11-15               859865.00
# 2020-11-16              1036960.00
# 2020-11-17              1134731.00
# 2020-11-18              1187942.00
#             addresses/sending_count
# Date
# 2020-11-14                578027.00
# 2020-11-15                559028.00
# 2020-11-16                663147.00
# 2020-11-17                706546.00
# 2020-11-18                750796.00
#             addresses/receiving_count
# Date
# 2020-11-14                  613361.00
# 2020-11-15                  555358.00
# 2020-11-16                  681255.00
# 2020-11-17                  770674.00
# 2020-11-18                  807692.00
#             addresses/new_non_zero_count
# Date
# 2020-11-14                     449703.00
# 2020-11-15                     407914.00
# 2020-11-16                     493329.00
# 2020-11-17                     558880.00
# 2020-11-18                     581082.00
#             addresses/non_zero_count
# Date
# 2019-11-14               27746740.00
# 2019-11-15               27796663.00
# 2019-11-16               27822902.00
# 2019-11-17               27836570.00
# 2019-11-18               27869049.00
#             addresses/min_point_zero_1_count
# Date
# 2019-11-14                        7647928.00
# 2019-11-15                        7654573.00
# 2019-11-16                        7662899.00
# 2019-11-17                        7668564.00
# 2019-11-18                        7677843.00
#             addresses/min_point_1_count
# Date
# 2019-11-14                   2800078.00
# 2019-11-15                   2801324.00
# 2019-11-16                   2800653.00
# 2019-11-17                   2800393.00
# 2019-11-18                   2803381.00
#             addresses/min_1_count
# Date
# 2019-11-14              783515.00
# 2019-11-15              784472.00
# 2019-11-16              783023.00
# 2019-11-17              783337.00
# 2019-11-18              784431.00
#             addresses/min_10_count
# Date
# 2019-11-14               153134.00
# 2019-11-15               153033.00
# 2019-11-16               153069.00
# 2019-11-17               153147.00
# 2019-11-18               153299.00
#             addresses/min_100_count
# Date
# 2019-11-14                 16204.00
# 2019-11-15                 16205.00
# 2019-11-16                 16234.00
# 2019-11-17                 16236.00
# 2019-11-18                 16230.00
#             addresses/min_1k_count
# Date
# 2019-11-14                 2154.00
# 2019-11-15                 2159.00
# 2019-11-16                 2156.00
# 2019-11-17                 2153.00
# 2019-11-18                 2153.00
#             addresses/min_10k_count
# Date
# 2019-11-14                   110.00
# 2019-11-15                   110.00
# 2019-11-16                   110.00
# 2019-11-17                   110.00
# 2019-11-18                   109.00

# %% [markdown]
# #### Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Futures Features
# futures_feature_list = ['derivatives/futures_volume_daily_all_sum', 'derivatives/futures_volume_daily_perpetual_sum', 'derivatives/futures_open_interest_all_sum', 'derivatives/futures_open_interest_perpetual_sum', 'derivatives/futures_funding_rate_perpetual']

# %% [markdown]
# ##### Data Frame of Future features
# df_futures = import_glassnode_many(futures_feature_list)

# %% [markdown]
# ## File Import and Data Tidying

# %%
# Import of Modules and Packages
import os
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.6f}'.format

# %% [markdown]
# ### Import Blockchain CSV-Files

# %% [markdown]
# #### Market Metric CSV-Files

# %%
# List of Market Features
market_feature_list = ['price_usd_close', 'price_drawdown_relative', 'price_realized_usd', 'mvrv']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in market_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_market = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_market.columns:
    try:
        df_market["{}".format(y)] = df_market["{}".format(y)].str.replace(',','.')
        df_market["{}".format(y)] = df_market["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Market Metric Values
df_market.tail()
# Out:
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2020-09-05            10169.567221                       -0.486695
# 2020-09-06            10280.351703                       -0.481103
# 2020-09-07            10369.563739                       -0.476600
# 2020-09-08            10131.516646                       -0.488615
# 2020-09-09            10242.347780                       -0.483021
#
#             market/price_realized_usd  market/mvrv
# Date
# 2020-09-05                6211.499707     1.658554
# 2020-09-06                6210.008152     1.646271
# 2020-09-07                6207.098565     1.639718
# 2020-09-08                6207.190589     1.637774
# 2020-09-09                6204.759023     1.644332

# %% [markdown]
# #### Mining Metric CSV-Files

# %%
# List of Mining Features
mining_feature_list = ['difficulty_latest', 'hash_rate_mean', 'revenue_sum','marketcap_thermocap_ratio']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in mining_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame    
df_mining = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_mining.columns:
    try:
        df_mining["{}".format(y)] = df_mining["{}".format(y)].str.replace(',','.')
        df_mining["{}".format(y)] = df_mining["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Mining Metric Values
df_mining.tail()
# Out:
#                  mining/difficulty_latest        mining/hash_rate_mean  \
# Date
# 2020-09-05 75411005869439401852928.000000 123489638432487997440.000000
# 2020-09-06 75411005869439401852928.000000 131717679503667003392.000000
# 2020-09-07 74500493292953204162560.000000 150352516655708995584.000000
# 2020-09-08 74500493292953204162560.000000 133450167690280992768.000000
# 2020-09-09 74500493292953204162560.000000 129306481305694994432.000000
#
#             mining/revenue_sum  mining/marketcap_thermocap_ratio
# Date
# 2020-09-05         1001.139638                          0.000001
# 2020-09-06         1008.237179                          0.000001
# 2020-09-07         1190.467910                          0.000001
# 2020-09-08         1052.811853                          0.000001
# 2020-09-09         1020.445800                          0.000001

# %% [markdown]
# #### Blocks Metric CSV-Files

# %%
# List of Blockchain Features
block_feature_list = ['block_count', 'block_interval_mean', 'block_size_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in block_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_blockfeatures = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_blockfeatures.columns:
    try:
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].str.replace(',','.')
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].astype(float)
    except:
        pass

# %%
# Show Latest Feature Values
df_blockfeatures.tail()
# Out:
#             blockchain/block_count  blockchain/block_interval_mean  \
# Date
# 2020-10-05              140.000000                      617.328571
# 2020-10-06              130.000000                      668.361538
# 2020-10-07              151.000000                      561.801325
# 2020-10-08              162.000000                      542.246914
# 2020-10-09              142.000000                      610.232394
#
#             blockchain/block_size_sum
# Date
# 2020-10-05           167965395.000000
# 2020-10-06           169091960.000000
# 2020-10-07           193107049.000000
# 2020-10-08           198240304.000000
# 2020-10-09           186523246.000000

# %% [markdown]
# #### Distribution Metric CSV-Files

# %%
# List of Distribution Features
distribution_feature_list = ['balance_1pct_holders', 'gini', 'herfindahl']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in distribution_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        # Data Frame Setup
        df_new = df
    
    # Increase Counter    
    counter +=1

# Store Data Frame Copy in Distribution Data Frame    
df_distribution = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_distribution.columns:
    try:
        df_distribution["{}".format(y)] = df_distribution["{}".format(y)].str.replace(',','.')
        df_distribution["{}".format(y)] = df_distribution["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Distribution Metric Values
df_distribution.tail()
# Out:
#             distribution/balance_1pct_holders  distribution/gini  \
# Date
# 2020-09-05                           0.890939           0.987210
# 2020-09-06                           0.890973           0.987214
# 2020-09-07                           0.890878           0.987196
# 2020-09-08                           0.890821           0.987184
# 2020-09-09                           0.890752           0.987169
#
#             distribution/herfindahl
# Date
# 2020-09-05                 0.000263
# 2020-09-06                 0.000264
# 2020-09-07                 0.000263
# 2020-09-08                 0.000263
# 2020-09-09                 0.000264

# %% [markdown]
# #### Fee Metric CSV-Files

# %%
# List of Fee Features
fees_feature_list = ['volume_sum', 'volume_mean', 'fee_ratio_multiple']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in fees_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date') #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
        
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Fees Data Frame    
df_fees = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_fees.columns:
    try:
        df_fees["{}".format(y)] = df_fees["{}".format(y)].str.replace(',','.')
        df_fees["{}".format(y)] = df_fees["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Fee Metric Values
df_fees.tail()
# Out:
#             fees/volume_sum  fees/volume_mean  fees/fee_ratio_multiple
# Date
# 2020-09-05       119.889638          0.000368                 8.350510
# 2020-09-06        70.737179          0.000269                14.253285
# 2020-09-07        96.717910          0.000295                12.308660
# 2020-09-08        84.061853          0.000253                12.524252
# 2020-09-09        89.195800          0.000283                11.440514

# %% [markdown]
# #### UTXO Metric CSV-Files

# %%
# List of UTXO Features
utxo_feature_list = ['utxo_created_count', 'utxo_spent_count','utxo_created_value_sum', 'utxo_spent_value_sum', 'utxo_profit_relative', 'utxo_profit_count', 'utxo_loss_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in utxo_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df

    # Increase Counter
    counter +=1

# Store Data Frame Copy in UTXO Data Frame
df_utxo = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_utxo.columns:
    try:
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].str.replace(',','.')
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest UTXO Metric Values
df_utxo.tail()
# Out:
#             blockchain/utxo_created_count  blockchain/utxo_spent_count  \
# Date
# 2020-09-05                  925701.000000                839626.000000
# 2020-09-06                  747957.000000                997263.000000
# 2020-09-07                  912702.000000               1069859.000000
# 2020-09-08                  933802.000000                872714.000000
# 2020-09-09                  907595.000000                809305.000000
#
#             blockchain/utxo_created_value_sum  \
# Date
# 2020-09-05                     2428545.247330
# 2020-09-06                     2294692.652075
# 2020-09-07                     2985927.900432
# 2020-09-08                     2703153.939851
# 2020-09-09                     3188715.629767
#
#             blockchain/utxo_spent_value_sum  blockchain/utxo_profit_relative  \
# Date
# 2020-09-05                   2427663.997330                         0.832917
# 2020-09-06                   2293755.152075                         0.847663
# 2020-09-07                   2984834.150432                         0.861291
# 2020-09-08                   2702185.189851                         0.831366
# 2020-09-09                   3187784.379767                         0.846510
#
#             blockchain/utxo_profit_count  blockchain/utxo_loss_count
# Date
# 2020-09-05               94240815.000000             18904623.000000
# 2020-09-06               95697864.000000             17198268.000000
# 2020-09-07               97101066.000000             15632606.000000
# 2020-09-08               93778111.000000             19014662.000000
# 2020-09-09               95569553.000000             17328800.000000

# %% [markdown]
# #### Supply Metric CSV-Files

# %%
# List of Supply Features
supply_feature_list = ['current','profit_relative', 'profit_sum', 'loss_sum', 'active_more_1y_percent', 'active_more_2y_percent', 'active_more_3y_percent', 'active_more_5y_percent', 'active_24h', 'active_1d_1w', 'active_1w_1m', 'active_1m_3m', 'active_3m_6m', 'active_6m_12m', 'active_1y_2y', 'active_2y_3y', 'active_3y_5y', 'active_5y_7y', 'active_7y_10y', 'active_more_10y', 'issued', 'inflation_rate']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in supply_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Supply Data Frame    
df_supply = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_supply.columns:
    try:
        df_supply["{}".format(y)] = df_supply["{}".format(y)].str.replace(',','.')
        df_supply["{}".format(y)] = df_supply["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Supply Metric Values
df_supply.tail()
# Out:
#             supply/current  supply/profit_relative  supply/profit_sum  \
# Date
# 2020-09-05 18480650.000000                0.783486    14469173.790002
# 2020-09-06 18481587.500000                0.792496    14636306.944967
# 2020-09-07 18482681.250000                0.804938    14866964.527154
# 2020-09-08 18483650.000000                0.783258    14467315.643342
# 2020-09-09 18484581.250000                0.794971    14684389.936085
#
#             supply/loss_sum  supply/active_more_1y_percent  \
# Date
# 2020-09-05   3998505.805496                       0.634489
# 2020-09-06   3832310.150531                       0.634314
# 2020-09-07   3601637.538862                       0.634205
# 2020-09-08   3980531.109461                       0.634162
# 2020-09-09   3787220.909413                       0.634064
#
#             supply/active_more_2y_percent  supply/active_more_3y_percent  \
# Date
# 2020-09-05                       0.445548                       0.308462
# 2020-09-06                       0.445496                       0.308816
# 2020-09-07                       0.445498                       0.309087
# 2020-09-08                       0.445434                       0.309335
# 2020-09-09                       0.445411                       0.309538
#
#             supply/active_more_5y_percent  supply/active_24h  \
# Date
# 2020-09-05                       0.221502      175335.661985
# 2020-09-06                       0.221571      151096.858008
# 2020-09-07                       0.221602      221178.322319
# 2020-09-08                       0.221628      206674.160374
# 2020-09-09                       0.221628      216157.470549
#
#             supply/active_1d_1w  ...  supply/active_3m_6m  \
# Date                             ...
# 2020-09-05        678373.873689  ...       1657062.036439
# 2020-09-06        702575.835108  ...       1659170.475326
# 2020-09-07        583815.632521  ...       1654505.193763
# 2020-09-08        551707.748592  ...       1632537.485685
# 2020-09-09        527859.794664  ...       1580106.647402
#
#             supply/active_6m_12m  supply/active_1y_2y  supply/active_2y_3y  \
# Date
# 2020-09-05        1822226.476150       3491765.045316       2533434.793751
# 2020-09-06        1828106.808315       3489658.019463       2526058.318393
# 2020-09-07        1835875.455344       3487806.260101       2521244.942070
# 2020-09-08        1862435.161095       3488377.160182       2515602.683376
# 2020-09-09        1911659.761397       3487173.233428       2511552.370232
#
#             supply/active_3y_5y  supply/active_5y_7y  supply/active_7y_10y  \
# Date
# 2020-09-05       1607071.603475       1045528.172318        1337951.267960
# 2020-09-06       1612439.302114       1045849.879701        1337600.520433
# 2020-09-07       1616962.904250       1046398.894270        1335757.709378
# 2020-09-08       1621156.970465       1046728.562786        1334344.248736
# 2020-09-09       1624969.166269       1044889.609220        1335050.951617
#
#             supply/active_more_10y  supply/issued  supply/inflation_rate
# Date
# 2020-09-05          1710025.400001     881.250000               0.017557
# 2020-09-06          1711524.770001     937.500000               0.018687
# 2020-09-07          1713637.800001    1093.750000               0.021834
# 2020-09-08          1715415.020001     968.750000               0.019314
# 2020-09-09          1716766.550001     931.250000               0.018558
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Transaction Metric CSV-Files

# %%
# List of Transaction features
transaction_feature_list = ['count', 'size_sum','transfers_volume_sum', 'transfers_volume_adjusted_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in transaction_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Transaction Data Frame
df_transaction = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_transaction.columns:
    try:
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].str.replace(',','.')
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Transaction Metric Values
df_transaction.tail()
# Out:
#             transactions/count  transactions/size_sum  \
# Date
# 2020-09-05       325382.000000       179872382.000000
# 2020-09-06       262670.000000       213209020.000000
# 2020-09-07       327487.000000       224017559.000000
# 2020-09-08       332513.000000       193608771.000000
# 2020-09-09       314715.000000       177932171.000000
#
#             transactions/transfers_volume_sum  \
# Date
# 2020-09-05                     2427544.107692
# 2020-09-06                     2293684.414896
# 2020-09-07                     2984737.432522
# 2020-09-08                     2702101.127999
# 2020-09-09                     3187695.183966
#
#             transactions/transfers_volume_adjusted_sum
# Date
# 2020-09-05                               480993.837158
# 2020-09-06                               348972.268069
# 2020-09-07                               568893.911576
# 2020-09-08                               542331.281634
# 2020-09-09                               526944.230915

# %% [markdown]
# #### Exchange Metrics CSV-Files

# %%
# List of Exchange Features
exchange_feature_list = ['transfers_volume_to_exchanges_sum', 'transfers_volume_from_exchanges_sum', 'transfers_to_exchanges_count', 
                         'transfers_from_exchanges_count', 'balance_exchanges', 'transfers_volume_exchanges_net']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in exchange_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Exchange Data Frame    
df_exchange = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_exchange.columns:
    try:
        df_exchange["{}".format(y)] = df_exchange["{}".format(y)].str.replace(',','.')
        df_exchange["{}".format(y)] = df_exchange["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Exchange Metric Values
df_exchange.tail()
# Out:
#             transactions/transfers_volume_to_exchanges_sum  \
# Date
# 2020-09-05                                    53962.884790
# 2020-09-06                                    31456.336042
# 2020-09-07                                    52941.250815
# 2020-09-08                                    58024.846185
# 2020-09-09                                    49015.406219
#
#             transactions/transfers_volume_from_exchanges_sum  \
# Date
# 2020-09-05                                      51027.600140
# 2020-09-06                                      31973.120103
# 2020-09-07                                      54976.821228
# 2020-09-08                                      55913.185665
# 2020-09-09                                      56092.802659
#
#             transactions/transfers_to_exchanges_count  \
# Date
# 2020-09-05                               53500.000000
# 2020-09-06                               39986.000000
# 2020-09-07                               49756.000000
# 2020-09-08                               49709.000000
# 2020-09-09                               47085.000000
#
#             transactions/transfers_from_exchanges_count  \
# Date
# 2020-09-05                                 35980.000000
# 2020-09-06                                 30536.000000
# 2020-09-07                                 36567.000000
# 2020-09-08                                 38397.000000
# 2020-09-09                                 36679.000000
#
#             distribution/balance_exchanges  \
# Date
# 2020-09-05                  2648079.155227
# 2020-09-06                  2647552.890663
# 2020-09-07                  2645507.052860
# 2020-09-08                  2647609.948049
# 2020-09-09                  2640524.461597
#
#             transactions/transfers_volume_exchanges_net
# Date
# 2020-09-05                                  2935.284650
# 2020-09-06                                  -516.784061
# 2020-09-07                                 -2035.570413
# 2020-09-08                                  2111.660520
# 2020-09-09                                 -7077.396440

# %% [markdown]
# #### Indicator-1 Metric CSV-Files

# %%
# List of Indicator-1 features
indicator1_feature_list = ['sopr_adjusted', 'nvt', 'velocity', 'cdd','reserve_risk', 'average_dormancy', 'liveliness'] 

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator1_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-1 Data Frame    
df_indicator1 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator1.columns:
    try:
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].str.replace(',','.')
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-1 Metric Values
df_indicator1.tail()
# Out:
#             indicators/sopr_adjusted  indicators/nvt  indicators/velocity  \
# Date
# 2020-09-05                  0.984660       38.421802             0.026027
# 2020-09-06                  0.994371       52.960046             0.018882
# 2020-09-07                  0.983302       32.488801             0.030780
# 2020-09-08                  0.992893       34.081844             0.029341
# 2020-09-09                  0.994115       35.078819             0.028507
#
#             indicators/cdd  indicators/reserve_risk  \
# Date
# 2020-09-05  6397277.756080                 0.001843
# 2020-09-06  6168054.324518                 0.001827
# 2020-09-07  5445931.881983                 0.001817
# 2020-09-08  5112802.499078                 0.001813
# 2020-09-09  7244463.878951                 0.001818
#
#             indicators/average_dormancy  indicators/liveliness
# Date
# 2020-09-05                    13.300124               0.597944
# 2020-09-06                    17.674913               0.597853
# 2020-09-07                     9.572843               0.597742
# 2020-09-08                     9.427453               0.597622
# 2020-09-09                    13.748066               0.597536

# %% [markdown]
# #### Indicator-2 Metrics CSV-Files

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['asol', 'sol_1h', 'sol_1h_24h', 'sol_1d_1w','sol_1w_1m', 'sol_1m_3m', 'sol_3m_6m', 'sol_6m_12m','sol_1y_2y', 'sol_2y_3y', 'sol_3y_5y', 'sol_5y_7y', 'sol_7y_10y']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator2_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-2 Data Frame
df_indicator2 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator2.columns:
    try:
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].str.replace(',','.')
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-2 Metric Values
df_indicator2.tail()
# Out:
#             indicators/asol  indicators/sol_1h  indicators/sol_1h_24h  \
# Date
# 2020-09-05        23.303986      208408.000000          310222.000000
# 2020-09-06        26.525989      164268.000000          264299.000000
# 2020-09-07        24.863023      241307.000000          304534.000000
# 2020-09-08        36.178580      233048.000000          313106.000000
# 2020-09-09        27.408392      215810.000000          312450.000000
#
#             indicators/sol_1d_1w  indicators/sol_1w_1m  indicators/sol_1m_3m  \
# Date
# 2020-09-05         190765.000000          70913.000000          30428.000000
# 2020-09-06         377874.000000         111198.000000          36821.000000
# 2020-09-07         347322.000000         102984.000000          34980.000000
# 2020-09-08         168385.000000          67799.000000          34684.000000
# 2020-09-09         137975.000000          76905.000000          28601.000000
#
#             indicators/sol_3m_6m  indicators/sol_6m_12m  indicators/sol_1y_2y  \
# Date
# 2020-09-05          12582.000000            6917.000000           4596.000000
# 2020-09-06          15127.000000           11207.000000          10826.000000
# 2020-09-07          15385.000000            9753.000000           8414.000000
# 2020-09-08          22886.000000           17386.000000          10367.000000
# 2020-09-09          15676.000000           12605.000000           5063.000000
#
#             indicators/sol_2y_3y  indicators/sol_3y_5y  indicators/sol_5y_7y  \
# Date
# 2020-09-05           2715.000000           1467.000000            598.000000
# 2020-09-06           3337.000000           1582.000000            659.000000
# 2020-09-07           2836.000000           1182.000000            149.000000
# 2020-09-08           2462.000000           1418.000000            554.000000
# 2020-09-09           1686.000000           1913.000000            576.000000
#
#             indicators/sol_7y_10y
# Date
# 2020-09-05              15.000000
# 2020-09-06              65.000000
# 2020-09-07            1013.000000
# 2020-09-08             619.000000
# 2020-09-09              45.000000

# %% [markdown]
# #### Indicator-3 Metrics CSV-Files

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['net_unrealized_profit_loss', 'unrealized_profit', 'unrealized_loss', 'net_realized_profit_loss', 'realized_profit', 'realized_loss', 'nupl_more_155', 'nupl_less_155', 'puell_multiple', 'stock_to_flow_deflection', 'difficulty_ribbon_compression']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator3_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-3 Data Frame
df_indicator3 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator3.columns:
    try:
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].str.replace(',','.')
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-3 Metric Values
df_indicator3.tail()
# Out:
#             indicators/net_unrealized_profit_loss  \
# Date
# 2020-09-05                               0.389151
# 2020-09-06                               0.395802
# 2020-09-07                               0.401342
# 2020-09-08                               0.387441
# 2020-09-09                               0.394155
#
#             indicators/unrealized_profit  indicators/unrealized_loss  \
# Date
# 2020-09-05                      0.425496                    0.036344
# 2020-09-06                      0.429177                    0.033375
# 2020-09-07                      0.432245                    0.030902
# 2020-09-08                      0.423610                    0.036169
# 2020-09-09                      0.427354                    0.033199
#
#             indicators/net_realized_profit_loss  indicators/realized_profit  \
# Date
# 2020-09-05                     -61851863.965988             47222360.380414
# 2020-09-06                     -16733697.235759             55132755.501418
# 2020-09-07                     -69834053.851105             69159303.574316
# 2020-09-08                     -34616584.664973             57932183.512442
# 2020-09-09                     -19888002.740329             63696979.798852
#
#             indicators/realized_loss  indicators/nupl_more_155  \
# Date
# 2020-09-05          109074224.346402                  0.453316
# 2020-09-06           71866452.737177                  0.459436
# 2020-09-07          138993357.425421                  0.464243
# 2020-09-08           92548768.177415                  0.451633
# 2020-09-09           83584982.539181                  0.457918
#
#             indicators/nupl_less_155  indicators/puell_multiple  \
# Date
# 2020-09-05                 -0.013060                   0.686735
# 2020-09-06                 -0.001650                   0.727444
# 2020-09-07                  0.009046                   0.845757
# 2020-09-08                 -0.013745                   0.750200
# 2020-09-09                 -0.002911                   0.725566
#
#             indicators/stock_to_flow_deflection  \
# Date
# 2020-09-05                             0.612226
# 2020-09-06                             0.615408
# 2020-09-07                             0.616606
# 2020-09-08                             0.599242
# 2020-09-09                             0.601125
#
#             indicators/difficulty_ribbon_compression
# Date
# 2020-09-05                                  0.035154
# 2020-09-06                                  0.035243
# 2020-09-07                                  0.034681
# 2020-09-08                                  0.034149
# 2020-09-09                                  0.033648

# %% [markdown]
# #### Addresses Metric CSV-Files

# %%
# List of Addresses Features
addresses_feature_list = ['active_count', 'sending_count', 'receiving_count', 'new_non_zero_count', 'non_zero_count', 'min_point_zero_1_count', 'min_point_1_count', 'min_1_count', 'min_10_count', 'min_100_count', 'min_1k_count', 'min_10k_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in addresses_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Addresses Data Frame
df_addresses = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_addresses.columns:
    try:
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].str.replace(',','.')
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Addresses Metric Values
df_addresses.tail()
# Out:
#             addresses/active_count  addresses/sending_count  \
# Date
# 2020-09-05           980198.000000            599227.000000
# 2020-09-06           992013.000000            695956.000000
# 2020-09-07          1088277.000000            759464.000000
# 2020-09-08           980353.000000            630745.000000
# 2020-09-09           965163.000000            597952.000000
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-09-05              685725.000000                 473696.000000
# 2020-09-06              557361.000000                 398510.000000
# 2020-09-07              672708.000000                 478470.000000
# 2020-09-08              693529.000000                 498882.000000
# 2020-09-09              681412.000000                 484473.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-09-05           31282312.000000                    8596301.000000
# 2020-09-06           31123319.000000                    8521624.000000
# 2020-09-07           31009419.000000                    8496344.000000
# 2020-09-08           31046954.000000                    8500540.000000
# 2020-09-09           31096380.000000                    8517532.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-09-05               3135389.000000          822481.000000
# 2020-09-06               3124437.000000          822205.000000
# 2020-09-07               3125898.000000          822652.000000
# 2020-09-08               3130380.000000          823072.000000
# 2020-09-09               3134510.000000          823685.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-09-05           153779.000000             15982.000000
# 2020-09-06           153468.000000             15994.000000
# 2020-09-07           153364.000000             16011.000000
# 2020-09-08           153197.000000             15990.000000
# 2020-09-09           153145.000000             15986.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-09-05             2198.000000               106.000000
# 2020-09-06             2196.000000               106.000000
# 2020-09-07             2193.000000               106.000000
# 2020-09-08             2187.000000               105.000000
# 2020-09-09             2190.000000               104.000000

# %% [markdown]
# #### Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Future Features
# futures_feature_list = ['futures_volume_daily_all_sum', 'futures_volume_daily_perpetual_sum', 'futures_open_interest_all_sum', 'futures_open_interest_perpetual_sum', 'futures_funding_rate_perpetual']
#
# ##### Counter to Differentiate between Data Frame Setup and Data Frame Extension
# counter=0
#
# ##### For Loop through all Features in the List
# for x in futures_feature_list:
#
#     ##### Import Feature CSV-Files
#     df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
#
#     ##### Condition - Data Frame Set up or Data Frame Extension
#     if counter > 0:
#
#         ##### Data Frame Extension - Inner Join
#         df_new = df_new.join(df, how='inner')
#
#     else:
#
#         ##### Data Frame Setup
#         df_new = df
#
#     ##### Increase Counter
#     counter +=1
#
# ##### Store Data Frame Copy in Market Data Frame
# df_futures = df_new.copy()
#
# ##### Delete Original Data Frame
# del df_new
#
# ##### Change Data Type of Columns to Float
# for y in df_futures.columns:
#     try:
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].str.replace(',','.')
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].astype(float)
#     except:
#         pass

# %% [markdown]
# ## Target Variables

# %%
df_return = pd.DataFrame(df_market['market/price_usd_close'])

# %%
df_return.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_return['Daily Return in USD'] = df_return['Closed Price USD'].diff()

# %% [raw]
# # Add Column with BTC Daily Returns in Percent
# df_return['Daily Returns in Percent'] = (df_return['Daily Returns USD']) / (df_return['Closed Price USD'].shift(1))*100

# %% [raw]
# # Add Column with BTC Daily Log Returns in Percent
# df_return['Daily Log Returns in Percent'] = pd.DataFrame(np.log(df_return['Closed Price USD']/df_return['Closed Price USD'].shift(1))*100)

# %%
df_return.tail()
# Out:
#             Closed Price USD  Daily Return in USD
# Date
# 2020-09-05      10169.567221          -342.246660
# 2020-09-06      10280.351703           110.784482
# 2020-09-07      10369.563739            89.212035
# 2020-09-08      10131.516646          -238.047093
# 2020-09-09      10242.347780           110.831135

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Volatility

# %%
# Selecting BTC Close Price in USD
df_volatility = pd.DataFrame(df_market['market/price_usd_close'])

# %%
# Rename Price Column
df_volatility.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_volatility['Daily Return in USD'] = df_volatility['Closed Price USD'].diff()

# %%
# Add Column with BTC Daily Returns in Percent
df_volatility['Daily Return in Percent'] = (df_volatility['Daily Return in USD']) / (df_volatility['Closed Price USD'].shift(1))*100

# %%
# Add Column with BTC Daily Log Returns in Percent
df_volatility['Daily Log Return in Percent'] = pd.DataFrame(np.log(df_volatility['Closed Price USD']/df_volatility['Closed Price USD'].shift(1))*100)

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-09-05      10169.567221          -342.246660                -3.255829
# 2020-09-06      10280.351703           110.784482                 1.089373
# 2020-09-07      10369.563739            89.212035                 0.867792
# 2020-09-08      10131.516646          -238.047093                -2.295633
# 2020-09-09      10242.347780           110.831135                 1.093924
#
#             Daily Log Return in Percent
# Date
# 2020-09-05                    -3.310010
# 2020-09-06                     1.083482
# 2020-09-07                     0.864048
# 2020-09-08                    -2.322393
# 2020-09-09                     1.087984

# %%
# Calculation of Rolling Volatility of BTC Daily Log Returns for 10, 20 and 30 days period
df_volatility['Volatility Daily Log Return in Percent 3D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=3, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 5D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=5, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 10D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=10, min_periods=1).std())

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-09-05      10169.567221          -342.246660                -3.255829
# 2020-09-06      10280.351703           110.784482                 1.089373
# 2020-09-07      10369.563739            89.212035                 0.867792
# 2020-09-08      10131.516646          -238.047093                -2.295633
# 2020-09-09      10242.347780           110.831135                 1.093924
#
#             Daily Log Return in Percent  \
# Date
# 2020-09-05                    -3.310010
# 2020-09-06                     1.083482
# 2020-09-07                     0.864048
# 2020-09-08                    -2.322393
# 2020-09-09                     1.087984
#
#             Volatility Daily Log Return in Percent 3D  \
# Date
# 2020-09-05                                   6.786241
# 2020-09-06                                   3.083593
# 2020-09-07                                   2.475671
# 2020-09-08                                   1.906198
# 2020-09-09                                   1.907626
#
#             Volatility Daily Log Return in Percent 5D  \
# Date
# 2020-09-05                                   5.615865
# 2020-09-06                                   5.336722
# 2020-09-07                                   5.481009
# 2020-09-08                                   2.499613
# 2020-09-09                                   2.127506
#
#             Volatility Daily Log Return in Percent 10D
# Date
# 2020-09-05                                    4.198397
# 2020-09-06                                    4.258963
# 2020-09-07                                    4.193748
# 2020-09-08                                    4.199602
# 2020-09-09                                    4.154492

# %%
df_volatility_reduced = df_volatility['Volatility Daily Log Return in Percent 5D']

# %% [markdown]
# ### Log Price

# %%
# Selecting BTC Close Price in USD
df_logprice = pd.DataFrame(np.log(df_market['market/price_usd_close']))

# %%
df_logprice.columns = ['Log Price in USD']

# %%
df_logprice.tail()
# Out:
#             Log Price in USD
# Date
# 2020-09-05          9.227155
# 2020-09-06          9.237990
# 2020-09-07          9.246630
# 2020-09-08          9.223406
# 2020-09-09          9.234286

# %% [markdown]
# # Data Sets

# %% [markdown]
# ## Data Set I. - Blockchain Metrics Only

# %%
# Merging all Blockchain DataFrame Metrics
df_blockchain = pd.concat([df_return, df_logprice, df_volatility_reduced, df_market, df_mining, df_blockfeatures, df_distribution, df_fees, df_utxo, df_supply, 
                           df_transaction, df_exchange, df_indicator1, df_indicator2, df_indicator3, df_addresses], axis=1, join='inner')

# %%
df_blockchain = df_blockchain.dropna()

# %%
df_blockchain = df_blockchain.drop(['Closed Price USD'], axis=1)

# %%
df_blockchain.index = df_blockchain.index.astype('datetime64[ns]')

# %%
df_blockchain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3344 entries, 2011-07-16 to 2020-09-09
# Columns: 102 entries, Daily Return in USD to addresses/min_10k_count
# dtypes: float64(102)
# memory usage: 2.6 MB

# %%
df_blockchain.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-09-05          -342.246660          9.227155
# 2020-09-06           110.784482          9.237990
# 2020-09-07            89.212035          9.246630
# 2020-09-08          -238.047093          9.223406
# 2020-09-09           110.831135          9.234286
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-09-05                                   5.615865            10169.567221
# 2020-09-06                                   5.336722            10280.351703
# 2020-09-07                                   5.481009            10369.563739
# 2020-09-08                                   2.499613            10131.516646
# 2020-09-09                                   2.127506            10242.347780
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-09-05                       -0.486695                6211.499707
# 2020-09-06                       -0.481103                6210.008152
# 2020-09-07                       -0.476600                6207.098565
# 2020-09-08                       -0.488615                6207.190589
# 2020-09-09                       -0.483021                6204.759023
#
#             market/mvrv       mining/difficulty_latest  \
# Date
# 2020-09-05     1.658554 75411005869439401852928.000000
# 2020-09-06     1.646271 75411005869439401852928.000000
# 2020-09-07     1.639718 74500493292953204162560.000000
# 2020-09-08     1.637774 74500493292953204162560.000000
# 2020-09-09     1.644332 74500493292953204162560.000000
#
#                   mining/hash_rate_mean  mining/revenue_sum  ...  \
# Date                                                         ...
# 2020-09-05 123489638432487997440.000000         1001.139638  ...
# 2020-09-06 131717679503667003392.000000         1008.237179  ...
# 2020-09-07 150352516655708995584.000000         1190.467910  ...
# 2020-09-08 133450167690280992768.000000         1052.811853  ...
# 2020-09-09 129306481305694994432.000000         1020.445800  ...
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-09-05              685725.000000                 473696.000000
# 2020-09-06              557361.000000                 398510.000000
# 2020-09-07              672708.000000                 478470.000000
# 2020-09-08              693529.000000                 498882.000000
# 2020-09-09              681412.000000                 484473.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-09-05           31282312.000000                    8596301.000000
# 2020-09-06           31123319.000000                    8521624.000000
# 2020-09-07           31009419.000000                    8496344.000000
# 2020-09-08           31046954.000000                    8500540.000000
# 2020-09-09           31096380.000000                    8517532.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-09-05               3135389.000000          822481.000000
# 2020-09-06               3124437.000000          822205.000000
# 2020-09-07               3125898.000000          822652.000000
# 2020-09-08               3130380.000000          823072.000000
# 2020-09-09               3134510.000000          823685.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-09-05           153779.000000             15982.000000
# 2020-09-06           153468.000000             15994.000000
# 2020-09-07           153364.000000             16011.000000
# 2020-09-08           153197.000000             15990.000000
# 2020-09-09           153145.000000             15986.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-09-05             2198.000000               106.000000
# 2020-09-06             2196.000000               106.000000
# 2020-09-07             2193.000000               106.000000
# 2020-09-08             2187.000000               105.000000
# 2020-09-09             2190.000000               104.000000
#
# [5 rows x 102 columns]

# %%
# Summary of each variable
df_blockchain.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count          3344.000000       3344.000000
# mean              3.058773          6.279792
# std             225.487080          2.455966
# min           -3052.461475          0.718341
# 25%              -6.534588          5.295034
# 50%               0.095859          6.393392
# 75%              11.443671          8.746587
# max            3224.132131          9.882653
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                3344.000000             3344.000000
# mean                                    3.566279             2924.878496
# std                                     3.392327             3878.275231
# min                                     0.157723                2.051027
# 25%                                     1.531871              199.345387
# 50%                                     2.672647              597.881197
# 75%                                     4.446801             6289.187189
# max                                    41.749946            19587.613733
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                     3344.000000                3344.000000  3344.000000
# mean                        -0.555069                1805.961988     1.679730
# std                          0.229599                2303.813693     0.749288
# min                         -0.935694                   4.780226     0.402165
# 25%                         -0.720218                  69.300460     1.163912
# 50%                         -0.603482                 341.256743     1.580175
# 75%                         -0.458343                4610.358370     1.953875
# max                          0.000000                6219.679803     5.733982
#
#             mining/difficulty_latest        mining/hash_rate_mean  \
# count                    3344.000000                  3344.000000
# mean  12175171531858262360064.000000  20686986380631875584.000000
# std   20852044755581787963392.000000  35352772706990092288.000000
# min          4684588175054590.000000         6399665203131.940430
# 25%       1679026357970510080.000000      3408642057090500.000000
# 50%     618975430320051978240.000000   1078662194888004992.000000
# 75%   18498207565771700174848.000000  32589174816671752192.000000
# max   75411005869439401852928.000000 150352516655708995584.000000
#
#        mining/revenue_sum  ...  addresses/receiving_count  \
# count         3344.000000  ...                3344.000000
# mean          3552.759335  ...              315336.374701
# std           1933.478408  ...              223493.359800
# min            738.150148  ...                7539.000000
# 25%           1967.983825  ...               87953.000000
# 50%           3426.371382  ...              356018.000000
# 75%           4302.302926  ...              498151.500000
# max           9214.887810  ...             1072829.000000
#
#        addresses/new_non_zero_count  addresses/non_zero_count  \
# count                   3344.000000               3344.000000
# mean                  210148.206041           11669322.645634
# std                   155533.274874           10458853.833058
# min                     4241.000000             296738.000000
# 25%                    55479.000000            2013822.250000
# 50%                   215741.000000            6988090.500000
# 75%                   339647.750000           22249301.750000
# max                   800180.000000           31282312.000000
#
#        addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# count                       3344.000000                  3344.000000
# mean                     3336915.744019               1346774.656400
# std                      2827410.992229               1000395.450101
# min                       195085.000000                125059.000000
# 25%                       656507.500000                387254.250000
# 50%                      2432543.500000               1122513.000000
# 75%                      6333465.500000               2416907.250000
# max                      8605894.000000               3139207.000000
#
#        addresses/min_1_count  addresses/min_10_count  addresses/min_100_count  \
# count            3344.000000             3344.000000              3344.000000
# mean           461280.800239           124714.035586             14640.431519
# std            236468.714695            28903.588065              3668.678095
# min             98120.000000            64333.000000              3746.000000
# 25%            224272.000000            97109.750000             12781.750000
# 50%            468687.500000           137234.500000             16194.000000
# 75%            705807.750000           149574.000000             17180.000000
# max            823685.000000           157275.000000             18543.000000
#
#        addresses/min_1k_count  addresses/min_10k_count
# count             3344.000000              3344.000000
# mean              1604.180622               102.082536
# std                379.531818                14.903109
# min                597.000000                62.000000
# 25%               1449.000000                96.000000
# 50%               1670.000000               105.000000
# 75%               1832.000000               113.000000
# max               2209.000000               126.000000
#
# [8 rows x 102 columns]

# %%
# Creating CSV-File of Blockchain Data
df_blockchain.to_csv("df_dataset1.csv")

# %% [markdown]
# # Classification Models - Data Set Variations

# %%
# Import of Modules and Packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix, classification_report

# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from pycaret.classification import *

# Deep Neural Networks
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from keras.optimizers import Adam

# PyCaret
import pycaret

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Import Data Sets

# %% [markdown]
# ## Data Set I.

# %%
# CSV Import of Data Set I. - Blockchain Data
df_dataset1 = pd.read_csv('df_dataset1.csv', parse_dates = True, index_col='Date')

# %%
df_dataset1
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-07-16                -0.09              2.62
# 2011-07-17                -0.55              2.58
# 2011-07-18                 0.26              2.60
# 2011-07-19                 0.42              2.63
# 2011-07-20                -0.15              2.62
# ...                         ...               ...
# 2020-09-05              -342.25              9.23
# 2020-09-06               110.78              9.24
# 2020-09-07                89.21              9.25
# 2020-09-08              -238.05              9.22
# 2020-09-09               110.83              9.23
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-07-16                                       0.70                   13.72
# 2011-07-17                                       1.70                   13.17
# 2011-07-18                                       2.23                   13.42
# 2011-07-19                                       2.83                   13.84
# 2011-07-20                                       2.80                   13.69
# ...                                               ...                     ...
# 2020-09-05                                       5.62                10169.57
# 2020-09-06                                       5.34                10280.35
# 2020-09-07                                       5.48                10369.56
# 2020-09-08                                       2.50                10131.52
# 2020-09-09                                       2.13                10242.35
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-07-16                           -0.57                       7.31
# 2011-07-17                           -0.59                       7.32
# 2011-07-18                           -0.58                       7.01
# 2011-07-19                           -0.57                       7.03
# 2011-07-20                           -0.57                       6.97
# ...                                    ...                        ...
# 2020-09-05                           -0.49                    6211.50
# 2020-09-06                           -0.48                    6210.01
# 2020-09-07                           -0.48                    6207.10
# 2020-09-08                           -0.49                    6207.19
# 2020-09-09                           -0.48                    6204.76
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2011-07-16         1.87        6713154126051590.00        11654137109701.80
# 2011-07-17         1.82        6713154126051590.00        13208752331351.50
# 2011-07-18         1.86        6713154126051590.00        13355914725081.60
# 2011-07-19         1.96        7262342175053680.00        11065053631354.40
# 2011-07-20         1.98        7262342175053680.00        12525772772957.20
# ...                 ...                        ...                      ...
# 2020-09-05         1.66 75411005869439401852928.00 123489638432487997440.00
# 2020-09-06         1.65 75411005869439401852928.00 131717679503667003392.00
# 2020-09-07         1.64 74500493292953204162560.00 150352516655708995584.00
# 2020-09-08         1.64 74500493292953204162560.00 133450167690280992768.00
# 2020-09-09         1.64 74500493292953204162560.00 129306481305694994432.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2011-07-16             7861.15  ...                   20543.00
# 2011-07-17             8512.13  ...                   21180.00
# 2011-07-18             8512.94  ...                   21198.00
# 2011-07-19             7114.85  ...                   21433.00
# 2011-07-20             7460.57  ...                   21633.00
# ...                        ...  ...                        ...
# 2020-09-05             1001.14  ...                  685725.00
# 2020-09-06             1008.24  ...                  557361.00
# 2020-09-07             1190.47  ...                  672708.00
# 2020-09-08             1052.81  ...                  693529.00
# 2020-09-09             1020.45  ...                  681412.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-07-16                      14625.00                 296738.00
# 2011-07-17                      15530.00                 303267.00
# 2011-07-18                      15356.00                 305043.00
# 2011-07-19                      15873.00                 310575.00
# 2011-07-20                      15840.00                 315842.00
# ...                                  ...                       ...
# 2020-09-05                     473696.00               31282312.00
# 2020-09-06                     398510.00               31123319.00
# 2020-09-07                     478470.00               31009419.00
# 2020-09-08                     498882.00               31046954.00
# 2020-09-09                     484473.00               31096380.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-07-16                         196860.00                    126035.00
# 2011-07-17                         197576.00                    126461.00
# 2011-07-18                         195085.00                    125059.00
# 2011-07-19                         196075.00                    125791.00
# 2011-07-20                         196368.00                    126121.00
# ...                                      ...                          ...
# 2020-09-05                        8596301.00                   3135389.00
# 2020-09-06                        8521624.00                   3124437.00
# 2020-09-07                        8496344.00                   3125898.00
# 2020-09-08                        8500540.00                   3130380.00
# 2020-09-09                        8517532.00                   3134510.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-07-16               99005.00                64333.00
# 2011-07-17               99364.00                64511.00
# 2011-07-18               98120.00                64454.00
# 2011-07-19               98755.00                64598.00
# 2011-07-20               99090.00                64643.00
# ...                           ...                     ...
# 2020-09-05              822481.00               153779.00
# 2020-09-06              822205.00               153468.00
# 2020-09-07              822652.00               153364.00
# 2020-09-08              823072.00               153197.00
# 2020-09-09              823685.00               153145.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-07-16                  3805.00                  598.00
# 2011-07-17                  3824.00                  599.00
# 2011-07-18                  3746.00                  600.00
# 2011-07-19                  3761.00                  597.00
# 2011-07-20                  3799.00                  598.00
# ...                             ...                     ...
# 2020-09-05                 15982.00                 2198.00
# 2020-09-06                 15994.00                 2196.00
# 2020-09-07                 16011.00                 2193.00
# 2020-09-08                 15990.00                 2187.00
# 2020-09-09                 15986.00                 2190.00
#
#             addresses/min_10k_count
# Date
# 2011-07-16                    62.00
# 2011-07-17                    62.00
# 2011-07-18                    63.00
# 2011-07-19                    63.00
# 2011-07-20                    63.00
# ...                             ...
# 2020-09-05                   106.00
# 2020-09-06                   106.00
# 2020-09-07                   106.00
# 2020-09-08                   105.00
# 2020-09-09                   104.00
#
# [3344 rows x 102 columns]

# %%
# Data Set Info
df_dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3344 entries, 2011-07-16 to 2020-09-09
# Columns: 102 entries, Daily Return in USD to addresses/min_10k_count
# dtypes: float64(102)
# memory usage: 2.6 MB

# %%
# List of Data Types
l_dtypes = df_dataset1.dtypes

# %%
# Counter
counter = 0

# Cross-Check of Data Types
for i in l_dtypes:
    if (i == float):
        counter = counter+1
    else:
        counter = counter

# Number of Float Data Types
print(counter)
# Out:
# 102

# %%
# Data Types
df_dataset1.dtypes
# Out:
# Daily Return in USD                          float64
# Log Price in USD                             float64
# Volatility Daily Log Return in Percent 5D    float64
# market/price_usd_close                       float64
# market/price_drawdown_relative               float64
#                                               ...
# addresses/min_1_count                        float64
# addresses/min_10_count                       float64
# addresses/min_100_count                      float64
# addresses/min_1k_count                       float64
# addresses/min_10k_count                      float64
# Length: 102, dtype: object

# %%
# Summary Statistics
df_dataset1.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count              3344.00           3344.00
# mean                  3.06              6.28
# std                 225.49              2.46
# min               -3052.46              0.72
# 25%                  -6.53              5.30
# 50%                   0.10              6.39
# 75%                  11.44              8.75
# max                3224.13              9.88
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                    3344.00                 3344.00
# mean                                        3.57                 2924.88
# std                                         3.39                 3878.28
# min                                         0.16                    2.05
# 25%                                         1.53                  199.35
# 50%                                         2.67                  597.88
# 75%                                         4.45                 6289.19
# max                                        41.75                19587.61
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                         3344.00                    3344.00      3344.00
# mean                            -0.56                    1805.96         1.68
# std                              0.23                    2303.81         0.75
# min                             -0.94                       4.78         0.40
# 25%                             -0.72                      69.30         1.16
# 50%                             -0.60                     341.26         1.58
# 75%                             -0.46                    4610.36         1.95
# max                              0.00                    6219.68         5.73
#
#         mining/difficulty_latest    mining/hash_rate_mean  mining/revenue_sum  \
# count                    3344.00                  3344.00             3344.00
# mean  12175171531858262360064.00  20686986380631875584.00             3552.76
# std   20852044755581787963392.00  35352772706990092288.00             1933.48
# min          4684588175054590.00         6399665203131.94              738.15
# 25%       1679026357970510080.00      3408642057090500.00             1967.98
# 50%     618975430320051978240.00   1078662194888004992.00             3426.37
# 75%   18498207565771700174848.00  32589174816671752192.00             4302.30
# max   75411005869439401852928.00 150352516655708995584.00             9214.89
#
#        ...  addresses/receiving_count  addresses/new_non_zero_count  \
# count  ...                    3344.00                       3344.00
# mean   ...                  315336.37                     210148.21
# std    ...                  223493.36                     155533.27
# min    ...                    7539.00                       4241.00
# 25%    ...                   87953.00                      55479.00
# 50%    ...                  356018.00                     215741.00
# 75%    ...                  498151.50                     339647.75
# max    ...                 1072829.00                     800180.00
#
#        addresses/non_zero_count  addresses/min_point_zero_1_count  \
# count                   3344.00                           3344.00
# mean                11669322.65                        3336915.74
# std                 10458853.83                        2827410.99
# min                   296738.00                         195085.00
# 25%                  2013822.25                         656507.50
# 50%                  6988090.50                        2432543.50
# 75%                 22249301.75                        6333465.50
# max                 31282312.00                        8605894.00
#
#        addresses/min_point_1_count  addresses/min_1_count  \
# count                      3344.00                3344.00
# mean                    1346774.66              461280.80
# std                     1000395.45              236468.71
# min                      125059.00               98120.00
# 25%                      387254.25              224272.00
# 50%                     1122513.00              468687.50
# 75%                     2416907.25              705807.75
# max                     3139207.00              823685.00
#
#        addresses/min_10_count  addresses/min_100_count  \
# count                 3344.00                  3344.00
# mean                124714.04                 14640.43
# std                  28903.59                  3668.68
# min                  64333.00                  3746.00
# 25%                  97109.75                 12781.75
# 50%                 137234.50                 16194.00
# 75%                 149574.00                 17180.00
# max                 157275.00                 18543.00
#
#        addresses/min_1k_count  addresses/min_10k_count
# count                 3344.00                  3344.00
# mean                  1604.18                   102.08
# std                    379.53                    14.90
# min                    597.00                    62.00
# 25%                   1449.00                    96.00
# 50%                   1670.00                   105.00
# 75%                   1832.00                   113.00
# max                   2209.00                   126.00
#
# [8 rows x 102 columns]

# %%
# Dataset Tail
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-09-05              -342.25              9.23
# 2020-09-06               110.78              9.24
# 2020-09-07                89.21              9.25
# 2020-09-08              -238.05              9.22
# 2020-09-09               110.83              9.23
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-09-05                                       5.62                10169.57
# 2020-09-06                                       5.34                10280.35
# 2020-09-07                                       5.48                10369.56
# 2020-09-08                                       2.50                10131.52
# 2020-09-09                                       2.13                10242.35
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-09-05                           -0.49                    6211.50
# 2020-09-06                           -0.48                    6210.01
# 2020-09-07                           -0.48                    6207.10
# 2020-09-08                           -0.49                    6207.19
# 2020-09-09                           -0.48                    6204.76
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-09-05         1.66 75411005869439401852928.00 123489638432487997440.00
# 2020-09-06         1.65 75411005869439401852928.00 131717679503667003392.00
# 2020-09-07         1.64 74500493292953204162560.00 150352516655708995584.00
# 2020-09-08         1.64 74500493292953204162560.00 133450167690280992768.00
# 2020-09-09         1.64 74500493292953204162560.00 129306481305694994432.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2020-09-05             1001.14  ...                  685725.00
# 2020-09-06             1008.24  ...                  557361.00
# 2020-09-07             1190.47  ...                  672708.00
# 2020-09-08             1052.81  ...                  693529.00
# 2020-09-09             1020.45  ...                  681412.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-09-05                     473696.00               31282312.00
# 2020-09-06                     398510.00               31123319.00
# 2020-09-07                     478470.00               31009419.00
# 2020-09-08                     498882.00               31046954.00
# 2020-09-09                     484473.00               31096380.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-09-05                        8596301.00                   3135389.00
# 2020-09-06                        8521624.00                   3124437.00
# 2020-09-07                        8496344.00                   3125898.00
# 2020-09-08                        8500540.00                   3130380.00
# 2020-09-09                        8517532.00                   3134510.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-09-05              822481.00               153779.00
# 2020-09-06              822205.00               153468.00
# 2020-09-07              822652.00               153364.00
# 2020-09-08              823072.00               153197.00
# 2020-09-09              823685.00               153145.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-09-05                 15982.00                 2198.00
# 2020-09-06                 15994.00                 2196.00
# 2020-09-07                 16011.00                 2193.00
# 2020-09-08                 15990.00                 2187.00
# 2020-09-09                 15986.00                 2190.00
#
#             addresses/min_10k_count
# Date
# 2020-09-05                   106.00
# 2020-09-06                   106.00
# 2020-09-07                   106.00
# 2020-09-08                   105.00
# 2020-09-09                   104.00
#
# [5 rows x 102 columns]

# %% [markdown]
# ## Prediction Shift

# %% [markdown]
# ### Data Set I.

# %%
# Shift of Target Column by 1 Day
df_dataset1['Daily Return in USD'] = df_dataset1['Daily Return in USD'].shift(1)

# %%
# Check Shift
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-09-05               273.36              9.23
# 2020-09-06              -342.25              9.24
# 2020-09-07               110.78              9.25
# 2020-09-08                89.21              9.22
# 2020-09-09              -238.05              9.23
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-09-05                                       5.62                10169.57
# 2020-09-06                                       5.34                10280.35
# 2020-09-07                                       5.48                10369.56
# 2020-09-08                                       2.50                10131.52
# 2020-09-09                                       2.13                10242.35
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-09-05                           -0.49                    6211.50
# 2020-09-06                           -0.48                    6210.01
# 2020-09-07                           -0.48                    6207.10
# 2020-09-08                           -0.49                    6207.19
# 2020-09-09                           -0.48                    6204.76
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-09-05         1.66 75411005869439401852928.00 123489638432487997440.00
# 2020-09-06         1.65 75411005869439401852928.00 131717679503667003392.00
# 2020-09-07         1.64 74500493292953204162560.00 150352516655708995584.00
# 2020-09-08         1.64 74500493292953204162560.00 133450167690280992768.00
# 2020-09-09         1.64 74500493292953204162560.00 129306481305694994432.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2020-09-05             1001.14  ...                  685725.00
# 2020-09-06             1008.24  ...                  557361.00
# 2020-09-07             1190.47  ...                  672708.00
# 2020-09-08             1052.81  ...                  693529.00
# 2020-09-09             1020.45  ...                  681412.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-09-05                     473696.00               31282312.00
# 2020-09-06                     398510.00               31123319.00
# 2020-09-07                     478470.00               31009419.00
# 2020-09-08                     498882.00               31046954.00
# 2020-09-09                     484473.00               31096380.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-09-05                        8596301.00                   3135389.00
# 2020-09-06                        8521624.00                   3124437.00
# 2020-09-07                        8496344.00                   3125898.00
# 2020-09-08                        8500540.00                   3130380.00
# 2020-09-09                        8517532.00                   3134510.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-09-05              822481.00               153779.00
# 2020-09-06              822205.00               153468.00
# 2020-09-07              822652.00               153364.00
# 2020-09-08              823072.00               153197.00
# 2020-09-09              823685.00               153145.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-09-05                 15982.00                 2198.00
# 2020-09-06                 15994.00                 2196.00
# 2020-09-07                 16011.00                 2193.00
# 2020-09-08                 15990.00                 2187.00
# 2020-09-09                 15986.00                 2190.00
#
#             addresses/min_10k_count
# Date
# 2020-09-05                   106.00
# 2020-09-06                   106.00
# 2020-09-07                   106.00
# 2020-09-08                   105.00
# 2020-09-09                   104.00
#
# [5 rows x 102 columns]

# %%
# Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          1
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 102, dtype: int64

# %%
# daily return: von gestern auf heute die preisveränderung deswegen shift später
df_dataset1.isnull()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-07-16                 True             False
# 2011-07-17                False             False
# 2011-07-18                False             False
# 2011-07-19                False             False
# 2011-07-20                False             False
# ...                         ...               ...
# 2020-09-05                False             False
# 2020-09-06                False             False
# 2020-09-07                False             False
# 2020-09-08                False             False
# 2020-09-09                False             False
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-07-16                                      False                   False
# 2011-07-17                                      False                   False
# 2011-07-18                                      False                   False
# 2011-07-19                                      False                   False
# 2011-07-20                                      False                   False
# ...                                               ...                     ...
# 2020-09-05                                      False                   False
# 2020-09-06                                      False                   False
# 2020-09-07                                      False                   False
# 2020-09-08                                      False                   False
# 2020-09-09                                      False                   False
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-07-16                           False                      False
# 2011-07-17                           False                      False
# 2011-07-18                           False                      False
# 2011-07-19                           False                      False
# 2011-07-20                           False                      False
# ...                                    ...                        ...
# 2020-09-05                           False                      False
# 2020-09-06                           False                      False
# 2020-09-07                           False                      False
# 2020-09-08                           False                      False
# 2020-09-09                           False                      False
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-07-16        False                     False                  False
# 2011-07-17        False                     False                  False
# 2011-07-18        False                     False                  False
# 2011-07-19        False                     False                  False
# 2011-07-20        False                     False                  False
# ...                 ...                       ...                    ...
# 2020-09-05        False                     False                  False
# 2020-09-06        False                     False                  False
# 2020-09-07        False                     False                  False
# 2020-09-08        False                     False                  False
# 2020-09-09        False                     False                  False
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2011-07-16               False  ...                      False
# 2011-07-17               False  ...                      False
# 2011-07-18               False  ...                      False
# 2011-07-19               False  ...                      False
# 2011-07-20               False  ...                      False
# ...                        ...  ...                        ...
# 2020-09-05               False  ...                      False
# 2020-09-06               False  ...                      False
# 2020-09-07               False  ...                      False
# 2020-09-08               False  ...                      False
# 2020-09-09               False  ...                      False
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-07-16                         False                     False
# 2011-07-17                         False                     False
# 2011-07-18                         False                     False
# 2011-07-19                         False                     False
# 2011-07-20                         False                     False
# ...                                  ...                       ...
# 2020-09-05                         False                     False
# 2020-09-06                         False                     False
# 2020-09-07                         False                     False
# 2020-09-08                         False                     False
# 2020-09-09                         False                     False
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-07-16                             False                        False
# 2011-07-17                             False                        False
# 2011-07-18                             False                        False
# 2011-07-19                             False                        False
# 2011-07-20                             False                        False
# ...                                      ...                          ...
# 2020-09-05                             False                        False
# 2020-09-06                             False                        False
# 2020-09-07                             False                        False
# 2020-09-08                             False                        False
# 2020-09-09                             False                        False
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-07-16                  False                   False
# 2011-07-17                  False                   False
# 2011-07-18                  False                   False
# 2011-07-19                  False                   False
# 2011-07-20                  False                   False
# ...                           ...                     ...
# 2020-09-05                  False                   False
# 2020-09-06                  False                   False
# 2020-09-07                  False                   False
# 2020-09-08                  False                   False
# 2020-09-09                  False                   False
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-07-16                    False                   False
# 2011-07-17                    False                   False
# 2011-07-18                    False                   False
# 2011-07-19                    False                   False
# 2011-07-20                    False                   False
# ...                             ...                     ...
# 2020-09-05                    False                   False
# 2020-09-06                    False                   False
# 2020-09-07                    False                   False
# 2020-09-08                    False                   False
# 2020-09-09                    False                   False
#
#             addresses/min_10k_count
# Date
# 2011-07-16                    False
# 2011-07-17                    False
# 2011-07-18                    False
# 2011-07-19                    False
# 2011-07-20                    False
# ...                             ...
# 2020-09-05                    False
# 2020-09-06                    False
# 2020-09-07                    False
# 2020-09-08                    False
# 2020-09-09                    False
#
# [3344 rows x 102 columns]

# %%
# Delete Empty Row
df_dataset1 = df_dataset1.dropna()

# %%
# Re-Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          0
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 102, dtype: int64

# %% [markdown]
# # Classification Setup

# %% [markdown]
# ## Create Data Set Copies for Trading Strategy

# %%
# Data Set Copy for Trading Extension
df_dataset1_copy = df_dataset1.copy()

# %% [markdown]
# ## Categorization - Data Set I.

# %%
# Categorization
# Class 1 for all Returns >= 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] >= 0, 'Class'] = 1
# Class 0 for all Returns < 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0
# Out:
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(new_indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-104-55abdf32f90e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-07-17                -0.09              2.58
# 2011-07-18                -0.55              2.60
# 2011-07-19                 0.26              2.63
# 2011-07-20                 0.42              2.62
# 2011-07-21                -0.15              2.61
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-07-17                                       1.70                   13.17
# 2011-07-18                                       2.23                   13.42
# 2011-07-19                                       2.83                   13.84
# 2011-07-20                                       2.80                   13.69
# 2011-07-21                                       2.80                   13.61
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-07-17                           -0.59                       7.32
# 2011-07-18                           -0.58                       7.01
# 2011-07-19                           -0.57                       7.03
# 2011-07-20                           -0.57                       6.97
# 2011-07-21                           -0.57                       6.97
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-07-17         1.82       6713154126051590.00      13208752331351.50
# 2011-07-18         1.86       6713154126051590.00      13355914725081.60
# 2011-07-19         1.96       7262342175053680.00      11065053631354.40
# 2011-07-20         1.98       7262342175053680.00      12525772772957.20
# 2011-07-21         1.96       7262342175053680.00      12836364605425.40
#
#             mining/revenue_sum  ...  addresses/new_non_zero_count  \
# Date                            ...
# 2011-07-17             8512.13  ...                      15530.00
# 2011-07-18             8512.94  ...                      15356.00
# 2011-07-19             7114.85  ...                      15873.00
# 2011-07-20             7460.57  ...                      15840.00
# 2011-07-21             7609.00  ...                      16486.00
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2011-07-17                 303267.00                         197576.00
# 2011-07-18                 305043.00                         195085.00
# 2011-07-19                 310575.00                         196075.00
# 2011-07-20                 315842.00                         196368.00
# 2011-07-21                 322618.00                         196641.00
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2011-07-17                    126461.00               99364.00
# 2011-07-18                    125059.00               98120.00
# 2011-07-19                    125791.00               98755.00
# 2011-07-20                    126121.00               99090.00
# 2011-07-21                    126152.00               99055.00
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2011-07-17                64511.00                  3824.00
# 2011-07-18                64454.00                  3746.00
# 2011-07-19                64598.00                  3761.00
# 2011-07-20                64643.00                  3799.00
# 2011-07-21                64747.00                  3816.00
#
#             addresses/min_1k_count  addresses/min_10k_count  Class
# Date
# 2011-07-17                  599.00                    62.00   0.00
# 2011-07-18                  600.00                    63.00   0.00
# 2011-07-19                  597.00                    63.00   1.00
# 2011-07-20                  598.00                    63.00   1.00
# 2011-07-21                  599.00                    63.00   0.00
#
# [5 rows x 103 columns]

# %%
# Delete Original Target Column
df_dataset1 = df_dataset1.drop(['Daily Return in USD'], axis=1)

# %%
# Check Class Balance
df_dataset1['Class'].value_counts()
# Out:
# 1.00    1807
# 0.00    1536
# Name: Class, dtype: int64

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Log Price in USD  Volatility Daily Log Return in Percent 5D  \
# Date
# 2011-07-17              2.58                                       1.70
# 2011-07-18              2.60                                       2.23
# 2011-07-19              2.63                                       2.83
# 2011-07-20              2.62                                       2.80
# 2011-07-21              2.61                                       2.80
#
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2011-07-17                   13.17                           -0.59
# 2011-07-18                   13.42                           -0.58
# 2011-07-19                   13.84                           -0.57
# 2011-07-20                   13.69                           -0.57
# 2011-07-21                   13.61                           -0.57
#
#             market/price_realized_usd  market/mvrv  mining/difficulty_latest  \
# Date
# 2011-07-17                       7.32         1.82       6713154126051590.00
# 2011-07-18                       7.01         1.86       6713154126051590.00
# 2011-07-19                       7.03         1.96       7262342175053680.00
# 2011-07-20                       6.97         1.98       7262342175053680.00
# 2011-07-21                       6.97         1.96       7262342175053680.00
#
#             mining/hash_rate_mean  mining/revenue_sum  \
# Date
# 2011-07-17      13208752331351.50             8512.13
# 2011-07-18      13355914725081.60             8512.94
# 2011-07-19      11065053631354.40             7114.85
# 2011-07-20      12525772772957.20             7460.57
# 2011-07-21      12836364605425.40             7609.00
#
#             mining/marketcap_thermocap_ratio  ...  \
# Date                                          ...
# 2011-07-17                              0.00  ...
# 2011-07-18                              0.00  ...
# 2011-07-19                              0.00  ...
# 2011-07-20                              0.00  ...
# 2011-07-21                              0.00  ...
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-07-17                      15530.00                 303267.00
# 2011-07-18                      15356.00                 305043.00
# 2011-07-19                      15873.00                 310575.00
# 2011-07-20                      15840.00                 315842.00
# 2011-07-21                      16486.00                 322618.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-07-17                         197576.00                    126461.00
# 2011-07-18                         195085.00                    125059.00
# 2011-07-19                         196075.00                    125791.00
# 2011-07-20                         196368.00                    126121.00
# 2011-07-21                         196641.00                    126152.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-07-17               99364.00                64511.00
# 2011-07-18               98120.00                64454.00
# 2011-07-19               98755.00                64598.00
# 2011-07-20               99090.00                64643.00
# 2011-07-21               99055.00                64747.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-07-17                  3824.00                  599.00
# 2011-07-18                  3746.00                  600.00
# 2011-07-19                  3761.00                  597.00
# 2011-07-20                  3799.00                  598.00
# 2011-07-21                  3816.00                  599.00
#
#             addresses/min_10k_count  Class
# Date
# 2011-07-17                    62.00   0.00
# 2011-07-18                    63.00   0.00
# 2011-07-19                    63.00   1.00
# 2011-07-20                    63.00   1.00
# 2011-07-21                    63.00   0.00
#
# [5 rows x 102 columns]

# %% [markdown]
# # Model Preparation - Data Set I.

# %% [markdown]
# ## Train Test Split - Data Set I.

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
predictors = df_dataset1.drop(['Class'], axis=1).values.astype(np.float32)

# %%
# Setup of Categorized Target Variable
target = df_dataset1['Class'].astype(np.float32)

# %%
# Predictor Dimensions
predictors.shape
# Out:
# (3343, 101)

# %%
# Target Dimensions
target.shape
# Out:
# (3343,)

# %%
# Train-Test-Split Function to Create Training and Test Data Set
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state = 41, stratify=target)

# %%
# Dimensions of Predictors for Training
X_train.shape
# Out:
# (2340, 101)

# %%
# Dimensions of Target for Training
y_train.shape
# Out:
# (2340,)

# %%
# Number of Predictors
n_nodes = predictors.shape[1]
n_nodes
# Out:
# 101

# %% [markdown]
# ### Check of Class Balance

# %%
# Check Training Target of Class 0
y_train[y_train==0].count()
# Out:
# 1075

# %%
# Check Training Target of Class 1
y_train[y_train==1].count()
# Out:
# 1265

# %%
# Check Test Target of Class 0
y_test[y_test==0].count()
# Out:
# 461

# %%
# Check Test Target of Class 1
y_test[y_test==1].count()
# Out:
# 542

# %% [markdown]
# ## Feature Scaling - Data Set I.

# %%
# Instantiation of MinMaxScaler and StandardSacler
norm_scaler = MinMaxScaler()
#std_scaler = StandardScaler()

# %%
# Scaler Training and Transformation of Training Set
X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))

# %%
# Scaler Transformation of Test Set
X_test_scaled = norm_scaler.transform(X_test)

# %%
# Scaled Test Features
X_test_scaled
# Out:
# array([[0.8260981 , 0.1797023 , 0.20383392, ..., 0.9870148 , 0.71011794,
#         0.84375   ],
#        [0.56016296, 0.1602186 , 0.01782017, ..., 0.61470306, 0.53196776,
#         0.515625  ],
#        [0.9405575 , 0.14039162, 0.5806679 , ..., 0.9214798 , 0.63376784,
#         0.78125   ],
#        ...,
#        [0.92184997, 0.06452803, 0.4893588 , ..., 0.8340323 , 0.9639975 ,
#         0.703125  ],
#        [0.61781496, 0.01697705, 0.03026265, ..., 0.7735697 , 0.58845437,
#         0.578125  ],
#        [0.51613677, 0.01523763, 0.01187944, ..., 0.8516165 , 0.6654252 ,
#         0.625     ]], dtype=float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
predictors_scaled = norm_scaler.transform(predictors)

# %% [markdown]
# # Classification Models - Data Set I.

# %%
# Function To Show Accuracy Mean and Accuracy Standard Deviation
def show_scores(scores):
    # Scores Series
    print('Scores:', scores)
    # Score Mean
    print('Mean:', np.mean(scores))
    # Score Standard Deviation
    print('Standard Deviation:', np.std(scores))

# %% [markdown]
# ## Logistic Regression - Data Set I.

# %%
# Instantiate Classifier - LogisticRegression
lreg = LogisticRegression(max_iter=1200)

# %%
# Train Classifier
lreg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1200)

# %%
# Prediction of Classes
y_pred = lreg.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = lreg.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.77476428, 0.47712719, 0.51657139, 0.04153502, 0.59642954,
#        0.68414896, 0.61833316, 0.61604112, 0.50599682, 0.46734192])

# %%
# Select Actual Classes
np.array(y_test[1:11])
# Out:
# array([0., 1., 0., 1., 1., 0., 0., 1., 0., 1.], dtype=float32)

# %%
# Train Accuracy
lreg.score(X_train_scaled, y_train)
# Out:
# 0.6282051282051282

# %%
# Test Accuracy
lreg.score(X_test_scaled, y_test)
# Out:
# 0.6081754735792622

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[224 237]
#  [156 386]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.49      0.53       461
#          1.0       0.62      0.71      0.66       542
#
#     accuracy                           0.61      1003
#    macro avg       0.60      0.60      0.60      1003
# weighted avg       0.61      0.61      0.60      1003

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# Plot of ROC curve
_ = plt.plot([0, 1], [0, 1])
_ = plt.plot(fpr, tpr)
_ = plt.xlabel('False Positive Rate')
_ = plt.ylabel('True Positive Rate')
_ = plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC Score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6447519030504838

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.68551338 0.68339671 0.65613116 0.68102453 0.64603175 0.63726551
#  0.64922544 0.6582891  0.64247283 0.66258621]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.6119403  0.59402985 0.63283582 0.58682635 0.63173653 0.59281437
#  0.63473054 0.59281437 0.62874251 0.58083832]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.6119403  0.59402985 0.63283582 0.58682635 0.63173653 0.59281437
#  0.63473054 0.59281437 0.62874251 0.58083832]
# Mean: 0.608730896416123
# Standard Deviation: 0.02043930077928663

# %% [markdown]
# ## Random Forest Classifier - Data Set I.

# %%
# Instantiate Classifier - Random Forest
rfc = RandomForestClassifier(n_estimators=100, max_leaf_nodes=None, criterion='gini', max_depth=3, random_state=41)

# %%
# Train Classifier
rfc.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=3, random_state=41)

# %%
# Prediction of Classes
y_pred = rfc.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = rfc.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.75933412, 0.48647576, 0.43197106, 0.40402082, 0.56138725,
#        0.6323705 , 0.54081889, 0.56116107, 0.53277753, 0.44526666])

# %%
# Train Accuracy
rfc.score(X_train_scaled, y_train)
# Out:
# 0.6337606837606837

# %%
# Test Accuracy
rfc.score(X_test_scaled, y_test)
# Out:
# 0.6291126620139581

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[255 206]
#  [166 376]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.55      0.58       461
#          1.0       0.65      0.69      0.67       542
#
#     accuracy                           0.63      1003
#    macro avg       0.63      0.62      0.62      1003
# weighted avg       0.63      0.63      0.63      1003

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6637483891107891

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.67439191 0.62301787 0.71349645 0.67193362 0.66839827 0.63015873
#  0.62456216 0.65608638 0.65095873 0.66941104]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.60895522 0.62089552 0.59402985 0.68263473 0.62874251 0.58383234
#  0.61976048 0.63473054 0.63173653 0.59580838]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.60895522 0.62089552 0.59402985 0.68263473 0.62874251 0.58383234
#  0.61976048 0.63473054 0.63173653 0.59580838]
# Mean: 0.6201126105996961
# Standard Deviation: 0.026542001469063804

# %% [markdown]
# # Trading Strategy - Data Set I

# %% [markdown]
# ## Trading Strategy in Combination with Logistic Regression

# %%
# Create Lists To Store All Calculated Values For Every Variable of Every Run
# Specified Period
# Threshold 0.5
spec_list_05_total = []
spec_list_05_profit = []
spec_list_05_loss = []
spec_list_05_trans = []
spec_list_05_acc = []
spec_list_05_preds_corr = []
spec_list_05_preds = []
# Threshold 0.6
spec_list_06_total = []
spec_list_06_profit = []
spec_list_06_loss = []
spec_list_06_trans = []
spec_list_06_acc = []
spec_list_06_preds_corr = []
spec_list_06_preds = []
# Threshold 0.7
spec_list_07_total = []
spec_list_07_profit = []
spec_list_07_loss = []
spec_list_07_trans = []
spec_list_07_acc = []
spec_list_07_preds_corr = []
spec_list_07_preds = []
# Threshold 0.8
spec_list_08_total = []
spec_list_08_profit = []
spec_list_08_loss = []
spec_list_08_trans = []
spec_list_08_acc = []
spec_list_08_preds_corr = []
spec_list_08_preds = []

# Entire Period
# Threshold 0.5
list_05_total = []
list_05_profit = []
list_05_loss = []
list_05_trans = []
list_05_acc = []
list_05_preds_corr = []
list_05_preds = []
# Threshold 0.6
list_06_total = []
list_06_profit = []
list_06_loss = []
list_06_trans = []
list_06_acc = []
list_06_preds_corr = []
list_06_preds = []
# Threshold 0.7
list_07_total = []
list_07_profit = []
list_07_loss = []
list_07_trans = []
list_07_acc = []
list_07_preds_corr = []
list_07_preds = []
# Threshold 0.8
list_08_total = []
list_08_profit = []
list_08_loss = []
list_08_trans = []
list_08_acc = []
list_08_preds_corr = []
list_08_preds = []

# %%
target
# Out:
# Date
# 2011-07-17   0.00
# 2011-07-18   0.00
# 2011-07-19   1.00
# 2011-07-20   1.00
# 2011-07-21   0.00
#              ...
# 2020-09-05   1.00
# 2020-09-06   0.00
# 2020-09-07   1.00
# 2020-09-08   1.00
# 2020-09-09   0.00
# Name: Class, Length: 3343, dtype: float32

# %%
predictors
# Out:
# array([[2.5777836e+00, 1.7005341e+00, 1.3167919e+01, ..., 3.8240000e+03,
#         5.9900000e+02, 6.2000000e+01],
#        [2.5969751e+00, 2.2271056e+00, 1.3423072e+01, ..., 3.7460000e+03,
#         6.0000000e+02, 6.3000000e+01],
#        [2.6277070e+00, 2.8262084e+00, 1.3841993e+01, ..., 3.7610000e+03,
#         5.9700000e+02, 6.3000000e+01],
#        ...,
#        [9.2466307e+00, 5.4810090e+00, 1.0369563e+04, ..., 1.6011000e+04,
#         2.1930000e+03, 1.0600000e+02],
#        [9.2234058e+00, 2.4996128e+00, 1.0131517e+04, ..., 1.5990000e+04,
#         2.1870000e+03, 1.0500000e+02],
#        [9.2342863e+00, 2.1275063e+00, 1.0242348e+04, ..., 1.5986000e+04,
#         2.1900000e+03, 1.0400000e+02]], dtype=float32)

# %%
for x in df_dataset1.columns:
    print(x)
# Out:
# Log Price in USD
# Volatility Daily Log Return in Percent 5D
# market/price_usd_close
# market/price_drawdown_relative
# market/price_realized_usd
# market/mvrv
# mining/difficulty_latest
# mining/hash_rate_mean
# mining/revenue_sum
# mining/marketcap_thermocap_ratio
# blockchain/block_count
# blockchain/block_interval_mean
# blockchain/block_size_sum
# distribution/balance_1pct_holders
# distribution/gini
# distribution/herfindahl
# fees/volume_sum
# fees/volume_mean
# fees/fee_ratio_multiple
# blockchain/utxo_created_count
# blockchain/utxo_spent_count
# blockchain/utxo_created_value_sum
# blockchain/utxo_spent_value_sum
# blockchain/utxo_profit_relative
# blockchain/utxo_profit_count
# blockchain/utxo_loss_count
# supply/current
# supply/profit_relative
# supply/profit_sum
# supply/loss_sum
# supply/active_more_1y_percent
# supply/active_more_2y_percent
# supply/active_more_3y_percent
# supply/active_more_5y_percent
# supply/active_24h
# supply/active_1d_1w
# supply/active_1w_1m
# supply/active_1m_3m
# supply/active_3m_6m
# supply/active_6m_12m
# supply/active_1y_2y
# supply/active_2y_3y
# supply/active_3y_5y
# supply/active_5y_7y
# supply/active_7y_10y
# supply/active_more_10y
# supply/issued
# supply/inflation_rate
# transactions/count
# transactions/size_sum
# transactions/transfers_volume_sum
# transactions/transfers_volume_adjusted_sum
# transactions/transfers_volume_to_exchanges_sum
# transactions/transfers_volume_from_exchanges_sum
# transactions/transfers_to_exchanges_count
# transactions/transfers_from_exchanges_count
# distribution/balance_exchanges
# transactions/transfers_volume_exchanges_net
# indicators/sopr_adjusted
# indicators/nvt
# indicators/velocity
# indicators/cdd
# indicators/reserve_risk
# indicators/average_dormancy
# indicators/liveliness
# indicators/asol
# indicators/sol_1h
# indicators/sol_1h_24h
# indicators/sol_1d_1w
# indicators/sol_1w_1m
# indicators/sol_1m_3m
# indicators/sol_3m_6m
# indicators/sol_6m_12m
# indicators/sol_1y_2y
# indicators/sol_2y_3y
# indicators/sol_3y_5y
# indicators/sol_5y_7y
# indicators/sol_7y_10y
# indicators/net_unrealized_profit_loss
# indicators/unrealized_profit
# indicators/unrealized_loss
# indicators/net_realized_profit_loss
# indicators/realized_profit
# indicators/realized_loss
# indicators/nupl_more_155
# indicators/nupl_less_155
# indicators/puell_multiple
# indicators/stock_to_flow_deflection
# indicators/difficulty_ribbon_compression
# addresses/active_count
# addresses/sending_count
# addresses/receiving_count
# addresses/new_non_zero_count
# addresses/non_zero_count
# addresses/min_point_zero_1_count
# addresses/min_point_1_count
# addresses/min_1_count
# addresses/min_10_count
# addresses/min_100_count
# addresses/min_1k_count
# addresses/min_10k_count
# Class

# %%
df_dataset1_copy[['Daily Return in USD']]
# Out:
#             Daily Return in USD
# Date
# 2011-07-17                -0.09
# 2011-07-18                -0.55
# 2011-07-19                 0.26
# 2011-07-20                 0.42
# 2011-07-21                -0.15
# ...                         ...
# 2020-09-05               273.36
# 2020-09-06              -342.25
# 2020-09-07               110.78
# 2020-09-08                89.21
# 2020-09-09              -238.05
#
# [3343 rows x 1 columns]

# %%
df_dataset1_copy["percentage_daily_return"] = df_dataset1_copy["Daily Return in USD"]/df_dataset1_copy["market/price_usd_close"]
df_dataset1_copy["percentage_daily_return"]
# Out:
# Date
# 2011-07-17   -0.01
# 2011-07-18   -0.04
# 2011-07-19    0.02
# 2011-07-20    0.03
# 2011-07-21   -0.01
#               ...
# 2020-09-05    0.03
# 2020-09-06   -0.03
# 2020-09-07    0.01
# 2020-09-08    0.01
# 2020-09-09   -0.02
# Name: percentage_daily_return, Length: 3343, dtype: float64

# %%
predictors
# Out:
# array([[2.5777836e+00, 1.7005341e+00, 1.3167919e+01, ..., 3.8240000e+03,
#         5.9900000e+02, 6.2000000e+01],
#        [2.5969751e+00, 2.2271056e+00, 1.3423072e+01, ..., 3.7460000e+03,
#         6.0000000e+02, 6.3000000e+01],
#        [2.6277070e+00, 2.8262084e+00, 1.3841993e+01, ..., 3.7610000e+03,
#         5.9700000e+02, 6.3000000e+01],
#        ...,
#        [9.2466307e+00, 5.4810090e+00, 1.0369563e+04, ..., 1.6011000e+04,
#         2.1930000e+03, 1.0600000e+02],
#        [9.2234058e+00, 2.4996128e+00, 1.0131517e+04, ..., 1.5990000e+04,
#         2.1870000e+03, 1.0500000e+02],
#        [9.2342863e+00, 2.1275063e+00, 1.0242348e+04, ..., 1.5986000e+04,
#         2.1900000e+03, 1.0400000e+02]], dtype=float32)

# %%
einsatz = 1000
percentlist=[]
zinseszins=[]
profitpercent=[]


# For Loop to Simulate K-fold Cross Validation
for x in range(1, 20):
    
    # Display Number of Runs
    print("Run:", x)
    
    # Split Data into Training and Testing
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, stratify=target)
    
    # Amount of Columns
    n_nodes = predictors.shape[1]

    # Instantiation of MinMaxScaler
    norm_scaler = MinMaxScaler()
    
    # Training and Application of Feature Scaler on Training Data of Predictors
    X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))
    
    # Application of Feature Scaler on Test Data of Predictors
    X_test_scaled = norm_scaler.transform(X_test)
    
    # Instantiate Classifier Logistic Regression
    lreg = LogisticRegression(max_iter=12000) 
    
    # Train Classifier
    lreg.fit(X_train_scaled, y_train)
    
    # Prediction of Classes
    y_pred = lreg.predict(X_test_scaled)
    
    # Display Confusion Matrix and Classification Report
    print(confusion_matrix(y_test, y_pred))
#     print(classification_report(y_test, y_pred))

    # Prediction of Probabilities
    y_pred_prob = lreg.predict_proba(X_test_scaled)[:,1]

    # Create Data Frame of Actual Values - y_test
    df_y_test = pd.DataFrame(y_test)
    
    # Add Predicted Probabilities to Data Frame
    df_y_test["y_pred_prob"] = y_pred_prob
    
    # Add Predicted Classes (0 or 1) to Data Frame to Cross-Check Predicted Probabilities 
    df_y_test["y_pred"] =  y_pred
    
    # Select Actual Daily Returns in USD from the Data Set Copy
    df_dataset1_copy_dailyreturns=df_dataset1_copy[['Daily Return in USD']]
    
    # Merge Predictions and Daily Returns Data Frame on the Column "Date"
    df_y_test_withdailyreturns = pd.merge(df_y_test, df_dataset1_copy_dailyreturns, on='Date')
    
    df_dataset1_copy_percentage=df_dataset1_copy[['percentage_daily_return']]
    df_y_test_withdailyreturns = pd.merge(df_y_test_withdailyreturns, df_dataset1_copy_percentage, on='Date')
    
    # Add Bitcoin Price in USD
    df_y_test_withdailyreturns = pd.merge(df_y_test_withdailyreturns, df_dataset1['market/price_usd_close'] , on='Date')
    
    df_y_test_withdailyreturns['y_pred_prob_bereinigt'] = np.where(df_y_test_withdailyreturns['y_pred_prob']<0.5, 1-df_y_test_withdailyreturns['y_pred_prob'],df_y_test_withdailyreturns['y_pred_prob'])

    df_y_test_withdailyreturns["Einsatz"]=einsatz*df_y_test_withdailyreturns["y_pred_prob_bereinigt"]#**2
    
    # Add and Calculate Transaction Costs based on the Bitcoin Price in USD
    df_y_test_withdailyreturns['Transaction Costs in USD'] = df_y_test_withdailyreturns['Einsatz']*0.0005*2
    
    # Create List of Multiple Thresholds 
    # A Threshold of 0.7 means that only predicted probabilites with more than 0.7 or less than 0.3 are considered further
    list_thresholdcalc = [0.5, 0.6, 0.7, 0.8]
    
    # Try and Except Block to Address Cases in Which a Data Frame does NOT Contain Any Values Because No predicted Probability Meets the Threshold Requirements
    try:
        
        # For Loop Over List
        for thresholdcalc in list_thresholdcalc:
            
            # Creation of a Data Frame Containing Only Probability Predictions Which Meet the Threshold Requirements 
            df_y_test_probaall = df_y_test.loc[(df_y_test['y_pred_prob'] > thresholdcalc) | (df_y_test['y_pred_prob'] < 1-thresholdcalc)]
            
            # Calculation Of Accuracy Only for the Data Subset Meeting Threshold Requirements
            acc_calc = len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]) / len(df_y_test_probaall)
 
            print("Threshold of:", thresholdcalc)
            print(classification_report(df_y_test_probaall["Class"], df_y_test_probaall["y_pred"]))

            # Creation of Another Data Frame including Returns and Transaction Costs Only For Probability Predicitons that Meet the Threshold Requirements
            df_y_test_probaall_withdailyreturns = df_y_test_withdailyreturns.loc[(df_y_test_withdailyreturns['y_pred_prob'] > thresholdcalc) | (df_y_test_withdailyreturns['y_pred_prob'] < 1-thresholdcalc)]
            
            # Trading Assumption: Bet Amount = 1 Bitcoin for Each Prediction
            # Select Daily Returns Only From True Predictions Where Predicted Class equals Actual Class. It does not matter whether Daily Returns are Positive or Negative as Short-Selling Option Allows To Profit From Falling Prices
            profit = df_y_test_probaall_withdailyreturns["percentage_daily_return"][df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()
            
            # Select  Daily Returns Only From False Predictions Where Predicted Class equals Actual Class
            loss = df_y_test_probaall_withdailyreturns["percentage_daily_return"][df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()
            
            print( "{:.2f}%".format((profit-loss)*100) )
            
            if thresholdcalc == 0.5:
                percentlist.append( int((profit-loss)*100) )
            
            
            loss = loss * einsatz
            profit = profit * einsatz
            
            # Calculation of Transaction Costs based On BTC Value in USD. Each Future Trade considers Transaction Costs twice, becauase of Buying and Selling the Future
            transaction_costs = df_y_test_probaall_withdailyreturns['Transaction Costs in USD'].sum()
            
            # Calculation of Total Profit Considering Profit, Loss and Transaction Costs
            total=profit-loss-transaction_costs
            
            # In addition, the same setting with different time horizon
            currentpreds_all = len(df_y_test_probaall_withdailyreturns[df_y_test_probaall_withdailyreturns.index >= '2019-09-09' ])
            
            # Analog to Profit Calculation Above
            currentpreds_winning_total = df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])].abs().sum()
            # Analog to Loss Calculation Above 
            currentpreds_loosing_total = df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred'])].abs().sum()
            # Analog to Calculation of Transaction Costs Above
            currentpreds_transaction_costs = df_y_test_probaall_withdailyreturns['Transaction Costs in USD'][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred'])].sum()
            
            # Analog to Calculation of Total Profit
            currentpreds_total=currentpreds_winning_total-currentpreds_loosing_total-currentpreds_transaction_costs
            
            # Condition
            # In Case the Shorter Time Horizon Does Not Include any Sample -> Empyt Output
            if currentpreds_all == 0:
                currentpreds_all = '-'
                current_acc_calc = '-'
            
            # Otherwise Calculation of Accuracy analog to theeins Accuracy Calculation for the Entire Period
            else:
                current_acc_calc = (len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])]))/currentpreds_all
            
            # Display of Threshold, Total Profit, Profit, Loss, Transaction Costs, Accuracy and Correct Number of Predictions Both for the Specified Time Horizon and the Entire Time
#             print("Specified Period:")
#             print("Total Return in Specified Period:", int(currentpreds_total), "/ Profit: ", int(currentpreds_winning_total), "/ Loss: ", int(currentpreds_loosing_total), "/ Transaction Costs: ", int(currentpreds_transaction_costs),"/ Calculated Accuracy", current_acc_calc, "/ #Correct Predictions:", (len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])), "of", currentpreds_all)
#             print()
            print("Entire Period:")
            print("einsatz", int(df_y_test_withdailyreturns["Einsatz"].sum()),"Total Return:", int(total), "/ Profit: ", int(profit), "/ Loss: ", int(loss), "/ Transaction Costs: ", int(transaction_costs), "/ Calculated Accuracy", round(acc_calc, 2), "/ #Correct Predictions:", len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]),  "Of", len(df_y_test_probaall))
            print("einsatz/bet", df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall), "Total Return / bet", int(total) / len(df_y_test_probaall),"/ Transaction Costs / bet ", int(transaction_costs) / len(df_y_test_probaall), "/ Calculated Accuracy", round(acc_calc, 2))
            print("profit in % per bet: {:.2f}".format( 100*(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ))
            if thresholdcalc == 0.5:
                profitpercent.append( 100*(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) )
            
            print("einsatz * 1+profit% ^ # wetten {:.2f}".format( einsatz*(1+(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ) ** len(df_y_test_probaall) ) )
            if thresholdcalc == 0.5:
                zinseszins.append( einsatz*(1+(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ) ** len(df_y_test_probaall) )
            print()
            print()
            
            # Store All Calculated Values For Every Variable of Every Run
            # Specified Period
            # Threshold = 0.5
            if thresholdcalc == 0.5:
                spec_list_05_total.append(currentpreds_total) 
                spec_list_05_profit.append(currentpreds_winning_total) 
                spec_list_05_loss.append(currentpreds_loosing_total)
                spec_list_05_trans.append(currentpreds_transaction_costs)
                spec_list_05_acc.append(current_acc_calc)
                spec_list_05_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_05_preds.append(currentpreds_all)
            # Threshold = 0.6
            if thresholdcalc == 0.6:
                spec_list_06_total.append(currentpreds_total) 
                spec_list_06_profit.append(currentpreds_winning_total) 
                spec_list_06_loss.append(currentpreds_loosing_total)
                spec_list_06_trans.append(currentpreds_transaction_costs)
                spec_list_06_acc.append(current_acc_calc)
                spec_list_06_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_06_preds.append(currentpreds_all)
            # Threshold = 0.7
            if thresholdcalc == 0.7:
                spec_list_07_total.append(currentpreds_total) 
                spec_list_07_profit.append(currentpreds_winning_total) 
                spec_list_07_loss.append(currentpreds_loosing_total)
                spec_list_07_trans.append(currentpreds_transaction_costs)
                spec_list_07_acc.append(current_acc_calc)
                spec_list_07_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_07_preds.append(currentpreds_all)
            # Threshold = 0.8
            if thresholdcalc == 0.8:
                spec_list_08_total.append(currentpreds_total) 
                spec_list_08_profit.append(currentpreds_winning_total) 
                spec_list_08_loss.append(currentpreds_loosing_total)
                spec_list_08_trans.append(currentpreds_transaction_costs)
                spec_list_08_acc.append(current_acc_calc)
                spec_list_08_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_08_preds.append(currentpreds_all)  
          
            # Entire Period
            # Threshold = 0.5
            if thresholdcalc == 0.5:
                list_05_total.append(total) 
                list_05_profit.append(profit) 
                list_05_loss.append(loss)
                list_05_trans.append(transaction_costs)
                list_05_acc.append(acc_calc)
                list_05_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_05_preds.append(len(df_y_test_probaall))    
            # Threshold = 0.6
            if thresholdcalc == 0.6:
                list_06_total.append(total) 
                list_06_profit.append(profit) 
                list_06_loss.append(loss)
                list_06_trans.append(transaction_costs)
                list_06_acc.append(acc_calc)
                list_06_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_06_preds.append(len(df_y_test_probaall))        
            # Threshold = 0.7
            if thresholdcalc == 0.7:
                list_07_total.append(total) 
                list_07_profit.append(profit) 
                list_07_loss.append(loss)
                list_07_trans.append(transaction_costs)
                list_07_acc.append(acc_calc)
                list_07_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_07_preds.append(len(df_y_test_probaall))
            # Threshold = 0.8
            if thresholdcalc == 0.8:
                list_08_total.append(total) 
                list_08_profit.append(profit) 
                list_08_loss.append(loss)
                list_08_trans.append(transaction_costs)
                list_08_acc.append(acc_calc)
                list_08_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_08_preds.append(len(df_y_test_probaall)) 
            
    except:
        print("error")
    # Display Empty Rows Between Each Run
    print()
    print()
# Out:
# Run: 1
# [[220 241]
#  [142 400]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.48      0.53       461
#          1.0       0.62      0.74      0.68       542
#
#     accuracy                           0.62      1003
#    macro avg       0.62      0.61      0.61      1003
# weighted avg       0.62      0.62      0.61      1003
#
# 997.27%
# Entire Period:
# einsatz 609387 Total Return: 9363 / Profit:  19209 / Loss:  9236 / Transaction Costs:  609 / Calculated Accuracy 0.62 / #Correct Predictions: 620 Of 1003
# einsatz/bet 607.5646817413136 Total Return / bet 9.334995014955135 / Transaction Costs / bet  0.6071784646061814 / Calculated Accuracy 0.62
# profit in % per bet: 1.54
# einsatz * 1+profit% ^ # wetten 4384183649.68
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.39      0.48       189
#          1.0       0.69      0.85      0.76       299
#
#     accuracy                           0.67       488
#    macro avg       0.65      0.62      0.62       488
# weighted avg       0.66      0.67      0.65       488
#
# 708.02%
# Entire Period:
# einsatz 609387 Total Return: 6753 / Profit:  11256 / Loss:  4176 / Transaction Costs:  326 / Calculated Accuracy 0.67 / #Correct Predictions: 327 Of 488
# einsatz/bet 1248.7446225133965 Total Return / bet 13.83811475409836 / Transaction Costs / bet  0.6680327868852459 / Calculated Accuracy 0.67
# profit in % per bet: 1.11
# einsatz * 1+profit% ^ # wetten 216607.48
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.49      0.61        43
#          1.0       0.74      0.93      0.83        69
#
#     accuracy                           0.76       112
#    macro avg       0.78      0.71      0.72       112
# weighted avg       0.77      0.76      0.74       112
#
# 387.81%
# Entire Period:
# einsatz 609387 Total Return: 3794 / Profit:  4755 / Loss:  877 / Transaction Costs:  83 / Calculated Accuracy 0.76 / #Correct Predictions: 85 Of 112
# einsatz/bet 5440.958712379799 Total Return / bet 33.875 / Transaction Costs / bet  0.7410714285714286 / Calculated Accuracy 0.76
# profit in % per bet: 0.62
# einsatz * 1+profit% ^ # wetten 2003.99
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57         3
#          1.0       0.83      0.71      0.77         7
#
#     accuracy                           0.70        10
#    macro avg       0.67      0.69      0.67        10
# weighted avg       0.73      0.70      0.71        10
#
# 19.31%
# Entire Period:
# einsatz 609387 Total Return: 184 / Profit:  313 / Loss:  120 / Transaction Costs:  8 / Calculated Accuracy 0.7 / #Correct Predictions: 7 Of 10
# einsatz/bet 60938.73757865375 Total Return / bet 18.4 / Transaction Costs / bet  0.8 / Calculated Accuracy 0.7
# profit in % per bet: 0.03
# einsatz * 1+profit% ^ # wetten 1003.02
#
#
#
#
# Run: 2
# [[241 220]
#  [163 379]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.52      0.56       461
#          1.0       0.63      0.70      0.66       542
#
#     accuracy                           0.62      1003
#    macro avg       0.61      0.61      0.61      1003
# weighted avg       0.62      0.62      0.62      1003
#
# 1319.66%
# Entire Period:
# einsatz 611046 Total Return: 12585 / Profit:  21402 / Loss:  8206 / Transaction Costs:  611 / Calculated Accuracy 0.62 / #Correct Predictions: 620 Of 1003
# einsatz/bet 609.218579991012 Total Return / bet 12.547357926221336 / Transaction Costs / bet  0.609172482552343 / Calculated Accuracy 0.62
# profit in % per bet: 2.06
# einsatz * 1+profit% ^ # wetten 759185383958.35
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.50      0.57       202
#          1.0       0.70      0.84      0.77       289
#
#     accuracy                           0.70       491
#    macro avg       0.69      0.67      0.67       491
# weighted avg       0.70      0.70      0.69       491
#
# 1004.73%
# Entire Period:
# einsatz 611046 Total Return: 9717 / Profit:  13163 / Loss:  3115 / Transaction Costs:  329 / Calculated Accuracy 0.7 / #Correct Predictions: 343 Of 491
# einsatz/bet 1244.493351794267 Total Return / bet 19.790224032586558 / Transaction Costs / bet  0.670061099796334 / Calculated Accuracy 0.7
# profit in % per bet: 1.59
# einsatz * 1+profit% ^ # wetten 2313611.11
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.59      0.65        41
#          1.0       0.81      0.89      0.85        81
#
#     accuracy                           0.79       122
#    macro avg       0.77      0.74      0.75       122
# weighted avg       0.78      0.79      0.78       122
#
# 381.06%
# Entire Period:
# einsatz 611046 Total Return: 3719 / Profit:  4327 / Loss:  517 / Transaction Costs:  90 / Calculated Accuracy 0.79 / #Correct Predictions: 96 Of 122
# einsatz/bet 5008.575702712992 Total Return / bet 30.483606557377048 / Transaction Costs / bet  0.7377049180327869 / Calculated Accuracy 0.79
# profit in % per bet: 0.61
# einsatz * 1+profit% ^ # wetten 2096.51
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.50      0.40         2
#          1.0       0.83      0.71      0.77         7
#
#     accuracy                           0.67         9
#    macro avg       0.58      0.61      0.58         9
# weighted avg       0.72      0.67      0.69         9
#
# 47.55%
# Entire Period:
# einsatz 611046 Total Return: 467 / Profit:  512 / Loss:  37 / Transaction Costs:  7 / Calculated Accuracy 0.67 / #Correct Predictions: 6 Of 9
# einsatz/bet 67894.02619233167 Total Return / bet 51.888888888888886 / Transaction Costs / bet  0.7777777777777778 / Calculated Accuracy 0.67
# profit in % per bet: 0.08
# einsatz * 1+profit% ^ # wetten 1006.90
#
#
#
#
# Run: 3
# [[216 245]
#  [157 385]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.47      0.52       461
#          1.0       0.61      0.71      0.66       542
#
#     accuracy                           0.60      1003
#    macro avg       0.60      0.59      0.59      1003
# weighted avg       0.60      0.60      0.59      1003
#
# 821.05%
# Entire Period:
# einsatz 610353 Total Return: 7600 / Profit:  17496 / Loss:  9286 / Transaction Costs:  610 / Calculated Accuracy 0.6 / #Correct Predictions: 601 Of 1003
# einsatz/bet 608.528332616584 Total Return / bet 7.577268195413759 / Transaction Costs / bet  0.6081754735792622 / Calculated Accuracy 0.6
# profit in % per bet: 1.25
# einsatz * 1+profit% ^ # wetten 245740332.21
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.42      0.51       202
#          1.0       0.66      0.82      0.74       280
#
#     accuracy                           0.66       482
#    macro avg       0.65      0.62      0.62       482
# weighted avg       0.65      0.66      0.64       482
#
# 627.16%
# Entire Period:
# einsatz 610353 Total Return: 5946 / Profit:  10178 / Loss:  3906 / Transaction Costs:  325 / Calculated Accuracy 0.66 / #Correct Predictions: 316 Of 482
# einsatz/bet 1266.2944348847172 Total Return / bet 12.336099585062241 / Transaction Costs / bet  0.6742738589211619 / Calculated Accuracy 0.66
# profit in % per bet: 0.97
# einsatz * 1+profit% ^ # wetten 107003.97
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.41      0.52        41
#          1.0       0.79      0.93      0.85        97
#
#     accuracy                           0.78       138
#    macro avg       0.75      0.67      0.69       138
# weighted avg       0.77      0.78      0.76       138
#
# 433.44%
# Entire Period:
# einsatz 610353 Total Return: 4231 / Profit:  4950 / Loss:  616 / Transaction Costs:  103 / Calculated Accuracy 0.78 / #Correct Predictions: 107 Of 138
# einsatz/bet 4422.854475466911 Total Return / bet 30.659420289855074 / Transaction Costs / bet  0.7463768115942029 / Calculated Accuracy 0.78
# profit in % per bet: 0.69
# einsatz * 1+profit% ^ # wetten 2594.31
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.57      0.67         7
#          1.0       0.70      0.88      0.78         8
#
#     accuracy                           0.73        15
#    macro avg       0.75      0.72      0.72        15
# weighted avg       0.75      0.73      0.73        15
#
# 69.88%
# Entire Period:
# einsatz 610353 Total Return: 686 / Profit:  784 / Loss:  85 / Transaction Costs:  12 / Calculated Accuracy 0.73 / #Correct Predictions: 11 Of 15
# einsatz/bet 40690.26117429558 Total Return / bet 45.733333333333334 / Transaction Costs / bet  0.8 / Calculated Accuracy 0.73
# profit in % per bet: 0.11
# einsatz * 1+profit% ^ # wetten 1016.99
#
#
#
#
# Run: 4
# [[222 239]
#  [150 392]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.53       461
#          1.0       0.62      0.72      0.67       542
#
#     accuracy                           0.61      1003
#    macro avg       0.61      0.60      0.60      1003
# weighted avg       0.61      0.61      0.61      1003
#
# 1080.15%
# Entire Period:
# einsatz 612206 Total Return: 10189 / Profit:  20319 / Loss:  9517 / Transaction Costs:  612 / Calculated Accuracy 0.61 / #Correct Predictions: 614 Of 1003
# einsatz/bet 610.3758414809502 Total Return / bet 10.15852442671984 / Transaction Costs / bet  0.6101694915254238 / Calculated Accuracy 0.61
# profit in % per bet: 1.66
# einsatz * 1+profit% ^ # wetten 15488441256.23
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.52      0.55       180
#          1.0       0.73      0.78      0.76       302
#
#     accuracy                           0.68       482
#    macro avg       0.66      0.65      0.65       482
# weighted avg       0.68      0.68      0.68       482
#
# 809.95%
# Entire Period:
# einsatz 612206 Total Return: 7774 / Profit:  12384 / Loss:  4284 / Transaction Costs:  325 / Calculated Accuracy 0.68 / #Correct Predictions: 330 Of 482
# einsatz/bet 1270.1389398452136 Total Return / bet 16.12863070539419 / Transaction Costs / bet  0.6742738589211619 / Calculated Accuracy 0.68
# profit in % per bet: 1.27
# einsatz * 1+profit% ^ # wetten 437928.44
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.64      0.62        42
#          1.0       0.84      0.82      0.83        99
#
#     accuracy                           0.77       141
#    macro avg       0.72      0.73      0.73       141
# weighted avg       0.77      0.77      0.77       141
#
# 521.61%
# Entire Period:
# einsatz 612206 Total Return: 5110 / Profit:  6547 / Loss:  1331 / Transaction Costs:  105 / Calculated Accuracy 0.77 / #Correct Predictions: 108 Of 141
# einsatz/bet 4341.893397201368 Total Return / bet 36.241134751773046 / Transaction Costs / bet  0.7446808510638298 / Calculated Accuracy 0.77
# profit in % per bet: 0.83
# einsatz * 1+profit% ^ # wetten 3228.51
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.80      0.76        10
#          1.0       0.75      0.67      0.71         9
#
#     accuracy                           0.74        19
#    macro avg       0.74      0.73      0.73        19
# weighted avg       0.74      0.74      0.74        19
#
# 166.58%
# Entire Period:
# einsatz 612206 Total Return: 1649 / Profit:  1950 / Loss:  284 / Transaction Costs:  16 / Calculated Accuracy 0.74 / #Correct Predictions: 14 Of 19
# einsatz/bet 32221.41942133647 Total Return / bet 86.78947368421052 / Transaction Costs / bet  0.8421052631578947 / Calculated Accuracy 0.74
# profit in % per bet: 0.27
# einsatz * 1+profit% ^ # wetten 1052.44
#
#
#
#
# Run: 5
# [[237 224]
#  [160 382]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.51      0.55       461
#          1.0       0.63      0.70      0.67       542
#
#     accuracy                           0.62      1003
#    macro avg       0.61      0.61      0.61      1003
# weighted avg       0.62      0.62      0.61      1003
#
# 1076.29%
# Entire Period:
# einsatz 615723 Total Return: 10147 / Profit:  19947 / Loss:  9184 / Transaction Costs:  615 / Calculated Accuracy 0.62 / #Correct Predictions: 619 Of 1003
# einsatz/bet 613.8822239824478 Total Return / bet 10.116650049850449 / Transaction Costs / bet  0.613160518444666 / Calculated Accuracy 0.62
# profit in % per bet: 1.65
# einsatz * 1+profit% ^ # wetten 13183916770.07
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.45      0.52       213
#          1.0       0.68      0.82      0.74       302
#
#     accuracy                           0.66       515
#    macro avg       0.66      0.63      0.63       515
# weighted avg       0.66      0.66      0.65       515
#
# 819.84%
# Entire Period:
# einsatz 615723 Total Return: 7851 / Profit:  12846 / Loss:  4648 / Transaction Costs:  347 / Calculated Accuracy 0.66 / #Correct Predictions: 342 Of 515
# einsatz/bet 1195.5803313677577 Total Return / bet 15.244660194174758 / Transaction Costs / bet  0.6737864077669903 / Calculated Accuracy 0.66
# profit in % per bet: 1.28
# einsatz * 1+profit% ^ # wetten 682097.49
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.48      0.54        42
#          1.0       0.79      0.88      0.83        97
#
#     accuracy                           0.76       139
#    macro avg       0.71      0.68      0.69       139
# weighted avg       0.74      0.76      0.74       139
#
# 372.84%
# Entire Period:
# einsatz 615723 Total Return: 3624 / Profit:  5234 / Loss:  1506 / Transaction Costs:  103 / Calculated Accuracy 0.76 / #Correct Predictions: 105 Of 139
# einsatz/bet 4429.668134204282 Total Return / bet 26.071942446043167 / Transaction Costs / bet  0.7410071942446043 / Calculated Accuracy 0.76
# profit in % per bet: 0.59
# einsatz * 1+profit% ^ # wetten 2260.81
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      1.00      0.89         4
#          1.0       1.00      0.91      0.95        11
#
#     accuracy                           0.93        15
#    macro avg       0.90      0.95      0.92        15
# weighted avg       0.95      0.93      0.94        15
#
# 132.70%
# Entire Period:
# einsatz 615723 Total Return: 1314 / Profit:  1376 / Loss:  49 / Transaction Costs:  12 / Calculated Accuracy 0.93 / #Correct Predictions: 14 Of 15
# einsatz/bet 41048.258043626345 Total Return / bet 87.6 / Transaction Costs / bet  0.8 / Calculated Accuracy 0.93
# profit in % per bet: 0.21
# einsatz * 1+profit% ^ # wetten 1032.49
#
#
#
#
# Run: 6
# [[222 239]
#  [152 390]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.48      0.53       461
#          1.0       0.62      0.72      0.67       542
#
#     accuracy                           0.61      1003
#    macro avg       0.61      0.60      0.60      1003
# weighted avg       0.61      0.61      0.60      1003
#
# 809.05%
# Entire Period:
# einsatz 613125 Total Return: 7477 / Profit:  18100 / Loss:  10010 / Transaction Costs:  613 / Calculated Accuracy 0.61 / #Correct Predictions: 612 Of 1003
# einsatz/bet 611.2914036563491 Total Return / bet 7.454636091724826 / Transaction Costs / bet  0.6111665004985045 / Calculated Accuracy 0.61
# profit in % per bet: 1.22
# einsatz * 1+profit% ^ # wetten 190518071.74
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.45      0.54       209
#          1.0       0.69      0.85      0.76       301
#
#     accuracy                           0.68       510
#    macro avg       0.68      0.65      0.65       510
# weighted avg       0.68      0.68      0.67       510
#
# 722.41%
# Entire Period:
# einsatz 613125 Total Return: 6882 / Profit:  11458 / Loss:  4234 / Transaction Costs:  341 / Calculated Accuracy 0.68 / #Correct Predictions: 349 Of 510
# einsatz/bet 1202.2064271908198 Total Return / bet 13.494117647058824 / Transaction Costs / bet  0.6686274509803921 / Calculated Accuracy 0.68
# profit in % per bet: 1.12
# einsatz * 1+profit% ^ # wetten 296659.73
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.46      0.56        50
#          1.0       0.74      0.89      0.81        85
#
#     accuracy                           0.73       135
#    macro avg       0.73      0.68      0.68       135
# weighted avg       0.73      0.73      0.72       135
#
# 373.24%
# Entire Period:
# einsatz 613125 Total Return: 3631 / Profit:  5179 / Loss:  1446 / Transaction Costs:  100 / Calculated Accuracy 0.73 / #Correct Predictions: 99 Of 135
# einsatz/bet 4541.668724943097 Total Return / bet 26.896296296296295 / Transaction Costs / bet  0.7407407407407407 / Calculated Accuracy 0.73
# profit in % per bet: 0.59
# einsatz * 1+profit% ^ # wetten 2219.16
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.75      0.75         8
#          1.0       0.78      0.78      0.78         9
#
#     accuracy                           0.76        17
#    macro avg       0.76      0.76      0.76        17
# weighted avg       0.76      0.76      0.76        17
#
# 86.97%
# Entire Period:
# einsatz 613125 Total Return: 855 / Profit:  930 / Loss:  60 / Transaction Costs:  14 / Calculated Accuracy 0.76 / #Correct Predictions: 13 Of 17
# einsatz/bet 36066.19281572459 Total Return / bet 50.294117647058826 / Transaction Costs / bet  0.8235294117647058 / Calculated Accuracy 0.76
# profit in % per bet: 0.14
# einsatz * 1+profit% ^ # wetten 1023.97
#
#
#
#
# Run: 7
# [[229 232]
#  [141 401]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.55       461
#          1.0       0.63      0.74      0.68       542
#
#     accuracy                           0.63      1003
#    macro avg       0.63      0.62      0.62      1003
# weighted avg       0.63      0.63      0.62      1003
#
# 1262.59%
# Entire Period:
# einsatz 607524 Total Return: 12018 / Profit:  21052 / Loss:  8426 / Transaction Costs:  607 / Calculated Accuracy 0.63 / #Correct Predictions: 630 Of 1003
# einsatz/bet 605.7072812425959 Total Return / bet 11.982053838484546 / Transaction Costs / bet  0.6051844466600199 / Calculated Accuracy 0.63
# profit in % per bet: 1.98
# einsatz * 1+profit% ^ # wetten 341059773685.09
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.49      0.59       206
#          1.0       0.70      0.88      0.78       278
#
#     accuracy                           0.71       484
#    macro avg       0.73      0.69      0.69       484
# weighted avg       0.72      0.71      0.70       484
#
# 1072.47%
# Entire Period:
# einsatz 607524 Total Return: 10401 / Profit:  13843 / Loss:  3119 / Transaction Costs:  323 / Calculated Accuracy 0.71 / #Correct Predictions: 346 Of 484
# einsatz/bet 1255.2157088560407 Total Return / bet 21.489669421487605 / Transaction Costs / bet  0.6673553719008265 / Calculated Accuracy 0.71
# profit in % per bet: 1.71
# einsatz * 1+profit% ^ # wetten 3700018.73
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.67      0.74        46
#          1.0       0.80      0.90      0.85        67
#
#     accuracy                           0.81       113
#    macro avg       0.81      0.78      0.79       113
# weighted avg       0.81      0.81      0.80       113
#
# 516.82%
# Entire Period:
# einsatz 607524 Total Return: 5083 / Profit:  6030 / Loss:  862 / Transaction Costs:  84 / Calculated Accuracy 0.81 / #Correct Predictions: 91 Of 113
# einsatz/bet 5376.322151206404 Total Return / bet 44.982300884955755 / Transaction Costs / bet  0.7433628318584071 / Calculated Accuracy 0.81
# profit in % per bet: 0.84
# einsatz * 1+profit% ^ # wetten 2563.85
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.25      1.00      0.40         1
#          1.0       1.00      0.67      0.80         9
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.83      0.60        10
# weighted avg       0.93      0.70      0.76        10
#
# 47.71%
# Entire Period:
# einsatz 607524 Total Return: 468 / Profit:  567 / Loss:  90 / Transaction Costs:  8 / Calculated Accuracy 0.7 / #Correct Predictions: 7 Of 10
# einsatz/bet 60752.440308632365 Total Return / bet 46.8 / Transaction Costs / bet  0.8 / Calculated Accuracy 0.7
# profit in % per bet: 0.08
# einsatz * 1+profit% ^ # wetten 1007.73
#
#
#
#
# Run: 8
# [[226 235]
#  [139 403]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.49      0.55       461
#          1.0       0.63      0.74      0.68       542
#
#     accuracy                           0.63      1003
#    macro avg       0.63      0.62      0.62      1003
# weighted avg       0.63      0.63      0.62      1003
#
# 1088.65%
# Entire Period:
# einsatz 611484 Total Return: 10275 / Profit:  19381 / Loss:  8495 / Transaction Costs:  611 / Calculated Accuracy 0.63 / #Correct Predictions: 629 Of 1003
# einsatz/bet 609.6555854403509 Total Return / bet 10.244267198404785 / Transaction Costs / bet  0.609172482552343 / Calculated Accuracy 0.63
# profit in % per bet: 1.68
# einsatz * 1+profit% ^ # wetten 18142078359.63
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.44      0.53       210
#          1.0       0.68      0.84      0.75       296
#
#     accuracy                           0.68       506
#    macro avg       0.67      0.64      0.64       506
# weighted avg       0.67      0.68      0.66       506
#
# 911.58%
# Entire Period:
# einsatz 611484 Total Return: 8777 / Profit:  13024 / Loss:  3908 / Transaction Costs:  338 / Calculated Accuracy 0.68 / #Correct Predictions: 342 Of 506
# einsatz/bet 1208.467494459826 Total Return / bet 17.345849802371543 / Transaction Costs / bet  0.6679841897233202 / Calculated Accuracy 0.68
# profit in % per bet: 1.44
# einsatz * 1+profit% ^ # wetten 1354634.20
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.51      0.63        43
#          1.0       0.78      0.94      0.85        78
#
#     accuracy                           0.79       121
#    macro avg       0.80      0.72      0.74       121
# weighted avg       0.79      0.79      0.77       121
#
# 410.06%
# Entire Period:
# einsatz 611484 Total Return: 4009 / Profit:  4849 / Loss:  749 / Transaction Costs:  90 / Calculated Accuracy 0.79 / #Correct Predictions: 95 Of 121
# einsatz/bet 5053.591340468363 Total Return / bet 33.13223140495868 / Transaction Costs / bet  0.743801652892562 / Calculated Accuracy 0.79
# profit in % per bet: 0.66
# einsatz * 1+profit% ^ # wetten 2204.96
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.20      0.25         5
#          1.0       0.73      0.85      0.79        13
#
#     accuracy                           0.67        18
#    macro avg       0.53      0.52      0.52        18
# weighted avg       0.62      0.67      0.64        18
#
# 40.87%
# Entire Period:
# einsatz 611484 Total Return: 393 / Profit:  595 / Loss:  187 / Transaction Costs:  15 / Calculated Accuracy 0.67 / #Correct Predictions: 12 Of 18
# einsatz/bet 33971.36401092622 Total Return / bet 21.833333333333332 / Transaction Costs / bet  0.8333333333333334 / Calculated Accuracy 0.67
# profit in % per bet: 0.06
# einsatz * 1+profit% ^ # wetten 1011.63
#
#
#
#
# Run: 9
# [[238 223]
#  [168 374]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.52      0.55       461
#          1.0       0.63      0.69      0.66       542
#
#     accuracy                           0.61      1003
#    macro avg       0.61      0.60      0.60      1003
# weighted avg       0.61      0.61      0.61      1003
#
# 1183.58%
# Entire Period:
# einsatz 611535 Total Return: 11224 / Profit:  20972 / Loss:  9136 / Transaction Costs:  611 / Calculated Accuracy 0.61 / #Correct Predictions: 612 Of 1003
# einsatz/bet 609.7060312884425 Total Return / bet 11.190428713858426 / Transaction Costs / bet  0.609172482552343 / Calculated Accuracy 0.61
# profit in % per bet: 1.84
# einsatz * 1+profit% ^ # wetten 83635121606.58
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.46      0.54       213
#          1.0       0.67      0.83      0.74       287
#
#     accuracy                           0.67       500
#    macro avg       0.67      0.64      0.64       500
# weighted avg       0.67      0.67      0.66       500
#
# 991.41%
# Entire Period:
# einsatz 611535 Total Return: 9577 / Profit:  14010 / Loss:  4096 / Transaction Costs:  336 / Calculated Accuracy 0.67 / #Correct Predictions: 335 Of 500
# einsatz/bet 1223.0702987646157 Total Return / bet 19.154 / Transaction Costs / bet  0.672 / Calculated Accuracy 0.67
# profit in % per bet: 1.57
# einsatz * 1+profit% ^ # wetten 2367555.32
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.51      0.61        47
#          1.0       0.79      0.91      0.84        92
#
#     accuracy                           0.78       139
#    macro avg       0.77      0.71      0.73       139
# weighted avg       0.77      0.78      0.76       139
#
# 582.40%
# Entire Period:
# einsatz 611535 Total Return: 5720 / Profit:  6425 / Loss:  601 / Transaction Costs:  103 / Calculated Accuracy 0.78 / #Correct Predictions: 108 Of 139
# einsatz/bet 4399.533448793582 Total Return / bet 41.15107913669065 / Transaction Costs / bet  0.7410071942446043 / Calculated Accuracy 0.78
# profit in % per bet: 0.94
# einsatz * 1+profit% ^ # wetten 3647.69
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.83      0.77         6
#          1.0       0.93      0.87      0.90        15
#
#     accuracy                           0.86        21
#    macro avg       0.82      0.85      0.83        21
# weighted avg       0.87      0.86      0.86        21
#
# 146.83%
# Entire Period:
# einsatz 611535 Total Return: 1450 / Profit:  1533 / Loss:  65 / Transaction Costs:  17 / Calculated Accuracy 0.86 / #Correct Predictions: 18 Of 21
# einsatz/bet 29120.72139915752 Total Return / bet 69.04761904761905 / Transaction Costs / bet  0.8095238095238095 / Calculated Accuracy 0.86
# profit in % per bet: 0.24
# einsatz * 1+profit% ^ # wetten 1050.99
#
#
#
#
# Run: 10
# [[228 233]
#  [158 384]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.49      0.54       461
#          1.0       0.62      0.71      0.66       542
#
#     accuracy                           0.61      1003
#    macro avg       0.61      0.60      0.60      1003
# weighted avg       0.61      0.61      0.61      1003
#
# 1034.12%
# Entire Period:
# einsatz 608478 Total Return: 9732 / Profit:  20376 / Loss:  10035 / Transaction Costs:  608 / Calculated Accuracy 0.61 / #Correct Predictions: 612 Of 1003
# einsatz/bet 606.6584611071592 Total Return / bet 9.702891326021934 / Transaction Costs / bet  0.6061814556331007 / Calculated Accuracy 0.61
# profit in % per bet: 1.60
# einsatz * 1+profit% ^ # wetten 8162322320.24
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.49      0.56       193
#          1.0       0.70      0.82      0.75       279
#
#     accuracy                           0.68       472
#    macro avg       0.68      0.65      0.66       472
# weighted avg       0.68      0.68      0.67       472
#
# 841.31%
# Entire Period:
# einsatz 608478 Total Return: 8095 / Profit:  12624 / Loss:  4211 / Transaction Costs:  317 / Calculated Accuracy 0.68 / #Correct Predictions: 323 Of 472
# einsatz/bet 1289.1492298527132 Total Return / bet 17.15042372881356 / Transaction Costs / bet  0.6716101694915254 / Calculated Accuracy 0.68
# profit in % per bet: 1.33
# einsatz * 1+profit% ^ # wetten 511799.41
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.50      0.61        44
#          1.0       0.79      0.93      0.85        88
#
#     accuracy                           0.79       132
#    macro avg       0.79      0.72      0.73       132
# weighted avg       0.79      0.79      0.77       132
#
# 504.92%
# Entire Period:
# einsatz 608478 Total Return: 4950 / Profit:  5903 / Loss:  854 / Transaction Costs:  98 / Calculated Accuracy 0.79 / #Correct Predictions: 104 Of 132
# einsatz/bet 4609.685124927884 Total Return / bet 37.5 / Transaction Costs / bet  0.7424242424242424 / Calculated Accuracy 0.79
# profit in % per bet: 0.81
# einsatz * 1+profit% ^ # wetten 2913.87
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80         5
#          1.0       0.91      0.91      0.91        11
#
#     accuracy                           0.88        16
#    macro avg       0.85      0.85      0.85        16
# weighted avg       0.88      0.88      0.88        16
#
# 115.16%
# Entire Period:
# einsatz 608478 Total Return: 1137 / Profit:  1215 / Loss:  63 / Transaction Costs:  13 / Calculated Accuracy 0.88 / #Correct Predictions: 14 Of 16
# einsatz/bet 38029.90228065504 Total Return / bet 71.0625 / Transaction Costs / bet  0.8125 / Calculated Accuracy 0.88
# profit in % per bet: 0.19
# einsatz * 1+profit% ^ # wetten 1030.32
#
#
#
#
# Run: 11
# [[233 228]
#  [160 382]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.51      0.55       461
#          1.0       0.63      0.70      0.66       542
#
#     accuracy                           0.61      1003
#    macro avg       0.61      0.61      0.60      1003
# weighted avg       0.61      0.61      0.61      1003
#
# 1123.44%
# Entire Period:
# einsatz 601531 Total Return: 10632 / Profit:  19418 / Loss:  8183 / Transaction Costs:  601 / Calculated Accuracy 0.61 / #Correct Predictions: 615 Of 1003
# einsatz/bet 599.7321410782704 Total Return / bet 10.600199401794615 / Transaction Costs / bet  0.5992023928215354 / Calculated Accuracy 0.61
# profit in % per bet: 1.77
# einsatz * 1+profit% ^ # wetten 42843597779.20
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.51      0.59       177
#          1.0       0.73      0.86      0.79       267
#
#     accuracy                           0.72       444
#    macro avg       0.72      0.69      0.69       444
# weighted avg       0.72      0.72      0.71       444
#
# 823.44%
# Entire Period:
# einsatz 601531 Total Return: 7939 / Profit:  11093 / Loss:  2858 / Transaction Costs:  294 / Calculated Accuracy 0.72 / #Correct Predictions: 320 Of 444
# einsatz/bet 1354.8003096880748 Total Return / bet 17.88063063063063 / Transaction Costs / bet  0.6621621621621622 / Calculated Accuracy 0.72
# profit in % per bet: 1.32
# einsatz * 1+profit% ^ # wetten 337502.07
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.67      0.69        27
#          1.0       0.88      0.90      0.89        70
#
#     accuracy                           0.84        97
#    macro avg       0.80      0.78      0.79        97
# weighted avg       0.83      0.84      0.83        97
#
# 293.27%
# Entire Period:
# einsatz 601531 Total Return: 2861 / Profit:  3521 / Loss:  588 / Transaction Costs:  71 / Calculated Accuracy 0.84 / #Correct Predictions: 81 Of 97
# einsatz/bet 6201.353994860878 Total Return / bet 29.49484536082474 / Transaction Costs / bet  0.7319587628865979 / Calculated Accuracy 0.84
# profit in % per bet: 0.48
# einsatz * 1+profit% ^ # wetten 1584.48
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.86         4
#          1.0       0.88      1.00      0.93         7
#
#     accuracy                           0.91        11
#    macro avg       0.94      0.88      0.90        11
# weighted avg       0.92      0.91      0.91        11
#
# 71.02%
# Entire Period:
# einsatz 601531 Total Return: 701 / Profit:  760 / Loss:  50 / Transaction Costs:  9 / Calculated Accuracy 0.91 / #Correct Predictions: 10 Of 11
# einsatz/bet 54684.66704559138 Total Return / bet 63.72727272727273 / Transaction Costs / bet  0.8181818181818182 / Calculated Accuracy 0.91
# profit in % per bet: 0.12
# einsatz * 1+profit% ^ # wetten 1012.89
#
#
#
#
# Run: 12
# [[250 211]
#  [169 373]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.54      0.57       461
#          1.0       0.64      0.69      0.66       542
#
#     accuracy                           0.62      1003
#    macro avg       0.62      0.62      0.62      1003
# weighted avg       0.62      0.62      0.62      1003
#
# 1057.93%
# Entire Period:
# einsatz 608083 Total Return: 9971 / Profit:  18893 / Loss:  8314 / Transaction Costs:  608 / Calculated Accuracy 0.62 / #Correct Predictions: 623 Of 1003
# einsatz/bet 606.2643372810686 Total Return / bet 9.941176470588236 / Transaction Costs / bet  0.6061814556331007 / Calculated Accuracy 0.62
# profit in % per bet: 1.64
# einsatz * 1+profit% ^ # wetten 12154819873.24
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.56      0.63       199
#          1.0       0.71      0.84      0.77       261
#
#     accuracy                           0.72       460
#    macro avg       0.72      0.70      0.70       460
# weighted avg       0.72      0.72      0.71       460
#
# 874.34%
# Entire Period:
# einsatz 608083 Total Return: 8433 / Profit:  11667 / Loss:  2924 / Transaction Costs:  309 / Calculated Accuracy 0.72 / #Correct Predictions: 329 Of 460
# einsatz/bet 1321.9198484628516 Total Return / bet 18.332608695652173 / Transaction Costs / bet  0.6717391304347826 / Calculated Accuracy 0.72
# profit in % per bet: 1.39
# einsatz * 1+profit% ^ # wetten 564267.14
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.71      0.73        41
#          1.0       0.86      0.89      0.88        85
#
#     accuracy                           0.83       126
#    macro avg       0.81      0.80      0.81       126
# weighted avg       0.83      0.83      0.83       126
#
# 429.07%
# Entire Period:
# einsatz 608083 Total Return: 4196 / Profit:  4796 / Loss:  506 / Transaction Costs:  94 / Calculated Accuracy 0.83 / #Correct Predictions: 105 Of 126
# einsatz/bet 4826.056589626284 Total Return / bet 33.301587301587304 / Transaction Costs / bet  0.746031746031746 / Calculated Accuracy 0.83
# profit in % per bet: 0.69
# einsatz * 1+profit% ^ # wetten 2378.48
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.75      0.71         8
#          1.0       0.78      0.70      0.74        10
#
#     accuracy                           0.72        18
#    macro avg       0.72      0.72      0.72        18
# weighted avg       0.73      0.72      0.72        18
#
# 50.03%
# Entire Period:
# einsatz 608083 Total Return: 484 / Profit:  643 / Loss:  142 / Transaction Costs:  15 / Calculated Accuracy 0.72 / #Correct Predictions: 13 Of 18
# einsatz/bet 33782.39612738399 Total Return / bet 26.88888888888889 / Transaction Costs / bet  0.8333333333333334 / Calculated Accuracy 0.72
# profit in % per bet: 0.08
# einsatz * 1+profit% ^ # wetten 1014.42
#
#
#
#
# Run: 13
# [[241 220]
#  [162 380]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.52      0.56       461
#          1.0       0.63      0.70      0.67       542
#
#     accuracy                           0.62      1003
#    macro avg       0.62      0.61      0.61      1003
# weighted avg       0.62      0.62      0.62      1003
#
# 1058.31%
# Entire Period:
# einsatz 612232 Total Return: 9970 / Profit:  19507 / Loss:  8924 / Transaction Costs:  612 / Calculated Accuracy 0.62 / #Correct Predictions: 621 Of 1003
# einsatz/bet 610.4014078439246 Total Return / bet 9.940179461615154 / Transaction Costs / bet  0.6101694915254238 / Calculated Accuracy 0.62
# profit in % per bet: 1.63
# einsatz * 1+profit% ^ # wetten 10874679420.84
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.48      0.56       221
#          1.0       0.67      0.84      0.74       282
#
#     accuracy                           0.68       503
#    macro avg       0.68      0.66      0.65       503
# weighted avg       0.68      0.68      0.67       503
#
# 879.94%
# Entire Period:
# einsatz 612232 Total Return: 8461 / Profit:  12512 / Loss:  3713 / Transaction Costs:  337 / Calculated Accuracy 0.68 / #Correct Predictions: 341 Of 503
# einsatz/bet 1217.162250631126 Total Return / bet 16.821073558648113 / Transaction Costs / bet  0.6699801192842942 / Calculated Accuracy 0.68
# profit in % per bet: 1.38
# einsatz * 1+profit% ^ # wetten 996071.56
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.55      0.64        40
#          1.0       0.82      0.92      0.87        89
#
#     accuracy                           0.81       129
#    macro avg       0.79      0.74      0.75       129
# weighted avg       0.80      0.81      0.80       129
#
# 448.85%
# Entire Period:
# einsatz 612232 Total Return: 4391 / Profit:  5020 / Loss:  532 / Transaction Costs:  96 / Calculated Accuracy 0.81 / #Correct Predictions: 104 Of 129
# einsatz/bet 4745.989240832995 Total Return / bet 34.03875968992248 / Transaction Costs / bet  0.7441860465116279 / Calculated Accuracy 0.81
# profit in % per bet: 0.72
# einsatz * 1+profit% ^ # wetten 2514.06
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.75      0.90      0.82        10
#
#     accuracy                           0.69        13
#    macro avg       0.38      0.45      0.41        13
# weighted avg       0.58      0.69      0.63        13
#
# 32.76%
# Entire Period:
# einsatz 612232 Total Return: 316 / Profit:  369 / Loss:  42 / Transaction Costs:  10 / Calculated Accuracy 0.69 / #Correct Predictions: 9 Of 13
# einsatz/bet 47094.81631288126 Total Return / bet 24.307692307692307 / Transaction Costs / bet  0.7692307692307693 / Calculated Accuracy 0.69
# profit in % per bet: 0.05
# einsatz * 1+profit% ^ # wetten 1006.73
#
#
#
#
# Run: 14
# [[219 242]
#  [151 391]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.48      0.53       461
#          1.0       0.62      0.72      0.67       542
#
#     accuracy                           0.61      1003
#    macro avg       0.60      0.60      0.60      1003
# weighted avg       0.61      0.61      0.60      1003
#
# 1041.59%
# Entire Period:
# einsatz 613316 Total Return: 9802 / Profit:  19476 / Loss:  9060 / Transaction Costs:  613 / Calculated Accuracy 0.61 / #Correct Predictions: 610 Of 1003
# einsatz/bet 611.4823457482238 Total Return / bet 9.772681954137587 / Transaction Costs / bet  0.6111665004985045 / Calculated Accuracy 0.61
# profit in % per bet: 1.60
# einsatz * 1+profit% ^ # wetten 8065874620.55
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.43      0.52       193
#          1.0       0.70      0.85      0.77       298
#
#     accuracy                           0.68       491
#    macro avg       0.67      0.64      0.64       491
# weighted avg       0.68      0.68      0.67       491
#
# 949.79%
# Entire Period:
# einsatz 613316 Total Return: 9165 / Profit:  12681 / Loss:  3183 / Transaction Costs:  332 / Calculated Accuracy 0.68 / #Correct Predictions: 336 Of 491
# einsatz/bet 1249.11770424739 Total Return / bet 18.665987780040734 / Transaction Costs / bet  0.6761710794297352 / Calculated Accuracy 0.68
# profit in % per bet: 1.49
# einsatz * 1+profit% ^ # wetten 1455199.04
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.56      0.61        41
#          1.0       0.82      0.88      0.85        92
#
#     accuracy                           0.78       133
#    macro avg       0.75      0.72      0.73       133
# weighted avg       0.77      0.78      0.78       133
#
# 518.28%
# Entire Period:
# einsatz 613316 Total Return: 5081 / Profit:  6002 / Loss:  820 / Transaction Costs:  101 / Calculated Accuracy 0.78 / #Correct Predictions: 104 Of 133
# einsatz/bet 4611.404457033598 Total Return / bet 38.203007518796994 / Transaction Costs / bet  0.7593984962406015 / Calculated Accuracy 0.78
# profit in % per bet: 0.83
# einsatz * 1+profit% ^ # wetten 2996.05
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.75      0.71         8
#          1.0       0.88      0.83      0.86        18
#
#     accuracy                           0.81        26
#    macro avg       0.77      0.79      0.78        26
# weighted avg       0.82      0.81      0.81        26
#
# 192.17%
# Entire Period:
# einsatz 613316 Total Return: 1899 / Profit:  2058 / Loss:  136 / Transaction Costs:  22 / Calculated Accuracy 0.81 / #Correct Predictions: 21 Of 26
# einsatz/bet 23589.10741482571 Total Return / bet 73.03846153846153 / Transaction Costs / bet  0.8461538461538461 / Calculated Accuracy 0.81
# profit in % per bet: 0.31
# einsatz * 1+profit% ^ # wetten 1083.70
#
#
#
#
# Run: 15
# [[216 245]
#  [139 403]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.47      0.53       461
#          1.0       0.62      0.74      0.68       542
#
#     accuracy                           0.62      1003
#    macro avg       0.62      0.61      0.60      1003
# weighted avg       0.62      0.62      0.61      1003
#
# 1221.93%
# Entire Period:
# einsatz 613574 Total Return: 11605 / Profit:  20760 / Loss:  8541 / Transaction Costs:  613 / Calculated Accuracy 0.62 / #Correct Predictions: 619 Of 1003
# einsatz/bet 611.7394517287447 Total Return / bet 11.570289132602193 / Transaction Costs / bet  0.6111665004985045 / Calculated Accuracy 0.62
# profit in % per bet: 1.89
# einsatz * 1+profit% ^ # wetten 145156571620.49
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.41      0.52       200
#          1.0       0.68      0.87      0.76       290
#
#     accuracy                           0.68       490
#    macro avg       0.68      0.64      0.64       490
# weighted avg       0.68      0.68      0.66       490
#
# 925.03%
# Entire Period:
# einsatz 613574 Total Return: 8918 / Profit:  12891 / Loss:  3641 / Transaction Costs:  331 / Calculated Accuracy 0.68 / #Correct Predictions: 335 Of 490
# einsatz/bet 1252.1932042529204 Total Return / bet 18.2 / Transaction Costs / bet  0.6755102040816326 / Calculated Accuracy 0.68
# profit in % per bet: 1.45
# einsatz * 1+profit% ^ # wetten 1176905.27
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.38      0.52        52
#          1.0       0.74      0.95      0.83        98
#
#     accuracy                           0.75       150
#    macro avg       0.77      0.67      0.68       150
# weighted avg       0.76      0.75      0.73       150
#
# 444.07%
# Entire Period:
# einsatz 613574 Total Return: 4328 / Profit:  5572 / Loss:  1131 / Transaction Costs:  112 / Calculated Accuracy 0.75 / #Correct Predictions: 113 Of 150
# einsatz/bet 4090.49780055954 Total Return / bet 28.85333333333333 / Transaction Costs / bet  0.7466666666666667 / Calculated Accuracy 0.75
# profit in % per bet: 0.71
# einsatz * 1+profit% ^ # wetten 2870.10
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         6
#          1.0       0.77      1.00      0.87        10
#
#     accuracy                           0.81        16
#    macro avg       0.88      0.75      0.77        16
# weighted avg       0.86      0.81      0.79        16
#
# 152.54%
# Entire Period:
# einsatz 613574 Total Return: 1511 / Profit:  1675 / Loss:  150 / Transaction Costs:  13 / Calculated Accuracy 0.81 / #Correct Predictions: 13 Of 16
# einsatz/bet 38348.416880245684 Total Return / bet 94.4375 / Transaction Costs / bet  0.8125 / Calculated Accuracy 0.81
# profit in % per bet: 0.25
# einsatz * 1+profit% ^ # wetten 1040.14
#
#
#
#
# Run: 16
# [[223 238]
#  [149 393]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.54       461
#          1.0       0.62      0.73      0.67       542
#
#     accuracy                           0.61      1003
#    macro avg       0.61      0.60      0.60      1003
# weighted avg       0.61      0.61      0.61      1003
#
# 960.00%
# Entire Period:
# einsatz 612855 Total Return: 8987 / Profit:  18824 / Loss:  9224 / Transaction Costs:  612 / Calculated Accuracy 0.61 / #Correct Predictions: 616 Of 1003
# einsatz/bet 611.022560159822 Total Return / bet 8.96011964107677 / Transaction Costs / bet  0.6101694915254238 / Calculated Accuracy 0.61
# profit in % per bet: 1.47
# einsatz * 1+profit% ^ # wetten 2194210800.23
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.46      0.55       217
#          1.0       0.68      0.85      0.75       295
#
#     accuracy                           0.68       512
#    macro avg       0.68      0.65      0.65       512
# weighted avg       0.68      0.68      0.67       512
#
# 814.70%
# Entire Period:
# einsatz 612855 Total Return: 7803 / Profit:  12281 / Loss:  4134 / Transaction Costs:  343 / Calculated Accuracy 0.68 / #Correct Predictions: 349 Of 512
# einsatz/bet 1196.9836481255888 Total Return / bet 15.240234375 / Transaction Costs / bet  0.669921875 / Calculated Accuracy 0.68
# profit in % per bet: 1.27
# einsatz * 1+profit% ^ # wetten 650495.96
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.68      0.73        38
#          1.0       0.86      0.91      0.88        78
#
#     accuracy                           0.84       116
#    macro avg       0.82      0.80      0.81       116
# weighted avg       0.83      0.84      0.83       116
#
# 422.19%
# Entire Period:
# einsatz 612855 Total Return: 4134 / Profit:  4833 / Loss:  611 / Transaction Costs:  87 / Calculated Accuracy 0.84 / #Correct Predictions: 97 Of 116
# einsatz/bet 5283.238171037082 Total Return / bet 35.63793103448276 / Transaction Costs / bet  0.75 / Calculated Accuracy 0.84
# profit in % per bet: 0.67
# einsatz * 1+profit% ^ # wetten 2181.14
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.67      0.73         6
#          1.0       0.85      0.92      0.88        12
#
#     accuracy                           0.83        18
#    macro avg       0.82      0.79      0.80        18
# weighted avg       0.83      0.83      0.83        18
#
# 119.19%
# Entire Period:
# einsatz 612855 Total Return: 1176 / Profit:  1235 / Loss:  43 / Transaction Costs:  15 / Calculated Accuracy 0.83 / #Correct Predictions: 15 Of 18
# einsatz/bet 34047.53488001675 Total Return / bet 65.33333333333333 / Transaction Costs / bet  0.8333333333333334 / Calculated Accuracy 0.83
# profit in % per bet: 0.19
# einsatz * 1+profit% ^ # wetten 1035.11
#
#
#
#
# Run: 17
# [[236 225]
#  [162 380]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.51      0.55       461
#          1.0       0.63      0.70      0.66       542
#
#     accuracy                           0.61      1003
#    macro avg       0.61      0.61      0.61      1003
# weighted avg       0.61      0.61      0.61      1003
#
# 1127.46%
# Entire Period:
# einsatz 614736 Total Return: 10659 / Profit:  20012 / Loss:  8738 / Transaction Costs:  614 / Calculated Accuracy 0.61 / #Correct Predictions: 616 Of 1003
# einsatz/bet 612.8973553698884 Total Return / bet 10.627118644067796 / Transaction Costs / bet  0.6121635094715853 / Calculated Accuracy 0.61
# profit in % per bet: 1.73
# einsatz * 1+profit% ^ # wetten 30771917601.20
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.47      0.54       199
#          1.0       0.70      0.82      0.75       295
#
#     accuracy                           0.68       494
#    macro avg       0.67      0.64      0.65       494
# weighted avg       0.67      0.68      0.67       494
#
# 1000.81%
# Entire Period:
# einsatz 614736 Total Return: 9672 / Profit:  13385 / Loss:  3377 / Transaction Costs:  335 / Calculated Accuracy 0.68 / #Correct Predictions: 335 Of 494
# einsatz/bet 1244.4049543238825 Total Return / bet 19.57894736842105 / Transaction Costs / bet  0.6781376518218624 / Calculated Accuracy 0.68
# profit in % per bet: 1.57
# einsatz * 1+profit% ^ # wetten 2234738.73
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.60      0.65        47
#          1.0       0.83      0.90      0.86       105
#
#     accuracy                           0.80       152
#    macro avg       0.77      0.75      0.76       152
# weighted avg       0.80      0.80      0.80       152
#
# 539.49%
# Entire Period:
# einsatz 614736 Total Return: 5280 / Profit:  6124 / Loss:  729 / Transaction Costs:  113 / Calculated Accuracy 0.8 / #Correct Predictions: 122 Of 152
# einsatz/bet 4044.3161015526184 Total Return / bet 34.73684210526316 / Transaction Costs / bet  0.743421052631579 / Calculated Accuracy 0.8
# profit in % per bet: 0.86
# einsatz * 1+profit% ^ # wetten 3669.15
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.92      0.85        12
#          1.0       0.75      0.50      0.60         6
#
#     accuracy                           0.78        18
#    macro avg       0.77      0.71      0.72        18
# weighted avg       0.77      0.78      0.76        18
#
# 143.93%
# Entire Period:
# einsatz 614736 Total Return: 1423 / Profit:  1696 / Loss:  257 / Transaction Costs:  15 / Calculated Accuracy 0.78 / #Correct Predictions: 14 Of 18
# einsatz/bet 34152.00263533322 Total Return / bet 79.05555555555556 / Transaction Costs / bet  0.8333333333333334 / Calculated Accuracy 0.78
# profit in % per bet: 0.23
# einsatz * 1+profit% ^ # wetten 1042.50
#
#
#
#
# Run: 18
# [[225 236]
#  [148 394]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.49      0.54       461
#          1.0       0.63      0.73      0.67       542
#
#     accuracy                           0.62      1003
#    macro avg       0.61      0.61      0.61      1003
# weighted avg       0.62      0.62      0.61      1003
#
# 1010.60%
# Entire Period:
# einsatz 609067 Total Return: 9496 / Profit:  19041 / Loss:  8935 / Transaction Costs:  609 / Calculated Accuracy 0.62 / #Correct Predictions: 619 Of 1003
# einsatz/bet 607.2455288623585 Total Return / bet 9.467597208374876 / Transaction Costs / bet  0.6071784646061814 / Calculated Accuracy 0.62
# profit in % per bet: 1.56
# einsatz * 1+profit% ^ # wetten 5483057801.98
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.47      0.56       205
#          1.0       0.71      0.87      0.78       303
#
#     accuracy                           0.71       508
#    macro avg       0.71      0.67      0.67       508
# weighted avg       0.71      0.71      0.69       508
#
# 943.02%
# Entire Period:
# einsatz 609067 Total Return: 9092 / Profit:  13124 / Loss:  3693 / Transaction Costs:  337 / Calculated Accuracy 0.71 / #Correct Predictions: 359 Of 508
# einsatz/bet 1198.9513099388691 Total Return / bet 17.89763779527559 / Transaction Costs / bet  0.6633858267716536 / Calculated Accuracy 0.71
# profit in % per bet: 1.49
# einsatz * 1+profit% ^ # wetten 1857989.16
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.53      0.63        30
#          1.0       0.83      0.93      0.88        72
#
#     accuracy                           0.81       102
#    macro avg       0.79      0.73      0.75       102
# weighted avg       0.81      0.81      0.80       102
#
# 432.48%
# Entire Period:
# einsatz 609067 Total Return: 4249 / Profit:  4793 / Loss:  468 / Transaction Costs:  75 / Calculated Accuracy 0.81 / #Correct Predictions: 83 Of 102
# einsatz/bet 5971.247700479858 Total Return / bet 41.65686274509804 / Transaction Costs / bet  0.7352941176470589 / Calculated Accuracy 0.81
# profit in % per bet: 0.70
# einsatz * 1+profit% ^ # wetten 2032.17
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.60      1.00      0.75         3
#          1.0       1.00      0.80      0.89        10
#
#     accuracy                           0.85        13
#    macro avg       0.80      0.90      0.82        13
# weighted avg       0.91      0.85      0.86        13
#
# 138.95%
# Entire Period:
# einsatz 609067 Total Return: 1378 / Profit:  1456 / Loss:  66 / Transaction Costs:  10 / Calculated Accuracy 0.85 / #Correct Predictions: 11 Of 13
# einsatz/bet 46851.328111457355 Total Return / bet 106.0 / Transaction Costs / bet  0.7692307692307693 / Calculated Accuracy 0.85
# profit in % per bet: 0.23
# einsatz * 1+profit% ^ # wetten 1029.81
#
#
#
#
# Run: 19
# [[226 235]
#  [165 377]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.49      0.53       461
#          1.0       0.62      0.70      0.65       542
#
#     accuracy                           0.60      1003
#    macro avg       0.60      0.59      0.59      1003
# weighted avg       0.60      0.60      0.60      1003
#
# 1114.31%
# Entire Period:
# einsatz 612729 Total Return: 10530 / Profit:  19631 / Loss:  8488 / Transaction Costs:  612 / Calculated Accuracy 0.6 / #Correct Predictions: 603 Of 1003
# einsatz/bet 610.8971616626912 Total Return / bet 10.498504486540378 / Transaction Costs / bet  0.6101694915254238 / Calculated Accuracy 0.6
# profit in % per bet: 1.72
# einsatz * 1+profit% ^ # wetten 26443138817.80
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.47      0.55       213
#          1.0       0.66      0.81      0.73       270
#
#     accuracy                           0.66       483
#    macro avg       0.66      0.64      0.64       483
# weighted avg       0.66      0.66      0.65       483
#
# 813.91%
# Entire Period:
# einsatz 612729 Total Return: 7810 / Profit:  12212 / Loss:  4073 / Transaction Costs:  328 / Calculated Accuracy 0.66 / #Correct Predictions: 320 Of 483
# einsatz/bet 1268.5918284631043 Total Return / bet 16.169772256728777 / Transaction Costs / bet  0.6790890269151139 / Calculated Accuracy 0.66
# profit in % per bet: 1.27
# einsatz * 1+profit% ^ # wetten 453741.25
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.42      0.52        59
#          1.0       0.72      0.88      0.79       101
#
#     accuracy                           0.71       160
#    macro avg       0.70      0.65      0.66       160
# weighted avg       0.71      0.71      0.69       160
#
# 386.33%
# Entire Period:
# einsatz 612729 Total Return: 3742 / Profit:  5163 / Loss:  1300 / Transaction Costs:  120 / Calculated Accuracy 0.71 / #Correct Predictions: 114 Of 160
# einsatz/bet 3829.561582172996 Total Return / bet 23.3875 / Transaction Costs / bet  0.75 / Calculated Accuracy 0.71
# profit in % per bet: 0.61
# einsatz * 1+profit% ^ # wetten 2648.95
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.70      0.70        10
#          1.0       0.81      0.81      0.81        16
#
#     accuracy                           0.77        26
#    macro avg       0.76      0.76      0.76        26
# weighted avg       0.77      0.77      0.77        26
#
# 126.85%
# Entire Period:
# einsatz 612729 Total Return: 1246 / Profit:  1497 / Loss:  228 / Transaction Costs:  21 / Calculated Accuracy 0.77 / #Correct Predictions: 20 Of 26
# einsatz/bet 23566.532813372283 Total Return / bet 47.92307692307692 / Transaction Costs / bet  0.8076923076923077 / Calculated Accuracy 0.77
# profit in % per bet: 0.20
# einsatz * 1+profit% ^ # wetten 1054.24

# %%
import statistics
print("einsatz", einsatz)
print( statistics.median(zinseszins) )
print( statistics.median(profitpercent) )
print( statistics.median(percentlist) )
# Out:
# einsatz 1000
# 13183916770.067236
# 1.647978985972349
# 1076

# %%
profitpercent
# Out:
# [1.5364611037298166,
#  2.059582281027353,
#  1.2451791953272906,
#  1.6643064381565777,
#  1.647978985972349,
#  1.2194897633331703,
#  1.9781921415743282,
#  1.680336807052363,
#  1.835381009797557,
#  1.5993993240140487,
#  1.7674889631121498,
#  1.6397429073878433,
#  1.6284660116899319,
#  1.5981952744979921,
#  1.8913753396000768,
#  1.4664138814666872,
#  1.7339149126617206,
#  1.5591052973435482,
#  1.7185387566650965]

# %%
df_y_test_withdailyreturns.sort_values("Daily Return in USD")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2018-01-17   0.00         0.18    0.00             -2107.42
# 2018-01-12   0.00         0.39    0.00             -1539.51
# 2017-12-23   0.00         0.46    0.00             -1510.96
# 2018-01-22   0.00         0.35    0.00             -1308.25
# 2018-02-06   0.00         0.15    0.00             -1284.53
# ...           ...          ...     ...                  ...
# 2017-12-16   1.00         0.66    1.00              1036.31
# 2020-07-28   1.00         0.63    1.00              1117.09
# 2019-10-26   1.00         0.64    1.00              1158.86
# 2019-06-29   1.00         0.60    1.00              1240.96
# 2018-01-03   1.00         0.49    0.00              1296.05
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2018-01-17                    -0.19                11136.81
# 2018-01-12                    -0.11                13797.82
# 2017-12-23                    -0.10                14800.70
# 2018-01-22                    -0.12                10781.27
# 2018-02-06                    -0.17                 7714.39
# ...                             ...                     ...
# 2017-12-16                     0.05                19587.61
# 2020-07-28                     0.10                10909.90
# 2019-10-26                     0.13                 9248.61
# 2019-06-29                     0.10                11958.97
# 2018-01-03                     0.09                15068.49
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2018-01-17                   0.82   824.98                      0.82
# 2018-01-12                   0.61   609.16                      0.61
# 2017-12-23                   0.54   537.57                      0.54
# 2018-01-22                   0.65   646.77                      0.65
# 2018-02-06                   0.85   847.77                      0.85
# ...                           ...      ...                       ...
# 2017-12-16                   0.66   658.11                      0.66
# 2020-07-28                   0.63   632.94                      0.63
# 2019-10-26                   0.64   641.70                      0.64
# 2019-06-29                   0.60   596.94                      0.60
# 2018-01-03                   0.51   511.72                      0.51
#
# [1003 rows x 9 columns]

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]].abs().sum()
# Out:
# Class                          165.00
# y_pred_prob                    211.69
# y_pred                         235.00
# Daily Return in USD          27466.04
# percentage_daily_return          8.49
# market/price_usd_close     1293925.88
# y_pred_prob_bereinigt          238.08
# Einsatz                     238077.27
# Transaction Costs in USD       238.08
# dtype: float64

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]].abs().sum()
# Out:
# Class                          377.00
# y_pred_prob                    327.19
# y_pred                         377.00
# Daily Return in USD          63067.52
# percentage_daily_return         19.63
# market/price_usd_close     1847906.13
# y_pred_prob_bereinigt          374.65
# Einsatz                     374652.58
# Transaction Costs in USD       374.65
# dtype: float64

# %%
dfrights = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]]
dfwrongs = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]]

# %%
dfwrongs.abs().sort_values("percentage_daily_return")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2015-01-07   1.00         0.37    0.00                 0.00
# 2013-01-12   0.00         0.71    1.00                 0.00
# 2016-08-20   1.00         0.49    0.00                 0.05
# 2019-01-27   0.00         0.52    1.00                 0.32
# 2017-02-09   0.00         0.69    1.00                 0.15
# ...           ...          ...     ...                  ...
# 2017-09-16   1.00         0.41    0.00               470.09
# 2014-01-08   0.00         0.67    1.00               127.79
# 2011-08-10   1.00         0.28    0.00                 1.92
# 2011-08-08   1.00         0.20    0.00                 1.66
# 2013-04-13   1.00         0.31    0.00                27.11
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2015-01-07                     0.00                  276.80
# 2013-01-12                     0.00                   13.89
# 2016-08-20                     0.00                  580.68
# 2019-01-27                     0.00                 3586.69
# 2017-02-09                     0.00                  988.41
# ...                             ...                     ...
# 2017-09-16                     0.13                 3711.87
# 2014-01-08                     0.16                  822.86
# 2011-08-10                     0.19                   10.01
# 2011-08-08                     0.21                    7.83
# 2013-04-13                     0.29                   92.81
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2015-01-07                   0.63   627.88                      0.63
# 2013-01-12                   0.71   706.24                      0.71
# 2016-08-20                   0.51   511.91                      0.51
# 2019-01-27                   0.52   518.35                      0.52
# 2017-02-09                   0.69   688.11                      0.69
# ...                           ...      ...                       ...
# 2017-09-16                   0.59   593.37                      0.59
# 2014-01-08                   0.67   669.49                      0.67
# 2011-08-10                   0.72   721.31                      0.72
# 2011-08-08                   0.80   796.13                      0.80
# 2013-04-13                   0.69   688.58                      0.69
#
# [400 rows x 9 columns]

# %%
dfrights.sort_values("percentage_daily_return")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2011-10-18   0.00         0.36    0.00                -1.02
# 2015-01-15   0.00         0.43    0.00               -54.02
# 2013-04-16   0.00         0.23    0.00               -17.11
# 2013-05-02   0.00         0.36    0.00               -22.83
# 2018-01-17   0.00         0.18    0.00             -2107.42
# ...           ...          ...     ...                  ...
# 2019-04-03   1.00         0.69    1.00               729.28
# 2013-04-19   1.00         0.65    1.00                19.17
# 2013-04-18   1.00         0.54    1.00                21.91
# 2012-01-06   1.00         0.67    1.00                 1.40
# 2017-07-21   1.00         0.64    1.00               574.01
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2011-10-18                    -0.42                    2.41
# 2015-01-15                    -0.26                  210.22
# 2013-04-16                    -0.25                   67.98
# 2013-05-02                    -0.21                  106.44
# 2018-01-17                    -0.19                11136.81
# ...                             ...                     ...
# 2019-04-03                     0.15                 4971.31
# 2013-04-19                     0.16                  117.87
# 2013-04-18                     0.20                  109.05
# 2012-01-06                     0.21                    6.70
# 2017-07-21                     0.22                 2667.80
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2011-10-18                   0.64   640.85                      0.64
# 2015-01-15                   0.57   571.84                      0.57
# 2013-04-16                   0.77   766.53                      0.77
# 2013-05-02                   0.64   640.54                      0.64
# 2018-01-17                   0.82   824.98                      0.82
# ...                           ...      ...                       ...
# 2019-04-03                   0.69   689.60                      0.69
# 2013-04-19                   0.65   653.75                      0.65
# 2013-04-18                   0.54   536.24                      0.54
# 2012-01-06                   0.67   674.53                      0.67
# 2017-07-21                   0.64   642.95                      0.64
#
# [603 rows x 9 columns]

# %%
dfwrongs["year"] = dfwrongs.index.year
dfwrongs.groupby(['year']).agg(['sum', 'count'])
# Out:
# <ipython-input-179-6a845089450b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfwrongs["year"] = dfwrongs.index.year
#      Class       y_pred_prob       y_pred       Daily Return in USD        \
#        sum count         sum count    sum count                 sum count
# year
# 2011 15.00    22        9.78    22   7.00    22                4.55    22
# 2012  9.00    36       20.35    36  27.00    36               -2.05    36
# 2013 11.00    41       24.66    41  30.00    41                9.08    41
# 2014 27.00    43       20.06    43  16.00    43               31.09    43
# 2015 15.00    44       22.87    44  29.00    44               -0.87    44
# 2016 12.00    33       17.99    33  21.00    33              -54.18    33
# 2017  5.00    42       25.71    42  37.00    42            -1377.38    42
# 2018 33.00    58       29.35    58  25.00    58             -444.72    58
# 2019 19.00    48       25.28    48  29.00    48            -2047.28    48
# 2020 19.00    33       15.63    33  14.00    33             1738.57    33
#
#      percentage_daily_return       market/price_usd_close        \
#                          sum count                    sum count
# year
# 2011                    0.51    22                 120.20    22
# 2012                   -0.22    36                 312.56    36
# 2013                    0.08    41                5200.01    41
# 2014                    0.29    43               22217.73    43
# 2015                   -0.02    44               12033.52    44
# 2016                   -0.02    33               19614.54    33
# 2017                   -0.72    42              124405.51    42
# 2018                   -0.08    58              445794.98    58
# 2019                   -0.21    48              358083.25    48
# 2020                    0.25    33              306143.56    33
#
#      y_pred_prob_bereinigt        Einsatz       Transaction Costs in USD
#                        sum count      sum count                      sum count
# year
# 2011                 15.16    22 15161.94    22                    15.16    22
# 2012                 21.05    36 21052.58    36                    21.05    36
# 2013                 26.04    41 26035.11    41                    26.04    41
# 2014                 25.10    43 25097.08    43                    25.10    43
# 2015                 24.43    44 24433.18    44                    24.43    44
# 2016                 19.17    33 19173.15    33                    19.17    33
# 2017                 26.15    42 26151.72    42                    26.15    42
# 2018                 33.62    58 33623.38    58                    33.62    58
# 2019                 28.37    48 28365.34    48                    28.37    48
# 2020                 18.98    33 18983.80    33                    18.98    33

# %%
dfrights["year"] = dfrights.index.year
dfrights.abs().groupby(['year']).agg(['sum', 'count'])
# Out:
# <ipython-input-180-90c79a75818e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfrights["year"] = dfrights.index.year
#         Class       y_pred_prob       y_pred       Daily Return in USD        \
#           sum count         sum count    sum count                 sum count
# year
# 2011.00  7.00    27       11.48    27   7.00    27                7.92    27
# 2012.00 41.00    56       32.80    56  41.00    56               13.90    56
# 2013.00 65.00    75       48.65    75  65.00    75              850.69    75
# 2014.00 20.00    59       26.08    59  20.00    59              840.14    59
# 2015.00 37.00    65       33.33    65  37.00    65              486.45    65
# 2016.00 58.00    72       41.22    72  58.00    72              745.13    72
# 2017.00 52.00    61       39.42    61  52.00    61            11471.95    61
# 2018.00 28.00    67       32.67    67  28.00    67            21608.52    67
# 2019.00 44.00    70       37.43    70  44.00    70            15756.46    70
# 2020.00 25.00    51       24.11    51  25.00    51            11286.36    51
#
#         percentage_daily_return       market/price_usd_close        \
#                             sum count                    sum count
# year
# 2011.00                    1.56    27                 159.13    27
# 2012.00                    1.83    56                 461.14    56
# 2013.00                    3.35    75               14291.39    75
# 2014.00                    1.70    59               30190.84    59
# 2015.00                    1.83    65               17403.89    65
# 2016.00                    1.23    72               41874.15    72
# 2017.00                    2.35    61              249792.26    61
# 2018.00                    2.57    67              516066.41    67
# 2019.00                    1.96    70              511725.37    70
# 2020.00                    1.28    51              465941.55    51
#
#         y_pred_prob_bereinigt        Einsatz       Transaction Costs in USD  \
#                           sum count      sum count                      sum
# year
# 2011.00                 18.62    27 18624.54    27                    18.62
# 2012.00                 34.75    56 34753.53    56                    34.75
# 2013.00                 51.39    75 51390.66    75                    51.39
# 2014.00                 36.15    59 36147.18    59                    36.15
# 2015.00                 36.99    65 36986.79    65                    36.99
# 2016.00                 42.78    72 42782.21    72                    42.78
# 2017.00                 40.38    61 40379.15    61                    40.38
# 2018.00                 40.89    67 40891.80    67                    40.89
# 2019.00                 42.41    70 42407.98    70                    42.41
# 2020.00                 30.29    51 30288.74    51                    30.29
#
#
#         count
# year
# 2011.00    27
# 2012.00    56
# 2013.00    75
# 2014.00    59
# 2015.00    65
# 2016.00    72
# 2017.00    61
# 2018.00    67
# 2019.00    70
# 2020.00    51

# %%
predictors
# Out:
# array([[2.5777836e+00, 1.7005341e+00, 1.3167919e+01, ..., 3.8240000e+03,
#         5.9900000e+02, 6.2000000e+01],
#        [2.5969751e+00, 2.2271056e+00, 1.3423072e+01, ..., 3.7460000e+03,
#         6.0000000e+02, 6.3000000e+01],
#        [2.6277070e+00, 2.8262084e+00, 1.3841993e+01, ..., 3.7610000e+03,
#         5.9700000e+02, 6.3000000e+01],
#        ...,
#        [9.2466307e+00, 5.4810090e+00, 1.0369563e+04, ..., 1.6011000e+04,
#         2.1930000e+03, 1.0600000e+02],
#        [9.2234058e+00, 2.4996128e+00, 1.0131517e+04, ..., 1.5990000e+04,
#         2.1870000e+03, 1.0500000e+02],
#        [9.2342863e+00, 2.1275063e+00, 1.0242348e+04, ..., 1.5986000e+04,
#         2.1900000e+03, 1.0400000e+02]], dtype=float32)

# %% [markdown]
# # Bet on tomorrow

# %%
# Split Data into Training and Testing
#X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, stratify=target)

# Amount of Columns
n_nodes = predictors.shape[1]
print("Amount of Columns", n_nodes)

# Instantiation of MinMaxScaler
norm_scaler = MinMaxScaler()

# Training and Application of Feature Scaler on Training Data of Predictors
predictors_scaled = pd.DataFrame(norm_scaler.fit_transform(predictors))

# Instantiate Classifier Logistic Regression
lreg = LogisticRegression(max_iter=12000) 

# Train Classifier
lreg.fit(predictors_scaled, target)
# Out:
# Amount of Columns 101
# LogisticRegression(max_iter=12000)

# %% [markdown]
# # get x train data of today to predict tomorrow y

# %%
most_current_day = df_dataset1.tail(1)
dateofprediction = most_current_day.index
most_current_day
# Out:
#             Log Price in USD  Volatility Daily Log Return in Percent 5D  \
# Date
# 2020-09-09              9.23                                       2.13
#
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2020-09-09                10242.35                           -0.48
#
#             market/price_realized_usd  market/mvrv   mining/difficulty_latest  \
# Date
# 2020-09-09                    6204.76         1.64 74500493292953204162560.00
#
#               mining/hash_rate_mean  mining/revenue_sum  \
# Date
# 2020-09-09 129306481305694994432.00             1020.45
#
#             mining/marketcap_thermocap_ratio  ...  \
# Date                                          ...
# 2020-09-09                              0.00  ...
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-09-09                     484473.00               31096380.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-09-09                        8517532.00                   3134510.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-09-09              823685.00               153145.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-09-09                 15986.00                 2190.00
#
#             addresses/min_10k_count  Class
# Date
# 2020-09-09                   104.00   0.00
#
# [1 rows x 102 columns]

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
most_current_day_predictors = most_current_day.drop(['Class'], axis=1).values.astype(np.float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
most_current_day_predictors_scaled = norm_scaler.transform(most_current_day_predictors)
most_current_day_predictors_scaled
# Out:
# array([[9.2925102e-01, 4.7359414e-02, 5.2284926e-01, 4.8378259e-01,
#         9.9759924e-01, 2.3297258e-01, 9.8792607e-01, 8.6002201e-01,
#         3.3302397e-02, 9.0501510e-02, 3.8333336e-01, 3.0591422e-01,
#         6.9369072e-01, 9.7535133e-01, 9.5044041e-01, 2.4729036e-04,
#         5.8308784e-02, 5.6612408e-03, 2.8340805e-03, 4.4308823e-01,
#         7.1739489e-01, 4.4658344e-02, 4.4729818e-02, 8.3283299e-01,
#         8.7317157e-01, 2.6284692e-01, 9.9999994e-01, 6.7888510e-01,
#         7.8782308e-01, 3.5423589e-01, 9.9879634e-01, 9.1954195e-01,
#         8.3614153e-01, 1.0000000e+00, 2.1247765e-01, 2.3860338e-01,
#         2.6479068e-01, 2.9900962e-01, 3.2730445e-01, 3.0754250e-01,
#         7.1254051e-01, 7.8642637e-01, 5.0567991e-01, 5.1915318e-01,
#         5.5093378e-01, 9.9999994e-01, 3.4306571e-02, 1.0057885e-02,
#         6.3836521e-01, 6.9369125e-01, 4.4728581e-02, 5.1655932e-03,
#         2.3319772e-02, 2.7005995e-02, 1.7273173e-01, 3.4791684e-01,
#         8.8621527e-01, 4.9018401e-01, 3.9507246e-01, 4.8411456e-01,
#         3.3072222e-03, 1.7695205e-02, 2.3622643e-02, 6.2470302e-02,
#         9.3128264e-01, 6.9409862e-02, 5.1482964e-01, 8.0728835e-01,
#         3.6359897e-01, 2.4049915e-01, 1.0185501e-01, 1.1545752e-01,
#         3.8474102e-02, 1.9510597e-02, 1.6909204e-02, 2.8860226e-02,
#         7.8753076e-02, 4.1360293e-02, 8.1433463e-01, 2.3874193e-01,
#         1.6970700e-02, 2.4924992e-01, 1.5025669e-02, 5.8085505e-02,
#         8.1650525e-01, 8.5345930e-01, 4.4726416e-02, 1.8635424e-02,
#         3.7535898e-02, 7.4984819e-01, 7.1883929e-01, 6.3257241e-01,
#         6.0335279e-01, 9.9399823e-01, 9.8949420e-01, 9.9844170e-01,
#         9.9999988e-01, 9.5550573e-01, 8.2719481e-01, 9.8821342e-01,
#         6.5625000e-01]], dtype=float32)

# %%
# Prediction of Classes
most_current_day_pred = lreg.predict(most_current_day_predictors_scaled)
most_current_day_pred
# Out:
# array([0.], dtype=float32)

# %%
# Prediction of Probabilities
most_current_day_pred_prob = lreg.predict_proba(most_current_day_predictors_scaled)[:,1]
most_current_day_pred_prob[0]
# Out:
# 0.40553025184461616

# %%
dateofprediction[0]
# Out:
# Timestamp('2020-09-09 00:00:00')

# %%
predicted_df = pd.DataFrame([[dateofprediction[0],most_current_day_pred_prob[0],most_current_day_pred[0]]], index=dateofprediction, columns=["dateofprediction","most_current_day_pred_prob","most_current_day_pred"])
predicted_df
# Out:
#            dateofprediction  most_current_day_pred_prob  most_current_day_pred
# Date
# 2020-09-09       2020-09-09                        0.41                   0.00

# %% [markdown]
# # Store DF of the one prediction in database

# %%
from datetime import datetime
from sqlalchemy import create_engine

engine = create_engine("mysql://root:root@127.0.0.1/btc_predictions")

predicted_df.to_sql(name="btc_preds", 
                con=engine, index=False,
                if_exists='append', 
                )
