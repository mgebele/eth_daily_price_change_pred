# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Data-Import-via-Application-Programming-Interfaces" data-toc-modified-id="Data-Import-via-Application-Programming-Interfaces-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data Import via Application Programming Interfaces</a></span><ul class="toc-item"><li><span><a href="#Blockchain-Data-from-Glassnode" data-toc-modified-id="Blockchain-Data-from-Glassnode-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Blockchain Data from Glassnode</a></span><ul class="toc-item"><li><span><a href="#Market-Metrics-from-Glassnode" data-toc-modified-id="Market-Metrics-from-Glassnode-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Market Metrics from Glassnode</a></span></li><li><span><a href="#Mining-Metrics-from-Glassnode" data-toc-modified-id="Mining-Metrics-from-Glassnode-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Mining Metrics from Glassnode</a></span></li><li><span><a href="#Blocks-Metrics-from-Glassnode" data-toc-modified-id="Blocks-Metrics-from-Glassnode-1.1.1.3"><span class="toc-item-num">1.1.1.3&nbsp;&nbsp;</span>Blocks Metrics from Glassnode</a></span></li><li><span><a href="#Distribution-Metrics-from-Glassnode" data-toc-modified-id="Distribution-Metrics-from-Glassnode-1.1.1.4"><span class="toc-item-num">1.1.1.4&nbsp;&nbsp;</span>Distribution Metrics from Glassnode</a></span></li><li><span><a href="#Fee-Metrics-from-Glassnode" data-toc-modified-id="Fee-Metrics-from-Glassnode-1.1.1.5"><span class="toc-item-num">1.1.1.5&nbsp;&nbsp;</span>Fee Metrics from Glassnode</a></span></li><li><span><a href="#UTXO-Metrics-from-Glassnode" data-toc-modified-id="UTXO-Metrics-from-Glassnode-1.1.1.6"><span class="toc-item-num">1.1.1.6&nbsp;&nbsp;</span>UTXO Metrics from Glassnode</a></span></li><li><span><a href="#Supply-Metrics-from-Glassnode" data-toc-modified-id="Supply-Metrics-from-Glassnode-1.1.1.7"><span class="toc-item-num">1.1.1.7&nbsp;&nbsp;</span>Supply Metrics from Glassnode</a></span></li><li><span><a href="#Transaction-Metrics-from-Glassnode" data-toc-modified-id="Transaction-Metrics-from-Glassnode-1.1.1.8"><span class="toc-item-num">1.1.1.8&nbsp;&nbsp;</span>Transaction Metrics from Glassnode</a></span></li><li><span><a href="#Exchange-Metrics-from-Glassnode---1-Month-Lag" data-toc-modified-id="Exchange-Metrics-from-Glassnode---1-Month-Lag-1.1.1.9"><span class="toc-item-num">1.1.1.9&nbsp;&nbsp;</span>Exchange Metrics from Glassnode - 1 Month Lag</a></span></li><li><span><a href="#Indicator-I-Metrics-from-Glassnode" data-toc-modified-id="Indicator-I-Metrics-from-Glassnode-1.1.1.10"><span class="toc-item-num">1.1.1.10&nbsp;&nbsp;</span>Indicator-I Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-2-Metrics-from-Glassnode" data-toc-modified-id="Indicator-2-Metrics-from-Glassnode-1.1.1.11"><span class="toc-item-num">1.1.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics from Glassnode</a></span></li><li><span><a href="#Indicator-3-Metrics-from-Glassnode" data-toc-modified-id="Indicator-3-Metrics-from-Glassnode-1.1.1.12"><span class="toc-item-num">1.1.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics from Glassnode</a></span></li><li><span><a href="#Addresses-Metrics-from-Glassnode" data-toc-modified-id="Addresses-Metrics-from-Glassnode-1.1.1.13"><span class="toc-item-num">1.1.1.13&nbsp;&nbsp;</span>Addresses Metrics from Glassnode</a></span></li><li><span><a href="#Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-from-Glassnode---Excluded-as-Data-Available-Only-Since-Feb-2020-1.1.1.14"><span class="toc-item-num">1.1.1.14&nbsp;&nbsp;</span>Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Futures-Features" data-toc-modified-id="List-of-Futures-Features-1.1.1.14.1"><span class="toc-item-num">1.1.1.14.1&nbsp;&nbsp;</span>List of Futures Features</a></span></li><li><span><a href="#Data-Frame-of-Future-features" data-toc-modified-id="Data-Frame-of-Future-features-1.1.1.14.2"><span class="toc-item-num">1.1.1.14.2&nbsp;&nbsp;</span>Data Frame of Future features</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#File-Import-and-Data-Tidying" data-toc-modified-id="File-Import-and-Data-Tidying-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>File Import and Data Tidying</a></span><ul class="toc-item"><li><span><a href="#Import-Blockchain-CSV-Files" data-toc-modified-id="Import-Blockchain-CSV-Files-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Import Blockchain CSV-Files</a></span><ul class="toc-item"><li><span><a href="#Market-Metric-CSV-Files" data-toc-modified-id="Market-Metric-CSV-Files-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>Market Metric CSV-Files</a></span></li><li><span><a href="#Mining-Metric-CSV-Files" data-toc-modified-id="Mining-Metric-CSV-Files-1.2.1.2"><span class="toc-item-num">1.2.1.2&nbsp;&nbsp;</span>Mining Metric CSV-Files</a></span></li><li><span><a href="#Blocks-Metric-CSV-Files" data-toc-modified-id="Blocks-Metric-CSV-Files-1.2.1.3"><span class="toc-item-num">1.2.1.3&nbsp;&nbsp;</span>Blocks Metric CSV-Files</a></span></li><li><span><a href="#Distribution-Metric-CSV-Files" data-toc-modified-id="Distribution-Metric-CSV-Files-1.2.1.4"><span class="toc-item-num">1.2.1.4&nbsp;&nbsp;</span>Distribution Metric CSV-Files</a></span></li><li><span><a href="#Fee-Metric-CSV-Files" data-toc-modified-id="Fee-Metric-CSV-Files-1.2.1.5"><span class="toc-item-num">1.2.1.5&nbsp;&nbsp;</span>Fee Metric CSV-Files</a></span></li><li><span><a href="#UTXO-Metric-CSV-Files" data-toc-modified-id="UTXO-Metric-CSV-Files-1.2.1.6"><span class="toc-item-num">1.2.1.6&nbsp;&nbsp;</span>UTXO Metric CSV-Files</a></span></li><li><span><a href="#Supply-Metric-CSV-Files" data-toc-modified-id="Supply-Metric-CSV-Files-1.2.1.7"><span class="toc-item-num">1.2.1.7&nbsp;&nbsp;</span>Supply Metric CSV-Files</a></span></li><li><span><a href="#Transaction-Metric-CSV-Files" data-toc-modified-id="Transaction-Metric-CSV-Files-1.2.1.8"><span class="toc-item-num">1.2.1.8&nbsp;&nbsp;</span>Transaction Metric CSV-Files</a></span></li><li><span><a href="#Exchange-Metrics-CSV-Files" data-toc-modified-id="Exchange-Metrics-CSV-Files-1.2.1.9"><span class="toc-item-num">1.2.1.9&nbsp;&nbsp;</span>Exchange Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-1-Metric-CSV-Files" data-toc-modified-id="Indicator-1-Metric-CSV-Files-1.2.1.10"><span class="toc-item-num">1.2.1.10&nbsp;&nbsp;</span>Indicator-1 Metric CSV-Files</a></span></li><li><span><a href="#Indicator-2-Metrics-CSV-Files" data-toc-modified-id="Indicator-2-Metrics-CSV-Files-1.2.1.11"><span class="toc-item-num">1.2.1.11&nbsp;&nbsp;</span>Indicator-2 Metrics CSV-Files</a></span></li><li><span><a href="#Indicator-3-Metrics-CSV-Files" data-toc-modified-id="Indicator-3-Metrics-CSV-Files-1.2.1.12"><span class="toc-item-num">1.2.1.12&nbsp;&nbsp;</span>Indicator-3 Metrics CSV-Files</a></span></li><li><span><a href="#Addresses-Metric-CSV-Files" data-toc-modified-id="Addresses-Metric-CSV-Files-1.2.1.13"><span class="toc-item-num">1.2.1.13&nbsp;&nbsp;</span>Addresses Metric CSV-Files</a></span></li><li><span><a href="#Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020" data-toc-modified-id="Futures-Metrics-CSV-Files---Excluded-as-Data-Available-Only-Since-Feb-2020-1.2.1.14"><span class="toc-item-num">1.2.1.14&nbsp;&nbsp;</span>Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020</a></span><ul class="toc-item"><li><span><a href="#List-of-Future-Features" data-toc-modified-id="List-of-Future-Features-1.2.1.14.1"><span class="toc-item-num">1.2.1.14.1&nbsp;&nbsp;</span>List of Future Features</a></span></li><li><span><a href="#Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension" data-toc-modified-id="Counter-to-Differentiate-between-Data-Frame-Setup-and-Data-Frame-Extension-1.2.1.14.2"><span class="toc-item-num">1.2.1.14.2&nbsp;&nbsp;</span>Counter to Differentiate between Data Frame Setup and Data Frame Extension</a></span></li><li><span><a href="#For-Loop-through-all-Features-in-the-List" data-toc-modified-id="For-Loop-through-all-Features-in-the-List-1.2.1.14.3"><span class="toc-item-num">1.2.1.14.3&nbsp;&nbsp;</span>For Loop through all Features in the List</a></span></li><li><span><a href="#Store-Data-Frame-Copy-in-Market-Data-Frame" data-toc-modified-id="Store-Data-Frame-Copy-in-Market-Data-Frame-1.2.1.14.4"><span class="toc-item-num">1.2.1.14.4&nbsp;&nbsp;</span>Store Data Frame Copy in Market Data Frame</a></span></li><li><span><a href="#Delete-Original-Data-Frame" data-toc-modified-id="Delete-Original-Data-Frame-1.2.1.14.5"><span class="toc-item-num">1.2.1.14.5&nbsp;&nbsp;</span>Delete Original Data Frame</a></span></li><li><span><a href="#Change-Data-Type-of-Columns-to-Float" data-toc-modified-id="Change-Data-Type-of-Columns-to-Float-1.2.1.14.6"><span class="toc-item-num">1.2.1.14.6&nbsp;&nbsp;</span>Change Data Type of Columns to Float</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Target-Variables" data-toc-modified-id="Target-Variables-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Target Variables</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Volatility" data-toc-modified-id="Volatility-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Volatility</a></span></li><li><span><a href="#Log-Price" data-toc-modified-id="Log-Price-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Log Price</a></span></li></ul></li></ul></li><li><span><a href="#Data-Sets" data-toc-modified-id="Data-Sets-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I.---Blockchain-Metrics-Only" data-toc-modified-id="Data-Set-I.---Blockchain-Metrics-Only-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data Set I. - Blockchain Metrics Only</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-Variations" data-toc-modified-id="Classification-Models---Data-Set-Variations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Classification Models - Data Set Variations</a></span></li><li><span><a href="#Import-Data-Sets" data-toc-modified-id="Import-Data-Sets-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import Data Sets</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Data Set I.</a></span></li><li><span><a href="#Prediction-Shift" data-toc-modified-id="Prediction-Shift-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Prediction Shift</a></span><ul class="toc-item"><li><span><a href="#Data-Set-I." data-toc-modified-id="Data-Set-I.-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Data Set I.</a></span></li></ul></li></ul></li><li><span><a href="#Classification-Setup" data-toc-modified-id="Classification-Setup-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Classification Setup</a></span><ul class="toc-item"><li><span><a href="#Create-Data-Set-Copies-for-Trading-Strategy" data-toc-modified-id="Create-Data-Set-Copies-for-Trading-Strategy-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Create Data Set Copies for Trading Strategy</a></span></li><li><span><a href="#Categorization---Data-Set-I." data-toc-modified-id="Categorization---Data-Set-I.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Categorization - Data Set I.</a></span></li></ul></li><li><span><a href="#Model-Preparation---Data-Set-I." data-toc-modified-id="Model-Preparation---Data-Set-I.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model Preparation - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split---Data-Set-I." data-toc-modified-id="Train-Test-Split---Data-Set-I.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Train Test Split - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Check-of-Class-Balance" data-toc-modified-id="Check-of-Class-Balance-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Check of Class Balance</a></span></li></ul></li><li><span><a href="#Feature-Scaling---Data-Set-I." data-toc-modified-id="Feature-Scaling---Data-Set-I.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Feature Scaling - Data Set I.</a></span></li></ul></li><li><span><a href="#Classification-Models---Data-Set-I." data-toc-modified-id="Classification-Models---Data-Set-I.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Classification Models - Data Set I.</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression---Data-Set-I." data-toc-modified-id="Logistic-Regression---Data-Set-I.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Logistic Regression - Data Set I.</a></span></li><li><span><a href="#Random-Forest-Classifier---Data-Set-I." data-toc-modified-id="Random-Forest-Classifier---Data-Set-I.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Random Forest Classifier - Data Set I.</a></span></li></ul></li><li><span><a href="#Trading-Strategy---Data-Set-I" data-toc-modified-id="Trading-Strategy---Data-Set-I-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Trading Strategy - Data Set I</a></span><ul class="toc-item"><li><span><a href="#Trading-Strategy-in-Combination-with-Logistic-Regression" data-toc-modified-id="Trading-Strategy-in-Combination-with-Logistic-Regression-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Trading Strategy in Combination with Logistic Regression</a></span></li></ul></li><li><span><a href="#Bet-on-tomorrow" data-toc-modified-id="Bet-on-tomorrow-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Bet on tomorrow</a></span></li><li><span><a href="#get-x-train-data-of-today-to-predict-tomorrow-y" data-toc-modified-id="get-x-train-data-of-today-to-predict-tomorrow-y-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>get x train data of today to predict tomorrow y</a></span></li><li><span><a href="#Store-DF-of-the-one-prediction-in-database" data-toc-modified-id="Store-DF-of-the-one-prediction-in-database-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Store DF of the one prediction in database</a></span></li></ul></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Import via Application Programming Interfaces

# %%
# Import of Modules and Packages
import os
import requests
import json
import datetime
import yfinance as yf
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pytrends.request import TrendReq
from pytrends import dailydata

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %%
# Glassnode API Key
API_Key =''

# %%
os.getcwd()
# Out:
# 'C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010'

# %%
os.chdir('C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010\\Glassnode')

# %% [markdown]
# ### Blockchain Data from Glassnode

# %%
# Import Function for a Single Feature Variable from Glassnode
def import_glassnode (url, feature_name):
    data = requests.get(url).json()
    df = pd.json_normalize(data)
    
    # Rename columns
    df.columns = ['Date', feature_name]
   
    # Convert Object to Datetime Object
    df.Date = pd.to_datetime(df.Date, unit='s')
    df.Date = df.Date.map(lambda x: x.strftime('%Y-%m-%d'))
    
    # Set Date Column as Index
    df.set_index('Date', inplace=True)
    
    # Drop Missing Values
    df = df.dropna()
    
    # Change Data Type to Float
    df = df.astype(float)
    
    # Creation of CSV-File, Part of Feature Name as CSV File Name 
    df.to_csv("{}.csv".format(feature_name.rsplit('/')[-1]), decimal=',')
    
    # Plot of DataFrame
    #df.plot(figsize=(4.5, 1.75))
    #plt.xticks(rotation=45)
    return df

# %%
# Import Function for Several Feature Variables from Glassnode
def import_glassnode_many(feature_list):
    # Counter to Differentiate between Data Frame Setup and Data Frame Join
    counter=0
    
    # For Loop through all Features in the List
    for feature in feature_list:
        
        # URL
        url = 'https://api.glassnode.com/v1/metrics/{}?a=btc&f=json&api_key={}'.format(feature, API_Key)
        
        # Execute Import Function for a Single Feature Variable
        df=import_glassnode(url, feature)
        
        # Display Data Frame Tail
        print(df.tail())
        
        # Condition - Data Frame Set up or Data Frame Join
        if counter > 0:
            
            # Data Frame Join
            df_new = df_new.join(df, how='inner')   
        
        else:
            
            # Data Frame Setup
            df_new = df
        
        # Increase Counter
        counter +=1
    
    return df_new

# %% [markdown]
# #### Market Metrics from Glassnode

# %%
# List of Market Features
market_feature_list = ['market/price_usd_close', 'market/price_drawdown_relative', 'market/price_realized_usd', 'market/mvrv']

# %%
# Data Frame of Market Features
df_market = import_glassnode_many(market_feature_list)
# Out:
#             market/price_usd_close
# Date
# 2020-11-16                16709.61
# 2020-11-17                17667.38
# 2020-11-18                17812.23
# 2020-11-19                17797.55
# 2020-11-20                18251.84
#             market/price_drawdown_relative
# Date
# 2020-11-15                           -0.19
# 2020-11-16                           -0.16
# 2020-11-17                           -0.11
# 2020-11-18                           -0.10
# 2020-11-19                           -0.10
#             market/price_realized_usd
# Date
# 2020-11-15                    6910.67
# 2020-11-16                    6926.41
# 2020-11-17                    6962.39
# 2020-11-18                    7037.45
# 2020-11-19                    7059.76
#             market/mvrv
# Date
# 2020-11-15         2.31
# 2020-11-16         2.36
# 2020-11-17         2.45
# 2020-11-18         2.54
# 2020-11-19         2.52

# %% [markdown]
# #### Mining Metrics from Glassnode

# %%
# List of Mining Features
mining_feature_list = ['mining/difficulty_latest', 'mining/hash_rate_mean', 'mining/revenue_sum', 'mining/marketcap_thermocap_ratio']

# %%
# Data Frame of Mining Features
df_mining = import_glassnode_many(mining_feature_list)
# Out:
#              mining/difficulty_latest
# Date
# 2020-11-15 72102964397116403744768.00
# 2020-11-16 75577685065077505392640.00
# 2020-11-17 75577685065077505392640.00
# 2020-11-18 75577685065077505392640.00
# 2020-11-19 75577685065077505392640.00
#               mining/hash_rate_mean
# Date
# 2020-11-15 124875241422092992512.00
# 2020-11-16 136158304329831006208.00
# 2020-11-17 136840305323567005696.00
# 2020-11-18 146411297553796005888.00
# 2020-11-19 119777232389561008128.00
#             mining/revenue_sum
# Date
# 2020-11-15              979.93
# 2020-11-16             1083.46
# 2020-11-17             1071.79
# 2020-11-18             1153.89
# 2020-11-19              944.13
#             mining/marketcap_thermocap_ratio
# Date
# 2020-11-15                              0.00
# 2020-11-16                              0.00
# 2020-11-17                              0.00
# 2020-11-18                              0.00
# 2020-11-19                              0.00

# %% [markdown]
# #### Blocks Metrics from Glassnode

# %%
# List of Blockchain Features
blockchain_feature_list = ['blockchain/block_count', 'blockchain/block_interval_mean', 'blockchain/block_size_sum']

# %%
# Data Frame of Blockchain Features
df_blockchainfeatures = import_glassnode_many(blockchain_feature_list)
# Out:
#             blockchain/block_count
# Date
# 2020-11-15                  150.00
# 2020-11-16                  160.00
# 2020-11-17                  157.00
# 2020-11-18                  169.00
# 2020-11-19                  137.00
#             blockchain/block_interval_mean
# Date
# 2020-11-15                          577.40
# 2020-11-16                          536.43
# 2020-11-17                          552.31
# 2020-11-18                          516.20
# 2020-11-19                          630.99
#             blockchain/block_size_sum
# Date
# 2020-11-15               180783978.00
# 2020-11-16               193429011.00
# 2020-11-17               201346288.00
# 2020-11-18               213284264.00
# 2020-11-19               182218606.00

# %% [markdown]
# #### Distribution Metrics from Glassnode

# %%
# List of Distribution Features
distribution_feature_list = ['distribution/balance_1pct_holders', 'distribution/gini', 'distribution/herfindahl']

# %%
# Data Frame of Distribution Features
df_distribution = import_glassnode_many(distribution_feature_list)
# Out:
#             distribution/balance_1pct_holders
# Date
# 2020-11-15                               0.89
# 2020-11-16                               0.89
# 2020-11-17                               0.89
# 2020-11-18                               0.89
# 2020-11-19                               0.89
#             distribution/gini
# Date
# 2020-11-15               0.99
# 2020-11-16               0.99
# 2020-11-17               0.99
# 2020-11-18               0.99
# 2020-11-19               0.99
#             distribution/herfindahl
# Date
# 2020-11-15                     0.00
# 2020-11-16                     0.00
# 2020-11-17                     0.00
# 2020-11-18                     0.00
# 2020-11-19                     0.00

# %% [markdown]
# #### Fee Metrics from Glassnode

# %%
# List of Fee Features
fees_feature_list = ['fees/volume_sum', 'fees/volume_mean', 'fees/fee_ratio_multiple']

# %%
# Data Frame of Fee Features
df_fees = import_glassnode_many(fees_feature_list)
# Out:
#             fees/volume_sum
# Date
# 2020-11-15            42.43
# 2020-11-16            83.46
# 2020-11-17            90.54
# 2020-11-18            97.64
# 2020-11-19            94.52
#             fees/volume_mean
# Date
# 2020-11-15              0.00
# 2020-11-16              0.00
# 2020-11-17              0.00
# 2020-11-18              0.00
# 2020-11-19              0.00
#             fees/fee_ratio_multiple
# Date
# 2020-11-15                    23.09
# 2020-11-16                    12.98
# 2020-11-17                    11.84
# 2020-11-18                    11.82
# 2020-11-19                    10.06

# %% [markdown]
# #### UTXO Metrics from Glassnode

# %%
# List of UTXO Features
utxo_feature_list = ['blockchain/utxo_created_count', 'blockchain/utxo_spent_count', 'blockchain/utxo_created_value_sum', 'blockchain/utxo_spent_value_sum', 'blockchain/utxo_profit_relative', 'blockchain/utxo_profit_count', 'blockchain/utxo_loss_count']

# %%
# Data Frame of UTXO Features
df_utxo = import_glassnode_many(utxo_feature_list)
# Out:
#             blockchain/utxo_created_count
# Date
# 2020-11-15                      720717.00
# 2020-11-16                      869288.00
# 2020-11-17                      974192.00
# 2020-11-18                     1017548.00
# 2020-11-19                      900212.00
#             blockchain/utxo_spent_count
# Date
# 2020-11-15                    856807.00
# 2020-11-16                    919942.00
# 2020-11-17                    952316.00
# 2020-11-18                   1015256.00
# 2020-11-19                    854196.00
#             blockchain/utxo_created_value_sum
# Date
# 2020-11-15                         1598945.68
# 2020-11-16                         3618303.62
# 2020-11-17                         3030811.52
# 2020-11-18                         2930159.47
# 2020-11-19                         2378459.75
#             blockchain/utxo_spent_value_sum
# Date
# 2020-11-15                       1598008.18
# 2020-11-16                       3617303.62
# 2020-11-17                       3029830.27
# 2020-11-18                       2929103.22
# 2020-11-19                       2377603.50
#             blockchain/utxo_profit_relative
# Date
# 2020-11-15                             0.99
# 2020-11-16                             0.99
# 2020-11-17                             1.00
# 2020-11-18                             1.00
# 2020-11-19                             0.99
#             blockchain/utxo_profit_count
# Date
# 2020-11-15                  113245855.00
# 2020-11-16                  114208074.00
# 2020-11-17                  114563460.00
# 2020-11-18                  114328125.00
# 2020-11-19                  114089648.00
#             blockchain/utxo_loss_count
# Date
# 2020-11-15                  1631223.00
# 2020-11-16                   618350.00
# 2020-11-17                   284840.00
# 2020-11-18                   511448.00
# 2020-11-19                   802121.00

# %% [markdown]
# #### Supply Metrics from Glassnode

# %%
# List of Supply Features
supply_feature_list = ['supply/current','supply/profit_relative', 'supply/profit_sum', 'supply/loss_sum', 'supply/active_more_1y_percent', 'supply/active_more_2y_percent', 'supply/active_more_3y_percent', 'supply/active_more_5y_percent', 'supply/active_24h', 'supply/active_1d_1w', 'supply/active_1w_1m', 'supply/active_1m_3m', 'supply/active_3m_6m', 'supply/active_6m_12m', 'supply/active_1y_2y', 'supply/active_2y_3y', 'supply/active_3y_5y', 'supply/active_5y_7y', 'supply/active_7y_10y', 'supply/active_more_10y', 'supply/issued', 'supply/inflation_rate']

# %%
# Data Frame of Supply Features
df_supply = import_glassnode_many(supply_feature_list)
# Out:
#             supply/current
# Date
# 2020-11-15     18544412.50
# 2020-11-16     18545412.50
# 2020-11-17     18546393.75
# 2020-11-18     18547450.00
# 2020-11-19     18548306.25
#             supply/profit_relative
# Date
# 2020-11-15                    0.97
# 2020-11-16                    0.99
# 2020-11-17                    0.99
# 2020-11-18                    0.99
# 2020-11-19                    0.98
#             supply/profit_sum
# Date
# 2020-11-15        17945673.96
# 2020-11-16        18346861.57
# 2020-11-17        18411620.91
# 2020-11-18        18316325.54
# 2020-11-19        18224074.15
#             supply/loss_sum
# Date
# 2020-11-15        585768.13
# 2020-11-16        185580.53
# 2020-11-17        121802.43
# 2020-11-18        197306.40
# 2020-11-19        291114.05
#             supply/active_more_1y_percent
# Date
# 2020-11-15                           0.62
# 2020-11-16                           0.62
# 2020-11-17                           0.62
# 2020-11-18                           0.61
# 2020-11-19                           0.61
#             supply/active_more_2y_percent
# Date
# 2020-11-15                           0.44
# 2020-11-16                           0.44
# 2020-11-17                           0.44
# 2020-11-18                           0.44
# 2020-11-19                           0.44
#             supply/active_more_3y_percent
# Date
# 2020-11-15                           0.32
# 2020-11-16                           0.32
# 2020-11-17                           0.32
# 2020-11-18                           0.32
# 2020-11-19                           0.32
#             supply/active_more_5y_percent
# Date
# 2020-11-15                           0.22
# 2020-11-16                           0.22
# 2020-11-17                           0.22
# 2020-11-18                           0.22
# 2020-11-19                           0.22
#             supply/active_24h
# Date
# 2020-11-15          139075.56
# 2020-11-16          227828.59
# 2020-11-17          313405.86
# 2020-11-18          394194.82
# 2020-11-19          227999.22
#             supply/active_1d_1w
# Date
# 2020-11-15            593580.45
# 2020-11-16            492479.14
# 2020-11-17            492280.72
# 2020-11-18            549168.94
# 2020-11-19            692139.82
#             supply/active_1w_1m
# Date
# 2020-11-15           1725468.65
# 2020-11-16           1755278.02
# 2020-11-17           1709309.33
# 2020-11-18           1619539.85
# 2020-11-19           1649246.12
#             supply/active_1m_3m
# Date
# 2020-11-15           1273759.50
# 2020-11-16           1249076.01
# 2020-11-17           1227603.01
# 2020-11-18           1212140.82
# 2020-11-19           1211312.94
#             supply/active_3m_6m
# Date
# 2020-11-15           1366710.58
# 2020-11-16           1380162.58
# 2020-11-17           1382657.88
# 2020-11-18           1377854.54
# 2020-11-19           1386108.79
#             supply/active_6m_12m
# Date
# 2020-11-15            2013697.32
# 2020-11-16            2014860.74
# 2020-11-17            2003131.79
# 2020-11-18            1990316.15
# 2020-11-19            1983957.25
#             supply/active_1y_2y
# Date
# 2020-11-15           3265603.11
# 2020-11-16           3263008.47
# 2020-11-17           3266448.44
# 2020-11-18           3262643.36
# 2020-11-19           3257923.74
#             supply/active_2y_3y
# Date
# 2020-11-15           2172900.50
# 2020-11-16           2163209.23
# 2020-11-17           2147485.02
# 2020-11-18           2137064.62
# 2020-11-19           2129561.72
#             supply/active_3y_5y
# Date
# 2020-11-15           1928168.41
# 2020-11-16           1934808.60
# 2020-11-17           1938911.19
# 2020-11-18           1940395.31
# 2020-11-19           1948148.73
#             supply/active_5y_7y
# Date
# 2020-11-15            911328.97
# 2020-11-16            909509.51
# 2020-11-17            905284.01
# 2020-11-18            899361.19
# 2020-11-19            894063.24
#             supply/active_7y_10y
# Date
# 2020-11-15            1325715.61
# 2020-11-16            1326036.83
# 2020-11-17            1330216.46
# 2020-11-18            1334656.14
# 2020-11-19            1337175.83
#             supply/active_more_10y
# Date
# 2020-11-15              1828374.88
# 2020-11-16              1829125.84
# 2020-11-17              1829631.10
# 2020-11-18              1830085.31
# 2020-11-19              1830639.90
#             supply/issued
# Date
# 2020-11-15         937.50
# 2020-11-16        1000.00
# 2020-11-17         981.25
# 2020-11-18        1056.25
# 2020-11-19         856.25
#             supply/inflation_rate
# Date
# 2020-11-15                   0.02
# 2020-11-16                   0.02
# 2020-11-17                   0.02
# 2020-11-18                   0.02
# 2020-11-19                   0.02

# %% [markdown]
# #### Transaction Metrics from Glassnode

# %%
# List of Transaction Features
transaction_feature_list = ['transactions/count', 'transactions/size_sum','transactions/transfers_volume_sum', 'transactions/transfers_volume_adjusted_sum']

# %%
# Data Frame of Transaction Features
df_transaction = import_glassnode_many(transaction_feature_list)
# Out:
#             transactions/count
# Date
# 2020-11-15           252565.00
# 2020-11-16           311317.00
# 2020-11-17           347615.00
# 2020-11-18           361838.00
# 2020-11-19           310924.00
#             transactions/size_sum
# Date
# 2020-11-15           180725345.00
# 2020-11-16           193367265.00
# 2020-11-17           201284684.00
# 2020-11-18           213218316.00
# 2020-11-19           182164679.00
#             transactions/transfers_volume_sum
# Date
# 2020-11-15                         1597965.75
# 2020-11-16                         3617220.16
# 2020-11-17                         3029739.73
# 2020-11-18                         2929005.58
# 2020-11-19                         2377508.98
#             transactions/transfers_volume_adjusted_sum
# Date
# 2020-11-15                                   339972.31
# 2020-11-16                                   500350.56
# 2020-11-17                                   606039.94
# 2020-11-18                                   720480.43
# 2020-11-19                                   511400.15

# %% [markdown]
# #### Exchange Metrics from Glassnode - 1 Month Lag

# %%
# List of Exchange Features
exchange_feature_list = ['transactions/transfers_volume_to_exchanges_sum', 'transactions/transfers_volume_from_exchanges_sum', 'transactions/transfers_to_exchanges_count', 'transactions/transfers_from_exchanges_count', 'distribution/balance_exchanges', 'transactions/transfers_volume_exchanges_net']

# %%
# Data Frame of Exchange Features
df_exchange = import_glassnode_many(exchange_feature_list)
# Out:
#             transactions/transfers_volume_to_exchanges_sum
# Date
# 2020-11-15                                        14819.35
# 2020-11-16                                        44358.89
# 2020-11-17                                        62861.92
# 2020-11-18                                        62859.97
# 2020-11-19                                        37289.40
#             transactions/transfers_volume_from_exchanges_sum
# Date
# 2020-11-15                                          26917.24
# 2020-11-16                                          57895.80
# 2020-11-17                                          58174.99
# 2020-11-18                                          63359.33
# 2020-11-19                                          42568.07
#             transactions/transfers_to_exchanges_count
# Date
# 2020-11-15                                   33987.00
# 2020-11-16                                   46521.00
# 2020-11-17                                   55273.00
# 2020-11-18                                   58305.00
# 2020-11-19                                   44027.00
#             transactions/transfers_from_exchanges_count
# Date
# 2020-11-15                                     27317.00
# 2020-11-16                                     38593.00
# 2020-11-17                                     45555.00
# 2020-11-18                                     51254.00
# 2020-11-19                                     40509.00
#             distribution/balance_exchanges
# Date
# 2020-11-15                      2388668.25
# 2020-11-16                      2375124.32
# 2020-11-17                      2379803.19
# 2020-11-18                      2379294.22
# 2020-11-19                      2374006.81
#             transactions/transfers_volume_exchanges_net
# Date
# 2020-11-15                                    -12097.90
# 2020-11-16                                    -13536.90
# 2020-11-17                                      4686.93
# 2020-11-18                                      -499.37
# 2020-11-19                                     -5278.67

# %% [markdown]
# #### Indicator-I Metrics from Glassnode

# %%
# List of Indicator-1 Features
indicator1_feature_list = ['indicators/sopr_adjusted', 'indicators/nvt', 'indicators/velocity', 'indicators/cdd', 'indicators/reserve_risk', 'indicators/average_dormancy', 'indicators/liveliness']

# %%
# Data Frame of Indicator-1 Features
df_indicator1 = import_glassnode_many(indicator1_feature_list)
# Out:
#             indicators/sopr_adjusted
# Date
# 2020-11-15                      1.03
# 2020-11-16                      1.06
# 2020-11-17                      1.09
# 2020-11-18                      1.14
# 2020-11-19                      1.06
#             indicators/nvt
# Date
# 2020-11-15           54.55
# 2020-11-16           37.06
# 2020-11-17           30.60
# 2020-11-18           25.74
# 2020-11-19           36.27
#             indicators/velocity
# Date
# 2020-11-15                 0.02
# 2020-11-16                 0.03
# 2020-11-17                 0.03
# 2020-11-18                 0.04
# 2020-11-19                 0.03
#             indicators/cdd
# Date
# 2020-11-15      6737980.38
# 2020-11-16     11738676.20
# 2020-11-17     19199910.20
# 2020-11-18     26137906.24
# 2020-11-19     13848626.22
#             indicators/reserve_risk
# Date
# 2020-11-15                     0.00
# 2020-11-16                     0.00
# 2020-11-17                     0.00
# 2020-11-18                     0.00
# 2020-11-19                     0.00
#             indicators/average_dormancy
# Date
# 2020-11-15                        19.82
# 2020-11-16                        23.46
# 2020-11-17                        31.68
# 2020-11-18                        36.28
# 2020-11-19                        27.08
#             indicators/liveliness
# Date
# 2020-11-15                   0.60
# 2020-11-16                   0.60
# 2020-11-17                   0.60
# 2020-11-18                   0.60
# 2020-11-19                   0.60

# %% [markdown]
# #### Indicator-2 Metrics from Glassnode

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['indicators/asol', 'indicators/sol_1h', 'indicators/sol_1h_24h', 'indicators/sol_1d_1w', 'indicators/sol_1w_1m', 'indicators/sol_1m_3m', 'indicators/sol_3m_6m', 'indicators/sol_6m_12m', 'indicators/sol_1y_2y', 'indicators/sol_2y_3y', 'indicators/sol_3y_5y', 'indicators/sol_5y_7y', 'indicators/sol_7y_10y']

# %%
# Data Frame of Indicator-2 Features
df_indicator2 = import_glassnode_many(indicator2_feature_list)
# Out:
#             indicators/asol
# Date
# 2020-11-15            63.95
# 2020-11-16            40.54
# 2020-11-17            50.81
# 2020-11-18            65.74
# 2020-11-19            44.55
#             indicators/sol_1h
# Date
# 2020-11-15          163126.00
# 2020-11-16          192036.00
# 2020-11-17          201319.00
# 2020-11-18          213162.00
# 2020-11-19          182160.00
#             indicators/sol_1h_24h
# Date
# 2020-11-15              241036.00
# 2020-11-16              267226.00
# 2020-11-17              352909.00
# 2020-11-18              381374.00
# 2020-11-19              313044.00
#             indicators/sol_1d_1w
# Date
# 2020-11-15             178305.00
# 2020-11-16             214443.00
# 2020-11-17             173725.00
# 2020-11-18             170940.00
# 2020-11-19             176222.00
#             indicators/sol_1w_1m
# Date
# 2020-11-15              72499.00
# 2020-11-16             113569.00
# 2020-11-17             102277.00
# 2020-11-18             108110.00
# 2020-11-19              91418.00
#             indicators/sol_1m_3m
# Date
# 2020-11-15              67035.00
# 2020-11-16              71610.00
# 2020-11-17              52328.00
# 2020-11-18              46348.00
# 2020-11-19              39797.00
#             indicators/sol_3m_6m
# Date
# 2020-11-15              39096.00
# 2020-11-16              28353.00
# 2020-11-17              21482.00
# 2020-11-18              24868.00
# 2020-11-19              14084.00
#             indicators/sol_6m_12m
# Date
# 2020-11-15               74430.00
# 2020-11-16               12903.00
# 2020-11-17               17076.00
# 2020-11-18               22454.00
# 2020-11-19               12644.00
#             indicators/sol_1y_2y
# Date
# 2020-11-15              13304.00
# 2020-11-16              10135.00
# 2020-11-17              14237.00
# 2020-11-18              23293.00
# 2020-11-19              11008.00
#             indicators/sol_2y_3y
# Date
# 2020-11-15               5138.00
# 2020-11-16               6554.00
# 2020-11-17              12030.00
# 2020-11-18              18314.00
# 2020-11-19               9915.00
#             indicators/sol_3y_5y
# Date
# 2020-11-15               2037.00
# 2020-11-16               2391.00
# 2020-11-17               3818.00
# 2020-11-18               5096.00
# 2020-11-19               3094.00
#             indicators/sol_5y_7y
# Date
# 2020-11-15                766.00
# 2020-11-16                600.00
# 2020-11-17               1034.00
# 2020-11-18               1009.00
# 2020-11-19                705.00
#             indicators/sol_7y_10y
# Date
# 2020-11-15                  35.00
# 2020-11-16                 122.00
# 2020-11-17                  81.00
# 2020-11-18                 288.00
# 2020-11-19                 104.00

# %% [markdown]
# #### Indicator-3 Metrics from Glassnode

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['indicators/net_unrealized_profit_loss', 'indicators/unrealized_profit', 'indicators/unrealized_loss', 'indicators/net_realized_profit_loss', 'indicators/realized_profit', 'indicators/realized_loss', 'indicators/nupl_more_155', 'indicators/nupl_less_155', 'indicators/puell_multiple', 'indicators/stock_to_flow_deflection', 'indicators/difficulty_ribbon_compression']

# %%
# Data Frame of Indicator-3 Features
df_indicator3 = import_glassnode_many(indicator3_feature_list)
# Out:
#             indicators/net_unrealized_profit_loss
# Date
# 2020-11-15                                   0.57
# 2020-11-16                                   0.58
# 2020-11-17                                   0.60
# 2020-11-18                                   0.60
# 2020-11-19                                   0.60
#             indicators/unrealized_profit
# Date
# 2020-11-15                          0.57
# 2020-11-16                          0.58
# 2020-11-17                          0.60
# 2020-11-18                          0.60
# 2020-11-19                          0.60
#             indicators/unrealized_loss
# Date
# 2020-11-15                        0.00
# 2020-11-16                        0.00
# 2020-11-17                        0.00
# 2020-11-18                        0.00
# 2020-11-19                        0.00
#             indicators/net_realized_profit_loss
# Date
# 2020-11-15                         137336945.28
# 2020-11-16                         372514844.96
# 2020-11-17                         807779063.20
# 2020-11-18                        1334539073.51
# 2020-11-19                         415593482.70
#             indicators/realized_profit
# Date
# 2020-11-15                168119815.55
# 2020-11-16                390235235.90
# 2020-11-17                838096570.16
# 2020-11-18               1421394923.04
# 2020-11-19                469638576.26
#             indicators/realized_loss
# Date
# 2020-11-15               30782870.28
# 2020-11-16               17720390.93
# 2020-11-17               30317506.96
# 2020-11-18               86855849.53
# 2020-11-19               54045093.57
#             indicators/nupl_more_155
# Date
# 2020-11-15                      0.65
# 2020-11-16                      0.66
# 2020-11-17                      0.68
# 2020-11-18                      0.69
# 2020-11-19                      0.69
#             indicators/nupl_less_155
# Date
# 2020-11-15                      0.22
# 2020-11-16                      0.25
# 2020-11-17                      0.28
# 2020-11-18                      0.27
# 2020-11-19                      0.26
#             indicators/puell_multiple
# Date
# 2020-11-15                       1.24
# 2020-11-16                       1.35
# 2020-11-17                       1.39
# 2020-11-18                       1.56
# 2020-11-19                       1.26
#             indicators/stock_to_flow_deflection
# Date
# 2020-11-15                                 0.62
# 2020-11-16                                 0.64
# 2020-11-17                                 0.67
# 2020-11-18                                 0.68
# 2020-11-19                                 0.67
#             indicators/difficulty_ribbon_compression
# Date
# 2020-11-15                                      0.04
# 2020-11-16                                      0.04
# 2020-11-17                                      0.04
# 2020-11-18                                      0.04
# 2020-11-19                                      0.04

# %% [markdown]
# #### Addresses Metrics from Glassnode

# %%
# List of Addresses Features
addresses_feature_list = ['addresses/active_count', 'addresses/sending_count', 'addresses/receiving_count', 'addresses/new_non_zero_count', 'addresses/non_zero_count', 'addresses/min_point_zero_1_count','addresses/min_point_1_count', 'addresses/min_1_count', 'addresses/min_10_count', 'addresses/min_100_count', 'addresses/min_1k_count', 'addresses/min_10k_count']

# %%
# Data Frame of Addresses Features
df_addresses = import_glassnode_many(addresses_feature_list)
# Out:
#             addresses/active_count
# Date
# 2020-11-15               859865.00
# 2020-11-16              1036960.00
# 2020-11-17              1134731.00
# 2020-11-18              1187942.00
# 2020-11-19              1058686.00
#             addresses/sending_count
# Date
# 2020-11-15                559028.00
# 2020-11-16                663147.00
# 2020-11-17                706546.00
# 2020-11-18                750796.00
# 2020-11-19                660869.00
#             addresses/receiving_count
# Date
# 2020-11-15                  555358.00
# 2020-11-16                  681255.00
# 2020-11-17                  770674.00
# 2020-11-18                  807692.00
# 2020-11-19                  717366.00
#             addresses/new_non_zero_count
# Date
# 2020-11-15                     407914.00
# 2020-11-16                     493329.00
# 2020-11-17                     558880.00
# 2020-11-18                     581082.00
# 2020-11-19                     517332.00
#             addresses/non_zero_count
# Date
# 2020-11-15               32479715.00
# 2020-11-16               32473955.00
# 2020-11-17               32506599.00
# 2020-11-18               32525162.00
# 2020-11-19               32544167.00
#             addresses/min_point_zero_1_count
# Date
# 2020-11-15                        8571801.00
# 2020-11-16                        8564964.00
# 2020-11-17                        8553575.00
# 2020-11-18                        8532965.00
# 2020-11-19                        8542553.00
#             addresses/min_point_1_count
# Date
# 2020-11-15                   3126946.00
# 2020-11-16                   3124999.00
# 2020-11-17                   3127510.00
# 2020-11-18                   3123601.00
# 2020-11-19                   3125440.00
#             addresses/min_1_count
# Date
# 2020-11-15              818993.00
# 2020-11-16              818622.00
# 2020-11-17              819167.00
# 2020-11-18              818953.00
# 2020-11-19              819280.00
#             addresses/min_10_count
# Date
# 2020-11-15               154497.00
# 2020-11-16               154343.00
# 2020-11-17               154240.00
# 2020-11-18               154259.00
# 2020-11-19               154441.00
#             addresses/min_100_count
# Date
# 2020-11-15                 16241.00
# 2020-11-16                 16276.00
# 2020-11-17                 16238.00
# 2020-11-18                 16242.00
# 2020-11-19                 16199.00
#             addresses/min_1k_count
# Date
# 2020-11-15                 2237.00
# 2020-11-16                 2237.00
# 2020-11-17                 2232.00
# 2020-11-18                 2228.00
# 2020-11-19                 2229.00
#             addresses/min_10k_count
# Date
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
# 2020-11-19                   112.00

# %% [markdown]
# #### Futures Metrics from Glassnode - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Futures Features
# futures_feature_list = ['derivatives/futures_volume_daily_all_sum', 'derivatives/futures_volume_daily_perpetual_sum', 'derivatives/futures_open_interest_all_sum', 'derivatives/futures_open_interest_perpetual_sum', 'derivatives/futures_funding_rate_perpetual']

# %% [markdown]
# ##### Data Frame of Future features
# df_futures = import_glassnode_many(futures_feature_list)

# %% [markdown]
# ## File Import and Data Tidying

# %%
# Import of Modules and Packages
import os
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.6f}'.format

# %%
os.chdir('C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010')

# %% [markdown]
# ### Import Blockchain CSV-Files

# %% [markdown]
# #### Market Metric CSV-Files

# %%
# List of Market Features
market_feature_list = ['price_usd_close', 'price_drawdown_relative', 'price_realized_usd', 'mvrv']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in market_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_market = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_market.columns:
    try:
        df_market["{}".format(y)] = df_market["{}".format(y)].str.replace(',','.')
        df_market["{}".format(y)] = df_market["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Market Metric Values
df_market.tail()
# Out:
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2020-11-15            15962.098952                       -0.194319
# 2020-11-16            16709.612284                       -0.156588
# 2020-11-17            17667.381593                       -0.108245
# 2020-11-18            17812.233237                       -0.100934
# 2020-11-19            17797.552692                       -0.101675
#
#             market/price_realized_usd  market/mvrv
# Date
# 2020-11-15                6910.668850     2.311843
# 2020-11-16                6926.408944     2.359903
# 2020-11-17                6962.388651     2.448941
# 2020-11-18                7037.449307     2.537373
# 2020-11-19                7059.762417     2.523737

# %% [markdown]
# #### Mining Metric CSV-Files

# %%
# List of Mining Features
mining_feature_list = ['difficulty_latest', 'hash_rate_mean', 'revenue_sum','marketcap_thermocap_ratio']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in mining_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame    
df_mining = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_mining.columns:
    try:
        df_mining["{}".format(y)] = df_mining["{}".format(y)].str.replace(',','.')
        df_mining["{}".format(y)] = df_mining["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Mining Metric Values
df_mining.tail()
# Out:
#                  mining/difficulty_latest        mining/hash_rate_mean  \
# Date
# 2020-11-15 72102964397116403744768.000000 124875241422092992512.000000
# 2020-11-16 75577685065077505392640.000000 136158304329831006208.000000
# 2020-11-17 75577685065077505392640.000000 136840305323567005696.000000
# 2020-11-18 75577685065077505392640.000000 146411297553796005888.000000
# 2020-11-19 75577685065077505392640.000000 119777232389561008128.000000
#
#             mining/revenue_sum  mining/marketcap_thermocap_ratio
# Date
# 2020-11-15          979.933355                          0.000001
# 2020-11-16         1083.457706                          0.000001
# 2020-11-17         1071.791296                          0.000001
# 2020-11-18         1153.888686                          0.000001
# 2020-11-19          944.126362                          0.000001

# %% [markdown]
# #### Blocks Metric CSV-Files

# %%
# List of Blockchain Features
block_feature_list = ['block_count', 'block_interval_mean', 'block_size_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in block_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Market Data Frame
df_blockfeatures = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_blockfeatures.columns:
    try:
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].str.replace(',','.')
        df_blockfeatures["{}".format(y)] = df_blockfeatures["{}".format(y)].astype(float)
    except:
        pass

# %%
# Show Latest Feature Values
df_blockfeatures.tail()
# Out:
#             blockchain/block_count  blockchain/block_interval_mean  \
# Date
# 2020-11-15              150.000000                      577.400000
# 2020-11-16              160.000000                      536.431250
# 2020-11-17              157.000000                      552.305732
# 2020-11-18              169.000000                      516.201183
# 2020-11-19              137.000000                      630.985401
#
#             blockchain/block_size_sum
# Date
# 2020-11-15           180783978.000000
# 2020-11-16           193429011.000000
# 2020-11-17           201346288.000000
# 2020-11-18           213284264.000000
# 2020-11-19           182218606.000000

# %% [markdown]
# #### Distribution Metric CSV-Files

# %%
# List of Distribution Features
distribution_feature_list = ['balance_1pct_holders', 'gini', 'herfindahl']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in distribution_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        # Data Frame Setup
        df_new = df
    
    # Increase Counter    
    counter +=1

# Store Data Frame Copy in Distribution Data Frame    
df_distribution = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_distribution.columns:
    try:
        df_distribution["{}".format(y)] = df_distribution["{}".format(y)].str.replace(',','.')
        df_distribution["{}".format(y)] = df_distribution["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Distribution Metric Values
df_distribution.tail()
# Out:
#             distribution/balance_1pct_holders  distribution/gini  \
# Date
# 2020-11-15                           0.893230           0.987461
# 2020-11-16                           0.893373           0.987469
# 2020-11-17                           0.893490           0.987465
# 2020-11-18                           0.893707           0.987466
# 2020-11-19                           0.893856           0.987453
#
#             distribution/herfindahl
# Date
# 2020-11-15                 0.000257
# 2020-11-16                 0.000257
# 2020-11-17                 0.000257
# 2020-11-18                 0.000259
# 2020-11-19                 0.000260

# %% [markdown]
# #### Fee Metric CSV-Files

# %%
# List of Fee Features
fees_feature_list = ['volume_sum', 'volume_mean', 'fee_ratio_multiple']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in fees_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date') #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
        
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Fees Data Frame    
df_fees = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_fees.columns:
    try:
        df_fees["{}".format(y)] = df_fees["{}".format(y)].str.replace(',','.')
        df_fees["{}".format(y)] = df_fees["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Fee Metric Values
df_fees.tail()
# Out:
#             fees/volume_sum  fees/volume_mean  fees/fee_ratio_multiple
# Date
# 2020-11-15        42.433355          0.000168                23.093469
# 2020-11-16        83.457706          0.000268                12.982117
# 2020-11-17        90.541296          0.000260                11.837596
# 2020-11-18        97.638686          0.000270                11.817946
# 2020-11-19        94.518720          0.000304                10.059052

# %% [markdown]
# #### UTXO Metric CSV-Files

# %%
# List of UTXO Features
utxo_feature_list = ['utxo_created_count', 'utxo_spent_count','utxo_created_value_sum', 'utxo_spent_value_sum', 'utxo_profit_relative', 'utxo_profit_count', 'utxo_loss_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in utxo_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df

    # Increase Counter
    counter +=1

# Store Data Frame Copy in UTXO Data Frame
df_utxo = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_utxo.columns:
    try:
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].str.replace(',','.')
        df_utxo["{}".format(y)] = df_utxo["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest UTXO Metric Values
df_utxo.tail()
# Out:
#             blockchain/utxo_created_count  blockchain/utxo_spent_count  \
# Date
# 2020-11-15                  720717.000000                856807.000000
# 2020-11-16                  869288.000000                919942.000000
# 2020-11-17                  974192.000000                952316.000000
# 2020-11-18                 1017548.000000               1015256.000000
# 2020-11-19                  900212.000000                854196.000000
#
#             blockchain/utxo_created_value_sum  \
# Date
# 2020-11-15                     1598945.684913
# 2020-11-16                     3618303.617861
# 2020-11-17                     3030811.519460
# 2020-11-18                     2930159.471229
# 2020-11-19                     2378459.751287
#
#             blockchain/utxo_spent_value_sum  blockchain/utxo_profit_relative  \
# Date
# 2020-11-15                   1598008.184913                         0.985800
# 2020-11-16                   3617303.617861                         0.994615
# 2020-11-17                   3029830.269460                         0.997520
# 2020-11-18                   2929103.221229                         0.995451
# 2020-11-19                   2377603.501287                         0.992977
#
#             blockchain/utxo_profit_count  blockchain/utxo_loss_count
# Date
# 2020-11-15              113245855.000000              1631223.000000
# 2020-11-16              114208074.000000               618350.000000
# 2020-11-17              114563460.000000               284840.000000
# 2020-11-18              114328125.000000               511448.000000
# 2020-11-19              114089648.000000               802121.000000

# %% [markdown]
# #### Supply Metric CSV-Files

# %%
# List of Supply Features
supply_feature_list = ['current','profit_relative', 'profit_sum', 'loss_sum', 'active_more_1y_percent', 'active_more_2y_percent', 'active_more_3y_percent', 'active_more_5y_percent', 'active_24h', 'active_1d_1w', 'active_1w_1m', 'active_1m_3m', 'active_3m_6m', 'active_6m_12m', 'active_1y_2y', 'active_2y_3y', 'active_3y_5y', 'active_5y_7y', 'active_7y_10y', 'active_more_10y', 'issued', 'inflation_rate']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in supply_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Supply Data Frame    
df_supply = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_supply.columns:
    try:
        df_supply["{}".format(y)] = df_supply["{}".format(y)].str.replace(',','.')
        df_supply["{}".format(y)] = df_supply["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Supply Metric Values
df_supply.tail()
# Out:
#             supply/current  supply/profit_relative  supply/profit_sum  \
# Date
# 2020-11-15 18544412.500000                0.968391    17945673.963364
# 2020-11-16 18545412.500000                0.989986    18346861.568218
# 2020-11-17 18546393.750000                0.993428    18411620.914683
# 2020-11-18 18547450.000000                0.988230    18316325.540314
# 2020-11-19 18548306.250000                0.983207    18224074.148339
#
#             supply/loss_sum  supply/active_more_1y_percent  \
# Date
# 2020-11-15    585768.132134                       0.616471
# 2020-11-16    185580.527281                       0.616093
# 2020-11-17    121802.430816                       0.615644
# 2020-11-18    197306.397519                       0.614867
# 2020-11-19    291114.045093                       0.614477
#
#             supply/active_more_2y_percent  supply/active_more_3y_percent  \
# Date
# 2020-11-15                       0.440375                       0.323202
# 2020-11-16                       0.440146                       0.323502
# 2020-11-17                       0.439521                       0.323731
# 2020-11-18                       0.438959                       0.323737
# 2020-11-19                       0.438832                       0.324020
#
#             supply/active_more_5y_percent  supply/active_24h  \
# Date
# 2020-11-15                       0.219226      139075.561298
# 2020-11-16                       0.219174      227828.587066
# 2020-11-17                       0.219187      313405.857466
# 2020-11-18                       0.219119      394194.817699
# 2020-11-19                       0.218989      227999.215351
#
#             supply/active_1d_1w  ...  supply/active_3m_6m  \
# Date                             ...
# 2020-11-15        593580.449497  ...       1366710.575710
# 2020-11-16        492479.137858  ...       1380162.578385
# 2020-11-17        492280.719246  ...       1382657.878780
# 2020-11-18        549168.936573  ...       1377854.544249
# 2020-11-19        692139.823347  ...       1386108.785409
#
#             supply/active_6m_12m  supply/active_1y_2y  supply/active_2y_3y  \
# Date
# 2020-11-15        2013697.316634       3265603.113156       2172900.504835
# 2020-11-16        2014860.736466       3263008.474305       2163209.234417
# 2020-11-17        2003131.791775       3266448.437168       2147485.015524
# 2020-11-18        1990316.146085       3262643.362735       2137064.624152
# 2020-11-19        1983957.248577       3257923.741956       2129561.721358
#
#             supply/active_3y_5y  supply/active_5y_7y  supply/active_7y_10y  \
# Date
# 2020-11-15       1928168.414221        911328.968932        1325715.614833
# 2020-11-16       1934808.597038        909509.505109        1326036.831733
# 2020-11-17       1938911.185932        905284.005404        1330216.463808
# 2020-11-18       1940395.309883        899361.187043        1334656.136976
# 2020-11-19       1948148.729363        894063.239987        1337175.833245
#
#             supply/active_more_10y  supply/issued  supply/inflation_rate
# Date
# 2020-11-15          1828374.878235     937.500000               0.018623
# 2020-11-16          1829125.838235    1000.000000               0.019876
# 2020-11-17          1829631.098235     981.250000               0.019499
# 2020-11-18          1830085.308235    1056.250000               0.021003
# 2020-11-19          1830639.898235     856.250000               0.016992
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Transaction Metric CSV-Files

# %%
# List of Transaction features
transaction_feature_list = ['count', 'size_sum','transfers_volume_sum', 'transfers_volume_adjusted_sum']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in transaction_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Transaction Data Frame
df_transaction = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_transaction.columns:
    try:
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].str.replace(',','.')
        df_transaction["{}".format(y)] = df_transaction["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Transaction Metric Values
df_transaction.tail()
# Out:
#             transactions/count  transactions/size_sum  \
# Date
# 2020-11-15       252565.000000       180725345.000000
# 2020-11-16       311317.000000       193367265.000000
# 2020-11-17       347615.000000       201284684.000000
# 2020-11-18       361838.000000       213218316.000000
# 2020-11-19       310924.000000       182164679.000000
#
#             transactions/transfers_volume_sum  \
# Date
# 2020-11-15                     1597965.751559
# 2020-11-16                     3617220.160155
# 2020-11-17                     3029739.728163
# 2020-11-18                     2929005.582543
# 2020-11-19                     2377508.982567
#
#             transactions/transfers_volume_adjusted_sum
# Date
# 2020-11-15                               339972.305718
# 2020-11-16                               500350.562608
# 2020-11-17                               606039.940181
# 2020-11-18                               720480.434819
# 2020-11-19                               511400.151687

# %% [markdown]
# #### Exchange Metrics CSV-Files

# %%
# List of Exchange Features
exchange_feature_list = ['transfers_volume_to_exchanges_sum', 'transfers_volume_from_exchanges_sum', 'transfers_to_exchanges_count', 
                         'transfers_from_exchanges_count', 'balance_exchanges', 'transfers_volume_exchanges_net']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in exchange_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Exchange Data Frame    
df_exchange = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_exchange.columns:
    try:
        df_exchange["{}".format(y)] = df_exchange["{}".format(y)].str.replace(',','.')
        df_exchange["{}".format(y)] = df_exchange["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Exchange Metric Values
df_exchange.tail()
# Out:
#             transactions/transfers_volume_to_exchanges_sum  \
# Date
# 2020-11-15                                    14819.345601
# 2020-11-16                                    44358.893768
# 2020-11-17                                    62861.921379
# 2020-11-18                                    62859.965772
# 2020-11-19                                    37289.397508
#
#             transactions/transfers_volume_from_exchanges_sum  \
# Date
# 2020-11-15                                      26917.243131
# 2020-11-16                                      57895.796605
# 2020-11-17                                      58174.993411
# 2020-11-18                                      63359.331057
# 2020-11-19                                      42568.071558
#
#             transactions/transfers_to_exchanges_count  \
# Date
# 2020-11-15                               33987.000000
# 2020-11-16                               46521.000000
# 2020-11-17                               55273.000000
# 2020-11-18                               58305.000000
# 2020-11-19                               44027.000000
#
#             transactions/transfers_from_exchanges_count  \
# Date
# 2020-11-15                                 27317.000000
# 2020-11-16                                 38593.000000
# 2020-11-17                                 45555.000000
# 2020-11-18                                 51254.000000
# 2020-11-19                                 40509.000000
#
#             distribution/balance_exchanges  \
# Date
# 2020-11-15                  2388668.252110
# 2020-11-16                  2375124.320623
# 2020-11-17                  2379803.193088
# 2020-11-18                  2379294.219876
# 2020-11-19                  2374006.808050
#
#             transactions/transfers_volume_exchanges_net
# Date
# 2020-11-15                                -12097.897530
# 2020-11-16                                -13536.902838
# 2020-11-17                                  4686.927968
# 2020-11-18                                  -499.365285
# 2020-11-19                                 -5278.674049

# %% [markdown]
# #### Indicator-1 Metric CSV-Files

# %%
# List of Indicator-1 features
indicator1_feature_list = ['sopr_adjusted', 'nvt', 'velocity', 'cdd','reserve_risk', 'average_dormancy', 'liveliness'] 

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator1_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date', ) #decimal="."
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-1 Data Frame    
df_indicator1 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator1.columns:
    try:
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].str.replace(',','.')
        df_indicator1["{}".format(y)] = df_indicator1["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-1 Metric Values
df_indicator1.tail()
# Out:
#             indicators/sopr_adjusted  indicators/nvt  indicators/velocity  \
# Date
# 2020-11-15                  1.030034       54.546833             0.018333
# 2020-11-16                  1.058912       37.064838             0.026980
# 2020-11-17                  1.091134       30.602593             0.032677
# 2020-11-18                  1.135606       25.743170             0.038845
# 2020-11-19                  1.063966       36.269653             0.027571
#
#             indicators/cdd  indicators/reserve_risk  \
# Date
# 2020-11-15  6737980.384089                 0.002615
# 2020-11-16 11738676.198240                 0.002673
# 2020-11-17 19199910.199331                 0.002785
# 2020-11-18 26137906.239649                 0.002913
# 2020-11-19 13848626.224980                 0.002902
#
#             indicators/average_dormancy  indicators/liveliness
# Date
# 2020-11-15                    19.819204               0.601624
# 2020-11-16                    23.460903               0.601580
# 2020-11-17                    31.680932               0.601637
# 2020-11-18                    36.278440               0.601956
# 2020-11-19                    27.079824               0.602099

# %% [markdown]
# #### Indicator-2 Metrics CSV-Files

# %%
# List of Indicator-2 Features
indicator2_feature_list = ['asol', 'sol_1h', 'sol_1h_24h', 'sol_1d_1w','sol_1w_1m', 'sol_1m_3m', 'sol_3m_6m', 'sol_6m_12m','sol_1y_2y', 'sol_2y_3y', 'sol_3y_5y', 'sol_5y_7y', 'sol_7y_10y']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator2_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-2 Data Frame
df_indicator2 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator2.columns:
    try:
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].str.replace(',','.')
        df_indicator2["{}".format(y)] = df_indicator2["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-2 Metric Values
df_indicator2.tail()
# Out:
#             indicators/asol  indicators/sol_1h  indicators/sol_1h_24h  \
# Date
# 2020-11-15        63.952704      163126.000000          241036.000000
# 2020-11-16        40.539993      192036.000000          267226.000000
# 2020-11-17        50.813525      201319.000000          352909.000000
# 2020-11-18        65.742210      213162.000000          381374.000000
# 2020-11-19        44.553064      182160.000000          313044.000000
#
#             indicators/sol_1d_1w  indicators/sol_1w_1m  indicators/sol_1m_3m  \
# Date
# 2020-11-15         178305.000000          72499.000000          67035.000000
# 2020-11-16         214443.000000         113569.000000          71610.000000
# 2020-11-17         173725.000000         102277.000000          52328.000000
# 2020-11-18         170940.000000         108110.000000          46348.000000
# 2020-11-19         176222.000000          91418.000000          39797.000000
#
#             indicators/sol_3m_6m  indicators/sol_6m_12m  indicators/sol_1y_2y  \
# Date
# 2020-11-15          39096.000000           74430.000000          13304.000000
# 2020-11-16          28353.000000           12903.000000          10135.000000
# 2020-11-17          21482.000000           17076.000000          14237.000000
# 2020-11-18          24868.000000           22454.000000          23293.000000
# 2020-11-19          14084.000000           12644.000000          11008.000000
#
#             indicators/sol_2y_3y  indicators/sol_3y_5y  indicators/sol_5y_7y  \
# Date
# 2020-11-15           5138.000000           2037.000000            766.000000
# 2020-11-16           6554.000000           2391.000000            600.000000
# 2020-11-17          12030.000000           3818.000000           1034.000000
# 2020-11-18          18314.000000           5096.000000           1009.000000
# 2020-11-19           9915.000000           3094.000000            705.000000
#
#             indicators/sol_7y_10y
# Date
# 2020-11-15              35.000000
# 2020-11-16             122.000000
# 2020-11-17              81.000000
# 2020-11-18             288.000000
# 2020-11-19             104.000000

# %% [markdown]
# #### Indicator-3 Metrics CSV-Files

# %%
# List of Indicator-3 Features
indicator3_feature_list = ['net_unrealized_profit_loss', 'unrealized_profit', 'unrealized_loss', 'net_realized_profit_loss', 'realized_profit', 'realized_loss', 'nupl_more_155', 'nupl_less_155', 'puell_multiple', 'stock_to_flow_deflection', 'difficulty_ribbon_compression']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in indicator3_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Indicator-3 Data Frame
df_indicator3 = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_indicator3.columns:
    try:
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].str.replace(',','.')
        df_indicator3["{}".format(y)] = df_indicator3["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Indicator-3 Metric Values
df_indicator3.tail()
# Out:
#             indicators/net_unrealized_profit_loss  \
# Date
# 2020-11-15                               0.565391
# 2020-11-16                               0.583600
# 2020-11-17                               0.603680
# 2020-11-18                               0.602824
# 2020-11-19                               0.601207
#
#             indicators/unrealized_profit  indicators/unrealized_loss  \
# Date
# 2020-11-15                      0.566447                    0.001056
# 2020-11-16                      0.583943                    0.000343
# 2020-11-17                      0.603805                    0.000124
# 2020-11-18                      0.603017                    0.000193
# 2020-11-19                      0.601440                    0.000233
#
#             indicators/net_realized_profit_loss  indicators/realized_profit  \
# Date
# 2020-11-15                     137336945.277239            168119815.554779
# 2020-11-16                     372514844.963326            390235235.895932
# 2020-11-17                     807779063.197345            838096570.157533
# 2020-11-18                    1334539073.514310           1421394923.043790
# 2020-11-19                     415593482.698119            469638576.264795
#
#             indicators/realized_loss  indicators/nupl_more_155  \
# Date
# 2020-11-15           30782870.277541                  0.649257
# 2020-11-16           17720390.932606                  0.664884
# 2020-11-17           30317506.960188                  0.682597
# 2020-11-18           86855849.529486                  0.685710
# 2020-11-19           54045093.566676                  0.685386
#
#             indicators/nupl_less_155  indicators/puell_multiple  \
# Date
# 2020-11-15                  0.215121                   1.240418
# 2020-11-16                  0.246091                   1.353830
# 2020-11-17                  0.277236                   1.386802
# 2020-11-18                  0.269365                   1.563237
# 2020-11-19                  0.264858                   1.262393
#
#             indicators/stock_to_flow_deflection  \
# Date
# 2020-11-15                             0.617117
# 2020-11-16                             0.641549
# 2020-11-17                             0.673337
# 2020-11-18                             0.675437
# 2020-11-19                             0.670532
#
#             indicators/difficulty_ribbon_compression
# Date
# 2020-11-15                                  0.043579
# 2020-11-16                                  0.043584
# 2020-11-17                                  0.041677
# 2020-11-18                                  0.039892
# 2020-11-19                                  0.037933

# %% [markdown]
# #### Addresses Metric CSV-Files

# %%
# List of Addresses Features
addresses_feature_list = ['active_count', 'sending_count', 'receiving_count', 'new_non_zero_count', 'non_zero_count', 'min_point_zero_1_count', 'min_point_1_count', 'min_1_count', 'min_10_count', 'min_100_count', 'min_1k_count', 'min_10k_count']

# Counter to Differentiate between Data Frame Setup and Data Frame Extension
counter=0

# For Loop through all Features in the List
for x in addresses_feature_list:
    
    # Import Feature CSV-Files
    df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
    
    # Condition - Data Frame Set up or Data Frame Extension
    if counter > 0:
        
        # Data Frame Extension - Inner Join
        df_new = df_new.join(df, how='inner')
    
    else:
        
        # Data Frame Setup
        df_new = df
    
    # Increase Counter
    counter +=1

# Store Data Frame Copy in Addresses Data Frame
df_addresses = df_new.copy()

# Delete Original Data Frame
del df_new

# Change Data Type of Columns to Float
for y in df_addresses.columns:
    try:
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].str.replace(',','.')
        df_addresses["{}".format(y)] = df_addresses["{}".format(y)].astype(float)
    except:
        pass

# %%
# Latest Addresses Metric Values
df_addresses.tail()
# Out:
#             addresses/active_count  addresses/sending_count  \
# Date
# 2020-11-15           859865.000000            559028.000000
# 2020-11-16          1036960.000000            663147.000000
# 2020-11-17          1134731.000000            706546.000000
# 2020-11-18          1187942.000000            750796.000000
# 2020-11-19          1058686.000000            660869.000000
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-11-15              555358.000000                 407914.000000
# 2020-11-16              681255.000000                 493329.000000
# 2020-11-17              770674.000000                 558880.000000
# 2020-11-18              807692.000000                 581082.000000
# 2020-11-19              717366.000000                 517332.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-11-15           32479715.000000                    8571801.000000
# 2020-11-16           32473955.000000                    8564964.000000
# 2020-11-17           32506599.000000                    8553575.000000
# 2020-11-18           32525162.000000                    8532965.000000
# 2020-11-19           32544167.000000                    8542553.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-11-15               3126946.000000          818993.000000
# 2020-11-16               3124999.000000          818622.000000
# 2020-11-17               3127510.000000          819167.000000
# 2020-11-18               3123601.000000          818953.000000
# 2020-11-19               3125440.000000          819280.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-11-15           154497.000000             16241.000000
# 2020-11-16           154343.000000             16276.000000
# 2020-11-17           154240.000000             16238.000000
# 2020-11-18           154259.000000             16242.000000
# 2020-11-19           154441.000000             16199.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-11-15             2237.000000               110.000000
# 2020-11-16             2237.000000               111.000000
# 2020-11-17             2232.000000               111.000000
# 2020-11-18             2228.000000               113.000000
# 2020-11-19             2229.000000               112.000000

# %% [markdown]
# #### Futures Metrics CSV-Files - Excluded as Data Available Only Since Feb 2020

# %% [markdown]
# ##### List of Future Features
# futures_feature_list = ['futures_volume_daily_all_sum', 'futures_volume_daily_perpetual_sum', 'futures_open_interest_all_sum', 'futures_open_interest_perpetual_sum', 'futures_funding_rate_perpetual']
#
# ##### Counter to Differentiate between Data Frame Setup and Data Frame Extension
# counter=0
#
# ##### For Loop through all Features in the List
# for x in futures_feature_list:
#
#     ##### Import Feature CSV-Files
#     df = pd.read_csv("Glassnode/{}.csv".format(x), index_col='Date')
#
#     ##### Condition - Data Frame Set up or Data Frame Extension
#     if counter > 0:
#
#         ##### Data Frame Extension - Inner Join
#         df_new = df_new.join(df, how='inner')
#
#     else:
#
#         ##### Data Frame Setup
#         df_new = df
#
#     ##### Increase Counter
#     counter +=1
#
# ##### Store Data Frame Copy in Market Data Frame
# df_futures = df_new.copy()
#
# ##### Delete Original Data Frame
# del df_new
#
# ##### Change Data Type of Columns to Float
# for y in df_futures.columns:
#     try:
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].str.replace(',','.')
#         df_futures["{}".format(y)] = df_futures["{}".format(y)].astype(float)
#     except:
#         pass

# %% [markdown]
# ## Target Variables

# %%
df_return = pd.DataFrame(df_market['market/price_usd_close'])

# %%
df_return.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_return['Daily Return in USD'] = df_return['Closed Price USD'].diff()

# %% [raw]
# # Add Column with BTC Daily Returns in Percent
# df_return['Daily Returns in Percent'] = (df_return['Daily Returns USD']) / (df_return['Closed Price USD'].shift(1))*100

# %% [raw]
# # Add Column with BTC Daily Log Returns in Percent
# df_return['Daily Log Returns in Percent'] = pd.DataFrame(np.log(df_return['Closed Price USD']/df_return['Closed Price USD'].shift(1))*100)

# %%
df_return.tail()
# Out:
#             Closed Price USD  Daily Return in USD
# Date
# 2020-11-15      15962.098952          -113.353782
# 2020-11-16      16709.612284           747.513332
# 2020-11-17      17667.381593           957.769310
# 2020-11-18      17812.233237           144.851643
# 2020-11-19      17797.552692           -14.680545

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Volatility

# %%
# Selecting BTC Close Price in USD
df_volatility = pd.DataFrame(df_market['market/price_usd_close'])

# %%
# Rename Price Column
df_volatility.columns = ['Closed Price USD']

# %%
# Add Column with BTC Daily Returns in USD
df_volatility['Daily Return in USD'] = df_volatility['Closed Price USD'].diff()

# %%
# Add Column with BTC Daily Returns in Percent
df_volatility['Daily Return in Percent'] = (df_volatility['Daily Return in USD']) / (df_volatility['Closed Price USD'].shift(1))*100

# %%
# Add Column with BTC Daily Log Returns in Percent
df_volatility['Daily Log Return in Percent'] = pd.DataFrame(np.log(df_volatility['Closed Price USD']/df_volatility['Closed Price USD'].shift(1))*100)

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-11-15      15962.098952          -113.353782                -0.705136
# 2020-11-16      16709.612284           747.513332                 4.683052
# 2020-11-17      17667.381593           957.769310                 5.731846
# 2020-11-18      17812.233237           144.851643                 0.819882
# 2020-11-19      17797.552692           -14.680545                -0.082418
#
#             Daily Log Return in Percent
# Date
# 2020-11-15                    -0.707634
# 2020-11-16                     4.576704
# 2020-11-17                     5.573595
# 2020-11-18                     0.816539
# 2020-11-19                    -0.082452

# %%
# Calculation of Rolling Volatility of BTC Daily Log Returns for 10, 20 and 30 days period
df_volatility['Volatility Daily Log Return in Percent 3D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=3, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 5D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=5, min_periods=1).std())
df_volatility['Volatility Daily Log Return in Percent 10D'] = pd.DataFrame(df_volatility['Daily Log Return in Percent'].rolling(window=10, min_periods=1).std())

# %%
df_volatility.tail()
# Out:
#             Closed Price USD  Daily Return in USD  Daily Return in Percent  \
# Date
# 2020-11-15      15962.098952          -113.353782                -0.705136
# 2020-11-16      16709.612284           747.513332                 4.683052
# 2020-11-17      17667.381593           957.769310                 5.731846
# 2020-11-18      17812.233237           144.851643                 0.819882
# 2020-11-19      17797.552692           -14.680545                -0.082418
#
#             Daily Log Return in Percent  \
# Date
# 2020-11-15                    -0.707634
# 2020-11-16                     4.576704
# 2020-11-17                     5.573595
# 2020-11-18                     0.816539
# 2020-11-19                    -0.082452
#
#             Volatility Daily Log Return in Percent 3D  \
# Date
# 2020-11-15                                   0.822261
# 2020-11-16                                   3.288918
# 2020-11-17                                   3.375694
# 2020-11-18                                   2.508725
# 2020-11-19                                   3.039425
#
#             Volatility Daily Log Return in Percent 5D  \
# Date
# 2020-11-15                                   2.194807
# 2020-11-16                                   2.704052
# 2020-11-17                                   3.214138
# 2020-11-18                                   3.154788
# 2020-11-19                                   2.849220
#
#             Volatility Daily Log Return in Percent 10D
# Date
# 2020-11-15                                    2.633703
# 2020-11-16                                    2.960628
# 2020-11-17                                    2.655435
# 2020-11-18                                    2.518824
# 2020-11-19                                    2.440548

# %%
df_volatility_reduced = df_volatility['Volatility Daily Log Return in Percent 5D']

# %% [markdown]
# ### Log Price

# %%
# Selecting BTC Close Price in USD
df_logprice = pd.DataFrame(np.log(df_market['market/price_usd_close']))

# %%
df_logprice.columns = ['Log Price in USD']

# %%
df_logprice.tail()
# Out:
#             Log Price in USD
# Date
# 2020-11-15          9.677972
# 2020-11-16          9.723739
# 2020-11-17          9.779475
# 2020-11-18          9.787641
# 2020-11-19          9.786816

# %% [markdown]
# # Data Sets

# %% [markdown]
# ## Data Set I. - Blockchain Metrics Only

# %%
# Merging all Blockchain DataFrame Metrics
df_blockchain = pd.concat([df_return, df_logprice, df_volatility_reduced, df_market, df_mining, df_blockfeatures, df_distribution, df_fees, df_utxo, df_supply, 
                           df_transaction, df_exchange, df_indicator1, df_indicator2, df_indicator3, df_addresses], axis=1, join='inner')

# %%
df_blockchain = df_blockchain.dropna()

# %%
df_blockchain = df_blockchain.drop(['Closed Price USD'], axis=1)

# %%
df_blockchain.index = df_blockchain.index.astype('datetime64[ns]')

# %%
df_blockchain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3383 entries, 2011-08-17 to 2020-11-19
# Columns: 102 entries, Daily Return in USD to addresses/min_10k_count
# dtypes: float64(102)
# memory usage: 2.7 MB

# %%
df_blockchain.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-15          -113.353782          9.677972
# 2020-11-16           747.513332          9.723739
# 2020-11-17           957.769310          9.779475
# 2020-11-18           144.851643          9.787641
# 2020-11-19           -14.680545          9.786816
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-15                                   2.194807            15962.098952
# 2020-11-16                                   2.704052            16709.612284
# 2020-11-17                                   3.214138            17667.381593
# 2020-11-18                                   3.154788            17812.233237
# 2020-11-19                                   2.849220            17797.552692
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-15                       -0.194319                6910.668850
# 2020-11-16                       -0.156588                6926.408944
# 2020-11-17                       -0.108245                6962.388651
# 2020-11-18                       -0.100934                7037.449307
# 2020-11-19                       -0.101675                7059.762417
#
#             market/mvrv       mining/difficulty_latest  \
# Date
# 2020-11-15     2.311843 72102964397116403744768.000000
# 2020-11-16     2.359903 75577685065077505392640.000000
# 2020-11-17     2.448941 75577685065077505392640.000000
# 2020-11-18     2.537373 75577685065077505392640.000000
# 2020-11-19     2.523737 75577685065077505392640.000000
#
#                   mining/hash_rate_mean  mining/revenue_sum  ...  \
# Date                                                         ...
# 2020-11-15 124875241422092992512.000000          979.933355  ...
# 2020-11-16 136158304329831006208.000000         1083.457706  ...
# 2020-11-17 136840305323567005696.000000         1071.791296  ...
# 2020-11-18 146411297553796005888.000000         1153.888686  ...
# 2020-11-19 119777232389561008128.000000          944.126362  ...
#
#             addresses/receiving_count  addresses/new_non_zero_count  \
# Date
# 2020-11-15              555358.000000                 407914.000000
# 2020-11-16              681255.000000                 493329.000000
# 2020-11-17              770674.000000                 558880.000000
# 2020-11-18              807692.000000                 581082.000000
# 2020-11-19              717366.000000                 517332.000000
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2020-11-15           32479715.000000                    8571801.000000
# 2020-11-16           32473955.000000                    8564964.000000
# 2020-11-17           32506599.000000                    8553575.000000
# 2020-11-18           32525162.000000                    8532965.000000
# 2020-11-19           32544167.000000                    8542553.000000
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2020-11-15               3126946.000000          818993.000000
# 2020-11-16               3124999.000000          818622.000000
# 2020-11-17               3127510.000000          819167.000000
# 2020-11-18               3123601.000000          818953.000000
# 2020-11-19               3125440.000000          819280.000000
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2020-11-15           154497.000000             16241.000000
# 2020-11-16           154343.000000             16276.000000
# 2020-11-17           154240.000000             16238.000000
# 2020-11-18           154259.000000             16242.000000
# 2020-11-19           154441.000000             16199.000000
#
#             addresses/min_1k_count  addresses/min_10k_count
# Date
# 2020-11-15             2237.000000               110.000000
# 2020-11-16             2237.000000               111.000000
# 2020-11-17             2232.000000               111.000000
# 2020-11-18             2228.000000               113.000000
# 2020-11-19             2229.000000               112.000000
#
# [5 rows x 102 columns]

# %%
# Summary of each variable
df_blockchain.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count          3383.000000       3383.000000
# mean              5.257639          6.381996
# std             229.354170          2.453672
# min           -3052.461475          0.718341
# 25%              -7.045212          5.421285
# 50%               0.108877          6.426303
# 75%              12.969243          8.780060
# max            3224.132131          9.882653
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                3383.000000             3383.000000
# mean                                    3.495852             3154.327545
# std                                     3.254410             4096.011651
# min                                     0.157723                2.051027
# 25%                                     1.515492              226.169512
# 50%                                     2.651172              617.885270
# 75%                                     4.396525             6503.265224
# max                                    41.749946            19587.613733
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                     3383.000000                3383.000000  3383.000000
# mean                        -0.550409                1920.178218     1.684656
# std                          0.230191                2377.877387     0.746225
# min                         -0.935694                   4.780226     0.402165
# 25%                         -0.717077                 245.539108     1.174297
# 50%                         -0.597350                 350.998365     1.592842
# 75%                         -0.450968                4847.302726     1.967659
# max                          0.000000                7059.762417     5.733982
#
#             mining/difficulty_latest        mining/hash_rate_mean  \
# count                    3383.000000                  3383.000000
# mean  13714869606467917316096.000000  23225501122548989952.000000
# std   22876505714677323399168.000000  38613525907786825728.000000
# min          4684588175054590.000000         6399665203131.940430
# 25%       3469816344043044864.000000      7242754818631385.000000
# 50%     716621792837638029312.000000   1240432941748699904.000000
# 75%   23036823578322000674816.000000  38106466854720249856.000000
# max   85887904103269694177280.000000 160765244797356015616.000000
#
#        mining/revenue_sum  ...  addresses/receiving_count  \
# count         3383.000000  ...                3383.000000
# mean          3461.906265  ...              325498.770913
# std           1915.738124  ...              226103.395284
# min            738.150148  ...                7539.000000
# 25%           1942.741938  ...              108242.500000
# 50%           3335.552722  ...              368253.000000
# 75%           4255.627504  ...              509361.500000
# max           9214.887810  ...             1072829.000000
#
#        addresses/new_non_zero_count  addresses/non_zero_count  \
# count                   3383.000000               3383.000000
# mean                  217680.781555           12201116.424180
# std                   158350.532730           10735352.805330
# min                     4241.000000             425513.000000
# 25%                    66893.000000            2283238.000000
# 50%                   225259.000000            7547079.000000
# 75%                   348657.000000           22403644.000000
# max                   800180.000000           32849437.000000
#
#        addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# count                       3383.000000                  3383.000000
# mean                     3476664.696128               1396125.959799
# std                      2892641.155452               1020321.969876
# min                       208208.000000                133210.000000
# 25%                       803197.000000                446654.500000
# 50%                      2587405.000000               1194238.000000
# 75%                      6385109.000000               2461688.500000
# max                      8753449.000000               3186455.000000
#
#        addresses/min_1_count  addresses/min_10_count  addresses/min_100_count  \
# count            3383.000000             3383.000000              3383.000000
# mean           472151.216080           125886.301803             14772.417381
# std            237885.657826            28431.731520              3500.113369
# min            103869.000000            65620.000000              4147.000000
# 25%            246639.500000           100358.000000             12972.500000
# 50%            481578.000000           138446.000000             16192.000000
# 75%            710387.000000           149746.500000             17163.000000
# max            825254.000000           157275.000000             18543.000000
#
#        addresses/min_1k_count  addresses/min_10k_count
# count             3383.000000              3383.000000
# mean              1626.082767               102.524978
# std                374.498313                14.436136
# min                622.000000                63.000000
# 25%               1479.000000                97.000000
# 50%               1687.000000               105.000000
# 75%               1843.000000               113.000000
# max               2237.000000               126.000000
#
# [8 rows x 102 columns]

# %%
# Creating CSV-File of Blockchain Data
df_blockchain.to_csv("df_dataset1.csv")

# %% [markdown]
# # Classification Models - Data Set Variations

# %%
# Import of Modules and Packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix, classification_report

# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from pycaret.classification import *

# Deep Neural Networks
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from keras.optimizers import Adam

# PyCaret
import pycaret

# %%
# Adjustment of Decimal Places
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Import Data Sets

# %% [markdown]
# ## Data Set I.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\markus.gebele\\github_repo\\JupyterLabDir\\Rest\\MA BTC\\Markus_Code_MA_final\\20201010'

# %%
# CSV Import of Data Set I. - Blockchain Data
df_dataset1 = pd.read_csv('df_dataset1.csv', parse_dates = True, index_col='Date')

# %%
df_dataset1
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-08-17                 0.03              2.40
# 2011-08-18                -0.15              2.38
# 2011-08-19                 0.80              2.46
# 2011-08-20                -0.20              2.44
# 2011-08-21                -0.13              2.43
# ...                         ...               ...
# 2020-11-15              -113.35              9.68
# 2020-11-16               747.51              9.72
# 2020-11-17               957.77              9.78
# 2020-11-18               144.85              9.79
# 2020-11-19               -14.68              9.79
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-08-17                                       3.60                   10.99
# 2011-08-18                                       3.29                   10.85
# 2011-08-19                                       3.72                   11.65
# 2011-08-20                                       3.77                   11.45
# 2011-08-21                                       3.71                   11.32
# ...                                               ...                     ...
# 2020-11-15                                       2.19                15962.10
# 2020-11-16                                       2.70                16709.61
# 2020-11-17                                       3.21                17667.38
# 2020-11-18                                       3.15                17812.23
# 2020-11-19                                       2.85                17797.55
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-08-17                           -0.66                       6.81
# 2011-08-18                           -0.66                       6.81
# 2011-08-19                           -0.63                       6.82
# 2011-08-20                           -0.64                       6.83
# 2011-08-21                           -0.64                       6.83
# ...                                    ...                        ...
# 2020-11-15                           -0.19                    6910.67
# 2020-11-16                           -0.16                    6926.41
# 2020-11-17                           -0.11                    6962.39
# 2020-11-18                           -0.10                    7037.45
# 2020-11-19                           -0.10                    7059.76
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2011-08-17         1.60        7755426037811680.00        12230547335773.00
# 2011-08-18         1.60        7755426037811680.00        12915246321786.50
# 2011-08-19         1.65        7755426037811680.00        11678381642086.70
# 2011-08-20         1.68        7755426037811680.00        13035626696015.50
# 2011-08-21         1.67        7755426037811680.00        14115210625069.60
# ...                 ...                        ...                      ...
# 2020-11-15         2.31 72102964397116403744768.00 124875241422092992512.00
# 2020-11-16         2.36 75577685065077505392640.00 136158304329831006208.00
# 2020-11-17         2.45 75577685065077505392640.00 136840305323567005696.00
# 2020-11-18         2.54 75577685065077505392640.00 146411297553796005888.00
# 2020-11-19         2.52 75577685065077505392640.00 119777232389561008128.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2011-08-17             6806.74  ...                   16662.00
# 2011-08-18             7205.92  ...                   17676.00
# 2011-08-19             6557.77  ...                   18932.00
# 2011-08-20             7605.42  ...                   18345.00
# 2011-08-21             8005.69  ...                   19626.00
# ...                        ...  ...                        ...
# 2020-11-15              979.93  ...                  555358.00
# 2020-11-16             1083.46  ...                  681255.00
# 2020-11-17             1071.79  ...                  770674.00
# 2020-11-18             1153.89  ...                  807692.00
# 2020-11-19              944.13  ...                  717366.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-08-17                      11974.00                 425513.00
# 2011-08-18                      11917.00                 429263.00
# 2011-08-19                      14238.00                 434988.00
# 2011-08-20                      12994.00                 440560.00
# 2011-08-21                      14851.00                 446963.00
# ...                                  ...                       ...
# 2020-11-15                     407914.00               32479715.00
# 2020-11-16                     493329.00               32473955.00
# 2020-11-17                     558880.00               32506599.00
# 2020-11-18                     581082.00               32525162.00
# 2020-11-19                     517332.00               32544167.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-08-17                         208208.00                    133210.00
# 2011-08-18                         208892.00                    133657.00
# 2011-08-19                         209553.00                    133993.00
# 2011-08-20                         210510.00                    134628.00
# 2011-08-21                         211300.00                    135057.00
# ...                                      ...                          ...
# 2020-11-15                        8571801.00                   3126946.00
# 2020-11-16                        8564964.00                   3124999.00
# 2020-11-17                        8553575.00                   3127510.00
# 2020-11-18                        8532965.00                   3123601.00
# 2020-11-19                        8542553.00                   3125440.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-08-17              103869.00                65620.00
# 2011-08-18              104143.00                65707.00
# 2011-08-19              104342.00                65756.00
# 2011-08-20              104796.00                65874.00
# 2011-08-21              105154.00                66045.00
# ...                           ...                     ...
# 2020-11-15              818993.00               154497.00
# 2020-11-16              818622.00               154343.00
# 2020-11-17              819167.00               154240.00
# 2020-11-18              818953.00               154259.00
# 2020-11-19              819280.00               154441.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-08-17                  4147.00                  622.00
# 2011-08-18                  4174.00                  624.00
# 2011-08-19                  4171.00                  627.00
# 2011-08-20                  4187.00                  625.00
# 2011-08-21                  4203.00                  625.00
# ...                             ...                     ...
# 2020-11-15                 16241.00                 2237.00
# 2020-11-16                 16276.00                 2237.00
# 2020-11-17                 16238.00                 2232.00
# 2020-11-18                 16242.00                 2228.00
# 2020-11-19                 16199.00                 2229.00
#
#             addresses/min_10k_count
# Date
# 2011-08-17                    75.00
# 2011-08-18                    75.00
# 2011-08-19                    75.00
# 2011-08-20                    75.00
# 2011-08-21                    75.00
# ...                             ...
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
# 2020-11-19                   112.00
#
# [3383 rows x 102 columns]

# %%
# Data Set Info
df_dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3383 entries, 2011-08-17 to 2020-11-19
# Columns: 102 entries, Daily Return in USD to addresses/min_10k_count
# dtypes: float64(102)
# memory usage: 2.7 MB

# %%
# List of Data Types
l_dtypes = df_dataset1.dtypes

# %%
# Counter
counter = 0

# Cross-Check of Data Types
for i in l_dtypes:
    if (i == float):
        counter = counter+1
    else:
        counter = counter

# Number of Float Data Types
print(counter)
# Out:
# 102

# %%
# Data Types
df_dataset1.dtypes
# Out:
# Daily Return in USD                          float64
# Log Price in USD                             float64
# Volatility Daily Log Return in Percent 5D    float64
# market/price_usd_close                       float64
# market/price_drawdown_relative               float64
#                                               ...
# addresses/min_1_count                        float64
# addresses/min_10_count                       float64
# addresses/min_100_count                      float64
# addresses/min_1k_count                       float64
# addresses/min_10k_count                      float64
# Length: 102, dtype: object

# %%
# Summary Statistics
df_dataset1.describe()
# Out:
#        Daily Return in USD  Log Price in USD  \
# count              3383.00           3383.00
# mean                  5.26              6.38
# std                 229.35              2.45
# min               -3052.46              0.72
# 25%                  -7.05              5.42
# 50%                   0.11              6.43
# 75%                  12.97              8.78
# max                3224.13              9.88
#
#        Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# count                                    3383.00                 3383.00
# mean                                        3.50                 3154.33
# std                                         3.25                 4096.01
# min                                         0.16                    2.05
# 25%                                         1.52                  226.17
# 50%                                         2.65                  617.89
# 75%                                         4.40                 6503.27
# max                                        41.75                19587.61
#
#        market/price_drawdown_relative  market/price_realized_usd  market/mvrv  \
# count                         3383.00                    3383.00      3383.00
# mean                            -0.55                    1920.18         1.68
# std                              0.23                    2377.88         0.75
# min                             -0.94                       4.78         0.40
# 25%                             -0.72                     245.54         1.17
# 50%                             -0.60                     351.00         1.59
# 75%                             -0.45                    4847.30         1.97
# max                              0.00                    7059.76         5.73
#
#         mining/difficulty_latest    mining/hash_rate_mean  mining/revenue_sum  \
# count                    3383.00                  3383.00             3383.00
# mean  13714869606467917316096.00  23225501122548989952.00             3461.91
# std   22876505714677323399168.00  38613525907786825728.00             1915.74
# min          4684588175054590.00         6399665203131.94              738.15
# 25%       3469816344043044864.00      7242754818631385.00             1942.74
# 50%     716621792837638029312.00   1240432941748699904.00             3335.55
# 75%   23036823578322000674816.00  38106466854720249856.00             4255.63
# max   85887904103269694177280.00 160765244797356015616.00             9214.89
#
#        ...  addresses/receiving_count  addresses/new_non_zero_count  \
# count  ...                    3383.00                       3383.00
# mean   ...                  325498.77                     217680.78
# std    ...                  226103.40                     158350.53
# min    ...                    7539.00                       4241.00
# 25%    ...                  108242.50                      66893.00
# 50%    ...                  368253.00                     225259.00
# 75%    ...                  509361.50                     348657.00
# max    ...                 1072829.00                     800180.00
#
#        addresses/non_zero_count  addresses/min_point_zero_1_count  \
# count                   3383.00                           3383.00
# mean                12201116.42                        3476664.70
# std                 10735352.81                        2892641.16
# min                   425513.00                         208208.00
# 25%                  2283238.00                         803197.00
# 50%                  7547079.00                        2587405.00
# 75%                 22403644.00                        6385109.00
# max                 32849437.00                        8753449.00
#
#        addresses/min_point_1_count  addresses/min_1_count  \
# count                      3383.00                3383.00
# mean                    1396125.96              472151.22
# std                     1020321.97              237885.66
# min                      133210.00              103869.00
# 25%                      446654.50              246639.50
# 50%                     1194238.00              481578.00
# 75%                     2461688.50              710387.00
# max                     3186455.00              825254.00
#
#        addresses/min_10_count  addresses/min_100_count  \
# count                 3383.00                  3383.00
# mean                125886.30                 14772.42
# std                  28431.73                  3500.11
# min                  65620.00                  4147.00
# 25%                 100358.00                 12972.50
# 50%                 138446.00                 16192.00
# 75%                 149746.50                 17163.00
# max                 157275.00                 18543.00
#
#        addresses/min_1k_count  addresses/min_10k_count
# count                 3383.00                  3383.00
# mean                  1626.08                   102.52
# std                    374.50                    14.44
# min                    622.00                    63.00
# 25%                   1479.00                    97.00
# 50%                   1687.00                   105.00
# 75%                   1843.00                   113.00
# max                   2237.00                   126.00
#
# [8 rows x 102 columns]

# %%
# Dataset Tail
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-15              -113.35              9.68
# 2020-11-16               747.51              9.72
# 2020-11-17               957.77              9.78
# 2020-11-18               144.85              9.79
# 2020-11-19               -14.68              9.79
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-15                                       2.19                15962.10
# 2020-11-16                                       2.70                16709.61
# 2020-11-17                                       3.21                17667.38
# 2020-11-18                                       3.15                17812.23
# 2020-11-19                                       2.85                17797.55
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-15                           -0.19                    6910.67
# 2020-11-16                           -0.16                    6926.41
# 2020-11-17                           -0.11                    6962.39
# 2020-11-18                           -0.10                    7037.45
# 2020-11-19                           -0.10                    7059.76
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-11-15         2.31 72102964397116403744768.00 124875241422092992512.00
# 2020-11-16         2.36 75577685065077505392640.00 136158304329831006208.00
# 2020-11-17         2.45 75577685065077505392640.00 136840305323567005696.00
# 2020-11-18         2.54 75577685065077505392640.00 146411297553796005888.00
# 2020-11-19         2.52 75577685065077505392640.00 119777232389561008128.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2020-11-15              979.93  ...                  555358.00
# 2020-11-16             1083.46  ...                  681255.00
# 2020-11-17             1071.79  ...                  770674.00
# 2020-11-18             1153.89  ...                  807692.00
# 2020-11-19              944.13  ...                  717366.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-15                     407914.00               32479715.00
# 2020-11-16                     493329.00               32473955.00
# 2020-11-17                     558880.00               32506599.00
# 2020-11-18                     581082.00               32525162.00
# 2020-11-19                     517332.00               32544167.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-15                        8571801.00                   3126946.00
# 2020-11-16                        8564964.00                   3124999.00
# 2020-11-17                        8553575.00                   3127510.00
# 2020-11-18                        8532965.00                   3123601.00
# 2020-11-19                        8542553.00                   3125440.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-15              818993.00               154497.00
# 2020-11-16              818622.00               154343.00
# 2020-11-17              819167.00               154240.00
# 2020-11-18              818953.00               154259.00
# 2020-11-19              819280.00               154441.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-15                 16241.00                 2237.00
# 2020-11-16                 16276.00                 2237.00
# 2020-11-17                 16238.00                 2232.00
# 2020-11-18                 16242.00                 2228.00
# 2020-11-19                 16199.00                 2229.00
#
#             addresses/min_10k_count
# Date
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
# 2020-11-19                   112.00
#
# [5 rows x 102 columns]

# %% [markdown]
# ## Prediction Shift

# %% [markdown]
# ### Data Set I.

# %%
# Shift of Target Column by 1 Day
df_dataset1['Daily Return in USD'] = df_dataset1['Daily Return in USD'].shift(1)

# %%
# Check Shift
df_dataset1.tail()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2020-11-15              -236.06              9.68
# 2020-11-16              -113.35              9.72
# 2020-11-17               747.51              9.78
# 2020-11-18               957.77              9.79
# 2020-11-19               144.85              9.79
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2020-11-15                                       2.19                15962.10
# 2020-11-16                                       2.70                16709.61
# 2020-11-17                                       3.21                17667.38
# 2020-11-18                                       3.15                17812.23
# 2020-11-19                                       2.85                17797.55
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2020-11-15                           -0.19                    6910.67
# 2020-11-16                           -0.16                    6926.41
# 2020-11-17                           -0.11                    6962.39
# 2020-11-18                           -0.10                    7037.45
# 2020-11-19                           -0.10                    7059.76
#
#             market/mvrv   mining/difficulty_latest    mining/hash_rate_mean  \
# Date
# 2020-11-15         2.31 72102964397116403744768.00 124875241422092992512.00
# 2020-11-16         2.36 75577685065077505392640.00 136158304329831006208.00
# 2020-11-17         2.45 75577685065077505392640.00 136840305323567005696.00
# 2020-11-18         2.54 75577685065077505392640.00 146411297553796005888.00
# 2020-11-19         2.52 75577685065077505392640.00 119777232389561008128.00
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2020-11-15              979.93  ...                  555358.00
# 2020-11-16             1083.46  ...                  681255.00
# 2020-11-17             1071.79  ...                  770674.00
# 2020-11-18             1153.89  ...                  807692.00
# 2020-11-19              944.13  ...                  717366.00
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-15                     407914.00               32479715.00
# 2020-11-16                     493329.00               32473955.00
# 2020-11-17                     558880.00               32506599.00
# 2020-11-18                     581082.00               32525162.00
# 2020-11-19                     517332.00               32544167.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-15                        8571801.00                   3126946.00
# 2020-11-16                        8564964.00                   3124999.00
# 2020-11-17                        8553575.00                   3127510.00
# 2020-11-18                        8532965.00                   3123601.00
# 2020-11-19                        8542553.00                   3125440.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-15              818993.00               154497.00
# 2020-11-16              818622.00               154343.00
# 2020-11-17              819167.00               154240.00
# 2020-11-18              818953.00               154259.00
# 2020-11-19              819280.00               154441.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-15                 16241.00                 2237.00
# 2020-11-16                 16276.00                 2237.00
# 2020-11-17                 16238.00                 2232.00
# 2020-11-18                 16242.00                 2228.00
# 2020-11-19                 16199.00                 2229.00
#
#             addresses/min_10k_count
# Date
# 2020-11-15                   110.00
# 2020-11-16                   111.00
# 2020-11-17                   111.00
# 2020-11-18                   113.00
# 2020-11-19                   112.00
#
# [5 rows x 102 columns]

# %%
# Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          1
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 102, dtype: int64

# %%
# daily return: von gestern auf heute die preisveränderung deswegen shift später
df_dataset1.isnull()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-08-17                 True             False
# 2011-08-18                False             False
# 2011-08-19                False             False
# 2011-08-20                False             False
# 2011-08-21                False             False
# ...                         ...               ...
# 2020-11-15                False             False
# 2020-11-16                False             False
# 2020-11-17                False             False
# 2020-11-18                False             False
# 2020-11-19                False             False
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-08-17                                      False                   False
# 2011-08-18                                      False                   False
# 2011-08-19                                      False                   False
# 2011-08-20                                      False                   False
# 2011-08-21                                      False                   False
# ...                                               ...                     ...
# 2020-11-15                                      False                   False
# 2020-11-16                                      False                   False
# 2020-11-17                                      False                   False
# 2020-11-18                                      False                   False
# 2020-11-19                                      False                   False
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-08-17                           False                      False
# 2011-08-18                           False                      False
# 2011-08-19                           False                      False
# 2011-08-20                           False                      False
# 2011-08-21                           False                      False
# ...                                    ...                        ...
# 2020-11-15                           False                      False
# 2020-11-16                           False                      False
# 2020-11-17                           False                      False
# 2020-11-18                           False                      False
# 2020-11-19                           False                      False
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-08-17        False                     False                  False
# 2011-08-18        False                     False                  False
# 2011-08-19        False                     False                  False
# 2011-08-20        False                     False                  False
# 2011-08-21        False                     False                  False
# ...                 ...                       ...                    ...
# 2020-11-15        False                     False                  False
# 2020-11-16        False                     False                  False
# 2020-11-17        False                     False                  False
# 2020-11-18        False                     False                  False
# 2020-11-19        False                     False                  False
#
#             mining/revenue_sum  ...  addresses/receiving_count  \
# Date                            ...
# 2011-08-17               False  ...                      False
# 2011-08-18               False  ...                      False
# 2011-08-19               False  ...                      False
# 2011-08-20               False  ...                      False
# 2011-08-21               False  ...                      False
# ...                        ...  ...                        ...
# 2020-11-15               False  ...                      False
# 2020-11-16               False  ...                      False
# 2020-11-17               False  ...                      False
# 2020-11-18               False  ...                      False
# 2020-11-19               False  ...                      False
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-08-17                         False                     False
# 2011-08-18                         False                     False
# 2011-08-19                         False                     False
# 2011-08-20                         False                     False
# 2011-08-21                         False                     False
# ...                                  ...                       ...
# 2020-11-15                         False                     False
# 2020-11-16                         False                     False
# 2020-11-17                         False                     False
# 2020-11-18                         False                     False
# 2020-11-19                         False                     False
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-08-17                             False                        False
# 2011-08-18                             False                        False
# 2011-08-19                             False                        False
# 2011-08-20                             False                        False
# 2011-08-21                             False                        False
# ...                                      ...                          ...
# 2020-11-15                             False                        False
# 2020-11-16                             False                        False
# 2020-11-17                             False                        False
# 2020-11-18                             False                        False
# 2020-11-19                             False                        False
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-08-17                  False                   False
# 2011-08-18                  False                   False
# 2011-08-19                  False                   False
# 2011-08-20                  False                   False
# 2011-08-21                  False                   False
# ...                           ...                     ...
# 2020-11-15                  False                   False
# 2020-11-16                  False                   False
# 2020-11-17                  False                   False
# 2020-11-18                  False                   False
# 2020-11-19                  False                   False
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-08-17                    False                   False
# 2011-08-18                    False                   False
# 2011-08-19                    False                   False
# 2011-08-20                    False                   False
# 2011-08-21                    False                   False
# ...                             ...                     ...
# 2020-11-15                    False                   False
# 2020-11-16                    False                   False
# 2020-11-17                    False                   False
# 2020-11-18                    False                   False
# 2020-11-19                    False                   False
#
#             addresses/min_10k_count
# Date
# 2011-08-17                    False
# 2011-08-18                    False
# 2011-08-19                    False
# 2011-08-20                    False
# 2011-08-21                    False
# ...                             ...
# 2020-11-15                    False
# 2020-11-16                    False
# 2020-11-17                    False
# 2020-11-18                    False
# 2020-11-19                    False
#
# [3383 rows x 102 columns]

# %%
# Delete Empty Row
df_dataset1 = df_dataset1.dropna()

# %%
# Re-Check Empty Cells
df_dataset1.isnull().sum()
# Out:
# Daily Return in USD                          0
# Log Price in USD                             0
# Volatility Daily Log Return in Percent 5D    0
# market/price_usd_close                       0
# market/price_drawdown_relative               0
#                                             ..
# addresses/min_1_count                        0
# addresses/min_10_count                       0
# addresses/min_100_count                      0
# addresses/min_1k_count                       0
# addresses/min_10k_count                      0
# Length: 102, dtype: int64

# %% [markdown]
# # Classification Setup

# %% [markdown]
# ## Create Data Set Copies for Trading Strategy

# %%
# Data Set Copy for Trading Extension
df_dataset1_copy = df_dataset1.copy()

# %% [markdown]
# ## Categorization - Data Set I.

# %%
# Categorization
# Class 1 for all Returns >= 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] >= 0, 'Class'] = 1
# Class 0 for all Returns < 0 USD
df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0
# Out:
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:1601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(new_indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\markus.gebele\Anaconda3\envs\btcpred\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-105-55abdf32f90e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dataset1.loc[df_dataset1['Daily Return in USD'] < 0, 'Class'] = 0

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Daily Return in USD  Log Price in USD  \
# Date
# 2011-08-18                 0.03              2.38
# 2011-08-19                -0.15              2.46
# 2011-08-20                 0.80              2.44
# 2011-08-21                -0.20              2.43
# 2011-08-22                -0.13              2.39
#
#             Volatility Daily Log Return in Percent 5D  market/price_usd_close  \
# Date
# 2011-08-18                                       3.29                   10.85
# 2011-08-19                                       3.72                   11.65
# 2011-08-20                                       3.77                   11.45
# 2011-08-21                                       3.71                   11.32
# 2011-08-22                                       4.15                   10.94
#
#             market/price_drawdown_relative  market/price_realized_usd  \
# Date
# 2011-08-18                           -0.66                       6.81
# 2011-08-19                           -0.63                       6.82
# 2011-08-20                           -0.64                       6.83
# 2011-08-21                           -0.64                       6.83
# 2011-08-22                           -0.66                       6.84
#
#             market/mvrv  mining/difficulty_latest  mining/hash_rate_mean  \
# Date
# 2011-08-18         1.60       7755426037811680.00      12915246321786.50
# 2011-08-19         1.65       7755426037811680.00      11678381642086.70
# 2011-08-20         1.68       7755426037811680.00      13035626696015.50
# 2011-08-21         1.67       7755426037811680.00      14115210625069.60
# 2011-08-22         1.63       7755426037811680.00      15232874647151.10
#
#             mining/revenue_sum  ...  addresses/new_non_zero_count  \
# Date                            ...
# 2011-08-18             7205.92  ...                      11917.00
# 2011-08-19             6557.77  ...                      14238.00
# 2011-08-20             7605.42  ...                      12994.00
# 2011-08-21             8005.69  ...                      14851.00
# 2011-08-22             8457.55  ...                      16250.00
#
#             addresses/non_zero_count  addresses/min_point_zero_1_count  \
# Date
# 2011-08-18                 429263.00                         208892.00
# 2011-08-19                 434988.00                         209553.00
# 2011-08-20                 440560.00                         210510.00
# 2011-08-21                 446963.00                         211300.00
# 2011-08-22                 454630.00                         212086.00
#
#             addresses/min_point_1_count  addresses/min_1_count  \
# Date
# 2011-08-18                    133657.00              104143.00
# 2011-08-19                    133993.00              104342.00
# 2011-08-20                    134628.00              104796.00
# 2011-08-21                    135057.00              105154.00
# 2011-08-22                    135509.00              105520.00
#
#             addresses/min_10_count  addresses/min_100_count  \
# Date
# 2011-08-18                65707.00                  4174.00
# 2011-08-19                65756.00                  4171.00
# 2011-08-20                65874.00                  4187.00
# 2011-08-21                66045.00                  4203.00
# 2011-08-22                66149.00                  4218.00
#
#             addresses/min_1k_count  addresses/min_10k_count  Class
# Date
# 2011-08-18                  624.00                    75.00   1.00
# 2011-08-19                  627.00                    75.00   0.00
# 2011-08-20                  625.00                    75.00   1.00
# 2011-08-21                  625.00                    75.00   0.00
# 2011-08-22                  627.00                    76.00   0.00
#
# [5 rows x 103 columns]

# %%
# Delete Original Target Column
df_dataset1 = df_dataset1.drop(['Daily Return in USD'], axis=1)

# %%
# Check Class Balance
df_dataset1['Class'].value_counts()
# Out:
# 1.00    1836
# 0.00    1546
# Name: Class, dtype: int64

# %%
# Data Set Head
df_dataset1.head()
# Out:
#             Log Price in USD  Volatility Daily Log Return in Percent 5D  \
# Date
# 2011-08-18              2.38                                       3.29
# 2011-08-19              2.46                                       3.72
# 2011-08-20              2.44                                       3.77
# 2011-08-21              2.43                                       3.71
# 2011-08-22              2.39                                       4.15
#
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2011-08-18                   10.85                           -0.66
# 2011-08-19                   11.65                           -0.63
# 2011-08-20                   11.45                           -0.64
# 2011-08-21                   11.32                           -0.64
# 2011-08-22                   10.94                           -0.66
#
#             market/price_realized_usd  market/mvrv  mining/difficulty_latest  \
# Date
# 2011-08-18                       6.81         1.60       7755426037811680.00
# 2011-08-19                       6.82         1.65       7755426037811680.00
# 2011-08-20                       6.83         1.68       7755426037811680.00
# 2011-08-21                       6.83         1.67       7755426037811680.00
# 2011-08-22                       6.84         1.63       7755426037811680.00
#
#             mining/hash_rate_mean  mining/revenue_sum  \
# Date
# 2011-08-18      12915246321786.50             7205.92
# 2011-08-19      11678381642086.70             6557.77
# 2011-08-20      13035626696015.50             7605.42
# 2011-08-21      14115210625069.60             8005.69
# 2011-08-22      15232874647151.10             8457.55
#
#             mining/marketcap_thermocap_ratio  ...  \
# Date                                          ...
# 2011-08-18                              0.00  ...
# 2011-08-19                              0.00  ...
# 2011-08-20                              0.00  ...
# 2011-08-21                              0.00  ...
# 2011-08-22                              0.00  ...
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2011-08-18                      11917.00                 429263.00
# 2011-08-19                      14238.00                 434988.00
# 2011-08-20                      12994.00                 440560.00
# 2011-08-21                      14851.00                 446963.00
# 2011-08-22                      16250.00                 454630.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2011-08-18                         208892.00                    133657.00
# 2011-08-19                         209553.00                    133993.00
# 2011-08-20                         210510.00                    134628.00
# 2011-08-21                         211300.00                    135057.00
# 2011-08-22                         212086.00                    135509.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2011-08-18              104143.00                65707.00
# 2011-08-19              104342.00                65756.00
# 2011-08-20              104796.00                65874.00
# 2011-08-21              105154.00                66045.00
# 2011-08-22              105520.00                66149.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2011-08-18                  4174.00                  624.00
# 2011-08-19                  4171.00                  627.00
# 2011-08-20                  4187.00                  625.00
# 2011-08-21                  4203.00                  625.00
# 2011-08-22                  4218.00                  627.00
#
#             addresses/min_10k_count  Class
# Date
# 2011-08-18                    75.00   1.00
# 2011-08-19                    75.00   0.00
# 2011-08-20                    75.00   1.00
# 2011-08-21                    75.00   0.00
# 2011-08-22                    76.00   0.00
#
# [5 rows x 102 columns]

# %% [markdown]
# # Model Preparation - Data Set I.

# %% [markdown]
# ## Train Test Split - Data Set I.

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
predictors = df_dataset1.drop(['Class'], axis=1).values.astype(np.float32)

# %%
# Setup of Categorized Target Variable
target = df_dataset1['Class'].astype(np.float32)

# %%
# Predictor Dimensions
predictors.shape
# Out:
# (3382, 101)

# %%
# Target Dimensions
target.shape
# Out:
# (3382,)

# %%
# Train-Test-Split Function to Create Training and Test Data Set
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state = 41, stratify=target)

# %%
# Dimensions of Predictors for Training
X_train.shape
# Out:
# (2367, 101)

# %%
# Dimensions of Target for Training
y_train.shape
# Out:
# (2367,)

# %%
# Number of Predictors
n_nodes = predictors.shape[1]
n_nodes
# Out:
# 101

# %% [markdown]
# ### Check of Class Balance

# %%
# Check Training Target of Class 0
y_train[y_train==0].count()
# Out:
# 1082

# %%
# Check Training Target of Class 1
y_train[y_train==1].count()
# Out:
# 1285

# %%
# Check Test Target of Class 0
y_test[y_test==0].count()
# Out:
# 464

# %%
# Check Test Target of Class 1
y_test[y_test==1].count()
# Out:
# 551

# %% [markdown]
# ## Feature Scaling - Data Set I.

# %%
# Instantiation of MinMaxScaler and StandardSacler
norm_scaler = MinMaxScaler()
#std_scaler = StandardScaler()

# %%
# Scaler Training and Transformation of Training Set
X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))

# %%
# Scaler Transformation of Test Set
X_test_scaled = norm_scaler.transform(X_test)

# %%
# Scaled Test Features
X_test_scaled
# Out:
# array([[0.85705435, 0.06179439, 0.269744  , ..., 0.84574175, 0.8498759 ,
#         0.6349207 ],
#        [0.44207895, 0.09661104, 0.00591413, ..., 0.49965206, 0.46836227,
#         0.5079366 ],
#        [0.4501204 , 0.03416266, 0.00637444, ..., 0.5354856 , 0.58560795,
#         0.49206352],
#        ...,
#        [0.6146527 , 0.10500881, 0.029161  , ..., 0.7281519 , 0.5552109 ,
#         0.5238097 ],
#        [0.6814573 , 0.02622648, 0.05387643, ..., 0.99568605, 0.68362284,
#         0.80952394],
#        [0.5146563 , 0.02781713, 0.01160031, ..., 0.8731562 , 0.6954094 ,
#         0.71428585]], dtype=float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
predictors_scaled = norm_scaler.transform(predictors)

# %% [markdown]
# # Classification Models - Data Set I.

# %%
# Function To Show Accuracy Mean and Accuracy Standard Deviation
def show_scores(scores):
    # Scores Series
    print('Scores:', scores)
    # Score Mean
    print('Mean:', np.mean(scores))
    # Score Standard Deviation
    print('Standard Deviation:', np.std(scores))

# %% [markdown]
# ## Logistic Regression - Data Set I.

# %%
# Instantiate Classifier - LogisticRegression
lreg = LogisticRegression(max_iter=1200)

# %%
# Train Classifier
lreg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1200)

# %%
# Prediction of Classes
y_pred = lreg.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = lreg.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.49509232, 0.63049705, 0.43246508, 0.45074446, 0.47964649,
#        0.62697195, 0.33297187, 0.68676481, 0.52662767, 0.27242517])

# %%
# Select Actual Classes
np.array(y_test[1:11])
# Out:
# array([0., 1., 1., 1., 0., 1., 1., 1., 0., 0.], dtype=float32)

# %%
# Train Accuracy
lreg.score(X_train_scaled, y_train)
# Out:
# 0.6261089987325729

# %%
# Test Accuracy
lreg.score(X_test_scaled, y_test)
# Out:
# 0.6305418719211823

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[230 234]
#  [141 410]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.55       464
#          1.0       0.64      0.74      0.69       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.62      0.62      1015
# weighted avg       0.63      0.63      0.62      1015

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# Plot of ROC curve
_ = plt.plot([0, 1], [0, 1])
_ = plt.plot(fpr, tpr)
_ = plt.xlabel('False Positive Rate')
_ = plt.ylabel('True Positive Rate')
_ = plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC Score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6798219538143815

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.62934783 0.66069425 0.70959204 0.68746471 0.67670102 0.66300819
#  0.6142429  0.64248193 0.67971091 0.62947294]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(lreg, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.58702065 0.6460177  0.64792899 0.61242604 0.62721893 0.6035503
#  0.62130178 0.59763314 0.60059172 0.59467456]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.58702065 0.6460177  0.64792899 0.61242604 0.62721893 0.6035503
#  0.62130178 0.59763314 0.60059172 0.59467456]
# Mean: 0.6138363791869578
# Standard Deviation: 0.020161315170477125

# %% [markdown]
# ## Random Forest Classifier - Data Set I.

# %%
# Instantiate Classifier - Random Forest
rfc = RandomForestClassifier(n_estimators=100, max_leaf_nodes=None, criterion='gini', max_depth=3, random_state=41)

# %%
# Train Classifier
rfc.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=3, random_state=41)

# %%
# Prediction of Classes
y_pred = rfc.predict(X_test_scaled)

# %%
# Prediction of Probabilities
y_pred_prob = rfc.predict_proba(X_test_scaled)[:,1]

# %%
# Select Predicted Probabilities
y_pred_prob[1:11]
# Out:
# array([0.43138482, 0.614885  , 0.51028735, 0.46622439, 0.46339144,
#        0.64520753, 0.43367756, 0.74828652, 0.45015291, 0.45858682])

# %%
# Train Accuracy
rfc.score(X_train_scaled, y_train)
# Out:
# 0.63709336713139

# %%
# Test Accuracy
rfc.score(X_test_scaled, y_test)
# Out:
# 0.6305418719211823

# %%
# Output of Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[245 219]
#  [156 395]]

# %%
# Output of Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.53      0.57       464
#          1.0       0.64      0.72      0.68       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.62      0.62      1015
# weighted avg       0.63      0.63      0.63      1015

# %%
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# %%
# 10-fold Cross Validation including Stratification
skf = StratifiedKFold(shuffle=True, n_splits=10)

# %%
# Compute and print AUC score
print("AUC: {}".format(roc_auc_score(y_test, y_pred_prob)))
# Out:
# AUC: 0.6718661993866951

# %%
# Cross-Validation for AUC scores
cv_auc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='roc_auc')

# %%
# Print List of AUC scores
print("AUC scores computed using 10-fold cross-validation: {}".format(cv_auc))
# Out:
# AUC scores computed using 10-fold cross-validation: [0.6316094  0.66974053 0.65817335 0.65051525 0.63876341 0.64165726
#  0.68857747 0.64378636 0.67805394 0.64304601]

# %%
# Cross-Validation for Accuracy Scores
cv_acc = cross_val_score(rfc, predictors_scaled, target, cv=skf, scoring='accuracy')

# %%
# Print List of Accuracy Scores
print("Accuracy scores computed using 10-fold cross-validation: {}".format(cv_acc))
# Out:
# Accuracy scores computed using 10-fold cross-validation: [0.61946903 0.61061947 0.63313609 0.60650888 0.64792899 0.63609467
#  0.5887574  0.6035503  0.62721893 0.63017751]

# %%
# Accuracy Results - Mean and Standard Deviation
show_scores(cv_acc)
# Out:
# Scores: [0.61946903 0.61061947 0.63313609 0.60650888 0.64792899 0.63609467
#  0.5887574  0.6035503  0.62721893 0.63017751]
# Mean: 0.620346127664031
# Standard Deviation: 0.016979696106768003

# %% [markdown]
# # Trading Strategy - Data Set I

# %% [markdown]
# ## Trading Strategy in Combination with Logistic Regression

# %%
# Create Lists To Store All Calculated Values For Every Variable of Every Run
# Specified Period
# Threshold 0.5
spec_list_05_total = []
spec_list_05_profit = []
spec_list_05_loss = []
spec_list_05_trans = []
spec_list_05_acc = []
spec_list_05_preds_corr = []
spec_list_05_preds = []
# Threshold 0.6
spec_list_06_total = []
spec_list_06_profit = []
spec_list_06_loss = []
spec_list_06_trans = []
spec_list_06_acc = []
spec_list_06_preds_corr = []
spec_list_06_preds = []
# Threshold 0.7
spec_list_07_total = []
spec_list_07_profit = []
spec_list_07_loss = []
spec_list_07_trans = []
spec_list_07_acc = []
spec_list_07_preds_corr = []
spec_list_07_preds = []
# Threshold 0.8
spec_list_08_total = []
spec_list_08_profit = []
spec_list_08_loss = []
spec_list_08_trans = []
spec_list_08_acc = []
spec_list_08_preds_corr = []
spec_list_08_preds = []

# Entire Period
# Threshold 0.5
list_05_total = []
list_05_profit = []
list_05_loss = []
list_05_trans = []
list_05_acc = []
list_05_preds_corr = []
list_05_preds = []
# Threshold 0.6
list_06_total = []
list_06_profit = []
list_06_loss = []
list_06_trans = []
list_06_acc = []
list_06_preds_corr = []
list_06_preds = []
# Threshold 0.7
list_07_total = []
list_07_profit = []
list_07_loss = []
list_07_trans = []
list_07_acc = []
list_07_preds_corr = []
list_07_preds = []
# Threshold 0.8
list_08_total = []
list_08_profit = []
list_08_loss = []
list_08_trans = []
list_08_acc = []
list_08_preds_corr = []
list_08_preds = []

# %%
target
# Out:
# Date
# 2011-08-18   1.00
# 2011-08-19   0.00
# 2011-08-20   1.00
# 2011-08-21   0.00
# 2011-08-22   0.00
#              ...
# 2020-11-15   0.00
# 2020-11-16   0.00
# 2020-11-17   1.00
# 2020-11-18   1.00
# 2020-11-19   1.00
# Name: Class, Length: 3382, dtype: float32

# %%
predictors
# Out:
# array([[2.3838902e+00, 3.2931430e+00, 1.0847017e+01, ..., 4.1740000e+03,
#         6.2400000e+02, 7.5000000e+01],
#        [2.4553063e+00, 3.7208679e+00, 1.1650000e+01, ..., 4.1710000e+03,
#         6.2700000e+02, 7.5000000e+01],
#        [2.4380770e+00, 3.7733192e+00, 1.1450998e+01, ..., 4.1870000e+03,
#         6.2500000e+02, 7.5000000e+01],
#        ...,
#        [9.7794752e+00, 3.2141380e+00, 1.7667381e+04, ..., 1.6238000e+04,
#         2.2320000e+03, 1.1100000e+02],
#        [9.7876406e+00, 3.1547880e+00, 1.7812232e+04, ..., 1.6242000e+04,
#         2.2280000e+03, 1.1300000e+02],
#        [9.7868166e+00, 2.8492196e+00, 1.7797553e+04, ..., 1.6199000e+04,
#         2.2290000e+03, 1.1200000e+02]], dtype=float32)

# %%
for x in df_dataset1.columns:
    print(x)
# Out:
# Log Price in USD
# Volatility Daily Log Return in Percent 5D
# market/price_usd_close
# market/price_drawdown_relative
# market/price_realized_usd
# market/mvrv
# mining/difficulty_latest
# mining/hash_rate_mean
# mining/revenue_sum
# mining/marketcap_thermocap_ratio
# blockchain/block_count
# blockchain/block_interval_mean
# blockchain/block_size_sum
# distribution/balance_1pct_holders
# distribution/gini
# distribution/herfindahl
# fees/volume_sum
# fees/volume_mean
# fees/fee_ratio_multiple
# blockchain/utxo_created_count
# blockchain/utxo_spent_count
# blockchain/utxo_created_value_sum
# blockchain/utxo_spent_value_sum
# blockchain/utxo_profit_relative
# blockchain/utxo_profit_count
# blockchain/utxo_loss_count
# supply/current
# supply/profit_relative
# supply/profit_sum
# supply/loss_sum
# supply/active_more_1y_percent
# supply/active_more_2y_percent
# supply/active_more_3y_percent
# supply/active_more_5y_percent
# supply/active_24h
# supply/active_1d_1w
# supply/active_1w_1m
# supply/active_1m_3m
# supply/active_3m_6m
# supply/active_6m_12m
# supply/active_1y_2y
# supply/active_2y_3y
# supply/active_3y_5y
# supply/active_5y_7y
# supply/active_7y_10y
# supply/active_more_10y
# supply/issued
# supply/inflation_rate
# transactions/count
# transactions/size_sum
# transactions/transfers_volume_sum
# transactions/transfers_volume_adjusted_sum
# transactions/transfers_volume_to_exchanges_sum
# transactions/transfers_volume_from_exchanges_sum
# transactions/transfers_to_exchanges_count
# transactions/transfers_from_exchanges_count
# distribution/balance_exchanges
# transactions/transfers_volume_exchanges_net
# indicators/sopr_adjusted
# indicators/nvt
# indicators/velocity
# indicators/cdd
# indicators/reserve_risk
# indicators/average_dormancy
# indicators/liveliness
# indicators/asol
# indicators/sol_1h
# indicators/sol_1h_24h
# indicators/sol_1d_1w
# indicators/sol_1w_1m
# indicators/sol_1m_3m
# indicators/sol_3m_6m
# indicators/sol_6m_12m
# indicators/sol_1y_2y
# indicators/sol_2y_3y
# indicators/sol_3y_5y
# indicators/sol_5y_7y
# indicators/sol_7y_10y
# indicators/net_unrealized_profit_loss
# indicators/unrealized_profit
# indicators/unrealized_loss
# indicators/net_realized_profit_loss
# indicators/realized_profit
# indicators/realized_loss
# indicators/nupl_more_155
# indicators/nupl_less_155
# indicators/puell_multiple
# indicators/stock_to_flow_deflection
# indicators/difficulty_ribbon_compression
# addresses/active_count
# addresses/sending_count
# addresses/receiving_count
# addresses/new_non_zero_count
# addresses/non_zero_count
# addresses/min_point_zero_1_count
# addresses/min_point_1_count
# addresses/min_1_count
# addresses/min_10_count
# addresses/min_100_count
# addresses/min_1k_count
# addresses/min_10k_count
# Class

# %%
df_dataset1_copy[['Daily Return in USD']]
# Out:
#             Daily Return in USD
# Date
# 2011-08-18                 0.03
# 2011-08-19                -0.15
# 2011-08-20                 0.80
# 2011-08-21                -0.20
# 2011-08-22                -0.13
# ...                         ...
# 2020-11-15              -236.06
# 2020-11-16              -113.35
# 2020-11-17               747.51
# 2020-11-18               957.77
# 2020-11-19               144.85
#
# [3382 rows x 1 columns]

# %%
df_dataset1_copy["percentage_daily_return"] = df_dataset1_copy["Daily Return in USD"]/df_dataset1_copy["market/price_usd_close"]
df_dataset1_copy["percentage_daily_return"]
# Out:
# Date
# 2011-08-18    0.00
# 2011-08-19   -0.01
# 2011-08-20    0.07
# 2011-08-21   -0.02
# 2011-08-22   -0.01
#               ...
# 2020-11-15   -0.01
# 2020-11-16   -0.01
# 2020-11-17    0.04
# 2020-11-18    0.05
# 2020-11-19    0.01
# Name: percentage_daily_return, Length: 3382, dtype: float64

# %%
predictors
# Out:
# array([[2.3838902e+00, 3.2931430e+00, 1.0847017e+01, ..., 4.1740000e+03,
#         6.2400000e+02, 7.5000000e+01],
#        [2.4553063e+00, 3.7208679e+00, 1.1650000e+01, ..., 4.1710000e+03,
#         6.2700000e+02, 7.5000000e+01],
#        [2.4380770e+00, 3.7733192e+00, 1.1450998e+01, ..., 4.1870000e+03,
#         6.2500000e+02, 7.5000000e+01],
#        ...,
#        [9.7794752e+00, 3.2141380e+00, 1.7667381e+04, ..., 1.6238000e+04,
#         2.2320000e+03, 1.1100000e+02],
#        [9.7876406e+00, 3.1547880e+00, 1.7812232e+04, ..., 1.6242000e+04,
#         2.2280000e+03, 1.1300000e+02],
#        [9.7868166e+00, 2.8492196e+00, 1.7797553e+04, ..., 1.6199000e+04,
#         2.2290000e+03, 1.1200000e+02]], dtype=float32)

# %%
einsatz = 1000
percentlist=[]
zinseszins=[]
profitpercent=[]


# For Loop to Simulate K-fold Cross Validation
for x in range(1, 20):
    
    # Display Number of Runs
    print("Run:", x)
    
    # Split Data into Training and Testing
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, stratify=target)
    
    # Amount of Columns
    n_nodes = predictors.shape[1]

    # Instantiation of MinMaxScaler
    norm_scaler = MinMaxScaler()
    
    # Training and Application of Feature Scaler on Training Data of Predictors
    X_train_scaled = pd.DataFrame(norm_scaler.fit_transform(X_train))
    
    # Application of Feature Scaler on Test Data of Predictors
    X_test_scaled = norm_scaler.transform(X_test)
    
    # Instantiate Classifier Logistic Regression
    lreg = LogisticRegression(max_iter=12000) 
    
    # Train Classifier
    lreg.fit(X_train_scaled, y_train)
    
    # Prediction of Classes
    y_pred = lreg.predict(X_test_scaled)
    
    # Display Confusion Matrix and Classification Report
    print(confusion_matrix(y_test, y_pred))
#     print(classification_report(y_test, y_pred))

    # Prediction of Probabilities
    y_pred_prob = lreg.predict_proba(X_test_scaled)[:,1]

    # Create Data Frame of Actual Values - y_test
    df_y_test = pd.DataFrame(y_test)
    
    # Add Predicted Probabilities to Data Frame
    df_y_test["y_pred_prob"] = y_pred_prob
    
    # Add Predicted Classes (0 or 1) to Data Frame to Cross-Check Predicted Probabilities 
    df_y_test["y_pred"] =  y_pred
    
    # Select Actual Daily Returns in USD from the Data Set Copy
    df_dataset1_copy_dailyreturns=df_dataset1_copy[['Daily Return in USD']]
    
    # Merge Predictions and Daily Returns Data Frame on the Column "Date"
    df_y_test_withdailyreturns = pd.merge(df_y_test, df_dataset1_copy_dailyreturns, on='Date')
    
    df_dataset1_copy_percentage=df_dataset1_copy[['percentage_daily_return']]
    df_y_test_withdailyreturns = pd.merge(df_y_test_withdailyreturns, df_dataset1_copy_percentage, on='Date')
    
    # Add Bitcoin Price in USD
    df_y_test_withdailyreturns = pd.merge(df_y_test_withdailyreturns, df_dataset1['market/price_usd_close'] , on='Date')
    
    df_y_test_withdailyreturns['y_pred_prob_bereinigt'] = np.where(df_y_test_withdailyreturns['y_pred_prob']<0.5, 1-df_y_test_withdailyreturns['y_pred_prob'],df_y_test_withdailyreturns['y_pred_prob'])

    df_y_test_withdailyreturns["Einsatz"]=einsatz*df_y_test_withdailyreturns["y_pred_prob_bereinigt"]#**2
    
    # Add and Calculate Transaction Costs based on the Bitcoin Price in USD
    df_y_test_withdailyreturns['Transaction Costs in USD'] = df_y_test_withdailyreturns['Einsatz']*0.0003*2
    
    # Create List of Multiple Thresholds 
    # A Threshold of 0.7 means that only predicted probabilites with more than 0.7 or less than 0.3 are considered further
    list_thresholdcalc = [0.5, 0.6, 0.7, 0.8]
    
    # Try and Except Block to Address Cases in Which a Data Frame does NOT Contain Any Values Because No predicted Probability Meets the Threshold Requirements
    try:
        
        # For Loop Over List
        for thresholdcalc in list_thresholdcalc:
            
            # Creation of a Data Frame Containing Only Probability Predictions Which Meet the Threshold Requirements 
            df_y_test_probaall = df_y_test.loc[(df_y_test['y_pred_prob'] > thresholdcalc) | (df_y_test['y_pred_prob'] < 1-thresholdcalc)]
            
            # Calculation Of Accuracy Only for the Data Subset Meeting Threshold Requirements
            acc_calc = len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]) / len(df_y_test_probaall)
 
            print("Threshold of:", thresholdcalc)
            print(classification_report(df_y_test_probaall["Class"], df_y_test_probaall["y_pred"]))

            # Creation of Another Data Frame including Returns and Transaction Costs Only For Probability Predicitons that Meet the Threshold Requirements
            df_y_test_probaall_withdailyreturns = df_y_test_withdailyreturns.loc[(df_y_test_withdailyreturns['y_pred_prob'] > thresholdcalc) | (df_y_test_withdailyreturns['y_pred_prob'] < 1-thresholdcalc)]
            
            # Trading Assumption: Bet Amount = 1 Bitcoin for Each Prediction
            # Select Daily Returns Only From True Predictions Where Predicted Class equals Actual Class. It does not matter whether Daily Returns are Positive or Negative as Short-Selling Option Allows To Profit From Falling Prices
            profit = df_y_test_probaall_withdailyreturns["percentage_daily_return"][df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()
            
            # Select  Daily Returns Only From False Predictions Where Predicted Class equals Actual Class
            loss = df_y_test_probaall_withdailyreturns["percentage_daily_return"][df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred']].abs().sum()
            
            print( "{:.2f}%".format((profit-loss)*100) )
            
            if thresholdcalc == 0.5:
                percentlist.append( int((profit-loss)*100) )
            
            
            loss = loss * einsatz
            profit = profit * einsatz
            
            # Calculation of Transaction Costs based On BTC Value in USD. Each Future Trade considers Transaction Costs twice, becauase of Buying and Selling the Future
            transaction_costs = df_y_test_probaall_withdailyreturns['Transaction Costs in USD'].sum()
            
            # Calculation of Total Profit Considering Profit, Loss and Transaction Costs
            total=profit-loss-transaction_costs
            
            # In addition, the same setting with different time horizon
            currentpreds_all = len(df_y_test_probaall_withdailyreturns[df_y_test_probaall_withdailyreturns.index >= '2019-09-09' ])
            
            # Analog to Profit Calculation Above
            currentpreds_winning_total = df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])].abs().sum()
            # Analog to Loss Calculation Above 
            currentpreds_loosing_total = df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred'])].abs().sum()
            # Analog to Calculation of Transaction Costs Above
            currentpreds_transaction_costs = df_y_test_probaall_withdailyreturns['Transaction Costs in USD'][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] != df_y_test_probaall_withdailyreturns['y_pred'])].sum()
            
            # Analog to Calculation of Total Profit
            currentpreds_total=currentpreds_winning_total-currentpreds_loosing_total-currentpreds_transaction_costs
            
            # Condition
            # In Case the Shorter Time Horizon Does Not Include any Sample -> Empyt Output
            if currentpreds_all == 0:
                currentpreds_all = '-'
                current_acc_calc = '-'
            
            # Otherwise Calculation of Accuracy analog to theeins Accuracy Calculation for the Entire Period
            else:
                current_acc_calc = (len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])]))/currentpreds_all
            
            #Display of Threshold, Total Profit, Profit, Loss, Transaction Costs, Accuracy and Correct Number of Predictions Both for the Specified Time Horizon and the Entire Time
            print("Specified Period:")
            print("Total Return in Specified Period:", int(currentpreds_total), "/ Profit: ", int(currentpreds_winning_total), "/ Loss: ", int(currentpreds_loosing_total), "/ Transaction Costs: ", int(currentpreds_transaction_costs),"/ Calculated Accuracy", current_acc_calc, "/ #Correct Predictions:", (len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])), "of", currentpreds_all)
            print()
            print("Entire Period:")
            print("einsatz", int(df_y_test_withdailyreturns["Einsatz"].sum()),"Total Return:", int(total), "/ Profit: ", int(profit), "/ Loss: ", int(loss), "/ Transaction Costs: ", int(transaction_costs), "/ Calculated Accuracy", round(acc_calc, 2), "/ #Correct Predictions:", len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]),  "Of", len(df_y_test_probaall))
            print("einsatz/bet", df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall), "Total Return / bet", int(total) / len(df_y_test_probaall),"/ Transaction Costs / bet ", int(transaction_costs) / len(df_y_test_probaall), "/ Calculated Accuracy", round(acc_calc, 2))
            print("profit in % per bet: {:.2f}".format( 100*(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ))
            if thresholdcalc == 0.5:
                profitpercent.append( 100*(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) )
            
            print("einsatz * 1+profit% ^ # wetten {:.2f}".format( einsatz*(1+(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ) ** len(df_y_test_probaall) ) )
            if thresholdcalc == 0.5:
                zinseszins.append( einsatz*(1+(int(total) / len(df_y_test_probaall)) / (df_y_test_withdailyreturns["Einsatz"].sum() / len(df_y_test_probaall) ) ) ** len(df_y_test_probaall) )
            print()
            print()
            
            # Store All Calculated Values For Every Variable of Every Run
            # Specified Period
            # Threshold = 0.5
            if thresholdcalc == 0.5:
                spec_list_05_total.append(currentpreds_total) 
                spec_list_05_profit.append(currentpreds_winning_total) 
                spec_list_05_loss.append(currentpreds_loosing_total)
                spec_list_05_trans.append(currentpreds_transaction_costs)
                spec_list_05_acc.append(current_acc_calc)
                spec_list_05_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_05_preds.append(currentpreds_all)
            # Threshold = 0.6
            if thresholdcalc == 0.6:
                spec_list_06_total.append(currentpreds_total) 
                spec_list_06_profit.append(currentpreds_winning_total) 
                spec_list_06_loss.append(currentpreds_loosing_total)
                spec_list_06_trans.append(currentpreds_transaction_costs)
                spec_list_06_acc.append(current_acc_calc)
                spec_list_06_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_06_preds.append(currentpreds_all)
            # Threshold = 0.7
            if thresholdcalc == 0.7:
                spec_list_07_total.append(currentpreds_total) 
                spec_list_07_profit.append(currentpreds_winning_total) 
                spec_list_07_loss.append(currentpreds_loosing_total)
                spec_list_07_trans.append(currentpreds_transaction_costs)
                spec_list_07_acc.append(current_acc_calc)
                spec_list_07_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_07_preds.append(currentpreds_all)
            # Threshold = 0.8
            if thresholdcalc == 0.8:
                spec_list_08_total.append(currentpreds_total) 
                spec_list_08_profit.append(currentpreds_winning_total) 
                spec_list_08_loss.append(currentpreds_loosing_total)
                spec_list_08_trans.append(currentpreds_transaction_costs)
                spec_list_08_acc.append(current_acc_calc)
                spec_list_08_preds_corr.append((len(df_y_test_probaall_withdailyreturns["Daily Return in USD"][(df_y_test_probaall_withdailyreturns.index >= '2019-09-09') & (df_y_test_probaall_withdailyreturns['Class'] == df_y_test_probaall_withdailyreturns['y_pred'])])))
                spec_list_08_preds.append(currentpreds_all)  
          
            # Entire Period
            # Threshold = 0.5
            if thresholdcalc == 0.5:
                list_05_total.append(total) 
                list_05_profit.append(profit) 
                list_05_loss.append(loss)
                list_05_trans.append(transaction_costs)
                list_05_acc.append(acc_calc)
                list_05_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_05_preds.append(len(df_y_test_probaall))    
            # Threshold = 0.6
            if thresholdcalc == 0.6:
                list_06_total.append(total) 
                list_06_profit.append(profit) 
                list_06_loss.append(loss)
                list_06_trans.append(transaction_costs)
                list_06_acc.append(acc_calc)
                list_06_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_06_preds.append(len(df_y_test_probaall))        
            # Threshold = 0.7
            if thresholdcalc == 0.7:
                list_07_total.append(total) 
                list_07_profit.append(profit) 
                list_07_loss.append(loss)
                list_07_trans.append(transaction_costs)
                list_07_acc.append(acc_calc)
                list_07_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_07_preds.append(len(df_y_test_probaall))
            # Threshold = 0.8
            if thresholdcalc == 0.8:
                list_08_total.append(total) 
                list_08_profit.append(profit) 
                list_08_loss.append(loss)
                list_08_trans.append(transaction_costs)
                list_08_acc.append(acc_calc)
                list_08_preds_corr.append(len(df_y_test_probaall[df_y_test_probaall['Class'] == df_y_test_probaall['y_pred']]))
                list_08_preds.append(len(df_y_test_probaall)) 
            
    except:
        print("error")
    # Display Empty Rows Between Each Run
    print()
    print()
# Out:
# Run: 1
# [[220 244]
#  [152 399]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.47      0.53       464
#          1.0       0.62      0.72      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.60      1015
#
# 1074.48%
# Specified Period:
# Total Return in Specified Period: 9575 / Profit:  17340 / Loss:  7746 / Transaction Costs:  18 / Calculated Accuracy 0.5895522388059702 / #Correct Predictions: 79 of 134
#
# Entire Period:
# einsatz 622915 Total Return: 10371 / Profit:  19391 / Loss:  8646 / Transaction Costs:  373 / Calculated Accuracy 0.61 / #Correct Predictions: 619 Of 1015
# einsatz/bet 613.7093791131125 Total Return / bet 10.217733990147783 / Transaction Costs / bet  0.367487684729064 / Calculated Accuracy 0.61
# profit in % per bet: 1.66
# einsatz * 1+profit% ^ # wetten 18996102804.72
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.42      0.50       212
#          1.0       0.66      0.81      0.73       298
#
#     accuracy                           0.65       510
#    macro avg       0.64      0.62      0.61       510
# weighted avg       0.64      0.65      0.63       510
#
# 771.44%
# Specified Period:
# Total Return in Specified Period: 6392 / Profit:  8471 / Loss:  2073 / Transaction Costs:  6 / Calculated Accuracy 0.6521739130434783 / #Correct Predictions: 30 of 46
#
# Entire Period:
# einsatz 622915 Total Return: 7506 / Profit:  11841 / Loss:  4127 / Transaction Costs:  207 / Calculated Accuracy 0.65 / #Correct Predictions: 331 Of 510
# einsatz/bet 1221.401999607469 Total Return / bet 14.717647058823529 / Transaction Costs / bet  0.40588235294117647 / Calculated Accuracy 0.65
# profit in % per bet: 1.20
# einsatz * 1+profit% ^ # wetten 449738.46
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.53      0.62        66
#          1.0       0.74      0.88      0.81       102
#
#     accuracy                           0.74       168
#    macro avg       0.74      0.71      0.71       168
# weighted avg       0.74      0.74      0.73       168
#
# 461.16%
# Specified Period:
# Total Return in Specified Period: 516 / Profit:  1203 / Loss:  686 / Transaction Costs:  0 / Calculated Accuracy 0.8333333333333334 / #Correct Predictions: 5 of 6
#
# Entire Period:
# einsatz 622915 Total Return: 4536 / Profit:  5550 / Loss:  938 / Transaction Costs:  75 / Calculated Accuracy 0.74 / #Correct Predictions: 125 Of 168
# einsatz/bet 3707.827498808388 Total Return / bet 27.0 / Transaction Costs / bet  0.44642857142857145 / Calculated Accuracy 0.74
# profit in % per bet: 0.73
# einsatz * 1+profit% ^ # wetten 3383.55
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.50      0.55         6
#          1.0       0.80      0.86      0.83        14
#
#     accuracy                           0.75        20
#    macro avg       0.70      0.68      0.69        20
# weighted avg       0.74      0.75      0.74        20
#
# 73.46%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 622915 Total Return: 724 / Profit:  902 / Loss:  167 / Transaction Costs:  10 / Calculated Accuracy 0.75 / #Correct Predictions: 15 Of 20
# einsatz/bet 31145.75098999046 Total Return / bet 36.2 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.75
# profit in % per bet: 0.12
# einsatz * 1+profit% ^ # wetten 1023.50
#
#
#
#
# Run: 2
# [[229 235]
#  [154 397]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.49      0.54       464
#          1.0       0.63      0.72      0.67       551
#
#     accuracy                           0.62      1015
#    macro avg       0.61      0.61      0.61      1015
# weighted avg       0.61      0.62      0.61      1015
#
# 1316.37%
# Specified Period:
# Total Return in Specified Period: 10321 / Profit:  16263 / Loss:  5925 / Transaction Costs:  17 / Calculated Accuracy 0.5420560747663551 / #Correct Predictions: 58 of 107
#
# Entire Period:
# einsatz 617146 Total Return: 12793 / Profit:  21865 / Loss:  8701 / Transaction Costs:  370 / Calculated Accuracy 0.62 / #Correct Predictions: 626 Of 1015
# einsatz/bet 608.0263008654913 Total Return / bet 12.603940886699508 / Transaction Costs / bet  0.3645320197044335 / Calculated Accuracy 0.62
# profit in % per bet: 2.07
# einsatz * 1+profit% ^ # wetten 1107201813306.54
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.44      0.55       212
#          1.0       0.66      0.86      0.75       263
#
#     accuracy                           0.67       475
#    macro avg       0.69      0.65      0.65       475
# weighted avg       0.69      0.67      0.66       475
#
# 978.12%
# Specified Period:
# Total Return in Specified Period: 7102 / Profit:  9222 / Loss:  2114 / Transaction Costs:  5 / Calculated Accuracy 0.631578947368421 / #Correct Predictions: 24 of 38
#
# Entire Period:
# einsatz 617146 Total Return: 9588 / Profit:  13441 / Loss:  3660 / Transaction Costs:  192 / Calculated Accuracy 0.67 / #Correct Predictions: 320 Of 475
# einsatz/bet 1299.2562007967865 Total Return / bet 20.185263157894738 / Transaction Costs / bet  0.40421052631578946 / Calculated Accuracy 0.67
# profit in % per bet: 1.55
# einsatz * 1+profit% ^ # wetten 1514542.88
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.53      0.63        59
#          1.0       0.72      0.89      0.80        82
#
#     accuracy                           0.74       141
#    macro avg       0.75      0.71      0.71       141
# weighted avg       0.74      0.74      0.73       141
#
# 530.28%
# Specified Period:
# Total Return in Specified Period: 6079 / Profit:  6429 / Loss:  348 / Transaction Costs:  1 / Calculated Accuracy 0.8461538461538461 / #Correct Predictions: 11 of 13
#
# Entire Period:
# einsatz 617146 Total Return: 5239 / Profit:  6039 / Loss:  736 / Transaction Costs:  63 / Calculated Accuracy 0.74 / #Correct Predictions: 104 Of 141
# einsatz/bet 4376.926917577827 Total Return / bet 37.156028368794324 / Transaction Costs / bet  0.44680851063829785 / Calculated Accuracy 0.74
# profit in % per bet: 0.85
# einsatz * 1+profit% ^ # wetten 3293.35
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        10
#          1.0       0.86      0.86      0.86         7
#
#     accuracy                           0.88        17
#    macro avg       0.88      0.88      0.88        17
# weighted avg       0.88      0.88      0.88        17
#
# 185.30%
# Specified Period:
# Total Return in Specified Period: 2705 / Profit:  3055 / Loss:  348 / Transaction Costs:  1 / Calculated Accuracy 0.5 / #Correct Predictions: 2 of 4
#
# Entire Period:
# einsatz 617146 Total Return: 1844 / Profit:  1902 / Loss:  49 / Transaction Costs:  8 / Calculated Accuracy 0.88 / #Correct Predictions: 15 Of 17
# einsatz/bet 36302.74678696904 Total Return / bet 108.47058823529412 / Transaction Costs / bet  0.47058823529411764 / Calculated Accuracy 0.88
# profit in % per bet: 0.30
# einsatz * 1+profit% ^ # wetten 1052.03
#
#
#
#
# Run: 3
# [[207 257]
#  [147 404]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.45      0.51       464
#          1.0       0.61      0.73      0.67       551
#
#     accuracy                           0.60      1015
#    macro avg       0.60      0.59      0.59      1015
# weighted avg       0.60      0.60      0.59      1015
#
# 921.83%
# Specified Period:
# Total Return in Specified Period: 6192 / Profit:  15301 / Loss:  9087 / Transaction Costs:  20 / Calculated Accuracy 0.5413533834586466 / #Correct Predictions: 72 of 133
#
# Entire Period:
# einsatz 615944 Total Return: 8848 / Profit:  18281 / Loss:  9063 / Transaction Costs:  369 / Calculated Accuracy 0.6 / #Correct Predictions: 611 Of 1015
# einsatz/bet 606.84175658764 Total Return / bet 8.717241379310344 / Transaction Costs / bet  0.36354679802955664 / Calculated Accuracy 0.6
# profit in % per bet: 1.44
# einsatz * 1+profit% ^ # wetten 1937049041.30
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.46      0.56       205
#          1.0       0.68      0.85      0.76       280
#
#     accuracy                           0.69       485
#    macro avg       0.69      0.66      0.66       485
# weighted avg       0.69      0.69      0.67       485
#
# 768.89%
# Specified Period:
# Total Return in Specified Period: 5769 / Profit:  9610 / Loss:  3834 / Transaction Costs:  6 / Calculated Accuracy 0.6458333333333334 / #Correct Predictions: 31 of 48
#
# Entire Period:
# einsatz 615944 Total Return: 7493 / Profit:  11262 / Loss:  3573 / Transaction Costs:  195 / Calculated Accuracy 0.69 / #Correct Predictions: 333 Of 485
# einsatz/bet 1269.9884184256796 Total Return / bet 15.449484536082474 / Transaction Costs / bet  0.4020618556701031 / Calculated Accuracy 0.69
# profit in % per bet: 1.22
# einsatz * 1+profit% ^ # wetten 352290.09
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.42      0.53        38
#          1.0       0.80      0.94      0.86        94
#
#     accuracy                           0.79       132
#    macro avg       0.76      0.68      0.70       132
# weighted avg       0.78      0.79      0.77       132
#
# 297.58%
# Specified Period:
# Total Return in Specified Period: 1398 / Profit:  2129 / Loss:  729 / Transaction Costs:  0 / Calculated Accuracy 0.7142857142857143 / #Correct Predictions: 5 of 7
#
# Entire Period:
# einsatz 615944 Total Return: 2916 / Profit:  3559 / Loss:  583 / Transaction Costs:  59 / Calculated Accuracy 0.79 / #Correct Predictions: 104 Of 132
# einsatz/bet 4666.245325276172 Total Return / bet 22.09090909090909 / Transaction Costs / bet  0.44696969696969696 / Calculated Accuracy 0.79
# profit in % per bet: 0.47
# einsatz * 1+profit% ^ # wetten 1865.33
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.33      0.44         6
#          1.0       0.73      0.92      0.81        12
#
#     accuracy                           0.72        18
#    macro avg       0.70      0.62      0.63        18
# weighted avg       0.71      0.72      0.69        18
# 49.41%
# Specified Period:
# Total Return in Specified Period: 593 / Profit:  637 / Loss:  43 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 615944 Total Return: 485 / Profit:  561 / Loss:  67 / Transaction Costs:  9 / Calculated Accuracy 0.72 / #Correct Predictions: 13 Of 18
# einsatz/bet 34219.13238535859 Total Return / bet 26.944444444444443 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.72
# profit in % per bet: 0.08
# einsatz * 1+profit% ^ # wetten 1014.27
#
#
#
#
# Run: 4
# [[228 236]
#  [151 400]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.49      0.54       464
#          1.0       0.63      0.73      0.67       551
#
#     accuracy                           0.62      1015
#    macro avg       0.62      0.61      0.61      1015
# weighted avg       0.62      0.62      0.61      1015
#
# 1174.26%
# Specified Period:
# Total Return in Specified Period: 7195 / Profit:  14380 / Loss:  7168 / Transaction Costs:  16 / Calculated Accuracy 0.5663716814159292 / #Correct Predictions: 64 of 113
#
# Entire Period:
# einsatz 612070 Total Return: 11375 / Profit:  20081 / Loss:  8338 / Transaction Costs:  367 / Calculated Accuracy 0.62 / #Correct Predictions: 628 Of 1015
# einsatz/bet 603.0253812172053 Total Return / bet 11.206896551724139 / Transaction Costs / bet  0.361576354679803 / Calculated Accuracy 0.62
# profit in % per bet: 1.86
# einsatz * 1+profit% ^ # wetten 130917750883.23
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.49      0.59       185
#          1.0       0.72      0.89      0.80       278
#
#     accuracy                           0.73       463
#    macro avg       0.74      0.69      0.70       463
# weighted avg       0.73      0.73      0.72       463
#
# 952.86%
# Specified Period:
# Total Return in Specified Period: 7889 / Profit:  8796 / Loss:  903 / Transaction Costs:  3 / Calculated Accuracy 0.7714285714285715 / #Correct Predictions: 27 of 35
#
# Entire Period:
# einsatz 612070 Total Return: 9342 / Profit:  12350 / Loss:  2822 / Transaction Costs:  186 / Calculated Accuracy 0.73 / #Correct Predictions: 338 Of 463
# einsatz/bet 1321.9670884135278 Total Return / bet 20.177105831533478 / Transaction Costs / bet  0.4017278617710583 / Calculated Accuracy 0.73
# profit in % per bet: 1.53
# einsatz * 1+profit% ^ # wetten 1111376.54
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.50      0.60        36
#          1.0       0.81      0.93      0.87        83
#
#     accuracy                           0.80       119
#    macro avg       0.78      0.71      0.73       119
# weighted avg       0.79      0.80      0.78       119
#
# 398.31%
# Specified Period:
# Total Return in Specified Period: 603 / Profit:  799 / Loss:  195 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 612070 Total Return: 3930 / Profit:  4493 / Loss:  510 / Transaction Costs:  52 / Calculated Accuracy 0.8 / #Correct Predictions: 95 Of 119
# einsatz/bet 5143.451780970281 Total Return / bet 33.02521008403362 / Transaction Costs / bet  0.4369747899159664 / Calculated Accuracy 0.8
# profit in % per bet: 0.64
# einsatz * 1+profit% ^ # wetten 2141.78
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       0.88      1.00      0.93         7
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.83      0.87        10
# weighted avg       0.91      0.90      0.89        10
#
# 55.86%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 612070 Total Return: 553 / Profit:  568 / Loss:  9 / Transaction Costs:  4 / Calculated Accuracy 0.9 / #Correct Predictions: 9 Of 10
# einsatz/bet 61207.07619354634 Total Return / bet 55.3 / Transaction Costs / bet  0.4 / Calculated Accuracy 0.9
# profit in % per bet: 0.09
# einsatz * 1+profit% ^ # wetten 1009.07
#
#
#
#
# Run: 5
# [[244 220]
#  [173 378]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.53      0.55       464
#          1.0       0.63      0.69      0.66       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.61      0.61      1015
# weighted avg       0.61      0.61      0.61      1015
#
# 1124.53%
# Specified Period:
# Total Return in Specified Period: 4054 / Profit:  14236 / Loss:  10160 / Transaction Costs:  21 / Calculated Accuracy 0.5 / #Correct Predictions: 62 of 124
#
# Entire Period:
# einsatz 622485 Total Return: 10871 / Profit:  20524 / Loss:  9279 / Transaction Costs:  373 / Calculated Accuracy 0.61 / #Correct Predictions: 622 Of 1015
# einsatz/bet 613.2862508908321 Total Return / bet 10.710344827586207 / Transaction Costs / bet  0.367487684729064 / Calculated Accuracy 0.61
# profit in % per bet: 1.75
# einsatz * 1+profit% ^ # wetten 42832829812.94
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.52      0.60       219
#          1.0       0.70      0.83      0.76       290
#
#     accuracy                           0.70       509
#    macro avg       0.70      0.68      0.68       509
# weighted avg       0.70      0.70      0.69       509
#
# 991.93%
# Specified Period:
# Total Return in Specified Period: 6872 / Profit:  10523 / Loss:  3644 / Transaction Costs:  6 / Calculated Accuracy 0.6382978723404256 / #Correct Predictions: 30 of 47
#
# Entire Period:
# einsatz 622485 Total Return: 9712 / Profit:  13717 / Loss:  3798 / Transaction Costs:  206 / Calculated Accuracy 0.7 / #Correct Predictions: 355 Of 509
# einsatz/bet 1222.9578480436044 Total Return / bet 19.08055009823183 / Transaction Costs / bet  0.40471512770137524 / Calculated Accuracy 0.7
# profit in % per bet: 1.56
# einsatz * 1+profit% ^ # wetten 2644105.89
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.50      0.60        50
#          1.0       0.80      0.93      0.86       107
#
#     accuracy                           0.79       157
#    macro avg       0.78      0.71      0.73       157
# weighted avg       0.79      0.79      0.78       157
#
# 547.52%
# Specified Period:
# Total Return in Specified Period: 1394 / Profit:  1699 / Loss:  303 / Transaction Costs:  0 / Calculated Accuracy 0.7142857142857143 / #Correct Predictions: 5 of 7
#
# Entire Period:
# einsatz 622485 Total Return: 5404 / Profit:  5944 / Loss:  468 / Transaction Costs:  70 / Calculated Accuracy 0.79 / #Correct Predictions: 124 Of 157
# einsatz/bet 3964.876080599966 Total Return / bet 34.4203821656051 / Transaction Costs / bet  0.445859872611465 / Calculated Accuracy 0.79
# profit in % per bet: 0.87
# einsatz * 1+profit% ^ # wetten 3884.86
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.82      0.86        11
#          1.0       0.87      0.93      0.90        14
#
#     accuracy                           0.88        25
#    macro avg       0.88      0.87      0.88        25
# weighted avg       0.88      0.88      0.88        25
#
# 177.25%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 622485 Total Return: 1759 / Profit:  1879 / Loss:  107 / Transaction Costs:  12 / Calculated Accuracy 0.88 / #Correct Predictions: 22 Of 25
# einsatz/bet 24899.421786167786 Total Return / bet 70.36 / Transaction Costs / bet  0.48 / Calculated Accuracy 0.88
# profit in % per bet: 0.28
# einsatz * 1+profit% ^ # wetten 1073.09
#
#
#
#
# Run: 6
# [[224 240]
#  [160 391]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.48      0.53       464
#          1.0       0.62      0.71      0.66       551
#
#     accuracy                           0.61      1015
#    macro avg       0.60      0.60      0.59      1015
# weighted avg       0.60      0.61      0.60      1015
#
# 888.93%
# Specified Period:
# Total Return in Specified Period: 6730 / Profit:  12988 / Loss:  6243 / Transaction Costs:  14 / Calculated Accuracy 0.6132075471698113 / #Correct Predictions: 65 of 106
#
# Entire Period:
# einsatz 625231 Total Return: 8514 / Profit:  17883 / Loss:  8994 / Transaction Costs:  375 / Calculated Accuracy 0.61 / #Correct Predictions: 615 Of 1015
# einsatz/bet 615.991855378286 Total Return / bet 8.388177339901478 / Transaction Costs / bet  0.3694581280788177 / Calculated Accuracy 0.61
# profit in % per bet: 1.36
# einsatz * 1+profit% ^ # wetten 916530059.68
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.44      0.54       233
#          1.0       0.64      0.85      0.73       280
#
#     accuracy                           0.66       513
#    macro avg       0.68      0.64      0.64       513
# weighted avg       0.67      0.66      0.65       513
#
# 669.32%
# Specified Period:
# Total Return in Specified Period: 7038 / Profit:  7928 / Loss:  885 / Transaction Costs:  3 / Calculated Accuracy 0.7857142857142857 / #Correct Predictions: 33 of 42
#
# Entire Period:
# einsatz 625231 Total Return: 6483 / Profit:  10712 / Loss:  4018 / Transaction Costs:  209 / Calculated Accuracy 0.66 / #Correct Predictions: 340 Of 513
# einsatz/bet 1218.7753083995326 Total Return / bet 12.637426900584796 / Transaction Costs / bet  0.4074074074074074 / Calculated Accuracy 0.66
# profit in % per bet: 1.04
# einsatz * 1+profit% ^ # wetten 198717.79
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.43      0.53        54
#          1.0       0.78      0.92      0.84       119
#
#     accuracy                           0.76       173
#    macro avg       0.74      0.67      0.69       173
# weighted avg       0.75      0.76      0.74       173
#
# 432.46%
# Specified Period:
# Total Return in Specified Period: 2213 / Profit:  2367 / Loss:  153 / Transaction Costs:  0 / Calculated Accuracy 0.8333333333333334 / #Correct Predictions: 5 of 6
#
# Entire Period:
# einsatz 625231 Total Return: 4246 / Profit:  5232 / Loss:  908 / Transaction Costs:  78 / Calculated Accuracy 0.76 / #Correct Predictions: 132 Of 173
# einsatz/bet 3614.0562613234697 Total Return / bet 24.54335260115607 / Transaction Costs / bet  0.4508670520231214 / Calculated Accuracy 0.76
# profit in % per bet: 0.68
# einsatz * 1+profit% ^ # wetten 3224.85
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.50      0.53         8
#          1.0       0.79      0.83      0.81        18
#
#     accuracy                           0.73        26
#    macro avg       0.68      0.67      0.67        26
# weighted avg       0.72      0.73      0.73        26
#
# 82.93%
# Specified Period:
# Total Return in Specified Period: -151 / Profit:  2 / Loss:  153 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 625231 Total Return: 816 / Profit:  1002 / Loss:  173 / Transaction Costs:  13 / Calculated Accuracy 0.73 / #Correct Predictions: 19 Of 26
# einsatz/bet 24047.37435419078 Total Return / bet 31.384615384615383 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.73
# profit in % per bet: 0.13
# einsatz * 1+profit% ^ # wetten 1034.49
#
#
#
#
# Run: 7
# [[238 226]
#  [162 389]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.51      0.55       464
#          1.0       0.63      0.71      0.67       551
#
#     accuracy                           0.62      1015
#    macro avg       0.61      0.61      0.61      1015
# weighted avg       0.62      0.62      0.61      1015
#
# 1291.14%
# Specified Period:
# Total Return in Specified Period: 6569 / Profit:  15941 / Loss:  9352 / Transaction Costs:  18 / Calculated Accuracy 0.6014492753623188 / #Correct Predictions: 83 of 138
#
# Entire Period:
# einsatz 616764 Total Return: 12541 / Profit:  20968 / Loss:  8056 / Transaction Costs:  370 / Calculated Accuracy 0.62 / #Correct Predictions: 627 Of 1015
# einsatz/bet 607.6495162141032 Total Return / bet 12.355665024630541 / Transaction Costs / bet  0.3645320197044335 / Calculated Accuracy 0.62
# profit in % per bet: 2.03
# einsatz * 1+profit% ^ # wetten 746955577490.99
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.45      0.53       184
#          1.0       0.71      0.86      0.78       292
#
#     accuracy                           0.70       476
#    macro avg       0.69      0.65      0.65       476
# weighted avg       0.69      0.70      0.68       476
#
# 906.98%
# Specified Period:
# Total Return in Specified Period: 4530 / Profit:  6865 / Loss:  2330 / Transaction Costs:  4 / Calculated Accuracy 0.725 / #Correct Predictions: 29 of 40
#
# Entire Period:
# einsatz 616764 Total Return: 8877 / Profit:  12244 / Loss:  3175 / Transaction Costs:  192 / Calculated Accuracy 0.7 / #Correct Predictions: 332 Of 476
# einsatz/bet 1295.7232331036025 Total Return / bet 18.649159663865547 / Transaction Costs / bet  0.40336134453781514 / Calculated Accuracy 0.7
# profit in % per bet: 1.44
# einsatz * 1+profit% ^ # wetten 899793.59
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.61      0.67        49
#          1.0       0.81      0.89      0.85        91
#
#     accuracy                           0.79       140
#    macro avg       0.78      0.75      0.76       140
# weighted avg       0.79      0.79      0.79       140
#
# 497.85%
# Specified Period:
# Total Return in Specified Period: 1958 / Profit:  1958 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 7 of 7
#
# Entire Period:
# einsatz 616764 Total Return: 4916 / Profit:  5549 / Loss:  571 / Transaction Costs:  62 / Calculated Accuracy 0.79 / #Correct Predictions: 111 Of 140
# einsatz/bet 4405.458992552249 Total Return / bet 35.114285714285714 / Transaction Costs / bet  0.44285714285714284 / Calculated Accuracy 0.79
# profit in % per bet: 0.80
# einsatz * 1+profit% ^ # wetten 3038.81
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.60      0.67         5
#          1.0       0.50      0.67      0.57         3
#
#     accuracy                           0.62         8
#    macro avg       0.62      0.63      0.62         8
# weighted avg       0.66      0.62      0.63         8
#
# 15.01%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 616764 Total Return: 146 / Profit:  299 / Loss:  149 / Transaction Costs:  4 / Calculated Accuracy 0.62 / #Correct Predictions: 5 Of 8
# einsatz/bet 77095.53236966435 Total Return / bet 18.25 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.62
# profit in % per bet: 0.02
# einsatz * 1+profit% ^ # wetten 1001.90
#
#
#
#
# Run: 8
# [[226 238]
#  [162 389]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.49      0.53       464
#          1.0       0.62      0.71      0.66       551
#
#     accuracy                           0.61      1015
#    macro avg       0.60      0.60      0.60      1015
# weighted avg       0.60      0.61      0.60      1015
#
# 883.59%
# Specified Period:
# Total Return in Specified Period: 8287 / Profit:  18383 / Loss:  10077 / Transaction Costs:  18 / Calculated Accuracy 0.5813953488372093 / #Correct Predictions: 75 of 129
#
# Entire Period:
# einsatz 619740 Total Return: 8464 / Profit:  18829 / Loss:  9994 / Transaction Costs:  371 / Calculated Accuracy 0.61 / #Correct Predictions: 615 Of 1015
# einsatz/bet 610.581411759807 Total Return / bet 8.338916256157635 / Transaction Costs / bet  0.36551724137931035 / Calculated Accuracy 0.61
# profit in % per bet: 1.37
# einsatz * 1+profit% ^ # wetten 953972469.19
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.46      0.54       211
#          1.0       0.67      0.81      0.73       285
#
#     accuracy                           0.66       496
#    macro avg       0.66      0.64      0.64       496
# weighted avg       0.66      0.66      0.65       496
#
# 739.10%
# Specified Period:
# Total Return in Specified Period: 4338 / Profit:  8838 / Loss:  4492 / Transaction Costs:  7 / Calculated Accuracy 0.6122448979591837 / #Correct Predictions: 30 of 49
#
# Entire Period:
# einsatz 619740 Total Return: 7190 / Profit:  11371 / Loss:  3980 / Transaction Costs:  200 / Calculated Accuracy 0.66 / #Correct Predictions: 329 Of 496
# einsatz/bet 1249.4760744681535 Total Return / bet 14.495967741935484 / Transaction Costs / bet  0.4032258064516129 / Calculated Accuracy 0.66
# profit in % per bet: 1.16
# einsatz * 1+profit% ^ # wetten 305297.76
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.46      0.56        46
#          1.0       0.75      0.90      0.82        83
#
#     accuracy                           0.74       129
#    macro avg       0.74      0.68      0.69       129
# weighted avg       0.74      0.74      0.73       129
#
# 270.93%
# Specified Period:
# Total Return in Specified Period: 897 / Profit:  1131 / Loss:  233 / Transaction Costs:  0 / Calculated Accuracy 0.6666666666666666 / #Correct Predictions: 4 of 6
#
# Entire Period:
# einsatz 619740 Total Return: 2651 / Profit:  3555 / Loss:  846 / Transaction Costs:  58 / Calculated Accuracy 0.74 / #Correct Predictions: 96 Of 129
# einsatz/bet 4804.187077024838 Total Return / bet 20.550387596899224 / Transaction Costs / bet  0.4496124031007752 / Calculated Accuracy 0.74
# profit in % per bet: 0.43
# einsatz * 1+profit% ^ # wetten 1734.35
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83         6
#          1.0       0.86      0.86      0.86         7
#
#     accuracy                           0.85        13
#    macro avg       0.85      0.85      0.85        13
# weighted avg       0.85      0.85      0.85        13
#
# 53.43%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 619740 Total Return: 527 / Profit:  560 / Loss:  26 / Transaction Costs:  6 / Calculated Accuracy 0.85 / #Correct Predictions: 11 Of 13
# einsatz/bet 47672.317918169545 Total Return / bet 40.53846153846154 / Transaction Costs / bet  0.46153846153846156 / Calculated Accuracy 0.85
# profit in % per bet: 0.09
# einsatz * 1+profit% ^ # wetten 1011.11
#
#
#
#
# Run: 9
# [[216 248]
#  [161 390]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.47      0.51       464
#          1.0       0.61      0.71      0.66       551
#
#     accuracy                           0.60      1015
#    macro avg       0.59      0.59      0.58      1015
# weighted avg       0.59      0.60      0.59      1015
#
# 852.30%
# Specified Period:
# Total Return in Specified Period: 10452 / Profit:  17889 / Loss:  7418 / Transaction Costs:  18 / Calculated Accuracy 0.5923076923076923 / #Correct Predictions: 77 of 130
#
# Entire Period:
# einsatz 622258 Total Return: 8149 / Profit:  19039 / Loss:  10516 / Transaction Costs:  373 / Calculated Accuracy 0.6 / #Correct Predictions: 606 Of 1015
# einsatz/bet 613.0628140743686 Total Return / bet 8.028571428571428 / Transaction Costs / bet  0.367487684729064 / Calculated Accuracy 0.6
# profit in % per bet: 1.31
# einsatz * 1+profit% ^ # wetten 543612271.04
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.43      0.52       205
#          1.0       0.68      0.84      0.75       296
#
#     accuracy                           0.67       501
#    macro avg       0.67      0.64      0.64       501
# weighted avg       0.67      0.67      0.66       501
#
# 774.97%
# Specified Period:
# Total Return in Specified Period: 5308 / Profit:  7560 / Loss:  2245 / Transaction Costs:  5 / Calculated Accuracy 0.6666666666666666 / #Correct Predictions: 28 of 42
#
# Entire Period:
# einsatz 622258 Total Return: 7545 / Profit:  12441 / Loss:  4691 / Transaction Costs:  204 / Calculated Accuracy 0.67 / #Correct Predictions: 338 Of 501
# einsatz/bet 1242.0334456796088 Total Return / bet 15.059880239520957 / Transaction Costs / bet  0.40718562874251496 / Calculated Accuracy 0.67
# profit in % per bet: 1.21
# einsatz * 1+profit% ^ # wetten 419130.43
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.57      0.62        42
#          1.0       0.84      0.90      0.87       109
#
#     accuracy                           0.81       151
#    macro avg       0.77      0.74      0.75       151
# weighted avg       0.80      0.81      0.80       151
#
# 502.06%
# Specified Period:
# Total Return in Specified Period: 319 / Profit:  1108 / Loss:  788 / Transaction Costs:  0 / Calculated Accuracy 0.6666666666666666 / #Correct Predictions: 4 of 6
#
# Entire Period:
# einsatz 622258 Total Return: 4952 / Profit:  5878 / Loss:  857 / Transaction Costs:  68 / Calculated Accuracy 0.81 / #Correct Predictions: 122 Of 151
# einsatz/bet 4120.918915797908 Total Return / bet 32.794701986754966 / Transaction Costs / bet  0.4503311258278146 / Calculated Accuracy 0.81
# profit in % per bet: 0.80
# einsatz * 1+profit% ^ # wetten 3309.90
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.45      1.00      0.62         5
#          1.0       1.00      0.68      0.81        19
#
#     accuracy                           0.75        24
#    macro avg       0.73      0.84      0.72        24
# weighted avg       0.89      0.75      0.77        24
#
# 93.70%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 622258 Total Return: 924 / Profit:  1118 / Loss:  181 / Transaction Costs:  12 / Calculated Accuracy 0.75 / #Correct Predictions: 18 Of 24
# einsatz/bet 25927.448178561837 Total Return / bet 38.5 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.75
# profit in % per bet: 0.15
# einsatz * 1+profit% ^ # wetten 1036.25
#
#
#
#
# Run: 10
# [[213 251]
#  [147 404]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.46      0.52       464
#          1.0       0.62      0.73      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.60      0.60      0.59      1015
# weighted avg       0.61      0.61      0.60      1015
#
# 1164.28%
# Specified Period:
# Total Return in Specified Period: 7373 / Profit:  14022 / Loss:  6627 / Transaction Costs:  20 / Calculated Accuracy 0.5343511450381679 / #Correct Predictions: 70 of 131
#
# Entire Period:
# einsatz 618916 Total Return: 11271 / Profit:  19956 / Loss:  8313 / Transaction Costs:  371 / Calculated Accuracy 0.61 / #Correct Predictions: 617 Of 1015
# einsatz/bet 609.7696565408448 Total Return / bet 11.104433497536945 / Transaction Costs / bet  0.36551724137931035 / Calculated Accuracy 0.61
# profit in % per bet: 1.82
# einsatz * 1+profit% ^ # wetten 90218016257.45
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.42      0.53       201
#          1.0       0.68      0.88      0.77       284
#
#     accuracy                           0.69       485
#    macro avg       0.69      0.65      0.65       485
# weighted avg       0.69      0.69      0.67       485
#
# 959.40%
# Specified Period:
# Total Return in Specified Period: 6125 / Profit:  7844 / Loss:  1712 / Transaction Costs:  6 / Calculated Accuracy 0.6304347826086957 / #Correct Predictions: 29 of 46
#
# Entire Period:
# einsatz 618916 Total Return: 9397 / Profit:  13000 / Loss:  3406 / Transaction Costs:  196 / Calculated Accuracy 0.69 / #Correct Predictions: 333 Of 485
# einsatz/bet 1276.11587915249 Total Return / bet 19.37525773195876 / Transaction Costs / bet  0.4041237113402062 / Calculated Accuracy 0.69
# profit in % per bet: 1.52
# einsatz * 1+profit% ^ # wetten 1492800.12
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.44      0.56        45
#          1.0       0.80      0.93      0.86       106
#
#     accuracy                           0.79       151
#    macro avg       0.77      0.69      0.71       151
# weighted avg       0.78      0.79      0.77       151
#
# 476.58%
# Specified Period:
# Total Return in Specified Period: 1079 / Profit:  1118 / Loss:  37 / Transaction Costs:  0 / Calculated Accuracy 0.8333333333333334 / #Correct Predictions: 5 of 6
#
# Entire Period:
# einsatz 618916 Total Return: 4698 / Profit:  5547 / Loss:  781 / Transaction Costs:  67 / Calculated Accuracy 0.79 / #Correct Predictions: 119 Of 151
# einsatz/bet 4098.782790655348 Total Return / bet 31.112582781456954 / Transaction Costs / bet  0.44370860927152317 / Calculated Accuracy 0.79
# profit in % per bet: 0.76
# einsatz * 1+profit% ^ # wetten 3132.61
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.50      0.40         2
#          1.0       0.93      0.87      0.90        15
#
#     accuracy                           0.82        17
#    macro avg       0.63      0.68      0.65        17
# weighted avg       0.86      0.82      0.84        17
#
# 49.81%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 618916 Total Return: 489 / Profit:  587 / Loss:  89 / Transaction Costs:  8 / Calculated Accuracy 0.82 / #Correct Predictions: 14 Of 17
# einsatz/bet 36406.835375821036 Total Return / bet 28.764705882352942 / Transaction Costs / bet  0.47058823529411764 / Calculated Accuracy 0.82
# profit in % per bet: 0.08
# einsatz * 1+profit% ^ # wetten 1013.52
#
#
#
#
# Run: 11
# [[212 252]
#  [161 390]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.46      0.51       464
#          1.0       0.61      0.71      0.65       551
#
#     accuracy                           0.59      1015
#    macro avg       0.59      0.58      0.58      1015
# weighted avg       0.59      0.59      0.59      1015
#
# 839.97%
# Specified Period:
# Total Return in Specified Period: 8156 / Profit:  14737 / Loss:  6564 / Transaction Costs:  16 / Calculated Accuracy 0.6129032258064516 / #Correct Predictions: 76 of 124
#
# Entire Period:
# einsatz 623910 Total Return: 8025 / Profit:  17738 / Loss:  9338 / Transaction Costs:  374 / Calculated Accuracy 0.59 / #Correct Predictions: 602 Of 1015
# einsatz/bet 614.6905746021312 Total Return / bet 7.906403940886699 / Transaction Costs / bet  0.36847290640394087 / Calculated Accuracy 0.59
# profit in % per bet: 1.29
# einsatz * 1+profit% ^ # wetten 430240865.03
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.44      0.54       216
#          1.0       0.67      0.86      0.75       289
#
#     accuracy                           0.68       505
#    macro avg       0.68      0.65      0.64       505
# weighted avg       0.68      0.68      0.66       505
#
# 822.07%
# Specified Period:
# Total Return in Specified Period: 5516 / Profit:  8707 / Loss:  3185 / Transaction Costs:  6 / Calculated Accuracy 0.6808510638297872 / #Correct Predictions: 32 of 47
#
# Entire Period:
# einsatz 623910 Total Return: 8014 / Profit:  12390 / Loss:  4169 / Transaction Costs:  206 / Calculated Accuracy 0.68 / #Correct Predictions: 342 Of 505
# einsatz/bet 1235.4671944973527 Total Return / bet 15.86930693069307 / Transaction Costs / bet  0.4079207920792079 / Calculated Accuracy 0.68
# profit in % per bet: 1.28
# einsatz * 1+profit% ^ # wetten 629741.07
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.55      0.63        58
#          1.0       0.80      0.91      0.85       116
#
#     accuracy                           0.79       174
#    macro avg       0.77      0.73      0.74       174
# weighted avg       0.78      0.79      0.78       174
#
# 547.88%
# Specified Period:
# Total Return in Specified Period: 2521 / Profit:  3445 / Loss:  921 / Transaction Costs:  1 / Calculated Accuracy 0.6363636363636364 / #Correct Predictions: 7 of 11
#
# Entire Period:
# einsatz 623910 Total Return: 5400 / Profit:  6305 / Loss:  827 / Transaction Costs:  78 / Calculated Accuracy 0.79 / #Correct Predictions: 137 Of 174
# einsatz/bet 3585.6950185124315 Total Return / bet 31.03448275862069 / Transaction Costs / bet  0.4482758620689655 / Calculated Accuracy 0.79
# profit in % per bet: 0.87
# einsatz * 1+profit% ^ # wetten 4479.47
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.57      0.62         7
#          1.0       0.84      0.89      0.86        18
#
#     accuracy                           0.80        25
#    macro avg       0.75      0.73      0.74        25
# weighted avg       0.79      0.80      0.80        25
#
# 142.73%
# Specified Period:
# Total Return in Specified Period: 442 / Profit:  639 / Loss:  196 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 2 of 4
#
# Entire Period:
# einsatz 623910 Total Return: 1414 / Profit:  1526 / Loss:  99 / Transaction Costs:  12 / Calculated Accuracy 0.8 / #Correct Predictions: 20 Of 25
# einsatz/bet 24956.437328846525 Total Return / bet 56.56 / Transaction Costs / bet  0.48 / Calculated Accuracy 0.8
# profit in % per bet: 0.23
# einsatz * 1+profit% ^ # wetten 1058.23
#
#
#
#
# Run: 12
# [[232 232]
#  [143 408]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.55       464
#          1.0       0.64      0.74      0.69       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.62      0.62      1015
# weighted avg       0.63      0.63      0.62      1015
#
# 1323.05%
# Specified Period:
# Total Return in Specified Period: 8843 / Profit:  18526 / Loss:  9661 / Transaction Costs:  21 / Calculated Accuracy 0.5447761194029851 / #Correct Predictions: 73 of 134
#
# Entire Period:
# einsatz 616924 Total Return: 12860 / Profit:  22213 / Loss:  8982 / Transaction Costs:  370 / Calculated Accuracy 0.63 / #Correct Predictions: 640 Of 1015
# einsatz/bet 607.8077690399272 Total Return / bet 12.669950738916256 / Transaction Costs / bet  0.3645320197044335 / Calculated Accuracy 0.63
# profit in % per bet: 2.08
# einsatz * 1+profit% ^ # wetten 1242635049744.78
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.45      0.56       193
#          1.0       0.70      0.88      0.78       278
#
#     accuracy                           0.71       471
#    macro avg       0.71      0.67      0.67       471
# weighted avg       0.71      0.71      0.69       471
#
# 1080.36%
# Specified Period:
# Total Return in Specified Period: 8204 / Profit:  11824 / Loss:  3612 / Transaction Costs:  6 / Calculated Accuracy 0.660377358490566 / #Correct Predictions: 35 of 53
#
# Entire Period:
# einsatz 616924 Total Return: 10612 / Profit:  14410 / Loss:  3606 / Transaction Costs:  190 / Calculated Accuracy 0.71 / #Correct Predictions: 333 Of 471
# einsatz/bet 1309.8192899692697 Total Return / bet 22.530785562632698 / Transaction Costs / bet  0.4033970276008493 / Calculated Accuracy 0.71
# profit in % per bet: 1.72
# einsatz * 1+profit% ^ # wetten 3080933.37
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.61      0.67        44
#          1.0       0.83      0.90      0.86        90
#
#     accuracy                           0.81       134
#    macro avg       0.79      0.76      0.77       134
# weighted avg       0.80      0.81      0.80       134
#
# 539.88%
# Specified Period:
# Total Return in Specified Period: 4637 / Profit:  5324 / Loss:  686 / Transaction Costs:  0 / Calculated Accuracy 0.8888888888888888 / #Correct Predictions: 8 of 9
#
# Entire Period:
# einsatz 616924 Total Return: 5338 / Profit:  6195 / Loss:  797 / Transaction Costs:  60 / Calculated Accuracy 0.81 / #Correct Predictions: 108 Of 134
# einsatz/bet 4603.917056533776 Total Return / bet 39.83582089552239 / Transaction Costs / bet  0.44776119402985076 / Calculated Accuracy 0.81
# profit in % per bet: 0.87
# einsatz * 1+profit% ^ # wetten 3172.31
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80        10
#          1.0       0.83      0.83      0.83        12
#
#     accuracy                           0.82        22
#    macro avg       0.82      0.82      0.82        22
# weighted avg       0.82      0.82      0.82        22
#
# 105.78%
# Specified Period:
# Total Return in Specified Period: 2365 / Profit:  3052 / Loss:  686 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 616924 Total Return: 1046 / Profit:  1439 / Loss:  381 / Transaction Costs:  11 / Calculated Accuracy 0.82 / #Correct Predictions: 18 Of 22
# einsatz/bet 28042.040253433002 Total Return / bet 47.54545454545455 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.82
# profit in % per bet: 0.17
# einsatz * 1+profit% ^ # wetten 1037.97
#
#
#
#
# Run: 13
# [[212 252]
#  [149 402]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.46      0.51       464
#          1.0       0.61      0.73      0.67       551
#
#     accuracy                           0.60      1015
#    macro avg       0.60      0.59      0.59      1015
# weighted avg       0.60      0.60      0.60      1015
#
# 1050.44%
# Specified Period:
# Total Return in Specified Period: 9445 / Profit:  19651 / Loss:  10182 / Transaction Costs:  23 / Calculated Accuracy 0.5586206896551724 / #Correct Predictions: 81 of 145
#
# Entire Period:
# einsatz 626684 Total Return: 10128 / Profit:  19322 / Loss:  8817 / Transaction Costs:  376 / Calculated Accuracy 0.6 / #Correct Predictions: 614 Of 1015
# einsatz/bet 617.4230730313288 Total Return / bet 9.97832512315271 / Transaction Costs / bet  0.3704433497536946 / Calculated Accuracy 0.6
# profit in % per bet: 1.62
# einsatz * 1+profit% ^ # wetten 11669885736.30
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.41      0.50       216
#          1.0       0.68      0.84      0.75       315
#
#     accuracy                           0.67       531
#    macro avg       0.66      0.63      0.63       531
# weighted avg       0.66      0.67      0.65       531
#
# 853.55%
# Specified Period:
# Total Return in Specified Period: 5262 / Profit:  11210 / Loss:  5935 / Transaction Costs:  11 / Calculated Accuracy 0.5538461538461539 / #Correct Predictions: 36 of 65
#
# Entire Period:
# einsatz 626684 Total Return: 8319 / Profit:  12832 / Loss:  4297 / Transaction Costs:  216 / Calculated Accuracy 0.67 / #Correct Predictions: 354 Of 531
# einsatz/bet 1180.1966461898282 Total Return / bet 15.666666666666666 / Transaction Costs / bet  0.4067796610169492 / Calculated Accuracy 0.67
# profit in % per bet: 1.33
# einsatz * 1+profit% ^ # wetten 1099323.23
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.44      0.53        57
#          1.0       0.77      0.89      0.83       121
#
#     accuracy                           0.75       178
#    macro avg       0.71      0.67      0.68       178
# weighted avg       0.74      0.75      0.73       178
#
# 454.87%
# Specified Period:
# Total Return in Specified Period: 2431 / Profit:  4326 / Loss:  1891 / Transaction Costs:  2 / Calculated Accuracy 0.6470588235294118 / #Correct Predictions: 11 of 17
#
# Entire Period:
# einsatz 626684 Total Return: 4468 / Profit:  5896 / Loss:  1347 / Transaction Costs:  79 / Calculated Accuracy 0.75 / #Correct Predictions: 133 Of 178
# einsatz/bet 3520.69898385842 Total Return / bet 25.10112359550562 / Transaction Costs / bet  0.4438202247191011 / Calculated Accuracy 0.75
# profit in % per bet: 0.71
# einsatz * 1+profit% ^ # wetten 3541.55
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.40      0.50        10
#          1.0       0.65      0.85      0.73        13
#
#     accuracy                           0.65        23
#    macro avg       0.66      0.62      0.62        23
# weighted avg       0.66      0.65      0.63        23
#
# 95.30%
# Specified Period:
# Total Return in Specified Period: 222 / Profit:  376 / Loss:  153 / Transaction Costs:  0 / Calculated Accuracy 0.5 / #Correct Predictions: 1 of 2
#
# Entire Period:
# einsatz 626684 Total Return: 941 / Profit:  1313 / Loss:  360 / Transaction Costs:  11 / Calculated Accuracy 0.65 / #Correct Predictions: 15 Of 23
# einsatz/bet 27247.148657686903 Total Return / bet 40.91304347826087 / Transaction Costs / bet  0.4782608695652174 / Calculated Accuracy 0.65
# profit in % per bet: 0.15
# einsatz * 1+profit% ^ # wetten 1035.11
#
#
#
#
# Run: 14
# [[224 240]
#  [152 399]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.48      0.53       464
#          1.0       0.62      0.72      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.61      1015
#
# 1194.83%
# Specified Period:
# Total Return in Specified Period: 13467 / Profit:  21460 / Loss:  7973 / Transaction Costs:  19 / Calculated Accuracy 0.6028368794326241 / #Correct Predictions: 85 of 141
#
# Entire Period:
# ...
#
# 300.88%
# Specified Period:
# Total Return in Specified Period: 1000 / Profit:  1688 / Loss:  686 / Transaction Costs:  0 / Calculated Accuracy 0.8888888888888888 / #Correct Predictions: 8 of 9
#
# Entire Period:
# einsatz 616056 Total Return: 2952 / Profit:  3816 / Loss:  807 / Transaction Costs:  55 / Calculated Accuracy 0.78 / #Correct Predictions: 97 Of 125
# einsatz/bet 4928.4526168584 Total Return / bet 23.616 / Transaction Costs / bet  0.44 / Calculated Accuracy 0.78
# profit in % per bet: 0.48
# einsatz * 1+profit% ^ # wetten 1817.64
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.40      0.50         5
#          1.0       0.75      0.90      0.82        10
#
#     accuracy                           0.73        15
#    macro avg       0.71      0.65      0.66        15
# weighted avg       0.72      0.73      0.71        15
#
# 87.73%
# Specified Period:
# Total Return in Specified Period: 0 / Profit:  0 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy - / #Correct Predictions: 0 of -
#
# Entire Period:
# einsatz 616056 Total Return: 869 / Profit:  977 / Loss:  100 / Transaction Costs:  7 / Calculated Accuracy 0.73 / #Correct Predictions: 11 Of 15
# einsatz/bet 41070.438473819995 Total Return / bet 57.93333333333333 / Transaction Costs / bet  0.4666666666666667 / Calculated Accuracy 0.73
# profit in % per bet: 0.14
# einsatz * 1+profit% ^ # wetten 1021.37
#
#
#
#
# Run: 16
# [[212 252]
#  [139 412]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.46      0.52       464
#          1.0       0.62      0.75      0.68       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.61      1015
#
# 1012.17%
# Specified Period:
# Total Return in Specified Period: 9929 / Profit:  18291 / Loss:  8342 / Transaction Costs:  18 / Calculated Accuracy 0.5702479338842975 / #Correct Predictions: 69 of 121
#
# Entire Period:
# einsatz 622366 Total Return: 9748 / Profit:  18758 / Loss:  8636 / Transaction Costs:  373 / Calculated Accuracy 0.61 / #Correct Predictions: 624 Of 1015
# einsatz/bet 613.1694574321044 Total Return / bet 9.603940886699508 / Transaction Costs / bet  0.367487684729064 / Calculated Accuracy 0.61
# profit in % per bet: 1.57
# einsatz * 1+profit% ^ # wetten 7092224313.47
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.39      0.48       197
#          1.0       0.67      0.86      0.75       293
#
#     accuracy                           0.67       490
#    macro avg       0.66      0.62      0.62       490
# weighted avg       0.66      0.67      0.65       490
#
# 844.09%
# Specified Period:
# Total Return in Specified Period: 9677 / Profit:  13171 / Loss:  3484 / Transaction Costs:  8 / Calculated Accuracy 0.5769230769230769 / #Correct Predictions: 30 of 52
#
# Entire Period:
# einsatz 622366 Total Return: 8240 / Profit:  12502 / Loss:  4062 / Transaction Costs:  200 / Calculated Accuracy 0.67 / #Correct Predictions: 327 Of 490
# einsatz/bet 1270.1367332522163 Total Return / bet 16.816326530612244 / Transaction Costs / bet  0.40816326530612246 / Calculated Accuracy 0.67
# profit in % per bet: 1.32
# einsatz * 1+profit% ^ # wetten 629495.93
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.57      0.64        60
#          1.0       0.77      0.88      0.82       100
#
#     accuracy                           0.76       160
#    macro avg       0.76      0.72      0.73       160
# weighted avg       0.76      0.76      0.75       160
#
# 489.70%
# Specified Period:
# Total Return in Specified Period: 3886 / Profit:  4532 / Loss:  643 / Transaction Costs:  2 / Calculated Accuracy 0.5833333333333334 / #Correct Predictions: 7 of 12
#
# Entire Period:
# einsatz 622366 Total Return: 4824 / Profit:  6157 / Loss:  1260 / Transaction Costs:  72 / Calculated Accuracy 0.76 / #Correct Predictions: 122 Of 160
# einsatz/bet 3889.7937455849124 Total Return / bet 30.15 / Transaction Costs / bet  0.45 / Calculated Accuracy 0.76
# profit in % per bet: 0.78
# einsatz * 1+profit% ^ # wetten 3439.71
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.62      0.67         8
#          1.0       0.77      0.83      0.80        12
#
#     accuracy                           0.75        20
#    macro avg       0.74      0.73      0.73        20
# weighted avg       0.75      0.75      0.75        20
#
# 153.47%
# Specified Period:
# Total Return in Specified Period: 2702 / Profit:  3052 / Loss:  348 / Transaction Costs:  1 / Calculated Accuracy 0.3333333333333333 / #Correct Predictions: 1 of 3
#
# Entire Period:
# einsatz 622366 Total Return: 1524 / Profit:  1661 / Loss:  126 / Transaction Costs:  10 / Calculated Accuracy 0.75 / #Correct Predictions: 15 Of 20
# einsatz/bet 31118.3499646793 Total Return / bet 76.2 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.75
# profit in % per bet: 0.24
# einsatz * 1+profit% ^ # wetten 1050.13
#
#
#
#
# Run: 17
# [[232 232]
#  [162 389]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.50      0.54       464
#          1.0       0.63      0.71      0.66       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.61      1015
#
# 1120.58%
# Specified Period:
# Total Return in Specified Period: 6382 / Profit:  15105 / Loss:  8699 / Transaction Costs:  22 / Calculated Accuracy 0.5114503816793893 / #Correct Predictions: 67 of 131
#
# Entire Period:
# einsatz 620882 Total Return: 10833 / Profit:  19661 / Loss:  8456 / Transaction Costs:  372 / Calculated Accuracy 0.61 / #Correct Predictions: 621 Of 1015
# einsatz/bet 611.7064666749279 Total Return / bet 10.672906403940887 / Transaction Costs / bet  0.3665024630541872 / Calculated Accuracy 0.61
# profit in % per bet: 1.74
# einsatz * 1+profit% ^ # wetten 42150324489.80
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.45      0.53       210
#          1.0       0.66      0.83      0.74       278
#
#     accuracy                           0.66       488
#    macro avg       0.66      0.64      0.64       488
# weighted avg       0.66      0.66      0.65       488
#
# 704.35%
# Specified Period:
# Total Return in Specified Period: 5948 / Profit:  10123 / Loss:  4165 / Transaction Costs:  9 / Calculated Accuracy 0.625 / #Correct Predictions: 40 of 64
#
# Entire Period:
# einsatz 620882 Total Return: 6844 / Profit:  10890 / Loss:  3846 / Transaction Costs:  198 / Calculated Accuracy 0.66 / #Correct Predictions: 324 Of 488
# einsatz/bet 1272.2993108095322 Total Return / bet 14.024590163934427 / Transaction Costs / bet  0.4057377049180328 / Calculated Accuracy 0.66
# profit in % per bet: 1.10
# einsatz * 1+profit% ^ # wetten 210567.38
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.47      0.57        47
#          1.0       0.78      0.92      0.85        98
#
#     accuracy                           0.77       145
#    macro avg       0.76      0.69      0.71       145
# weighted avg       0.77      0.77      0.76       145
#
# 420.12%
# Specified Period:
# Total Return in Specified Period: 1508 / Profit:  2195 / Loss:  686 / Transaction Costs:  0 / Calculated Accuracy 0.8 / #Correct Predictions: 4 of 5
#
# Entire Period:
# einsatz 620882 Total Return: 4135 / Profit:  5165 / Loss:  963 / Transaction Costs:  65 / Calculated Accuracy 0.77 / #Correct Predictions: 112 Of 145
# einsatz/bet 4281.945266724495 Total Return / bet 28.517241379310345 / Transaction Costs / bet  0.4482758620689655 / Calculated Accuracy 0.77
# profit in % per bet: 0.67
# einsatz * 1+profit% ^ # wetten 2618.18
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.67      0.67         6
#          1.0       0.85      0.85      0.85        13
#
#     accuracy                           0.79        19
#    macro avg       0.76      0.76      0.76        19
# weighted avg       0.79      0.79      0.79        19
#
# 68.45%
# Specified Period:
# Total Return in Specified Period: -687 / Profit:  0 / Loss:  686 / Transaction Costs:  0 / Calculated Accuracy 0.0 / #Correct Predictions: 0 of 1
#
# Entire Period:
# einsatz 620882 Total Return: 674 / Profit:  1025 / Loss:  340 / Transaction Costs:  9 / Calculated Accuracy 0.79 / #Correct Predictions: 15 Of 19
# einsatz/bet 32678.003351318515 Total Return / bet 35.473684210526315 / Transaction Costs / bet  0.47368421052631576 / Calculated Accuracy 0.79
# profit in % per bet: 0.11
# einsatz * 1+profit% ^ # wetten 1020.83
#
#
#
#
# Run: 18
# [[249 215]
#  [157 394]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.54      0.57       464
#          1.0       0.65      0.72      0.68       551
#
#     accuracy                           0.63      1015
#    macro avg       0.63      0.63      0.63      1015
# weighted avg       0.63      0.63      0.63      1015
#
# 1137.59%
# Specified Period:
# Total Return in Specified Period: 7856 / Profit:  16499 / Loss:  8625 / Transaction Costs:  17 / Calculated Accuracy 0.5772357723577236 / #Correct Predictions: 71 of 123
#
# Entire Period:
# einsatz 616848 Total Return: 11005 / Profit:  19401 / Loss:  8025 / Transaction Costs:  370 / Calculated Accuracy 0.63 / #Correct Predictions: 643 Of 1015
# einsatz/bet 607.7326818950391 Total Return / bet 10.842364532019705 / Transaction Costs / bet  0.3645320197044335 / Calculated Accuracy 0.63
# profit in % per bet: 1.78
# einsatz * 1+profit% ^ # wetten 62373705163.98
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.52      0.59       196
#          1.0       0.72      0.84      0.77       291
#
#     accuracy                           0.71       487
#    macro avg       0.70      0.68      0.68       487
# weighted avg       0.70      0.71      0.70       487
#
# 888.25%
# Specified Period:
# Total Return in Specified Period: 5516 / Profit:  8018 / Loss:  2497 / Transaction Costs:  4 / Calculated Accuracy 0.6486486486486487 / #Correct Predictions: 24 of 37
#
# Entire Period:
# einsatz 616848 Total Return: 8686 / Profit:  12423 / Loss:  3540 / Transaction Costs:  196 / Calculated Accuracy 0.71 / #Correct Predictions: 345 Of 487
# einsatz/bet 1266.6297168859646 Total Return / bet 17.835728952772072 / Transaction Costs / bet  0.4024640657084189 / Calculated Accuracy 0.71
# profit in % per bet: 1.41
# einsatz * 1+profit% ^ # wetten 906630.89
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.69      0.75        42
#          1.0       0.85      0.92      0.88        78
#
#     accuracy                           0.84       120
#    macro avg       0.84      0.81      0.82       120
# weighted avg       0.84      0.84      0.84       120
#
# 445.31%
# Specified Period:
# Total Return in Specified Period: 3541 / Profit:  3541 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 6 of 6
#
# Entire Period:
# einsatz 616848 Total Return: 4398 / Profit:  4743 / Loss:  290 / Transaction Costs:  54 / Calculated Accuracy 0.84 / #Correct Predictions: 101 Of 120
# einsatz/bet 5140.405601028873 Total Return / bet 36.65 / Transaction Costs / bet  0.45 / Calculated Accuracy 0.84
# profit in % per bet: 0.71
# einsatz * 1+profit% ^ # wetten 2345.59
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.62      0.71         8
#          1.0       0.77      0.91      0.83        11
#
#     accuracy                           0.79        19
#    macro avg       0.80      0.77      0.77        19
# weighted avg       0.80      0.79      0.78        19
#
# 125.95%
# Specified Period:
# Total Return in Specified Period: 3052 / Profit:  3052 / Loss:  0 / Transaction Costs:  0 / Calculated Accuracy 1.0 / #Correct Predictions: 1 of 1
#
# Entire Period:
# einsatz 616848 Total Return: 1249 / Profit:  1358 / Loss:  99 / Transaction Costs:  9 / Calculated Accuracy 0.79 / #Correct Predictions: 15 Of 19
# einsatz/bet 32465.719585445513 Total Return / bet 65.73684210526316 / Transaction Costs / bet  0.47368421052631576 / Calculated Accuracy 0.79
# profit in % per bet: 0.20
# einsatz * 1+profit% ^ # wetten 1039.18
#
#
#
#
# Run: 19
# [[226 238]
#  [154 397]]
# Threshold of: 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.49      0.54       464
#          1.0       0.63      0.72      0.67       551
#
#     accuracy                           0.61      1015
#    macro avg       0.61      0.60      0.60      1015
# weighted avg       0.61      0.61      0.61      1015
#
# 884.58%
# Specified Period:
# Total Return in Specified Period: 4591 / Profit:  15182 / Loss:  10569 / Transaction Costs:  21 / Calculated Accuracy 0.5492957746478874 / #Correct Predictions: 78 of 142
#
# Entire Period:
# einsatz 614917 Total Return: 8476 / Profit:  17564 / Loss:  8718 / Transaction Costs:  368 / Calculated Accuracy 0.61 / #Correct Predictions: 623 Of 1015
# einsatz/bet 605.8302887611814 Total Return / bet 8.350738916256157 / Transaction Costs / bet  0.3625615763546798 / Calculated Accuracy 0.61
# profit in % per bet: 1.38
# einsatz * 1+profit% ^ # wetten 1082918301.61
#
#
# Threshold of: 0.6
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.50      0.58       201
#          1.0       0.69      0.84      0.76       271
#
#     accuracy                           0.69       472
#    macro avg       0.69      0.67      0.67       472
# weighted avg       0.69      0.69      0.68       472
#
# 689.11%
# Specified Period:
# Total Return in Specified Period: 3019 / Profit:  5909 / Loss:  2885 / Transaction Costs:  5 / Calculated Accuracy 0.6829268292682927 / #Correct Predictions: 28 of 41
#
# Entire Period:
# einsatz 614917 Total Return: 6700 / Profit:  10318 / Loss:  3427 / Transaction Costs:  190 / Calculated Accuracy 0.69 / #Correct Predictions: 327 Of 472
# einsatz/bet 1302.791828586015 Total Return / bet 14.194915254237289 / Transaction Costs / bet  0.4025423728813559 / Calculated Accuracy 0.69
# profit in % per bet: 1.09
# einsatz * 1+profit% ^ # wetten 166498.48
#
#
# Threshold of: 0.7
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.56      0.62        43
#          1.0       0.80      0.89      0.84        87
#
#     accuracy                           0.78       130
#    macro avg       0.75      0.72      0.73       130
# weighted avg       0.77      0.78      0.77       130
#
# 353.31%
# Specified Period:
# Total Return in Specified Period: -341 / Profit:  8 / Loss:  348 / Transaction Costs:  1 / Calculated Accuracy 0.6 / #Correct Predictions: 3 of 5
#
# Entire Period:
# einsatz 614917 Total Return: 3474 / Profit:  4459 / Loss:  926 / Transaction Costs:  58 / Calculated Accuracy 0.78 / #Correct Predictions: 101 Of 130
# einsatz/bet 4730.1364853276855 Total Return / bet 26.723076923076924 / Transaction Costs / bet  0.4461538461538462 / Calculated Accuracy 0.78
# profit in % per bet: 0.56
# einsatz * 1+profit% ^ # wetten 2080.01
#
#
# Threshold of: 0.8
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.55      0.67        11
#          1.0       0.55      0.86      0.67         7
#
#     accuracy                           0.67        18
#    macro avg       0.70      0.70      0.67        18
# weighted avg       0.74      0.67      0.67        18
#
# 56.31%
# Specified Period:
# Total Return in Specified Period: -346 / Profit:  2 / Loss:  348 / Transaction Costs:  1 / Calculated Accuracy 0.3333333333333333 / #Correct Predictions: 1 of 3
#
# Entire Period:
# einsatz 614917 Total Return: 554 / Profit:  741 / Loss:  178 / Transaction Costs:  9 / Calculated Accuracy 0.67 / #Correct Predictions: 12 Of 18
# einsatz/bet 34162.09683847773 Total Return / bet 30.77777777777778 / Transaction Costs / bet  0.5 / Calculated Accuracy 0.67
# profit in % per bet: 0.09
# einsatz * 1+profit% ^ # wetten 1016.34

# %%
import statistics
print("einsatz", einsatz)
print( statistics.median(zinseszins) )
print( statistics.median(profitpercent) )
print( statistics.median(percentlist) )
# Out:
# einsatz 1000
# 18996102804.71743
# 1.6649141006959511
# 1074

# %%
profitpercent
# Out:
# [1.6649141006959511,
#  2.072926922529257,
#  1.436493333670489,
#  1.858445249701272,
#  1.7463859351206457,
#  1.3617351052069067,
#  2.0333538816275576,
#  1.3657337245369716,
#  1.3095838214707816,
#  1.821086598590549,
#  1.286241284243581,
#  2.0845325420781124,
#  1.6161244305566138,
#  1.8783668644137568,
#  1.5941717635926567,
#  1.5662784194959585,
#  1.7447758010399892,
#  1.7840680376462423,
#  1.3783957440180121]

# %%
df_y_test_withdailyreturns.sort_values("Daily Return in USD")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2018-01-17   0.00         0.16    0.00             -2107.42
# 2019-06-28   0.00         0.66    1.00             -1851.95
# 2017-12-31   0.00         0.30    0.00             -1743.41
# 2019-07-17   0.00         0.48    0.00             -1409.18
# 2017-12-20   0.00         0.58    1.00             -1269.35
# ...           ...          ...     ...                  ...
# 2017-12-02   1.00         0.71    1.00               909.05
# 2020-04-30   1.00         0.59    1.00               993.74
# 2018-01-01   1.00         0.29    0.00              1152.82
# 2019-06-29   1.00         0.56    1.00              1240.96
# 2018-01-03   1.00         0.51    1.00              1296.05
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2018-01-17                    -0.19                11136.81
# 2019-06-28                    -0.15                12392.33
# 2017-12-31                    -0.13                13896.63
# 2019-07-17                    -0.15                 9694.45
# 2017-12-20                    -0.08                16456.23
# ...                             ...                     ...
# 2017-12-02                     0.08                10923.74
# 2020-04-30                     0.11                 8657.19
# 2018-01-01                     0.09                13436.40
# 2019-06-29                     0.10                11958.97
# 2018-01-03                     0.09                15068.49
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2018-01-17                   0.84   838.02                      0.50
# 2019-06-28                   0.66   657.10                      0.39
# 2017-12-31                   0.70   696.30                      0.42
# 2019-07-17                   0.52   524.29                      0.31
# 2017-12-20                   0.58   576.18                      0.35
# ...                           ...      ...                       ...
# 2017-12-02                   0.71   707.43                      0.42
# 2020-04-30                   0.59   591.15                      0.35
# 2018-01-01                   0.71   708.01                      0.42
# 2019-06-29                   0.56   564.08                      0.34
# 2018-01-03                   0.51   513.34                      0.31
#
# [1015 rows x 9 columns]

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]].abs().sum()
# Out:
# Class                          154.00
# y_pred_prob                    207.52
# y_pred                         238.00
# Daily Return in USD          28597.16
# percentage_daily_return          8.72
# market/price_usd_close     1308510.91
# y_pred_prob_bereinigt          230.30
# Einsatz                     230299.23
# Transaction Costs in USD       138.18
# dtype: float64

# %%
df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]].abs().sum()
# Out:
# Class                          397.00
# y_pred_prob                    338.35
# y_pred                         397.00
# Daily Return in USD          58442.74
# percentage_daily_return         17.56
# market/price_usd_close     1922546.89
# y_pred_prob_bereinigt          384.62
# Einsatz                     384618.51
# Transaction Costs in USD       230.77
# dtype: float64

# %%
dfrights = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] == df_y_test_withdailyreturns["y_pred"]]
dfwrongs = df_y_test_withdailyreturns[df_y_test_withdailyreturns["Class"] != df_y_test_withdailyreturns["y_pred"]]

# %%
dfwrongs.abs().sort_values("percentage_daily_return")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2018-07-23   0.00         0.68    1.00                 0.22
# 2017-05-22   0.00         0.74    1.00                 0.43
# 2020-01-02   1.00         0.34    0.00                 2.13
# 2018-10-31   1.00         0.49    0.00                 1.95
# 2020-09-19   0.00         0.58    1.00                 4.40
# ...           ...          ...     ...                  ...
# 2017-01-12   0.00         0.54    1.00               116.67
# 2019-06-28   0.00         0.66    1.00              1851.95
# 2015-01-16   1.00         0.38    0.00                38.01
# 2012-08-21   1.00         0.45    0.00                 2.15
# 2013-04-13   1.00         0.30    0.00                27.11
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2018-07-23                     0.00                 7713.31
# 2017-05-22                     0.00                 2114.35
# 2020-01-02                     0.00                 6985.66
# 2018-10-31                     0.00                 6317.75
# 2020-09-19                     0.00                11094.35
# ...                             ...                     ...
# 2017-01-12                     0.14                  810.62
# 2019-06-28                     0.15                12392.33
# 2015-01-16                     0.18                  207.40
# 2012-08-21                     0.22                    9.91
# 2013-04-13                     0.29                   92.81
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2018-07-23                   0.68   680.71                      0.41
# 2017-05-22                   0.74   740.76                      0.44
# 2020-01-02                   0.66   656.51                      0.39
# 2018-10-31                   0.51   511.88                      0.31
# 2020-09-19                   0.58   578.94                      0.35
# ...                           ...      ...                       ...
# 2017-01-12                   0.54   538.10                      0.32
# 2019-06-28                   0.66   657.10                      0.39
# 2015-01-16                   0.62   622.49                      0.37
# 2012-08-21                   0.55   554.12                      0.33
# 2013-04-13                   0.70   702.57                      0.42
#
# [392 rows x 9 columns]

# %%
dfrights.sort_values("percentage_daily_return")
# Out:
#             Class  y_pred_prob  y_pred  Daily Return in USD  \
# Date
# 2018-01-17   0.00         0.16    0.00             -2107.42
# 2014-04-11   0.00         0.26    0.00               -79.21
# 2013-04-14   0.00         0.25    0.00               -15.51
# 2018-11-20   0.00         0.24    0.00              -746.88
# 2019-07-17   0.00         0.48    0.00             -1409.18
# ...           ...          ...     ...                  ...
# 2019-05-12   1.00         0.72    1.00               833.00
# 2017-08-06   1.00         0.70    1.00               391.35
# 2013-11-09   1.00         0.77    1.00                43.35
# 2013-04-19   1.00         0.60    1.00                19.17
# 2013-04-18   1.00         0.52    1.00                21.91
#
#             percentage_daily_return  market/price_usd_close  \
# Date
# 2018-01-17                    -0.19                11136.81
# 2014-04-11                    -0.19                  423.41
# 2013-04-14                    -0.17                   91.11
# 2018-11-20                    -0.17                 4415.07
# 2019-07-17                    -0.15                 9694.45
# ...                             ...                     ...
# 2019-05-12                     0.12                 6972.37
# 2017-08-06                     0.12                 3219.14
# 2013-11-09                     0.13                  334.88
# 2013-04-19                     0.16                  117.87
# 2013-04-18                     0.20                  109.05
#
#             y_pred_prob_bereinigt  Einsatz  Transaction Costs in USD
# Date
# 2018-01-17                   0.84   838.02                      0.50
# 2014-04-11                   0.74   744.18                      0.45
# 2013-04-14                   0.75   745.24                      0.45
# 2018-11-20                   0.76   756.61                      0.45
# 2019-07-17                   0.52   524.29                      0.31
# ...                           ...      ...                       ...
# 2019-05-12                   0.72   716.08                      0.43
# 2017-08-06                   0.70   703.12                      0.42
# 2013-11-09                   0.77   765.68                      0.46
# 2013-04-19                   0.60   603.19                      0.36
# 2013-04-18                   0.52   524.58                      0.31
#
# [623 rows x 9 columns]

# %%
dfwrongs["year"] = dfwrongs.index.year
dfwrongs.abs().groupby(['year']).agg(['sum', 'count'])
# Out:
# <ipython-input-180-dc1a0dd5c2f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfwrongs["year"] = dfwrongs.index.year
#         Class       y_pred_prob       y_pred       Daily Return in USD        \
#           sum count         sum count    sum count                 sum count
# year
# 2011.00  8.00    18        9.69    18  10.00    18                2.67    18
# 2012.00 11.00    39       21.89    39  28.00    39                6.33    39
# 2013.00  9.00    36       20.72    36  27.00    36              273.86    36
# 2014.00 26.00    40       18.67    40  14.00    40              473.46    40
# 2015.00 14.00    47       24.74    47  33.00    47              253.11    47
# 2016.00 12.00    41       22.94    41  29.00    41              292.14    41
# 2017.00  5.00    38       22.28    38  33.00    38             5407.42    38
# 2018.00 24.00    48       23.75    48  24.00    48             8036.52    48
# 2019.00 17.00    35       17.98    35  18.00    35             4614.14    35
# 2020.00 28.00    50       24.86    50  22.00    50             9237.50    50
#
#         percentage_daily_return       market/price_usd_close        \
#                             sum count                    sum count
# year
# 2011.00                    0.59    18                  72.93    18
# 2012.00                    0.72    39                 348.71    39
# 2013.00                    1.05    36                8553.81    36
# 2014.00                    0.90    40               20609.02    40
# 2015.00                    0.92    47               13091.14    47
# 2016.00                    0.55    41               22090.48    41
# 2017.00                    1.44    38              160618.14    38
# 2018.00                    0.96    48              361810.29    48
# 2019.00                    0.57    35              232920.55    35
# 2020.00                    1.01    50              488395.83    50
#
#         y_pred_prob_bereinigt        Einsatz       Transaction Costs in USD  \
#                           sum count      sum count                      sum
# year
# 2011.00                 12.16    18 12157.39    18                     7.29
# 2012.00                 23.05    39 23053.74    39                    13.83
# 2013.00                 22.03    36 22025.37    36                    13.22
# 2014.00                 23.47    40 23474.91    40                    14.08
# 2015.00                 26.23    47 26233.01    47                    15.74
# 2016.00                 24.02    41 24021.06    41                    14.41
# 2017.00                 23.31    38 23312.36    38                    13.99
# 2018.00                 27.22    48 27218.48    48                    16.33
# 2019.00                 20.47    35 20470.60    35                    12.28
# 2020.00                 28.33    50 28332.31    50                    17.00
#
#
#         count
# year
# 2011.00    18
# 2012.00    39
# 2013.00    36
# 2014.00    40
# 2015.00    47
# 2016.00    41
# 2017.00    38
# 2018.00    48
# 2019.00    35
# 2020.00    50

# %%
dfrights["year"] = dfrights.index.year
dfrights.abs().groupby(['year']).agg(['sum', 'count'])
# Out:
# <ipython-input-181-90c79a75818e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfrights["year"] = dfrights.index.year
#         Class       y_pred_prob       y_pred       Daily Return in USD        \
#           sum count         sum count    sum count                 sum count
# year
# 2011.00  7.00    21        9.13    21   7.00    21                3.73    21
# 2012.00 54.00    72       40.52    72  54.00    72               11.81    72
# 2013.00 66.00    80       50.14    80  66.00    80              992.57    80
# 2014.00 21.00    67       30.61    67  21.00    67              789.24    67
# 2015.00 39.00    66       34.39    66  39.00    66              489.38    66
# 2016.00 51.00    64       37.08    64  51.00    64              520.04    64
# 2017.00 61.00    68       43.51    68  61.00    68            10273.48    68
# 2018.00 28.00    62       29.32    62  28.00    62            18614.62    62
# 2019.00 36.00    62       32.66    62  36.00    62            13936.25    62
# 2020.00 34.00    61       30.99    61  34.00    61            12811.61    61
#
#         percentage_daily_return       market/price_usd_close        \
#                             sum count                    sum count
# year
# 2011.00                    0.76    21                 113.33    21
# 2012.00                    1.44    72                 596.69    72
# 2013.00                    3.79    80               15364.76    80
# 2014.00                    1.58    67               35508.94    67
# 2015.00                    1.73    66               17578.97    66
# 2016.00                    0.90    64               36656.27    64
# 2017.00                    2.11    68              265295.31    68
# 2018.00                    2.20    62              496864.84    62
# 2019.00                    1.73    62              453909.64    62
# 2020.00                    1.32    61              600658.13    61
#
#         y_pred_prob_bereinigt        Einsatz       Transaction Costs in USD  \
#                           sum count      sum count                      sum
# year
# 2011.00                 15.32    21 15317.44    21                     9.19
# 2012.00                 44.03    72 44033.32    72                    26.42
# 2013.00                 52.76    80 52763.73    80                    31.66
# 2014.00                 41.47    67 41473.87    67                    24.88
# 2015.00                 37.42    66 37415.87    66                    22.45
# 2016.00                 38.25    64 38249.08    64                    22.95
# 2017.00                 44.64    68 44642.33    68                    26.79
# 2018.00                 37.59    62 37591.73    62                    22.56
# 2019.00                 37.14    62 37140.83    62                    22.28
# 2020.00                 35.99    61 35990.32    61                    21.59
#
#
#         count
# year
# 2011.00    21
# 2012.00    72
# 2013.00    80
# 2014.00    67
# 2015.00    66
# 2016.00    64
# 2017.00    68
# 2018.00    62
# 2019.00    62
# 2020.00    61

# %%
predictors
# Out:
# array([[2.3838902e+00, 3.2931430e+00, 1.0847017e+01, ..., 4.1740000e+03,
#         6.2400000e+02, 7.5000000e+01],
#        [2.4553063e+00, 3.7208679e+00, 1.1650000e+01, ..., 4.1710000e+03,
#         6.2700000e+02, 7.5000000e+01],
#        [2.4380770e+00, 3.7733192e+00, 1.1450998e+01, ..., 4.1870000e+03,
#         6.2500000e+02, 7.5000000e+01],
#        ...,
#        [9.7794752e+00, 3.2141380e+00, 1.7667381e+04, ..., 1.6238000e+04,
#         2.2320000e+03, 1.1100000e+02],
#        [9.7876406e+00, 3.1547880e+00, 1.7812232e+04, ..., 1.6242000e+04,
#         2.2280000e+03, 1.1300000e+02],
#        [9.7868166e+00, 2.8492196e+00, 1.7797553e+04, ..., 1.6199000e+04,
#         2.2290000e+03, 1.1200000e+02]], dtype=float32)

# %% [markdown]
# # Bet on tomorrow

# %%
# Split Data into Training and Testing
#X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, stratify=target)

# Amount of Columns
n_nodes = predictors.shape[1]
print("Amount of Columns", n_nodes)

# Instantiation of MinMaxScaler
norm_scaler = MinMaxScaler()

# Training and Application of Feature Scaler on Training Data of Predictors
predictors_scaled = pd.DataFrame(norm_scaler.fit_transform(predictors))

# Instantiate Classifier Logistic Regression
lreg = LogisticRegression(max_iter=12000) 

# Train Classifier
lreg.fit(predictors_scaled, target)
# Out:
# Amount of Columns 101
# LogisticRegression(max_iter=12000)

# %% [markdown]
# # get x train data of today to predict tomorrow y

# %%
most_current_day = df_dataset1.tail(1)
dateofprediction = most_current_day.index
most_current_day
# Out:
#             Log Price in USD  Volatility Daily Log Return in Percent 5D  \
# Date
# 2020-11-19              9.79                                       2.85
#
#             market/price_usd_close  market/price_drawdown_relative  \
# Date
# 2020-11-19                17797.55                           -0.10
#
#             market/price_realized_usd  market/mvrv   mining/difficulty_latest  \
# Date
# 2020-11-19                    7059.76         2.52 75577685065077505392640.00
#
#               mining/hash_rate_mean  mining/revenue_sum  \
# Date
# 2020-11-19 119777232389561008128.00              944.13
#
#             mining/marketcap_thermocap_ratio  ...  \
# Date                                          ...
# 2020-11-19                              0.00  ...
#
#             addresses/new_non_zero_count  addresses/non_zero_count  \
# Date
# 2020-11-19                     517332.00               32544167.00
#
#             addresses/min_point_zero_1_count  addresses/min_point_1_count  \
# Date
# 2020-11-19                        8542553.00                   3125440.00
#
#             addresses/min_1_count  addresses/min_10_count  \
# Date
# 2020-11-19              819280.00               154441.00
#
#             addresses/min_100_count  addresses/min_1k_count  \
# Date
# 2020-11-19                 16199.00                 2229.00
#
#             addresses/min_10k_count  Class
# Date
# 2020-11-19                   112.00   1.00
#
# [1 rows x 102 columns]

# %%
# Setup of Predictors (Indpendent Variables) by Excluding Target Variable
most_current_day_predictors = most_current_day.drop(['Class'], axis=1).values.astype(np.float32)

# %%
# Scaler Transformation of Entire Training Set - Input for Cross-Validation
most_current_day_predictors_scaled = norm_scaler.transform(most_current_day_predictors)
most_current_day_predictors_scaled
# Out:
# array([[9.89542544e-01, 6.47115335e-02, 9.08603013e-01, 8.91337216e-01,
#         1.00000000e+00, 3.97907794e-01, 8.79957378e-01, 7.45044291e-01,
#         2.42989957e-02, 1.69397533e-01, 3.16666692e-01, 3.75196755e-01,
#         7.10345447e-01, 9.89867687e-01, 9.29632187e-01, 3.05319205e-04,
#         6.18719980e-02, 6.13905303e-03, 2.40597525e-03, 4.39441293e-01,
#         6.90220773e-01, 3.25946920e-02, 3.26675586e-02, 9.92350876e-01,
#         9.94406223e-01, 1.21667413e-02, 1.00000000e+00, 9.73699093e-01,
#         9.87547994e-01, 2.72292104e-02, 9.41260755e-01, 8.99725318e-01,
#         8.75262558e-01, 9.81935322e-01, 2.26886839e-01, 3.36511493e-01,
#         5.18653154e-01, 1.89320758e-01, 2.55086035e-01, 3.27392995e-01,
#         6.47892356e-01, 6.30797088e-01, 6.06251299e-01, 4.44215149e-01,
#         5.51810682e-01, 1.00000000e+00, 3.05010900e-02, 9.84585471e-03,
#         6.30564332e-01, 7.10365355e-01, 3.26662362e-02, 4.93381545e-03,
#         1.32220030e-01, 1.52960911e-01, 1.63530529e-01, 3.85697156e-01,
#         7.98530579e-01, 3.87305737e-01, 4.65142012e-01, 5.00654995e-01,
#         3.09608108e-03, 3.43351848e-02, 5.38568422e-02, 1.23290569e-01,
#         9.49729323e-01, 1.20665699e-01, 4.33734894e-01, 7.86127269e-01,
#         4.65060145e-01, 2.86175609e-01, 1.42112315e-01, 1.03716329e-01,
#         3.85931395e-02, 4.24200371e-02, 9.94393677e-02, 4.66772281e-02,
#         9.63904858e-02, 5.86344907e-03, 9.00752068e-01, 5.60680270e-01,
#         1.19311066e-04, 3.28598320e-01, 1.10788196e-01, 3.75557020e-02,
#         8.99846137e-01, 9.13855374e-01, 9.90377292e-02, 3.42885517e-02,
#         4.70118746e-02, 8.23243201e-01, 7.82313764e-01, 6.66322827e-01,
#         6.44636095e-01, 9.90584075e-01, 9.75318134e-01, 9.80013430e-01,
#         9.91715610e-01, 9.69050288e-01, 8.36905122e-01, 9.95043397e-01,
#         7.77777910e-01]], dtype=float32)

# %%
# Prediction of Classes
most_current_day_pred = lreg.predict(most_current_day_predictors_scaled)
most_current_day_pred
# Out:
# array([1.], dtype=float32)

# %%
# Prediction of Probabilities
most_current_day_pred_prob = lreg.predict_proba(most_current_day_predictors_scaled)[:,1]
most_current_day_pred_prob[0]
# Out:
# 0.543148953183009

# %%
dateofprediction[0]
# Out:
# Timestamp('2020-11-19 00:00:00')

# %%
predicted_df = pd.DataFrame([[dateofprediction[0],most_current_day_pred_prob[0],most_current_day_pred[0]]], index=dateofprediction, columns=["dateofprediction","most_current_day_pred_prob","most_current_day_pred"])
predicted_df
# Out:
#            dateofprediction  most_current_day_pred_prob  most_current_day_pred
# Date
# 2020-11-19       2020-11-19                        0.54                   1.00

# %% [markdown]
# # Store DF of the one prediction in database

# %%
from datetime import datetime
from sqlalchemy import create_engine

engine = create_engine("mysql://root:root@127.0.0.1/btc_predictions")

predicted_df.to_sql(name="btc_preds", 
                con=engine, index=False,
                if_exists='append', 
                )
